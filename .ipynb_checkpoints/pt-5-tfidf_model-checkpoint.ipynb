# %% [markdown]
# #### TFIDF Recommender System
# Since the results for the Bag of Words model were underwhelming, I decided to try a TFIDF approach. The reasoning for the text normalization and parameters are the same, but TFIDF allows us to give weight to words, so unique words specific to the queries are ranked higher, and words that appear in more documents are lower. For example, the query, "musical instrument store" will rank "musical" and "instrument" higher, while store will get a lower score since it appears more often in the text.

# %%
import pandas as pd
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import re

# %%
stop_words = set(stopwords.words("english"))

PATTERN_S = re.compile("\'s")  # matches `'s` from text  
PATTERN_RN = re.compile("\\r\\n\\b") #matches `\r` and `\n`
PATTERN_PUNC = re.compile(r"[^\w\s]") # matches all non 0-9 A-z whitespace 


def clean_text(text):
    """
    Series of cleaning. String to lower case, remove non words characters and numbers (punctuation, curly brackets etc).
        text (str): input text
    return (str): modified initial text
    """
    text = text.lower()  # lowercase text
    # replace the matched string with ' '
    text = re.sub(PATTERN_S, ' ', text)
    text = re.sub(PATTERN_RN, ' ', text)
    text = re.sub(PATTERN_PUNC, ' ', text)
    return text

def tokenizer(description, stop_words, normalization):
    
    if normalization == 'lemmatize':
        # tokenize and lemmatize text
        lemmatizer = WordNetLemmatizer()
        tokens = [lemmatizer.lemmatize(w) for w in word_tokenize(description)]
        
    elif normalization == 'stem':
        # tokenize and stem text
        stemmer = PorterStemmer()
        tokens = [stemmer.stem(w) for w in word_tokenize(description)]
    
   # remove tokens length of 2 or below and make all lowercase and remove stop words
    tokens = [w.lower() for w in tokens if (w.lower() not in stop_words) and (len(w) > 2) and(w.isalpha())]
    
    return tokens    
    
def process_query(query, normalization):
    stop_words = set(stopwords.words("english"))
    
    return tokenizer(clean_text(query), stop_words, normalization)

# %%
# code example taken from https://towardsdatascience.com/build-a-text-recommendation-system-with-python-e8b95d9f251c
def retrieve_top_n(m, max_docs):
    # return the sum on all tokens of cosinus for each sentence
    if len(m.shape) > 1:
        cos_sim = np.mean(m, axis=0) 
    else: 
        cos_sim = m
    index = np.argsort(cos_sim)[::-1] # from highest idx to smallest score \
    mask = np.ones(len(cos_sim))
    mask = np.logical_or(cos_sim[index] != 0, mask) #eliminate 0 cosine distance
    best_index = index[mask][:max_docs]  
    return best_index

# %%
class TfidfRecommenderSystem:
    def __init__(self, docs, alpha=1.0, beta=0.75, gamma=0.15):
        self.alpha, self.beta, self.gamma = alpha, beta, gamma
        
        # create a doc-term matrix out of our doc collection
        self.vec = TfidfVectorizer()
        doc_term_mat = self.vec.fit_transform([" ".join(docs[doc_id]) for doc_id in docs])
        result = doc_term_mat
        
        self.q_vecs = {}
        
        self.doc_vecs = result # document vectors in a matrix
        
    def retrieve_docs(self, query, max_docs=10, normalization='lemmatize'):
        query = ' '.join(process_query(query, normalization))
        
        if query not in self.q_vecs:
            q_vec = self.vec.transform([query])
            self.q_vecs[query] = q_vec
        
        ret_docs = {}
        
        mat = cosine_similarity(self.q_vecs[query], self.doc_vecs)
        best_index = retrieve_top_n(mat, max_docs=max_docs)
        
        return best_index

# %%
df = pd.read_pickle(r'assets/processed_df.pkl')
docs = dict(zip(df['naics'], df['lemmatized']))

# %%
tfidf_model = TfidfRecommenderSystem(docs)

# %%
best_index = tfidf_model.retrieve_docs('library', normalization='lemmatize')

# %%
naics_titles = pd.read_excel('assets/6-digit_2017_Codes.xlsx')
naics_titles['naics'] = naics_titles['naics'].astype(str)

# %%
df = df.merge(naics_titles, on='naics', how='outer')

# %%
df.iloc[best_index][['naics', 'title']]
# Out:
#       naics                                              title
# 719  519120                            Libraries and Archives
# 721  519190                     All Other Information Services
# 703  512199         Other Motion Picture and Video Industries
# 474  337127             Institutional Furniture Manufacturing
# 718  519110                                    News Syndicates
# 470  337121     Upholstered Household Furniture Manufacturing
# 472  337124           Metal Household Furniture Manufacturing
# 471  337122  Nonupholstered Wood Household Furniture Manufa...
# 473  337125  Household Furniture (except Wood and Metal) Ma...
# 720  519130  Internet Publishing and Broadcasting and Web S...

# %%
relevant_naics = pd.read_pickle('assets/relevant_naics_df.pkl')

# %%
relevant_naics.head()
# Out:
#                     query                                    relevant_naics
# 0  Home improvement store                  [444110, 444120, 444130, 444190]
# 1    Diesel fuel supplier                                  [424710, 424720]
# 2                  Church                                          [813110]
# 3                    Farm  [115116, 115111, 115112, 115113, 115114, 115115]
# 4           Seed supplier  [424910, 424920, 424930, 424940, 424950, 424990]

# %%
max_docs = 10

# %% [markdown]
# ## Test Results

# %%
def calc_pre_rec_at_n(ret_docs, reljudges, n=-1):
    """
    Calculate precision and recall at n for each query in ret_docs
    """
    
    pre_at_n, rec_at_n = {}, {}
    
    for k, v in ret_docs.items():
        if n > -1 and n <= len(ret_docs):
            s1 = set(v[:n])
        else:
            s1 = set(v)
        s2 = reljudges[k]
        precision = len(s1.intersection(s2)) / len(s1)
        recall = len(s1.intersection(s2)) / len(reljudges[k])
        pre_at_n[k] = round(precision, 3)
        rec_at_n[k] = round(recall, 3)
    return pre_at_n, rec_at_n

# %%
def calc_avg_pre(ret_docs, reljudges, cutoff=-1):
    """
    Calculate (mean) average precision for each query in ret_docs
    """
    
    avg_pre, mean_avg_pre = {}, None
    for k, v in ret_docs.items():
        total_rel = 0
        total = 0
        avg_prec = 0
        for i, doc in enumerate(v):
            if doc in reljudges[k] and cutoff == -1:
                total_rel += 1
                total += 1
                precision = total_rel/total
            elif doc in reljudges[k] and i+1 <= cutoff:
                total_rel += 1
                total += 1
                precision = total_rel/total
            else:
                total += 1
                precision = 0
            avg_prec += precision

        avg_pre[k] = round(avg_prec/len(reljudges[k]), 3,)
    
    mean_avg_pre = round(sum(avg_pre.values()) / len(avg_pre), 3)
        
    return avg_pre, mean_avg_pre

# %%
import math

def calc_NDCG_at_n(ret_docs, reljudges, n=-1, base=2):
    """
    Calculate NDCG at n for each query in ret_docs
    """
    
    ndcg = {}
    
    for k, v in ret_docs.items():
        
        counts = list(reversed([x for x in range(2,len(reljudges[k])+2)]))
        ideals = {reljudges[k][i]: counts[i] for i in range(len(reljudges[k]))}
        
        add_ons = {}
        if len(v) > len(reljudges[k]):
            for i in range(len(v)-len(reljudges[k])):
                add_ons[i] = 1
        ideals.update(add_ons)
        nums = list(map(ideals.get, v))
        
        systems = {}
        for i, doc in enumerate(v):
            if nums[i] == None:
                systems[doc] = 1
            else:
                systems[doc] = nums[i]
                
        ideal_order = {}
        if n != -1:
            for i, (key, value) in enumerate(ideals.items()):
                if i < n:
                    ideal_order[key] = value
        else:
            ideal_order = ideals
        
        add_ons = {}
        
        
        log = 0
        for i, (doc, rank) in enumerate(ideal_order.items()):
            if i >= len(v):
                break
            elif i < base:
                log += rank
            else:
                log += rank/math.log(i+1, base)

                
        system_order = {}
        if n != -1:
            for i, (key, value) in enumerate(systems.items()):
                if i < n:
                    system_order[key] = value
        else:
            system_order = systems
        
        
        
        system_log = 0
        for i, (doc, rank) in enumerate(system_order.items()):
            if i >= len(v):
                break
            elif i < base:
                system_log += rank
            else:
                system_log += rank/math.log(i+1, base)
        system_log / log
        ndcg[k] = round(system_log / log, 3)
        
    
    return ndcg

# %%
ret_docs_dic = {}
queries_dic = {}

for query in relevant_naics.iterrows():
    query_name =  ' '.join(process_query(query[1]['query'], 'lemmatize'))
    ret_docs_index = tfidf_model.retrieve_docs(query_name, max_docs=max_docs, normalization='lemmatize')
    ret_docs = df.iloc[ret_docs_index]['naics'].tolist()

    query_docs = query[1]['relevant_naics']
    ret_docs_dic[query_name] = ret_docs
    queries_dic[query_name] = query_docs

# %%
ret_docs_dic
# Out:
# {'home improvement store': ['442299',
#   '453998',
#   '453991',
#   '442291',
#   '453930',
#   '453910',
#   '453920',
#   '453310',
#   '445299',
#   '444110'],
#  'diesel fuel supplier': ['447190',
#   '447110',
#   '454310',
#   '221112',
#   '445120',
#   '333618',
#   '454390',
#   '213115',
#   '336310',
#   '333611'],
#  'church': ['813110',
#   '337127',
#   '337121',
#   '337124',
#   '337122',
#   '337125',
#   '337110',
#   '423490',
#   '236220',
#   '327991'],
#  'farm': ['115116',
#   '115115',
#   '115111',
#   '115113',
#   '115112',
#   '115114',
#   '114210',
#   '112512',
#   '112519',
#   '115210'],
#  'seed supplier': ['111120',
#   '111110',
#   '111140',
#   '111150',
#   '111160',
#   '111199',
#   '111191',
#   '111219',
#   '111211',
#   '311911'],
#  'accountant': ['541211',
#   '541219',
#   '541213',
#   '541214',
#   '813920',
#   '332911',
#   '332721',
#   '332722',
#   '332811',
#   '332812'],
#  'trucking company': ['484220',
#   '484230',
#   '484110',
#   '484122',
#   '484121',
#   '484210',
#   '551111',
#   '551112',
#   '551114',
#   '561110'],
#  'exporter': ['522293',
#   '928120',
#   '332919',
#   '332811',
#   '332812',
#   '332813',
#   '332911',
#   '332912',
#   '332913',
#   '332991'],
#  'grain elevator': ['111191',
#   '111199',
#   '333921',
#   '311213',
#   '311211',
#   '311212',
#   '493130',
#   '424510',
#   '311119',
#   '111998'],
#  'popcorn store': ['445299',
#   '445292',
#   '453991',
#   '453998',
#   '453910',
#   '453920',
#   '453930',
#   '442299',
#   '446199',
#   '453310'],
#  'agricultural service': ['812990',
#   '812910',
#   '812930',
#   '541990',
#   '541890',
#   '812922',
#   '812921',
#   '812191',
#   '812113',
#   '812320'],
#  'warehouse': ['452311',
#   '452319',
#   '493130',
#   '493110',
#   '493120',
#   '493190',
#   '425110',
#   '425120',
#   '424610',
#   '424710'],
#  'agricultural production': ['112390',
#   '111310',
#   '111130',
#   '111110',
#   '111140',
#   '111150',
#   '112330',
#   '111120',
#   '111160',
#   '111910'],
#  'ranch': ['112340',
#   '112330',
#   '112320',
#   '114210',
#   '112210',
#   '112420',
#   '115210',
#   '112130',
#   '112390',
#   '112120'],
#  'holding company': ['551112',
#   '551111',
#   '551114',
#   '561110',
#   '561740',
#   '561410',
#   '561440',
#   '561730',
#   '561710',
#   '561510'],
#  'farm equipment supplier': ['115116',
#   '115115',
#   '333111',
#   '115111',
#   '115113',
#   '114210',
#   '112512',
#   '112519',
#   '115112',
#   '115114'],
#  'store': ['453991',
#   '453998',
#   '453910',
#   '445299',
#   '453920',
#   '453930',
#   '442299',
#   '445292',
#   '446199',
#   '453310'],
#  'grocery store': ['445110',
#   '453991',
#   '453998',
#   '453910',
#   '445299',
#   '453920',
#   '453930',
#   '442299',
#   '445292',
#   '445120'],
#  'rice mill': ['311212',
#   '111160',
#   '311211',
#   '111199',
#   '311119',
#   '311111',
#   '322130',
#   '333519',
#   '322122',
#   '322121'],
#  'food product supplier': ['311119',
#   '311111',
#   '311930',
#   '722310',
#   '311991',
#   '445230',
#   '311920',
#   '445220',
#   '722320',
#   '311911'],
#  'accounting firm': ['541211',
#   '541219',
#   '541213',
#   '541214',
#   '236118',
#   '236116',
#   '525190',
#   '236115',
#   '236210',
#   '236220'],
#  'produce market': ['425110',
#   '445220',
#   '445230',
#   '445210',
#   '425120',
#   '111191',
#   '522294',
#   '312120',
#   '112210',
#   '312140'],
#  'pet supply store': ['453910',
#   '453991',
#   '453998',
#   '453210',
#   '453920',
#   '453930',
#   '453310',
#   '446199',
#   '453110',
#   '444190'],
#  'wholesaler': ['423220',
#   '423690',
#   '423510',
#   '424130',
#   '423450',
#   '423710',
#   '424210',
#   '424120',
#   '423440',
#   '424690'],
#  'produce wholesaler': ['423220',
#   '423690',
#   '423510',
#   '424130',
#   '423450',
#   '423710',
#   '424210',
#   '424120',
#   '423440',
#   '424690'],
#  'distribution service': ['541890',
#   '812990',
#   '541870',
#   '541990',
#   '812910',
#   '221210',
#   '812930',
#   '541860',
#   '812922',
#   '812921'],
#  'crop grower': ['111411',
#   '111419',
#   '111992',
#   '111998',
#   '111991',
#   '111310',
#   '111910',
#   '111920',
#   '111930',
#   '111211'],
#  'addiction treatment center': ['621420',
#   '621498',
#   '621493',
#   '221320',
#   '562219',
#   '621492',
#   '562211',
#   '621491',
#   '221310',
#   '221330'],
#  'natural good store': ['453991',
#   '453998',
#   '453910',
#   '445299',
#   '453920',
#   '453310',
#   '453930',
#   '445291',
#   '451110',
#   '445292'],
#  'orchard': ['111331',
#   '115116',
#   '111310',
#   '111130',
#   '111110',
#   '111140',
#   '111150',
#   '111120',
#   '111160',
#   '111910'],
#  'lumber store': ['453991',
#   '453998',
#   '444190',
#   '453910',
#   '445299',
#   '453920',
#   '453930',
#   '321912',
#   '321113',
#   '442299'],
#  'mine': ['212230',
#   '212222',
#   '212221',
#   '212210',
#   '212113',
#   '212112',
#   '212311',
#   '212291',
#   '212313',
#   '212111'],
#  'transportation service': ['488999',
#   '488991',
#   '488510',
#   '485991',
#   '488210',
#   '488190',
#   '488330',
#   '485999',
#   '488490',
#   '488390'],
#  'investment company': ['523930',
#   '551111',
#   '551112',
#   '523999',
#   '525990',
#   '551114',
#   '523991',
#   '523910',
#   '525910',
#   '523920'],
#  'fruit wholesaler': ['424590',
#   '424490',
#   '423220',
#   '423690',
#   '423510',
#   '424130',
#   '423450',
#   '424430',
#   '423710',
#   '424210'],
#  'real estate agency': ['531390',
#   '531320',
#   '531312',
#   '531311',
#   '531210',
#   '531190',
#   '531130',
#   '531110',
#   '531120',
#   '533110'],
#  'event venue': ['711219',
#   '711211',
#   '711212',
#   '711320',
#   '711310',
#   '711410',
#   '711120',
#   '711190',
#   '722320',
#   '711510'],
#  'frozen dessert supplier': ['311520',
#   '311412',
#   '311411',
#   '311813',
#   '424420',
#   '311512',
#   '311812',
#   '445210',
#   '311999',
#   '311514'],
#  'wine wholesaler importer': ['424820',
#   '424810',
#   '423220',
#   '445310',
#   '312130',
#   '423690',
#   '423510',
#   '424130',
#   '423450',
#   '423710'],
#  'winery': ['312130',
#   '312120',
#   '312140',
#   '312113',
#   '312112',
#   '312111',
#   '312230',
#   '332991',
#   '332919',
#   '332913'],
#  'aerospace company': ['551111',
#   '336414',
#   '551112',
#   '551114',
#   '336411',
#   '336413',
#   '336419',
#   '336412',
#   '336415',
#   '336999'],
#  'cold storage facility': ['493190',
#   '493120',
#   '493130',
#   '493110',
#   '335911',
#   '486210',
#   '334112',
#   '711310',
#   '713930',
#   '711320'],
#  'employment agency': ['561311',
#   '561312',
#   '561330',
#   '926110',
#   '561320',
#   '923140',
#   '925120',
#   '926150',
#   '921190',
#   '561599'],
#  'plant nursery': ['111421',
#   '111422',
#   '444220',
#   '111411',
#   '111419',
#   '424930',
#   '111910',
#   '111920',
#   '111930',
#   '111940'],
#  'air conditioning contractor': ['238220',
#   '238210',
#   '333415',
#   '238310',
#   '238910',
#   '238990',
#   '238130',
#   '238110',
#   '238320',
#   '238140'],
#  'air conditioning repair service': ['811198',
#   '811111',
#   '811118',
#   '811191',
#   '811420',
#   '811412',
#   '811113',
#   '811192',
#   '811490',
#   '811430'],
#  'fruit vegetable wholesaler': ['311411',
#   '424490',
#   '424590',
#   '424480',
#   '445230',
#   '424420',
#   '424430',
#   '423220',
#   '423690',
#   '423510'],
#  'aircraft rental service': ['336411',
#   '532289',
#   '532284',
#   '532282',
#   '532281',
#   '532283',
#   '488190',
#   '336412',
#   '336413',
#   '532111'],
#  'monastery': ['813110',
#   '928120',
#   '332721',
#   '332996',
#   '332994',
#   '332993',
#   '332992',
#   '332991',
#   '332919',
#   '332913'],
#  'allergist': ['621111',
#   '928120',
#   '332721',
#   '332996',
#   '332994',
#   '332993',
#   '332992',
#   '332991',
#   '332919',
#   '332913'],
#  'herb shop': ['453220',
#   '812112',
#   '325414',
#   '332710',
#   '325412',
#   '325411',
#   '325413',
#   '812111',
#   '442299',
#   '811121'],
#  'aluminum supplier': ['331318',
#   '331313',
#   '331314',
#   '331315',
#   '331492',
#   '331491',
#   '331410',
#   '331524',
#   '325180',
#   '331420'],
#  'ambulance service': ['812990',
#   '812910',
#   '812930',
#   '541990',
#   '541890',
#   '812922',
#   '812921',
#   '621910',
#   '812191',
#   '812113'],
#  'wholesale plant nursery': ['424930',
#   '111421',
#   '425120',
#   '424910',
#   '111422',
#   '424920',
#   '424950',
#   '424940',
#   '424610',
#   '424710'],
#  'amusement machine supplier': ['713110',
#   '713120',
#   '713990',
#   '713950',
#   '713930',
#   '713920',
#   '713910',
#   '713940',
#   '713210',
#   '333517'],
#  'animal hospital': ['112990',
#   '112930',
#   '112920',
#   '112910',
#   '112340',
#   '112330',
#   '112320',
#   '112210',
#   '112420',
#   '112519'],
#  'farmer market': ['425110',
#   '445220',
#   '445210',
#   '445230',
#   '425120',
#   '522294',
#   '424610',
#   '424710',
#   '424340',
#   '424480'],
#  'vaporizer store': ['453991',
#   '453998',
#   '453910',
#   '445299',
#   '453920',
#   '453930',
#   '442299',
#   '445292',
#   '446199',
#   '453310'],
#  'cigar shop': ['453220',
#   '812112',
#   '332710',
#   '312230',
#   '812111',
#   '442299',
#   '453991',
#   '811121',
#   '722515',
#   '811198'],
#  'tobacco shop': ['312230',
#   '453220',
#   '812112',
#   '332710',
#   '312120',
#   '312140',
#   '312113',
#   '312130',
#   '312112',
#   '312111'],
#  'well drilling contractor': ['238210',
#   '238910',
#   '238310',
#   '238990',
#   '213111',
#   '238130',
#   '238110',
#   '238320',
#   '238140',
#   '238220'],
#  'library': ['519120',
#   '519190',
#   '512199',
#   '337127',
#   '519110',
#   '337121',
#   '337124',
#   '337122',
#   '337125',
#   '519130'],
#  'apartment building': ['444190',
#   '236220',
#   '236116',
#   '236210',
#   '444130',
#   '336611',
#   '444110',
#   '444120',
#   '236117',
#   '236118'],
#  'apartment rental agency': ['532289',
#   '532284',
#   '532282',
#   '532281',
#   '532283',
#   '532111',
#   '532210',
#   '532120',
#   '532420',
#   '532411'],
#  'dairy farm': ['311514',
#   '115116',
#   '311512',
#   '311511',
#   '115115',
#   '112120',
#   '115210',
#   '311513',
#   '115111',
#   '115113'],
#  'architect': ['541320',
#   '541310',
#   '813920',
#   '423490',
#   '928120',
#   '332912',
#   '332722',
#   '332811',
#   '332812',
#   '332813'],
#  'organic farm': ['325199',
#   '115116',
#   '115115',
#   '115111',
#   '115113',
#   '115112',
#   '115114',
#   '114210',
#   '112512',
#   '112519'],
#  'architectural designer': ['541490',
#   '332323',
#   '541310',
#   '541410',
#   '541340',
#   '541320',
#   '332322',
#   '337212',
#   '332321',
#   '541350'],
#  'architecture firm': ['541490',
#   '236118',
#   '236116',
#   '525190',
#   '236115',
#   '236210',
#   '236220',
#   '525120',
#   '525110',
#   '523110'],
#  'livestock producer': ['115210',
#   '488999',
#   '311119',
#   '424520',
#   '311111',
#   '311520',
#   '311230',
#   '311340',
#   '311710',
#   '311830'],
#  'dairy supplier': ['311514',
#   '311512',
#   '311511',
#   '311513',
#   '311520',
#   '112120',
#   '112111',
#   '115210',
#   '112112',
#   '445299'],
#  'biotechnology company': ['541714',
#   '541715',
#   '551111',
#   '551112',
#   '551114',
#   '561110',
#   '561740',
#   '561410',
#   '561440',
#   '561730'],
#  'artist': ['711130',
#   '711190',
#   '711410',
#   '711120',
#   '711510',
#   '711110',
#   '711320',
#   '711212',
#   '711310',
#   '711211'],
#  'egg supplier': ['112310',
#   '112330',
#   '112390',
#   '112340',
#   '112320',
#   '322299',
#   '311999',
#   '311991',
#   '322291',
#   '561320'],
#  'poultry farm': ['112340',
#   '112390',
#   '115116',
#   '115210',
#   '115115',
#   '112330',
#   '112320',
#   '311615',
#   '112310',
#   '333111'],
#  'chicken hatchery': ['112320',
#   '112310',
#   '112340',
#   '112390',
#   '112511',
#   '114210',
#   '115210',
#   '115115',
#   '115111',
#   '115113'],
#  'art organization': ['711320',
#   '711310',
#   '711190',
#   '711120',
#   '711510',
#   '711110',
#   '711410',
#   '711130',
#   '711212',
#   '711211'],
#  'association organization': ['813990',
#   '813920',
#   '813910',
#   '813410',
#   '813312',
#   '813319',
#   '813930',
#   '813311',
#   '813940',
#   '813212'],
#  'food store': ['445299',
#   '445292',
#   '445291',
#   '445120',
#   '445110',
#   '453991',
#   '445230',
#   '453998',
#   '445220',
#   '453910'],
#  'deli': ['424470',
#   '928120',
#   '332722',
#   '332999',
#   '332996',
#   '332994',
#   '332993',
#   '332992',
#   '332991',
#   '332919'],
#  'bank': ['521110',
#   '522320',
#   '522190',
#   '522110',
#   '551111',
#   '621991',
#   '522293',
#   '523991',
#   '522120',
#   '522210'],
#  'fish processing': ['445220',
#   '311710',
#   '114210',
#   '112511',
#   '518210',
#   '114119',
#   '114111',
#   '114112',
#   '445299',
#   '445110'],
#  'fish farm': ['115116',
#   '114210',
#   '112511',
#   '114119',
#   '115115',
#   '114111',
#   '114112',
#   '115111',
#   '115113',
#   '115112'],
#  'seafood wholesaler': ['311710',
#   '424490',
#   '424460',
#   '423220',
#   '424430',
#   '423690',
#   '423510',
#   '424130',
#   '423450',
#   '424420'],
#  'tropical fish store': ['445299',
#   '453991',
#   '453998',
#   '453910',
#   '445292',
#   '445291',
#   '453920',
#   '453930',
#   '442299',
#   '445220'],
#  'non profit organization': ['813312',
#   '813319',
#   '813990',
#   '813311',
#   '611710',
#   '812191',
#   '813940',
#   '813910',
#   '813930',
#   '813920'],
#  'economic development agency': ['926110',
#   '541714',
#   '925120',
#   '541713',
#   '541715',
#   '541720',
#   '925110',
#   '561311',
#   '926130',
#   '926150'],
#  'seafood market': ['311710',
#   '445220',
#   '424460',
#   '425110',
#   '424490',
#   '445299',
#   '311412',
#   '311422',
#   '311999',
#   '311991'],
#  'honey farm': ['115116',
#   '115115',
#   '112910',
#   '115111',
#   '115113',
#   '115112',
#   '115114',
#   '114210',
#   '112512',
#   '112920'],
#  'horse breeder': ['115210',
#   '112920',
#   '711212',
#   '487110',
#   '711219',
#   '112990',
#   '713950',
#   '713930',
#   '713120',
#   '713920'],
#  'asphalt contractor': ['324122',
#   '324121',
#   '238210',
#   '238910',
#   '238310',
#   '238990',
#   '238130',
#   '238110',
#   '238320',
#   '238140'],
#  'livestock dealer': ['441228',
#   '441222',
#   '441120',
#   '441210',
#   '444190',
#   '441110',
#   '444130',
#   '441320',
#   '444120',
#   '453998'],
#  'department store': ['452210',
#   '453991',
#   '453998',
#   '452319',
#   '453910',
#   '445299',
#   '453920',
#   '453930',
#   '442299',
#   '445292'],
#  'mill': ['311119',
#   '311111',
#   '322130',
#   '333519',
#   '322122',
#   '322121',
#   '322110',
#   '315190',
#   '314120',
#   '314110'],
#  'atv dealer': ['441228',
#   '441222',
#   '441120',
#   '441210',
#   '444190',
#   '441110',
#   '444130',
#   '441320',
#   '444120',
#   '453998'],
#  'audio visual consultant': ['334614',
#   '541430',
#   '541410',
#   '334310',
#   '334613',
#   '621320',
#   '532310',
#   '611710',
#   '443142',
#   '512240'],
#  'pallet supplier': ['321920',
#   '493110',
#   '333924',
#   '322211',
#   '321999',
#   '321991',
#   '561320',
#   '321992',
#   '332999',
#   '322212'],
#  'wood supplier': ['321920',
#   '321999',
#   '321992',
#   '321918',
#   '321911',
#   '321991',
#   '321214',
#   '321912',
#   '321213',
#   '321219'],
#  'hardware store': ['444130',
#   '453991',
#   '453998',
#   '453910',
#   '445299',
#   '453920',
#   '453930',
#   '452319',
#   '442299',
#   '445292'],
#  'furniture wholesaler': ['337127',
#   '337121',
#   '337124',
#   '337125',
#   '337122',
#   '423210',
#   '337214',
#   '337211',
#   '337910',
#   '442110'],
#  'auditor': ['541211',
#   '921190',
#   '541614',
#   '332722',
#   '332811',
#   '332812',
#   '332813',
#   '332911',
#   '332912',
#   '332999'],
#  'oil natural gas company': ['211130',
#   '211120',
#   '486210',
#   '486990',
#   '221210',
#   '213111',
#   '213112',
#   '486110',
#   '212230',
#   '213113'],
#  'auto body shop': ['811121',
#   '336211',
#   '811122',
#   '453220',
#   '812112',
#   '336212',
#   '332710',
#   '336213',
#   '811198',
#   '921120'],
#  'boat repair shop': ['811198',
#   '811118',
#   '811191',
#   '811111',
#   '811192',
#   '336612',
#   '811490',
#   '811112',
#   '811420',
#   '811430'],
#  'association': ['813990',
#   '813920',
#   '813910',
#   '813410',
#   '522294',
#   '325120',
#   '325920',
#   '325520',
#   '325130',
#   '325620'],
#  'railing contractor': ['238210',
#   '238910',
#   '238310',
#   '238990',
#   '238130',
#   '238110',
#   '238320',
#   '238140',
#   '238220',
#   '238150'],
#  'publisher': ['511199',
#   '511130',
#   '511120',
#   '511191',
#   '511140',
#   '511110',
#   '511210',
#   '512230',
#   '519130',
#   '512290'],
#  'pond supply store': ['453991',
#   '453998',
#   '453910',
#   '453210',
#   '446199',
#   '453920',
#   '453930',
#   '444190',
#   '445299',
#   '453310'],
#  'agriculture cooperative': ['115115',
#   '115210',
#   '115111',
#   '115113',
#   '115310',
#   '115112',
#   '115114',
#   '115116',
#   '813990',
#   '111310'],
#  'printing equipment supplier': ['323111',
#   '323117',
#   '323113',
#   '323120',
#   '561439',
#   '333244',
#   '336510',
#   '336991',
#   '444210',
#   '336413'],
#  'auto insurance agency': ['524298',
#   '524292',
#   '524291',
#   '524126',
#   '524128',
#   '524127',
#   '524210',
#   '524113',
#   '524114',
#   '524130'],
#  'alternative fuel station': ['447190',
#   '447110',
#   '454310',
#   '424720',
#   '221112',
#   '517919',
#   '115210',
#   '115115',
#   '115111',
#   '115113'],
#  'auto part manufacturer': ['441120',
#   '452319',
#   '441310',
#   '423930',
#   '423140',
#   '441320',
#   '423120',
#   '425120',
#   '423130',
#   '423110'],
#  'foundation': ['813211',
#   '238110',
#   '238190',
#   '238130',
#   '238140',
#   '238910',
#   '813219',
#   '813212',
#   '238160',
#   '238170'],
#  'fertilizer supplier': ['325311',
#   '325314',
#   '325312',
#   '325320',
#   '325998',
#   '325991',
#   '325992',
#   '325920',
#   '325910',
#   '212393'],
#  'farming company': ['111199',
#   '111339',
#   '111998',
#   '111219',
#   '111335',
#   '111334',
#   '111992',
#   '111991',
#   '111191',
#   '111419'],
#  'finance broker': ['425120',
#   '523120',
#   '523140',
#   '522291',
#   '523999',
#   '524210',
#   '523130',
#   '522310',
#   '523210',
#   '522294'],
#  'agricultural cooperative': ['115115',
#   '115116',
#   '111310',
#   '111130',
#   '115210',
#   '111110',
#   '111331',
#   '111140',
#   '111333',
#   '111150'],
#  'fire station': ['447190',
#   '447110',
#   '922160',
#   '424720',
#   '517919',
#   '561621',
#   '237110',
#   '562111',
#   '562112',
#   '488490'],
#  'environmental consultant': ['541620',
#   '541410',
#   '924110',
#   '924120',
#   '541611',
#   '541690',
#   '813319',
#   '541715',
#   '611710',
#   '334512'],
#  'civil engineer': ['541330',
#   '237990',
#   '813920',
#   '541620',
#   '237210',
#   '488119',
#   '921190',
#   '237310',
#   '237120',
#   '237110'],
#  'fire protection service': ['922160',
#   '812990',
#   '812910',
#   '541990',
#   '812930',
#   '541890',
#   '812922',
#   '812921',
#   '812191',
#   '812113'],
#  'gas company': ['211130',
#   '221210',
#   '211120',
#   '551111',
#   '551112',
#   '551114',
#   '213111',
#   '486210',
#   '213112',
#   '212230'],
#  'oilfield': ['928120',
#   '332721',
#   '332999',
#   '332996',
#   '332994',
#   '332993',
#   '332992',
#   '332991',
#   '332919',
#   '332913'],
#  'banquet hall': ['722320',
#   '712110',
#   '532310',
#   '713290',
#   '721211',
#   '713210',
#   '713990',
#   '531120',
#   '532289',
#   '334413'],
#  'mining company': ['212112',
#   '212393',
#   '551111',
#   '212399',
#   '551112',
#   '212111',
#   '212113',
#   '212299',
#   '551114',
#   '212291'],
#  'coalfield': ['928120',
#   '332721',
#   '332999',
#   '332996',
#   '332994',
#   '332993',
#   '332992',
#   '332991',
#   '332919',
#   '332913'],
#  'steel fabricator': ['331221',
#   '331210',
#   '331222',
#   '331110',
#   '331513',
#   '332111',
#   '331512',
#   '238120',
#   '331511',
#   '332613'],
#  'quarry': ['212230',
#   '212210',
#   '212113',
#   '212112',
#   '212221',
#   '212222',
#   '212111',
#   '327410',
#   '327420',
#   '327310'],
#  'gold mining company': ['212221',
#   '212222',
#   '212299',
#   '212393',
#   '212399',
#   '212112',
#   '212113',
#   '212291',
#   '212111',
#   '212392'],
#  'high rise building': ['444190',
#   '236220',
#   '236116',
#   '236210',
#   '444130',
#   '336611',
#   '541350',
#   '444110',
#   '444120',
#   '236117'],
#  'basketball club': ['452311',
#   '813410',
#   '711211',
#   '713910',
#   '713990',
#   '452319',
#   '713940',
#   '713930',
#   '713950',
#   '713920'],
#  'gold dealer': ['441228',
#   '441222',
#   '441120',
#   '441210',
#   '444190',
#   '441110',
#   '444130',
#   '441320',
#   '444120',
#   '453998'],
#  'battery manufacturer': ['335911',
#   '335912',
#   '335999',
#   '335312',
#   '425120',
#   '335991',
#   '425110',
#   '424610',
#   '424710',
#   '424340'],
#  'electric utility company': ['221114',
#   '221122',
#   '221116',
#   '221115',
#   '221113',
#   '221121',
#   '221117',
#   '221118',
#   '221112',
#   '221111'],
#  'environmental program': ['924110',
#   '924120',
#   '541620',
#   '923120',
#   '923130',
#   '923110',
#   '923140',
#   '925110',
#   '926140',
#   '926120'],
#  'office': ['621399',
#   '621391',
#   '453210',
#   '621340',
#   '541120',
#   '541110',
#   '541199',
#   '541191',
#   '551114',
#   '541219'],
#  'stone supplier': ['327991',
#   '212319',
#   '327999',
#   '212311',
#   '423320',
#   '212312',
#   '212313',
#   '339993',
#   '339910',
#   '327390'],
#  'aggregate supplier': ['561320',
#   '519110',
#   '519120',
#   '519190',
#   '517410',
#   '518210',
#   '512110',
#   '515210',
#   '512120',
#   '512240'],
#  'sand gravel supplier': ['212321',
#   '327211',
#   '212322',
#   '327320',
#   '327212',
#   '327213',
#   '327215',
#   '327390',
#   '327410',
#   '327420'],
#  'building material supplier': ['444190',
#   '444110',
#   '444130',
#   '444120',
#   '236220',
#   '236210',
#   '336611',
#   '236117',
#   '236118',
#   '236116'],
#  'beauty supply store': ['446199',
#   '446120',
#   '453991',
#   '453998',
#   '453910',
#   '453210',
#   '446191',
#   '453920',
#   '453930',
#   '444190'],
#  'crushed stone supplier': ['212319',
#   '212312',
#   '212313',
#   '327991',
#   '212311',
#   '327999',
#   '423320',
#   '339993',
#   '339910',
#   '327390'],
#  'rock shop': ['453220',
#   '812112',
#   '332710',
#   '812111',
#   '442299',
#   '811121',
#   '212392',
#   '722515',
#   '811198',
#   '811191'],
#  'road construction company': ['237310',
#   '236220',
#   '236210',
#   '237990',
#   '237120',
#   '237110',
#   '237130',
#   '236116',
#   '236115',
#   '236118'],
#  'marketing consultant': ['541410',
#   '541613',
#   '541611',
#   '541910',
#   '611710',
#   '541618',
#   '425110',
#   '425120',
#   '926140',
#   '424610'],
#  'blood testing service': ['541380',
#   '621991',
#   '812990',
#   '621999',
#   '541940',
#   '541511',
#   '541340',
#   '541310',
#   '541330',
#   '541350'],
#  'contractor': ['238210',
#   '238910',
#   '238310',
#   '238990',
#   '238130',
#   '238110',
#   '238320',
#   '238140',
#   '238220',
#   '238150'],
#  'excavating contractor': ['238910',
#   '238210',
#   '238310',
#   '238990',
#   '238130',
#   '238110',
#   '238320',
#   '238140',
#   '238220',
#   '238150'],
#  'asphalt mixing plant': ['324122',
#   '324121',
#   '325314',
#   '325311',
#   '325312',
#   '327320',
#   '325320',
#   '311999',
#   '325510',
#   '325211'],
#  'ready mix concrete supplier': ['327320',
#   '311942',
#   '327999',
#   '327332',
#   '327331',
#   '327390',
#   '327991',
#   '327992',
#   '327993',
#   '311824'],
#  'sand plant': ['327211',
#   '327320',
#   '212322',
#   '327212',
#   '212321',
#   '327213',
#   '327215',
#   '327390',
#   '327310',
#   '327332'],
#  'bmw dealer': ['441228',
#   '441222',
#   '441120',
#   '441210',
#   '444190',
#   '441110',
#   '444130',
#   '441320',
#   '444120',
#   '453998'],
#  'bookbinder': ['316110',
#   '928120',
#   '332811',
#   '332812',
#   '332813',
#   '332911',
#   '332912',
#   '332913',
#   '332919',
#   '332721'],
#  'garden center': ['444220',
#   '444110',
#   '444210',
#   '621498',
#   '444130',
#   '621493',
#   '444120',
#   '621492',
#   '621491',
#   '444190'],
#  'abrasive supplier': ['327910',
#   '327999',
#   '327991',
#   '327992',
#   '327993',
#   '327390',
#   '327410',
#   '327420',
#   '327213',
#   '327310'],
#  'granite supplier': ['212313',
#   '212319',
#   '327991',
#   '238340',
#   '561320',
#   '238140',
#   '519110',
#   '519120',
#   '519190',
#   '517410'],
#  'drilling contractor': ['238210',
#   '238910',
#   '238310',
#   '238990',
#   '238130',
#   '238110',
#   '238320',
#   '238140',
#   '238220',
#   '238150'],
#  'bpo company': ['551111',
#   '551112',
#   '551114',
#   '561110',
#   '561740',
#   '561410',
#   '561440',
#   '561730',
#   '561710',
#   '561510'],
#  'oil gas exploration service': ['211130',
#   '211120',
#   '213112',
#   '213111',
#   '213113',
#   '213114',
#   '213115',
#   '221210',
#   '212230',
#   '212210'],
#  'building complex': ['444190',
#   '236220',
#   '236210',
#   '444130',
#   '336611',
#   '444110',
#   '444120',
#   '236117',
#   '236118',
#   '236116'],
#  'construction equipment supplier': ['236220',
#   '236210',
#   '237990',
#   '237120',
#   '237110',
#   '237130',
#   '236116',
#   '236115',
#   '236118',
#   '237310'],
#  'mining equipment': ['212112',
#   '212393',
#   '212399',
#   '212111',
#   '212113',
#   '212299',
#   '212291',
#   '212392',
#   '212325',
#   '212391'],
#  'bus ticket agency': ['485510',
#   '485410',
#   '485210',
#   '485113',
#   '485999',
#   '485991',
#   '561599',
#   '485112',
#   '485111',
#   '336350'],
#  'business center': ['621498',
#   '621493',
#   '621492',
#   '621491',
#   '425110',
#   '561439',
#   '621512',
#   '621420',
#   '444110',
#   '621112'],
#  'skyscraper': ['928120',
#   '332721',
#   '332999',
#   '332996',
#   '332994',
#   '332993',
#   '332992',
#   '332991',
#   '332919',
#   '332913'],
#  'software company': ['511210',
#   '551111',
#   '551112',
#   '551114',
#   '541511',
#   '511110',
#   '541519',
#   '541512',
#   '511191',
#   '511120'],
#  'business development service': ['541714',
#   '541713',
#   '541715',
#   '541720',
#   '561499',
#   '541990',
#   '812990',
#   '561990',
#   '812910',
#   '812930'],
#  'business management consultant': ['541611',
#   '561330',
#   '561450',
#   '541410',
#   '561410',
#   '561440',
#   '561491',
#   '561320',
#   '561110',
#   '561920'],
#  'cabinet maker': ['337110',
#   '444190',
#   '337122',
#   '337124',
#   '443141',
#   '333318',
#   '722515',
#   '337127',
#   '337121',
#   '337125'],
#  'call center': ['561422',
#   '561421',
#   '621498',
#   '621493',
#   '621492',
#   '621491',
#   '621512',
#   '621420',
#   '444110',
#   '621112'],
#  'cancer treatment center': ['621498',
#   '621420',
#   '621493',
#   '221320',
#   '562219',
#   '621492',
#   '813212',
#   '562211',
#   '621491',
#   '221310'],
#  'power plant consultant': ['221111',
#   '221115',
#   '221113',
#   '221118',
#   '221116',
#   '221117',
#   '221114',
#   '221112',
#   '221122',
#   '221121'],
#  'business park': ['713110',
#   '721211',
#   '425110',
#   '712190',
#   '721214',
#   '713120',
#   '423850',
#   '561499',
#   '561491',
#   '561450'],
#  'petroleum product company': ['324110',
#   '324191',
#   '324199',
#   '551111',
#   '551112',
#   '324121',
#   '551114',
#   '324122',
#   '424710',
#   '424720'],
#  'parking lot': ['812930',
#   '541870',
#   '812990',
#   '441320',
#   '441120',
#   '441110',
#   '441210',
#   '237310',
#   '441310',
#   '812220'],
#  'water utility company': ['221310',
#   '221330',
#   '221320',
#   '221210',
#   '483212',
#   '483211',
#   '551111',
#   '551112',
#   '551114',
#   '237110'],
#  'car repair maintenance': ['811192',
#   '811198',
#   '811111',
#   '811118',
#   '811113',
#   '811191',
#   '811112',
#   '811490',
#   '811420',
#   '811310'],
#  'water treatment plant': ['221310',
#   '221320',
#   '221330',
#   '562219',
#   '562211',
#   '483212',
#   '483211',
#   '237110',
#   '483114',
#   '483111'],
#  'car service': ['561613',
#   '811192',
#   '812990',
#   '488210',
#   '561611',
#   '812910',
#   '812930',
#   '541990',
#   '561612',
#   '541890'],
#  'cattle market': ['112111',
#   '112112',
#   '112120',
#   '112130',
#   '425110',
#   '112990',
#   '424520',
#   '445220',
#   '115210',
#   '112920'],
#  'sewage disposal service': ['221320',
#   '221330',
#   '221310',
#   '562219',
#   '221210',
#   '562211',
#   '562212',
#   '562213',
#   '562998',
#   '562991'],
#  'certified public accountant': ['541211',
#   '541219',
#   '922140',
#   '922190',
#   '922130',
#   '923120',
#   '922150',
#   '922160',
#   '922120',
#   '922110'],
#  'government office': ['921190',
#   '921110',
#   '926150',
#   '922190',
#   '921130',
#   '921140',
#   '922130',
#   '926140',
#   '921120',
#   '922150'],
#  'charity': ['813219',
#   '928120',
#   '332721',
#   '332996',
#   '332994',
#   '332993',
#   '332992',
#   '332991',
#   '332919',
#   '332913'],
#  'air conditioning system supplier': ['333415',
#   '481112',
#   '481219',
#   '481111',
#   '481212',
#   '481211',
#   '333413',
#   '333414',
#   '221330',
#   '488111'],
#  'chemical industry': ['325120',
#   '325920',
#   '325130',
#   '325910',
#   '325193',
#   '325992',
#   '325180',
#   '325194',
#   '325991',
#   '325320'],
#  'chemical manufacturer': ['325120',
#   '325920',
#   '325130',
#   '325910',
#   '325992',
#   '325193',
#   '325194',
#   '325180',
#   '325991',
#   '325998'],
#  'title company': ['551111',
#   '551112',
#   '541191',
#   '551114',
#   '561110',
#   '561740',
#   '561410',
#   '561440',
#   '561730',
#   '561710'],
#  'chemical plant': ['325120',
#   '325920',
#   '325130',
#   '325910',
#   '325992',
#   '325193',
#   '325194',
#   '325180',
#   '325991',
#   '325998'],
#  'property management company': ['551111',
#   '551112',
#   '551114',
#   '561110',
#   '561740',
#   '561410',
#   '561330',
#   '561510',
#   '561730',
#   '561440'],
#  'custom home builder': ['236117',
#   '442299',
#   '442291',
#   '236116',
#   '442110',
#   '236115',
#   '442210',
#   '236118',
#   '444110',
#   '236210'],
#  'window installation service': ['541519',
#   '442291',
#   '541890',
#   '812990',
#   '238290',
#   '812910',
#   '541990',
#   '541330',
#   '812930',
#   '332321'],
#  'fire damage restoration service': ['812990',
#   '541620',
#   '812910',
#   '541990',
#   '812930',
#   '541890',
#   '812922',
#   '812921',
#   '812191',
#   '812113'],
#  'equipment rental agency': ['532289',
#   '532283',
#   '532282',
#   '532284',
#   '532281',
#   '532210',
#   '532111',
#   '532412',
#   '532310',
#   '532411'],
#  'chemical wholesaler': ['424690',
#   '325120',
#   '325920',
#   '325130',
#   '325910',
#   '424130',
#   '424210',
#   '424120',
#   '424590',
#   '325992'],
#  'financial planner': ['523930',
#   '523999',
#   '523991',
#   '523210',
#   '523910',
#   '523920',
#   '523140',
#   '523130',
#   '522320',
#   '523120'],
#  'telecommunication service provider': ['517919',
#   '517911',
#   '517311',
#   '517312',
#   '517410',
#   '812990',
#   '541990',
#   '541890',
#   '812910',
#   '812930'],
#  'energy equipment solution': ['221114',
#   '221118',
#   '325412',
#   '221111',
#   '221116',
#   '221117',
#   '221115',
#   '221113',
#   '221112',
#   '335929'],
#  'chiropractor': ['621310',
#   '621399',
#   '621391',
#   '928120',
#   '332721',
#   '332811',
#   '332812',
#   '332813',
#   '332911',
#   '332912'],
#  'steel distributor': ['331221',
#   '331210',
#   '331222',
#   '331110',
#   '331513',
#   '332111',
#   '331512',
#   '238120',
#   '331511',
#   '332613'],
#  'city government office': ['921140',
#   '921190',
#   '921110',
#   '926150',
#   '922190',
#   '921130',
#   '922130',
#   '921120',
#   '926140',
#   '922150'],
#  'crane service': ['812990',
#   '333923',
#   '812910',
#   '812930',
#   '541990',
#   '541890',
#   '812922',
#   '812921',
#   '812191',
#   '812113'],
#  'garage door supplier': ['454310',
#   '454210',
#   '454390',
#   '332321',
#   '444190',
#   '454110',
#   '321911',
#   '541870',
#   '238350',
#   '332322'],
#  'industrial door supplier': ['454310',
#   '454210',
#   '454390',
#   '332321',
#   '454110',
#   '321911',
#   '444190',
#   '541870',
#   '335999',
#   '332911'],
#  'city town hall': ['921140',
#   '722320',
#   '712110',
#   '713290',
#   '721211',
#   '531110',
#   '713210',
#   '713990',
#   '236115',
#   '236116'],
#  'clothing wholesaler': ['448140',
#   '448130',
#   '448110',
#   '448120',
#   '448190',
#   '448150',
#   '448210',
#   '424330',
#   '424320',
#   '448310'],
#  'coin operated laundry equipment supplier': ['812310',
#   '812320',
#   '812331',
#   '812332',
#   '812990',
#   '812930',
#   '812910',
#   '812921',
#   '812922',
#   '812220'],
#  'metal supplier': ['332812',
#   '332811',
#   '332322',
#   '332321',
#   '332813',
#   '332323',
#   '332311',
#   '332312',
#   '332119',
#   '332313'],
#  'glass shop': ['327212',
#   '327211',
#   '327215',
#   '327213',
#   '811122',
#   '453220',
#   '812112',
#   '327993',
#   '327999',
#   '327991'],
#  'college': ['611310',
#   '611210',
#   '611691',
#   '611692',
#   '611699',
#   '611710',
#   '611630',
#   '611610',
#   '611110',
#   '611620'],
#  'siding contractor': ['238170',
#   '238210',
#   '238910',
#   '238310',
#   '238990',
#   '238130',
#   '238110',
#   '238320',
#   '238140',
#   '238220'],
#  'commercial printer': ['333318',
#   '333413',
#   '333316',
#   '333314',
#   '333415',
#   '333414',
#   '334118',
#   '323111',
#   '541922',
#   '423440'],
#  'storage facility': ['493190',
#   '493120',
#   '493130',
#   '493110',
#   '335911',
#   '486210',
#   '334112',
#   '711310',
#   '713930',
#   '711320'],
#  'communication tower': ['334290',
#   '334220',
#   '334210',
#   '237130',
#   '811213',
#   '334310',
#   '334512',
#   '334516',
#   '334413',
#   '334517'],
#  'janitorial service': ['561720',
#   '561790',
#   '812990',
#   '812910',
#   '812930',
#   '541990',
#   '541890',
#   '812922',
#   '812921',
#   '561730'],
#  'computer consultant': ['334118',
#   '334111',
#   '334112',
#   '541512',
#   '541519',
#   '541513',
#   '334413',
#   '334310',
#   '334417',
#   '541410'],
#  'fire protection system supplier': ['922160',
#   '561621',
#   '541512',
#   '485119',
#   '221122',
#   '221121',
#   '221310',
#   '922190',
#   '561622',
#   '221111'],
#  'elevator service': ['333921',
#   '812990',
#   '812910',
#   '812930',
#   '541990',
#   '541890',
#   '812922',
#   '812921',
#   '812191',
#   '812113'],
#  'industrial equipment supplier': ['336510',
#   '532490',
#   '336991',
#   '333413',
#   '532310',
#   '532412',
#   '444210',
#   '336413',
#   '335999',
#   '532411'],
#  'dry wall contractor': ['238210',
#   '238320',
#   '238310',
#   '238910',
#   '238990',
#   '238130',
#   '238110',
#   '238140',
#   '238220',
#   '238150'],
#  'insulation contractor': ['238310',
#   '238210',
#   '238910',
#   '238990',
#   '238130',
#   '238110',
#   '238320',
#   '238140',
#   '238220',
#   '238150'],
#  'concrete contractor': ['238110',
#   '238120',
#   '238210',
#   '238910',
#   '238130',
#   '238310',
#   '238190',
#   '238990',
#   '238140',
#   '238320'],
#  'scaffolding rental service': ['532289',
#   '532284',
#   '532282',
#   '532281',
#   '532283',
#   '532111',
#   '532210',
#   '532120',
#   '532420',
#   '532411'],
#  'construction company': ['236220',
#   '236210',
#   '237990',
#   '237120',
#   '236116',
#   '237110',
#   '237130',
#   '236115',
#   '236118',
#   '236117'],
#  'flooring store': ['453991',
#   '453998',
#   '453910',
#   '445299',
#   '453920',
#   '453930',
#   '442299',
#   '445292',
#   '446199',
#   '453310'],
#  'flooring contractor': ['238330',
#   '238210',
#   '238310',
#   '238910',
#   '238990',
#   '238130',
#   '238110',
#   '238320',
#   '238140',
#   '238340'],
#  'tile contractor': ['238340',
#   '238210',
#   '238310',
#   '238330',
#   '238910',
#   '238990',
#   '238130',
#   '238110',
#   '238320',
#   '238140'],
#  'tile manufacturer': ['327120',
#   '442210',
#   '425120',
#   '238340',
#   '425110',
#   '423320',
#   '424610',
#   '327110',
#   '424710',
#   '424340'],
#  'glass mirror shop': ['327212',
#   '327215',
#   '327211',
#   '327213',
#   '811122',
#   '453220',
#   '812112',
#   '327993',
#   '327999',
#   '327991'],
#  'construction material wholesaler': ['423390',
#   '423690',
#   '423220',
#   '423810',
#   '423510',
#   '423320',
#   '423850',
#   '423450',
#   '423710',
#   '423440'],
#  'gutter cleaning service': ['561790',
#   '561720',
#   '562998',
#   '812320',
#   '561740',
#   '812990',
#   '812910',
#   '812930',
#   '562991',
#   '812922'],
#  'sheet metal contractor': ['332322',
#   '332323',
#   '332321',
#   '238210',
#   '238910',
#   '238310',
#   '238990',
#   '332812',
#   '332311',
#   '238150'],
#  'consultant': ['541410',
#   '611710',
#   '541611',
#   '541310',
#   '541512',
#   '524291',
#   '531390',
#   '813920',
#   '332811',
#   '332710'],
#  'container service': ['812990',
#   '812910',
#   '812930',
#   '541990',
#   '541890',
#   '812922',
#   '812921',
#   '812191',
#   '332439',
#   '332431'],
#  'septic system service': ['562991',
#   '541512',
#   '541513',
#   '562998',
#   '812990',
#   '541519',
#   '541990',
#   '812910',
#   '812930',
#   '812922'],
#  'corporate campus': ['721310',
#   '541430',
#   '551114',
#   '541110',
#   '813211',
#   '541410',
#   '522130',
#   '332913',
#   '332912',
#   '332911'],
#  'water damage restoration service': ['221310',
#   '483212',
#   '483211',
#   '488330',
#   '488390',
#   '541620',
#   '483114',
#   '483111',
#   '483112',
#   '812990'],
#  'welder': ['316998',
#   '316992',
#   '339113',
#   '315280',
#   '315210',
#   '928120',
#   '332721',
#   '332722',
#   '332811',
#   '332812'],
#  'corporate office': ['621399',
#   '551114',
#   '541430',
#   '541110',
#   '621391',
#   '453210',
#   '621340',
#   '541410',
#   '813211',
#   '541120'],
#  'animal': ['112990',
#   '112930',
#   '112920',
#   '112910',
#   '112340',
#   '112330',
#   '112320',
#   '112210',
#   '112420',
#   '112519'],
#  'animal feed store': ['112990',
#   '112930',
#   '311119',
#   '112920',
#   '112910',
#   '453991',
#   '453998',
#   '112340',
#   '112330',
#   '112320'],
#  'animal protection organization': ['112990',
#   '112930',
#   '112920',
#   '112910',
#   '112340',
#   '112330',
#   '112320',
#   '112210',
#   '112420',
#   '112519'],
#  'brewing supply store': ['453991',
#   '453998',
#   '453910',
#   '453210',
#   '446199',
#   '453920',
#   '453930',
#   '444190',
#   '445299',
#   '453310'],
#  'cosmetic store': ['446120',
#   '446199',
#   '453991',
#   '453998',
#   '446191',
#   '453910',
#   '445299',
#   '453920',
#   '453930',
#   '442299'],
#  'county government office': ['921140',
#   '921190',
#   '921110',
#   '926150',
#   '922190',
#   '921130',
#   '921120',
#   '922130',
#   '926140',
#   '923110'],
#  'sugar factory': ['311313',
#   '311314',
#   '311340',
#   '488190',
#   '488210',
#   '111991',
#   '311351',
#   '311710',
#   '311352',
#   '311999'],
#  'confectionery wholesaler': ['311340',
#   '311352',
#   '424490',
#   '424450',
#   '311351',
#   '423220',
#   '424430',
#   '423690',
#   '423510',
#   '424130'],
#  'financial institution': ['523930',
#   '523999',
#   '523210',
#   '523991',
#   '523910',
#   '523920',
#   '523140',
#   '523130',
#   '522120',
#   '523120'],
#  'candy store': ['453991',
#   '453998',
#   '445292',
#   '453910',
#   '445299',
#   '453920',
#   '453930',
#   '442299',
#   '446199',
#   '453310'],
#  'confectionery': ['311340',
#   '311352',
#   '311351',
#   '445292',
#   '311999',
#   '424450',
#   '311991',
#   '311930',
#   '445291',
#   '311920'],
#  'chocolate factory': ['311352',
#   '311351',
#   '311340',
#   '488190',
#   '311314',
#   '311313',
#   '488210',
#   '311710',
#   '311999',
#   '488111'],
#  'chocolate shop': ['311352',
#   '311351',
#   '311340',
#   '453220',
#   '812112',
#   '332710',
#   '311314',
#   '311313',
#   '812111',
#   '442299'],
#  'courier service': ['492110',
#   '492210',
#   '481112',
#   '491110',
#   '481212',
#   '481111',
#   '481211',
#   '812990',
#   '481219',
#   '812910'],
#  'coworking space': ['927110',
#   '336419',
#   '336414',
#   '336415',
#   '488119',
#   '531130',
#   '541410',
#   '488111',
#   '722410',
#   '336411'],
#  'frozen food manufacturer': ['311412',
#   '311411',
#   '311520',
#   '445210',
#   '445220',
#   '311813',
#   '445110',
#   '722310',
#   '424420',
#   '445230'],
#  'beverage distributor': ['312120',
#   '312140',
#   '312130',
#   '312113',
#   '312112',
#   '312111',
#   '312230',
#   '445310',
#   '445230',
#   '445220'],
#  'agricultural organization': ['813312',
#   '813319',
#   '813990',
#   '813311',
#   '813910',
#   '813940',
#   '813930',
#   '115115',
#   '115116',
#   '115210'],
#  'dairy store': ['445299',
#   '453991',
#   '453998',
#   '311514',
#   '453910',
#   '445292',
#   '453920',
#   '445291',
#   '453930',
#   '442299'],
#  'dairy': ['311514',
#   '311512',
#   '311511',
#   '311513',
#   '311520',
#   '112120',
#   '112111',
#   '115210',
#   '112112',
#   '445299'],
#  'ice cream shop': ['311520',
#   '722515',
#   '312113',
#   '453220',
#   '812112',
#   '722330',
#   '332710',
#   '312112',
#   '312111',
#   '311511'],
#  'medical laboratory': ['621511',
#   '621512',
#   '339116',
#   '339112',
#   '622110',
#   '339114',
#   '339115',
#   '339113',
#   '622310',
#   '334516'],
#  'demolition contractor': ['238910',
#   '238210',
#   '238310',
#   '238990',
#   '238130',
#   '238110',
#   '238320',
#   '238140',
#   '238220',
#   '238150'],
#  'meat processor': ['311612',
#   '311613',
#   '311615',
#   '445210',
#   '311611',
#   '424470',
#   '311111',
#   '311119',
#   '112320',
#   '311942'],
#  'fmcg manufacturer': ['425120',
#   '425110',
#   '424610',
#   '424710',
#   '424340',
#   '424480',
#   '424450',
#   '424460',
#   '424810',
#   '424410'],
#  'garbage collection service': ['562111',
#   '562920',
#   '561440',
#   '562119',
#   '562998',
#   '562112',
#   '812990',
#   '561499',
#   '562991',
#   '812910'],
#  'wholesale bakery': ['311812',
#   '311811',
#   '311813',
#   '311830',
#   '425120',
#   '311821',
#   '425110',
#   '424610',
#   '424710',
#   '424340'],
#  'dentist': ['621399',
#   '621999',
#   '621391',
#   '621991',
#   '339114',
#   '621210',
#   '621310',
#   '813920',
#   '621910',
#   '621320'],
#  'dessert shop': ['311520',
#   '453220',
#   '812112',
#   '332710',
#   '311999',
#   '812111',
#   '442299',
#   '811121',
#   '722515',
#   '811198'],
#  'cupcake shop': ['453220',
#   '812112',
#   '332710',
#   '812111',
#   '442299',
#   '811121',
#   '722515',
#   '811198',
#   '811191',
#   '445210'],
#  'nut store': ['445292',
#   '445299',
#   '453991',
#   '453998',
#   '453910',
#   '445291',
#   '453920',
#   '453930',
#   '442299',
#   '446199'],
#  'wholesale grocer': ['425120',
#   '425110',
#   '424610',
#   '424710',
#   '424340',
#   '424480',
#   '424450',
#   '424460',
#   '424810',
#   '424410'],
#  'design engineer': ['541490',
#   '541410',
#   '541420',
#   '541330',
#   '541430',
#   '541620',
#   '813920',
#   '541512',
#   '541320',
#   '541519'],
#  'business business service': ['425110',
#   '561499',
#   '561491',
#   '561990',
#   '561439',
#   '561492',
#   '561431',
#   '812310',
#   '812990',
#   '561450'],
#  'condiment supplier': ['311930',
#   '311920',
#   '311911',
#   '311919',
#   '311991',
#   '311942',
#   '311941',
#   '311999',
#   '561320',
#   '519110'],
#  'digital printing service': ['323111',
#   '323117',
#   '323113',
#   '323120',
#   '561439',
#   '561431',
#   '541921',
#   '812990',
#   '812910',
#   '812930'],
#  'culinary school': ['611519',
#   '611110',
#   '611511',
#   '611610',
#   '611512',
#   '611513',
#   '611692',
#   '611699',
#   '611620',
#   '611691'],
#  'importer': ['928120',
#   '332721',
#   '332999',
#   '332996',
#   '332994',
#   '332993',
#   '332992',
#   '332991',
#   '332919',
#   '332913'],
#  'bottled water supplier': ['221310',
#   '483212',
#   '483211',
#   '312112',
#   '445299',
#   '483114',
#   '483111',
#   '483112',
#   '454390',
#   '483113'],
#  'coffee roaster': ['311920',
#   '722515',
#   '311999',
#   '311991',
#   '311942',
#   '112320',
#   '445299',
#   '311930',
#   '454390',
#   '311941'],
#  'packaging supply store': ['453991',
#   '453998',
#   '453910',
#   '453210',
#   '446199',
#   '453920',
#   '453930',
#   '444190',
#   '445299',
#   '453310'],
#  'ice supplier': ['312113',
#   '311520',
#   '312112',
#   '312111',
#   '312120',
#   '722515',
#   '312140',
#   '312130',
#   '722330',
#   '311821'],
#  'brewery': ['312120',
#   '312140',
#   '312113',
#   '312130',
#   '312112',
#   '312111',
#   '333241',
#   '332992',
#   '332991',
#   '332919'],
#  'winemaking company': ['551111',
#   '551112',
#   '551114',
#   '561110',
#   '561740',
#   '561410',
#   '561440',
#   '561730',
#   '561710',
#   '561510'],
#  'distillery': ['312140',
#   '312120',
#   '312113',
#   '312130',
#   '312112',
#   '312111',
#   '325120',
#   '325920',
#   '325520',
#   '325130'],
#  'disability service support organisation': ['624120',
#   '561990',
#   '623210',
#   '624190',
#   '561499',
#   '561910',
#   '561491',
#   '561431',
#   '488490',
#   '561492'],
#  'district government office': ['921190',
#   '922130',
#   '921110',
#   '926150',
#   '922190',
#   '921130',
#   '921140',
#   '926140',
#   '921120',
#   '922150'],
#  'air filter supplier': ['333413',
#   '481112',
#   '481219',
#   '481111',
#   '481212',
#   '481211',
#   '333415',
#   '488111',
#   '333414',
#   '488190'],
#  'tire shop': ['441320',
#   '326212',
#   '326211',
#   '453220',
#   '314994',
#   '812112',
#   '332710',
#   '453310',
#   '811198',
#   '811191'],
#  'fastener supplier': ['339993',
#   '332722',
#   '332721',
#   '339999',
#   '332710',
#   '339992',
#   '339994',
#   '339995',
#   '339991',
#   '561320'],
#  'fabric product manufacturer': ['313210',
#   '313230',
#   '313220',
#   '313240',
#   '313310',
#   '313320',
#   '313110',
#   '314994',
#   '315240',
#   '315220'],
#  'textile': ['314120',
#   '314999',
#   '314910',
#   '314110',
#   '313320',
#   '313310',
#   '314994',
#   '313110',
#   '313230',
#   '313210'],
#  'textile exporter': ['314120',
#   '314999',
#   '314910',
#   '314110',
#   '313320',
#   '313310',
#   '314994',
#   '313110',
#   '313230',
#   '313210'],
#  'textile engineer': ['314120',
#   '314999',
#   '314910',
#   '314110',
#   '313320',
#   '313310',
#   '314994',
#   '313110',
#   '313230',
#   '313210'],
#  'fabric store': ['313210',
#   '313230',
#   '313220',
#   '313240',
#   '313310',
#   '313320',
#   '453991',
#   '453998',
#   '453910',
#   '445299'],
#  'knit shop': ['453220',
#   '812112',
#   '313240',
#   '332710',
#   '812111',
#   '315190',
#   '442299',
#   '811121',
#   '315210',
#   '722515'],
#  'doctor': ['621112',
#   '621111',
#   '621210',
#   '621498',
#   '621310',
#   '621320',
#   '621492',
#   '621491',
#   '621391',
#   '621493'],
#  'lamination service': ['812990',
#   '812910',
#   '812930',
#   '541990',
#   '541890',
#   '812922',
#   '812921',
#   '812191',
#   '812113',
#   '812320'],
#  'plastic resin manufacturer': ['325211',
#   '326112',
#   '326111',
#   '326113',
#   '326191',
#   '326199',
#   '326130',
#   '326122',
#   '326121',
#   '326160'],
#  'carpet manufacturer': ['314110',
#   '314999',
#   '314994',
#   '561740',
#   '442210',
#   '425120',
#   '314120',
#   '423220',
#   '425110',
#   '561790'],
#  'upholstery shop': ['453220',
#   '812112',
#   '332710',
#   '561740',
#   '811121',
#   '451130',
#   '812111',
#   '442299',
#   '722515',
#   '811198'],
#  'business administration service': ['924110',
#   '923120',
#   '926110',
#   '924120',
#   '923130',
#   '923110',
#   '923140',
#   '925120',
#   '926130',
#   '922140'],
#  'furniture store': ['442110',
#   '337127',
#   '337121',
#   '337124',
#   '337125',
#   '337122',
#   '337214',
#   '337211',
#   '453991',
#   '442299'],
#  'dry cleaner': ['311824',
#   '311514',
#   '311821',
#   '311942',
#   '111130',
#   '335912',
#   '443141',
#   '325510',
#   '311423',
#   '452319'],
#  'packaging company': ['551111',
#   '551112',
#   '561910',
#   '551114',
#   '561110',
#   '561740',
#   '561410',
#   '561440',
#   '325612',
#   '561730'],
#  'duty free store': ['453991',
#   '453998',
#   '453910',
#   '445299',
#   '453920',
#   '453930',
#   '442299',
#   '445292',
#   '446199',
#   '453310'],
#  'commerce service': ['813910',
#   '812990',
#   '812910',
#   '812930',
#   '541990',
#   '541890',
#   '812922',
#   '812921',
#   '812191',
#   '812113'],
#  'cable company': ['335921',
#   '335929',
#   '551111',
#   '551112',
#   '551114',
#   '561110',
#   '561740',
#   '561410',
#   '561440',
#   '561730'],
#  'education': ['923110',
#   '611110',
#   '624310',
#   '813212',
#   '515210',
#   '611710',
#   '923130',
#   '611692',
#   '813311',
#   '611430'],
#  'outlet store': ['453991',
#   '453998',
#   '453910',
#   '445299',
#   '453920',
#   '453930',
#   '442299',
#   '445292',
#   '446199',
#   '453310'],
#  'lingerie store': ['453991',
#   '453998',
#   '448190',
#   '453910',
#   '445299',
#   '453920',
#   '453930',
#   '442299',
#   '445292',
#   '446199'],
#  'clothes fabric manufacturer': ['313210',
#   '313230',
#   '313220',
#   '313240',
#   '313310',
#   '313320',
#   '313110',
#   '315240',
#   '315220',
#   '315280'],
#  'education center': ['621498',
#   '621493',
#   '621492',
#   '923110',
#   '621491',
#   '611110',
#   '621512',
#   '621420',
#   '444110',
#   '621112'],
#  'uniform store': ['451110',
#   '453991',
#   '453998',
#   '453910',
#   '445299',
#   '448190',
#   '453920',
#   '453930',
#   '442299',
#   '445292'],
#  'men clothing store': ['448110',
#   '448190',
#   '448140',
#   '448150',
#   '448130',
#   '448120',
#   '448210',
#   '453991',
#   '453998',
#   '453910'],
#  'clothing store': ['448190',
#   '448140',
#   '448110',
#   '448130',
#   '448150',
#   '448120',
#   '448210',
#   '453991',
#   '453998',
#   '453910'],
#  'woman clothing store': ['448120',
#   '448190',
#   '448140',
#   '448110',
#   '448130',
#   '448150',
#   '448210',
#   '453991',
#   '453998',
#   '453910'],
#  'western apparel store': ['315990',
#   '315280',
#   '315240',
#   '315210',
#   '315220',
#   '453991',
#   '453998',
#   '315110',
#   '315190',
#   '453910'],
#  'costume store': ['453991',
#   '453998',
#   '448150',
#   '453910',
#   '445299',
#   '453920',
#   '453930',
#   '448190',
#   '442299',
#   '445292'],
#  'game store': ['453991',
#   '453998',
#   '451120',
#   '453910',
#   '445299',
#   '453920',
#   '453930',
#   '451110',
#   '442299',
#   '445292'],
#  'hat shop': ['453220',
#   '812112',
#   '332710',
#   '812111',
#   '442299',
#   '811121',
#   '722515',
#   '811198',
#   '448310',
#   '811191'],
#  'leather good manufacturer': ['316998',
#   '316992',
#   '316110',
#   '316210',
#   '448320',
#   '811430',
#   '424340',
#   '423920',
#   '423910',
#   '424310'],
#  'educational consultant': ['611710',
#   '541410',
#   '611630',
#   '611210',
#   '611420',
#   '611410',
#   '611310',
#   '611430',
#   '611110',
#   '611511'],
#  'leather exporter': ['316998',
#   '316992',
#   '316110',
#   '316210',
#   '448320',
#   '811430',
#   '325613',
#   '325612',
#   '448310',
#   '325611'],
#  'shoe store': ['448210',
#   '453991',
#   '453998',
#   '453910',
#   '445299',
#   '453920',
#   '453930',
#   '442299',
#   '445292',
#   '446199'],
#  'boutique': ['928120',
#   '332721',
#   '332999',
#   '332996',
#   '332994',
#   '332993',
#   '332992',
#   '332991',
#   '332919',
#   '332913'],
#  'leather wholesaler': ['316998',
#   '316992',
#   '316110',
#   '316210',
#   '448320',
#   '423220',
#   '423690',
#   '423510',
#   '424130',
#   '423450'],
#  'handbag shop': ['453220',
#   '812112',
#   '332710',
#   '448320',
#   '316992',
#   '812111',
#   '442299',
#   '811121',
#   '448310',
#   '722515'],
#  'electronics store': ['453991',
#   '453998',
#   '443142',
#   '453910',
#   '453920',
#   '453930',
#   '445299',
#   '443141',
#   '442299',
#   '445292'],
#  'luggage store': ['448320',
#   '453991',
#   '453998',
#   '453910',
#   '445299',
#   '453920',
#   '453930',
#   '442299',
#   '445292',
#   '446199'],
#  'building material store': ['453991',
#   '444190',
#   '453998',
#   '453910',
#   '453920',
#   '453930',
#   '444130',
#   '445299',
#   '444120',
#   '453310'],
#  'saw mill': ['332216',
#   '333991',
#   '311119',
#   '311111',
#   '322130',
#   '333519',
#   '322122',
#   '322121',
#   '322110',
#   '315190'],
#  'electrical engineer': ['335931',
#   '335932',
#   '335314',
#   '335220',
#   '335929',
#   '335999',
#   '335912',
#   '335991',
#   '335911',
#   '335313'],
#  'deck builder': ['236117',
#   '236116',
#   '236115',
#   '236118',
#   '236210',
#   '237210',
#   '236220',
#   '238160',
#   '238170',
#   '238330'],
#  'concrete product supplier': ['327332',
#   '327331',
#   '327320',
#   '327390',
#   '327999',
#   '327310',
#   '327991',
#   '327993',
#   '327992',
#   '327910'],
#  'plywood supplier': ['321211',
#   '321212',
#   '321214',
#   '321219',
#   '321213',
#   '321991',
#   '423310',
#   '321992',
#   '321920',
#   '321999'],
#  'electrical installation service': ['335931',
#   '335932',
#   '335314',
#   '335220',
#   '335929',
#   '335999',
#   '335912',
#   '335991',
#   '335911',
#   '335313'],
#  'truss manufacturer': ['321214',
#   '425120',
#   '321213',
#   '425110',
#   '424610',
#   '424710',
#   '424340',
#   '424480',
#   '424450',
#   '424460'],
#  'door supplier': ['454310',
#   '454210',
# ...
#  'promotional product supplier': ['926140',
#   '327999',
#   '327991',
#   '327993',
#   '327992',
#   '327910',
#   '311119',
#   '311930',
#   '332114',
#   '327420'],
#  'advertising service': ['541890',
#   '541810',
#   '541860',
#   '541850',
#   '541830',
#   '541840',
#   '541870',
#   '541820',
#   '541990',
#   '812990'],
#  'record storage facility': ['493190',
#   '493120',
#   '493130',
#   '493110',
#   '335911',
#   '486210',
#   '334112',
#   '711310',
#   '713930',
#   '711320'],
#  'fund management company': ['525190',
#   '525990',
#   '525910',
#   '525110',
#   '525120',
#   '525920',
#   '522293',
#   '522190',
#   '522292',
#   '522110'],
#  'recreation center': ['713950',
#   '713940',
#   '621498',
#   '713930',
#   '713920',
#   '713990',
#   '713910',
#   '621493',
#   '621492',
#   '621491'],
#  'bakery': ['311812',
#   '311811',
#   '311813',
#   '311830',
#   '311821',
#   '311520',
#   '311824',
#   '311930',
#   '311920',
#   '311911'],
#  'database management company': ['551111',
#   '551112',
#   '551114',
#   '561110',
#   '561740',
#   '561410',
#   '561330',
#   '561510',
#   '561440',
#   '561730'],
#  'market researcher': ['425110',
#   '445220',
#   '445210',
#   '445230',
#   '425120',
#   '522294',
#   '424610',
#   '424710',
#   '424340',
#   '424480'],
#  'recycling center': ['621498',
#   '621493',
#   '621492',
#   '621491',
#   '621512',
#   '621420',
#   '444110',
#   '621112',
#   '621111',
#   '621391'],
#  'regional government office': ['921190',
#   '925120',
#   '921110',
#   '926150',
#   '922190',
#   '921130',
#   '921140',
#   '922130',
#   '926140',
#   '551114'],
#  'rehabilitation center': ['621498',
#   '624310',
#   '621493',
#   '621492',
#   '621491',
#   '621512',
#   '621420',
#   '444110',
#   '621112',
#   '621111'],
#  'religious institution': ['813110',
#   '813930',
#   '813990',
#   '813910',
#   '813920',
#   '813410',
#   '813219',
#   '813940',
#   '813212',
#   '813211'],
#  'religious organization': ['813110',
#   '813990',
#   '813930',
#   '813910',
#   '813312',
#   '813311',
#   '813319',
#   '813940',
#   '813920',
#   '813212'],
#  'repair service': ['811111',
#   '811118',
#   '811420',
#   '811113',
#   '811490',
#   '811430',
#   '811112',
#   '811310',
#   '811412',
#   '811198'],
#  'emergency veterinarian service': ['624230',
#   '541940',
#   '488410',
#   '812990',
#   '812910',
#   '621910',
#   '624221',
#   '812930',
#   '541990',
#   '541890'],
#  'pet sitter': ['453910',
#   '812910',
#   '453110',
#   '453310',
#   '453210',
#   '453998',
#   '812220',
#   '453991',
#   '453220',
#   '453920'],
#  'research product development': ['541714',
#   '541713',
#   '541715',
#   '541720',
#   '925120',
#   '541910',
#   '926110',
#   '541990',
#   '327999',
#   '327991'],
#  'building society': ['444190',
#   '236220',
#   '236210',
#   '444130',
#   '336611',
#   '444110',
#   '444120',
#   '236117',
#   '236118',
#   '236116'],
#  'valet parking service': ['812930',
#   '812990',
#   '812910',
#   '812921',
#   '812922',
#   '812210',
#   '812191',
#   '812113',
#   '812220',
#   '812320'],
#  'nursing agency': ['623110',
#   '623312',
#   '623311',
#   '623990',
#   '623210',
#   '623220',
#   '926110',
#   '561311',
#   '621610',
#   '923140'],
#  'executive search firm': ['561312',
#   '921140',
#   '921110',
#   '561311',
#   '519130',
#   '921120',
#   '921130',
#   '921190',
#   '921150',
#   '519190'],
#  'recruiter': ['928120',
#   '332721',
#   '332999',
#   '332996',
#   '332994',
#   '332993',
#   '332992',
#   '332991',
#   '332919',
#   '332913'],
#  'temp agency': ['926110',
#   '561311',
#   '923140',
#   '925120',
#   '926150',
#   '921190',
#   '561599',
#   '928120',
#   '926130',
#   '926140'],
#  'health center': ['621498',
#   '621491',
#   '621492',
#   '621493',
#   '621999',
#   '621112',
#   '621391',
#   '621111',
#   '621991',
#   '621310'],
#  'restaurant': ['722513',
#   '722511',
#   '492210',
#   '561591',
#   '561599',
#   '722310',
#   '722514',
#   '722515',
#   '722410',
#   '813410'],
#  'roofing contractor': ['238160',
#   '238210',
#   '238910',
#   '238310',
#   '238990',
#   '238130',
#   '238110',
#   '238320',
#   '238140',
#   '238220'],
#  'sport nutrition store': ['446191',
#   '453991',
#   '453998',
#   '453910',
#   '445299',
#   '453920',
#   '453930',
#   '451110',
#   '442299',
#   '445292'],
#  'credit reporting agency': ['522298',
#   '561450',
#   '522210',
#   '522292',
#   '522291',
#   '522294',
#   '522293',
#   '561492',
#   '522390',
#   '522130'],
#  'automobile storage facility': ['493190',
#   '493120',
#   '493130',
#   '493110',
#   '336111',
#   '335911',
#   '441120',
#   '486210',
#   '441110',
#   '334112'],
#  'debt collection agency': ['561440',
#   '562112',
#   '562119',
#   '562111',
#   '921130',
#   '561311',
#   '561491',
#   '561499',
#   '926110',
#   '562998'],
#  'park': ['721211',
#   '713110',
#   '712190',
#   '721214',
#   '713120',
#   '712130',
#   '721120',
#   '721110',
#   '721310',
#   '721199'],
#  'court reporter': ['922110',
#   '561492',
#   '561499',
#   '921150',
#   '928110',
#   '561410',
#   '922140',
#   '561491',
#   '922190',
#   '721110'],
#  'bus tour agency': ['485510',
#   '485410',
#   '485210',
#   '485113',
#   '485999',
#   '561520',
#   '485991',
#   '485111',
#   '336350',
#   '485112'],
#  'tour operator': ['561520',
#   '561591',
#   '561599',
#   '561510',
#   '114210',
#   '115210',
#   '115115',
#   '115111',
#   '115113',
#   '114119'],
#  'convention information bureau': ['519190',
#   '519110',
#   '561591',
#   '519120',
#   '519130',
#   '517410',
#   '515210',
#   '518210',
#   '511210',
#   '512110'],
#  'balloon ride tour agency': ['561520',
#   '487990',
#   '561599',
#   '713110',
#   '561591',
#   '561510',
#   '561311',
#   '926110',
#   '713990',
#   '923140'],
#  'security guard service': ['561612',
#   '561611',
#   '561613',
#   '523110',
#   '561621',
#   '561622',
#   '523120',
#   '928110',
#   '523999',
#   '523130'],
#  'locksmith': ['561622',
#   '561621',
#   '423850',
#   '332913',
#   '332811',
#   '332812',
#   '332813',
#   '332911',
#   '332912',
#   '332991'],
#  'commercial cleaning service': ['561790',
#   '561720',
#   '562998',
#   '333318',
#   '812320',
#   '541922',
#   '561740',
#   '812990',
#   '812910',
#   '812930'],
#  'blast cleaning service': ['561790',
#   '561720',
#   '562998',
#   '812320',
#   '561740',
#   '812990',
#   '812910',
#   '812930',
#   '562991',
#   '812922'],
#  'conference center': ['621498',
#   '621493',
#   '621492',
#   '621491',
#   '621512',
#   '621420',
#   '444110',
#   '621112',
#   '621111',
#   '621391'],
#  'safety equipment supplier': ['922190',
#   '922120',
#   '336510',
#   '922150',
#   '922160',
#   '922110',
#   '922130',
#   '336991',
#   '444210',
#   '922140'],
#  'garbage dump': ['562219',
#   '335220',
#   '562212',
#   '562213',
#   '562111',
#   '562920',
#   '562211',
#   '484220',
#   '332439',
#   '336211'],
#  'sanitation service': ['325612',
#   '812990',
#   '541620',
#   '561720',
#   '812910',
#   '812930',
#   '541990',
#   '541890',
#   '812922',
#   '812921'],
#  'garbage dump service': ['812990',
#   '812910',
#   '812930',
#   '541990',
#   '541890',
#   '812922',
#   '812921',
#   '812191',
#   '812113',
#   '812320'],
#  'environmental health service': ['541620',
#   '621999',
#   '621991',
#   '621910',
#   '621310',
#   '621330',
#   '621610',
#   '621320',
#   '621391',
#   '621112'],
#  'portable toilet supplier': ['325620',
#   '562991',
#   '335210',
#   '325612',
#   '454210',
#   '325611',
#   '562998',
#   '325613',
#   '454390',
#   '454310'],
#  'public work department': ['452210',
#   '922120',
#   '238390',
#   '238190',
#   '922140',
#   '238140',
#   '238150',
#   '238110',
#   '238310',
#   '238340'],
#  'school district office': ['611110',
#   '611519',
#   '611511',
#   '611610',
#   '611512',
#   '611513',
#   '611692',
#   '611699',
#   '621399',
#   '611410'],
#  'sailmaker': ['928120',
#   '332721',
#   '332999',
#   '332996',
#   '332994',
#   '332993',
#   '332992',
#   '332991',
#   '332919',
#   '332913'],
#  'community college': ['611310',
#   '611210',
#   '611691',
#   '611692',
#   '611699',
#   '611710',
#   '611630',
#   '611610',
#   '611110',
#   '611620'],
#  'salvage yard': ['488330',
#   '336611',
#   '336612',
#   '444190',
#   '333112',
#   '112112',
#   '423140',
#   '453310',
#   '423930',
#   '335121'],
#  'business school': ['611519',
#   '611110',
#   '611511',
#   '611610',
#   '611692',
#   '611699',
#   '611512',
#   '611513',
#   '611691',
#   '611620'],
#  'trade school': ['611519',
#   '611511',
#   '611110',
#   '611610',
#   '611512',
#   '611513',
#   '611699',
#   '611692',
#   '611691',
#   '611620'],
#  'private university': ['814110',
#   '611310',
#   '611699',
#   '611692',
#   '611691',
#   '611630',
#   '611710',
#   '611610',
#   '611620',
#   '611110'],
#  'computer training school': ['611519',
#   '611512',
#   '611511',
#   '611513',
#   '611420',
#   '611110',
#   '611692',
#   '611699',
#   '611430',
#   '611610'],
#  'school supply store': ['453991',
#   '453998',
#   '453210',
#   '453910',
#   '446199',
#   '453920',
#   '453930',
#   '444190',
#   '445299',
#   '453310'],
#  'screen printer': ['323113',
#   '323111',
#   '323117',
#   '323120',
#   '334118',
#   '334412',
#   '325992',
#   '334419',
#   '811212',
#   '334112'],
#  'medium consultant': ['541840',
#   '541410',
#   '541830',
#   '334613',
#   '541810',
#   '334614',
#   '611710',
#   '541890',
#   '541611',
#   '541850'],
#  'beauty school': ['611519',
#   '611110',
#   '611511',
#   '446120',
#   '611610',
#   '611512',
#   '611513',
#   '611692',
#   '611699',
#   '812112'],
#  'flight school': ['611519',
#   '611512',
#   '611511',
#   '611110',
#   '611513',
#   '611610',
#   '611692',
#   '611699',
#   '611620',
#   '611691'],
#  'seaport': ['811310',
#   '811420',
#   '811211',
#   '811212',
#   '811213',
#   '811430',
#   '811490',
#   '811219',
#   '811113',
#   '811412'],
#  'security system supplier': ['561621',
#   '523110',
#   '523120',
#   '561622',
#   '523999',
#   '523130',
#   '523140',
#   '523991',
#   '523910',
#   '561612'],
#  'middle school': ['611519',
#   '611110',
#   '611511',
#   '611610',
#   '611512',
#   '611513',
#   '611692',
#   '611699',
#   '611620',
#   '611691'],
#  'nonprofit': ['928120',
#   '332721',
#   '332999',
#   '332996',
#   '332994',
#   '332993',
#   '332992',
#   '332991',
#   '332919',
#   '332913'],
#  'shooting range': ['213112',
#   '713990',
#   '213111',
#   '213113',
#   '213114',
#   '213115',
#   '721120',
#   '721110',
#   '813219',
#   '721211'],
#  'soccer club': ['452311',
#   '711211',
#   '813410',
#   '713910',
#   '713990',
#   '452319',
#   '713940',
#   '713930',
#   '713950',
#   '713920'],
#  'camp': ['721214',
#   '721310',
#   '721211',
#   '611620',
#   '721120',
#   '721110',
#   '721199',
#   '721191',
#   '713990',
#   '623990'],
#  'diving contractor': ['238210',
#   '238910',
#   '238310',
#   '238990',
#   '238130',
#   '238110',
#   '238320',
#   '238140',
#   '238220',
#   '238150'],
#  'language school': ['611630',
#   '611110',
#   '611519',
#   '611511',
#   '611699',
#   '611692',
#   '611610',
#   '611512',
#   '611513',
#   '611691'],
#  'english language school': ['611630',
#   '611110',
#   '611519',
#   '611511',
#   '611699',
#   '611692',
#   '611610',
#   '611512',
#   '611513',
#   '611691'],
#  'preschool': ['624410',
#   '611110',
#   '928120',
#   '332913',
#   '332811',
#   '332812',
#   '332813',
#   '332911',
#   '332912',
#   '332919'],
#  'self storage facility': ['493190',
#   '493120',
#   '493130',
#   '493110',
#   '335911',
#   '531130',
#   '486210',
#   '334112',
#   '711310',
#   '713930'],
#  'semi conductor supplier': ['335931',
#   '336213',
#   '336211',
#   '336212',
#   '336214',
#   '532120',
#   '561320',
#   '519110',
#   '519120',
#   '519190'],
#  'driving school': ['611519',
#   '611692',
#   '611511',
#   '611110',
#   '611699',
#   '611512',
#   '611513',
#   '611610',
#   '611691',
#   '611620'],
#  'trucking school': ['484220',
#   '484230',
#   '484110',
#   '484122',
#   '484121',
#   '484210',
#   '611519',
#   '611110',
#   '611511',
#   '611610'],
#  'senior citizen center': ['621498',
#   '813311',
#   '621493',
#   '621492',
#   '621491',
#   '621512',
#   '621420',
#   '444110',
#   '621112',
#   '621111'],
#  'service': ['812990',
#   '812910',
#   '812930',
#   '541990',
#   '541890',
#   '812922',
#   '812921',
#   '812191',
#   '812113',
#   '812320'],
#  'childrens hospital': ['622310',
#   '622210',
#   '622110',
#   '621420',
#   '623220',
#   '623210',
#   '423450',
#   '928120',
#   '337127',
#   '926130'],
#  'dental supply store': ['339114',
#   '453991',
#   '453998',
#   '453910',
#   '453210',
#   '446199',
#   '453920',
#   '453930',
#   '444190',
#   '445299'],
#  'shipyard': ['336611',
#   '336612',
#   '488510',
#   '488210',
#   '488410',
#   '488490',
#   '488320',
#   '488310',
#   '488390',
#   '488991'],
#  'orthodox synagogue': ['813110',
#   '236220',
#   '332919',
#   '332812',
#   '332813',
#   '332911',
#   '332912',
#   '332913',
#   '928120',
#   '333112'],
#  'short term apartment rental agency': ['532289',
#   '532284',
#   '532282',
#   '532281',
#   '532283',
#   '532111',
#   '532210',
#   '532120',
#   '532112',
#   '532310'],
#  'nutritionist': ['621399',
#   '928120',
#   '332912',
#   '332722',
#   '332811',
#   '332812',
#   '332813',
#   '332911',
#   '332913',
#   '332710'],
#  'ophthalmologist': ['423460',
#   '423450',
#   '621111',
#   '928120',
#   '332721',
#   '332811',
#   '332812',
#   '332813',
#   '332911',
#   '332912'],
#  'ophthalmology clinic': ['621498',
#   '621493',
#   '621492',
#   '621491',
#   '621112',
#   '621111',
#   '621420',
#   '621391',
#   '621410',
#   '621210'],
#  'social service organization': ['624190',
#   '624110',
#   '624120',
#   '813990',
#   '624310',
#   '624410',
#   '813319',
#   '624210',
#   '624230',
#   '622310'],
#  'social welfare center': ['624190',
#   '624120',
#   '624110',
#   '621498',
#   '624410',
#   '621492',
#   '621493',
#   '624310',
#   '621491',
#   '621112'],
#  'solar energy company': ['221114',
#   '221118',
#   '221111',
#   '221116',
#   '221117',
#   '221115',
#   '221113',
#   '551111',
#   '551112',
#   '221112'],
#  'solar energy equipment supplier': ['221114',
#   '221118',
#   '221111',
#   '221116',
#   '221117',
#   '221115',
#   '221113',
#   '221112',
#   '335929',
#   '335999'],
#  'special education school': ['611110',
#   '611519',
#   '611511',
#   '611610',
#   '611512',
#   '611692',
#   '611513',
#   '611699',
#   '923110',
#   '611620'],
#  'podiatrist': ['621391',
#   '621399',
#   '928120',
#   '332710',
#   '332722',
#   '332811',
#   '332812',
#   '332813',
#   '332911',
#   '332912'],
#  'reproductive health clinic': ['621498',
#   '621491',
#   '621492',
#   '621493',
#   '621420',
#   '621112',
#   '621391',
#   '621111',
#   '621310',
#   '621330'],
#  'sporting good store': ['451110',
#   '451130',
#   '451120',
#   '453991',
#   '453998',
#   '453310',
#   '453910',
#   '451211',
#   '453920',
#   '453930'],
#  'dialysis center': ['621492',
#   '621498',
#   '621493',
#   '621491',
#   '621512',
#   '621420',
#   '444110',
#   '621112',
#   '621111',
#   '621391'],
#  'sport complex': ['711211',
#   '711219',
#   '711212',
#   '711320',
#   '713940',
#   '711310',
#   '713990',
#   '711410',
#   '711120',
#   '711190'],
#  'wellness program': ['924110',
#   '923130',
#   '923120',
#   '923110',
#   '923140',
#   '924120',
#   '925110',
#   '926140',
#   '926120',
#   '926130'],
#  'sportswear store': ['453991',
#   '453998',
#   '453910',
#   '445299',
#   '453920',
#   '453930',
#   '442299',
#   '445292',
#   '446199',
#   '453310'],
#  'private hospital': ['814110',
#   '622310',
#   '622210',
#   '622110',
#   '928120',
#   '922160',
#   '926130',
#   '922150',
#   '927110',
#   '926140'],
#  'radiologist': ['621111',
#   '928120',
#   '332721',
#   '332996',
#   '332994',
#   '332993',
#   '332992',
#   '332991',
#   '332919',
#   '332913'],
#  'medical diagnostic imaging center': ['621512',
#   '621511',
#   '621498',
#   '621493',
#   '622110',
#   '621491',
#   '621492',
#   '325413',
#   '621910',
#   '622310'],
#  'ray lab': ['334517',
#   '621512',
#   '812921',
#   '812922',
#   '622110',
#   '622210',
#   '622310',
#   '621511',
#   '621493',
#   '423450'],
#  'blood bank': ['621991',
#   '621999',
#   '521110',
#   '522320',
#   '325414',
#   '522190',
#   '339112',
#   '522110',
#   '551111',
#   '522293'],
#  'stainless steel plant': ['331210',
#   '331222',
#   '331221',
#   '331110',
#   '331513',
#   '332111',
#   '331512',
#   '238120',
#   '331511',
#   '236210'],
#  'state agency': ['926110',
#   '921120',
#   '923110',
#   '561311',
#   '923140',
#   '928120',
#   '925120',
#   '921190',
#   '926150',
#   '926130'],
#  'heliport': ['928120',
#   '332721',
#   '332999',
#   '332996',
#   '332994',
#   '332993',
#   '332992',
#   '332991',
#   '332919',
#   '332913'],
#  'health care company': ['621999',
#   '621991',
#   '621910',
#   '621610',
#   '621310',
#   '621330',
#   '621210',
#   '621410',
#   '623210',
#   '623990'],
#  'psychiatric hospital': ['622210',
#   '622310',
#   '622110',
#   '623220',
#   '621420',
#   '623110',
#   '623210',
#   '423450',
#   '928120',
#   '337127'],
#  'state government office': ['921190',
#   '921110',
#   '921120',
#   '926150',
#   '921130',
#   '922190',
#   '923110',
#   '921140',
#   '922130',
#   '926140'],
#  'medical institution': ['621511',
#   '339112',
#   '621512',
#   '622110',
#   '339116',
#   '339115',
#   '339113',
#   '621491',
#   '339114',
#   '621493'],
#  'steel construction company': ['238120',
#   '236210',
#   '236220',
#   '331221',
#   '331210',
#   '331222',
#   '237990',
#   '237120',
#   '236116',
#   '237110'],
#  'cleaning service': ['561790',
#   '561720',
#   '562998',
#   '812320',
#   '561740',
#   '812990',
#   '812910',
#   '812930',
#   '562991',
#   '812922'],
#  ...}

# %%
queries_dic
# Out:
# {'home improvement store': ['444110', '444120', '444130', '444190'],
#  'diesel fuel supplier': ['424710', '424720'],
#  'church': ['813110'],
#  'farm': ['115116', '115111', '115112', '115113', '115114', '115115'],
#  'seed supplier': ['424910', '424920', '424930', '424940', '424950', '424990'],
#  'accountant': ['541219', '541211', '541213', '541214'],
#  'trucking company': ['484110', '484121', '484122'],
#  'exporter': ['522293',
#   '522291',
#   '522292',
#   '522294',
#   '522298',
#   '522210',
#   '522220'],
#  'grain elevator': ['493130', '493110', '493120', '493190'],
#  'popcorn store': ['445299', '445291', '445292', '445210', '445220', '445230'],
#  'agricultural service': ['115116',
#   '115111',
#   '115112',
#   '115113',
#   '115114',
#   '115115'],
#  'warehouse': ['493110', '493120', '493130', '493190'],
#  'agricultural production': ['111998',
#   '111991',
#   '111992',
#   '111910',
#   '111920',
#   '111930',
#   '111940'],
#  'ranch': ['112130', '112111', '112112', '112120'],
#  'holding company': ['551112', '551111', '551114'],
#  'farm equipment supplier': ['423820',
#   '423810',
#   '423830',
#   '423840',
#   '423850',
#   '423860'],
#  'store': ['452319', '452311'],
#  'grocery store': ['445110', '445120'],
#  'rice mill': ['311212',
#   '311211',
#   '311213',
#   '311221',
#   '311224',
#   '311225',
#   '311230'],
#  'food product supplier': ['424490',
#   '424410',
#   '424420',
#   '424430',
#   '424440',
#   '424450',
#   '424460',
#   '424470',
#   '424480'],
#  'accounting firm': ['541219', '541211', '541213', '541214'],
#  'produce market': ['445230',
#   '445210',
#   '445220',
#   '445291',
#   '445292',
#   '445299'],
#  'pet supply store': ['453910', '453920', '453930', '453991', '453998'],
#  'wholesaler': ['425120', '425110'],
#  'produce wholesaler': ['424480',
#   '424410',
#   '424420',
#   '424430',
#   '424440',
#   '424450',
#   '424460',
#   '424470',
#   '424490'],
#  'distribution service': ['541614',
#   '541611',
#   '541612',
#   '541613',
#   '541618',
#   '541620',
#   '541690'],
#  'crop grower': ['111998',
#   '111991',
#   '111992',
#   '111910',
#   '111920',
#   '111930',
#   '111940'],
#  'addiction treatment center': ['623220', '623210'],
#  'natural good store': ['446191', '446199', '446110', '446120', '446130'],
#  'orchard': ['111331',
#   '111332',
#   '111333',
#   '111334',
#   '111335',
#   '111336',
#   '111339',
#   '111310',
#   '111320'],
#  'lumber store': ['423310', '423320', '423330', '423390'],
#  'mine': ['212299', '212291', '212210', '212221', '212222', '212230'],
#  'transportation service': ['485999', '485991'],
#  'investment company': ['523110', '523120', '523130', '523140'],
#  'fruit wholesaler': ['424480',
#   '424410',
#   '424420',
#   '424430',
#   '424440',
#   '424450',
#   '424460',
#   '424470',
#   '424490'],
#  'real estate agency': ['531210'],
#  'event venue': ['561920', '561910', '561990'],
#  'frozen dessert supplier': ['311520', '311511', '311512', '311513', '311514'],
#  'wine wholesaler importer': ['424820', '424810'],
#  'winery': ['312130', '312111', '312112', '312113', '312120', '312140'],
#  'aerospace company': ['336411',
#   '336412',
#   '336413',
#   '336414',
#   '336415',
#   '336419'],
#  'cold storage facility': ['493120', '493110', '493130', '493190'],
#  'employment agency': ['561311', '561312', '561320', '561330'],
#  'plant nursery': ['444220', '444210'],
#  'air conditioning contractor': ['238220', '238210', '238290'],
#  'air conditioning repair service': ['238220', '238210', '238290'],
#  'fruit vegetable wholesaler': ['445230',
#   '445210',
#   '445220',
#   '445291',
#   '445292',
#   '445299'],
#  'aircraft rental service': ['532411', '532412', '532420', '532490'],
#  'monastery': ['813110'],
#  'allergist': ['621111', '621112'],
#  'herb shop': ['446191', '446199', '446110', '446120', '446130'],
#  'aluminum supplier': ['331313', '331314', '331315', '331318'],
#  'ambulance service': ['621910', '621991', '621999'],
#  'wholesale plant nursery': ['424930',
#   '424910',
#   '424920',
#   '424940',
#   '424950',
#   '424990'],
#  'amusement machine supplier': ['713120', '713110'],
#  'animal hospital': ['541940',
#   '541910',
#   '541921',
#   '541922',
#   '541930',
#   '541990'],
#  'farmer market': ['445230', '445210', '445220', '445291', '445292', '445299'],
#  'vaporizer store': ['453991', '453998', '453910', '453920', '453930'],
#  'cigar shop': ['453991', '453998', '453910', '453920', '453930'],
#  'tobacco shop': ['453991', '453998', '453910', '453920', '453930'],
#  'well drilling contractor': ['213111',
#   '213112',
#   '213113',
#   '213114',
#   '213115'],
#  'library': ['519120', '519110', '519130', '519190'],
#  'apartment building': ['531110', '531120', '531130', '531190'],
#  'apartment rental agency': ['531110', '531120', '531130', '531190'],
#  'dairy farm': ['112120', '112111', '112112', '112130'],
#  'architect': ['541310',
#   '541320',
#   '541330',
#   '541340',
#   '541350',
#   '541360',
#   '541370',
#   '541380'],
#  'organic farm': ['111998',
#   '111991',
#   '111992',
#   '111910',
#   '111920',
#   '111930',
#   '111940'],
#  'architectural designer': ['541310',
#   '541320',
#   '541330',
#   '541340',
#   '541350',
#   '541360',
#   '541370',
#   '541380'],
#  'architecture firm': ['541310',
#   '541320',
#   '541330',
#   '541340',
#   '541350',
#   '541360',
#   '541370',
#   '541380'],
#  'livestock producer': ['112111', '112112', '112120', '112130'],
#  'dairy supplier': ['424430',
#   '424410',
#   '424420',
#   '424440',
#   '424450',
#   '424460',
#   '424470',
#   '424480',
#   '424490'],
#  'biotechnology company': ['541714', '541713', '541715', '541720'],
#  'artist': ['711510'],
#  'egg supplier': ['112310', '112320', '112330', '112340', '112390'],
#  'poultry farm': ['311615', '311611', '311612', '311613'],
#  'chicken hatchery': ['112340', '112310', '112320', '112330', '112390'],
#  'art organization': ['711190', '711110', '711120', '711130'],
#  'association organization': ['813910',
#   '813920',
#   '813930',
#   '813940',
#   '813990'],
#  'food store': ['445110', '445120'],
#  'deli': ['722513', '722511', '722514', '722515'],
#  'bank': ['522110', '522120', '522130', '522190'],
#  'fish processing': ['311710'],
#  'fish farm': ['112511', '112512', '112519'],
#  'seafood wholesaler': ['424460',
#   '424410',
#   '424420',
#   '424430',
#   '424440',
#   '424450',
#   '424470',
#   '424480',
#   '424490'],
#  'tropical fish store': ['453910', '453920', '453930', '453991', '453998'],
#  'non profit organization': ['813410'],
#  'economic development agency': ['926110',
#   '926120',
#   '926130',
#   '926140',
#   '926150'],
#  'seafood market': ['445220',
#   '445210',
#   '445230',
#   '445291',
#   '445292',
#   '445299'],
#  'honey farm': ['112910', '112920', '112930', '112990'],
#  'horse breeder': ['112920', '112910', '112930', '112990'],
#  'asphalt contractor': ['238990', '238910'],
#  'livestock dealer': ['424520', '424510', '424590'],
#  'department store': ['452210'],
#  'mill': ['321113', '321114'],
#  'atv dealer': ['441228', '441222', '441210'],
#  'audio visual consultant': ['334310'],
#  'pallet supplier': ['321920',
#   '321911',
#   '321912',
#   '321918',
#   '321991',
#   '321992',
#   '321999'],
#  'wood supplier': ['423310', '423320', '423330', '423390'],
#  'hardware store': ['444130', '444110', '444120', '444190'],
#  'furniture wholesaler': ['423210', '423220'],
#  'auditor': ['541211', '541213', '541214', '541219'],
#  'oil natural gas company': ['213111', '213112', '213113', '213114', '213115'],
#  'auto body shop': ['811111',
#   '811112',
#   '811113',
#   '811118',
#   '811121',
#   '811122',
#   '811191',
#   '811192',
#   '811198'],
#  'boat repair shop': ['336611', '336612'],
#  'association': ['813910', '813920', '813930', '813940', '813990'],
#  'railing contractor': ['332323',
#   '332321',
#   '332322',
#   '332311',
#   '332312',
#   '332313'],
#  'publisher': ['511130', '511110', '511120', '511140', '511191', '511199'],
#  'pond supply store': ['221310', '221320', '221330'],
#  'agriculture cooperative': ['926140', '926110', '926120', '926130', '926150'],
#  'printing equipment supplier': ['333244',
#   '333241',
#   '333242',
#   '333243',
#   '333249'],
#  'auto insurance agency': ['524210', '524291', '524292', '524298'],
#  'alternative fuel station': ['447190', '447110'],
#  'auto part manufacturer': ['336390',
#   '336310',
#   '336320',
#   '336330',
#   '336340',
#   '336350',
#   '336360',
#   '336370'],
#  'foundation': ['813211', '813212', '813219'],
#  'fertilizer supplier': ['325311', '325312', '325314', '325320'],
#  'farming company': ['115116',
#   '115111',
#   '115112',
#   '115113',
#   '115114',
#   '115115'],
#  'finance broker': ['522310', '522320', '522390'],
#  'agricultural cooperative': ['926140',
#   '926110',
#   '926120',
#   '926130',
#   '926150'],
#  'fire station': ['922160',
#   '922110',
#   '922120',
#   '922130',
#   '922140',
#   '922150',
#   '922190'],
#  'environmental consultant': ['541620',
#   '541611',
#   '541612',
#   '541613',
#   '541614',
#   '541618',
#   '541690'],
#  'civil engineer': ['237990'],
#  'fire protection service': ['922160',
#   '922110',
#   '922120',
#   '922130',
#   '922140',
#   '922150',
#   '922190'],
#  'gas company': ['221210'],
#  'oilfield': ['213111', '213112', '213113', '213114', '213115'],
#  'banquet hall': ['722320', '722310', '722330'],
#  'mining company': ['212299',
#   '212291',
#   '212210',
#   '212221',
#   '212222',
#   '212230'],
#  'coalfield': ['212112', '212111', '212113'],
#  'steel fabricator': ['332312',
#   '332311',
#   '332313',
#   '332321',
#   '332322',
#   '332323'],
#  'quarry': ['212311',
#   '212312',
#   '212313',
#   '212319',
#   '212321',
#   '212322',
#   '212324',
#   '212325',
#   '212391',
#   '212392',
#   '212393',
#   '212399'],
#  'gold mining company': ['212221',
#   '212222',
#   '212210',
#   '212230',
#   '212291',
#   '212299'],
#  'high rise building': ['236220', '236210'],
#  'basketball club': ['711211', '711212', '711219'],
#  'gold dealer': ['423940', '423910', '423920', '423930', '423990'],
#  'battery manufacturer': ['335911',
#   '335912',
#   '335921',
#   '335929',
#   '335931',
#   '335932',
#   '335991',
#   '335999'],
#  'electric utility company': ['926130',
#   '926110',
#   '926120',
#   '926140',
#   '926150'],
#  'environmental program': ['813312', '813311', '813319'],
#  'office': ['561110'],
#  'stone supplier': ['423320', '423310', '423330', '423390'],
#  'aggregate supplier': ['423320', '423310', '423330', '423390'],
#  'sand gravel supplier': ['212321',
#   '212322',
#   '212324',
#   '212325',
#   '212311',
#   '212312',
#   '212313',
#   '212319',
#   '212391',
#   '212392',
#   '212393',
#   '212399'],
#  'building material supplier': ['444190', '444110', '444120', '444130'],
#  'beauty supply store': ['446120', '446110', '446130', '446191', '446199'],
#  'crushed stone supplier': ['423320', '423310', '423330', '423390'],
#  'rock shop': ['423940', '423910', '423920', '423930', '423990'],
#  'road construction company': ['237310'],
#  'marketing consultant': ['541613',
#   '541611',
#   '541612',
#   '541614',
#   '541618',
#   '541620',
#   '541690'],
#  'blood testing service': ['541380',
#   '541310',
#   '541320',
#   '541330',
#   '541340',
#   '541350',
#   '541360',
#   '541370'],
#  'contractor': ['238990', '238910'],
#  'excavating contractor': ['238910', '238990'],
#  'asphalt mixing plant': ['324121', '324122', '324110', '324191', '324199'],
#  'ready mix concrete supplier': ['327320',
#   '327310',
#   '327331',
#   '327332',
#   '327390'],
#  'sand plant': ['212322',
#   '212321',
#   '212324',
#   '212325',
#   '212311',
#   '212312',
#   '212313',
#   '212319',
#   '212391',
#   '212392',
#   '212393',
#   '212399'],
#  'bmw dealer': ['441120', '441110'],
#  'bookbinder': ['323117', '323111', '323113', '323120'],
#  'garden center': ['444220', '444210'],
#  'abrasive supplier': ['327910', '327991', '327992', '327993', '327999'],
#  'granite supplier': ['327991', '327992', '327993', '327999', '327910'],
#  'drilling contractor': ['213111', '213112', '213113', '213114', '213115'],
#  'bpo company': ['561421',
#   '561422',
#   '561410',
#   '561431',
#   '561439',
#   '561440',
#   '561450',
#   '561491',
#   '561492',
#   '561499'],
#  'oil gas exploration service': ['213111',
#   '213112',
#   '213113',
#   '213114',
#   '213115'],
#  'building complex': ['531110', '531120', '531130', '531190'],
#  'construction equipment supplier': ['423810',
#   '423820',
#   '423830',
#   '423840',
#   '423850',
#   '423860'],
#  'mining equipment': ['333131', '333132', '333111', '333112', '333120'],
#  'bus ticket agency': ['561599', '561591', '561510', '561520'],
#  'business center': ['561439',
#   '561431',
#   '561410',
#   '561421',
#   '561422',
#   '561440',
#   '561450',
#   '561491',
#   '561492',
#   '561499'],
#  'skyscraper': ['236220', '236210'],
#  'software company': ['511210'],
#  'business development service': ['541611',
#   '541612',
#   '541613',
#   '541614',
#   '541618',
#   '541620',
#   '541690'],
#  'business management consultant': ['541611',
#   '541612',
#   '541613',
#   '541614',
#   '541618',
#   '541620',
#   '541690'],
#  'cabinet maker': ['337110', '337121', '337122', '337124', '337125', '337127'],
#  'call center': ['561421',
#   '561422',
#   '561410',
#   '561431',
#   '561439',
#   '561440',
#   '561450',
#   '561491',
#   '561492',
#   '561499'],
#  'cancer treatment center': ['622310'],
#  'power plant consultant': ['237130', '237110', '237120'],
#  'business park': ['812930', '812910', '812921', '812922', '812990'],
#  'petroleum product company': ['424720', '424710'],
#  'parking lot': ['812930', '812910', '812921', '812922', '812990'],
#  'water utility company': ['221310', '221320', '221330'],
#  'car repair maintenance': ['811111',
#   '811112',
#   '811113',
#   '811118',
#   '811121',
#   '811122',
#   '811191',
#   '811192',
#   '811198'],
#  'water treatment plant': ['221310', '221320', '221330'],
#  'car service': ['811198',
#   '811191',
#   '811192',
#   '811111',
#   '811112',
#   '811113',
#   '811118',
#   '811121',
#   '811122'],
#  'cattle market': ['424520', '424510', '424590'],
#  'sewage disposal service': ['221320', '221310', '221330'],
#  'certified public accountant': ['541211', '541213', '541214', '541219'],
#  'government office': ['921190',
#   '921110',
#   '921120',
#   '921130',
#   '921140',
#   '921150'],
#  'charity': ['813219', '813211', '813212'],
#  'air conditioning system supplier': ['423730', '423710', '423720', '423740'],
#  'chemical industry': ['325998', '325991', '325992', '325910', '325920'],
#  'chemical manufacturer': ['325998', '325991', '325992', '325910', '325920'],
#  'title company': ['541191', '541199', '541110', '541120'],
#  'chemical plant': ['325998', '325991', '325992', '325910', '325920'],
#  'property management company': ['531311', '531312', '531320', '531390'],
#  'custom home builder': ['236115', '236116', '236117', '236118'],
#  'window installation service': ['238150',
#   '238110',
#   '238120',
#   '238130',
#   '238140',
#   '238160',
#   '238170',
#   '238190'],
#  'fire damage restoration service': ['562910', '562920', '562991', '562998'],
#  'equipment rental agency': ['532490', '532411', '532412', '532420'],
#  'chemical wholesaler': ['424690', '424610'],
#  'financial planner': ['523930', '523910', '523920', '523991', '523999'],
#  'telecommunication service provider': ['517311', '517312'],
#  'energy equipment solution': ['444210', '444220'],
#  'chiropractor': ['621310', '621320', '621330', '621340', '621391', '621399'],
#  'steel distributor': ['423510', '423520'],
#  'city government office': ['921190',
#   '921110',
#   '921120',
#   '921130',
#   '921140',
#   '921150'],
#  'crane service': ['333923',
#   '333921',
#   '333922',
#   '333924',
#   '333912',
#   '333914',
#   '333991',
#   '333992',
#   '333993',
#   '333994',
#   '333995',
#   '333996',
#   '333997',
#   '333999'],
#  'garage door supplier': ['238350',
#   '238310',
#   '238320',
#   '238330',
#   '238340',
#   '238390'],
#  'industrial door supplier': ['332321',
#   '332322',
#   '332323',
#   '332311',
#   '332312',
#   '332313'],
#  'city town hall': ['921110',
#   '921120',
#   '921130',
#   '921140',
#   '921150',
#   '921190'],
#  'clothing wholesaler': ['424310', '424320', '424330', '424340'],
#  'coin operated laundry equipment supplier': ['812310',
#   '812320',
#   '812331',
#   '812332'],
#  'metal supplier': ['423510', '423520'],
#  'glass shop': ['238150',
#   '238110',
#   '238120',
#   '238130',
#   '238140',
#   '238160',
#   '238170',
#   '238190'],
#  'college': ['611310'],
#  'siding contractor': ['238170',
#   '238110',
#   '238120',
#   '238130',
#   '238140',
#   '238150',
#   '238160',
#   '238190'],
#  'commercial printer': ['323111', '323113', '323117', '323120'],
#  'storage facility': ['493110', '493120', '493130', '493190'],
#  'communication tower': ['237130', '237110', '237120'],
#  'janitorial service': ['561720', '561710', '561730', '561740', '561790'],
#  'computer consultant': ['541512', '541511', '541513', '541519'],
#  'fire protection system supplier': ['922160',
#   '922110',
#   '922120',
#   '922130',
#   '922140',
#   '922150',
#   '922190'],
#  'elevator service': ['333921',
#   '333922',
#   '333923',
#   '333924',
#   '333912',
#   '333914',
#   '333991',
#   '333992',
#   '333993',
#   '333994',
#   '333995',
#   '333996',
#   '333997',
#   '333999'],
#  'industrial equipment supplier': ['423830',
#   '423810',
#   '423820',
#   '423840',
#   '423850',
#   '423860'],
#  'dry wall contractor': ['238310',
#   '238320',
#   '238330',
#   '238340',
#   '238350',
#   '238390'],
#  'insulation contractor': ['238310',
#   '238320',
#   '238330',
#   '238340',
#   '238350',
#   '238390'],
#  'concrete contractor': ['238110',
#   '238120',
#   '238130',
#   '238140',
#   '238150',
#   '238160',
#   '238170',
#   '238190'],
#  'scaffolding rental service': ['532490', '532411', '532412', '532420'],
#  'construction company': ['236220', '236210'],
#  'flooring store': ['442210', '442291', '442299'],
#  'flooring contractor': ['238330',
#   '238310',
#   '238320',
#   '238340',
#   '238350',
#   '238390'],
#  'tile contractor': ['238340',
#   '238310',
#   '238320',
#   '238330',
#   '238350',
#   '238390'],
#  'tile manufacturer': ['238340',
#   '238310',
#   '238320',
#   '238330',
#   '238350',
#   '238390'],
#  'glass mirror shop': ['238150',
#   '238110',
#   '238120',
#   '238130',
#   '238140',
#   '238160',
#   '238170',
#   '238190'],
#  'construction material wholesaler': ['423390', '423310', '423320', '423330'],
#  'gutter cleaning service': ['561790', '561710', '561720', '561730', '561740'],
#  'sheet metal contractor': ['332322',
#   '332321',
#   '332323',
#   '332311',
#   '332312',
#   '332313'],
#  'consultant': ['541618',
#   '541611',
#   '541612',
#   '541613',
#   '541614',
#   '541620',
#   '541690'],
#  'container service': ['332439', '332431', '332410', '332420'],
#  'septic system service': ['562991', '562998', '562910', '562920'],
#  'corporate campus': ['551114', '551111', '551112'],
#  'water damage restoration service': ['562910', '562920', '562991', '562998'],
#  'welder': ['333992',
#   '333991',
#   '333993',
#   '333994',
#   '333995',
#   '333996',
#   '333997',
#   '333999',
#   '333912',
#   '333914',
#   '333921',
#   '333922',
#   '333923',
#   '333924'],
#  'corporate office': ['551114', '551111', '551112'],
#  'animal': ['112990', '112910', '112920', '112930'],
#  'animal feed store': ['453910', '453920', '453930', '453991', '453998'],
#  'animal protection organization': ['813312', '813311', '813319'],
#  'brewing supply store': ['424810', '424820'],
#  'cosmetic store': ['446120', '446110', '446130', '446191', '446199'],
#  'county government office': ['921190',
#   '921110',
#   '921120',
#   '921130',
#   '921140',
#   '921150'],
#  'sugar factory': ['311314', '311313', '311340', '311351', '311352'],
#  'confectionery wholesaler': ['424450',
#   '424410',
#   '424420',
#   '424430',
#   '424440',
#   '424460',
#   '424470',
#   '424480',
#   '424490'],
#  'financial institution': ['921130',
#   '921110',
#   '921120',
#   '921140',
#   '921150',
#   '921190'],
#  'candy store': ['445292', '445291', '445299', '445210', '445220', '445230'],
#  'confectionery': ['445292', '445291', '445299', '445210', '445220', '445230'],
#  'chocolate factory': ['311351', '311352', '311313', '311314', '311340'],
#  'chocolate shop': ['311351', '311352', '311313', '311314', '311340'],
#  'courier service': ['492110'],
#  'coworking space': ['531120', '531110', '531130', '531190'],
#  'frozen food manufacturer': ['311412',
#   '311411',
#   '311421',
#   '311422',
#   '311423'],
#  'beverage distributor': ['424820', '424810'],
#  'agricultural organization': ['926140',
#   '926110',
#   '926120',
#   '926130',
#   '926150'],
#  'dairy store': ['424430',
#   '424410',
#   '424420',
#   '424440',
#   '424450',
#   '424460',
#   '424470',
#   '424480',
#   '424490'],
#  'dairy': ['112120', '112111', '112112', '112130'],
#  'ice cream shop': ['311520', '311511', '311512', '311513', '311514'],
#  'medical laboratory': ['621511', '621512'],
#  'demolition contractor': ['238910', '238990'],
#  'meat processor': ['311612', '311611', '311613', '311615'],
#  'fmcg manufacturer': ['532289',
#   '532281',
#   '532282',
#   '532283',
#   '532284',
#   '532210'],
#  'garbage collection service': ['562111', '562112', '562119'],
#  'wholesale bakery': ['311812',
#   '311811',
#   '311813',
#   '311821',
#   '311824',
#   '311830'],
#  'dentist': ['621210'],
#  'dessert shop': ['311813', '311811', '311812', '311821', '311824', '311830'],
#  'cupcake shop': ['311811', '311812', '311813', '311821', '311824', '311830'],
#  'nut store': ['445292', '445291', '445299', '445210', '445220', '445230'],
#  'wholesale grocer': ['424490',
#   '424410',
#   '424420',
#   '424430',
#   '424440',
#   '424450',
#   '424460',
#   '424470',
#   '424480'],
#  'design engineer': ['541330',
#   '541310',
#   '541320',
#   '541340',
#   '541350',
#   '541360',
#   '541370',
#   '541380'],
#  'business business service': ['561499',
#   '561491',
#   '561492',
#   '561410',
#   '561421',
#   '561422',
#   '561431',
#   '561439',
#   '561440',
#   '561450'],
#  'condiment supplier': ['311941',
#   '311942',
#   '311911',
#   '311919',
#   '311920',
#   '311930',
#   '311991',
#   '311999'],
#  'digital printing service': ['323111', '323113', '323117', '323120'],
#  'culinary school': ['611519', '611511', '611512', '611513'],
#  'importer': ['522293',
#   '522291',
#   '522292',
#   '522294',
#   '522298',
#   '522210',
#   '522220'],
#  'bottled water supplier': ['312112',
#   '312111',
#   '312113',
#   '312120',
#   '312130',
#   '312140'],
#  'coffee roaster': ['311920',
#   '311911',
#   '311919',
#   '311930',
#   '311941',
#   '311942',
#   '311991',
#   '311999'],
#  'packaging supply store': ['561910', '561920', '561990'],
#  'ice supplier': ['312113', '312111', '312112', '312120', '312130', '312140'],
#  'brewery': ['312120', '312111', '312112', '312113', '312130', '312140'],
#  'winemaking company': ['312130',
#   '312111',
#   '312112',
#   '312113',
#   '312120',
#   '312140'],
#  'distillery': ['312140', '312111', '312112', '312113', '312120', '312130'],
#  'disability service support organisation': ['624120', '624110', '624190'],
#  'district government office': ['921190',
#   '921110',
#   '921120',
#   '921130',
#   '921140',
#   '921150'],
#  'air filter supplier': ['333413', '333414', '333415'],
#  'tire shop': ['441320', '441310'],
#  'fastener supplier': ['339993',
#   '339991',
#   '339992',
#   '339994',
#   '339995',
#   '339999',
#   '339910',
#   '339920',
#   '339930',
#   '339940',
#   '339950'],
#  'fabric product manufacturer': ['313310', '313320'],
#  'textile': ['313310', '313320'],
#  'textile exporter': ['313310', '313320'],
#  'textile engineer': ['313310', '313320'],
#  'fabric store': ['451130', '451110', '451120', '451140'],
#  'knit shop': ['313240', '313210', '313220', '313230'],
#  'doctor': ['621111', '621112'],
#  'lamination service': ['326130',
#   '326111',
#   '326112',
#   '326113',
#   '326121',
#   '326122',
#   '326140',
#   '326150',
#   '326160',
#   '326191',
#   '326199'],
#  'plastic resin manufacturer': ['325211', '325212', '325220'],
#  'carpet manufacturer': ['314110', '314120'],
#  'upholstery shop': ['811420', '811411', '811412', '811430', '811490'],
#  'business administration service': ['541611',
#   '541612',
#   '541613',
#   '541614',
#   '541618',
#   '541620',
#   '541690'],
#  'furniture store': ['442110'],
#  'dry cleaner': ['812320', '812310', '812331', '812332'],
#  'packaging company': ['561910', '561920', '561990'],
#  'duty free store': ['453998', '453991', '453910', '453920', '453930'],
#  'commerce service': ['454110'],
#  'cable company': ['515210'],
#  'education': ['611710'],
#  'outlet store': ['452319', '452311'],
#  'lingerie store': ['448190',
#   '448110',
#   '448120',
#   '448130',
#   '448140',
#   '448150'],
#  'clothes fabric manufacturer': ['313310', '313320'],
#  'education center': ['611710'],
#  'uniform store': ['448190', '448110', '448120', '448130', '448140', '448150'],
#  'men clothing store': ['448110',
#   '448120',
#   '448130',
#   '448140',
#   '448150',
#   '448190'],
#  'clothing store': ['448190',
#   '448110',
#   '448120',
#   '448130',
#   '448140',
#   '448150'],
#  'woman clothing store': ['448120',
#   '448110',
#   '448130',
#   '448140',
#   '448150',
#   '448190'],
#  'western apparel store': ['448140',
#   '448110',
#   '448120',
#   '448130',
#   '448150',
#   '448190'],
#  'costume store': ['532281', '532282', '532283', '532284', '532289', '532210'],
#  'game store': ['451120', '451110', '451130', '451140'],
#  'hat shop': ['448150', '448110', '448120', '448130', '448140', '448190'],
#  'leather good manufacturer': ['448320', '448310'],
#  'educational consultant': ['611710'],
#  'leather exporter': ['316998', '316992'],
#  'shoe store': ['448210'],
#  'boutique': ['448120', '448110', '448130', '448140', '448150', '448190'],
#  'leather wholesaler': ['448320', '448310'],
#  'handbag shop': ['316992', '316998'],
#  'electronics store': ['443142', '443141'],
#  'luggage store': ['448320', '448310'],
#  'building material store': ['444190', '444110', '444120', '444130'],
#  'saw mill': ['321113', '321114'],
#  'electrical engineer': ['541330',
#   '541310',
#   '541320',
#   '541340',
#   '541350',
#   '541360',
#   '541370',
#   '541380'],
#  'deck builder': ['238350', '238310', '238320', '238330', '238340', '238390'],
#  'concrete product supplier': ['327390',
#   '327310',
#   '327320',
#   '327331',
#   '327332'],
#  'plywood supplier': ['321211', '321212', '321213', '321214', '321219'],
#  'electrical installation service': ['238210', '238220', '238290'],
#  'truss manufacturer': ['321214', '321211', '321212', '321213', '321219'],
#  'door supplier': ['321911',
#   '321912',
#   '321918',
#   '321920',
#   '321991',
#   '321992',
#   '321999'],
#  'wood laminate flooring supplier': ['321918',
#   '321911',
#   '321912',
#   '321920',
#   '321991',
#   '321992',
#   '321999'],
#  'aircraft supply store': ['423860',
#   '423810',
#   '423820',
#   '423830',
#   '423840',
#   '423850'],
#  'modular home builder': ['321991',
#   '321992',
#   '321999',
#   '321911',
#   '321912',
#   '321918',
#   '321920'],
#  'portable building manufacturer': ['332311',
#   '332312',
#   '332313',
#   '332321',
#   '332322',
#   '332323'],
#  'modular home dealer': ['453930', '453910', '453920', '453991', '453998'],
#  'mulch supplier': ['424910',
#   '424920',
#   '424930',
#   '424940',
#   '424950',
#   '424990'],
#  'electrician': ['238210', '238220', '238290'],
#  'paper mill': ['322110', '322121', '322122', '322130'],
#  'energy supplier': ['221118',
#   '221111',
#   '221112',
#   '221113',
#   '221114',
#   '221115',
#   '221116',
#   '221117',
#   '221121',
#   '221122'],
#  'engineer': ['541330',
#   '541310',
#   '541320',
#   '541340',
#   '541350',
#   '541360',
#   '541370',
#   '541380'],
#  'print shop': ['323111', '323113', '323117', '323120'],
#  'custom label printer': ['323111', '323113', '323117', '323120'],
#  'marketing': ['541613',
#   '541611',
#   '541612',
#   '541614',
#   '541618',
#   '541620',
#   '541690'],
#  'marketing agency': ['541810',
#   '541820',
#   '541830',
#   '541840',
#   '541850',
#   '541860',
#   '541870',
#   '541890'],
#  'engineering consultant': ['541330',
#   '541310',
#   '541320',
#   '541340',
#   '541350',
#   '541360',
#   '541370',
#   '541380'],
#  'entertainer': ['713990', '713910', '713920', '713930', '713940', '713950'],
#  'envelope supplier': ['322230',
#   '322211',
#   '322212',
#   '322219',
#   '322220',
#   '322291',
#   '322299'],
#  'oil refinery': ['324110', '324121', '324122', '324191', '324199'],
#  'recording studio': ['512240', '512230', '512250', '512290'],
#  'environment renewable natural resource': ['221118',
#   '221111',
#   '221112',
#   '221113',
#   '221114',
#   '221115',
#   '221116',
#   '221117',
#   '221121',
#   '221122'],
#  'finishing material supplier': ['444190', '444110', '444120', '444130'],
#  'event ticket seller': ['561599', '561591', '561510', '561520'],
#  'waterproofing company': ['238390',
#   '238310',
#   '238320',
#   '238330',
#   '238340',
#   '238350'],
#  'auto part store': ['441310', '441320'],
#  'heating oil supplier': ['454310', '454390'],
#  'family practice physician': ['621111', '621112'],
#  'machining manufacturer': ['333249', '333241', '333242', '333243', '333244'],
#  'industrial gas supplier': ['325120',
#   '325110',
#   '325130',
#   '325180',
#   '325193',
#   '325194',
#   '325199'],
#  'welding supply store': ['333992',
#   '333991',
#   '333993',
#   '333994',
#   '333995',
#   '333996',
#   '333997',
#   '333999',
#   '333912',
#   '333914',
#   '333921',
#   '333922',
#   '333923',
#   '333924'],
#  'dry ice supplier': ['312113',
#   '312111',
#   '312112',
#   '312120',
#   '312130',
#   '312140'],
#  'private equity firm': ['523920', '523910', '523930', '523991', '523999'],
#  'family service center': ['624190', '624110', '624120'],
#  'federal government office': ['921190',
#   '921110',
#   '921120',
#   '921130',
#   '921140',
#   '921150'],
#  'vitamin supplement store': ['446191',
#   '446199',
#   '446110',
#   '446120',
#   '446130'],
#  'feed manufacturer': ['311119', '311111'],
#  'medical equipment supplier': ['423450',
#   '423410',
#   '423420',
#   '423430',
#   '423440',
#   '423460',
#   '423490'],
#  'medical supply store': ['423450',
#   '423410',
#   '423420',
#   '423430',
#   '423440',
#   '423460',
#   '423490'],
#  'medical clinic': ['621111', '621112'],
#  'research institute': ['541715', '541713', '541714', '541720'],
#  'biochemical supplier': ['424690', '424610'],
#  'fiber optic product supplier': ['335921',
#   '335929',
#   '335911',
#   '335912',
#   '335931',
#   '335932',
#   '335991',
#   '335999'],
#  'paint manufacturer': ['325510', '325520'],
#  'equipment supplier': ['423830',
#   '423810',
#   '423820',
#   '423840',
#   '423850',
#   '423860'],
#  'food': ['311999',
#   '311991',
#   '311911',
#   '311919',
#   '311920',
#   '311930',
#   '311941',
#   '311942'],
#  'pipe supplier': ['332996',
#   '332991',
#   '332992',
#   '332993',
#   '332994',
#   '332999',
#   '332911',
#   '332912',
#   '332913',
#   '332919'],
#  'oil field equipment supplier': ['333132',
#   '333131',
#   '333111',
#   '333112',
#   '333120'],
#  'food broker': ['424410',
#   '424420',
#   '424430',
#   '424440',
#   '424450',
#   '424460',
#   '424470',
#   '424480',
#   '424490'],
#  'food manufacturer': ['311119', '311111'],
#  'food processing company': ['311999',
#   '311991',
#   '311911',
#   '311919',
#   '311920',
#   '311930',
#   '311941',
#   '311942'],
#  'fence supply store': ['444190', '444110', '444120', '444130'],
#  'food producer': ['311999',
#   '311991',
#   '311911',
#   '311919',
#   '311920',
#   '311930',
#   '311941',
#   '311942'],
#  'forestry service': ['115310'],
#  'foundry': ['331513', '331511', '331512', '331523', '331524', '331529'],
#  'wholesale jeweler': ['423940', '423910', '423920', '423930', '423990'],
#  'cookie shop': ['311821', '311824', '311811', '311812', '311813', '311830'],
#  'truck rental agency': ['532120', '532111', '532112'],
#  'fruit vegetable processing': ['311421',
#   '311422',
#   '311423',
#   '311411',
#   '311412'],
#  'kitchen supply store': ['423440',
#   '423410',
#   '423420',
#   '423430',
#   '423450',
#   '423460',
#   '423490'],
#  'hydraulic equipment supplier': ['423830',
#   '423810',
#   '423820',
#   '423840',
#   '423850',
#   '423860'],
#  'irrigation equipment supplier': ['221310', '221320', '221330'],
#  'bearing supplier': ['332991',
#   '332992',
#   '332993',
#   '332994',
#   '332996',
#   '332999',
#   '332911',
#   '332912',
#   '332913',
#   '332919'],
#  'metallurgy company': ['332117', '332111', '332112', '332114', '332119'],
#  'plastic injection molding service': ['333511',
#   '333514',
#   '333515',
#   '333517',
#   '333519'],
#  'general contractor': ['236220', '236210'],
#  'general hospital': ['622110'],
#  'tool manufacturer': ['333515', '333511', '333514', '333517', '333519'],
#  'industrial design company': ['541420', '541410', '541430', '541490'],
#  'hyundai dealer': ['423110', '423120', '423130', '423140'],
#  'glass industry': ['327215', '327211', '327212', '327213'],
#  'polymer supplier': ['424610', '424690'],
#  'printing equipment supply': ['333244',
#   '333241',
#   '333242',
#   '333243',
#   '333249'],
#  'toner cartridge supplier': ['325910',
#   '325920',
#   '325991',
#   '325992',
#   '325998'],
#  'printer repair service': ['811212', '811211', '811213', '811219'],
#  'fuel supplier': ['424720', '424710'],
#  'glass manufacturer': ['327215', '327211', '327212', '327213'],
#  'plastic bag supplier': ['326111',
#   '326112',
#   '326113',
#   '326121',
#   '326122',
#   '326130',
#   '326140',
#   '326150',
#   '326160',
#   '326191',
#   '326199'],
#  'glassware manufacturer': ['327215', '327211', '327212', '327213'],
#  'polythene plastic sheeting supplier': ['326112',
#   '326111',
#   '326113',
#   '326121',
#   '326122',
#   '326130',
#   '326140',
#   '326150',
#   '326160',
#   '326191',
#   '326199'],
#  'pvc industry': ['326122',
#   '326121',
#   '326111',
#   '326112',
#   '326113',
#   '326130',
#   '326140',
#   '326150',
#   '326160',
#   '326191',
#   '326199'],
#  'countertop store': ['444190', '444110', '444120', '444130'],
#  'cabinet store': ['444190', '444110', '444120', '444130'],
#  'fiberglass supplier': ['327993', '327991', '327992', '327999', '327910'],
#  'golf cart dealer': ['441228', '441222', '441210'],
#  'auto repair shop': ['811111',
#   '811112',
#   '811113',
#   '811118',
#   '811121',
#   '811122',
#   '811191',
#   '811192',
#   '811198'],
#  'hose supplier': ['326220', '326211', '326212', '326291', '326299'],
#  'rubber product supplier': ['326299', '326291', '326211', '326212', '326220'],
#  'automotive': ['423110', '423120', '423130', '423140'],
#  'commercial refrigerator supplier': ['423740', '423710', '423720', '423730'],
#  'golf club': ['713910', '713920', '713930', '713940', '713950', '713990'],
#  'golf course': ['713910', '713920', '713930', '713940', '713950', '713990'],
#  'green energy supplier': ['221114',
#   '221111',
#   '221112',
#   '221113',
#   '221115',
#   '221116',
#   '221117',
#   '221118',
#   '221121',
#   '221122'],
#  'greenhouse': ['111411', '111419', '111421', '111422'],
#  'auto glass shop': ['811122',
#   '811121',
#   '811111',
#   '811112',
#   '811113',
#   '811118',
#   '811191',
#   '811192',
#   '811198'],
#  'lighting manufacturer': ['335122', '335121', '335129', '335110'],
#  'cement manufacturer': ['327310', '327320', '327331', '327332', '327390'],
#  'brick manufacturer': ['327331', '327332', '327310', '327320', '327390'],
#  'natural stone supplier': ['423320', '423310', '423330', '423390'],
#  'gym': ['713940', '713910', '713920', '713930', '713950', '713990'],
#  'marble supplier': ['327991', '327992', '327993', '327999', '327910'],
#  'corporate gift supplier': ['453220', '453210'],
#  'shipbuilding repair company': ['336611', '336612'],
#  'construction maintenance office': ['236220', '236210'],
#  'boiler manufacturer': ['332410', '332420', '332431', '332439'],
#  'container supplier': ['332439', '332431', '332410', '332420'],
#  'home construction': ['236115', '236116', '236117', '236118'],
#  'health': ['621111', '621112'],
#  'heart hospital': ['622310'],
#  'spring supplier': ['332613', '332618'],
#  'electric utility manufacturer': ['926130',
#   '926110',
#   '926120',
#   '926140',
#   '926150'],
#  'aircraft manufacturer': ['336411',
#   '336412',
#   '336413',
#   '336414',
#   '336415',
#   '336419'],
#  'metal heat treating service': ['332811', '332812', '332813'],
#  'plating service': ['332813', '332811', '332812'],
#  'automation company': ['335314', '335311', '335312', '335313'],
#  'heating contractor': ['238220', '238210', '238290'],
#  'plumbing supply store': ['423720', '423710', '423730', '423740'],
#  'gun shop': ['451110', '451120', '451130', '451140'],
#  'ammunition supplier': ['332993',
#   '332991',
#   '332992',
#   '332994',
#   '332996',
#   '332999',
#   '332911',
#   '332912',
#   '332913',
#   '332919'],
#  'pipe manufacturer': ['332996',
#   '332991',
#   '332992',
#   '332993',
#   '332994',
#   '332999',
#   '332911',
#   '332912',
#   '332913',
#   '332919'],
#  'school': ['611110'],
#  'fire protection equipment supplier': ['922160',
#   '922110',
#   '922120',
#   '922130',
#   '922140',
#   '922150',
#   '922190'],
#  'agricultural machinery manufacturer': ['333111',
#   '333112',
#   '333120',
#   '333131',
#   '333132'],
#  'lawn mower store': ['444210', '444220'],
#  'lawn irrigation equipment supplier': ['221310', '221320', '221330'],
#  'financial consultant': ['523930', '523910', '523920', '523991', '523999'],
#  'helicopter charter': ['481211', '481212', '481219'],
#  'packaging machinery': ['333993',
#   '333991',
#   '333992',
#   '333994',
#   '333995',
#   '333996',
#   '333997',
#   '333999',
#   '333912',
#   '333914',
#   '333921',
#   '333922',
#   '333923',
#   '333924'],
#  'historical landmark': ['712120', '712110', '712130', '712190'],
#  'electronics manufacturer': ['334419',
#   '334412',
#   '334413',
#   '334416',
#   '334417',
#   '334418'],
#  'graphic designer': ['541430', '541410', '541420', '541490'],
#  'eye care center': ['621320',
#   '621310',
#   '621330',
#   '621340',
#   '621391',
#   '621399'],
#  'optical product manufacturer': ['333314', '333316', '333318'],
#  'image consultant': ['541430', '541410', '541420', '541490'],
#  'cleaning product supplier': ['423850',
#   '423810',
#   '423820',
#   '423830',
#   '423840',
#   '423860'],
#  'fireplace store': ['423720', '423710', '423730', '423740'],
#  'home builder': ['236115', '236116', '236117', '236118'],
#  'tool die shop': ['333514', '333511', '333515', '333517', '333519'],
#  'metal stamping service': ['332119', '332111', '332112', '332114', '332117'],
#  'environmental organization': ['813312', '813311', '813319'],
#  'food processing equipment': ['333241',
#   '333242',
#   '333243',
#   '333244',
#   '333249'],
#  'loan agency': ['522310', '522320', '522390'],
#  'power plant equipment supplier': ['423610', '423620', '423690'],
#  'home good store': ['442299', '442291', '442210'],
#  'engine rebuilding service': ['811198',
#   '811191',
#   '811192',
#   '811111',
#   '811112',
#   '811113',
#   '811118',
#   '811121',
#   '811122'],
#  'air compressor supplier': ['333912',
#   '333914',
#   '333921',
#   '333922',
#   '333923',
#   '333924',
#   '333991',
#   '333992',
#   '333993',
#   '333994',
#   '333995',
#   '333996',
#   '333997',
#   '333999'],
#  'honda dealer': ['441110', '441120'],
#  'elevator manufacturer': ['333921',
#   '333922',
#   '333923',
#   '333924',
#   '333912',
#   '333914',
#   '333991',
#   '333992',
#   '333993',
#   '333994',
#   '333995',
#   '333996',
#   '333997',
#   '333999'],
#  'crane dealer': ['333923',
#   '333921',
#   '333922',
#   '333924',
#   '333912',
#   '333914',
#   '333991',
#   '333992',
#   '333993',
#   '333994',
#   '333995',
#   '333996',
#   '333997',
#   '333999'],
#  'crane rental agency': ['532412', '532411', '532420', '532490'],
#  'compound building': ['238190',
#   '238110',
#   '238120',
#   '238130',
#   '238140',
#   '238150',
#   '238160',
#   '238170'],
#  'tractor dealer': ['423820',
#   '423810',
#   '423830',
#   '423840',
#   '423850',
#   '423860'],
#  'furnace part supplier': ['423730', '423710', '423720', '423740'],
#  'heating equipment supplier': ['423720', '423710', '423730', '423740'],
#  'pneumatic tool supplier': ['423730', '423710', '423720', '423740'],
#  'truck stop': ['447110', '447190'],
#  'computer hardware manufacturer': ['334111', '334112', '334118'],
#  'satellite communication service': ['517410'],
#  'hospital': ['622110'],
#  'electronics company': ['443142', '443141'],
#  'electronic part supplier': ['423690', '423610', '423620'],
#  'hvac contractor': ['238220', '238210', '238290'],
#  'industrial engineer': ['541330',
#   '541310',
#   '541320',
#   '541340',
#   '541350',
#   '541360',
#   '541370',
#   '541380'],
#  'contact lens supplier': ['333314', '333316', '333318'],
#  'information service': ['519190', '519110', '519120', '519130'],
#  'building': ['236220', '236210'],
#  'water work equipment supplier': ['423720', '423710', '423730', '423740'],
#  'measuring instrument supplier': ['334513',
#   '334510',
#   '334511',
#   '334512',
#   '334514',
#   '334515',
#   '334516',
#   '334517',
#   '334519'],
#  'scientific equipment supplier': ['423490',
#   '423410',
#   '423420',
#   '423430',
#   '423440',
#   '423450',
#   '423460'],
#  'medical center': ['622110'],
#  'watch manufacturer': ['423940', '423910', '423920', '423930', '423990'],
#  'corporate entertainment service': ['711510'],
#  'insurance': ['524210', '524291', '524292', '524298'],
#  'record company': ['512250', '512230', '512240', '512290'],
#  'video duplication service': ['512191',
#   '512199',
#   '512110',
#   '512120',
#   '512131',
#   '512132'],
#  'insurance agency': ['524210', '524291', '524292', '524298'],
#  'lighting store': ['335122', '335121', '335129', '335110'],
#  'lighting wholesaler': ['335122', '335121', '335129', '335110'],
#  'entertainment agency': ['711410'],
#  'insurance broker': ['524210', '524291', '524292', '524298'],
#  'electrical equipment supplier': ['423610', '423620', '423690'],
#  'electric motor store': ['336320',
#   '336310',
#   '336330',
#   '336340',
#   '336350',
#   '336360',
#   '336370',
#   '336390'],
#  'railroad company': ['482111', '482112'],
#  'electrical supply store': ['423610', '423620', '423690'],
#  'insurance company': ['524210', '524291', '524292', '524298'],
#  'factory equipment supplier': ['423830',
#   '423810',
#   '423820',
#   '423840',
#   '423850',
#   '423860'],
#  'investment service': ['523999', '523991', '523910', '523920', '523930'],
#  'laser equipment supplier': ['334510',
#   '334511',
#   '334512',
#   '334513',
#   '334514',
#   '334515',
#   '334516',
#   '334517',
#   '334519'],
#  'executive suite rental agency': ['921110',
#   '921120',
#   '921130',
#   '921140',
#   '921150',
#   '921190'],
#  'truck dealer': ['423110', '423120', '423130', '423140'],
#  'motor vehicle dealer': ['441120', '441110'],
#  'car dealer': ['441120', '441110'],
#  'truck topper supplier': ['423860',
#   '423810',
#   '423820',
#   '423830',
#   '423840',
#   '423850'],
#  'police supply store': ['453998', '453991', '453910', '453920', '453930'],
#  'iron steel contractor': ['238120',
#   '238110',
#   '238130',
#   '238140',
#   '238150',
#   '238160',
#   '238170',
#   '238190'],
#  'fire department equipment supplier': ['922160',
#   '922110',
#   '922120',
#   '922130',
#   '922140',
#   '922150',
#   '922190'],
#  'towing equipment provider': ['488410', '488490'],
#  'logistics service': ['541614',
#   '541611',
#   '541612',
#   '541613',
#   '541618',
#   '541620',
#   '541690'],
#  'trailer manufacturer': ['336214', '336211', '336212', '336213'],
#  'trailer dealer': ['532120', '532111', '532112'],
#  'dealer': ['441210', '441222', '441228'],
#  'auto spring shop': ['811198',
#   '811191',
#   '811192',
#   '811111',
#   '811112',
#   '811113',
#   '811118',
#   '811121',
#   '811122'],
#  'auto upholsterer': ['336360',
#   '336310',
#   '336320',
#   '336330',
#   '336340',
#   '336350',
#   '336370',
#   '336390'],
#  'auto body part supplier': ['441310', '441320'],
#  'car factory': ['336111', '336112', '336120'],
#  'freight forwarding service': ['488510'],
#  'brake shop': ['811118',
#   '811111',
#   '811112',
#   '811113',
#   '811121',
#   '811122',
#   '811191',
#   '811192',
#   '811198'],
#  'railroad equipment supplier': ['423860',
#   '423810',
#   '423820',
#   '423830',
#   '423840',
#   '423850'],
#  'jewelry equipment supplier': ['339910',
#   '339920',
#   '339930',
#   '339940',
#   '339950',
#   '339991',
#   '339992',
#   '339993',
#   '339994',
#   '339995',
#   '339999'],
#  'boat builder': ['336612', '336611'],
#  'ship building': ['336611', '336612'],
#  'marine supply store': ['441222', '441228', '441210'],
#  'boat dealer': ['441222', '441228', '441210'],
#  'kawasaki motorcycle dealer': ['441228', '441222', '441210'],
#  'knife manufacturing': ['332215', '332216'],
#  'labor union': ['813930', '813910', '813920', '813940', '813990'],
#  'furniture maker': ['337122',
#   '337121',
#   '337124',
#   '337125',
#   '337127',
#   '337110'],
#  'banking finance': ['522110', '522120', '522130', '522190'],
#  'furniture manufacturer': ['337125',
#   '337121',
#   '337122',
#   '337124',
#   '337127',
#   '337110'],
#  'logistics': ['541614',
#   '541611',
#   '541612',
#   '541613',
#   '541618',
#   '541620',
#   '541690'],
#  'massage supply store': ['423850',
#   '423810',
#   '423820',
#   '423830',
#   '423840',
#   '423860'],
#  'telecommunication equipment supplier': ['334290', '334210', '334220'],
#  'baby store': ['448130', '448110', '448120', '448140', '448150', '448190'],
#  'molding supplier': ['333511', '333514', '333515', '333517', '333519'],
#  'office equipment supplier': ['423420',
#   '423410',
#   '423430',
#   '423440',
#   '423450',
#   '423460',
#   '423490'],
#  'office furniture store': ['337214', '337211', '337212', '337215'],
#  'store equipment supplier': ['423850',
#   '423810',
#   '423820',
#   '423830',
#   '423840',
#   '423860'],
#  'laboratory': ['541380',
#   '541310',
#   '541320',
#   '541330',
#   '541340',
#   '541350',
#   '541360',
#   '541370'],
#  'health beauty shop': ['812112', '812111', '812113', '812191', '812199'],
#  'learning center': ['611691',
#   '611692',
#   '611699',
#   '611610',
#   '611620',
#   '611630'],
#  'dental laboratory': ['339116', '339112', '339113', '339114', '339115'],
#  'land surveyor': ['541370',
#   '541310',
#   '541320',
#   '541330',
#   '541340',
#   '541350',
#   '541360',
#   '541380'],
#  'educational supply store': ['453210', '453220'],
#  'jewelry store': ['448310', '448320'],
#  'playground equipment supplier': ['423910',
#   '423920',
#   '423930',
#   '423940',
#   '423990'],
#  'outdoor sport store': ['451110', '451120', '451130', '451140'],
#  'toy store': ['451120', '451110', '451130', '451140'],
#  'security service': ['561612', '561611', '561613', '561621', '561622'],
#  'sign shop': ['339950',
#   '339910',
#   '339920',
#   '339930',
#   '339940',
#   '339991',
#   '339992',
#   '339993',
#   '339994',
#   '339995',
#   '339999'],
#  'office supply store': ['453210', '453220'],
#  'landscaper': ['561730', '561710', '561720', '561740', '561790'],
#  'gasket manufacturer': ['339991',
#   '339992',
#   '339993',
#   '339994',
#   '339995',
#   '339999',
#   '339910',
#   '339920',
#   '339930',
#   '339940',
#   '339950'],
#  'piano maker': ['339992',
#   '339991',
#   '339993',
#   '339994',
#   '339995',
#   '339999',
#   '339910',
#   '339920',
#   '339930',
#   '339940',
#   '339950'],
#  'piano store': ['451140', '451110', '451120', '451130'],
#  'funeral home': ['812210', '812220'],
#  'monument': ['712120', '712110', '712130', '712190'],
#  'book publisher': ['511130',
#   '511110',
#   '511120',
#   '511140',
#   '511191',
#   '511199'],
#  'wig shop': ['448150', '448110', '448120', '448130', '448140', '448190'],
#  'laundromat': ['812310', '812320', '812331', '812332'],
#  'auto wrecker': ['488410', '488490'],
#  'auto part market': ['441310', '441320'],
#  'jeep dealer': ['441110', '441120'],
#  'restaurant supply store': ['423850',
#   '423810',
#   '423820',
#   '423830',
#   '423840',
#   '423860'],
#  'roofing supply store': ['423330', '423310', '423320', '423390'],
#  'law firm': ['541110', '541120', '541191', '541199'],
#  'building material market': ['444190', '444110', '444120', '444130'],
#  'camera store': ['423410',
#   '423420',
#   '423430',
#   '423440',
#   '423450',
#   '423460',
#   '423490'],
#  'lawn care service': ['561730', '561710', '561720', '561740', '561790'],
#  'computer security service': ['561621',
#   '561622',
#   '561611',
#   '561612',
#   '561613'],
#  'computer store': ['423430',
#   '423410',
#   '423420',
#   '423440',
#   '423450',
#   '423460',
#   '423490'],
#  'design agency': ['541490', '541410', '541420', '541430'],
#  'diagnostic center': ['621512', '621511'],
#  'laboratory equipment supplier': ['334516',
#   '334510',
#   '334511',
#   '334512',
#   '334513',
#   '334514',
#   '334515',
#   '334517',
#   '334519'],
#  'home theater store': ['334310'],
#  'metal industry supplier': ['423510', '423520'],
#  'landscaping supply store': ['444220', '444210'],
#  'appliance part supplier': ['423620', '423610', '423690'],
#  'vacuum cleaner store': ['443141', '443142'],
#  'audio visual equipment supplier': ['334310'],
#  'lawyer': ['541110', '541120', '541191', '541199'],
#  'cell phone store': ['517312', '517311'],
#  'bathroom supply store': ['423720', '423710', '423730', '423740'],
#  'leasing service': ['532490', '532411', '532412', '532420'],
#  'construction machine dealer': ['423810',
#   '423820',
#   '423830',
#   '423840',
#   '423850',
#   '423860'],
#  'dairy farm equipment supplier': ['423820',
#   '423810',
#   '423830',
#   '423840',
#   '423850',
#   '423860'],
#  'propane supplier': ['454310', '454390'],
#  'legal service': ['541199', '541191', '541110', '541120'],
#  'janitorial equipment supplier': ['561720',
#   '561710',
#   '561730',
#   '561740',
#   '561790'],
#  'life insurance agency': ['524210', '524291', '524292', '524298'],
#  'railroad contractor': ['488210'],
#  'swimming pool supply store': ['453998',
#   '453991',
#   '453910',
#   '453920',
#   '453930'],
#  'light bulb supplier': ['335110', '335121', '335122', '335129'],
#  'linen store': ['812331', '812332', '812310', '812320'],
#  'metal construction company': ['332311',
#   '332312',
#   '332313',
#   '332321',
#   '332322',
#   '332323'],
#  'local government office': ['921190',
#   '921110',
#   '921120',
#   '921130',
#   '921140',
#   '921150'],
#  'logging contractor': ['113310'],
#  'machine shop': ['332710', '332721', '332722'],
#  'hotel supply store': ['721110', '721120', '721191', '721199'],
#  'import export company': ['522293',
#   '522291',
#   '522292',
#   '522294',
#   '522298',
#   '522210',
# ...
#   '512120',
#   '512131',
#   '512132',
#   '512191',
#   '512199'],
#  'movie theater': ['512131', '512132', '512110', '512120', '512191', '512199'],
#  'theater company': ['711110', '711120', '711130', '711190'],
#  'performing art theater': ['711190', '711110', '711120', '711130'],
#  'occupational safety health': ['813410'],
#  'office space rental agency': ['531120', '531110', '531130', '531190'],
#  'commercial real estate agency': ['531210'],
#  'art school': ['611610', '611620', '611630', '611691', '611692', '611699'],
#  'music publisher': ['512230', '512240', '512250', '512290'],
#  'printed music publisher': ['512230', '512240', '512250', '512290'],
#  'home audio store': ['334310'],
#  'musician': ['711130', '711110', '711120', '711190'],
#  'music management promotion': ['711410'],
#  'video editing service': ['512191',
#   '512199',
#   '512110',
#   '512120',
#   '512131',
#   '512132'],
#  'office supply wholesaler': ['424120', '424110', '424130'],
#  'official residence': ['531110', '531120', '531130', '531190'],
#  'orthopedic clinic': ['621111', '621112'],
#  'painter': ['238320', '238310', '238330', '238340', '238350', '238390'],
#  'painting': ['238320', '238310', '238330', '238340', '238350', '238390'],
#  'telephone company': ['517311', '517312'],
#  'medium house': ['541840',
#   '541810',
#   '541820',
#   '541830',
#   '541850',
#   '541860',
#   '541870',
#   '541890'],
#  'paper distributor': ['424130', '424110', '424120'],
#  'news service': ['451212', '451211'],
#  'public library': ['519120', '519110', '519130', '519190'],
#  'law library': ['519120', '519110', '519130', '519190'],
#  'museum': ['712110', '712120', '712130', '712190'],
#  'federal reserve bank': ['521110'],
#  'credit union': ['522130', '522110', '522120', '522190'],
#  'atm': ['522320', '522310', '522390'],
#  'paving contractor': ['238990', '238910'],
#  'mortgage lender': ['522310', '522320', '522390'],
#  'investment bank': ['523110', '523120', '523130', '523140'],
#  'check cashing service': ['522390', '522310', '522320'],
#  'stock broker': ['523120', '523110', '523130', '523140'],
#  'health consultant': ['541611',
#   '541612',
#   '541613',
#   '541614',
#   '541618',
#   '541620',
#   '541690'],
#  'health insurance agency': ['524114',
#   '524113',
#   '524126',
#   '524127',
#   '524128',
#   '524130'],
#  'payroll service': ['541214', '541211', '541213', '541219'],
#  'pediatrician': ['621111', '621112'],
#  'human resource consulting': ['541612',
#   '541611',
#   '541613',
#   '541614',
#   '541618',
#   '541620',
#   '541690'],
#  'pest control service': ['561710', '561720', '561730', '561740', '561790'],
#  'pet boarding service': ['812910', '812921', '812922', '812930', '812990'],
#  'pet care': ['812910', '812921', '812922', '812930', '812990'],
#  'loss adjuster': ['524291', '524292', '524298', '524210'],
#  'pharmaceutical company': ['325412', '325411', '325413', '325414'],
#  'pharmaceutical product wholesaler': ['424210'],
#  'pharmacy': ['446110', '446120', '446130', '446191', '446199'],
#  'educational institution': ['611310'],
#  'retirement community': ['623311', '623312'],
#  'fraternal organization': ['813410'],
#  'photo lab': ['541921', '541922', '541910', '541930', '541940', '541990'],
#  'property investment': ['531390', '531311', '531312', '531320'],
#  'photographer': ['541921', '541922', '541910', '541930', '541940', '541990'],
#  'photography school': ['541921',
#   '541922',
#   '541910',
#   '541930',
#   '541940',
#   '541990'],
#  'star hotel': ['721110', '721120', '721191', '721199'],
#  'convention center': ['561591', '561599', '561510', '561520'],
#  'real estate appraiser': ['531320', '531311', '531312', '531390'],
#  'photography service': ['541921',
#   '541922',
#   '541910',
#   '541930',
#   '541940',
#   '541990'],
#  'resort hotel': ['721110', '721120', '721191', '721199'],
#  'real estate consultant': ['531210'],
#  'car rental agency': ['532111', '532112', '532120'],
#  'car leasing service': ['532112', '532111', '532120'],
#  'ford dealer': ['441110', '441120'],
#  'car finance loan company': ['522220',
#   '522210',
#   '522291',
#   '522292',
#   '522293',
#   '522294',
#   '522298'],
#  'trailer rental service': ['532120', '532111', '532112'],
#  'furniture rental service': ['532289',
#   '532281',
#   '532282',
#   '532283',
#   '532284',
#   '532210'],
#  'tuxedo shop': ['532281', '532282', '532283', '532284', '532289', '532210'],
#  'dress tuxedo rental service': ['532281',
#   '532282',
#   '532283',
#   '532284',
#   '532289',
#   '532210'],
#  'wedding store': ['448190', '448110', '448120', '448130', '448140', '448150'],
#  'video store': ['443142', '443141'],
#  'movie rental': ['512199', '512191', '512110', '512120', '512131', '512132'],
#  'photography studio': ['541921',
#   '541922',
#   '541910',
#   '541930',
#   '541940',
#   '541990'],
#  'home health care service': ['621610'],
#  'skateboard shop': ['339920',
#   '339910',
#   '339930',
#   '339940',
#   '339950',
#   '339991',
#   '339992',
#   '339993',
#   '339994',
#   '339995',
#   '339999'],
#  'event technology service': ['561920', '561910', '561990'],
#  'party equipment rental service': ['532289',
#   '532281',
#   '532282',
#   '532283',
#   '532284',
#   '532210'],
#  'construction machine rental service': ['532412',
#   '532411',
#   '532420',
#   '532490'],
#  'audio visual equipment rental service': ['334310'],
#  'shipping equipment industry': ['423860',
#   '423810',
#   '423820',
#   '423830',
#   '423840',
#   '423850'],
#  'physical therapy clinic': ['621340',
#   '621310',
#   '621320',
#   '621330',
#   '621391',
#   '621399'],
#  'plastic fabrication company': ['326199',
#   '326191',
#   '326111',
#   '326112',
#   '326113',
#   '326121',
#   '326122',
#   '326130',
#   '326140',
#   '326150',
#   '326160'],
#  'plastic product supplier': ['326199',
#   '326191',
#   '326111',
#   '326112',
#   '326113',
#   '326121',
#   '326122',
#   '326130',
#   '326140',
#   '326150',
#   '326160'],
#  'auto tag agency': ['926120', '926110', '926130', '926140', '926150'],
#  'department motor vehicle': ['926120',
#   '926110',
#   '926130',
#   '926140',
#   '926150'],
#  'notary public': ['541120', '541110', '541191', '541199'],
#  'private investigator': ['561611', '561612', '561613', '561621', '561622'],
#  'escrow service': ['523991', '523999', '523910', '523920', '523930'],
#  'real estate agent': ['531210'],
#  'playground': ['713990', '713910', '713920', '713930', '713940', '713950'],
#  'plumber': ['238220', '238210', '238290'],
#  'port authority': ['488310', '488320', '488330', '488390'],
#  'portrait studio': ['541921',
#   '541922',
#   '541910',
#   '541930',
#   '541940',
#   '541990'],
#  'post office': ['491110'],
#  'professional service': ['541990',
#   '541910',
#   '541921',
#   '541922',
#   '541930',
#   '541940'],
#  'university hospital': ['622110'],
#  'public relation firm': ['541820',
#   '541810',
#   '541830',
#   '541840',
#   '541850',
#   '541860',
#   '541870',
#   '541890'],
#  'civil engineering company': ['237990'],
#  'drafting service': ['541340',
#   '541310',
#   '541320',
#   '541330',
#   '541350',
#   '541360',
#   '541370',
#   '541380'],
#  'pump supplier': ['333996',
#   '333991',
#   '333992',
#   '333993',
#   '333994',
#   '333995',
#   '333997',
#   '333999',
#   '333912',
#   '333914',
#   '333921',
#   '333922',
#   '333923',
#   '333924'],
#  'interior construction contractor': ['236220', '236210'],
#  'carpet cleaning service': ['561740', '561710', '561720', '561730', '561790'],
#  'exhibition planner': ['561920', '561910', '561990'],
#  'decal supplier': ['339950',
#   '339910',
#   '339920',
#   '339930',
#   '339940',
#   '339991',
#   '339992',
#   '339993',
#   '339994',
#   '339995',
#   '339999'],
#  'stage lighting equipment supplier': ['335129', '335121', '335122', '335110'],
#  'event management company': ['561920', '561910', '561990'],
#  'radio broadcaster': ['333996',
#   '333991',
#   '333992',
#   '333993',
#   '333994',
#   '333995',
#   '333997',
#   '333999',
#   '333912',
#   '333914',
#   '333921',
#   '333922',
#   '333923',
#   '333924'],
#  'computer support service': ['541519', '541511', '541512', '541513'],
#  'ravine': ['712190', '712110', '712120', '712130'],
#  'employment center': ['561311', '561312', '561320', '561330'],
#  'national health foundation': ['813212', '813211', '813219'],
#  'real estate developer': ['236117', '236115', '236116', '236118'],
#  'advertising agency': ['541810',
#   '541820',
#   '541830',
#   '541840',
#   '541850',
#   '541860',
#   '541870',
#   '541890'],
#  'promotional product supplier': ['541870',
#   '541810',
#   '541820',
#   '541830',
#   '541840',
#   '541850',
#   '541860',
#   '541890'],
#  'advertising service': ['541810',
#   '541820',
#   '541830',
#   '541840',
#   '541850',
#   '541860',
#   '541870',
#   '541890'],
#  'record storage facility': ['531130', '531110', '531120', '531190'],
#  'fund management company': ['523920', '523910', '523930', '523991', '523999'],
#  'recreation center': ['713940',
#   '713910',
#   '713920',
#   '713930',
#   '713950',
#   '713990'],
#  'bakery': ['311811', '311812', '311813', '311821', '311824', '311830'],
#  'database management company': ['518210'],
#  'market researcher': ['541910',
#   '541921',
#   '541922',
#   '541930',
#   '541940',
#   '541990'],
#  'recycling center': ['423930', '423910', '423920', '423940', '423990'],
#  'regional government office': ['921190',
#   '921110',
#   '921120',
#   '921130',
#   '921140',
#   '921150'],
#  'rehabilitation center': ['623220', '623210'],
#  'religious institution': ['813110'],
#  'religious organization': ['813110'],
#  'repair service': ['811490', '811411', '811412', '811420', '811430'],
#  'emergency veterinarian service': ['541940',
#   '541910',
#   '541921',
#   '541922',
#   '541930',
#   '541990'],
#  'pet sitter': ['812910', '812921', '812922', '812930', '812990'],
#  'research product development': ['541715', '541713', '541714', '541720'],
#  'building society': ['236220', '236210'],
#  'valet parking service': ['812930', '812910', '812921', '812922', '812990'],
#  'nursing agency': ['623110'],
#  'executive search firm': ['561312', '561311', '561320', '561330'],
#  'recruiter': ['561311', '561312', '561320', '561330'],
#  'temp agency': ['561311', '561312', '561320', '561330'],
#  'health center': ['622110'],
#  'restaurant': ['722511', '722513', '722514', '722515'],
#  'roofing contractor': ['238160',
#   '238110',
#   '238120',
#   '238130',
#   '238140',
#   '238150',
#   '238170',
#   '238190'],
#  'sport nutrition store': ['446191', '446199', '446110', '446120', '446130'],
#  'credit reporting agency': ['561450',
#   '561410',
#   '561421',
#   '561422',
#   '561431',
#   '561439',
#   '561440',
#   '561491',
#   '561492',
#   '561499'],
#  'automobile storage facility': ['493190', '493110', '493120', '493130'],
#  'debt collection agency': ['561440',
#   '561410',
#   '561421',
#   '561422',
#   '561431',
#   '561439',
#   '561450',
#   '561491',
#   '561492',
#   '561499'],
#  'park': ['812930', '812910', '812921', '812922', '812990'],
#  'court reporter': ['561492',
#   '561491',
#   '561499',
#   '561410',
#   '561421',
#   '561422',
#   '561431',
#   '561439',
#   '561440',
#   '561450'],
#  'bus tour agency': ['561520', '561510', '561591', '561599'],
#  'tour operator': ['561520', '561510', '561591', '561599'],
#  'convention information bureau': ['561591', '561599', '561510', '561520'],
#  'balloon ride tour agency': ['487990'],
#  'security guard service': ['561612', '561611', '561613', '561621', '561622'],
#  'locksmith': ['561622', '561621', '561611', '561612', '561613'],
#  'commercial cleaning service': ['561720',
#   '561710',
#   '561730',
#   '561740',
#   '561790'],
#  'blast cleaning service': ['561720', '561710', '561730', '561740', '561790'],
#  'conference center': ['561920', '561910', '561990'],
#  'safety equipment supplier': ['423490',
#   '423410',
#   '423420',
#   '423430',
#   '423440',
#   '423450',
#   '423460'],
#  'garbage dump': ['562212', '562211', '562213', '562219'],
#  'sanitation service': ['561720', '561710', '561730', '561740', '561790'],
#  'garbage dump service': ['562111', '562112', '562119'],
#  'environmental health service': ['541620',
#   '541611',
#   '541612',
#   '541613',
#   '541614',
#   '541618',
#   '541690'],
#  'portable toilet supplier': ['562991', '562998', '562910', '562920'],
#  'public work department': ['921190',
#   '921110',
#   '921120',
#   '921130',
#   '921140',
#   '921150'],
#  'school district office': ['611110'],
#  'sailmaker': ['313210', '313220', '313230', '313240'],
#  'community college': ['611210'],
#  'salvage yard': ['423140', '423110', '423120', '423130'],
#  'business school': ['611410', '611420', '611430'],
#  'trade school': ['611519', '611511', '611512', '611513'],
#  'private university': ['611310'],
#  'computer training school': ['611420', '611410', '611430'],
#  'school supply store': ['424120', '424110', '424130'],
#  'screen printer': ['323113', '323111', '323117', '323120'],
#  'medium consultant': ['541840',
#   '541810',
#   '541820',
#   '541830',
#   '541850',
#   '541860',
#   '541870',
#   '541890'],
#  'beauty school': ['611511', '611512', '611513', '611519'],
#  'flight school': ['611512', '611511', '611513', '611519'],
#  'seaport': ['488310', '488320', '488330', '488390'],
#  'security system supplier': ['561621',
#   '561622',
#   '561611',
#   '561612',
#   '561613'],
#  'middle school': ['611110'],
#  'nonprofit': ['813410'],
#  'shooting range': ['713990',
#   '713910',
#   '713920',
#   '713930',
#   '713940',
#   '713950'],
#  'soccer club': ['711211', '711212', '711219'],
#  'camp': ['721214', '721211'],
#  'diving contractor': ['561990', '561910', '561920'],
#  'language school': ['611630',
#   '611610',
#   '611620',
#   '611691',
#   '611692',
#   '611699'],
#  'english language school': ['611630',
#   '611610',
#   '611620',
#   '611691',
#   '611692',
#   '611699'],
#  'preschool': ['624410'],
#  'self storage facility': ['531130', '531110', '531120', '531190'],
#  'semi conductor supplier': ['334413',
#   '334412',
#   '334416',
#   '334417',
#   '334418',
#   '334419'],
#  'driving school': ['611692',
#   '611691',
#   '611699',
#   '611610',
#   '611620',
#   '611630'],
#  'trucking school': ['611692',
#   '611691',
#   '611699',
#   '611610',
#   '611620',
#   '611630'],
#  'senior citizen center': ['624120', '624110', '624190'],
#  'service': ['541519', '541511', '541512', '541513'],
#  'childrens hospital': ['622110'],
#  'dental supply store': ['339114', '339112', '339113', '339115', '339116'],
#  'shipyard': ['336611', '336612'],
#  'orthodox synagogue': ['813110'],
#  'short term apartment rental agency': ['531110',
#   '531120',
#   '531130',
#   '531190'],
#  'nutritionist': ['621399', '621391', '621310', '621320', '621330', '621340'],
#  'ophthalmologist': ['621320',
#   '621310',
#   '621330',
#   '621340',
#   '621391',
#   '621399'],
#  'ophthalmology clinic': ['621320',
#   '621310',
#   '621330',
#   '621340',
#   '621391',
#   '621399'],
#  'social service organization': ['624190', '624110', '624120'],
#  'social welfare center': ['624190', '624110', '624120'],
#  'solar energy company': ['221114',
#   '221111',
#   '221112',
#   '221113',
#   '221115',
#   '221116',
#   '221117',
#   '221118',
#   '221121',
#   '221122'],
#  'solar energy equipment supplier': ['221114',
#   '221111',
#   '221112',
#   '221113',
#   '221115',
#   '221116',
#   '221117',
#   '221118',
#   '221121',
#   '221122'],
#  'special education school': ['611110'],
#  'podiatrist': ['621391', '621399', '621310', '621320', '621330', '621340'],
#  'reproductive health clinic': ['621410',
#   '621420',
#   '621491',
#   '621492',
#   '621493',
#   '621498'],
#  'sporting good store': ['451110', '451120', '451130', '451140'],
#  'dialysis center': ['621492',
#   '621491',
#   '621493',
#   '621498',
#   '621410',
#   '621420'],
#  'sport complex': ['713940', '713910', '713920', '713930', '713950', '713990'],
#  'wellness program': ['525120', '525110', '525190'],
#  'sportswear store': ['451110', '451120', '451130', '451140'],
#  'private hospital': ['622110'],
#  'radiologist': ['621512', '621511'],
#  'medical diagnostic imaging center': ['621512', '621511'],
#  'ray lab': ['621512', '621511'],
#  'blood bank': ['621991', '621999', '621910'],
#  'stainless steel plant': ['331110'],
#  'state agency': ['921190', '921110', '921120', '921130', '921140', '921150'],
#  'heliport': ['488119', '488111', '488190'],
#  'health care company': ['622110'],
#  'psychiatric hospital': ['622210'],
#  'state government office': ['921190',
#   '921110',
#   '921120',
#   '921130',
#   '921140',
#   '921150'],
#  'medical institution': ['622110'],
#  'steel construction company': ['238120',
#   '238110',
#   '238130',
#   '238140',
#   '238150',
#   '238160',
#   '238170',
#   '238190'],
#  'cleaning service': ['561720', '561710', '561730', '561740', '561790'],
#  ...}

# %%
calc_pre_rec_at_n(ret_docs_dic, queries_dic, n=-1)[0]
# Out:
# {'home improvement store': 0.1,
#  'diesel fuel supplier': 0.0,
#  'church': 0.1,
#  'farm': 0.6,
#  'seed supplier': 0.0,
#  'accountant': 0.4,
#  'trucking company': 0.3,
#  'exporter': 0.1,
#  'grain elevator': 0.1,
#  'popcorn store': 0.2,
#  'agricultural service': 0.0,
#  'warehouse': 0.4,
#  'agricultural production': 0.1,
#  'ranch': 0.2,
#  'holding company': 0.3,
#  'farm equipment supplier': 0.0,
#  'store': 0.0,
#  'grocery store': 0.2,
#  'rice mill': 0.2,
#  'food product supplier': 0.0,
#  'accounting firm': 0.4,
#  'produce market': 0.3,
#  'pet supply store': 0.5,
#  'wholesaler': 0.0,
#  'produce wholesaler': 0.0,
#  'distribution service': 0.0,
#  'crop grower': 0.6,
#  'addiction treatment center': 0.0,
#  'natural good store': 0.0,
#  'orchard': 0.2,
#  'lumber store': 0.0,
#  'mine': 0.5,
#  'transportation service': 0.2,
#  'investment company': 0.0,
#  'fruit wholesaler': 0.2,
#  'real estate agency': 0.1,
#  'event venue': 0.0,
#  'frozen dessert supplier': 0.3,
#  'wine wholesaler importer': 0.2,
#  'winery': 0.6,
#  'aerospace company': 0.6,
#  'cold storage facility': 0.4,
#  'employment agency': 0.4,
#  'plant nursery': 0.1,
#  'air conditioning contractor': 0.2,
#  'air conditioning repair service': 0.0,
#  'fruit vegetable wholesaler': 0.1,
#  'aircraft rental service': 0.0,
#  'monastery': 0.1,
#  'allergist': 0.1,
#  'herb shop': 0.0,
#  'aluminum supplier': 0.4,
#  'ambulance service': 0.1,
#  'wholesale plant nursery': 0.5,
#  'amusement machine supplier': 0.2,
#  'animal hospital': 0.0,
#  'farmer market': 0.3,
#  'vaporizer store': 0.5,
#  'cigar shop': 0.1,
#  'tobacco shop': 0.0,
#  'well drilling contractor': 0.1,
#  'library': 0.4,
#  'apartment building': 0.0,
#  'apartment rental agency': 0.0,
#  'dairy farm': 0.1,
#  'architect': 0.2,
#  'organic farm': 0.0,
#  'architectural designer': 0.4,
#  'architecture firm': 0.0,
#  'livestock producer': 0.0,
#  'dairy supplier': 0.0,
#  'biotechnology company': 0.2,
#  'artist': 0.1,
#  'egg supplier': 0.5,
#  'poultry farm': 0.1,
#  'chicken hatchery': 0.4,
#  'art organization': 0.4,
#  'association organization': 0.5,
#  'food store': 0.2,
#  'deli': 0.0,
#  'bank': 0.3,
#  'fish processing': 0.1,
#  'fish farm': 0.1,
#  'seafood wholesaler': 0.4,
#  'tropical fish store': 0.5,
#  'non profit organization': 0.0,
#  'economic development agency': 0.3,
#  'seafood market': 0.2,
#  'honey farm': 0.2,
#  'horse breeder': 0.2,
#  'asphalt contractor': 0.2,
#  'livestock dealer': 0.0,
#  'department store': 0.1,
#  'mill': 0.0,
#  'atv dealer': 0.3,
#  'audio visual consultant': 0.1,
#  'pallet supplier': 0.4,
#  'wood supplier': 0.0,
#  'hardware store': 0.1,
#  'furniture wholesaler': 0.1,
#  'auditor': 0.1,
#  'oil natural gas company': 0.3,
#  'auto body shop': 0.3,
#  'boat repair shop': 0.1,
#  'association': 0.3,
#  'railing contractor': 0.0,
#  'publisher': 0.6,
#  'pond supply store': 0.0,
#  'agriculture cooperative': 0.0,
#  'printing equipment supplier': 0.1,
#  'auto insurance agency': 0.4,
#  'alternative fuel station': 0.2,
#  'auto part manufacturer': 0.0,
#  'foundation': 0.3,
#  'fertilizer supplier': 0.4,
#  'farming company': 0.0,
#  'finance broker': 0.1,
#  'agricultural cooperative': 0.0,
#  'fire station': 0.1,
#  'environmental consultant': 0.3,
#  'civil engineer': 0.1,
#  'fire protection service': 0.1,
#  'gas company': 0.1,
#  'oilfield': 0.0,
#  'banquet hall': 0.1,
#  'mining company': 0.2,
#  'coalfield': 0.0,
#  'steel fabricator': 0.0,
#  'quarry': 0.0,
#  'gold mining company': 0.4,
#  'high rise building': 0.2,
#  'basketball club': 0.1,
#  'gold dealer': 0.0,
#  'battery manufacturer': 0.4,
#  'electric utility company': 0.0,
#  'environmental program': 0.0,
#  'office': 0.0,
#  'stone supplier': 0.1,
#  'aggregate supplier': 0.0,
#  'sand gravel supplier': 0.2,
#  'building material supplier': 0.4,
#  'beauty supply store': 0.3,
#  'crushed stone supplier': 0.1,
#  'rock shop': 0.0,
#  'road construction company': 0.1,
#  'marketing consultant': 0.3,
#  'blood testing service': 0.5,
#  'contractor': 0.2,
#  'excavating contractor': 0.2,
#  'asphalt mixing plant': 0.2,
#  'ready mix concrete supplier': 0.4,
#  'sand plant': 0.2,
#  'bmw dealer': 0.2,
#  'bookbinder': 0.0,
#  'garden center': 0.2,
#  'abrasive supplier': 0.5,
#  'granite supplier': 0.1,
#  'drilling contractor': 0.0,
#  'bpo company': 0.2,
#  'oil gas exploration service': 0.5,
#  'building complex': 0.0,
#  'construction equipment supplier': 0.0,
#  'mining equipment': 0.0,
#  'bus ticket agency': 0.1,
#  'business center': 0.1,
#  'skyscraper': 0.0,
#  'software company': 0.1,
#  'business development service': 0.0,
#  'business management consultant': 0.1,
#  'cabinet maker': 0.6,
#  'call center': 0.2,
#  'cancer treatment center': 0.0,
#  'power plant consultant': 0.0,
#  'business park': 0.0,
#  'petroleum product company': 0.2,
#  'parking lot': 0.2,
#  'water utility company': 0.3,
#  'car repair maintenance': 0.7,
#  'water treatment plant': 0.3,
#  'car service': 0.1,
#  'cattle market': 0.1,
#  'sewage disposal service': 0.3,
#  'certified public accountant': 0.2,
#  'government office': 0.5,
#  'charity': 0.1,
#  'air conditioning system supplier': 0.0,
#  'chemical industry': 0.4,
#  'chemical manufacturer': 0.5,
#  'title company': 0.1,
#  'chemical plant': 0.5,
#  'property management company': 0.0,
#  'custom home builder': 0.4,
#  'window installation service': 0.0,
#  'fire damage restoration service': 0.0,
#  'equipment rental agency': 0.2,
#  'chemical wholesaler': 0.1,
#  'financial planner': 0.5,
#  'telecommunication service provider': 0.2,
#  'energy equipment solution': 0.0,
#  'chiropractor': 0.3,
#  'steel distributor': 0.0,
#  'city government office': 0.5,
#  'crane service': 0.1,
#  'garage door supplier': 0.1,
#  'industrial door supplier': 0.1,
#  'city town hall': 0.1,
#  'clothing wholesaler': 0.2,
#  'coin operated laundry equipment supplier': 0.4,
#  'metal supplier': 0.0,
#  'glass shop': 0.0,
#  'college': 0.1,
#  'siding contractor': 0.4,
#  'commercial printer': 0.1,
#  'storage facility': 0.4,
#  'communication tower': 0.1,
#  'janitorial service': 0.3,
#  'computer consultant': 0.3,
#  'fire protection system supplier': 0.2,
#  'elevator service': 0.1,
#  'industrial equipment supplier': 0.0,
#  'dry wall contractor': 0.2,
#  'insulation contractor': 0.2,
#  'concrete contractor': 0.5,
#  'scaffolding rental service': 0.2,
#  'construction company': 0.2,
#  'flooring store': 0.1,
#  'flooring contractor': 0.4,
#  'tile contractor': 0.4,
#  'tile manufacturer': 0.1,
#  'glass mirror shop': 0.0,
#  'construction material wholesaler': 0.2,
#  'gutter cleaning service': 0.3,
#  'sheet metal contractor': 0.4,
#  'consultant': 0.1,
#  'container service': 0.2,
#  'septic system service': 0.2,
#  'corporate campus': 0.1,
#  'water damage restoration service': 0.0,
#  'welder': 0.0,
#  'corporate office': 0.1,
#  'animal': 0.4,
#  'animal feed store': 0.2,
#  'animal protection organization': 0.0,
#  'brewing supply store': 0.0,
#  'cosmetic store': 0.3,
#  'county government office': 0.5,
#  'sugar factory': 0.5,
#  'confectionery wholesaler': 0.3,
#  'financial institution': 0.0,
#  'candy store': 0.2,
#  'confectionery': 0.2,
#  'chocolate factory': 0.5,
#  'chocolate shop': 0.5,
#  'courier service': 0.1,
#  'coworking space': 0.1,
#  'frozen food manufacturer': 0.2,
#  'beverage distributor': 0.0,
#  'agricultural organization': 0.0,
#  'dairy store': 0.0,
#  'dairy': 0.3,
#  'ice cream shop': 0.2,
#  'medical laboratory': 0.2,
#  'demolition contractor': 0.2,
#  'meat processor': 0.4,
#  'fmcg manufacturer': 0.0,
#  'garbage collection service': 0.3,
#  'wholesale bakery': 0.5,
#  'dentist': 0.1,
#  'dessert shop': 0.0,
#  'cupcake shop': 0.0,
#  'nut store': 0.3,
#  'wholesale grocer': 0.4,
#  'design engineer': 0.2,
#  'business business service': 0.6,
#  'condiment supplier': 0.8,
#  'digital printing service': 0.4,
#  'culinary school': 0.4,
#  'importer': 0.0,
#  'bottled water supplier': 0.1,
#  'coffee roaster': 0.6,
#  'packaging supply store': 0.0,
#  'ice supplier': 0.6,
#  'brewery': 0.6,
#  'winemaking company': 0.0,
#  'distillery': 0.6,
#  'disability service support organisation': 0.2,
#  'district government office': 0.5,
#  'air filter supplier': 0.3,
#  'tire shop': 0.1,
#  'fastener supplier': 0.6,
#  'fabric product manufacturer': 0.2,
#  'textile': 0.2,
#  'textile exporter': 0.2,
#  'textile engineer': 0.2,
#  'fabric store': 0.0,
#  'knit shop': 0.1,
#  'doctor': 0.2,
#  'lamination service': 0.0,
#  'plastic resin manufacturer': 0.1,
#  'carpet manufacturer': 0.2,
#  'upholstery shop': 0.0,
#  'business administration service': 0.0,
#  'furniture store': 0.1,
#  'dry cleaner': 0.0,
#  'packaging company': 0.1,
#  'duty free store': 0.5,
#  'commerce service': 0.0,
#  'cable company': 0.0,
#  'education': 0.1,
#  'outlet store': 0.0,
#  'lingerie store': 0.1,
#  'clothes fabric manufacturer': 0.2,
#  'education center': 0.0,
#  'uniform store': 0.1,
#  'men clothing store': 0.6,
#  'clothing store': 0.6,
#  'woman clothing store': 0.6,
#  'western apparel store': 0.0,
#  'costume store': 0.0,
#  'game store': 0.2,
#  'hat shop': 0.0,
#  'leather good manufacturer': 0.1,
#  'educational consultant': 0.1,
#  'leather exporter': 0.2,
#  'shoe store': 0.1,
#  'boutique': 0.0,
#  'leather wholesaler': 0.1,
#  'handbag shop': 0.1,
#  'electronics store': 0.2,
#  'luggage store': 0.1,
#  'building material store': 0.3,
#  'saw mill': 0.0,
#  'electrical engineer': 0.0,
#  'deck builder': 0.1,
#  'concrete product supplier': 0.5,
#  'plywood supplier': 0.5,
#  'electrical installation service': 0.0,
#  'truss manufacturer': 0.2,
#  'door supplier': 0.1,
#  'wood laminate flooring supplier': 0.7,
#  'aircraft supply store': 0.0,
#  'modular home builder': 0.0,
#  'portable building manufacturer': 0.0,
#  'modular home dealer': 0.2,
#  'mulch supplier': 0.0,
#  'electrician': 0.1,
#  'paper mill': 0.4,
#  'energy supplier': 0.8,
#  'engineer': 0.1,
#  'print shop': 0.2,
#  'custom label printer': 0.2,
#  'marketing': 0.3,
#  'marketing agency': 0.1,
#  'engineering consultant': 0.4,
#  'entertainer': 0.0,
#  'envelope supplier': 0.1,
#  'oil refinery': 0.2,
#  'recording studio': 0.4,
#  'environment renewable natural resource': 0.0,
#  'finishing material supplier': 0.0,
#  'event ticket seller': 0.0,
#  'waterproofing company': 0.0,
#  'auto part store': 0.0,
#  'heating oil supplier': 0.1,
#  'family practice physician': 0.2,
#  'machining manufacturer': 0.0,
#  'industrial gas supplier': 0.0,
#  'welding supply store': 0.0,
#  'dry ice supplier': 0.3,
#  'private equity firm': 0.0,
#  'family service center': 0.1,
#  'federal government office': 0.5,
#  'vitamin supplement store': 0.2,
#  'feed manufacturer': 0.2,
#  'medical equipment supplier': 0.0,
#  'medical supply store': 0.0,
#  'medical clinic': 0.2,
#  'research institute': 0.4,
#  'biochemical supplier': 0.0,
#  'fiber optic product supplier': 0.1,
#  'paint manufacturer': 0.2,
#  'equipment supplier': 0.0,
#  'food': 0.0,
#  'pipe supplier': 0.4,
#  'oil field equipment supplier': 0.2,
#  'food broker': 0.0,
#  'food manufacturer': 0.2,
#  'food processing company': 0.1,
#  'fence supply store': 0.1,
#  'food producer': 0.0,
#  'forestry service': 0.1,
#  'foundry': 0.6,
#  'wholesale jeweler': 0.1,
#  'cookie shop': 0.1,
#  'truck rental agency': 0.3,
#  'fruit vegetable processing': 0.4,
#  'kitchen supply store': 0.0,
#  'hydraulic equipment supplier': 0.0,
#  'irrigation equipment supplier': 0.1,
#  'bearing supplier': 0.3,
#  'metallurgy company': 0.1,
#  'plastic injection molding service': 0.0,
#  'general contractor': 0.0,
#  'general hospital': 0.1,
#  'tool manufacturer': 0.5,
#  'industrial design company': 0.3,
#  'hyundai dealer': 0.0,
#  'glass industry': 0.4,
#  'polymer supplier': 0.0,
#  'printing equipment supply': 0.0,
#  'toner cartridge supplier': 0.2,
#  'printer repair service': 0.1,
#  'fuel supplier': 0.0,
#  'glass manufacturer': 0.4,
#  'plastic bag supplier': 1.0,
#  'glassware manufacturer': 0.1,
#  'polythene plastic sheeting supplier': 1.0,
#  'pvc industry': 0.1,
#  'countertop store': 0.0,
#  'cabinet store': 0.1,
#  'fiberglass supplier': 0.1,
#  'golf cart dealer': 0.3,
#  'auto repair shop': 0.7,
#  'hose supplier': 0.3,
#  'rubber product supplier': 0.5,
#  'automotive': 0.0,
#  'commercial refrigerator supplier': 0.0,
#  'golf club': 0.6,
#  'golf course': 0.4,
#  'green energy supplier': 0.8,
#  'greenhouse': 0.4,
#  'auto glass shop': 0.1,
#  'lighting manufacturer': 0.4,
#  'cement manufacturer': 0.5,
#  'brick manufacturer': 0.5,
#  'natural stone supplier': 0.0,
#  'gym': 0.1,
#  'marble supplier': 0.1,
#  'corporate gift supplier': 0.2,
#  'shipbuilding repair company': 0.0,
#  'construction maintenance office': 0.2,
#  'boiler manufacturer': 0.3,
#  'container supplier': 0.4,
#  'home construction': 0.4,
#  'health': 0.2,
#  'heart hospital': 0.1,
#  'spring supplier': 0.2,
#  'electric utility manufacturer': 0.0,
#  'aircraft manufacturer': 0.6,
#  'metal heat treating service': 0.3,
#  'plating service': 0.1,
#  'automation company': 0.0,
#  'heating contractor': 0.2,
#  'plumbing supply store': 0.0,
#  'gun shop': 0.1,
#  'ammunition supplier': 0.6,
#  'pipe manufacturer': 0.2,
#  'school': 0.1,
#  'fire protection equipment supplier': 0.1,
#  'agricultural machinery manufacturer': 0.2,
#  'lawn mower store': 0.0,
#  'lawn irrigation equipment supplier': 0.1,
#  'financial consultant': 0.5,
#  'helicopter charter': 0.3,
#  'packaging machinery': 0.1,
#  'historical landmark': 0.4,
#  'electronics manufacturer': 0.0,
#  'graphic designer': 0.3,
#  'eye care center': 0.1,
#  'optical product manufacturer': 0.1,
#  'image consultant': 0.1,
#  'cleaning product supplier': 0.0,
#  'fireplace store': 0.0,
#  'home builder': 0.4,
#  'tool die shop': 0.5,
#  'metal stamping service': 0.2,
#  'environmental organization': 0.3,
#  'food processing equipment': 0.0,
#  'loan agency': 0.2,
#  'power plant equipment supplier': 0.0,
#  'home good store': 0.2,
#  'engine rebuilding service': 0.0,
#  'air compressor supplier': 0.3,
#  'honda dealer': 0.2,
#  'elevator manufacturer': 0.1,
#  'crane dealer': 0.0,
#  'crane rental agency': 0.2,
#  'compound building': 0.0,
#  'tractor dealer': 0.0,
#  'furnace part supplier': 0.0,
#  'heating equipment supplier': 0.1,
#  'pneumatic tool supplier': 0.0,
#  'truck stop': 0.1,
#  'computer hardware manufacturer': 0.3,
#  'satellite communication service': 0.1,
#  'hospital': 0.1,
#  'electronics company': 0.1,
#  'electronic part supplier': 0.0,
#  'hvac contractor': 0.2,
#  'industrial engineer': 0.1,
#  'contact lens supplier': 0.2,
#  'information service': 0.4,
#  'building': 0.2,
#  'water work equipment supplier': 0.0,
#  'measuring instrument supplier': 0.8,
#  'scientific equipment supplier': 0.0,
#  'medical center': 0.0,
#  'watch manufacturer': 0.2,
#  'corporate entertainment service': 0.0,
#  'insurance': 0.4,
#  'record company': 0.0,
#  'video duplication service': 0.2,
#  'insurance agency': 0.4,
#  'lighting store': 0.4,
#  'lighting wholesaler': 0.3,
#  'entertainment agency': 0.0,
#  'insurance broker': 0.4,
#  'electrical equipment supplier': 0.0,
#  'electric motor store': 0.0,
#  'railroad company': 0.2,
#  'electrical supply store': 0.0,
#  'insurance company': 0.4,
#  'factory equipment supplier': 0.0,
#  'investment service': 0.5,
#  'laser equipment supplier': 0.0,
#  'executive suite rental agency': 0.2,
#  'truck dealer': 0.0,
#  'motor vehicle dealer': 0.2,
#  'car dealer': 0.2,
#  'truck topper supplier': 0.0,
#  'police supply store': 0.5,
#  'iron steel contractor': 0.2,
#  'fire department equipment supplier': 0.1,
#  'towing equipment provider': 0.2,
#  'logistics service': 0.2,
#  'trailer manufacturer': 0.4,
#  'trailer dealer': 0.0,
#  'dealer': 0.3,
#  'auto spring shop': 0.0,
#  'auto upholsterer': 0.0,
#  'auto body part supplier': 0.0,
#  'car factory': 0.0,
#  'freight forwarding service': 0.1,
#  'brake shop': 0.3,
#  'railroad equipment supplier': 0.0,
#  'jewelry equipment supplier': 0.9,
#  'boat builder': 0.2,
#  'ship building': 0.2,
#  'marine supply store': 0.0,
#  'boat dealer': 0.3,
#  'kawasaki motorcycle dealer': 0.3,
#  'knife manufacturing': 0.0,
#  'labor union': 0.5,
#  'furniture maker': 0.6,
#  'banking finance': 0.2,
#  'furniture manufacturer': 0.6,
#  'logistics': 0.5,
#  'massage supply store': 0.0,
#  'telecommunication equipment supplier': 0.0,
#  'baby store': 0.0,
#  'molding supplier': 0.0,
#  'office equipment supplier': 0.0,
#  'office furniture store': 0.3,
#  'store equipment supplier': 0.0,
#  'laboratory': 0.1,
#  'health beauty shop': 0.1,
#  'learning center': 0.1,
#  'dental laboratory': 0.2,
#  'land surveyor': 0.1,
#  'educational supply store': 0.1,
#  'jewelry store': 0.1,
#  'playground equipment supplier': 0.0,
#  'outdoor sport store': 0.1,
#  'toy store': 0.2,
#  'security service': 0.3,
#  'sign shop': 0.1,
#  'office supply store': 0.1,
#  'landscaper': 0.0,
#  'gasket manufacturer': 0.1,
#  'piano maker': 0.1,
#  'piano store': 0.1,
#  'funeral home': 0.2,
#  'monument': 0.0,
#  'book publisher': 0.6,
#  'wig shop': 0.1,
#  'laundromat': 0.1,
#  'auto wrecker': 0.1,
#  'auto part market': 0.2,
#  'jeep dealer': 0.2,
#  'restaurant supply store': 0.0,
#  'roofing supply store': 0.0,
#  'law firm': 0.1,
#  'building material market': 0.4,
#  'camera store': 0.0,
#  'lawn care service': 0.0,
#  'computer security service': 0.1,
#  'computer store': 0.0,
#  'design agency': 0.4,
#  'diagnostic center': 0.2,
#  'laboratory equipment supplier': 0.1,
#  'home theater store': 0.0,
#  'metal industry supplier': 0.0,
#  'landscaping supply store': 0.0,
#  'appliance part supplier': 0.0,
#  'vacuum cleaner store': 0.1,
#  'audio visual equipment supplier': 0.1,
#  'lawyer': 0.4,
#  'cell phone store': 0.0,
#  'bathroom supply store': 0.0,
#  'leasing service': 0.4,
#  'construction machine dealer': 0.0,
#  'dairy farm equipment supplier': 0.0,
#  'propane supplier': 0.0,
#  'legal service': 0.4,
#  'janitorial equipment supplier': 0.1,
#  'life insurance agency': 0.4,
#  'railroad contractor': 0.0,
#  'swimming pool supply store': 0.5,
#  'light bulb supplier': 0.4,
#  'linen store': 0.0,
#  'metal construction company': 0.5,
#  'local government office': 0.5,
#  'logging contractor': 0.0,
#  'machine shop': 0.2,
#  'hotel supply store': 0.0,
#  'import export company': 0.0,
#  'sewing company': 0.1,
#  'research foundation': 0.4,
#  'machinery part manufacturer': 0.5,
#  'sport accessory wholesaler': 0.0,
#  'fashion designer': 0.2,
#  'cheese manufacturer': 0.1,
#  'cheese shop': 0.1,
#  'shipping mailing': 0.0,
#  'wholesale food store': 0.0,
#  'organic food store': 0.0,
#  'pie shop': 0.1,
#  'auction house': 0.5,
#  'livestock auction house': 0.1,
#  'cotton exporter': 0.3,
#  'plastic wholesaler': 0.0,
#  'mailing service': 0.0,
#  'manufacturer': 0.0,
#  'gas station': 0.2,
#  'beer distributor': 0.2,
#  'alcoholic beverage wholesaler': 0.2,
#  'religious good store': 0.1,
#  'book wholesaler': 0.1,
#  'masonry supply store': 0.1,
#  'wholesale florist': 0.2,
#  'florist': 0.1,
#  'marine engineer': 0.1,
#  'paint store': 0.1,
#  'used auto part store': 0.1,
#  'masonry contractor': 0.4,
#  'used car dealer': 0.2,
#  'used truck dealer': 0.2,
#  'massage therapist': 0.3,
#  'material handling equipment supplier': 0.0,
#  'marina': 0.6,
#  'meat packer': 0.1,
#  'mattress store': 0.0,
#  'blind shop': 0.1,
#  'interior designer': 0.2,
#  'window treatment store': 0.2,
#  'appliance store': 0.2,
#  'health food store': 0.2,
#  'direct mail advertising': 0.6,
#  'meat wholesaler': 0.4,
#  'butcher shop deli': 0.1,
#  'italian grocery store': 0.2,
#  'market': 0.0,
#  'food service': 0.3,
#  'grocery delivery service': 0.1,
#  'wine store': 0.1,
#  'liquor store': 0.1,
#  'kiosk': 0.0,
#  'optometrist': 0.3,
#  'optician': 0.1,
#  'mechanical contractor': 0.2,
#  'mechanical engineer': 0.1,
#  'cafe': 0.2,
#  'jeweler': 0.1,
#  'leather good store': 0.1,
#  'gift shop': 0.2,
#  'craft store': 0.1,
#  'hobby store': 0.3,
#  'fabric wholesaler': 0.0,
#  'scrap metal dealer': 0.0,
#  'quilt shop': 0.0,
#  'sheet music store': 0.1,
#  'musical instrument manufacturer': 0.1,
#  'music store': 0.1,
#  'musical instrument store': 0.4,
#  'band': 0.1,
#  'bookstore': 0.0,
#  'art museum': 0.4,
#  'newsstand': 0.1,
#  'medical equipment manufacturer': 0.5,
#  'fashion accessory store': 0.2,
#  'discount store': 0.0,
#  'cemetery': 0.1,
#  'bus stop': 0.4,
#  'variety store': 0.0,
#  'thrift store': 0.1,
#  'medical group': 0.0,
#  'donation center': 0.0,
#  'pet store': 0.5,
#  'art gallery': 0.1,
#  'art dealer': 0.2,
#  'housing development': 0.2,
#  'mobile home dealer': 0.2,
#  'convenience store': 0.2,
#  'medical office': 0.0,
#  'medical technology manufacturer': 0.1,
#  'childrens furniture store': 0.1,
#  'mental health clinic': 0.2,
#  'airline': 0.0,
#  'aviation consultant': 0.0,
#  'travel agency': 0.4,
#  'travel service': 0.4,
#  'airport': 0.2,
#  'mental health service': 0.2,
#  'shipping company': 0.0,
#  'metal fabricator': 0.6,
#  'cruise line company': 0.0,
#  'towing service': 0.2,
#  'ferry terminal': 0.1,
#  'ferry service': 0.0,
#  'metal finisher': 0.3,
#  'boat tour agency': 0.1,
#  'bus company': 0.4,
#  'moving company': 0.1,
#  'moving storage service': 0.1,
#  'state department transportation': 0.0,
#  'department transportation': 0.0,
#  'handicapped transportation service': 0.2,
#  'railway service': 0.0,
#  'train station': 0.0,
#  'bus depot': 0.1,
#  'bus charter': 0.1,
#  'metal processing company': 0.6,
#  'mixed use': 0.0,
#  'motorcycle shop': 0.2,
#  'limousine service': 0.2,
#  'chauffeur service': 0.0,
#  'school bus service': 0.1,
#  'airport shuttle service': 0.2,
#  'tourist information center': 0.0,
#  'carriage ride service': 0.0,
#  'cruise agency': 0.2,
#  'tourist attraction': 0.1,
#  'ski resort': 0.5,
#  'ski area': 0.1,
#  'fixed base operator': 0.0,
#  'aircraft maintenance company': 0.1,
#  'motorsports store': 0.0,
#  'boat rental service': 0.6,
#  'utility trailer dealer': 0.0,
#  'forklift dealer': 0.0,
#  'municipal administration office': 0.0,
#  'nephrologist': 0.0,
#  'bus coach company': 0.1,
#  'shipping service': 0.0,
#  'shipping mailing service': 0.0,
#  'newspaper publisher': 0.6,
#  'shredding service': 0.0,
#  'nuclear power company': 0.9,
#  'nursing home': 0.1,
#  'medium company': 0.2,
#  'multimedia electronic book publisher': 0.0,
#  'internet marketing service': 0.1,
#  'greeting card shop': 0.1,
#  'theme park': 0.2,
#  'film production company': 0.1,
#  'obstetrician gynecologist': 0.1,
#  'movie studio': 0.0,
#  'video production service': 0.3,
#  'movie theater': 0.5,
#  'theater company': 0.3,
#  'performing art theater': 0.4,
#  'occupational safety health': 0.0,
#  'office space rental agency': 0.0,
#  'commercial real estate agency': 0.1,
#  'art school': 0.2,
#  'music publisher': 0.2,
#  'printed music publisher': 0.1,
#  'home audio store': 0.0,
#  'musician': 0.1,
#  'music management promotion': 0.0,
#  'video editing service': 0.2,
#  'office supply wholesaler': 0.2,
#  'official residence': 0.1,
#  'orthopedic clinic': 0.2,
#  'painter': 0.0,
#  'painting': 0.5,
#  'telephone company': 0.0,
#  'medium house': 0.5,
#  'paper distributor': 0.0,
#  'news service': 0.1,
#  'public library': 0.0,
#  'law library': 0.4,
#  'museum': 0.4,
#  'federal reserve bank': 0.1,
#  'credit union': 0.2,
#  'atm': 0.1,
#  'paving contractor': 0.2,
#  'mortgage lender': 0.3,
#  'investment bank': 0.0,
#  'check cashing service': 0.2,
#  'stock broker': 0.0,
#  'health consultant': 0.0,
#  'health insurance agency': 0.6,
#  'payroll service': 0.4,
#  'pediatrician': 0.2,
#  'human resource consulting': 0.7,
#  'pest control service': 0.4,
#  'pet boarding service': 0.5,
#  'pet care': 0.1,
#  'loss adjuster': 0.2,
#  'pharmaceutical company': 0.4,
#  'pharmaceutical product wholesaler': 0.1,
#  'pharmacy': 0.1,
#  'educational institution': 0.1,
#  'retirement community': 0.2,
#  'fraternal organization': 0.1,
#  'photo lab': 0.0,
#  'property investment': 0.0,
#  'photographer': 0.1,
#  'photography school': 0.2,
#  'star hotel': 0.4,
#  'convention center': 0.1,
#  'real estate appraiser': 0.4,
#  'photography service': 0.2,
#  'resort hotel': 0.4,
#  'real estate consultant': 0.1,
#  'car rental agency': 0.3,
#  'car leasing service': 0.3,
#  'ford dealer': 0.2,
#  'car finance loan company': 0.5,
#  'trailer rental service': 0.2,
#  'furniture rental service': 0.5,
#  'tuxedo shop': 0.0,
#  'dress tuxedo rental service': 0.6,
#  'wedding store': 0.0,
#  'video store': 0.1,
#  'movie rental': 0.0,
#  'photography studio': 0.2,
#  'home health care service': 0.1,
#  'skateboard shop': 0.0,
#  'event technology service': 0.0,
#  'party equipment rental service': 0.6,
#  'construction machine rental service': 0.2,
#  'audio visual equipment rental service': 0.0,
#  'shipping equipment industry': 0.0,
#  'physical therapy clinic': 0.3,
#  'plastic fabrication company': 1.0,
#  'plastic product supplier': 1.0,
#  'auto tag agency': 0.2,
#  'department motor vehicle': 0.0,
#  'notary public': 0.3,
#  'private investigator': 0.0,
#  'escrow service': 0.0,
#  'real estate agent': 0.1,
#  'playground': 0.0,
#  'plumber': 0.1,
#  'port authority': 0.4,
#  'portrait studio': 0.2,
#  'post office': 0.1,
#  'professional service': 0.4,
#  'university hospital': 0.1,
#  'public relation firm': 0.5,
#  'civil engineering company': 0.1,
#  'drafting service': 0.7,
#  'pump supplier': 1.0,
#  'interior construction contractor': 0.0,
#  'carpet cleaning service': 0.5,
#  'exhibition planner': 0.0,
#  'decal supplier': 0.0,
#  'stage lighting equipment supplier': 0.4,
#  'event management company': 0.1,
#  'radio broadcaster': 0.0,
#  'computer support service': 0.4,
#  'ravine': 0.0,
#  'employment center': 0.3,
#  'national health foundation': 0.1,
#  'real estate developer': 0.0,
#  'advertising agency': 0.8,
#  'promotional product supplier': 0.0,
#  'advertising service': 0.8,
#  'record storage facility': 0.0,
#  'fund management company': 0.0,
#  'recreation center': 0.6,
#  'bakery': 0.6,
#  'database management company': 0.0,
#  'market researcher': 0.0,
#  'recycling center': 0.0,
#  'regional government office': 0.4,
#  'rehabilitation center': 0.0,
#  'religious institution': 0.1,
#  'religious organization': 0.1,
#  'repair service': 0.4,
#  'emergency veterinarian service': 0.2,
#  'pet sitter': 0.1,
#  'research product development': 0.4,
#  'building society': 0.2,
#  'valet parking service': 0.5,
#  'nursing agency': 0.1,
#  'executive search firm': 0.2,
#  'recruiter': 0.0,
#  'temp agency': 0.1,
#  'health center': 0.0,
#  'restaurant': 0.4,
#  'roofing contractor': 0.4,
#  'sport nutrition store': 0.1,
#  'credit reporting agency': 0.2,
#  'automobile storage facility': 0.4,
#  'debt collection agency': 0.3,
#  'park': 0.0,
#  'court reporter': 0.4,
#  'bus tour agency': 0.1,
#  'tour operator': 0.4,
#  'convention information bureau': 0.1,
#  'balloon ride tour agency': 0.1,
#  'security guard service': 0.5,
#  'locksmith': 0.2,
#  'commercial cleaning service': 0.3,
#  'blast cleaning service': 0.3,
#  'conference center': 0.0,
#  'safety equipment supplier': 0.0,
#  'garbage dump': 0.4,
#  'sanitation service': 0.1,
#  'garbage dump service': 0.0,
#  'environmental health service': 0.1,
#  'portable toilet supplier': 0.2,
#  'public work department': 0.0,
#  'school district office': 0.1,
#  'sailmaker': 0.0,
#  'community college': 0.1,
#  'salvage yard': 0.1,
#  'business school': 0.0,
#  'trade school': 0.4,
#  'private university': 0.1,
#  'computer training school': 0.2,
#  'school supply store': 0.0,
#  'screen printer': 0.4,
#  'medium consultant': 0.5,
#  'beauty school': 0.4,
#  'flight school': 0.4,
#  'seaport': 0.0,
#  'security system supplier': 0.3,
#  'middle school': 0.1,
#  'nonprofit': 0.0,
#  'shooting range': 0.1,
#  'soccer club': 0.1,
#  'camp': 0.2,
#  'diving contractor': 0.0,
#  'language school': 0.5,
#  'english language school': 0.5,
#  'preschool': 0.1,
#  'self storage facility': 0.1,
#  'semi conductor supplier': 0.0,
#  'driving school': 0.5,
#  'trucking school': 0.1,
#  'senior citizen center': 0.0,
#  'service': 0.0,
#  'childrens hospital': 0.1,
#  'dental supply store': 0.1,
#  'shipyard': 0.2,
#  'orthodox synagogue': 0.1,
#  'short term apartment rental agency': 0.0,
#  'nutritionist': 0.1,
#  'ophthalmologist': 0.0,
#  'ophthalmology clinic': 0.1,
#  'social service organization': 0.3,
#  'social welfare center': 0.3,
#  'solar energy company': 0.8,
#  'solar energy equipment supplier': 0.8,
#  'special education school': 0.1,
#  'podiatrist': 0.2,
#  'reproductive health clinic': 0.5,
#  'sporting good store': 0.3,
#  'dialysis center': 0.5,
#  'sport complex': 0.2,
#  'wellness program': 0.0,
#  'sportswear store': 0.0,
#  'private hospital': 0.1,
#  'radiologist': 0.0,
#  'medical diagnostic imaging center': 0.2,
#  'ray lab': 0.2,
#  'blood bank': 0.2,
#  'stainless steel plant': 0.1,
#  'state agency': 0.2,
#  'heliport': 0.0,
#  'health care company': 0.0,
#  'psychiatric hospital': 0.1,
#  'state government office': 0.5,
#  'medical institution': 0.1,
#  'steel construction company': 0.1,
#  'cleaning service': 0.3,
#  ...}

# %%
calc_pre_rec_at_n(ret_docs_dic, queries_dic, n=-1)[1]
# Out:
# {'home improvement store': 0.25,
#  'diesel fuel supplier': 0.0,
#  'church': 1.0,
#  'farm': 1.0,
#  'seed supplier': 0.0,
#  'accountant': 1.0,
#  'trucking company': 1.0,
#  'exporter': 0.143,
#  'grain elevator': 0.25,
#  'popcorn store': 0.333,
#  'agricultural service': 0.0,
#  'warehouse': 1.0,
#  'agricultural production': 0.143,
#  'ranch': 0.5,
#  'holding company': 1.0,
#  'farm equipment supplier': 0.0,
#  'store': 0.0,
#  'grocery store': 1.0,
#  'rice mill': 0.286,
#  'food product supplier': 0.0,
#  'accounting firm': 1.0,
#  'produce market': 0.5,
#  'pet supply store': 1.0,
#  'wholesaler': 0.0,
#  'produce wholesaler': 0.0,
#  'distribution service': 0.0,
#  'crop grower': 0.857,
#  'addiction treatment center': 0.0,
#  'natural good store': 0.0,
#  'orchard': 0.222,
#  'lumber store': 0.0,
#  'mine': 0.833,
#  'transportation service': 1.0,
#  'investment company': 0.0,
#  'fruit wholesaler': 0.222,
#  'real estate agency': 1.0,
#  'event venue': 0.0,
#  'frozen dessert supplier': 0.6,
#  'wine wholesaler importer': 1.0,
#  'winery': 1.0,
#  'aerospace company': 1.0,
#  'cold storage facility': 1.0,
#  'employment agency': 1.0,
#  'plant nursery': 0.5,
#  'air conditioning contractor': 0.667,
#  'air conditioning repair service': 0.0,
#  'fruit vegetable wholesaler': 0.167,
#  'aircraft rental service': 0.0,
#  'monastery': 1.0,
#  'allergist': 0.5,
#  'herb shop': 0.0,
#  'aluminum supplier': 1.0,
#  'ambulance service': 0.333,
#  'wholesale plant nursery': 0.833,
#  'amusement machine supplier': 1.0,
#  'animal hospital': 0.0,
#  'farmer market': 0.5,
#  'vaporizer store': 1.0,
#  'cigar shop': 0.2,
#  'tobacco shop': 0.0,
#  'well drilling contractor': 0.2,
#  'library': 1.0,
#  'apartment building': 0.0,
#  'apartment rental agency': 0.0,
#  'dairy farm': 0.25,
#  'architect': 0.25,
#  'organic farm': 0.0,
#  'architectural designer': 0.5,
#  'architecture firm': 0.0,
#  'livestock producer': 0.0,
#  'dairy supplier': 0.0,
#  'biotechnology company': 0.5,
#  'artist': 1.0,
#  'egg supplier': 1.0,
#  'poultry farm': 0.25,
#  'chicken hatchery': 0.8,
#  'art organization': 1.0,
#  'association organization': 1.0,
#  'food store': 1.0,
#  'deli': 0.0,
#  'bank': 0.75,
#  'fish processing': 1.0,
#  'fish farm': 0.333,
#  'seafood wholesaler': 0.444,
#  'tropical fish store': 1.0,
#  'non profit organization': 0.0,
#  'economic development agency': 0.6,
#  'seafood market': 0.333,
#  'honey farm': 0.5,
#  'horse breeder': 0.5,
#  'asphalt contractor': 1.0,
#  'livestock dealer': 0.0,
#  'department store': 1.0,
#  'mill': 0.0,
#  'atv dealer': 1.0,
#  'audio visual consultant': 1.0,
#  'pallet supplier': 0.571,
#  'wood supplier': 0.0,
#  'hardware store': 0.25,
#  'furniture wholesaler': 0.5,
#  'auditor': 0.25,
#  'oil natural gas company': 0.6,
#  'auto body shop': 0.333,
#  'boat repair shop': 0.5,
#  'association': 0.6,
#  'railing contractor': 0.0,
#  'publisher': 1.0,
#  'pond supply store': 0.0,
#  'agriculture cooperative': 0.0,
#  'printing equipment supplier': 0.2,
#  'auto insurance agency': 1.0,
#  'alternative fuel station': 1.0,
#  'auto part manufacturer': 0.0,
#  'foundation': 1.0,
#  'fertilizer supplier': 1.0,
#  'farming company': 0.0,
#  'finance broker': 0.333,
#  'agricultural cooperative': 0.0,
#  'fire station': 0.143,
#  'environmental consultant': 0.429,
#  'civil engineer': 1.0,
#  'fire protection service': 0.143,
#  'gas company': 1.0,
#  'oilfield': 0.0,
#  'banquet hall': 0.333,
#  'mining company': 0.333,
#  'coalfield': 0.0,
#  'steel fabricator': 0.0,
#  'quarry': 0.0,
#  'gold mining company': 0.667,
#  'high rise building': 1.0,
#  'basketball club': 0.333,
#  'gold dealer': 0.0,
#  'battery manufacturer': 0.5,
#  'electric utility company': 0.0,
#  'environmental program': 0.0,
#  'office': 0.0,
#  'stone supplier': 0.25,
#  'aggregate supplier': 0.0,
#  'sand gravel supplier': 0.167,
#  'building material supplier': 1.0,
#  'beauty supply store': 0.6,
#  'crushed stone supplier': 0.25,
#  'rock shop': 0.0,
#  'road construction company': 1.0,
#  'marketing consultant': 0.429,
#  'blood testing service': 0.625,
#  'contractor': 1.0,
#  'excavating contractor': 1.0,
#  'asphalt mixing plant': 0.4,
#  'ready mix concrete supplier': 0.8,
#  'sand plant': 0.167,
#  'bmw dealer': 1.0,
#  'bookbinder': 0.0,
#  'garden center': 1.0,
#  'abrasive supplier': 1.0,
#  'granite supplier': 0.2,
#  'drilling contractor': 0.0,
#  'bpo company': 0.2,
#  'oil gas exploration service': 1.0,
#  'building complex': 0.0,
#  'construction equipment supplier': 0.0,
#  'mining equipment': 0.0,
#  'bus ticket agency': 0.25,
#  'business center': 0.1,
#  'skyscraper': 0.0,
#  'software company': 1.0,
#  'business development service': 0.0,
#  'business management consultant': 0.143,
#  'cabinet maker': 1.0,
#  'call center': 0.2,
#  'cancer treatment center': 0.0,
#  'power plant consultant': 0.0,
#  'business park': 0.0,
#  'petroleum product company': 1.0,
#  'parking lot': 0.4,
#  'water utility company': 1.0,
#  'car repair maintenance': 0.778,
#  'water treatment plant': 1.0,
#  'car service': 0.111,
#  'cattle market': 0.333,
#  'sewage disposal service': 1.0,
#  'certified public accountant': 0.5,
#  'government office': 0.833,
#  'charity': 0.333,
#  'air conditioning system supplier': 0.0,
#  'chemical industry': 0.8,
#  'chemical manufacturer': 1.0,
#  'title company': 0.25,
#  'chemical plant': 1.0,
#  'property management company': 0.0,
#  'custom home builder': 1.0,
#  'window installation service': 0.0,
#  'fire damage restoration service': 0.0,
#  'equipment rental agency': 0.5,
#  'chemical wholesaler': 0.5,
#  'financial planner': 1.0,
#  'telecommunication service provider': 1.0,
#  'energy equipment solution': 0.0,
#  'chiropractor': 0.5,
#  'steel distributor': 0.0,
#  'city government office': 0.833,
#  'crane service': 0.071,
#  'garage door supplier': 0.167,
#  'industrial door supplier': 0.167,
#  'city town hall': 0.167,
#  'clothing wholesaler': 0.5,
#  'coin operated laundry equipment supplier': 1.0,
#  'metal supplier': 0.0,
#  'glass shop': 0.0,
#  'college': 1.0,
#  'siding contractor': 0.5,
#  'commercial printer': 0.25,
#  'storage facility': 1.0,
#  'communication tower': 0.333,
#  'janitorial service': 0.6,
#  'computer consultant': 0.75,
#  'fire protection system supplier': 0.286,
#  'elevator service': 0.071,
#  'industrial equipment supplier': 0.0,
#  'dry wall contractor': 0.333,
#  'insulation contractor': 0.333,
#  'concrete contractor': 0.625,
#  'scaffolding rental service': 0.5,
#  'construction company': 1.0,
#  'flooring store': 0.333,
#  'flooring contractor': 0.667,
#  'tile contractor': 0.667,
#  'tile manufacturer': 0.167,
#  'glass mirror shop': 0.0,
#  'construction material wholesaler': 0.5,
#  'gutter cleaning service': 0.6,
#  'sheet metal contractor': 0.667,
#  'consultant': 0.143,
#  'container service': 0.5,
#  'septic system service': 0.5,
#  'corporate campus': 0.333,
#  'water damage restoration service': 0.0,
#  'welder': 0.0,
#  'corporate office': 0.333,
#  'animal': 1.0,
#  'animal feed store': 0.4,
#  'animal protection organization': 0.0,
#  'brewing supply store': 0.0,
#  'cosmetic store': 0.6,
#  'county government office': 0.833,
#  'sugar factory': 1.0,
#  'confectionery wholesaler': 0.333,
#  'financial institution': 0.0,
#  'candy store': 0.333,
#  'confectionery': 0.333,
#  'chocolate factory': 1.0,
#  'chocolate shop': 1.0,
#  'courier service': 1.0,
#  'coworking space': 0.25,
#  'frozen food manufacturer': 0.4,
#  'beverage distributor': 0.0,
#  'agricultural organization': 0.0,
#  'dairy store': 0.0,
#  'dairy': 0.75,
#  'ice cream shop': 0.4,
#  'medical laboratory': 1.0,
#  'demolition contractor': 1.0,
#  'meat processor': 1.0,
#  'fmcg manufacturer': 0.0,
#  'garbage collection service': 1.0,
#  'wholesale bakery': 0.833,
#  'dentist': 1.0,
#  'dessert shop': 0.0,
#  'cupcake shop': 0.0,
#  'nut store': 0.5,
#  'wholesale grocer': 0.444,
#  'design engineer': 0.25,
#  'business business service': 0.6,
#  'condiment supplier': 1.0,
#  'digital printing service': 1.0,
#  'culinary school': 1.0,
#  'importer': 0.0,
#  'bottled water supplier': 0.167,
#  'coffee roaster': 0.75,
#  'packaging supply store': 0.0,
#  'ice supplier': 1.0,
#  'brewery': 1.0,
#  'winemaking company': 0.0,
#  'distillery': 1.0,
#  'disability service support organisation': 0.667,
#  'district government office': 0.833,
#  'air filter supplier': 1.0,
#  'tire shop': 0.5,
#  'fastener supplier': 0.545,
#  'fabric product manufacturer': 1.0,
#  'textile': 1.0,
#  'textile exporter': 1.0,
#  'textile engineer': 1.0,
#  'fabric store': 0.0,
#  'knit shop': 0.25,
#  'doctor': 1.0,
#  'lamination service': 0.0,
#  'plastic resin manufacturer': 0.333,
#  'carpet manufacturer': 1.0,
#  'upholstery shop': 0.0,
#  'business administration service': 0.0,
#  'furniture store': 1.0,
#  'dry cleaner': 0.0,
#  'packaging company': 0.333,
#  'duty free store': 1.0,
#  'commerce service': 0.0,
#  'cable company': 0.0,
#  'education': 1.0,
#  'outlet store': 0.0,
#  'lingerie store': 0.167,
#  'clothes fabric manufacturer': 1.0,
#  'education center': 0.0,
#  'uniform store': 0.167,
#  'men clothing store': 1.0,
#  'clothing store': 1.0,
#  'woman clothing store': 1.0,
#  'western apparel store': 0.0,
#  'costume store': 0.0,
#  'game store': 0.5,
#  'hat shop': 0.0,
#  'leather good manufacturer': 0.5,
#  'educational consultant': 1.0,
#  'leather exporter': 1.0,
#  'shoe store': 1.0,
#  'boutique': 0.0,
#  'leather wholesaler': 0.5,
#  'handbag shop': 0.5,
#  'electronics store': 1.0,
#  'luggage store': 0.5,
#  'building material store': 0.75,
#  'saw mill': 0.0,
#  'electrical engineer': 0.0,
#  'deck builder': 0.167,
#  'concrete product supplier': 1.0,
#  'plywood supplier': 1.0,
#  'electrical installation service': 0.0,
#  'truss manufacturer': 0.4,
#  'door supplier': 0.143,
#  'wood laminate flooring supplier': 1.0,
#  'aircraft supply store': 0.0,
#  'modular home builder': 0.0,
#  'portable building manufacturer': 0.0,
#  'modular home dealer': 0.4,
#  'mulch supplier': 0.0,
#  'electrician': 0.333,
#  'paper mill': 1.0,
#  'energy supplier': 0.8,
#  'engineer': 0.125,
#  'print shop': 0.5,
#  'custom label printer': 0.5,
#  'marketing': 0.429,
#  'marketing agency': 0.125,
#  'engineering consultant': 0.5,
#  'entertainer': 0.0,
#  'envelope supplier': 0.143,
#  'oil refinery': 0.4,
#  'recording studio': 1.0,
#  'environment renewable natural resource': 0.0,
#  'finishing material supplier': 0.0,
#  'event ticket seller': 0.0,
#  'waterproofing company': 0.0,
#  'auto part store': 0.0,
#  'heating oil supplier': 0.5,
#  'family practice physician': 1.0,
#  'machining manufacturer': 0.0,
#  'industrial gas supplier': 0.0,
#  'welding supply store': 0.0,
#  'dry ice supplier': 0.5,
#  'private equity firm': 0.0,
#  'family service center': 0.333,
#  'federal government office': 0.833,
#  'vitamin supplement store': 0.4,
#  'feed manufacturer': 1.0,
#  'medical equipment supplier': 0.0,
#  'medical supply store': 0.0,
#  'medical clinic': 1.0,
#  'research institute': 1.0,
#  'biochemical supplier': 0.0,
#  'fiber optic product supplier': 0.125,
#  'paint manufacturer': 1.0,
#  'equipment supplier': 0.0,
#  'food': 0.0,
#  'pipe supplier': 0.4,
#  'oil field equipment supplier': 0.4,
#  'food broker': 0.0,
#  'food manufacturer': 1.0,
#  'food processing company': 0.125,
#  'fence supply store': 0.25,
#  'food producer': 0.0,
#  'forestry service': 1.0,
#  'foundry': 1.0,
#  'wholesale jeweler': 0.2,
#  'cookie shop': 0.167,
#  'truck rental agency': 1.0,
#  'fruit vegetable processing': 0.8,
#  'kitchen supply store': 0.0,
#  'hydraulic equipment supplier': 0.0,
#  'irrigation equipment supplier': 0.333,
#  'bearing supplier': 0.3,
#  'metallurgy company': 0.2,
#  'plastic injection molding service': 0.0,
#  'general contractor': 0.0,
#  'general hospital': 1.0,
#  'tool manufacturer': 1.0,
#  'industrial design company': 0.75,
#  'hyundai dealer': 0.0,
#  'glass industry': 1.0,
#  'polymer supplier': 0.0,
#  'printing equipment supply': 0.0,
#  'toner cartridge supplier': 0.4,
#  'printer repair service': 0.25,
#  'fuel supplier': 0.0,
#  'glass manufacturer': 1.0,
#  'plastic bag supplier': 0.909,
#  'glassware manufacturer': 0.25,
#  'polythene plastic sheeting supplier': 0.909,
#  'pvc industry': 0.091,
#  'countertop store': 0.0,
#  'cabinet store': 0.25,
#  'fiberglass supplier': 0.2,
#  'golf cart dealer': 1.0,
#  'auto repair shop': 0.778,
#  'hose supplier': 0.6,
#  'rubber product supplier': 1.0,
#  'automotive': 0.0,
#  'commercial refrigerator supplier': 0.0,
#  'golf club': 1.0,
#  'golf course': 0.667,
#  'green energy supplier': 0.8,
#  'greenhouse': 1.0,
#  'auto glass shop': 0.111,
#  'lighting manufacturer': 1.0,
#  'cement manufacturer': 1.0,
#  'brick manufacturer': 1.0,
#  'natural stone supplier': 0.0,
#  'gym': 0.167,
#  'marble supplier': 0.2,
#  'corporate gift supplier': 1.0,
#  'shipbuilding repair company': 0.0,
#  'construction maintenance office': 1.0,
#  'boiler manufacturer': 0.75,
#  'container supplier': 1.0,
#  'home construction': 1.0,
#  'health': 1.0,
#  'heart hospital': 1.0,
#  'spring supplier': 1.0,
#  'electric utility manufacturer': 0.0,
#  'aircraft manufacturer': 1.0,
#  'metal heat treating service': 1.0,
#  'plating service': 0.333,
#  'automation company': 0.0,
#  'heating contractor': 0.667,
#  'plumbing supply store': 0.0,
#  'gun shop': 0.25,
#  'ammunition supplier': 0.6,
#  'pipe manufacturer': 0.2,
#  'school': 1.0,
#  'fire protection equipment supplier': 0.143,
#  'agricultural machinery manufacturer': 0.4,
#  'lawn mower store': 0.0,
#  'lawn irrigation equipment supplier': 0.333,
#  'financial consultant': 1.0,
#  'helicopter charter': 1.0,
#  'packaging machinery': 0.071,
#  'historical landmark': 1.0,
#  'electronics manufacturer': 0.0,
#  'graphic designer': 0.75,
#  'eye care center': 0.167,
#  'optical product manufacturer': 0.333,
#  'image consultant': 0.25,
#  'cleaning product supplier': 0.0,
#  'fireplace store': 0.0,
#  'home builder': 1.0,
#  'tool die shop': 1.0,
#  'metal stamping service': 0.4,
#  'environmental organization': 1.0,
#  'food processing equipment': 0.0,
#  'loan agency': 0.667,
#  'power plant equipment supplier': 0.0,
#  'home good store': 0.667,
#  'engine rebuilding service': 0.0,
#  'air compressor supplier': 0.214,
#  'honda dealer': 1.0,
#  'elevator manufacturer': 0.071,
#  'crane dealer': 0.0,
#  'crane rental agency': 0.5,
#  'compound building': 0.0,
#  'tractor dealer': 0.0,
#  'furnace part supplier': 0.0,
#  'heating equipment supplier': 0.25,
#  'pneumatic tool supplier': 0.0,
#  'truck stop': 0.5,
#  'computer hardware manufacturer': 1.0,
#  'satellite communication service': 1.0,
#  'hospital': 1.0,
#  'electronics company': 0.5,
#  'electronic part supplier': 0.0,
#  'hvac contractor': 0.667,
#  'industrial engineer': 0.125,
#  'contact lens supplier': 0.667,
#  'information service': 1.0,
#  'building': 1.0,
#  'water work equipment supplier': 0.0,
#  'measuring instrument supplier': 0.889,
#  'scientific equipment supplier': 0.0,
#  'medical center': 0.0,
#  'watch manufacturer': 0.4,
#  'corporate entertainment service': 0.0,
#  'insurance': 1.0,
#  'record company': 0.0,
#  'video duplication service': 0.333,
#  'insurance agency': 1.0,
#  'lighting store': 1.0,
#  'lighting wholesaler': 0.75,
#  'entertainment agency': 0.0,
#  'insurance broker': 1.0,
#  'electrical equipment supplier': 0.0,
#  'electric motor store': 0.0,
#  'railroad company': 1.0,
#  'electrical supply store': 0.0,
#  'insurance company': 1.0,
#  'factory equipment supplier': 0.0,
#  'investment service': 1.0,
#  'laser equipment supplier': 0.0,
#  'executive suite rental agency': 0.333,
#  'truck dealer': 0.0,
#  'motor vehicle dealer': 1.0,
#  'car dealer': 1.0,
#  'truck topper supplier': 0.0,
#  'police supply store': 1.0,
#  'iron steel contractor': 0.25,
#  'fire department equipment supplier': 0.143,
#  'towing equipment provider': 1.0,
#  'logistics service': 0.286,
#  'trailer manufacturer': 1.0,
#  'trailer dealer': 0.0,
#  'dealer': 1.0,
#  'auto spring shop': 0.0,
#  'auto upholsterer': 0.0,
#  'auto body part supplier': 0.0,
#  'car factory': 0.0,
#  'freight forwarding service': 1.0,
#  'brake shop': 0.333,
#  'railroad equipment supplier': 0.0,
#  'jewelry equipment supplier': 0.818,
#  'boat builder': 1.0,
#  'ship building': 1.0,
#  'marine supply store': 0.0,
#  'boat dealer': 1.0,
#  'kawasaki motorcycle dealer': 1.0,
#  'knife manufacturing': 0.0,
#  'labor union': 1.0,
#  'furniture maker': 1.0,
#  'banking finance': 0.5,
#  'furniture manufacturer': 1.0,
#  'logistics': 0.714,
#  'massage supply store': 0.0,
#  'telecommunication equipment supplier': 0.0,
#  'baby store': 0.0,
#  'molding supplier': 0.0,
#  'office equipment supplier': 0.0,
#  'office furniture store': 0.75,
#  'store equipment supplier': 0.0,
#  'laboratory': 0.125,
#  'health beauty shop': 0.2,
#  'learning center': 0.167,
#  'dental laboratory': 0.4,
#  'land surveyor': 0.125,
#  'educational supply store': 0.5,
#  'jewelry store': 0.5,
#  'playground equipment supplier': 0.0,
#  'outdoor sport store': 0.25,
#  'toy store': 0.5,
#  'security service': 0.6,
#  'sign shop': 0.091,
#  'office supply store': 0.5,
#  'landscaper': 0.0,
#  'gasket manufacturer': 0.091,
#  'piano maker': 0.091,
#  'piano store': 0.25,
#  'funeral home': 1.0,
#  'monument': 0.0,
#  'book publisher': 1.0,
#  'wig shop': 0.167,
#  'laundromat': 0.25,
#  'auto wrecker': 0.5,
#  'auto part market': 1.0,
#  'jeep dealer': 1.0,
#  'restaurant supply store': 0.0,
#  'roofing supply store': 0.0,
#  'law firm': 0.25,
#  'building material market': 1.0,
#  'camera store': 0.0,
#  'lawn care service': 0.0,
#  'computer security service': 0.2,
#  'computer store': 0.0,
#  'design agency': 1.0,
#  'diagnostic center': 1.0,
#  'laboratory equipment supplier': 0.111,
#  'home theater store': 0.0,
#  'metal industry supplier': 0.0,
#  'landscaping supply store': 0.0,
#  'appliance part supplier': 0.0,
#  'vacuum cleaner store': 0.5,
#  'audio visual equipment supplier': 1.0,
#  'lawyer': 1.0,
#  'cell phone store': 0.0,
#  'bathroom supply store': 0.0,
#  'leasing service': 1.0,
#  'construction machine dealer': 0.0,
#  'dairy farm equipment supplier': 0.0,
#  'propane supplier': 0.0,
#  'legal service': 1.0,
#  'janitorial equipment supplier': 0.2,
#  'life insurance agency': 1.0,
#  'railroad contractor': 0.0,
#  'swimming pool supply store': 1.0,
#  'light bulb supplier': 1.0,
#  'linen store': 0.0,
#  'metal construction company': 0.833,
#  'local government office': 0.833,
#  'logging contractor': 0.0,
#  'machine shop': 0.667,
#  'hotel supply store': 0.0,
#  'import export company': 0.0,
#  'sewing company': 0.25,
#  'research foundation': 1.0,
#  'machinery part manufacturer': 1.0,
#  'sport accessory wholesaler': 0.0,
#  'fashion designer': 0.5,
#  'cheese manufacturer': 0.2,
#  'cheese shop': 0.2,
#  'shipping mailing': 0.0,
#  'wholesale food store': 0.0,
#  'organic food store': 0.0,
#  'pie shop': 0.167,
#  'auction house': 1.0,
#  'livestock auction house': 0.333,
#  'cotton exporter': 0.429,
#  'plastic wholesaler': 0.0,
#  'mailing service': 0.0,
#  'manufacturer': 0.0,
#  'gas station': 1.0,
#  'beer distributor': 1.0,
#  'alcoholic beverage wholesaler': 1.0,
#  'religious good store': 1.0,
#  'book wholesaler': 0.167,
#  'masonry supply store': 0.25,
#  'wholesale florist': 0.333,
#  'florist': 1.0,
#  'marine engineer': 0.125,
#  'paint store': 0.25,
#  'used auto part store': 0.5,
#  'masonry contractor': 0.5,
#  'used car dealer': 1.0,
#  'used truck dealer': 1.0,
#  'massage therapist': 0.5,
#  'material handling equipment supplier': 0.0,
#  'marina': 1.0,
#  'meat packer': 0.111,
#  'mattress store': 0.0,
#  'blind shop': 0.5,
#  'interior designer': 0.5,
#  'window treatment store': 0.667,
#  'appliance store': 1.0,
#  'health food store': 0.4,
#  'direct mail advertising': 0.75,
#  'meat wholesaler': 0.444,
#  'butcher shop deli': 0.167,
#  'italian grocery store': 0.333,
#  'market': 0.0,
#  'food service': 1.0,
#  'grocery delivery service': 1.0,
#  'wine store': 1.0,
#  'liquor store': 1.0,
#  'kiosk': 0.0,
#  'optometrist': 0.5,
#  'optician': 0.167,
#  'mechanical contractor': 0.667,
#  'mechanical engineer': 0.125,
#  'cafe': 0.5,
#  'jeweler': 0.2,
#  'leather good store': 0.5,
#  'gift shop': 1.0,
#  'craft store': 0.25,
#  'hobby store': 0.75,
#  'fabric wholesaler': 0.0,
#  'scrap metal dealer': 0.0,
#  'quilt shop': 0.0,
#  'sheet music store': 0.25,
#  'musical instrument manufacturer': 0.091,
#  'music store': 0.25,
#  'musical instrument store': 1.0,
#  'band': 0.25,
#  'bookstore': 0.0,
#  'art museum': 1.0,
#  'newsstand': 0.5,
#  'medical equipment manufacturer': 1.0,
#  'fashion accessory store': 0.333,
#  'discount store': 0.0,
#  'cemetery': 0.5,
#  'bus stop': 1.0,
#  'variety store': 0.0,
#  'thrift store': 1.0,
#  'medical group': 0.0,
#  'donation center': 0.0,
#  'pet store': 1.0,
#  'art gallery': 0.2,
#  'art dealer': 0.4,
#  'housing development': 1.0,
#  'mobile home dealer': 0.4,
#  'convenience store': 1.0,
#  'medical office': 0.0,
#  'medical technology manufacturer': 0.2,
#  'childrens furniture store': 1.0,
#  'mental health clinic': 0.333,
#  'airline': 0.0,
#  'aviation consultant': 0.0,
#  'travel agency': 1.0,
#  'travel service': 1.0,
#  'airport': 0.667,
#  'mental health service': 0.333,
#  'shipping company': 0.0,
#  'metal fabricator': 1.0,
#  'cruise line company': 0.0,
#  'towing service': 1.0,
#  'ferry terminal': 0.25,
#  'ferry service': 0.0,
#  'metal finisher': 1.0,
#  'boat tour agency': 1.0,
#  'bus company': 1.0,
#  'moving company': 0.333,
#  'moving storage service': 0.333,
#  'state department transportation': 0.0,
#  'department transportation': 0.0,
#  'handicapped transportation service': 1.0,
#  'railway service': 0.0,
#  'train station': 0.0,
#  'bus depot': 1.0,
#  'bus charter': 1.0,
#  'metal processing company': 1.0,
#  'mixed use': 0.0,
#  'motorcycle shop': 0.667,
#  'limousine service': 1.0,
#  'chauffeur service': 0.0,
#  'school bus service': 1.0,
#  'airport shuttle service': 1.0,
#  'tourist information center': 0.0,
#  'carriage ride service': 0.0,
#  'cruise agency': 0.5,
#  'tourist attraction': 0.25,
#  'ski resort': 0.833,
#  'ski area': 0.167,
#  'fixed base operator': 0.0,
#  'aircraft maintenance company': 0.333,
#  'motorsports store': 0.0,
#  'boat rental service': 1.0,
#  'utility trailer dealer': 0.0,
#  'forklift dealer': 0.0,
#  'municipal administration office': 0.0,
#  'nephrologist': 0.0,
#  'bus coach company': 1.0,
#  'shipping service': 0.0,
#  'shipping mailing service': 0.0,
#  'newspaper publisher': 1.0,
#  'shredding service': 0.0,
#  'nuclear power company': 0.9,
#  'nursing home': 1.0,
#  'medium company': 0.25,
#  'multimedia electronic book publisher': 0.0,
#  'internet marketing service': 0.125,
#  'greeting card shop': 0.5,
#  'theme park': 1.0,
#  'film production company': 0.167,
#  'obstetrician gynecologist': 0.5,
#  'movie studio': 0.0,
#  'video production service': 0.5,
#  'movie theater': 0.833,
#  'theater company': 0.75,
#  'performing art theater': 1.0,
#  'occupational safety health': 0.0,
#  'office space rental agency': 0.0,
#  'commercial real estate agency': 1.0,
#  'art school': 0.333,
#  'music publisher': 0.5,
#  'printed music publisher': 0.25,
#  'home audio store': 0.0,
#  'musician': 0.25,
#  'music management promotion': 0.0,
#  'video editing service': 0.333,
#  'office supply wholesaler': 0.667,
#  'official residence': 0.25,
#  'orthopedic clinic': 1.0,
#  'painter': 0.0,
#  'painting': 0.833,
#  'telephone company': 0.0,
#  'medium house': 0.625,
#  'paper distributor': 0.0,
#  'news service': 0.5,
#  'public library': 0.0,
#  'law library': 1.0,
#  'museum': 1.0,
#  'federal reserve bank': 1.0,
#  'credit union': 0.5,
#  'atm': 0.333,
#  'paving contractor': 1.0,
#  'mortgage lender': 1.0,
#  'investment bank': 0.0,
#  'check cashing service': 0.667,
#  'stock broker': 0.0,
#  'health consultant': 0.0,
#  'health insurance agency': 1.0,
#  'payroll service': 1.0,
#  'pediatrician': 1.0,
#  'human resource consulting': 1.0,
#  'pest control service': 0.8,
#  'pet boarding service': 1.0,
#  'pet care': 0.2,
#  'loss adjuster': 0.5,
#  'pharmaceutical company': 1.0,
#  'pharmaceutical product wholesaler': 1.0,
#  'pharmacy': 0.2,
#  'educational institution': 1.0,
#  'retirement community': 1.0,
#  'fraternal organization': 1.0,
#  'photo lab': 0.0,
#  'property investment': 0.0,
#  'photographer': 0.167,
#  'photography school': 0.333,
#  'star hotel': 1.0,
#  'convention center': 0.25,
#  'real estate appraiser': 1.0,
#  'photography service': 0.333,
#  'resort hotel': 1.0,
#  'real estate consultant': 1.0,
#  'car rental agency': 1.0,
#  'car leasing service': 1.0,
#  'ford dealer': 1.0,
#  'car finance loan company': 0.714,
#  'trailer rental service': 0.667,
#  'furniture rental service': 0.833,
#  'tuxedo shop': 0.0,
#  'dress tuxedo rental service': 1.0,
#  'wedding store': 0.0,
#  'video store': 0.5,
#  'movie rental': 0.0,
#  'photography studio': 0.333,
#  'home health care service': 1.0,
#  'skateboard shop': 0.0,
#  'event technology service': 0.0,
#  'party equipment rental service': 1.0,
#  'construction machine rental service': 0.5,
#  'audio visual equipment rental service': 0.0,
#  'shipping equipment industry': 0.0,
#  'physical therapy clinic': 0.5,
#  'plastic fabrication company': 0.909,
#  'plastic product supplier': 0.909,
#  'auto tag agency': 0.4,
#  'department motor vehicle': 0.0,
#  'notary public': 0.75,
#  'private investigator': 0.0,
#  'escrow service': 0.0,
#  'real estate agent': 1.0,
#  'playground': 0.0,
#  'plumber': 0.333,
#  'port authority': 1.0,
#  'portrait studio': 0.333,
#  'post office': 1.0,
#  'professional service': 0.667,
#  'university hospital': 1.0,
#  'public relation firm': 0.625,
#  'civil engineering company': 1.0,
#  'drafting service': 0.875,
#  'pump supplier': 0.714,
#  'interior construction contractor': 0.0,
#  'carpet cleaning service': 1.0,
#  'exhibition planner': 0.0,
#  'decal supplier': 0.0,
#  'stage lighting equipment supplier': 1.0,
#  'event management company': 0.333,
#  'radio broadcaster': 0.0,
#  'computer support service': 1.0,
#  'ravine': 0.0,
#  'employment center': 0.75,
#  'national health foundation': 0.333,
#  'real estate developer': 0.0,
#  'advertising agency': 1.0,
#  'promotional product supplier': 0.0,
#  'advertising service': 1.0,
#  'record storage facility': 0.0,
#  'fund management company': 0.0,
#  'recreation center': 1.0,
#  'bakery': 1.0,
#  'database management company': 0.0,
#  'market researcher': 0.0,
#  'recycling center': 0.0,
#  'regional government office': 0.667,
#  'rehabilitation center': 0.0,
#  'religious institution': 1.0,
#  'religious organization': 1.0,
#  'repair service': 0.8,
#  'emergency veterinarian service': 0.333,
#  'pet sitter': 0.2,
#  'research product development': 1.0,
#  'building society': 1.0,
#  'valet parking service': 1.0,
#  'nursing agency': 1.0,
#  'executive search firm': 0.5,
#  'recruiter': 0.0,
#  'temp agency': 0.25,
#  'health center': 0.0,
#  'restaurant': 1.0,
#  'roofing contractor': 0.5,
#  'sport nutrition store': 0.2,
#  'credit reporting agency': 0.2,
#  'automobile storage facility': 1.0,
#  'debt collection agency': 0.3,
#  'park': 0.0,
#  'court reporter': 0.4,
#  'bus tour agency': 0.25,
#  'tour operator': 1.0,
#  'convention information bureau': 0.25,
#  'balloon ride tour agency': 1.0,
#  'security guard service': 1.0,
#  'locksmith': 0.4,
#  'commercial cleaning service': 0.6,
#  'blast cleaning service': 0.6,
#  'conference center': 0.0,
#  'safety equipment supplier': 0.0,
#  'garbage dump': 1.0,
#  'sanitation service': 0.2,
#  'garbage dump service': 0.0,
#  'environmental health service': 0.143,
#  'portable toilet supplier': 0.5,
#  'public work department': 0.0,
#  'school district office': 1.0,
#  'sailmaker': 0.0,
#  'community college': 1.0,
#  'salvage yard': 0.25,
#  'business school': 0.0,
#  'trade school': 1.0,
#  'private university': 1.0,
#  'computer training school': 0.667,
#  'school supply store': 0.0,
#  'screen printer': 1.0,
#  'medium consultant': 0.625,
#  'beauty school': 1.0,
#  'flight school': 1.0,
#  'seaport': 0.0,
#  'security system supplier': 0.6,
#  'middle school': 1.0,
#  'nonprofit': 0.0,
#  'shooting range': 0.167,
#  'soccer club': 0.333,
#  'camp': 1.0,
#  'diving contractor': 0.0,
#  'language school': 0.833,
#  'english language school': 0.833,
#  'preschool': 1.0,
#  'self storage facility': 0.25,
#  'semi conductor supplier': 0.0,
#  'driving school': 0.833,
#  'trucking school': 0.167,
#  'senior citizen center': 0.0,
#  'service': 0.0,
#  'childrens hospital': 1.0,
#  'dental supply store': 0.2,
#  'shipyard': 1.0,
#  'orthodox synagogue': 1.0,
#  'short term apartment rental agency': 0.0,
#  'nutritionist': 0.167,
#  'ophthalmologist': 0.0,
#  'ophthalmology clinic': 0.167,
#  'social service organization': 1.0,
#  'social welfare center': 1.0,
#  'solar energy company': 0.8,
#  'solar energy equipment supplier': 0.8,
#  'special education school': 1.0,
#  'podiatrist': 0.333,
#  'reproductive health clinic': 0.833,
#  'sporting good store': 0.75,
#  'dialysis center': 0.833,
#  'sport complex': 0.333,
#  'wellness program': 0.0,
#  'sportswear store': 0.0,
#  'private hospital': 1.0,
#  'radiologist': 0.0,
#  'medical diagnostic imaging center': 1.0,
#  'ray lab': 1.0,
#  'blood bank': 0.667,
#  'stainless steel plant': 1.0,
#  'state agency': 0.333,
#  'heliport': 0.0,
#  'health care company': 0.0,
#  'psychiatric hospital': 1.0,
#  'state government office': 0.833,
#  'medical institution': 1.0,
#  'steel construction company': 0.125,
#  'cleaning service': 0.6,
#  ...}

# %%
calc_avg_pre(ret_docs_dic, queries_dic, cutoff=-1)[0]
# Out:
# {'home improvement store': 0.025,
#  'diesel fuel supplier': 0.0,
#  'church': 1.0,
#  'farm': 1.0,
#  'seed supplier': 0.0,
#  'accountant': 1.0,
#  'trucking company': 0.478,
#  'exporter': 0.143,
#  'grain elevator': 0.036,
#  'popcorn store': 0.333,
#  'agricultural service': 0.0,
#  'warehouse': 0.525,
#  'agricultural production': 0.014,
#  'ranch': 0.081,
#  'holding company': 1.0,
#  'farm equipment supplier': 0.0,
#  'store': 0.0,
#  'grocery store': 0.6,
#  'rice mill': 0.238,
#  'food product supplier': 0.0,
#  'accounting firm': 1.0,
#  'produce market': 0.319,
#  'pet supply store': 0.927,
#  'wholesaler': 0.0,
#  'produce wholesaler': 0.0,
#  'distribution service': 0.0,
#  'crop grower': 0.471,
#  'addiction treatment center': 0.0,
#  'natural good store': 0.0,
#  'orchard': 0.185,
#  'lumber store': 0.0,
#  'mine': 0.771,
#  'transportation service': 0.25,
#  'investment company': 0.0,
#  'fruit wholesaler': 0.083,
#  'real estate agency': 0.2,
#  'event venue': 0.0,
#  'frozen dessert supplier': 0.327,
#  'wine wholesaler importer': 1.0,
#  'winery': 1.0,
#  'aerospace company': 0.544,
#  'cold storage facility': 1.0,
#  'employment agency': 0.95,
#  'plant nursery': 0.167,
#  'air conditioning contractor': 0.667,
#  'air conditioning repair service': 0.0,
#  'fruit vegetable wholesaler': 0.033,
#  'aircraft rental service': 0.0,
#  'monastery': 1.0,
#  'allergist': 0.5,
#  'herb shop': 0.0,
#  'aluminum supplier': 1.0,
#  'ambulance service': 0.042,
#  'wholesale plant nursery': 0.533,
#  'amusement machine supplier': 1.0,
#  'animal hospital': 0.0,
#  'farmer market': 0.319,
#  'vaporizer store': 0.927,
#  'cigar shop': 0.029,
#  'tobacco shop': 0.0,
#  'well drilling contractor': 0.04,
#  'library': 0.75,
#  'apartment building': 0.0,
#  'apartment rental agency': 0.0,
#  'dairy farm': 0.042,
#  'architect': 0.25,
#  'organic farm': 0.0,
#  'architectural designer': 0.204,
#  'architecture firm': 0.0,
#  'livestock producer': 0.0,
#  'dairy supplier': 0.0,
#  'biotechnology company': 0.5,
#  'artist': 0.2,
#  'egg supplier': 1.0,
#  'poultry farm': 0.031,
#  'chicken hatchery': 0.8,
#  'art organization': 0.458,
#  'association organization': 0.825,
#  'food store': 0.325,
#  'deli': 0.0,
#  'bank': 0.292,
#  'fish processing': 0.5,
#  'fish farm': 0.111,
#  'seafood wholesaler': 0.241,
#  'tropical fish store': 0.623,
#  'non profit organization': 0.0,
#  'economic development agency': 0.304,
#  'seafood market': 0.139,
#  'honey farm': 0.133,
#  'horse breeder': 0.208,
#  'asphalt contractor': 0.292,
#  'livestock dealer': 0.0,
#  'department store': 1.0,
#  'mill': 0.0,
#  'atv dealer': 0.917,
#  'audio visual consultant': 0.25,
#  'pallet supplier': 0.343,
#  'wood supplier': 0.0,
#  'hardware store': 0.25,
#  'furniture wholesaler': 0.083,
#  'auditor': 0.25,
#  'oil natural gas company': 0.15,
#  'auto body shop': 0.222,
#  'boat repair shop': 0.083,
#  'association': 0.6,
#  'railing contractor': 0.0,
#  'publisher': 1.0,
#  'pond supply store': 0.0,
#  'agriculture cooperative': 0.0,
#  'printing equipment supplier': 0.033,
#  'auto insurance agency': 0.893,
#  'alternative fuel station': 1.0,
#  'auto part manufacturer': 0.0,
#  'foundation': 0.554,
#  'fertilizer supplier': 1.0,
#  'farming company': 0.0,
#  'finance broker': 0.042,
#  'agricultural cooperative': 0.0,
#  'fire station': 0.048,
#  'environmental consultant': 0.271,
#  'civil engineer': 0.5,
#  'fire protection service': 0.143,
#  'gas company': 0.5,
#  'oilfield': 0.0,
#  'banquet hall': 0.333,
#  'mining company': 0.054,
#  'coalfield': 0.0,
#  'steel fabricator': 0.0,
#  'quarry': 0.0,
#  'gold mining company': 0.583,
#  'high rise building': 0.5,
#  'basketball club': 0.111,
#  'gold dealer': 0.0,
#  'battery manufacturer': 0.458,
#  'electric utility company': 0.0,
#  'environmental program': 0.0,
#  'office': 0.0,
#  'stone supplier': 0.05,
#  'aggregate supplier': 0.0,
#  'sand gravel supplier': 0.139,
#  'building material supplier': 1.0,
#  'beauty supply store': 0.486,
#  'crushed stone supplier': 0.036,
#  'rock shop': 0.0,
#  'road construction company': 1.0,
#  'marketing consultant': 0.238,
#  'blood testing service': 0.326,
#  'contractor': 0.5,
#  'excavating contractor': 0.75,
#  'asphalt mixing plant': 0.4,
#  'ready mix concrete supplier': 0.553,
#  'sand plant': 0.061,
#  'bmw dealer': 0.333,
#  'bookbinder': 0.0,
#  'garden center': 0.833,
#  'abrasive supplier': 1.0,
#  'granite supplier': 0.067,
#  'drilling contractor': 0.0,
#  'bpo company': 0.045,
#  'oil gas exploration service': 0.563,
#  'building complex': 0.0,
#  'construction equipment supplier': 0.0,
#  'mining equipment': 0.0,
#  'bus ticket agency': 0.036,
#  'business center': 0.017,
#  'skyscraper': 0.0,
#  'software company': 1.0,
#  'business development service': 0.0,
#  'business management consultant': 0.143,
#  'cabinet maker': 0.679,
#  'call center': 0.2,
#  'cancer treatment center': 0.0,
#  'power plant consultant': 0.0,
#  'business park': 0.0,
#  'petroleum product company': 0.156,
#  'parking lot': 0.333,
#  'water utility company': 1.0,
#  'car repair maintenance': 0.778,
#  'water treatment plant': 1.0,
#  'car service': 0.056,
#  'cattle market': 0.048,
#  'sewage disposal service': 1.0,
#  'certified public accountant': 0.5,
#  'government office': 0.637,
#  'charity': 0.333,
#  'air conditioning system supplier': 0.0,
#  'chemical industry': 0.389,
#  'chemical manufacturer': 0.509,
#  'title company': 0.083,
#  'chemical plant': 0.509,
#  'property management company': 0.0,
#  'custom home builder': 0.625,
#  'window installation service': 0.0,
#  'fire damage restoration service': 0.0,
#  'equipment rental agency': 0.081,
#  'chemical wholesaler': 0.5,
#  'financial planner': 0.927,
#  'telecommunication service provider': 0.417,
#  'energy equipment solution': 0.0,
#  'chiropractor': 0.5,
#  'steel distributor': 0.0,
#  'city government office': 0.715,
#  'crane service': 0.036,
#  'garage door supplier': 0.019,
#  'industrial door supplier': 0.042,
#  'city town hall': 0.167,
#  'clothing wholesaler': 0.087,
#  'coin operated laundry equipment supplier': 1.0,
#  'metal supplier': 0.0,
#  'glass shop': 0.0,
#  'college': 1.0,
#  'siding contractor': 0.276,
#  'commercial printer': 0.031,
#  'storage facility': 1.0,
#  'communication tower': 0.083,
#  'janitorial service': 0.46,
#  'computer consultant': 0.287,
#  'fire protection system supplier': 0.179,
#  'elevator service': 0.071,
#  'industrial equipment supplier': 0.0,
#  'dry wall contractor': 0.194,
#  'insulation contractor': 0.214,
#  'concrete contractor': 0.466,
#  'scaffolding rental service': 0.078,
#  'construction company': 1.0,
#  'flooring store': 0.048,
#  'flooring contractor': 0.407,
#  'tile contractor': 0.477,
#  'tile manufacturer': 0.042,
#  'glass mirror shop': 0.0,
#  'construction material wholesaler': 0.333,
#  'gutter cleaning service': 0.52,
#  'sheet metal contractor': 0.574,
#  'consultant': 0.048,
#  'container service': 0.078,
#  'septic system service': 0.375,
#  'corporate campus': 0.111,
#  'water damage restoration service': 0.0,
#  'welder': 0.0,
#  'corporate office': 0.167,
#  'animal': 1.0,
#  'animal feed store': 0.09,
#  'animal protection organization': 0.0,
#  'brewing supply store': 0.0,
#  'cosmetic store': 0.52,
#  'county government office': 0.73,
#  'sugar factory': 0.825,
#  'confectionery wholesaler': 0.14,
#  'financial institution': 0.0,
#  'candy store': 0.122,
#  'confectionery': 0.079,
#  'chocolate factory': 0.927,
#  'chocolate shop': 0.839,
#  'courier service': 1.0,
#  'coworking space': 0.042,
#  'frozen food manufacturer': 0.4,
#  'beverage distributor': 0.0,
#  'agricultural organization': 0.0,
#  'dairy store': 0.0,
#  'dairy': 0.196,
#  'ice cream shop': 0.24,
#  'medical laboratory': 1.0,
#  'demolition contractor': 0.75,
#  'meat processor': 0.95,
#  'fmcg manufacturer': 0.0,
#  'garbage collection service': 0.667,
#  'wholesale bakery': 0.806,
#  'dentist': 0.167,
#  'dessert shop': 0.0,
#  'cupcake shop': 0.0,
#  'nut store': 0.417,
#  'wholesale grocer': 0.136,
#  'design engineer': 0.059,
#  'business business service': 0.375,
#  'condiment supplier': 1.0,
#  'digital printing service': 1.0,
#  'culinary school': 0.733,
#  'importer': 0.0,
#  'bottled water supplier': 0.042,
#  'coffee roaster': 0.555,
#  'packaging supply store': 0.0,
#  'ice supplier': 0.78,
#  'brewery': 1.0,
#  'winemaking company': 0.0,
#  'distillery': 1.0,
#  'disability service support organisation': 0.5,
#  'district government office': 0.549,
#  'air filter supplier': 0.54,
#  'tire shop': 0.5,
#  'fastener supplier': 0.351,
#  'fabric product manufacturer': 0.267,
#  'textile': 0.267,
#  'textile exporter': 0.267,
#  'textile engineer': 0.267,
#  'fabric store': 0.0,
#  'knit shop': 0.083,
#  'doctor': 1.0,
#  'lamination service': 0.0,
#  'plastic resin manufacturer': 0.333,
#  'carpet manufacturer': 0.643,
#  'upholstery shop': 0.0,
#  'business administration service': 0.0,
#  'furniture store': 1.0,
#  'dry cleaner': 0.0,
#  'packaging company': 0.111,
#  'duty free store': 0.927,
#  'commerce service': 0.0,
#  'cable company': 0.0,
#  'education': 0.167,
#  'outlet store': 0.0,
#  'lingerie store': 0.056,
#  'clothes fabric manufacturer': 0.267,
#  'education center': 0.0,
#  'uniform store': 0.028,
#  'men clothing store': 1.0,
#  'clothing store': 1.0,
#  'woman clothing store': 1.0,
#  'western apparel store': 0.0,
#  'costume store': 0.0,
#  'game store': 0.146,
#  'hat shop': 0.0,
#  'leather good manufacturer': 0.1,
#  'educational consultant': 1.0,
#  'leather exporter': 1.0,
#  'shoe store': 1.0,
#  'boutique': 0.0,
#  'leather wholesaler': 0.1,
#  'handbag shop': 0.1,
#  'electronics store': 0.292,
#  'luggage store': 0.5,
#  'building material store': 0.28,
#  'saw mill': 0.0,
#  'electrical engineer': 0.0,
#  'deck builder': 0.017,
#  'concrete product supplier': 0.967,
#  'plywood supplier': 1.0,
#  'electrical installation service': 0.0,
#  'truss manufacturer': 0.333,
#  'door supplier': 0.024,
#  'wood laminate flooring supplier': 1.0,
#  'aircraft supply store': 0.0,
#  'modular home builder': 0.0,
#  'portable building manufacturer': 0.0,
#  'modular home dealer': 0.069,
#  'mulch supplier': 0.0,
#  'electrician': 0.111,
#  'paper mill': 0.793,
#  'energy supplier': 0.8,
#  'engineer': 0.125,
#  'print shop': 0.121,
#  'custom label printer': 0.417,
#  'marketing': 0.324,
#  'marketing agency': 0.014,
#  'engineering consultant': 0.321,
#  'entertainer': 0.0,
#  'envelope supplier': 0.071,
#  'oil refinery': 0.24,
#  'recording studio': 1.0,
#  'environment renewable natural resource': 0.0,
#  'finishing material supplier': 0.0,
#  'event ticket seller': 0.0,
#  'waterproofing company': 0.0,
#  'auto part store': 0.0,
#  'heating oil supplier': 0.125,
#  'family practice physician': 1.0,
#  'machining manufacturer': 0.0,
#  'industrial gas supplier': 0.0,
#  'welding supply store': 0.0,
#  'dry ice supplier': 0.317,
#  'private equity firm': 0.0,
#  'family service center': 0.167,
#  'federal government office': 0.674,
#  'vitamin supplement store': 0.4,
#  'feed manufacturer': 1.0,
#  'medical equipment supplier': 0.0,
#  'medical supply store': 0.0,
#  'medical clinic': 0.183,
#  'research institute': 1.0,
#  'biochemical supplier': 0.0,
#  'fiber optic product supplier': 0.125,
#  'paint manufacturer': 0.833,
#  'equipment supplier': 0.0,
#  'food': 0.0,
#  'pipe supplier': 0.223,
#  'oil field equipment supplier': 0.3,
#  'food broker': 0.0,
#  'food manufacturer': 0.174,
#  'food processing company': 0.016,
#  'fence supply store': 0.031,
#  'food producer': 0.0,
#  'forestry service': 1.0,
#  'foundry': 1.0,
#  'wholesale jeweler': 0.1,
#  'cookie shop': 0.167,
#  'truck rental agency': 0.262,
#  'fruit vegetable processing': 0.463,
#  'kitchen supply store': 0.0,
#  'hydraulic equipment supplier': 0.0,
#  'irrigation equipment supplier': 0.333,
#  'bearing supplier': 0.173,
#  'metallurgy company': 0.2,
#  'plastic injection molding service': 0.0,
#  'general contractor': 0.0,
#  'general hospital': 0.5,
#  'tool manufacturer': 1.0,
#  'industrial design company': 0.308,
#  'hyundai dealer': 0.0,
#  'glass industry': 1.0,
#  'polymer supplier': 0.0,
#  'printing equipment supply': 0.0,
#  'toner cartridge supplier': 0.3,
#  'printer repair service': 0.062,
#  'fuel supplier': 0.0,
#  'glass manufacturer': 1.0,
#  'plastic bag supplier': 0.909,
#  'glassware manufacturer': 0.125,
#  'polythene plastic sheeting supplier': 0.909,
#  'pvc industry': 0.03,
#  'countertop store': 0.0,
#  'cabinet store': 0.036,
#  'fiberglass supplier': 0.1,
#  'golf cart dealer': 0.917,
#  'auto repair shop': 0.744,
#  'hose supplier': 0.42,
#  'rubber product supplier': 1.0,
#  'automotive': 0.0,
#  'commercial refrigerator supplier': 0.0,
#  'golf club': 0.649,
#  'golf course': 0.456,
#  'green energy supplier': 0.8,
#  'greenhouse': 1.0,
#  'auto glass shop': 0.022,
#  'lighting manufacturer': 1.0,
#  'cement manufacturer': 1.0,
#  'brick manufacturer': 1.0,
#  'natural stone supplier': 0.0,
#  'gym': 0.167,
#  'marble supplier': 0.1,
#  'corporate gift supplier': 1.0,
#  'shipbuilding repair company': 0.0,
#  'construction maintenance office': 1.0,
#  'boiler manufacturer': 0.75,
#  'container supplier': 0.917,
#  'home construction': 0.35,
#  'health': 0.163,
#  'heart hospital': 0.5,
#  'spring supplier': 1.0,
#  'electric utility manufacturer': 0.0,
#  'aircraft manufacturer': 0.841,
#  'metal heat treating service': 1.0,
#  'plating service': 0.333,
#  'automation company': 0.0,
#  'heating contractor': 0.667,
#  'plumbing supply store': 0.0,
#  'gun shop': 0.062,
#  'ammunition supplier': 0.6,
#  'pipe manufacturer': 0.15,
#  'school': 0.5,
#  'fire protection equipment supplier': 0.143,
#  'agricultural machinery manufacturer': 0.078,
#  'lawn mower store': 0.0,
#  'lawn irrigation equipment supplier': 0.083,
#  'financial consultant': 0.927,
#  'helicopter charter': 0.331,
#  'packaging machinery': 0.024,
#  'historical landmark': 1.0,
#  'electronics manufacturer': 0.0,
#  'graphic designer': 0.688,
#  'eye care center': 0.024,
#  'optical product manufacturer': 0.111,
#  'image consultant': 0.25,
#  'cleaning product supplier': 0.0,
#  'fireplace store': 0.0,
#  'home builder': 0.625,
#  'tool die shop': 0.9,
#  'metal stamping service': 0.24,
#  'environmental organization': 0.639,
#  'food processing equipment': 0.0,
#  'loan agency': 0.222,
#  'power plant equipment supplier': 0.0,
#  'home good store': 0.244,
#  'engine rebuilding service': 0.0,
#  'air compressor supplier': 0.109,
#  'honda dealer': 0.333,
#  'elevator manufacturer': 0.071,
#  'crane dealer': 0.0,
#  'crane rental agency': 0.097,
#  'compound building': 0.0,
#  'tractor dealer': 0.0,
#  'furnace part supplier': 0.0,
#  'heating equipment supplier': 0.025,
#  'pneumatic tool supplier': 0.0,
#  'truck stop': 0.5,
#  'computer hardware manufacturer': 0.478,
#  'satellite communication service': 0.143,
#  'hospital': 0.333,
#  'electronics company': 0.125,
#  'electronic part supplier': 0.0,
#  'hvac contractor': 0.667,
#  'industrial engineer': 0.062,
#  'contact lens supplier': 0.3,
#  'information service': 0.917,
#  'building': 0.583,
#  'water work equipment supplier': 0.0,
#  'measuring instrument supplier': 0.808,
#  'scientific equipment supplier': 0.0,
#  'medical center': 0.0,
#  'watch manufacturer': 0.2,
#  'corporate entertainment service': 0.0,
#  'insurance': 0.678,
#  'record company': 0.0,
#  'video duplication service': 0.131,
#  'insurance agency': 0.893,
#  'lighting store': 0.85,
#  'lighting wholesaler': 0.75,
#  'entertainment agency': 0.0,
#  'insurance broker': 0.812,
#  'electrical equipment supplier': 0.0,
#  'electric motor store': 0.0,
#  'railroad company': 1.0,
#  'electrical supply store': 0.0,
#  'insurance company': 0.678,
#  'factory equipment supplier': 0.0,
#  'investment service': 0.927,
#  'laser equipment supplier': 0.0,
#  'executive suite rental agency': 0.065,
#  'truck dealer': 0.0,
#  'motor vehicle dealer': 0.325,
#  'car dealer': 0.5,
#  'truck topper supplier': 0.0,
#  'police supply store': 0.876,
#  'iron steel contractor': 0.077,
#  'fire department equipment supplier': 0.02,
#  'towing equipment provider': 1.0,
#  'logistics service': 0.093,
#  'trailer manufacturer': 1.0,
#  'trailer dealer': 0.0,
#  'dealer': 0.917,
#  'auto spring shop': 0.0,
#  'auto upholsterer': 0.0,
#  'auto body part supplier': 0.0,
#  'car factory': 0.0,
#  'freight forwarding service': 0.25,
#  'brake shop': 0.077,
#  'railroad equipment supplier': 0.0,
#  'jewelry equipment supplier': 0.643,
#  'boat builder': 0.833,
#  'ship building': 1.0,
#  'marine supply store': 0.0,
#  'boat dealer': 0.867,
#  'kawasaki motorcycle dealer': 0.917,
#  'knife manufacturing': 0.0,
#  'labor union': 1.0,
#  'furniture maker': 0.933,
#  'banking finance': 0.183,
#  'furniture manufacturer': 0.933,
#  'logistics': 0.305,
#  'massage supply store': 0.0,
#  'telecommunication equipment supplier': 0.0,
#  'baby store': 0.0,
#  'molding supplier': 0.0,
#  'office equipment supplier': 0.0,
#  'office furniture store': 0.399,
#  'store equipment supplier': 0.0,
#  'laboratory': 0.021,
#  'health beauty shop': 0.1,
#  'learning center': 0.042,
#  'dental laboratory': 0.3,
#  'land surveyor': 0.062,
#  'educational supply store': 0.125,
#  'jewelry store': 0.5,
#  'playground equipment supplier': 0.0,
#  'outdoor sport store': 0.083,
#  'toy store': 0.133,
#  'security service': 0.247,
#  'sign shop': 0.091,
#  'office supply store': 0.5,
#  'landscaper': 0.0,
#  'gasket manufacturer': 0.091,
#  'piano maker': 0.015,
#  'piano store': 0.05,
#  'funeral home': 1.0,
#  'monument': 0.0,
#  'book publisher': 0.697,
#  'wig shop': 0.167,
#  'laundromat': 0.25,
#  'auto wrecker': 0.071,
#  'auto part market': 0.367,
#  'jeep dealer': 0.333,
#  'restaurant supply store': 0.0,
#  'roofing supply store': 0.0,
#  'law firm': 0.25,
#  'building material market': 1.0,
#  'camera store': 0.0,
#  'lawn care service': 0.0,
#  'computer security service': 0.02,
#  'computer store': 0.0,
#  'design agency': 0.917,
#  'diagnostic center': 0.75,
#  'laboratory equipment supplier': 0.037,
#  'home theater store': 0.0,
#  'metal industry supplier': 0.0,
#  'landscaping supply store': 0.0,
#  'appliance part supplier': 0.0,
#  'vacuum cleaner store': 0.167,
#  'audio visual equipment supplier': 0.5,
#  'lawyer': 1.0,
#  'cell phone store': 0.0,
#  'bathroom supply store': 0.0,
#  'leasing service': 0.567,
#  'construction machine dealer': 0.0,
#  'dairy farm equipment supplier': 0.0,
#  'propane supplier': 0.0,
#  'legal service': 0.729,
#  'janitorial equipment supplier': 0.067,
#  'life insurance agency': 0.653,
#  'railroad contractor': 0.0,
#  'swimming pool supply store': 0.876,
#  'light bulb supplier': 0.692,
#  'linen store': 0.0,
#  'metal construction company': 0.38,
#  'local government office': 0.674,
#  'logging contractor': 0.0,
#  'machine shop': 0.417,
#  'hotel supply store': 0.0,
#  'import export company': 0.0,
#  'sewing company': 0.25,
#  'research foundation': 0.679,
#  'machinery part manufacturer': 1.0,
#  'sport accessory wholesaler': 0.0,
#  'fashion designer': 0.3,
#  'cheese manufacturer': 0.2,
#  'cheese shop': 0.2,
#  'shipping mailing': 0.0,
#  'wholesale food store': 0.0,
#  'organic food store': 0.0,
#  'pie shop': 0.056,
#  'auction house': 0.545,
#  'livestock auction house': 0.067,
#  'cotton exporter': 0.167,
#  'plastic wholesaler': 0.0,
#  'mailing service': 0.0,
#  'manufacturer': 0.0,
#  'gas station': 0.7,
#  'beer distributor': 0.417,
#  'alcoholic beverage wholesaler': 0.174,
#  'religious good store': 1.0,
#  'book wholesaler': 0.017,
#  'masonry supply store': 0.031,
#  'wholesale florist': 0.15,
#  'florist': 1.0,
#  'marine engineer': 0.018,
#  'paint store': 0.062,
#  'used auto part store': 0.056,
#  'masonry contractor': 0.27,
#  'used car dealer': 0.75,
#  'used truck dealer': 0.75,
#  'massage therapist': 0.5,
#  'material handling equipment supplier': 0.0,
#  'marina': 1.0,
#  'meat packer': 0.019,
#  'mattress store': 0.0,
#  'blind shop': 0.5,
#  'interior designer': 0.375,
#  'window treatment store': 0.667,
#  'appliance store': 0.75,
#  'health food store': 0.233,
#  'direct mail advertising': 0.504,
#  'meat wholesaler': 0.145,
#  'butcher shop deli': 0.167,
#  'italian grocery store': 0.07,
#  'market': 0.0,
#  'food service': 1.0,
#  'grocery delivery service': 0.5,
#  'wine store': 1.0,
#  'liquor store': 1.0,
#  'kiosk': 0.0,
#  'optometrist': 0.5,
#  'optician': 0.028,
#  'mechanical contractor': 0.667,
#  'mechanical engineer': 0.125,
#  'cafe': 0.098,
#  'jeweler': 0.2,
#  'leather good store': 0.125,
#  'gift shop': 0.833,
#  'craft store': 0.042,
#  'hobby store': 0.249,
#  'fabric wholesaler': 0.0,
#  'scrap metal dealer': 0.0,
#  'quilt shop': 0.0,
#  'sheet music store': 0.083,
#  'musical instrument manufacturer': 0.009,
#  'music store': 0.042,
#  'musical instrument store': 1.0,
#  'band': 0.042,
#  'bookstore': 0.0,
#  'art museum': 1.0,
#  'newsstand': 0.5,
#  'medical equipment manufacturer': 0.712,
#  'fashion accessory store': 0.333,
#  'discount store': 0.0,
#  'cemetery': 0.5,
#  'bus stop': 0.317,
#  'variety store': 0.0,
#  'thrift store': 1.0,
#  'medical group': 0.0,
#  'donation center': 0.0,
#  'pet store': 1.0,
#  'art gallery': 0.2,
#  'art dealer': 0.069,
#  'housing development': 0.5,
#  'mobile home dealer': 0.111,
#  'convenience store': 0.6,
#  'medical office': 0.0,
#  'medical technology manufacturer': 0.067,
#  'childrens furniture store': 1.0,
#  'mental health clinic': 0.067,
#  'airline': 0.0,
#  'aviation consultant': 0.0,
#  'travel agency': 1.0,
#  'travel service': 1.0,
#  'airport': 0.667,
#  'mental health service': 0.2,
#  'shipping company': 0.0,
#  'metal fabricator': 0.522,
#  'cruise line company': 0.0,
#  'towing service': 1.0,
#  'ferry terminal': 0.028,
#  'ferry service': 0.0,
#  'metal finisher': 0.867,
#  'boat tour agency': 0.2,
#  'bus company': 0.317,
#  'moving company': 0.067,
#  'moving storage service': 0.067,
#  'state department transportation': 0.0,
#  'department transportation': 0.0,
#  'handicapped transportation service': 0.75,
#  'railway service': 0.0,
#  'train station': 0.0,
#  'bus depot': 0.333,
#  'bus charter': 1.0,
#  'metal processing company': 0.522,
#  'mixed use': 0.0,
#  'motorcycle shop': 0.429,
#  'limousine service': 1.0,
#  'chauffeur service': 0.0,
#  'school bus service': 1.0,
#  'airport shuttle service': 0.75,
#  'tourist information center': 0.0,
#  'carriage ride service': 0.0,
#  'cruise agency': 0.35,
#  'tourist attraction': 0.125,
#  'ski resort': 0.591,
#  'ski area': 0.083,
#  'fixed base operator': 0.0,
#  'aircraft maintenance company': 0.111,
#  'motorsports store': 0.0,
#  'boat rental service': 0.703,
#  'utility trailer dealer': 0.0,
#  'forklift dealer': 0.0,
#  'municipal administration office': 0.0,
#  'nephrologist': 0.0,
#  'bus coach company': 1.0,
#  'shipping service': 0.0,
#  'shipping mailing service': 0.0,
#  'newspaper publisher': 1.0,
#  'shredding service': 0.0,
#  'nuclear power company': 0.9,
#  'nursing home': 1.0,
#  'medium company': 0.081,
#  'multimedia electronic book publisher': 0.0,
#  'internet marketing service': 0.021,
#  'greeting card shop': 0.5,
#  'theme park': 0.7,
#  'film production company': 0.028,
#  'obstetrician gynecologist': 0.5,
#  'movie studio': 0.0,
#  'video production service': 0.306,
#  'movie theater': 0.536,
#  'theater company': 0.475,
#  'performing art theater': 0.729,
#  'occupational safety health': 0.0,
#  'office space rental agency': 0.0,
#  'commercial real estate agency': 0.25,
#  'art school': 0.204,
#  'music publisher': 0.1,
#  'printed music publisher': 0.05,
#  'home audio store': 0.0,
#  'musician': 0.25,
#  'music management promotion': 0.0,
#  'video editing service': 0.333,
#  'office supply wholesaler': 0.167,
#  'official residence': 0.025,
#  'orthopedic clinic': 0.196,
#  'painter': 0.0,
#  'painting': 0.47,
#  'telephone company': 0.0,
#  'medium house': 0.375,
#  'paper distributor': 0.0,
#  'news service': 0.5,
#  'public library': 0.0,
#  'law library': 0.51,
#  'museum': 1.0,
#  'federal reserve bank': 1.0,
#  'credit union': 0.118,
#  'atm': 0.167,
#  'paving contractor': 0.7,
#  'mortgage lender': 0.387,
#  'investment bank': 0.0,
#  'check cashing service': 0.667,
#  'stock broker': 0.0,
#  'health consultant': 0.0,
#  'health insurance agency': 0.566,
#  'payroll service': 1.0,
#  'pediatrician': 1.0,
#  'human resource consulting': 0.982,
#  'pest control service': 0.6,
#  'pet boarding service': 0.673,
#  'pet care': 0.2,
#  'loss adjuster': 0.087,
#  'pharmaceutical company': 0.768,
#  'pharmaceutical product wholesaler': 1.0,
#  'pharmacy': 0.2,
#  'educational institution': 0.143,
#  'retirement community': 0.75,
#  'fraternal organization': 1.0,
#  'photo lab': 0.0,
#  'property investment': 0.0,
#  'photographer': 0.167,
#  'photography school': 0.333,
#  'star hotel': 1.0,
#  'convention center': 0.05,
#  'real estate appraiser': 1.0,
#  'photography service': 0.333,
#  'resort hotel': 0.893,
#  'real estate consultant': 0.2,
#  'car rental agency': 0.387,
#  'car leasing service': 0.917,
#  'ford dealer': 0.333,
#  'car finance loan company': 0.626,
#  'trailer rental service': 0.13,
#  'furniture rental service': 0.483,
#  'tuxedo shop': 0.0,
#  'dress tuxedo rental service': 0.976,
#  'wedding store': 0.0,
#  'video store': 0.071,
#  'movie rental': 0.0,
#  'photography studio': 0.333,
#  'home health care service': 1.0,
#  'skateboard shop': 0.0,
#  'event technology service': 0.0,
#  'party equipment rental service': 0.976,
#  'construction machine rental service': 0.081,
#  'audio visual equipment rental service': 0.0,
#  'shipping equipment industry': 0.0,
#  'physical therapy clinic': 0.119,
#  'plastic fabrication company': 0.909,
#  'plastic product supplier': 0.909,
#  'auto tag agency': 0.257,
#  'department motor vehicle': 0.0,
#  'notary public': 0.607,
#  'private investigator': 0.0,
#  'escrow service': 0.0,
#  'real estate agent': 0.333,
#  'playground': 0.0,
#  'plumber': 0.056,
#  'port authority': 0.775,
#  'portrait studio': 0.333,
#  'post office': 0.333,
#  'professional service': 0.611,
#  'university hospital': 0.333,
#  'public relation firm': 0.405,
#  'civil engineering company': 0.5,
#  'drafting service': 0.847,
#  'pump supplier': 0.714,
#  'interior construction contractor': 0.0,
#  'carpet cleaning service': 0.761,
#  'exhibition planner': 0.0,
#  'decal supplier': 0.0,
#  'stage lighting equipment supplier': 1.0,
#  'event management company': 0.042,
#  'radio broadcaster': 0.0,
#  'computer support service': 0.95,
#  'ravine': 0.0,
#  'employment center': 0.427,
#  'national health foundation': 0.333,
#  'real estate developer': 0.0,
#  'advertising agency': 1.0,
#  'promotional product supplier': 0.0,
#  'advertising service': 1.0,
#  'record storage facility': 0.0,
#  'fund management company': 0.0,
#  'recreation center': 0.873,
#  'bakery': 0.976,
#  'database management company': 0.0,
#  'market researcher': 0.0,
#  'recycling center': 0.0,
#  'regional government office': 0.456,
#  'rehabilitation center': 0.0,
#  'religious institution': 1.0,
#  'religious organization': 1.0,
#  'repair service': 0.336,
#  'emergency veterinarian service': 0.12,
#  'pet sitter': 0.1,
#  'research product development': 1.0,
#  'building society': 0.583,
#  'valet parking service': 1.0,
#  'nursing agency': 1.0,
#  'executive search firm': 0.375,
#  'recruiter': 0.0,
#  'temp agency': 0.125,
#  'health center': 0.0,
#  'restaurant': 0.732,
#  'roofing contractor': 0.276,
#  'sport nutrition store': 0.2,
#  'credit reporting agency': 0.075,
#  'automobile storage facility': 1.0,
#  'debt collection agency': 0.166,
#  'park': 0.0,
#  'court reporter': 0.217,
#  'bus tour agency': 0.042,
#  'tour operator': 1.0,
#  'convention information bureau': 0.083,
#  'balloon ride tour agency': 0.5,
#  'security guard service': 0.927,
#  'locksmith': 0.4,
#  'commercial cleaning service': 0.486,
#  'blast cleaning service': 0.52,
#  'conference center': 0.0,
#  'safety equipment supplier': 0.0,
#  'garbage dump': 0.747,
#  'sanitation service': 0.05,
#  'garbage dump service': 0.0,
#  'environmental health service': 0.143,
#  'portable toilet supplier': 0.196,
#  'public work department': 0.0,
#  'school district office': 1.0,
#  'sailmaker': 0.0,
#  'community college': 0.5,
#  'salvage yard': 0.036,
#  'business school': 0.0,
#  'trade school': 0.817,
#  'private university': 0.5,
#  'computer training school': 0.141,
#  'school supply store': 0.0,
#  'screen printer': 1.0,
#  'medium consultant': 0.408,
#  'beauty school': 0.685,
#  'flight school': 0.95,
#  'seaport': 0.0,
#  'security system supplier': 0.36,
#  'middle school': 0.5,
#  'nonprofit': 0.0,
#  'shooting range': 0.083,
#  'soccer club': 0.167,
#  'camp': 0.833,
#  'diving contractor': 0.0,
#  'language school': 0.495,
#  'english language school': 0.495,
#  'preschool': 1.0,
#  'self storage facility': 0.042,
#  'semi conductor supplier': 0.0,
#  'driving school': 0.37,
#  'trucking school': 0.017,
#  'senior citizen center': 0.0,
#  'service': 0.0,
#  'childrens hospital': 0.333,
#  'dental supply store': 0.2,
#  'shipyard': 1.0,
#  'orthodox synagogue': 1.0,
#  'short term apartment rental agency': 0.0,
#  'nutritionist': 0.167,
#  'ophthalmologist': 0.0,
#  'ophthalmology clinic': 0.021,
#  'social service organization': 1.0,
#  'social welfare center': 1.0,
#  'solar energy company': 0.78,
#  'solar energy equipment supplier': 0.8,
#  'special education school': 1.0,
#  'podiatrist': 0.333,
#  'reproductive health clinic': 0.833,
#  'sporting good store': 0.75,
#  'dialysis center': 0.806,
#  'sport complex': 0.081,
#  'wellness program': 0.0,
#  'sportswear store': 0.0,
#  'private hospital': 0.25,
#  'radiologist': 0.0,
#  'medical diagnostic imaging center': 1.0,
#  'ray lab': 0.375,
#  'blood bank': 0.667,
#  'stainless steel plant': 0.25,
#  'state agency': 0.125,
#  'heliport': 0.0,
#  'health care company': 0.0,
#  'psychiatric hospital': 1.0,
#  'state government office': 0.737,
#  'medical institution': 0.25,
#  'steel construction company': 0.125,
#  'cleaning service': 0.52,
#  ...}

# %% [markdown]
# #### The mAP@N score is higher for TFIDF than the BoW model

# %%
calc_avg_pre(ret_docs_dic, queries_dic, cutoff=-1)[1]
# Out:
# 0.34

# %%
tfidf_maps = []
for i in range(1, 11):
    tfidf_maps.append(calc_avg_pre(ret_docs_dic, queries_dic, cutoff=i)[1])

# %%
tfidf_maps
# Out:
# [0.129, 0.196, 0.24, 0.274, 0.294, 0.311, 0.321, 0.329, 0.335, 0.34]

# %%
calc_NDCG_at_n(ret_docs_dic, queries_dic, n=-1, base=2)
# Out:
# {'home improvement store': 0.461,
#  'diesel fuel supplier': 0.637,
#  'church': 1.0,
#  'farm': 0.901,
#  'seed supplier': 0.244,
#  'accountant': 1.0,
#  'trucking company': 0.782,
#  'exporter': 0.474,
#  'grain elevator': 0.477,
#  'popcorn store': 0.709,
#  'agricultural service': 0.244,
#  'warehouse': 0.727,
#  'agricultural production': 0.25,
#  'ranch': 0.491,
#  'holding company': 1.0,
#  'farm equipment supplier': 0.244,
#  'store': 0.637,
#  'grocery store': 0.915,
#  'rice mill': 0.621,
#  'food product supplier': 0.148,
#  'accounting firm': 1.0,
#  'produce market': 0.722,
#  'pet supply store': 0.897,
#  'wholesaler': 0.637,
#  'produce wholesaler': 0.148,
#  'distribution service': 0.203,
#  'crop grower': 0.679,
#  'addiction treatment center': 0.637,
#  'natural good store': 0.299,
#  'orchard': 0.438,
#  'lumber store': 0.375,
#  'mine': 0.642,
#  'transportation service': 0.778,
#  'investment company': 0.375,
#  'fruit wholesaler': 0.233,
#  'real estate agency': 0.909,
#  'event venue': 0.483,
#  'frozen dessert supplier': 0.667,
#  'wine wholesaler importer': 1.0,
#  'winery': 0.885,
#  'aerospace company': 0.699,
#  'cold storage facility': 0.929,
#  'employment agency': 0.981,
#  'plant nursery': 0.789,
#  'air conditioning contractor': 0.942,
#  'air conditioning repair service': 0.483,
#  'fruit vegetable wholesaler': 0.364,
#  'aircraft rental service': 0.375,
#  'monastery': 1.0,
#  'allergist': 0.879,
#  'herb shop': 0.299,
#  'aluminum supplier': 0.938,
#  'ambulance service': 0.575,
#  'wholesale plant nursery': 0.79,
#  'amusement machine supplier': 1.0,
#  'animal hospital': 0.244,
#  'farmer market': 0.716,
#  'vaporizer store': 0.99,
#  'cigar shop': 0.4,
#  'tobacco shop': 0.299,
#  'well drilling contractor': 0.421,
#  'library': 0.867,
#  'apartment building': 0.375,
#  'apartment rental agency': 0.375,
#  'dairy farm': 0.485,
#  'architect': 0.665,
#  'organic farm': 0.203,
#  'architectural designer': 0.537,
#  'architecture firm': 0.172,
#  'livestock producer': 0.375,
#  'dairy supplier': 0.148,
#  'biotechnology company': 0.803,
#  'artist': 0.909,
#  'egg supplier': 0.945,
#  'poultry farm': 0.47,
#  'chicken hatchery': 0.905,
#  'art organization': 0.733,
#  'association organization': 0.86,
#  'food store': 0.801,
#  'deli': 0.375,
#  'bank': 0.63,
#  'fish processing': 1.0,
#  'fish farm': 0.657,
#  'seafood wholesaler': 0.469,
#  'tropical fish store': 0.729,
#  'non profit organization': 0.84,
#  'economic development agency': 0.654,
#  'seafood market': 0.541,
#  'honey farm': 0.619,
#  'horse breeder': 0.688,
#  'asphalt contractor': 0.791,
#  'livestock dealer': 0.483,
#  'department store': 1.0,
#  'mill': 0.637,
#  'atv dealer': 0.988,
#  'audio visual consultant': 0.92,
#  'pallet supplier': 0.562,
#  'wood supplier': 0.375,
#  'hardware store': 0.66,
#  'furniture wholesaler': 0.73,
#  'auditor': 0.66,
#  'oil natural gas company': 0.541,
#  'auto body shop': 0.37,
#  'boat repair shop': 0.683,
#  'association': 0.763,
#  'railing contractor': 0.244,
#  'publisher': 0.883,
#  'pond supply store': 0.483,
#  'agriculture cooperative': 0.299,
#  'printing equipment supplier': 0.409,
#  'auto insurance agency': 0.826,
#  'alternative fuel station': 1.0,
#  'auto part manufacturer': 0.172,
#  'foundation': 0.852,
#  'fertilizer supplier': 0.974,
#  'farming company': 0.244,
#  'finance broker': 0.575,
#  'agricultural cooperative': 0.299,
#  'fire station': 0.374,
#  'environmental consultant': 0.589,
#  'civil engineer': 1.0,
#  'fire protection service': 0.474,
#  'gas company': 1.0,
#  'oilfield': 0.299,
#  'banquet hall': 0.758,
#  'mining company': 0.407,
#  'coalfield': 0.483,
#  'steel fabricator': 0.244,
#  'quarry': 0.103,
#  'gold mining company': 0.815,
#  'high rise building': 0.939,
#  'basketball club': 0.657,
#  'gold dealer': 0.299,
#  'battery manufacturer': 0.711,
#  'electric utility company': 0.299,
#  'environmental program': 0.483,
#  'office': 0.84,
#  'stone supplier': 0.498,
#  'aggregate supplier': 0.375,
#  'sand gravel supplier': 0.473,
#  'building material supplier': 0.991,
#  'beauty supply store': 0.681,
#  'crushed stone supplier': 0.477,
#  'rock shop': 0.299,
#  'road construction company': 1.0,
#  'marketing consultant': 0.666,
#  'blood testing service': 0.64,
#  'contractor': 0.879,
#  'excavating contractor': 0.939,
#  'asphalt mixing plant': 0.811,
#  'ready mix concrete supplier': 0.736,
#  'sand plant': 0.343,
#  'bmw dealer': 0.836,
#  'bookbinder': 0.375,
#  'garden center': 0.955,
#  'abrasive supplier': 0.918,
#  'granite supplier': 0.478,
#  'drilling contractor': 0.299,
#  'bpo company': 0.249,
#  'oil gas exploration service': 0.723,
#  'building complex': 0.375,
#  'construction equipment supplier': 0.244,
#  'mining equipment': 0.299,
#  'bus ticket agency': 0.477,
#  'business center': 0.224,
#  'skyscraper': 0.637,
#  'software company': 1.0,
#  'business development service': 0.203,
#  'business management consultant': 0.474,
#  'cabinet maker': 0.826,
#  'call center': 0.596,
#  'cancer treatment center': 0.84,
#  'power plant consultant': 0.483,
#  'business park': 0.299,
#  'petroleum product company': 0.748,
#  'parking lot': 0.619,
#  'water utility company': 0.966,
#  'car repair maintenance': 0.676,
#  'water treatment plant': 1.0,
#  'car service': 0.346,
#  'cattle market': 0.581,
#  'sewage disposal service': 0.966,
#  'certified public accountant': 0.732,
#  'government office': 0.91,
#  'charity': 0.758,
#  'air conditioning system supplier': 0.375,
#  'chemical industry': 0.551,
#  'chemical manufacturer': 0.644,
#  'title company': 0.555,
#  'chemical plant': 0.644,
#  'property management company': 0.375,
#  'custom home builder': 0.759,
#  'window installation service': 0.172,
#  'fire damage restoration service': 0.375,
#  'equipment rental agency': 0.487,
#  'chemical wholesaler': 0.879,
#  'financial planner': 0.876,
#  'telecommunication service provider': 0.85,
#  'energy equipment solution': 0.637,
#  'chiropractor': 0.628,
#  'steel distributor': 0.637,
#  'city government office': 0.878,
#  'crane service': 0.312,
#  'garage door supplier': 0.332,
#  'industrial door supplier': 0.383,
#  'city town hall': 0.383,
#  'clothing wholesaler': 0.49,
#  'coin operated laundry equipment supplier': 1.0,
#  'metal supplier': 0.637,
#  'glass shop': 0.172,
#  'college': 1.0,
#  'siding contractor': 0.622,
#  'commercial printer': 0.47,
#  'storage facility': 0.893,
#  'communication tower': 0.621,
#  'janitorial service': 0.692,
#  'computer consultant': 0.604,
#  'fire protection system supplier': 0.487,
#  'elevator service': 0.312,
#  'industrial equipment supplier': 0.244,
#  'dry wall contractor': 0.652,
#  'insulation contractor': 0.606,
#  'concrete contractor': 0.813,
#  'scaffolding rental service': 0.462,
#  'construction company': 1.0,
#  'flooring store': 0.515,
#  'flooring contractor': 0.773,
#  'tile contractor': 0.798,
#  'tile manufacturer': 0.383,
#  'glass mirror shop': 0.172,
#  'construction material wholesaler': 0.715,
#  'gutter cleaning service': 0.779,
#  'sheet metal contractor': 0.899,
#  'consultant': 0.35,
#  'container service': 0.529,
#  'septic system service': 0.767,
#  'corporate campus': 0.657,
#  'water damage restoration service': 0.375,
#  'welder': 0.085,
#  'corporate office': 0.758,
#  'animal': 0.929,
#  'animal feed store': 0.363,
#  'animal protection organization': 0.483,
#  'brewing supply store': 0.637,
#  'cosmetic store': 0.689,
#  'county government office': 0.882,
#  'sugar factory': 0.977,
#  'confectionery wholesaler': 0.354,
#  'financial institution': 0.244,
#  'candy store': 0.5,
#  'confectionery': 0.457,
#  'chocolate factory': 0.962,
#  'chocolate shop': 0.944,
#  'courier service': 1.0,
#  'coworking space': 0.43,
#  'frozen food manufacturer': 0.811,
#  'beverage distributor': 0.637,
#  'agricultural organization': 0.299,
#  'dairy store': 0.148,
#  'dairy': 0.607,
#  'ice cream shop': 0.652,
#  'medical laboratory': 1.0,
#  'demolition contractor': 0.939,
#  'meat processor': 0.94,
#  'fmcg manufacturer': 0.244,
#  'garbage collection service': 0.875,
#  'wholesale bakery': 0.949,
#  'dentist': 0.902,
#  'dessert shop': 0.244,
#  'cupcake shop': 0.244,
#  'nut store': 0.798,
#  'wholesale grocer': 0.296,
#  'design engineer': 0.366,
#  'business business service': 0.665,
#  'condiment supplier': 0.83,
#  'digital printing service': 0.974,
#  'culinary school': 0.884,
#  'importer': 0.203,
#  'bottled water supplier': 0.383,
#  'coffee roaster': 0.625,
#  'packaging supply store': 0.483,
#  'ice supplier': 0.864,
#  'brewery': 0.874,
#  'winemaking company': 0.244,
#  'distillery': 0.897,
#  'disability service support organisation': 0.804,
#  'district government office': 0.815,
#  'air filter supplier': 0.849,
#  'tire shop': 0.879,
#  'fastener supplier': 0.677,
#  'fabric product manufacturer': 0.788,
#  'textile': 0.782,
#  'textile exporter': 0.782,
#  'textile engineer': 0.782,
#  'fabric store': 0.375,
#  'knit shop': 0.555,
#  'doctor': 1.0,
#  'lamination service': 0.114,
#  'plastic resin manufacturer': 0.758,
#  'carpet manufacturer': 0.922,
#  'upholstery shop': 0.299,
#  'business administration service': 0.203,
#  'furniture store': 1.0,
#  'dry cleaner': 0.375,
#  'packaging company': 0.657,
#  'duty free store': 0.99,
#  'commerce service': 0.84,
#  'cable company': 0.84,
#  'education': 0.902,
#  'outlet store': 0.637,
#  'lingerie store': 0.42,
#  'clothes fabric manufacturer': 0.788,
#  'education center': 0.84,
#  'uniform store': 0.352,
#  'men clothing store': 0.874,
#  'clothing store': 0.924,
#  'woman clothing store': 0.889,
#  'western apparel store': 0.244,
#  'costume store': 0.244,
#  'game store': 0.626,
#  'hat shop': 0.244,
#  'leather good manufacturer': 0.741,
#  'educational consultant': 1.0,
#  'leather exporter': 1.0,
#  'shoe store': 1.0,
#  'boutique': 0.244,
#  'leather wholesaler': 0.741,
#  'handbag shop': 0.741,
#  'electronics store': 0.83,
#  'luggage store': 0.879,
#  'building material store': 0.731,
#  'saw mill': 0.637,
#  'electrical engineer': 0.172,
#  'deck builder': 0.286,
#  'concrete product supplier': 0.808,
#  'plywood supplier': 0.985,
#  'electrical installation service': 0.483,
#  'truss manufacturer': 0.655,
#  'door supplier': 0.308,
#  'wood laminate flooring supplier': 0.974,
#  'aircraft supply store': 0.244,
#  'modular home builder': 0.203,
#  'portable building manufacturer': 0.244,
#  'modular home dealer': 0.412,
#  'mulch supplier': 0.244,
#  'electrician': 0.657,
#  'paper mill': 0.88,
#  'energy supplier': 0.917,
#  'engineer': 0.435,
#  'print shop': 0.513,
#  'custom label printer': 0.795,
#  'marketing': 0.648,
#  'marketing agency': 0.183,
#  'engineering consultant': 0.637,
#  'entertainer': 0.244,
#  'envelope supplier': 0.474,
#  'oil refinery': 0.618,
#  'recording studio': 0.929,
#  'environment renewable natural resource': 0.129,
#  'finishing material supplier': 0.375,
#  'event ticket seller': 0.375,
#  'waterproofing company': 0.244,
#  'auto part store': 0.637,
#  'heating oil supplier': 0.758,
#  'family practice physician': 1.0,
#  'machining manufacturer': 0.299,
#  'industrial gas supplier': 0.203,
#  'welding supply store': 0.085,
#  'dry ice supplier': 0.693,
#  'private equity firm': 0.299,
#  'family service center': 0.758,
#  'federal government office': 0.923,
#  'vitamin supplement store': 0.811,
#  'feed manufacturer': 1.0,
#  'medical equipment supplier': 0.203,
#  'medical supply store': 0.203,
#  'medical clinic': 0.756,
#  'research institute': 0.919,
#  'biochemical supplier': 0.637,
#  'fiber optic product supplier': 0.435,
#  'paint manufacturer': 0.955,
#  'equipment supplier': 0.244,
#  'food': 0.172,
#  'pipe supplier': 0.503,
#  'oil field equipment supplier': 0.697,
#  'food broker': 0.148,
#  'food manufacturer': 0.753,
#  'food processing company': 0.249,
#  'fence supply store': 0.47,
#  'food producer': 0.172,
#  'forestry service': 1.0,
#  'foundry': 0.961,
#  'wholesale jeweler': 0.583,
#  'cookie shop': 0.523,
#  'truck rental agency': 0.684,
#  'fruit vegetable processing': 0.731,
#  'kitchen supply store': 0.203,
#  'hydraulic equipment supplier': 0.244,
#  'irrigation equipment supplier': 0.758,
#  'bearing supplier': 0.498,
#  'metallurgy company': 0.583,
#  'plastic injection molding service': 0.299,
#  'general contractor': 0.637,
#  'general hospital': 1.0,
#  'tool manufacturer': 0.945,
#  'industrial design company': 0.626,
#  'hyundai dealer': 0.375,
#  'glass industry': 0.974,
#  'polymer supplier': 0.637,
#  'printing equipment supply': 0.299,
#  'toner cartridge supplier': 0.555,
#  'printer repair service': 0.518,
#  'fuel supplier': 0.637,
#  'glass manufacturer': 0.947,
#  'plastic bag supplier': 0.805,
#  'glassware manufacturer': 0.518,
#  'polythene plastic sheeting supplier': 0.734,
#  'pvc industry': 0.265,
#  'countertop store': 0.375,
#  'cabinet store': 0.477,
#  'fiberglass supplier': 0.583,
#  'golf cart dealer': 0.988,
#  'auto repair shop': 0.698,
#  'hose supplier': 0.661,
#  'rubber product supplier': 0.981,
#  'automotive': 0.375,
#  'commercial refrigerator supplier': 0.375,
#  'golf club': 0.771,
#  'golf course': 0.655,
#  'green energy supplier': 0.876,
#  'greenhouse': 0.929,
#  'auto glass shop': 0.258,
#  'lighting manufacturer': 0.947,
#  'cement manufacturer': 0.914,
#  'brick manufacturer': 0.981,
#  'natural stone supplier': 0.375,
#  'gym': 0.523,
#  'marble supplier': 0.583,
#  'corporate gift supplier': 1.0,
#  'shipbuilding repair company': 0.637,
#  'construction maintenance office': 1.0,
#  'boiler manufacturer': 0.964,
#  'container supplier': 0.975,
#  'home construction': 0.659,
#  'health': 0.75,
#  'heart hospital': 1.0,
#  'spring supplier': 1.0,
#  'electric utility manufacturer': 0.299,
#  'aircraft manufacturer': 0.972,
#  'metal heat treating service': 0.966,
#  'plating service': 0.758,
#  'automation company': 0.375,
#  'heating contractor': 0.942,
#  'plumbing supply store': 0.375,
#  'gun shop': 0.518,
#  'ammunition supplier': 0.888,
#  'pipe manufacturer': 0.436,
#  'school': 1.0,
#  'fire protection equipment supplier': 0.474,
#  'agricultural machinery manufacturer': 0.401,
#  'lawn mower store': 0.637,
#  'lawn irrigation equipment supplier': 0.621,
#  'financial consultant': 0.876,
#  'helicopter charter': 0.698,
#  'packaging machinery': 0.228,
#  'historical landmark': 1.0,
#  'electronics manufacturer': 0.244,
#  'graphic designer': 0.839,
#  'eye care center': 0.343,
#  'optical product manufacturer': 0.657,
#  'image consultant': 0.589,
#  'cleaning product supplier': 0.244,
#  'fireplace store': 0.375,
#  'home builder': 0.759,
#  'tool die shop': 0.915,
#  'metal stamping service': 0.618,
#  'environmental organization': 0.84,
#  'food processing equipment': 0.299,
#  'loan agency': 0.692,
#  'power plant equipment supplier': 0.483,
#  'home good store': 0.736,
#  'engine rebuilding service': 0.148,
#  'air compressor supplier': 0.383,
#  'honda dealer': 0.807,
#  'elevator manufacturer': 0.312,
#  'crane dealer': 0.085,
#  'crane rental agency': 0.553,
#  'compound building': 0.172,
#  'tractor dealer': 0.244,
#  'furnace part supplier': 0.375,
#  'heating equipment supplier': 0.418,
#  'pneumatic tool supplier': 0.375,
#  'truck stop': 0.758,
#  'computer hardware manufacturer': 0.758,
#  'satellite communication service': 0.897,
#  'hospital': 0.941,
#  'electronics company': 0.758,
#  'electronic part supplier': 0.483,
#  'hvac contractor': 0.942,
#  'industrial engineer': 0.435,
#  'contact lens supplier': 0.798,
#  'information service': 0.992,
#  'building': 0.955,
#  'water work equipment supplier': 0.375,
#  'measuring instrument supplier': 0.78,
#  'scientific equipment supplier': 0.203,
#  'medical center': 0.84,
#  'watch manufacturer': 0.612,
#  'corporate entertainment service': 0.84,
#  'insurance': 0.718,
#  'record company': 0.375,
#  'video duplication service': 0.576,
#  'insurance agency': 0.826,
#  'lighting store': 0.933,
#  'lighting wholesaler': 0.912,
#  'entertainment agency': 0.84,
#  'insurance broker': 0.791,
#  'electrical equipment supplier': 0.483,
#  'electric motor store': 0.172,
#  'railroad company': 1.0,
#  'electrical supply store': 0.483,
#  'insurance company': 0.718,
#  'factory equipment supplier': 0.244,
#  'investment service': 0.901,
#  'laser equipment supplier': 0.148,
#  'executive suite rental agency': 0.387,
#  'truck dealer': 0.375,
#  'motor vehicle dealer': 0.81,
#  'car dealer': 0.939,
#  'truck topper supplier': 0.244,
#  'police supply store': 0.983,
#  'iron steel contractor': 0.408,
#  'fire department equipment supplier': 0.3,
#  'towing equipment provider': 1.0,
#  'logistics service': 0.389,
#  'trailer manufacturer': 0.955,
#  'trailer dealer': 0.483,
#  'dealer': 0.896,
#  'auto spring shop': 0.148,
#  'auto upholsterer': 0.172,
#  'auto body part supplier': 0.637,
#  'car factory': 0.483,
#  'freight forwarding service': 0.92,
#  'brake shop': 0.292,
#  'railroad equipment supplier': 0.244,
#  'jewelry equipment supplier': 0.76,
#  'boat builder': 0.955,
#  'ship building': 1.0,
#  'marine supply store': 0.483,
#  'boat dealer': 0.982,
#  'kawasaki motorcycle dealer': 0.988,
#  'knife manufacturing': 0.637,
#  'labor union': 0.918,
#  'furniture maker': 0.89,
#  'banking finance': 0.586,
#  'furniture manufacturer': 0.891,
#  'logistics': 0.574,
#  'massage supply store': 0.244,
#  'telecommunication equipment supplier': 0.483,
#  'baby store': 0.244,
#  'molding supplier': 0.299,
#  'office equipment supplier': 0.203,
#  'office furniture store': 0.821,
#  'store equipment supplier': 0.244,
#  'laboratory': 0.274,
#  'health beauty shop': 0.583,
#  'learning center': 0.383,
#  'dental laboratory': 0.555,
#  'land surveyor': 0.369,
#  'educational supply store': 0.758,
#  'jewelry store': 0.879,
#  'playground equipment supplier': 0.299,
#  'outdoor sport store': 0.555,
#  'toy store': 0.619,
#  'security service': 0.505,
#  'sign shop': 0.354,
#  'office supply store': 0.879,
#  'landscaper': 0.299,
#  'gasket manufacturer': 0.354,
#  'piano maker': 0.207,
#  'piano store': 0.498,
#  'funeral home': 1.0,
#  'monument': 0.375,
#  'book publisher': 0.812,
#  'wig shop': 0.523,
#  'laundromat': 0.66,
#  'auto wrecker': 0.723,
#  'auto part market': 0.842,
#  'jeep dealer': 0.807,
#  'restaurant supply store': 0.244,
#  'roofing supply store': 0.375,
#  'law firm': 0.66,
#  'building material market': 0.991,
#  'camera store': 0.203,
#  'lawn care service': 0.299,
#  'computer security service': 0.385,
#  'computer store': 0.203,
#  'design agency': 0.992,
#  'diagnostic center': 0.939,
#  'laboratory equipment supplier': 0.309,
#  'home theater store': 0.84,
#  'metal industry supplier': 0.637,
#  'landscaping supply store': 0.637,
#  'appliance part supplier': 0.483,
#  'vacuum cleaner store': 0.789,
#  'audio visual equipment supplier': 1.0,
#  'lawyer': 0.929,
#  'cell phone store': 0.637,
#  'bathroom supply store': 0.375,
#  'leasing service': 0.731,
#  'construction machine dealer': 0.244,
#  'dairy farm equipment supplier': 0.244,
#  'propane supplier': 0.637,
#  'legal service': 0.879,
#  'janitorial equipment supplier': 0.478,
#  'life insurance agency': 0.709,
#  'railroad contractor': 0.84,
#  'swimming pool supply store': 0.983,
#  'light bulb supplier': 0.851,
#  'linen store': 0.375,
#  'metal construction company': 0.548,
#  'local government office': 0.923,
#  'logging contractor': 0.84,
#  'machine shop': 0.82,
#  'hotel supply store': 0.375,
#  'import export company': 0.203,
#  'sewing company': 0.66,
#  'research foundation': 0.811,
#  'machinery part manufacturer': 0.914,
#  'sport accessory wholesaler': 0.299,
#  'fashion designer': 0.725,
#  'cheese manufacturer': 0.583,
#  'cheese shop': 0.583,
#  'shipping mailing': 0.84,
#  'wholesale food store': 0.148,
#  'organic food store': 0.299,
#  'pie shop': 0.42,
#  'auction house': 0.712,
#  'livestock auction house': 0.601,
#  'cotton exporter': 0.514,
#  'plastic wholesaler': 0.637,
#  'mailing service': 0.84,
#  'manufacturer': 0.114,
#  'gas station': 0.862,
#  'beer distributor': 0.85,
#  'alcoholic beverage wholesaler': 0.756,
#  'religious good store': 1.0,
#  'book wholesaler': 0.258,
#  'masonry supply store': 0.47,
#  'wholesale florist': 0.543,
#  'florist': 1.0,
#  'marine engineer': 0.266,
#  'paint store': 0.518,
#  'used auto part store': 0.713,
#  'masonry contractor': 0.62,
#  'used car dealer': 0.939,
#  'used truck dealer': 0.939,
#  'massage therapist': 0.716,
#  'material handling equipment supplier': 0.244,
#  'marina': 0.875,
#  'meat packer': 0.247,
#  'mattress store': 0.84,
#  'blind shop': 0.879,
#  'interior designer': 0.696,
#  'window treatment store': 0.942,
#  'appliance store': 0.939,
#  'health food store': 0.727,
#  'direct mail advertising': 0.643,
#  'meat wholesaler': 0.387,
#  'butcher shop deli': 0.523,
#  'italian grocery store': 0.423,
#  'market': 0.203,
#  'food service': 1.0,
#  'grocery delivery service': 1.0,
#  'wine store': 1.0,
#  'liquor store': 1.0,
#  'kiosk': 0.483,
#  'optometrist': 0.628,
#  'optician': 0.352,
#  'mechanical contractor': 0.942,
#  'mechanical engineer': 0.435,
#  'cafe': 0.495,
#  'jeweler': 0.583,
#  'leather good store': 0.758,
#  'gift shop': 0.955,
#  'craft store': 0.43,
#  'hobby store': 0.679,
#  'fabric wholesaler': 0.375,
#  'scrap metal dealer': 0.299,
#  'quilt shop': 0.375,
#  'sheet music store': 0.555,
#  'musical instrument manufacturer': 0.186,
#  'music store': 0.485,
#  'musical instrument store': 0.955,
#  'band': 0.485,
#  'bookstore': 0.637,
#  'art museum': 0.955,
#  'newsstand': 0.879,
#  'medical equipment manufacturer': 0.81,
#  'fashion accessory store': 0.569,
#  'discount store': 0.637,
#  'cemetery': 0.879,
#  'bus stop': 0.66,
#  'variety store': 0.637,
#  'thrift store': 1.0,
#  'medical group': 0.637,
#  'donation center': 0.84,
#  'pet store': 0.92,
#  'art gallery': 0.583,
#  'art dealer': 0.417,
#  'housing development': 0.939,
#  'mobile home dealer': 0.496,
#  'convenience store': 0.915,
#  'medical office': 0.637,
#  'medical technology manufacturer': 0.478,
#  'childrens furniture store': 1.0,
#  'mental health clinic': 0.392,
#  'airline': 0.637,
#  'aviation consultant': 0.483,
#  'travel agency': 0.876,
#  'travel service': 0.929,
#  'airport': 0.942,
#  'mental health service': 0.551,
#  'shipping company': 0.84,
#  'metal fabricator': 0.622,
#  'cruise line company': 0.375,
#  'towing service': 1.0,
#  'ferry terminal': 0.465,
#  'ferry service': 0.637,
#  'metal finisher': 0.877,
#  'boat tour agency': 0.909,
#  'bus company': 0.66,
#  'moving company': 0.601,
#  'moving storage service': 0.601,
#  'state department transportation': 0.299,
#  'department transportation': 0.299,
#  'handicapped transportation service': 0.939,
#  'railway service': 0.84,
#  'train station': 0.375,
#  'bus depot': 0.941,
#  'bus charter': 1.0,
#  'metal processing company': 0.622,
#  'mixed use': 0.375,
#  'motorcycle shop': 0.824,
#  'limousine service': 1.0,
#  'chauffeur service': 0.637,
#  'school bus service': 1.0,
#  'airport shuttle service': 0.939,
#  'tourist information center': 0.375,
#  'carriage ride service': 0.84,
#  'cruise agency': 0.508,
#  'tourist attraction': 0.66,
#  'ski resort': 0.801,
#  'ski area': 0.523,
#  'fixed base operator': 0.483,
#  'aircraft maintenance company': 0.657,
#  'motorsports store': 0.483,
#  'boat rental service': 0.774,
#  'utility trailer dealer': 0.483,
#  'forklift dealer': 0.244,
#  'municipal administration office': 0.244,
#  'nephrologist': 0.637,
#  'bus coach company': 1.0,
#  'shipping service': 0.84,
#  'shipping mailing service': 0.84,
#  'newspaper publisher': 0.843,
#  'shredding service': 0.483,
#  'nuclear power company': 0.888,
#  'nursing home': 1.0,
#  'medium company': 0.374,
#  'multimedia electronic book publisher': 0.375,
#  'internet marketing service': 0.185,
#  'greeting card shop': 0.879,
#  'theme park': 0.931,
#  'film production company': 0.262,
#  'obstetrician gynecologist': 0.879,
#  'movie studio': 0.244,
#  'video production service': 0.425,
#  'movie theater': 0.83,
#  'theater company': 0.78,
#  'performing art theater': 0.845,
#  'occupational safety health': 0.84,
#  'office space rental agency': 0.375,
#  'commercial real estate agency': 0.92,
#  'art school': 0.537,
#  'music publisher': 0.519,
#  'printed music publisher': 0.498,
#  'home audio store': 0.84,
#  'musician': 0.66,
#  'music management promotion': 0.84,
#  'video editing service': 0.755,
#  'office supply wholesaler': 0.651,
#  'official residence': 0.461,
#  'orthopedic clinic': 0.763,
#  'painter': 0.244,
#  'painting': 0.68,
#  'telephone company': 0.637,
#  'medium house': 0.656,
#  'paper distributor': 0.483,
#  'news service': 0.879,
#  'public library': 0.375,
#  'law library': 0.827,
#  'museum': 0.955,
#  'federal reserve bank': 1.0,
#  'credit union': 0.54,
#  'atm': 0.758,
#  'paving contractor': 0.931,
#  'mortgage lender': 0.762,
#  'investment bank': 0.375,
#  'check cashing service': 0.85,
#  'stock broker': 0.375,
#  'health consultant': 0.203,
#  'health insurance agency': 0.697,
#  'payroll service': 0.929,
#  'pediatrician': 1.0,
#  'human resource consulting': 0.939,
#  'pest control service': 0.79,
#  'pet boarding service': 0.801,
#  'pet care': 0.583,
#  'loss adjuster': 0.515,
#  'pharmaceutical company': 0.953,
#  'pharmaceutical product wholesaler': 1.0,
#  'pharmacy': 0.583,
#  'educational institution': 0.897,
#  'retirement community': 0.939,
#  'fraternal organization': 1.0,
#  'photo lab': 0.244,
#  'property investment': 0.375,
#  'photographer': 0.476,
#  'photography school': 0.755,
#  'star hotel': 0.991,
#  'convention center': 0.498,
#  'real estate appraiser': 0.929,
#  'photography service': 0.755,
#  'resort hotel': 0.97,
#  'real estate consultant': 0.909,
#  'car rental agency': 0.854,
#  'car leasing service': 0.988,
#  'ford dealer': 0.807,
#  'car finance loan company': 0.617,
#  'trailer rental service': 0.647,
#  'furniture rental service': 0.751,
#  'tuxedo shop': 0.244,
#  'dress tuxedo rental service': 0.916,
#  'wedding store': 0.244,
#  'video store': 0.723,
#  'movie rental': 0.244,
#  'photography studio': 0.755,
#  'home health care service': 1.0,
#  'skateboard shop': 0.114,
#  'event technology service': 0.483,
#  'party equipment rental service': 0.942,
#  'construction machine rental service': 0.508,
#  'audio visual equipment rental service': 0.84,
#  'shipping equipment industry': 0.244,
#  'physical therapy clinic': 0.442,
#  'plastic fabrication company': 0.982,
#  'plastic product supplier': 0.976,
#  'auto tag agency': 0.547,
#  'department motor vehicle': 0.299,
#  'notary public': 0.782,
#  'private investigator': 0.299,
#  'escrow service': 0.299,
#  'real estate agent': 0.941,
#  'playground': 0.244,
#  'plumber': 0.589,
#  'port authority': 0.871,
#  'portrait studio': 0.755,
#  'post office': 0.941,
#  'professional service': 0.78,
#  'university hospital': 0.941,
#  'public relation firm': 0.596,
#  'civil engineering company': 1.0,
#  'drafting service': 0.971,
#  'pump supplier': 0.82,
#  'interior construction contractor': 0.637,
#  'carpet cleaning service': 0.835,
#  'exhibition planner': 0.483,
#  'decal supplier': 0.114,
#  'stage lighting equipment supplier': 1.0,
#  'event management company': 0.575,
#  'radio broadcaster': 0.085,
#  'computer support service': 0.914,
#  'ravine': 0.375,
#  'employment center': 0.767,
#  'national health foundation': 0.666,
#  'real estate developer': 0.375,
#  'advertising agency': 0.866,
#  'promotional product supplier': 0.172,
#  'advertising service': 0.844,
#  'record storage facility': 0.375,
#  'fund management company': 0.299,
#  'recreation center': 0.866,
#  'bakery': 0.989,
#  'database management company': 0.84,
#  'market researcher': 0.244,
#  'recycling center': 0.299,
#  'regional government office': 0.756,
#  'rehabilitation center': 0.637,
#  'religious institution': 1.0,
#  'religious organization': 1.0,
#  'repair service': 0.569,
#  'emergency veterinarian service': 0.537,
#  'pet sitter': 0.583,
#  'research product development': 0.947,
#  'building society': 0.955,
#  'valet parking service': 0.918,
#  'nursing agency': 1.0,
#  'executive search firm': 0.767,
#  'recruiter': 0.375,
#  'temp agency': 0.66,
#  'health center': 0.84,
#  'restaurant': 0.949,
#  'roofing contractor': 0.622,
#  'sport nutrition store': 0.583,
#  'credit reporting agency': 0.391,
#  'automobile storage facility': 0.955,
#  'debt collection agency': 0.409,
#  'park': 0.299,
#  'court reporter': 0.639,
#  'bus tour agency': 0.485,
#  'tour operator': 0.955,
#  'convention information bureau': 0.555,
#  'balloon ride tour agency': 1.0,
#  'security guard service': 0.99,
#  'locksmith': 0.811,
#  'commercial cleaning service': 0.681,
#  'blast cleaning service': 0.689,
#  'conference center': 0.483,
#  'safety equipment supplier': 0.203,
#  'garbage dump': 0.774,
#  'sanitation service': 0.441,
#  'garbage dump service': 0.483,
#  'environmental health service': 0.474,
#  'portable toilet supplier': 0.737,
#  'public work department': 0.244,
#  'school district office': 1.0,
#  'sailmaker': 0.375,
#  'community college': 1.0,
#  'salvage yard': 0.477,
#  'business school': 0.483,
#  'trade school': 0.963,
#  'private university': 1.0,
#  'computer training school': 0.63,
#  'school supply store': 0.483,
#  'screen printer': 1.0,
#  'medium consultant': 0.688,
#  'beauty school': 0.76,
#  'flight school': 0.928,
#  'seaport': 0.375,
#  'security system supplier': 0.731,
#  'middle school': 1.0,
#  'nonprofit': 0.84,
#  'shooting range': 0.523,
#  'soccer club': 0.758,
#  'camp': 0.955,
#  'diving contractor': 0.483,
#  'language school': 0.703,
#  'english language school': 0.703,
#  'preschool': 1.0,
#  'self storage facility': 0.485,
#  'semi conductor supplier': 0.244,
#  'driving school': 0.751,
#  'trucking school': 0.286,
#  'senior citizen center': 0.483,
#  'service': 0.375,
#  'childrens hospital': 0.941,
#  'dental supply store': 0.583,
#  'shipyard': 1.0,
#  'orthodox synagogue': 1.0,
#  'short term apartment rental agency': 0.375,
#  'nutritionist': 0.523,
#  'ophthalmologist': 0.244,
#  'ophthalmology clinic': 0.275,
#  'social service organization': 1.0,
#  'social welfare center': 0.966,
#  'solar energy company': 0.87,
#  'solar energy equipment supplier': 0.876,
#  'special education school': 1.0,
#  'podiatrist': 0.755,
#  'reproductive health clinic': 0.711,
#  'sporting good store': 0.938,
#  'dialysis center': 0.914,
#  'sport complex': 0.381,
#  'wellness program': 0.483,
#  'sportswear store': 0.375,
#  'private hospital': 0.92,
#  'radiologist': 0.637,
#  'medical diagnostic imaging center': 1.0,
#  'ray lab': 0.919,
#  'blood bank': 0.942,
#  'stainless steel plant': 0.92,
#  'state agency': 0.523,
#  'heliport': 0.483,
#  'health care company': 0.84,
#  'psychiatric hospital': 1.0,
#  'state government office': 0.963,
#  'medical institution': 0.92,
#  'steel construction company': 0.435,
#  'cleaning service': 0.689,
#  ...}

# %% [markdown]
# ## Stemming

# %%
docs = dict(zip(df['naics'], df['stemmed']))

# %%
tfidf_model = TfidfRecommenderSystem(docs)

# %%
ret_docs_dic = {}
queries_dic = {}

for query in relevant_naics.iterrows():
    query_name =  ' '.join(process_query(query[1]['query'], 'stem'))
    ret_docs_index = tfidf_model.retrieve_docs(query_name, max_docs=max_docs, normalization='stem')
    ret_docs = df.iloc[ret_docs_index]['naics'].tolist()

    query_docs = query[1]['relevant_naics']
    ret_docs_dic[query_name] = ret_docs
    queries_dic[query_name] = query_docs

# %%
calc_pre_rec_at_n(ret_docs_dic, queries_dic, n=-1)[0]
# Out:
# {'home improv store': 0.0,
#  'diesel fuel supplier': 0.0,
#  'church': 0.1,
#  'farm': 0.0,
#  'seed supplier': 0.0,
#  'account': 0.4,
#  'truck compani': 0.3,
#  'export': 0.0,
#  'grain elev': 0.1,
#  'popcorn store': 0.2,
#  'agricultur servic': 0.4,
#  'warehous': 0.4,
#  'agricultur product': 0.0,
#  'ranch': 0.4,
#  'hold compani': 0.3,
#  'farm equip supplier': 0.0,
#  'store': 0.0,
#  'groceri store': 0.2,
#  'rice mill': 0.6,
#  'food product supplier': 0.0,
#  'account firm': 0.4,
#  'produc market': 0.2,
#  'pet suppli store': 0.5,
#  'wholesal': 0.0,
#  'produc wholesal': 0.4,
#  'distribut servic': 0.0,
#  'crop grower': 0.6,
#  'addict treatment center': 0.0,
#  'natur good store': 0.0,
#  'orchard': 0.2,
#  'lumber store': 0.0,
#  'mine': 0.5,
#  'transport servic': 0.2,
#  'invest compani': 0.0,
#  'fruit wholesal': 0.1,
#  'real estat agenc': 0.1,
#  'event venu': 0.0,
#  'frozen dessert supplier': 0.3,
#  'wine wholesal import': 0.2,
#  'wineri': 0.6,
#  'aerospac compani': 0.6,
#  'cold storag facil': 0.4,
#  'employ agenc': 0.3,
#  'plant nurseri': 0.1,
#  'air condit contractor': 0.2,
#  'air condit repair servic': 0.0,
#  'fruit veget wholesal': 0.1,
#  'aircraft rental servic': 0.0,
#  'monasteri': 0.1,
#  'allergist': 0.1,
#  'herb shop': 0.0,
#  'aluminum supplier': 0.4,
#  'ambul servic': 0.1,
#  'wholesal plant nurseri': 0.5,
#  'amus machin supplier': 0.0,
#  'anim hospit': 0.0,
#  'farmer market': 0.1,
#  'vapor store': 0.5,
#  'cigar shop': 0.1,
#  'tobacco shop': 0.0,
#  'well drill contractor': 0.0,
#  'librari': 0.3,
#  'apart build': 0.0,
#  'apart rental agenc': 0.0,
#  'dairi farm': 0.0,
#  'architect': 0.2,
#  'organ farm': 0.1,
#  'architectur design': 0.3,
#  'architectur firm': 0.6,
#  'livestock produc': 0.0,
#  'dairi supplier': 0.0,
#  'biotechnolog compani': 0.2,
#  'artist': 0.1,
#  'egg supplier': 0.5,
#  'poultri farm': 0.0,
#  'chicken hatcheri': 0.4,
#  'art organ': 0.4,
#  'associ organ': 0.5,
#  'food store': 0.2,
#  'deli': 0.0,
#  'bank': 0.3,
#  'fish process': 0.0,
#  'fish farm': 0.1,
#  'seafood wholesal': 0.7,
#  'tropic fish store': 0.5,
#  'non profit organ': 0.0,
#  'econom develop agenc': 0.4,
#  'seafood market': 0.2,
#  'honey farm': 0.0,
#  'hors breeder': 0.0,
#  'asphalt contractor': 0.2,
#  'livestock dealer': 0.0,
#  'depart store': 0.1,
#  'mill': 0.0,
#  'atv dealer': 0.3,
#  'audio visual consult': 0.1,
#  'pallet supplier': 0.2,
#  'wood supplier': 0.0,
#  'hardwar store': 0.1,
#  'furnitur wholesal': 0.0,
#  'auditor': 0.1,
#  'oil natur compani': 0.2,
#  'auto bodi shop': 0.3,
#  'boat repair shop': 0.1,
#  'associ': 0.3,
#  'rail contractor': 0.0,
#  'publish': 0.6,
#  'pond suppli store': 0.0,
#  'agricultur cooper': 0.0,
#  'print equip supplier': 0.1,
#  'auto insur agenc': 0.4,
#  'altern fuel station': 0.2,
#  'auto part manufactur': 0.0,
#  'foundat': 0.3,
#  'fertil supplier': 0.4,
#  'farm compani': 0.0,
#  'financ broker': 0.0,
#  'fire station': 0.1,
#  'environment consult': 0.7,
#  'civil engin': 0.1,
#  'fire protect servic': 0.1,
#  'compani': 0.0,
#  'oilfield': 0.0,
#  'banquet hall': 0.1,
#  'mine compani': 0.5,
#  'coalfield': 0.0,
#  'steel fabric': 0.0,
#  'quarri': 0.6,
#  'gold mine compani': 0.4,
#  'high rise build': 0.2,
#  'basketbal club': 0.1,
#  'gold dealer': 0.0,
#  'batteri manufactur': 0.3,
#  'electr util compani': 0.0,
#  'environment program': 0.0,
#  'offic': 0.0,
#  'stone supplier': 0.1,
#  'aggreg supplier': 0.0,
#  'sand gravel supplier': 0.2,
#  'build materi supplier': 0.4,
#  'beauti suppli store': 0.3,
#  'crush stone supplier': 0.1,
#  'rock shop': 0.0,
#  'road construct compani': 0.1,
#  'market consult': 0.7,
#  'blood test servic': 0.5,
#  'contractor': 0.2,
#  'excav contractor': 0.2,
#  'asphalt mix plant': 0.2,
#  'readi mix concret supplier': 0.5,
#  'sand plant': 0.2,
#  'bmw dealer': 0.2,
#  'bookbind': 0.4,
#  'garden center': 0.2,
#  'abras supplier': 0.0,
#  'granit supplier': 0.1,
#  'drill contractor': 0.0,
#  'bpo compani': 0.3,
#  'oil explor servic': 0.5,
#  'build complex': 0.0,
#  'construct equip supplier': 0.0,
#  'mine equip': 0.0,
#  'ticket agenc': 0.3,
#  'busi center': 0.1,
#  'skyscrap': 0.0,
#  'softwar compani': 0.1,
#  'busi develop servic': 0.1,
#  'busi manag consult': 0.7,
#  'cabinet maker': 0.6,
#  'call center': 0.2,
#  'cancer treatment center': 0.0,
#  'power plant consult': 0.0,
#  'busi park': 0.2,
#  'petroleum product compani': 0.2,
#  'park lot': 0.1,
#  'water util compani': 0.3,
#  'car repair mainten': 0.7,
#  'water treatment plant': 0.3,
#  'car servic': 0.1,
#  'cattl market': 0.1,
#  'sewag dispos servic': 0.3,
#  'certifi public account': 0.1,
#  'govern offic': 0.5,
#  'chariti': 0.1,
#  'air condit system supplier': 0.0,
#  'chemic industri': 0.3,
#  'chemic manufactur': 0.4,
#  'titl compani': 0.1,
#  'chemic plant': 0.4,
#  'properti manag compani': 0.0,
#  'custom home builder': 0.3,
#  'window instal servic': 0.0,
#  'fire damag restor servic': 0.0,
#  'equip rental agenc': 0.2,
#  'chemic wholesal': 0.0,
#  'financi planner': 0.0,
#  'telecommun servic provid': 0.2,
#  'energi equip solut': 0.0,
#  'chiropractor': 0.3,
#  'steel distributor': 0.0,
#  'citi govern offic': 0.5,
#  'crane servic': 0.1,
#  'garag door supplier': 0.1,
#  'industri door supplier': 0.3,
#  'citi town hall': 0.1,
#  'cloth wholesal': 0.1,
#  'coin oper laundri equip supplier': 0.4,
#  'metal supplier': 0.0,
#  'glass shop': 0.0,
#  'colleg': 0.1,
#  'side contractor': 0.4,
#  'commerci printer': 0.1,
#  'storag facil': 0.4,
#  'commun tower': 0.1,
#  'janitori servic': 0.2,
#  'comput consult': 0.1,
#  'fire protect system supplier': 0.1,
#  'elev servic': 0.1,
#  'industri equip supplier': 0.0,
#  'dri wall contractor': 0.2,
#  'insul contractor': 0.2,
#  'concret contractor': 0.5,
#  'scaffold rental servic': 0.2,
#  'construct compani': 0.2,
#  'floor store': 0.3,
#  'floor contractor': 0.3,
#  'tile contractor': 0.4,
#  'tile manufactur': 0.0,
#  'glass mirror shop': 0.0,
#  'construct materi wholesal': 0.0,
#  'gutter clean servic': 0.3,
#  'sheet metal contractor': 0.3,
#  'consult': 0.7,
#  'contain servic': 0.0,
#  'septic system servic': 0.2,
#  'corpor campu': 0.1,
#  'water damag restor servic': 0.0,
#  'welder': 0.0,
#  'corpor offic': 0.1,
#  'anim': 0.4,
#  'anim feed store': 0.0,
#  'anim protect organ': 0.0,
#  'brew suppli store': 0.0,
#  'cosmet store': 0.3,
#  'counti govern offic': 0.5,
#  'sugar factori': 0.5,
#  'confectioneri wholesal': 0.6,
#  'financi institut': 0.0,
#  'candi store': 0.2,
#  'confectioneri': 0.2,
#  'chocol factori': 0.5,
#  'chocol shop': 0.5,
#  'courier servic': 0.1,
#  'cowork space': 0.1,
#  'frozen food manufactur': 0.2,
#  'beverag distributor': 0.0,
#  'agricultur organ': 0.0,
#  'dairi store': 0.0,
#  'dairi': 0.3,
#  'ice cream shop': 0.2,
#  'medic laboratori': 0.2,
#  'demolit contractor': 0.2,
#  'meat processor': 0.4,
#  'fmcg manufactur': 0.0,
#  'garbag collect servic': 0.2,
#  'wholesal bakeri': 0.6,
#  'dentist': 0.1,
#  'dessert shop': 0.0,
#  'cupcak shop': 0.0,
#  'nut store': 0.3,
#  'wholesal grocer': 0.4,
#  'design engin': 0.1,
#  'busi busi servic': 0.5,
#  'condiment supplier': 0.8,
#  'digit print servic': 0.4,
#  'culinari school': 0.4,
#  'import': 0.0,
#  'bottl water supplier': 0.3,
#  'coffe roaster': 0.0,
#  'packag suppli store': 0.0,
#  'ice supplier': 0.6,
#  'breweri': 0.6,
#  'winemak compani': 0.0,
#  'distilleri': 0.6,
#  'disabl servic support organis': 0.2,
#  'district govern offic': 0.5,
#  'air filter supplier': 0.3,
#  'tire shop': 0.1,
#  'fasten supplier': 0.6,
#  'fabric product manufactur': 0.0,
#  'textil': 0.2,
#  'textil export': 0.2,
#  'textil engin': 0.2,
#  'fabric store': 0.0,
#  'knit shop': 0.2,
#  'doctor': 0.2,
#  'lamin servic': 0.0,
#  'plastic resin manufactur': 0.1,
#  'carpet manufactur': 0.1,
#  'upholsteri shop': 0.0,
#  'busi administr servic': 0.0,
#  'furnitur store': 0.1,
#  'dri cleaner': 0.0,
#  'packag compani': 0.1,
#  'duti free store': 0.5,
#  'commerc servic': 0.0,
#  'cabl compani': 0.0,
#  'educ': 0.1,
#  'outlet store': 0.0,
#  'lingeri store': 0.1,
#  'cloth fabric manufactur': 0.0,
#  'educ center': 0.1,
#  'uniform store': 0.1,
#  'men cloth store': 0.6,
#  'cloth store': 0.6,
#  'women cloth store': 0.6,
#  'western apparel store': 0.0,
#  'costum store': 0.0,
#  'game store': 0.2,
#  'hat shop': 0.0,
#  'leather good manufactur': 0.1,
#  'educ consult': 0.1,
#  'leather export': 0.2,
#  'shoe store': 0.1,
#  'boutiqu': 0.0,
#  'leather wholesal': 0.2,
#  'handbag shop': 0.1,
#  'electron store': 0.2,
#  'luggag store': 0.2,
#  'build materi store': 0.3,
#  'saw mill': 0.2,
#  'electr engin': 0.0,
#  'deck builder': 0.1,
#  'concret product supplier': 0.5,
#  'plywood supplier': 0.5,
#  'electr instal servic': 0.0,
#  'truss manufactur': 0.5,
#  'door supplier': 0.1,
#  'wood lamin floor supplier': 0.7,
#  'aircraft suppli store': 0.0,
#  'modular home builder': 0.0,
#  'portabl build manufactur': 0.0,
#  'modular home dealer': 0.2,
#  'mulch supplier': 0.0,
#  'electrician': 0.1,
#  'paper mill': 0.4,
#  'energi supplier': 0.8,
#  'engin': 0.2,
#  'print shop': 0.4,
#  'custom label printer': 0.1,
#  'market': 0.1,
#  'market agenc': 0.0,
#  'engin consult': 0.1,
#  'entertain': 0.0,
#  'envelop supplier': 0.1,
#  'oil refineri': 0.2,
#  'record studio': 0.4,
#  'environ renew natur resourc': 0.0,
#  'finish materi supplier': 0.2,
#  'event ticket seller': 0.0,
#  'waterproof compani': 0.0,
#  'auto part store': 0.1,
#  'heat oil supplier': 0.1,
#  'famili practic physician': 0.2,
#  'machin manufactur': 0.0,
#  'industri supplier': 0.0,
#  'weld suppli store': 0.0,
#  'dri ice supplier': 0.3,
#  'privat equiti firm': 0.0,
#  'famili servic center': 0.1,
#  'feder govern offic': 0.5,
#  'vitamin supplement store': 0.2,
#  'feed manufactur': 0.2,
#  'medic equip supplier': 0.0,
#  'medic suppli store': 0.0,
#  'medic clinic': 0.1,
#  'research institut': 0.4,
#  'biochem supplier': 0.0,
#  'fiber optic product supplier': 0.1,
#  'paint manufactur': 0.2,
#  'equip supplier': 0.0,
#  'food': 0.1,
#  'pipe supplier': 0.4,
#  'oil field equip supplier': 0.2,
#  'food broker': 0.0,
#  'food manufactur': 0.2,
#  'food process compani': 0.1,
#  'fenc suppli store': 0.1,
#  'food produc': 0.1,
#  'forestri servic': 0.1,
#  'foundri': 0.6,
#  'wholesal jewel': 0.2,
#  'cooki shop': 0.4,
#  'truck rental agenc': 0.3,
#  'fruit veget process': 0.4,
#  'kitchen suppli store': 0.0,
#  'hydraul equip supplier': 0.0,
#  'irrig equip supplier': 0.1,
#  'bear supplier': 0.3,
#  'metallurgi compani': 0.1,
#  'plastic inject mold servic': 0.0,
#  'gener contractor': 0.0,
#  'gener hospit': 0.1,
#  'tool manufactur': 0.5,
#  'industri design compani': 0.2,
#  'hyundai dealer': 0.0,
#  'glass industri': 0.4,
#  'polym supplier': 0.0,
#  'print equip suppli': 0.0,
#  'toner cartridg supplier': 0.2,
#  'printer repair servic': 0.1,
#  'fuel supplier': 0.0,
#  'glass manufactur': 0.4,
#  'plastic bag supplier': 1.0,
#  'glasswar manufactur': 0.1,
#  'polythen plastic sheet supplier': 1.0,
#  'pvc industri': 0.0,
#  'countertop store': 0.0,
#  'cabinet store': 0.1,
#  'fiberglass supplier': 0.1,
#  'golf cart dealer': 0.3,
#  'auto repair shop': 0.7,
#  'hose supplier': 0.3,
#  'rubber product supplier': 0.5,
#  'automot': 0.0,
#  'commerci refriger supplier': 0.0,
#  'golf club': 0.5,
#  'golf cours': 0.2,
#  'green energi supplier': 0.8,
#  'greenhous': 0.0,
#  'auto glass shop': 0.1,
#  'light manufactur': 0.4,
#  'cement manufactur': 0.5,
#  'brick manufactur': 0.5,
#  'natur stone supplier': 0.0,
#  'gym': 0.1,
#  'marbl supplier': 0.1,
#  'corpor gift supplier': 0.2,
#  'shipbuild repair compani': 0.0,
#  'construct mainten offic': 0.2,
#  'boiler manufactur': 0.3,
#  'contain supplier': 0.4,
#  'home construct': 0.4,
#  'health': 0.2,
#  'heart hospit': 0.1,
#  'spring supplier': 0.2,
#  'electr util manufactur': 0.0,
#  'aircraft manufactur': 0.5,
#  'metal heat treat servic': 0.3,
#  'plate servic': 0.0,
#  'autom compani': 0.0,
#  'heat contractor': 0.2,
#  'plumb suppli store': 0.0,
#  'gun shop': 0.1,
#  'ammunit supplier': 0.6,
#  'pipe manufactur': 0.5,
#  'school': 0.1,
#  'fire protect equip supplier': 0.1,
#  'agricultur machineri manufactur': 0.4,
#  'lawn mower store': 0.0,
#  'lawn irrig equip supplier': 0.1,
#  'financi consult': 0.0,
#  'helicopt charter': 0.3,
#  'packag machineri': 0.1,
#  'histor landmark': 0.4,
#  'electron manufactur': 0.6,
#  'graphic design': 0.4,
#  'eye care center': 0.1,
#  'optic product manufactur': 0.2,
#  'imag consult': 0.1,
#  'clean product supplier': 0.0,
#  'fireplac store': 0.0,
#  'home builder': 0.4,
#  'tool die shop': 0.5,
#  'metal stamp servic': 0.3,
#  'environment organ': 0.3,
#  'food process equip': 0.0,
#  'loan agenc': 0.2,
#  'power plant equip supplier': 0.0,
#  'home good store': 0.2,
#  'engin rebuild servic': 0.0,
#  'air compressor supplier': 0.3,
#  'honda dealer': 0.2,
#  'elev manufactur': 0.2,
#  'crane dealer': 0.0,
#  'crane rental agenc': 0.2,
#  'compound build': 0.0,
#  'tractor dealer': 0.0,
#  'furnac part supplier': 0.0,
#  'heat equip supplier': 0.0,
#  'pneumat tool supplier': 0.0,
#  'truck stop': 0.1,
#  'comput hardwar manufactur': 0.3,
#  'satellit commun servic': 0.1,
#  'hospit': 0.1,
#  'electron compani': 0.1,
#  'electron part supplier': 0.0,
#  'hvac contractor': 0.2,
#  'industri engin': 0.3,
#  'contact lens supplier': 0.1,
#  'inform servic': 0.4,
#  'build': 0.2,
#  'water work equip supplier': 0.0,
#  'measur instrument supplier': 0.8,
#  'scientif equip supplier': 0.0,
#  'medic center': 0.0,
#  'watch manufactur': 0.0,
#  'corpor entertain servic': 0.0,
#  'insur': 0.4,
#  'record compani': 0.4,
#  'video duplic servic': 0.1,
#  'insur agenc': 0.4,
#  'light store': 0.4,
#  'light wholesal': 0.4,
#  'entertain agenc': 0.1,
#  'insur broker': 0.4,
#  'electr equip supplier': 0.0,
#  'electr motor store': 0.0,
#  'railroad compani': 0.2,
#  'electr suppli store': 0.0,
#  'insur compani': 0.4,
#  'factori equip supplier': 0.0,
#  'invest servic': 0.5,
#  'laser equip supplier': 0.0,
#  'execut suit rental agenc': 0.2,
#  'truck dealer': 0.0,
#  'motor vehicl dealer': 0.2,
#  'car dealer': 0.2,
#  'truck topper supplier': 0.0,
#  'polic suppli store': 0.5,
#  'iron steel contractor': 0.2,
#  'fire depart equip supplier': 0.1,
#  'tow equip provid': 0.2,
#  'logist servic': 0.2,
#  'trailer manufactur': 0.4,
#  'trailer dealer': 0.0,
#  'dealer': 0.3,
#  'auto spring shop': 0.0,
#  'auto upholster': 0.0,
#  'auto bodi part supplier': 0.0,
#  'car factori': 0.0,
#  'freight forward servic': 0.1,
#  'brake shop': 0.3,
#  'railroad equip supplier': 0.0,
#  'jewelri equip supplier': 0.9,
#  'boat builder': 0.2,
#  'ship build': 0.2,
#  'marin suppli store': 0.0,
#  'boat dealer': 0.3,
#  'kawasaki motorcycl dealer': 0.3,
#  'knife manufactur': 0.0,
#  'labor union': 0.5,
#  'furnitur maker': 0.6,
#  'bank financ': 0.2,
#  'furnitur manufactur': 0.6,
#  'logist': 0.5,
#  'massag suppli store': 0.0,
#  'telecommun equip supplier': 0.0,
#  'babi store': 0.0,
#  'mold supplier': 0.1,
#  'offic equip supplier': 0.0,
#  'offic furnitur store': 0.4,
#  'store equip supplier': 0.0,
#  'laboratori': 0.1,
#  'health beauti shop': 0.1,
#  'learn center': 0.1,
#  'dental laboratori': 0.2,
#  'land surveyor': 0.1,
#  'educ suppli store': 0.1,
#  'jewelri store': 0.2,
#  'playground equip supplier': 0.0,
#  'outdoor sport store': 0.3,
#  'toy store': 0.2,
#  'secur servic': 0.3,
#  'sign shop': 0.1,
#  'offic suppli store': 0.1,
#  'landscap': 0.5,
#  'gasket manufactur': 0.7,
#  'piano maker': 0.1,
#  'piano store': 0.1,
#  'funer home': 0.2,
#  'monument': 0.0,
#  'book publish': 0.6,
#  'wig shop': 0.1,
#  'laundromat': 0.1,
#  'auto wrecker': 0.1,
#  'auto part market': 0.2,
#  'jeep dealer': 0.2,
#  'restaur suppli store': 0.0,
#  'roof suppli store': 0.0,
#  'law firm': 0.1,
#  'build materi market': 0.4,
#  'camera store': 0.0,
#  'lawn care servic': 0.0,
#  'comput secur servic': 0.0,
#  'comput store': 0.0,
#  'design agenc': 0.4,
#  'diagnost center': 0.2,
#  'laboratori equip supplier': 0.1,
#  'home theater store': 0.0,
#  'metal industri supplier': 0.0,
#  'landscap suppli store': 0.0,
#  'applianc part supplier': 0.0,
#  'vacuum cleaner store': 0.1,
#  'audio visual equip supplier': 0.1,
#  'lawyer': 0.4,
#  'cell phone store': 0.0,
#  'bathroom suppli store': 0.0,
#  'leas servic': 0.0,
#  'construct machin dealer': 0.0,
#  'dairi farm equip supplier': 0.0,
#  'propan supplier': 0.0,
#  'legal servic': 0.4,
#  'janitori equip supplier': 0.2,
#  'life insur agenc': 0.4,
#  'railroad contractor': 0.0,
#  'swim pool suppli store': 0.5,
#  'light bulb supplier': 0.4,
#  'linen store': 0.1,
#  'metal construct compani': 0.5,
#  'local govern offic': 0.5,
#  'log contractor': 0.0,
#  'machin shop': 0.3,
#  'hotel suppli store': 0.0,
#  'import export compani': 0.0,
#  'sew compani': 0.1,
#  'research foundat': 0.4,
#  'machineri part manufactur': 0.5,
#  'sport accessori wholesal': 0.0,
#  'fashion design': 0.4,
#  'chees manufactur': 0.0,
#  'chees shop': 0.0,
#  'ship mail': 0.1,
#  'wholesal food store': 0.0,
#  'organ food store': 0.0,
#  'pie shop': 0.1,
#  'auction hous': 0.5,
#  'livestock auction hous': 0.1,
#  'cotton export': 0.3,
#  'plastic wholesal': 0.0,
#  'mail servic': 0.1,
#  'manufactur': 0.7,
#  'station': 0.2,
#  'beer distributor': 0.2,
#  'alcohol beverag wholesal': 0.1,
#  'religi good store': 0.1,
#  'book wholesal': 0.6,
#  'masonri suppli store': 0.1,
#  'wholesal florist': 0.2,
#  'florist': 0.1,
#  'marin engin': 0.1,
#  'paint store': 0.1,
#  'use auto part store': 0.1,
#  'masonri contractor': 0.4,
#  'use car dealer': 0.2,
#  'use truck dealer': 0.2,
#  'massag therapist': 0.3,
#  'materi handl equip supplier': 0.0,
#  'marina': 0.6,
#  'meat packer': 0.1,
#  'mattress store': 0.0,
#  'blind shop': 0.1,
#  'interior design': 0.4,
#  'window treatment store': 0.2,
#  'applianc store': 0.2,
#  'health food store': 0.2,
#  'direct mail advertis': 0.2,
#  'meat wholesal': 0.3,
#  'butcher shop deli': 0.1,
#  'italian groceri store': 0.2,
#  'food servic': 0.3,
#  'groceri deliveri servic': 0.1,
#  'wine store': 0.1,
#  'liquor store': 0.1,
#  'kiosk': 0.0,
#  'optometrist': 0.3,
#  'optician': 0.1,
#  'mechan contractor': 0.2,
#  'mechan engin': 0.1,
#  'cafe': 0.2,
#  'jewel': 0.1,
#  'leather good store': 0.1,
#  'gift shop': 0.2,
#  'craft store': 0.1,
#  'hobbi store': 0.3,
#  'fabric wholesal': 0.0,
#  'scrap metal dealer': 0.0,
#  'quilt shop': 0.1,
#  'sheet music store': 0.4,
#  'music instrument manufactur': 0.1,
#  'music store': 0.4,
#  'music instrument store': 0.4,
#  'band': 0.1,
#  'bookstor': 0.0,
#  'art museum': 0.4,
#  'newsstand': 0.1,
#  'medic equip manufactur': 0.5,
#  'fashion accessori store': 0.6,
#  'discount store': 0.0,
#  'cemeteri': 0.1,
#  'stop': 0.0,
#  'varieti store': 0.0,
#  'thrift store': 0.1,
#  'medic group': 0.0,
#  'donat center': 0.0,
#  'pet store': 0.5,
#  'art galleri': 0.1,
#  'art dealer': 0.2,
#  'hous develop': 0.2,
#  'mobil home dealer': 0.2,
#  'conveni store': 0.2,
#  'medic offic': 0.0,
#  'medic technolog manufactur': 0.0,
#  'children furnitur store': 0.1,
#  'mental health clinic': 0.2,
#  'airlin': 0.0,
#  'aviat consult': 0.0,
#  'travel agenc': 0.4,
#  'travel servic': 0.4,
#  'airport': 0.2,
#  'mental health servic': 0.2,
#  'ship compani': 0.0,
#  'metal fabric': 0.5,
#  'cruis line compani': 0.0,
#  'tow servic': 0.2,
#  'ferri termin': 0.0,
#  'ferri servic': 0.0,
#  'metal finish': 0.3,
#  'boat tour agenc': 0.1,
#  'move compani': 0.1,
#  'move storag servic': 0.1,
#  'state depart transport': 0.0,
#  'depart transport': 0.0,
#  'handicap transport servic': 0.2,
#  'railway servic': 0.0,
#  'train station': 0.0,
#  'depot': 0.0,
#  'charter': 0.1,
#  'metal process compani': 0.6,
#  'mix use': 0.0,
#  'motorcycl shop': 0.2,
#  'limousin servic': 0.2,
#  'chauffeur servic': 0.0,
#  'school servic': 0.0,
#  'airport shuttl servic': 0.2,
#  'tourist inform center': 0.0,
#  'carriag ride servic': 0.0,
#  'cruis agenc': 0.1,
#  'tourist attract': 0.1,
#  'ski resort': 0.6,
#  'ski area': 0.1,
#  'fix base oper': 0.0,
#  'aircraft mainten compani': 0.1,
#  'motorsport store': 0.0,
#  'boat rental servic': 0.6,
#  'util trailer dealer': 0.0,
#  'forklift dealer': 0.0,
#  'municip administr offic': 0.0,
#  'nephrologist': 0.1,
#  'coach compani': 0.0,
#  'ship servic': 0.0,
#  'ship mail servic': 0.0,
#  'newspap publish': 0.6,
#  'shred servic': 0.0,
#  'nuclear power compani': 0.9,
#  'nurs home': 0.0,
#  'media compani': 0.4,
#  'multimedia electron book publish': 0.0,
#  'internet market servic': 0.1,
#  'greet card shop': 0.1,
#  'theme park': 0.2,
#  'film product compani': 0.2,
#  'obstetrician gynecologist': 0.1,
#  'movi studio': 0.0,
#  'video product servic': 0.6,
#  'movi theater': 0.5,
#  'theater compani': 0.3,
#  'perform art theater': 0.4,
#  'occup safeti health': 0.0,
#  'offic space rental agenc': 0.0,
#  'commerci real estat agenc': 0.1,
#  'art school': 0.2,
#  'music publish': 0.1,
#  'print music publish': 0.0,
#  'home audio store': 0.0,
#  'musician': 0.1,
#  'music manag promot': 0.1,
#  'video edit servic': 0.2,
#  'offic suppli wholesal': 0.0,
#  'offici resid': 0.0,
#  'orthoped clinic': 0.2,
#  'painter': 0.0,
#  'paint': 0.1,
#  'telephon compani': 0.0,
#  'media hous': 0.8,
#  'paper distributor': 0.0,
#  'news servic': 0.1,
#  'public librari': 0.0,
#  'law librari': 0.4,
#  'museum': 0.4,
#  'feder reserv bank': 0.1,
#  'credit union': 0.2,
#  'atm': 0.1,
#  'pave contractor': 0.2,
#  'mortgag lender': 0.3,
#  'invest bank': 0.0,
#  'check cash servic': 0.2,
#  'stock broker': 0.0,
#  'health consult': 0.6,
#  'health insur agenc': 0.6,
#  'payrol servic': 0.4,
#  'pediatrician': 0.2,
#  'human resourc consult': 0.7,
#  'pest control servic': 0.3,
#  'pet board servic': 0.5,
#  'pet care': 0.1,
#  'loss adjust': 0.3,
#  'pharmaceut compani': 0.4,
#  'pharmaceut product wholesal': 0.1,
#  'pharmaci': 0.1,
#  'educ institut': 0.1,
#  'retir commun': 0.2,
#  'fratern organ': 0.1,
#  'photo lab': 0.0,
#  'properti invest': 0.0,
#  'photograph': 0.3,
#  'photographi school': 0.2,
#  'star hotel': 0.4,
#  'convent center': 0.0,
#  'real estat apprais': 0.4,
#  'photographi servic': 0.2,
#  'resort hotel': 0.4,
#  'real estat consult': 0.1,
#  'car rental agenc': 0.3,
#  'car leas servic': 0.0,
#  'ford dealer': 0.2,
#  'car financ loan compani': 0.6,
#  'trailer rental servic': 0.2,
#  'furnitur rental servic': 0.2,
#  'tuxedo shop': 0.0,
#  'dress tuxedo rental servic': 0.6,
#  'wed store': 0.0,
#  'video store': 0.1,
#  'movi rental': 0.0,
#  'photographi studio': 0.2,
#  'home health care servic': 0.1,
#  'skateboard shop': 0.0,
#  'event technolog servic': 0.0,
#  'parti equip rental servic': 0.6,
#  'construct machin rental servic': 0.1,
#  'audio visual equip rental servic': 0.0,
#  'ship equip industri': 0.0,
#  'physic therapi clinic': 0.2,
#  'plastic fabric compani': 1.0,
#  'plastic product supplier': 1.0,
#  'auto tag agenc': 0.2,
#  'depart motor vehicl': 0.0,
#  'notari public': 0.3,
#  'privat investig': 0.4,
#  'escrow servic': 0.0,
#  'real estat agent': 0.1,
#  'playground': 0.0,
#  'plumber': 0.1,
#  'port author': 0.4,
#  'portrait studio': 0.2,
#  'post offic': 0.1,
#  'profession servic': 0.1,
#  'univers hospit': 0.1,
#  'public relat firm': 0.1,
#  'civil engin compani': 0.1,
#  'draft servic': 0.7,
#  'pump supplier': 0.9,
#  'interior construct contractor': 0.0,
#  'carpet clean servic': 0.3,
#  'exhibit planner': 0.0,
#  'decal supplier': 0.0,
#  'stage light equip supplier': 0.4,
#  'event manag compani': 0.1,
#  'radio broadcast': 0.0,
#  'comput support servic': 0.4,
#  'ravin': 0.0,
#  'employ center': 0.1,
#  'nation health foundat': 0.1,
#  'real estat develop': 0.0,
#  'advertis agenc': 0.0,
#  'promot product supplier': 0.0,
#  'advertis servic': 0.1,
#  'record storag facil': 0.0,
#  'fund manag compani': 0.1,
#  'recreat center': 0.6,
#  'bakeri': 0.6,
#  'databas manag compani': 0.0,
#  'market research': 0.2,
#  'recycl center': 0.0,
#  'region govern offic': 0.4,
#  'rehabilit center': 0.0,
#  'religi institut': 0.1,
#  'religi organ': 0.1,
#  'repair servic': 0.5,
#  'emerg veterinarian servic': 0.2,
#  'pet sitter': 0.1,
#  'research product develop': 0.4,
#  'build societi': 0.2,
#  'valet park servic': 0.5,
#  'nurs agenc': 0.0,
#  'execut search firm': 0.2,
#  'recruit': 0.4,
#  'temp agenc': 0.1,
#  'health center': 0.0,
#  'restaur': 0.4,
#  'roof contractor': 0.4,
#  'sport nutrit store': 0.1,
#  'credit report agenc': 0.2,
#  'automobil storag facil': 0.4,
#  'debt collect agenc': 0.3,
#  'park': 0.2,
#  'court report': 0.5,
#  'tour agenc': 0.4,
#  'tour oper': 0.4,
#  'convent inform bureau': 0.1,
#  'balloon ride tour agenc': 0.1,
#  'secur guard servic': 0.5,
#  'locksmith': 0.2,
#  'commerci clean servic': 0.3,
#  'blast clean servic': 0.3,
#  'confer center': 0.0,
#  'safeti equip supplier': 0.0,
#  'garbag dump': 0.4,
#  'sanit servic': 0.1,
#  'garbag dump servic': 0.0,
#  'environment health servic': 0.0,
#  'portabl toilet supplier': 0.2,
#  'public work depart': 0.1,
#  'school district offic': 0.1,
#  'sailmak': 0.0,
#  'commun colleg': 0.1,
#  'salvag yard': 0.1,
#  'busi school': 0.0,
#  'trade school': 0.4,
#  'privat univers': 0.0,
#  'comput train school': 0.2,
#  'school suppli store': 0.0,
#  'screen printer': 0.3,
#  'media consult': 0.3,
#  'beauti school': 0.4,
#  'flight school': 0.4,
#  'seaport': 0.0,
#  'secur system supplier': 0.2,
#  'middl school': 0.1,
#  'nonprofit': 0.0,
#  'shoot rang': 0.1,
#  'soccer club': 0.1,
#  'camp': 0.2,
#  'dive contractor': 0.0,
#  'languag school': 0.5,
#  'english languag school': 0.5,
#  'preschool': 0.1,
#  'self storag facil': 0.1,
#  'semi conductor supplier': 0.0,
#  'drive school': 0.5,
#  'truck school': 0.1,
#  'senior citizen center': 0.0,
#  'servic': 0.0,
#  'children hospit': 0.1,
#  'dental suppli store': 0.2,
#  'shipyard': 0.2,
#  'orthodox synagogu': 0.1,
#  'short term apart rental agenc': 0.0,
#  'nutritionist': 0.1,
#  'ophthalmologist': 0.0,
#  'ophthalmolog clinic': 0.2,
#  'social servic organ': 0.3,
#  'social welfar center': 0.3,
#  'solar energi compani': 0.8,
#  'solar energi equip supplier': 0.8,
#  'special educ school': 0.1,
#  'podiatrist': 0.2,
#  'reproduct health clinic': 0.5,
#  'sport good store': 0.3,
#  'dialysi center': 0.5,
#  'sport complex': 0.0,
#  'well program': 0.0,
#  'sportswear store': 0.0,
#  'privat hospit': 0.1,
#  'radiologist': 0.0,
#  'medic diagnost imag center': 0.2,
#  'ray lab': 0.2,
#  'blood bank': 0.2,
#  'stainless steel plant': 0.1,
#  'state agenc': 0.2,
#  'heliport': 0.0,
#  'health care compani': 0.0,
#  'psychiatr hospit': 0.1,
#  'state govern offic': 0.5,
#  'medic institut': 0.1,
#  'steel construct compani': 0.1,
#  'clean servic': 0.3,
#  'steel drum supplier': 0.0,
#  'assist live facil': 0.2,
#  'steel erector': 0.1,
#  ...}

# %%
calc_pre_rec_at_n(ret_docs_dic, queries_dic, n=-1)[1]
# Out:
# {'home improv store': 0.0,
#  'diesel fuel supplier': 0.0,
#  'church': 1.0,
#  'farm': 0.0,
#  'seed supplier': 0.0,
#  'account': 1.0,
#  'truck compani': 1.0,
#  'export': 0.0,
#  'grain elev': 0.25,
#  'popcorn store': 0.333,
#  'agricultur servic': 0.667,
#  'warehous': 1.0,
#  'agricultur product': 0.0,
#  'ranch': 1.0,
#  'hold compani': 1.0,
#  'farm equip supplier': 0.0,
#  'store': 0.0,
#  'groceri store': 1.0,
#  'rice mill': 0.857,
#  'food product supplier': 0.0,
#  'account firm': 1.0,
#  'produc market': 0.333,
#  'pet suppli store': 1.0,
#  'wholesal': 0.0,
#  'produc wholesal': 0.444,
#  'distribut servic': 0.0,
#  'crop grower': 0.857,
#  'addict treatment center': 0.0,
#  'natur good store': 0.0,
#  'orchard': 0.222,
#  'lumber store': 0.0,
#  'mine': 0.833,
#  'transport servic': 1.0,
#  'invest compani': 0.0,
#  'fruit wholesal': 0.111,
#  'real estat agenc': 1.0,
#  'event venu': 0.0,
#  'frozen dessert supplier': 0.6,
#  'wine wholesal import': 1.0,
#  'wineri': 1.0,
#  'aerospac compani': 1.0,
#  'cold storag facil': 1.0,
#  'employ agenc': 0.75,
#  'plant nurseri': 0.5,
#  'air condit contractor': 0.667,
#  'air condit repair servic': 0.0,
#  'fruit veget wholesal': 0.167,
#  'aircraft rental servic': 0.0,
#  'monasteri': 1.0,
#  'allergist': 0.5,
#  'herb shop': 0.0,
#  'aluminum supplier': 1.0,
#  'ambul servic': 0.333,
#  'wholesal plant nurseri': 0.833,
#  'amus machin supplier': 0.0,
#  'anim hospit': 0.0,
#  'farmer market': 0.167,
#  'vapor store': 1.0,
#  'cigar shop': 0.2,
#  'tobacco shop': 0.0,
#  'well drill contractor': 0.0,
#  'librari': 0.75,
#  'apart build': 0.0,
#  'apart rental agenc': 0.0,
#  'dairi farm': 0.0,
#  'architect': 0.25,
#  'organ farm': 0.143,
#  'architectur design': 0.375,
#  'architectur firm': 0.75,
#  'livestock produc': 0.0,
#  'dairi supplier': 0.0,
#  'biotechnolog compani': 0.5,
#  'artist': 1.0,
#  'egg supplier': 1.0,
#  'poultri farm': 0.0,
#  'chicken hatcheri': 0.8,
#  'art organ': 1.0,
#  'associ organ': 1.0,
#  'food store': 1.0,
#  'deli': 0.0,
#  'bank': 0.75,
#  'fish process': 0.0,
#  'fish farm': 0.333,
#  'seafood wholesal': 0.778,
#  'tropic fish store': 1.0,
#  'non profit organ': 0.0,
#  'econom develop agenc': 0.8,
#  'seafood market': 0.333,
#  'honey farm': 0.0,
#  'hors breeder': 0.0,
#  'asphalt contractor': 1.0,
#  'livestock dealer': 0.0,
#  'depart store': 1.0,
#  'mill': 0.0,
#  'atv dealer': 1.0,
#  'audio visual consult': 1.0,
#  'pallet supplier': 0.286,
#  'wood supplier': 0.0,
#  'hardwar store': 0.25,
#  'furnitur wholesal': 0.0,
#  'auditor': 0.25,
#  'oil natur compani': 0.4,
#  'auto bodi shop': 0.333,
#  'boat repair shop': 0.5,
#  'associ': 0.6,
#  'rail contractor': 0.0,
#  'publish': 1.0,
#  'pond suppli store': 0.0,
#  'agricultur cooper': 0.0,
#  'print equip supplier': 0.2,
#  'auto insur agenc': 1.0,
#  'altern fuel station': 1.0,
#  'auto part manufactur': 0.0,
#  'foundat': 1.0,
#  'fertil supplier': 1.0,
#  'farm compani': 0.0,
#  'financ broker': 0.0,
#  'fire station': 0.143,
#  'environment consult': 1.0,
#  'civil engin': 1.0,
#  'fire protect servic': 0.143,
#  'compani': 0.0,
#  'oilfield': 0.0,
#  'banquet hall': 0.333,
#  'mine compani': 0.833,
#  'coalfield': 0.0,
#  'steel fabric': 0.0,
#  'quarri': 0.5,
#  'gold mine compani': 0.667,
#  'high rise build': 1.0,
#  'basketbal club': 0.333,
#  'gold dealer': 0.0,
#  'batteri manufactur': 0.375,
#  'electr util compani': 0.0,
#  'environment program': 0.0,
#  'offic': 0.0,
#  'stone supplier': 0.25,
#  'aggreg supplier': 0.0,
#  'sand gravel supplier': 0.167,
#  'build materi supplier': 1.0,
#  'beauti suppli store': 0.6,
#  'crush stone supplier': 0.25,
#  'rock shop': 0.0,
#  'road construct compani': 1.0,
#  'market consult': 1.0,
#  'blood test servic': 0.625,
#  'contractor': 1.0,
#  'excav contractor': 1.0,
#  'asphalt mix plant': 0.4,
#  'readi mix concret supplier': 1.0,
#  'sand plant': 0.167,
#  'bmw dealer': 1.0,
#  'bookbind': 1.0,
#  'garden center': 1.0,
#  'abras supplier': 0.0,
#  'granit supplier': 0.2,
#  'drill contractor': 0.0,
#  'bpo compani': 0.3,
#  'oil explor servic': 1.0,
#  'build complex': 0.0,
#  'construct equip supplier': 0.0,
#  'mine equip': 0.0,
#  'ticket agenc': 0.75,
#  'busi center': 0.1,
#  'skyscrap': 0.0,
#  'softwar compani': 1.0,
#  'busi develop servic': 0.143,
#  'busi manag consult': 1.0,
#  'cabinet maker': 1.0,
#  'call center': 0.2,
#  'cancer treatment center': 0.0,
#  'power plant consult': 0.0,
#  'busi park': 0.4,
#  'petroleum product compani': 1.0,
#  'park lot': 0.2,
#  'water util compani': 1.0,
#  'car repair mainten': 0.778,
#  'water treatment plant': 1.0,
#  'car servic': 0.111,
#  'cattl market': 0.333,
#  'sewag dispos servic': 1.0,
#  'certifi public account': 0.25,
#  'govern offic': 0.833,
#  'chariti': 0.333,
#  'air condit system supplier': 0.0,
#  'chemic industri': 0.6,
#  'chemic manufactur': 0.8,
#  'titl compani': 0.25,
#  'chemic plant': 0.8,
#  'properti manag compani': 0.0,
#  'custom home builder': 0.75,
#  'window instal servic': 0.0,
#  'fire damag restor servic': 0.0,
#  'equip rental agenc': 0.5,
#  'chemic wholesal': 0.0,
#  'financi planner': 0.0,
#  'telecommun servic provid': 1.0,
#  'energi equip solut': 0.0,
#  'chiropractor': 0.5,
#  'steel distributor': 0.0,
#  'citi govern offic': 0.833,
#  'crane servic': 0.071,
#  'garag door supplier': 0.167,
#  'industri door supplier': 0.5,
#  'citi town hall': 0.167,
#  'cloth wholesal': 0.25,
#  'coin oper laundri equip supplier': 1.0,
#  'metal supplier': 0.0,
#  'glass shop': 0.0,
#  'colleg': 1.0,
#  'side contractor': 0.5,
#  'commerci printer': 0.25,
#  'storag facil': 1.0,
#  'commun tower': 0.333,
#  'janitori servic': 0.4,
#  'comput consult': 0.25,
#  'fire protect system supplier': 0.143,
#  'elev servic': 0.071,
#  'industri equip supplier': 0.0,
#  'dri wall contractor': 0.333,
#  'insul contractor': 0.333,
#  'concret contractor': 0.625,
#  'scaffold rental servic': 0.5,
#  'construct compani': 1.0,
#  'floor store': 1.0,
#  'floor contractor': 0.5,
#  'tile contractor': 0.667,
#  'tile manufactur': 0.0,
#  'glass mirror shop': 0.0,
#  'construct materi wholesal': 0.0,
#  'gutter clean servic': 0.6,
#  'sheet metal contractor': 0.5,
#  'consult': 1.0,
#  'contain servic': 0.0,
#  'septic system servic': 0.5,
#  'corpor campu': 0.333,
#  'water damag restor servic': 0.0,
#  'welder': 0.0,
#  'corpor offic': 0.333,
#  'anim': 1.0,
#  'anim feed store': 0.0,
#  'anim protect organ': 0.0,
#  'brew suppli store': 0.0,
#  'cosmet store': 0.6,
#  'counti govern offic': 0.833,
#  'sugar factori': 1.0,
#  'confectioneri wholesal': 0.667,
#  'financi institut': 0.0,
#  'candi store': 0.333,
#  'confectioneri': 0.333,
#  'chocol factori': 1.0,
#  'chocol shop': 1.0,
#  'courier servic': 1.0,
#  'cowork space': 0.25,
#  'frozen food manufactur': 0.4,
#  'beverag distributor': 0.0,
#  'agricultur organ': 0.0,
#  'dairi store': 0.0,
#  'dairi': 0.75,
#  'ice cream shop': 0.4,
#  'medic laboratori': 1.0,
#  'demolit contractor': 1.0,
#  'meat processor': 1.0,
#  'fmcg manufactur': 0.0,
#  'garbag collect servic': 0.667,
#  'wholesal bakeri': 1.0,
#  'dentist': 1.0,
#  'dessert shop': 0.0,
#  'cupcak shop': 0.0,
#  'nut store': 0.5,
#  'wholesal grocer': 0.444,
#  'design engin': 0.125,
#  'busi busi servic': 0.5,
#  'condiment supplier': 1.0,
#  'digit print servic': 1.0,
#  'culinari school': 1.0,
#  'import': 0.0,
#  'bottl water supplier': 0.5,
#  'coffe roaster': 0.0,
#  'packag suppli store': 0.0,
#  'ice supplier': 1.0,
#  'breweri': 1.0,
#  'winemak compani': 0.0,
#  'distilleri': 1.0,
#  'disabl servic support organis': 0.667,
#  'district govern offic': 0.833,
#  'air filter supplier': 1.0,
#  'tire shop': 0.5,
#  'fasten supplier': 0.545,
#  'fabric product manufactur': 0.0,
#  'textil': 1.0,
#  'textil export': 1.0,
#  'textil engin': 1.0,
#  'fabric store': 0.0,
#  'knit shop': 0.5,
#  'doctor': 1.0,
#  'lamin servic': 0.0,
#  'plastic resin manufactur': 0.333,
#  'carpet manufactur': 0.5,
#  'upholsteri shop': 0.0,
#  'busi administr servic': 0.0,
#  'furnitur store': 1.0,
#  'dri cleaner': 0.0,
#  'packag compani': 0.333,
#  'duti free store': 1.0,
#  'commerc servic': 0.0,
#  'cabl compani': 0.0,
#  'educ': 1.0,
#  'outlet store': 0.0,
#  'lingeri store': 0.167,
#  'cloth fabric manufactur': 0.0,
#  'educ center': 1.0,
#  'uniform store': 0.167,
#  'men cloth store': 1.0,
#  'cloth store': 1.0,
#  'women cloth store': 1.0,
#  'western apparel store': 0.0,
#  'costum store': 0.0,
#  'game store': 0.5,
#  'hat shop': 0.0,
#  'leather good manufactur': 0.5,
#  'educ consult': 1.0,
#  'leather export': 1.0,
#  'shoe store': 1.0,
#  'boutiqu': 0.0,
#  'leather wholesal': 1.0,
#  'handbag shop': 0.5,
#  'electron store': 1.0,
#  'luggag store': 1.0,
#  'build materi store': 0.75,
#  'saw mill': 1.0,
#  'electr engin': 0.0,
#  'deck builder': 0.167,
#  'concret product supplier': 1.0,
#  'plywood supplier': 1.0,
#  'electr instal servic': 0.0,
#  'truss manufactur': 1.0,
#  'door supplier': 0.143,
#  'wood lamin floor supplier': 1.0,
#  'aircraft suppli store': 0.0,
#  'modular home builder': 0.0,
#  'portabl build manufactur': 0.0,
#  'modular home dealer': 0.4,
#  'mulch supplier': 0.0,
#  'electrician': 0.333,
#  'paper mill': 1.0,
#  'energi supplier': 0.8,
#  'engin': 0.25,
#  'print shop': 1.0,
#  'custom label printer': 0.25,
#  'market': 0.143,
#  'market agenc': 0.0,
#  'engin consult': 0.125,
#  'entertain': 0.0,
#  'envelop supplier': 0.143,
#  'oil refineri': 0.4,
#  'record studio': 1.0,
#  'environ renew natur resourc': 0.0,
#  'finish materi supplier': 0.5,
#  'event ticket seller': 0.0,
#  'waterproof compani': 0.0,
#  'auto part store': 0.5,
#  'heat oil supplier': 0.5,
#  'famili practic physician': 1.0,
#  'machin manufactur': 0.0,
#  'industri supplier': 0.0,
#  'weld suppli store': 0.0,
#  'dri ice supplier': 0.5,
#  'privat equiti firm': 0.0,
#  'famili servic center': 0.333,
#  'feder govern offic': 0.833,
#  'vitamin supplement store': 0.4,
#  'feed manufactur': 1.0,
#  'medic equip supplier': 0.0,
#  'medic suppli store': 0.0,
#  'medic clinic': 0.5,
#  'research institut': 1.0,
#  'biochem supplier': 0.0,
#  'fiber optic product supplier': 0.125,
#  'paint manufactur': 1.0,
#  'equip supplier': 0.0,
#  'food': 0.125,
#  'pipe supplier': 0.4,
#  'oil field equip supplier': 0.4,
#  'food broker': 0.0,
#  'food manufactur': 1.0,
#  'food process compani': 0.125,
#  'fenc suppli store': 0.25,
#  'food produc': 0.125,
#  'forestri servic': 1.0,
#  'foundri': 1.0,
#  'wholesal jewel': 0.4,
#  'cooki shop': 0.667,
#  'truck rental agenc': 1.0,
#  'fruit veget process': 0.8,
#  'kitchen suppli store': 0.0,
#  'hydraul equip supplier': 0.0,
#  'irrig equip supplier': 0.333,
#  'bear supplier': 0.3,
#  'metallurgi compani': 0.2,
#  'plastic inject mold servic': 0.0,
#  'gener contractor': 0.0,
#  'gener hospit': 1.0,
#  'tool manufactur': 1.0,
#  'industri design compani': 0.5,
#  'hyundai dealer': 0.0,
#  'glass industri': 1.0,
#  'polym supplier': 0.0,
#  'print equip suppli': 0.0,
#  'toner cartridg supplier': 0.4,
#  'printer repair servic': 0.25,
#  'fuel supplier': 0.0,
#  'glass manufactur': 1.0,
#  'plastic bag supplier': 0.909,
#  'glasswar manufactur': 0.25,
#  'polythen plastic sheet supplier': 0.909,
#  'pvc industri': 0.0,
#  'countertop store': 0.0,
#  'cabinet store': 0.25,
#  'fiberglass supplier': 0.2,
#  'golf cart dealer': 1.0,
#  'auto repair shop': 0.778,
#  'hose supplier': 0.6,
#  'rubber product supplier': 1.0,
#  'automot': 0.0,
#  'commerci refriger supplier': 0.0,
#  'golf club': 0.833,
#  'golf cours': 0.333,
#  'green energi supplier': 0.8,
#  'greenhous': 0.0,
#  'auto glass shop': 0.111,
#  'light manufactur': 1.0,
#  'cement manufactur': 1.0,
#  'brick manufactur': 1.0,
#  'natur stone supplier': 0.0,
#  'gym': 0.167,
#  'marbl supplier': 0.2,
#  'corpor gift supplier': 1.0,
#  'shipbuild repair compani': 0.0,
#  'construct mainten offic': 1.0,
#  'boiler manufactur': 0.75,
#  'contain supplier': 1.0,
#  'home construct': 1.0,
#  'health': 1.0,
#  'heart hospit': 1.0,
#  'spring supplier': 1.0,
#  'electr util manufactur': 0.0,
#  'aircraft manufactur': 0.833,
#  'metal heat treat servic': 1.0,
#  'plate servic': 0.0,
#  'autom compani': 0.0,
#  'heat contractor': 0.667,
#  'plumb suppli store': 0.0,
#  'gun shop': 0.25,
#  'ammunit supplier': 0.6,
#  'pipe manufactur': 0.5,
#  'school': 1.0,
#  'fire protect equip supplier': 0.143,
#  'agricultur machineri manufactur': 0.8,
#  'lawn mower store': 0.0,
#  'lawn irrig equip supplier': 0.333,
#  'financi consult': 0.0,
#  'helicopt charter': 1.0,
#  'packag machineri': 0.071,
#  'histor landmark': 1.0,
#  'electron manufactur': 1.0,
#  'graphic design': 1.0,
#  'eye care center': 0.167,
#  'optic product manufactur': 0.667,
#  'imag consult': 0.25,
#  'clean product supplier': 0.0,
#  'fireplac store': 0.0,
#  'home builder': 1.0,
#  'tool die shop': 1.0,
#  'metal stamp servic': 0.6,
#  'environment organ': 1.0,
#  'food process equip': 0.0,
#  'loan agenc': 0.667,
#  'power plant equip supplier': 0.0,
#  'home good store': 0.667,
#  'engin rebuild servic': 0.0,
#  'air compressor supplier': 0.214,
#  'honda dealer': 1.0,
#  'elev manufactur': 0.143,
#  'crane dealer': 0.0,
#  'crane rental agenc': 0.5,
#  'compound build': 0.0,
#  'tractor dealer': 0.0,
#  'furnac part supplier': 0.0,
#  'heat equip supplier': 0.0,
#  'pneumat tool supplier': 0.0,
#  'truck stop': 0.5,
#  'comput hardwar manufactur': 1.0,
#  'satellit commun servic': 1.0,
#  'hospit': 1.0,
#  'electron compani': 0.5,
#  'electron part supplier': 0.0,
#  'hvac contractor': 0.667,
#  'industri engin': 0.375,
#  'contact lens supplier': 0.333,
#  'inform servic': 1.0,
#  'build': 1.0,
#  'water work equip supplier': 0.0,
#  'measur instrument supplier': 0.889,
#  'scientif equip supplier': 0.0,
#  'medic center': 0.0,
#  'watch manufactur': 0.0,
#  'corpor entertain servic': 0.0,
#  'insur': 1.0,
#  'record compani': 1.0,
#  'video duplic servic': 0.167,
#  'insur agenc': 1.0,
#  'light store': 1.0,
#  'light wholesal': 1.0,
#  'entertain agenc': 1.0,
#  'insur broker': 1.0,
#  'electr equip supplier': 0.0,
#  'electr motor store': 0.0,
#  'railroad compani': 1.0,
#  'electr suppli store': 0.0,
#  'insur compani': 1.0,
#  'factori equip supplier': 0.0,
#  'invest servic': 1.0,
#  'laser equip supplier': 0.0,
#  'execut suit rental agenc': 0.333,
#  'truck dealer': 0.0,
#  'motor vehicl dealer': 1.0,
#  'car dealer': 1.0,
#  'truck topper supplier': 0.0,
#  'polic suppli store': 1.0,
#  'iron steel contractor': 0.25,
#  'fire depart equip supplier': 0.143,
#  'tow equip provid': 1.0,
#  'logist servic': 0.286,
#  'trailer manufactur': 1.0,
#  'trailer dealer': 0.0,
#  'dealer': 1.0,
#  'auto spring shop': 0.0,
#  'auto upholster': 0.0,
#  'auto bodi part supplier': 0.0,
#  'car factori': 0.0,
#  'freight forward servic': 1.0,
#  'brake shop': 0.333,
#  'railroad equip supplier': 0.0,
#  'jewelri equip supplier': 0.818,
#  'boat builder': 1.0,
#  'ship build': 1.0,
#  'marin suppli store': 0.0,
#  'boat dealer': 1.0,
#  'kawasaki motorcycl dealer': 1.0,
#  'knife manufactur': 0.0,
#  'labor union': 1.0,
#  'furnitur maker': 1.0,
#  'bank financ': 0.5,
#  'furnitur manufactur': 1.0,
#  'logist': 0.714,
#  'massag suppli store': 0.0,
#  'telecommun equip supplier': 0.0,
#  'babi store': 0.0,
#  'mold supplier': 0.2,
#  'offic equip supplier': 0.0,
#  'offic furnitur store': 1.0,
#  'store equip supplier': 0.0,
#  'laboratori': 0.125,
#  'health beauti shop': 0.2,
#  'learn center': 0.167,
#  'dental laboratori': 0.4,
#  'land surveyor': 0.125,
#  'educ suppli store': 0.5,
#  'jewelri store': 1.0,
#  'playground equip supplier': 0.0,
#  'outdoor sport store': 0.75,
#  'toy store': 0.5,
#  'secur servic': 0.6,
#  'sign shop': 0.091,
#  'offic suppli store': 0.5,
#  'landscap': 1.0,
#  'gasket manufactur': 0.636,
#  'piano maker': 0.091,
#  'piano store': 0.25,
#  'funer home': 1.0,
#  'monument': 0.0,
#  'book publish': 1.0,
#  'wig shop': 0.167,
#  'laundromat': 0.25,
#  'auto wrecker': 0.5,
#  'auto part market': 1.0,
#  'jeep dealer': 1.0,
#  'restaur suppli store': 0.0,
#  'roof suppli store': 0.0,
#  'law firm': 0.25,
#  'build materi market': 1.0,
#  'camera store': 0.0,
#  'lawn care servic': 0.0,
#  'comput secur servic': 0.0,
#  'comput store': 0.0,
#  'design agenc': 1.0,
#  'diagnost center': 1.0,
#  'laboratori equip supplier': 0.111,
#  'home theater store': 0.0,
#  'metal industri supplier': 0.0,
#  'landscap suppli store': 0.0,
#  'applianc part supplier': 0.0,
#  'vacuum cleaner store': 0.5,
#  'audio visual equip supplier': 1.0,
#  'lawyer': 1.0,
#  'cell phone store': 0.0,
#  'bathroom suppli store': 0.0,
#  'leas servic': 0.0,
#  'construct machin dealer': 0.0,
#  'dairi farm equip supplier': 0.0,
#  'propan supplier': 0.0,
#  'legal servic': 1.0,
#  'janitori equip supplier': 0.4,
#  'life insur agenc': 1.0,
#  'railroad contractor': 0.0,
#  'swim pool suppli store': 1.0,
#  'light bulb supplier': 1.0,
#  'linen store': 0.25,
#  'metal construct compani': 0.833,
#  'local govern offic': 0.833,
#  'log contractor': 0.0,
#  'machin shop': 1.0,
#  'hotel suppli store': 0.0,
#  'import export compani': 0.0,
#  'sew compani': 0.25,
#  'research foundat': 1.0,
#  'machineri part manufactur': 1.0,
#  'sport accessori wholesal': 0.0,
#  'fashion design': 1.0,
#  'chees manufactur': 0.0,
#  'chees shop': 0.0,
#  'ship mail': 1.0,
#  'wholesal food store': 0.0,
#  'organ food store': 0.0,
#  'pie shop': 0.167,
#  'auction hous': 1.0,
#  'livestock auction hous': 0.333,
#  'cotton export': 0.429,
#  'plastic wholesal': 0.0,
#  'mail servic': 1.0,
#  'manufactur': 0.636,
#  'station': 1.0,
#  'beer distributor': 1.0,
#  'alcohol beverag wholesal': 0.5,
#  'religi good store': 1.0,
#  'book wholesal': 1.0,
#  'masonri suppli store': 0.25,
#  'wholesal florist': 0.333,
#  'florist': 1.0,
#  'marin engin': 0.125,
#  'paint store': 0.25,
#  'use auto part store': 0.5,
#  'masonri contractor': 0.5,
#  'use car dealer': 1.0,
#  'use truck dealer': 1.0,
#  'massag therapist': 0.5,
#  'materi handl equip supplier': 0.0,
#  'marina': 1.0,
#  'meat packer': 0.111,
#  'mattress store': 0.0,
#  'blind shop': 0.5,
#  'interior design': 1.0,
#  'window treatment store': 0.667,
#  'applianc store': 1.0,
#  'health food store': 0.4,
#  'direct mail advertis': 0.25,
#  'meat wholesal': 0.333,
#  'butcher shop deli': 0.167,
#  'italian groceri store': 0.333,
#  'food servic': 1.0,
#  'groceri deliveri servic': 1.0,
#  'wine store': 1.0,
#  'liquor store': 1.0,
#  'kiosk': 0.0,
#  'optometrist': 0.5,
#  'optician': 0.167,
#  'mechan contractor': 0.667,
#  'mechan engin': 0.125,
#  'cafe': 0.5,
#  'jewel': 0.2,
#  'leather good store': 0.5,
#  'gift shop': 1.0,
#  'craft store': 0.25,
#  'hobbi store': 0.75,
#  'fabric wholesal': 0.0,
#  'scrap metal dealer': 0.0,
#  'quilt shop': 0.25,
#  'sheet music store': 1.0,
#  'music instrument manufactur': 0.091,
#  'music store': 1.0,
#  'music instrument store': 1.0,
#  'band': 0.25,
#  'bookstor': 0.0,
#  'art museum': 1.0,
#  'newsstand': 0.5,
#  'medic equip manufactur': 1.0,
#  'fashion accessori store': 1.0,
#  'discount store': 0.0,
#  'cemeteri': 0.5,
#  'stop': 0.0,
#  'varieti store': 0.0,
#  'thrift store': 1.0,
#  'medic group': 0.0,
#  'donat center': 0.0,
#  'pet store': 1.0,
#  'art galleri': 0.2,
#  'art dealer': 0.4,
#  'hous develop': 1.0,
#  'mobil home dealer': 0.4,
#  'conveni store': 1.0,
#  'medic offic': 0.0,
#  'medic technolog manufactur': 0.0,
#  'children furnitur store': 1.0,
#  'mental health clinic': 0.333,
#  'airlin': 0.0,
#  'aviat consult': 0.0,
#  'travel agenc': 1.0,
#  'travel servic': 1.0,
#  'airport': 0.667,
#  'mental health servic': 0.333,
#  'ship compani': 0.0,
#  'metal fabric': 0.833,
#  'cruis line compani': 0.0,
#  'tow servic': 1.0,
#  'ferri termin': 0.0,
#  'ferri servic': 0.0,
#  'metal finish': 1.0,
#  'boat tour agenc': 1.0,
#  'move compani': 0.333,
#  'move storag servic': 0.333,
#  'state depart transport': 0.0,
#  'depart transport': 0.0,
#  'handicap transport servic': 1.0,
#  'railway servic': 0.0,
#  'train station': 0.0,
#  'depot': 0.0,
#  'charter': 1.0,
#  'metal process compani': 1.0,
#  'mix use': 0.0,
#  'motorcycl shop': 0.667,
#  'limousin servic': 1.0,
#  'chauffeur servic': 0.0,
#  'school servic': 0.0,
#  'airport shuttl servic': 1.0,
#  'tourist inform center': 0.0,
#  'carriag ride servic': 0.0,
#  'cruis agenc': 0.25,
#  'tourist attract': 0.25,
#  'ski resort': 1.0,
#  'ski area': 0.167,
#  'fix base oper': 0.0,
#  'aircraft mainten compani': 0.333,
#  'motorsport store': 0.0,
#  'boat rental servic': 1.0,
#  'util trailer dealer': 0.0,
#  'forklift dealer': 0.0,
#  'municip administr offic': 0.0,
#  'nephrologist': 0.5,
#  'coach compani': 0.0,
#  'ship servic': 0.0,
#  'ship mail servic': 0.0,
#  'newspap publish': 1.0,
#  'shred servic': 0.0,
#  'nuclear power compani': 0.9,
#  'nurs home': 0.0,
#  'media compani': 0.5,
#  'multimedia electron book publish': 0.0,
#  'internet market servic': 0.125,
#  'greet card shop': 0.5,
#  'theme park': 1.0,
#  'film product compani': 0.333,
#  'obstetrician gynecologist': 0.5,
#  'movi studio': 0.0,
#  'video product servic': 1.0,
#  'movi theater': 0.833,
#  'theater compani': 0.75,
#  'perform art theater': 1.0,
#  'occup safeti health': 0.0,
#  'offic space rental agenc': 0.0,
#  'commerci real estat agenc': 1.0,
#  'art school': 0.333,
#  'music publish': 0.25,
#  'print music publish': 0.0,
#  'home audio store': 0.0,
#  'musician': 0.25,
#  'music manag promot': 1.0,
#  'video edit servic': 0.333,
#  'offic suppli wholesal': 0.0,
#  'offici resid': 0.0,
#  'orthoped clinic': 1.0,
#  'painter': 0.0,
#  'paint': 0.167,
#  'telephon compani': 0.0,
#  'media hous': 1.0,
#  'paper distributor': 0.0,
#  'news servic': 0.5,
#  'public librari': 0.0,
#  'law librari': 1.0,
#  'museum': 1.0,
#  'feder reserv bank': 1.0,
#  'credit union': 0.5,
#  'atm': 0.333,
#  'pave contractor': 1.0,
#  'mortgag lender': 1.0,
#  'invest bank': 0.0,
#  'check cash servic': 0.667,
#  'stock broker': 0.0,
#  'health consult': 0.857,
#  'health insur agenc': 1.0,
#  'payrol servic': 1.0,
#  'pediatrician': 1.0,
#  'human resourc consult': 1.0,
#  'pest control servic': 0.6,
#  'pet board servic': 1.0,
#  'pet care': 0.2,
#  'loss adjust': 0.75,
#  'pharmaceut compani': 1.0,
#  'pharmaceut product wholesal': 1.0,
#  'pharmaci': 0.2,
#  'educ institut': 1.0,
#  'retir commun': 1.0,
#  'fratern organ': 1.0,
#  'photo lab': 0.0,
#  'properti invest': 0.0,
#  'photograph': 0.5,
#  'photographi school': 0.333,
#  'star hotel': 1.0,
#  'convent center': 0.0,
#  'real estat apprais': 1.0,
#  'photographi servic': 0.333,
#  'resort hotel': 1.0,
#  'real estat consult': 1.0,
#  'car rental agenc': 1.0,
#  'car leas servic': 0.0,
#  'ford dealer': 1.0,
#  'car financ loan compani': 0.857,
#  'trailer rental servic': 0.667,
#  'furnitur rental servic': 0.333,
#  'tuxedo shop': 0.0,
#  'dress tuxedo rental servic': 1.0,
#  'wed store': 0.0,
#  'video store': 0.5,
#  'movi rental': 0.0,
#  'photographi studio': 0.333,
#  'home health care servic': 1.0,
#  'skateboard shop': 0.0,
#  'event technolog servic': 0.0,
#  'parti equip rental servic': 1.0,
#  'construct machin rental servic': 0.25,
#  'audio visual equip rental servic': 0.0,
#  'ship equip industri': 0.0,
#  'physic therapi clinic': 0.333,
#  'plastic fabric compani': 0.909,
#  'plastic product supplier': 0.909,
#  'auto tag agenc': 0.4,
#  'depart motor vehicl': 0.0,
#  'notari public': 0.75,
#  'privat investig': 0.8,
#  'escrow servic': 0.0,
#  'real estat agent': 1.0,
#  'playground': 0.0,
#  'plumber': 0.333,
#  'port author': 1.0,
#  'portrait studio': 0.333,
#  'post offic': 1.0,
#  'profession servic': 0.167,
#  'univers hospit': 1.0,
#  'public relat firm': 0.125,
#  'civil engin compani': 1.0,
#  'draft servic': 0.875,
#  'pump supplier': 0.643,
#  'interior construct contractor': 0.0,
#  'carpet clean servic': 0.6,
#  'exhibit planner': 0.0,
#  'decal supplier': 0.0,
#  'stage light equip supplier': 1.0,
#  'event manag compani': 0.333,
#  'radio broadcast': 0.0,
#  'comput support servic': 1.0,
#  'ravin': 0.0,
#  'employ center': 0.25,
#  'nation health foundat': 0.333,
#  'real estat develop': 0.0,
#  'advertis agenc': 0.0,
#  'promot product supplier': 0.0,
#  'advertis servic': 0.125,
#  'record storag facil': 0.0,
#  'fund manag compani': 0.2,
#  'recreat center': 1.0,
#  'bakeri': 1.0,
#  'databas manag compani': 0.0,
#  'market research': 0.333,
#  'recycl center': 0.0,
#  'region govern offic': 0.667,
#  'rehabilit center': 0.0,
#  'religi institut': 1.0,
#  'religi organ': 1.0,
#  'repair servic': 1.0,
#  'emerg veterinarian servic': 0.333,
#  'pet sitter': 0.2,
#  'research product develop': 1.0,
#  'build societi': 1.0,
#  'valet park servic': 1.0,
#  'nurs agenc': 0.0,
#  'execut search firm': 0.5,
#  'recruit': 1.0,
#  'temp agenc': 0.25,
#  'health center': 0.0,
#  'restaur': 1.0,
#  'roof contractor': 0.5,
#  'sport nutrit store': 0.2,
#  'credit report agenc': 0.2,
#  'automobil storag facil': 1.0,
#  'debt collect agenc': 0.3,
#  'park': 0.4,
#  'court report': 0.5,
#  'tour agenc': 1.0,
#  'tour oper': 1.0,
#  'convent inform bureau': 0.25,
#  'balloon ride tour agenc': 1.0,
#  'secur guard servic': 1.0,
#  'locksmith': 0.4,
#  'commerci clean servic': 0.6,
#  'blast clean servic': 0.6,
#  'confer center': 0.0,
#  'safeti equip supplier': 0.0,
#  'garbag dump': 1.0,
#  'sanit servic': 0.2,
#  'garbag dump servic': 0.0,
#  'environment health servic': 0.0,
#  'portabl toilet supplier': 0.5,
#  'public work depart': 0.167,
#  'school district offic': 1.0,
#  'sailmak': 0.0,
#  'commun colleg': 1.0,
#  'salvag yard': 0.25,
#  'busi school': 0.0,
#  'trade school': 1.0,
#  'privat univers': 0.0,
#  'comput train school': 0.667,
#  'school suppli store': 0.0,
#  'screen printer': 0.75,
#  'media consult': 0.375,
#  'beauti school': 1.0,
#  'flight school': 1.0,
#  'seaport': 0.0,
#  'secur system supplier': 0.4,
#  'middl school': 1.0,
#  'nonprofit': 0.0,
#  'shoot rang': 0.167,
#  'soccer club': 0.333,
#  'camp': 1.0,
#  'dive contractor': 0.0,
#  'languag school': 0.833,
#  'english languag school': 0.833,
#  'preschool': 1.0,
#  'self storag facil': 0.25,
#  'semi conductor supplier': 0.0,
#  'drive school': 0.833,
#  'truck school': 0.167,
#  'senior citizen center': 0.0,
#  'servic': 0.0,
#  'children hospit': 1.0,
#  'dental suppli store': 0.4,
#  'shipyard': 1.0,
#  'orthodox synagogu': 1.0,
#  'short term apart rental agenc': 0.0,
#  'nutritionist': 0.167,
#  'ophthalmologist': 0.0,
#  'ophthalmolog clinic': 0.333,
#  'social servic organ': 1.0,
#  'social welfar center': 1.0,
#  'solar energi compani': 0.8,
#  'solar energi equip supplier': 0.8,
#  'special educ school': 1.0,
#  'podiatrist': 0.333,
#  'reproduct health clinic': 0.833,
#  'sport good store': 0.75,
#  'dialysi center': 0.833,
#  'sport complex': 0.0,
#  'well program': 0.0,
#  'sportswear store': 0.0,
#  'privat hospit': 1.0,
#  'radiologist': 0.0,
#  'medic diagnost imag center': 1.0,
#  'ray lab': 1.0,
#  'blood bank': 0.667,
#  'stainless steel plant': 1.0,
#  'state agenc': 0.333,
#  'heliport': 0.0,
#  'health care compani': 0.0,
#  'psychiatr hospit': 1.0,
#  'state govern offic': 0.833,
#  'medic institut': 1.0,
#  'steel construct compani': 0.125,
#  'clean servic': 0.6,
#  'steel drum supplier': 0.0,
#  'assist live facil': 1.0,
#  'steel erector': 0.125,
#  ...}

# %%
calc_avg_pre(ret_docs_dic, queries_dic, cutoff=-1)[0]
# Out:
# {'home improv store': 0.0,
#  'diesel fuel supplier': 0.0,
#  'church': 1.0,
#  'farm': 0.0,
#  'seed supplier': 0.0,
#  'account': 1.0,
#  'truck compani': 0.387,
#  'export': 0.0,
#  'grain elev': 0.036,
#  'popcorn store': 0.333,
#  'agricultur servic': 0.294,
#  'warehous': 1.0,
#  'agricultur product': 0.0,
#  'ranch': 1.0,
#  'hold compani': 1.0,
#  'farm equip supplier': 0.0,
#  'store': 0.0,
#  'groceri store': 0.6,
#  'rice mill': 0.704,
#  'food product supplier': 0.0,
#  'account firm': 0.683,
#  'produc market': 0.108,
#  'pet suppli store': 0.927,
#  'wholesal': 0.0,
#  'produc wholesal': 0.146,
#  'distribut servic': 0.0,
#  'crop grower': 0.471,
#  'addict treatment center': 0.0,
#  'natur good store': 0.0,
#  'orchard': 0.185,
#  'lumber store': 0.0,
#  'mine': 0.368,
#  'transport servic': 0.268,
#  'invest compani': 0.0,
#  'fruit wholesal': 0.014,
#  'real estat agenc': 0.333,
#  'event venu': 0.0,
#  'frozen dessert supplier': 0.333,
#  'wine wholesal import': 0.417,
#  'wineri': 1.0,
#  'aerospac compani': 0.561,
#  'cold storag facil': 1.0,
#  'employ agenc': 0.525,
#  'plant nurseri': 0.125,
#  'air condit contractor': 0.667,
#  'air condit repair servic': 0.0,
#  'fruit veget wholesal': 0.083,
#  'aircraft rental servic': 0.0,
#  'monasteri': 1.0,
#  'allergist': 0.5,
#  'herb shop': 0.0,
#  'aluminum supplier': 1.0,
#  'ambul servic': 0.037,
#  'wholesal plant nurseri': 0.422,
#  'amus machin supplier': 0.0,
#  'anim hospit': 0.0,
#  'farmer market': 0.042,
#  'vapor store': 0.877,
#  'cigar shop': 0.04,
#  'tobacco shop': 0.0,
#  'well drill contractor': 0.0,
#  'librari': 0.65,
#  'apart build': 0.0,
#  'apart rental agenc': 0.0,
#  'dairi farm': 0.0,
#  'architect': 0.25,
#  'organ farm': 0.024,
#  'architectur design': 0.139,
#  'architectur firm': 0.428,
#  'livestock produc': 0.0,
#  'dairi supplier': 0.0,
#  'biotechnolog compani': 0.5,
#  'artist': 0.5,
#  'egg supplier': 1.0,
#  'poultri farm': 0.0,
#  'chicken hatcheri': 0.8,
#  'art organ': 0.458,
#  'associ organ': 0.839,
#  'food store': 0.325,
#  'deli': 0.0,
#  'bank': 0.292,
#  'fish process': 0.0,
#  'fish farm': 0.037,
#  'seafood wholesal': 0.482,
#  'tropic fish store': 0.593,
#  'non profit organ': 0.0,
#  'econom develop agenc': 0.452,
#  'seafood market': 0.131,
#  'honey farm': 0.0,
#  'hors breeder': 0.0,
#  'asphalt contractor': 0.325,
#  'livestock dealer': 0.0,
#  'depart store': 1.0,
#  'mill': 0.0,
#  'atv dealer': 0.917,
#  'audio visual consult': 0.1,
#  'pallet supplier': 0.179,
#  'wood supplier': 0.0,
#  'hardwar store': 0.25,
#  'furnitur wholesal': 0.0,
#  'auditor': 0.25,
#  'oil natur compani': 0.062,
#  'auto bodi shop': 0.219,
#  'boat repair shop': 0.125,
#  'associ': 0.6,
#  'rail contractor': 0.0,
#  'publish': 1.0,
#  'pond suppli store': 0.0,
#  'agricultur cooper': 0.0,
#  'print equip supplier': 0.022,
#  'auto insur agenc': 0.875,
#  'altern fuel station': 1.0,
#  'auto part manufactur': 0.0,
#  'foundat': 0.554,
#  'fertil supplier': 1.0,
#  'farm compani': 0.0,
#  'financ broker': 0.0,
#  'fire station': 0.048,
#  'environment consult': 1.0,
#  'civil engin': 0.333,
#  'fire protect servic': 0.143,
#  'compani': 0.0,
#  'oilfield': 0.0,
#  'banquet hall': 0.333,
#  'mine compani': 0.368,
#  'coalfield': 0.0,
#  'steel fabric': 0.0,
#  'quarri': 0.458,
#  'gold mine compani': 0.491,
#  'high rise build': 0.5,
#  'basketbal club': 0.056,
#  'gold dealer': 0.0,
#  'batteri manufactur': 0.375,
#  'electr util compani': 0.0,
#  'environment program': 0.0,
#  'offic': 0.0,
#  'stone supplier': 0.05,
#  'aggreg supplier': 0.0,
#  'sand gravel supplier': 0.125,
#  'build materi supplier': 1.0,
#  'beauti suppli store': 0.486,
#  'crush stone supplier': 0.028,
#  'rock shop': 0.0,
#  'road construct compani': 1.0,
#  'market consult': 1.0,
#  'blood test servic': 0.326,
#  'contractor': 0.5,
#  'excav contractor': 0.75,
#  'asphalt mix plant': 0.4,
#  'readi mix concret supplier': 0.943,
#  'sand plant': 0.054,
#  'bmw dealer': 0.333,
#  'bookbind': 0.804,
#  'garden center': 0.833,
#  'abras supplier': 0.0,
#  'granit supplier': 0.1,
#  'drill contractor': 0.0,
#  'bpo compani': 0.079,
#  'oil explor servic': 0.563,
#  'build complex': 0.0,
#  'construct equip supplier': 0.0,
#  'mine equip': 0.0,
#  'ticket agenc': 0.51,
#  'busi center': 0.02,
#  'skyscrap': 0.0,
#  'softwar compani': 1.0,
#  'busi develop servic': 0.016,
#  'busi manag consult': 1.0,
#  'cabinet maker': 0.679,
#  'call center': 0.167,
#  'cancer treatment center': 0.0,
#  'power plant consult': 0.0,
#  'busi park': 0.267,
#  'petroleum product compani': 0.163,
#  'park lot': 0.2,
#  'water util compani': 0.917,
#  'car repair mainten': 0.778,
#  'water treatment plant': 1.0,
#  'car servic': 0.037,
#  'cattl market': 0.056,
#  'sewag dispos servic': 1.0,
#  'certifi public account': 0.25,
#  'govern offic': 0.628,
#  'chariti': 0.333,
#  'air condit system supplier': 0.0,
#  'chemic industri': 0.247,
#  'chemic manufactur': 0.253,
#  'titl compani': 0.083,
#  'chemic plant': 0.327,
#  'properti manag compani': 0.0,
#  'custom home builder': 0.427,
#  'window instal servic': 0.0,
#  'fire damag restor servic': 0.0,
#  'equip rental agenc': 0.081,
#  'chemic wholesal': 0.0,
#  'financi planner': 0.0,
#  'telecommun servic provid': 0.367,
#  'energi equip solut': 0.0,
#  'chiropractor': 0.5,
#  'steel distributor': 0.0,
#  'citi govern offic': 0.715,
#  'crane servic': 0.071,
#  'garag door supplier': 0.019,
#  'industri door supplier': 0.129,
#  'citi town hall': 0.167,
#  'cloth wholesal': 0.025,
#  'coin oper laundri equip supplier': 1.0,
#  'metal supplier': 0.0,
#  'glass shop': 0.0,
#  'colleg': 1.0,
#  'side contractor': 0.276,
#  'commerci printer': 0.031,
#  'storag facil': 1.0,
#  'commun tower': 0.333,
#  'janitori servic': 0.4,
#  'comput consult': 0.028,
#  'fire protect system supplier': 0.143,
#  'elev servic': 0.071,
#  'industri equip supplier': 0.0,
#  'dri wall contractor': 0.278,
#  'insul contractor': 0.214,
#  'concret contractor': 0.478,
#  'scaffold rental servic': 0.078,
#  'construct compani': 1.0,
#  'floor store': 0.611,
#  'floor contractor': 0.312,
#  'tile contractor': 0.477,
#  'tile manufactur': 0.0,
#  'glass mirror shop': 0.0,
#  'construct materi wholesal': 0.0,
#  'gutter clean servic': 0.5,
#  'sheet metal contractor': 0.403,
#  'consult': 1.0,
#  'contain servic': 0.0,
#  'septic system servic': 0.375,
#  'corpor campu': 0.111,
#  'water damag restor servic': 0.0,
#  'welder': 0.0,
#  'corpor offic': 0.111,
#  'anim': 1.0,
#  'anim feed store': 0.0,
#  'anim protect organ': 0.0,
#  'brew suppli store': 0.0,
#  'cosmet store': 0.52,
#  'counti govern offic': 0.73,
#  'sugar factori': 0.811,
#  'confectioneri wholesal': 0.296,
#  'financi institut': 0.0,
#  'candi store': 0.167,
#  'confectioneri': 0.079,
#  'chocol factori': 0.927,
#  'chocol shop': 0.839,
#  'courier servic': 1.0,
#  'cowork space': 0.042,
#  'frozen food manufactur': 0.4,
#  'beverag distributor': 0.0,
#  'agricultur organ': 0.0,
#  'dairi store': 0.0,
#  'dairi': 0.188,
#  'ice cream shop': 0.24,
#  'medic laboratori': 1.0,
#  'demolit contractor': 0.833,
#  'meat processor': 0.95,
#  'fmcg manufactur': 0.0,
#  'garbag collect servic': 0.417,
#  'wholesal bakeri': 0.976,
#  'dentist': 0.167,
#  'dessert shop': 0.0,
#  'cupcak shop': 0.0,
#  'nut store': 0.433,
#  'wholesal grocer': 0.136,
#  'design engin': 0.125,
#  'busi busi servic': 0.348,
#  'condiment supplier': 1.0,
#  'digit print servic': 1.0,
#  'culinari school': 0.733,
#  'import': 0.0,
#  'bottl water supplier': 0.258,
#  'coffe roaster': 0.0,
#  'packag suppli store': 0.0,
#  'ice supplier': 0.78,
#  'breweri': 1.0,
#  'winemak compani': 0.0,
#  'distilleri': 1.0,
#  'disabl servic support organis': 0.667,
#  'district govern offic': 0.54,
#  'air filter supplier': 0.554,
#  'tire shop': 0.5,
#  'fasten supplier': 0.351,
#  'fabric product manufactur': 0.0,
#  'textil': 0.325,
#  'textil export': 0.325,
#  'textil engin': 0.325,
#  'fabric store': 0.0,
#  'knit shop': 0.133,
#  'doctor': 1.0,
#  'lamin servic': 0.0,
#  'plastic resin manufactur': 0.333,
#  'carpet manufactur': 0.5,
#  'upholsteri shop': 0.0,
#  'busi administr servic': 0.0,
#  'furnitur store': 1.0,
#  'dri cleaner': 0.0,
#  'packag compani': 0.083,
#  'duti free store': 0.877,
#  'commerc servic': 0.0,
#  'cabl compani': 0.0,
#  'educ': 1.0,
#  'outlet store': 0.0,
#  'lingeri store': 0.167,
#  'cloth fabric manufactur': 0.0,
#  'educ center': 1.0,
#  'uniform store': 0.042,
#  'men cloth store': 1.0,
#  'cloth store': 1.0,
#  'women cloth store': 1.0,
#  'western apparel store': 0.0,
#  'costum store': 0.0,
#  'game store': 0.312,
#  'hat shop': 0.0,
#  'leather good manufactur': 0.1,
#  'educ consult': 0.143,
#  'leather export': 1.0,
#  'shoe store': 1.0,
#  'boutiqu': 0.0,
#  'leather wholesal': 0.2,
#  'handbag shop': 0.1,
#  'electron store': 0.292,
#  'luggag store': 0.6,
#  'build materi store': 0.415,
#  'saw mill': 0.417,
#  'electr engin': 0.0,
#  'deck builder': 0.017,
#  'concret product supplier': 0.967,
#  'plywood supplier': 1.0,
#  'electr instal servic': 0.0,
#  'truss manufactur': 0.689,
#  'door supplier': 0.024,
#  'wood lamin floor supplier': 0.787,
#  'aircraft suppli store': 0.0,
#  'modular home builder': 0.0,
#  'portabl build manufactur': 0.0,
#  'modular home dealer': 0.069,
#  'mulch supplier': 0.0,
#  'electrician': 0.111,
#  'paper mill': 0.692,
#  'energi supplier': 0.8,
#  'engin': 0.09,
#  'print shop': 1.0,
#  'custom label printer': 0.083,
#  'market': 0.071,
#  'market agenc': 0.0,
#  'engin consult': 0.018,
#  'entertain': 0.0,
#  'envelop supplier': 0.071,
#  'oil refineri': 0.244,
#  'record studio': 0.917,
#  'environ renew natur resourc': 0.0,
#  'finish materi supplier': 0.092,
#  'event ticket seller': 0.0,
#  'waterproof compani': 0.0,
#  'auto part store': 0.056,
#  'heat oil supplier': 0.071,
#  'famili practic physician': 0.325,
#  'machin manufactur': 0.0,
#  'industri supplier': 0.0,
#  'weld suppli store': 0.0,
#  'dri ice supplier': 0.317,
#  'privat equiti firm': 0.0,
#  'famili servic center': 0.167,
#  'feder govern offic': 0.637,
#  'vitamin supplement store': 0.4,
#  'feed manufactur': 1.0,
#  'medic equip supplier': 0.0,
#  'medic suppli store': 0.0,
#  'medic clinic': 0.05,
#  'research institut': 1.0,
#  'biochem supplier': 0.0,
#  'fiber optic product supplier': 0.125,
#  'paint manufactur': 1.0,
#  'equip supplier': 0.0,
#  'food': 0.013,
#  'pipe supplier': 0.223,
#  'oil field equip supplier': 0.3,
#  'food broker': 0.0,
#  'food manufactur': 0.417,
#  'food process compani': 0.013,
#  'fenc suppli store': 0.25,
#  'food produc': 0.013,
#  'forestri servic': 1.0,
#  'foundri': 1.0,
#  'wholesal jewel': 0.333,
#  'cooki shop': 0.383,
#  'truck rental agenc': 0.251,
#  'fruit veget process': 0.583,
#  'kitchen suppli store': 0.0,
#  'hydraul equip supplier': 0.0,
#  'irrig equip supplier': 0.333,
#  'bear supplier': 0.183,
#  'metallurgi compani': 0.2,
#  'plastic inject mold servic': 0.0,
#  'gener contractor': 0.0,
#  'gener hospit': 0.5,
#  'tool manufactur': 1.0,
#  'industri design compani': 0.163,
#  'hyundai dealer': 0.0,
#  'glass industri': 1.0,
#  'polym supplier': 0.0,
#  'print equip suppli': 0.0,
#  'toner cartridg supplier': 0.3,
#  'printer repair servic': 0.25,
#  'fuel supplier': 0.0,
#  'glass manufactur': 1.0,
#  'plastic bag supplier': 0.909,
#  'glasswar manufactur': 0.25,
#  'polythen plastic sheet supplier': 0.909,
#  'pvc industri': 0.0,
#  'countertop store': 0.0,
#  'cabinet store': 0.05,
#  'fiberglass supplier': 0.1,
#  'golf cart dealer': 0.917,
#  'auto repair shop': 0.753,
#  'hose supplier': 0.42,
#  'rubber product supplier': 1.0,
#  'automot': 0.0,
#  'commerci refriger supplier': 0.0,
#  'golf club': 0.528,
#  'golf cours': 0.278,
#  'green energi supplier': 0.8,
#  'greenhous': 0.0,
#  'auto glass shop': 0.022,
#  'light manufactur': 1.0,
#  'cement manufactur': 1.0,
#  'brick manufactur': 1.0,
#  'natur stone supplier': 0.0,
#  'gym': 0.167,
#  'marbl supplier': 0.1,
#  'corpor gift supplier': 1.0,
#  'shipbuild repair compani': 0.0,
#  'construct mainten offic': 1.0,
#  'boiler manufactur': 0.5,
#  'contain supplier': 0.917,
#  'home construct': 0.329,
#  'health': 0.171,
#  'heart hospit': 0.5,
#  'spring supplier': 1.0,
#  'electr util manufactur': 0.0,
#  'aircraft manufactur': 0.694,
#  'metal heat treat servic': 1.0,
#  'plate servic': 0.0,
#  'autom compani': 0.0,
#  'heat contractor': 0.667,
#  'plumb suppli store': 0.0,
#  'gun shop': 0.083,
#  'ammunit supplier': 0.6,
#  'pipe manufactur': 0.293,
#  'school': 0.5,
#  'fire protect equip supplier': 0.143,
#  'agricultur machineri manufactur': 0.247,
#  'lawn mower store': 0.0,
#  'lawn irrig equip supplier': 0.083,
#  'financi consult': 0.0,
#  'helicopt charter': 0.639,
#  'packag machineri': 0.012,
#  'histor landmark': 1.0,
#  'electron manufactur': 1.0,
#  'graphic design': 1.0,
#  'eye care center': 0.028,
#  'optic product manufactur': 0.217,
#  'imag consult': 0.025,
#  'clean product supplier': 0.0,
#  'fireplac store': 0.0,
#  'home builder': 0.568,
#  'tool die shop': 0.943,
#  'metal stamp servic': 0.4,
#  'environment organ': 0.806,
#  'food process equip': 0.0,
#  'loan agenc': 0.222,
#  'power plant equip supplier': 0.0,
#  'home good store': 0.3,
#  'engin rebuild servic': 0.0,
#  'air compressor supplier': 0.109,
#  'honda dealer': 0.333,
#  'elev manufactur': 0.095,
#  'crane dealer': 0.0,
#  'crane rental agenc': 0.097,
#  'compound build': 0.0,
#  'tractor dealer': 0.0,
#  'furnac part supplier': 0.0,
#  'heat equip supplier': 0.0,
#  'pneumat tool supplier': 0.0,
#  'truck stop': 0.071,
#  'comput hardwar manufactur': 1.0,
#  'satellit commun servic': 0.2,
#  'hospit': 0.333,
#  'electron compani': 0.062,
#  'electron part supplier': 0.0,
#  'hvac contractor': 0.667,
#  'industri engin': 0.19,
#  'contact lens supplier': 0.083,
#  'inform servic': 0.917,
#  'build': 0.833,
#  'water work equip supplier': 0.0,
#  'measur instrument supplier': 0.814,
#  'scientif equip supplier': 0.0,
#  'medic center': 0.0,
#  'watch manufactur': 0.0,
#  'corpor entertain servic': 0.0,
#  'insur': 0.636,
#  'record compani': 0.618,
#  'video duplic servic': 0.033,
#  'insur agenc': 0.875,
#  'light store': 0.917,
#  'light wholesal': 1.0,
#  'entertain agenc': 1.0,
#  'insur broker': 0.692,
#  'electr equip supplier': 0.0,
#  'electr motor store': 0.0,
#  'railroad compani': 1.0,
#  'electr suppli store': 0.0,
#  'insur compani': 0.636,
#  'factori equip supplier': 0.0,
#  'invest servic': 0.927,
#  'laser equip supplier': 0.0,
#  'execut suit rental agenc': 0.065,
#  'truck dealer': 0.0,
#  'motor vehicl dealer': 0.325,
#  'car dealer': 0.5,
#  'truck topper supplier': 0.0,
#  'polic suppli store': 0.876,
#  'iron steel contractor': 0.073,
#  'fire depart equip supplier': 0.029,
#  'tow equip provid': 1.0,
#  'logist servic': 0.119,
#  'trailer manufactur': 1.0,
#  'trailer dealer': 0.0,
#  'dealer': 0.917,
#  'auto spring shop': 0.0,
#  'auto upholster': 0.0,
#  'auto bodi part supplier': 0.0,
#  'car factori': 0.0,
#  'freight forward servic': 1.0,
#  'brake shop': 0.077,
#  'railroad equip supplier': 0.0,
#  'jewelri equip supplier': 0.643,
#  'boat builder': 0.833,
#  'ship build': 1.0,
#  'marin suppli store': 0.0,
#  'boat dealer': 0.867,
#  'kawasaki motorcycl dealer': 0.917,
#  'knife manufactur': 0.0,
#  'labor union': 1.0,
#  'furnitur maker': 0.933,
#  'bank financ': 0.133,
#  'furnitur manufactur': 0.933,
#  'logist': 0.288,
#  'massag suppli store': 0.0,
#  'telecommun equip supplier': 0.0,
#  'babi store': 0.0,
#  'mold supplier': 0.2,
#  'offic equip supplier': 0.0,
#  'offic furnitur store': 0.485,
#  'store equip supplier': 0.0,
#  'laboratori': 0.021,
#  'health beauti shop': 0.1,
#  'learn center': 0.042,
#  'dental laboratori': 0.333,
#  'land surveyor': 0.062,
#  'educ suppli store': 0.125,
#  'jewelri store': 0.625,
#  'playground equip supplier': 0.0,
#  'outdoor sport store': 0.475,
#  'toy store': 0.312,
#  'secur servic': 0.23,
#  'sign shop': 0.091,
#  'offic suppli store': 0.5,
#  'landscap': 0.573,
#  'gasket manufactur': 0.616,
#  'piano maker': 0.015,
#  'piano store': 0.05,
#  'funer home': 1.0,
#  'monument': 0.0,
#  'book publish': 0.915,
#  'wig shop': 0.167,
#  'laundromat': 0.25,
#  'auto wrecker': 0.071,
#  'auto part market': 0.31,
#  'jeep dealer': 0.333,
#  'restaur suppli store': 0.0,
#  'roof suppli store': 0.0,
#  'law firm': 0.25,
#  'build materi market': 1.0,
#  'camera store': 0.0,
#  'lawn care servic': 0.0,
#  'comput secur servic': 0.0,
#  'comput store': 0.0,
#  'design agenc': 0.817,
#  'diagnost center': 0.75,
#  'laboratori equip supplier': 0.037,
#  'home theater store': 0.0,
#  'metal industri supplier': 0.0,
#  'landscap suppli store': 0.0,
#  'applianc part supplier': 0.0,
#  'vacuum cleaner store': 0.167,
#  'audio visual equip supplier': 0.5,
#  'lawyer': 1.0,
#  'cell phone store': 0.0,
#  'bathroom suppli store': 0.0,
#  'leas servic': 0.0,
#  'construct machin dealer': 0.0,
#  'dairi farm equip supplier': 0.0,
#  'propan supplier': 0.0,
#  'legal servic': 0.729,
#  'janitori equip supplier': 0.144,
#  'life insur agenc': 0.586,
#  'railroad contractor': 0.0,
#  'swim pool suppli store': 0.876,
#  'light bulb supplier': 1.0,
#  'linen store': 0.042,
#  'metal construct compani': 0.317,
#  'local govern offic': 0.662,
#  'log contractor': 0.0,
#  'machin shop': 0.61,
#  'hotel suppli store': 0.0,
#  'import export compani': 0.0,
#  'sew compani': 0.25,
#  'research foundat': 0.679,
#  'machineri part manufactur': 1.0,
#  'sport accessori wholesal': 0.0,
#  'fashion design': 1.0,
#  'chees manufactur': 0.0,
#  'chees shop': 0.0,
#  'ship mail': 0.333,
#  'wholesal food store': 0.0,
#  'organ food store': 0.0,
#  'pie shop': 0.083,
#  'auction hous': 1.0,
#  'livestock auction hous': 0.111,
#  'cotton export': 0.162,
#  'plastic wholesal': 0.0,
#  'mail servic': 1.0,
#  'manufactur': 0.616,
#  'station': 1.0,
#  'beer distributor': 0.417,
#  'alcohol beverag wholesal': 0.05,
#  'religi good store': 1.0,
#  'book wholesal': 0.458,
#  'masonri suppli store': 0.031,
#  'wholesal florist': 0.117,
#  'florist': 1.0,
#  'marin engin': 0.025,
#  'paint store': 0.036,
#  'use auto part store': 0.056,
#  'masonri contractor': 0.27,
#  'use car dealer': 0.5,
#  'use truck dealer': 0.75,
#  'massag therapist': 0.5,
#  'materi handl equip supplier': 0.0,
#  'marina': 1.0,
#  'meat packer': 0.019,
#  'mattress store': 0.0,
#  'blind shop': 0.5,
#  'interior design': 0.793,
#  'window treatment store': 0.667,
#  'applianc store': 0.75,
#  'health food store': 0.233,
#  'direct mail advertis': 0.098,
#  'meat wholesal': 0.077,
#  'butcher shop deli': 0.167,
#  'italian groceri store': 0.079,
#  'food servic': 1.0,
#  'groceri deliveri servic': 0.5,
#  'wine store': 1.0,
#  'liquor store': 1.0,
#  'kiosk': 0.0,
#  'optometrist': 0.5,
#  'optician': 0.028,
#  'mechan contractor': 0.467,
#  'mechan engin': 0.125,
#  'cafe': 0.098,
#  'jewel': 0.2,
#  'leather good store': 0.125,
#  'gift shop': 1.0,
#  'craft store': 0.083,
#  'hobbi store': 0.415,
#  'fabric wholesal': 0.0,
#  'scrap metal dealer': 0.0,
#  'quilt shop': 0.028,
#  'sheet music store': 1.0,
#  'music instrument manufactur': 0.013,
#  'music store': 1.0,
#  'music instrument store': 1.0,
#  'band': 0.05,
#  'bookstor': 0.0,
#  'art museum': 1.0,
#  'newsstand': 0.5,
#  'medic equip manufactur': 0.811,
#  'fashion accessori store': 0.716,
#  'discount store': 0.0,
#  'cemeteri': 0.5,
#  'stop': 0.0,
#  'varieti store': 0.0,
#  'thrift store': 1.0,
#  'medic group': 0.0,
#  'donat center': 0.0,
#  'pet store': 0.927,
#  'art galleri': 0.2,
#  'art dealer': 0.069,
#  'hous develop': 0.268,
#  'mobil home dealer': 0.111,
#  'conveni store': 0.625,
#  'medic offic': 0.0,
#  'medic technolog manufactur': 0.0,
#  'children furnitur store': 1.0,
#  'mental health clinic': 0.117,
#  'airlin': 0.0,
#  'aviat consult': 0.0,
#  'travel agenc': 1.0,
#  'travel servic': 1.0,
#  'airport': 0.667,
#  'mental health servic': 0.2,
#  'ship compani': 0.0,
#  'metal fabric': 0.595,
#  'cruis line compani': 0.0,
#  'tow servic': 1.0,
#  'ferri termin': 0.0,
#  'ferri servic': 0.0,
#  'metal finish': 1.0,
#  'boat tour agenc': 0.2,
#  'move compani': 0.067,
#  'move storag servic': 0.067,
#  'state depart transport': 0.0,
#  'depart transport': 0.0,
#  'handicap transport servic': 0.75,
#  'railway servic': 0.0,
#  'train station': 0.0,
#  'depot': 0.0,
#  'charter': 1.0,
#  'metal process compani': 0.516,
#  'mix use': 0.0,
#  'motorcycl shop': 0.429,
#  'limousin servic': 1.0,
#  'chauffeur servic': 0.0,
#  'school servic': 0.0,
#  'airport shuttl servic': 0.75,
#  'tourist inform center': 0.0,
#  'carriag ride servic': 0.0,
#  'cruis agenc': 0.036,
#  'tourist attract': 0.125,
#  'ski resort': 1.0,
#  'ski area': 0.167,
#  'fix base oper': 0.0,
#  'aircraft mainten compani': 0.111,
#  'motorsport store': 0.0,
#  'boat rental servic': 0.703,
#  'util trailer dealer': 0.0,
#  'forklift dealer': 0.0,
#  'municip administr offic': 0.0,
#  'nephrologist': 0.5,
#  'coach compani': 0.0,
#  'ship servic': 0.0,
#  'ship mail servic': 0.0,
#  'newspap publish': 1.0,
#  'shred servic': 0.0,
#  'nuclear power compani': 0.9,
#  'nurs home': 0.0,
#  'media compani': 0.366,
#  'multimedia electron book publish': 0.0,
#  'internet market servic': 0.021,
#  'greet card shop': 0.5,
#  'theme park': 0.625,
#  'film product compani': 0.069,
#  'obstetrician gynecologist': 0.5,
#  'movi studio': 0.0,
#  'video product servic': 0.788,
#  'movi theater': 0.536,
#  'theater compani': 0.475,
#  'perform art theater': 0.747,
#  'occup safeti health': 0.0,
#  'offic space rental agenc': 0.0,
#  'commerci real estat agenc': 0.333,
#  'art school': 0.117,
#  'music publish': 0.025,
#  'print music publish': 0.0,
#  'home audio store': 0.0,
#  'musician': 0.25,
#  'music manag promot': 0.2,
#  'video edit servic': 0.333,
#  'offic suppli wholesal': 0.0,
#  'offici resid': 0.0,
#  'orthoped clinic': 0.226,
#  'painter': 0.0,
#  'paint': 0.033,
#  'telephon compani': 0.0,
#  'media hous': 0.824,
#  'paper distributor': 0.0,
#  'news servic': 0.5,
#  'public librari': 0.0,
#  'law librari': 0.499,
#  'museum': 1.0,
#  'feder reserv bank': 1.0,
#  'credit union': 0.118,
#  'atm': 0.167,
#  'pave contractor': 0.75,
#  'mortgag lender': 0.387,
#  'invest bank': 0.0,
#  'check cash servic': 0.556,
#  'stock broker': 0.0,
#  'health consult': 0.857,
#  'health insur agenc': 0.619,
#  'payrol servic': 1.0,
#  'pediatrician': 1.0,
#  'human resourc consult': 0.968,
#  'pest control servic': 0.52,
#  'pet board servic': 0.796,
#  'pet care': 0.2,
#  'loss adjust': 0.75,
#  'pharmaceut compani': 0.768,
#  'pharmaceut product wholesal': 0.2,
#  'pharmaci': 0.2,
#  'educ institut': 0.125,
#  'retir commun': 0.292,
#  'fratern organ': 1.0,
#  'photo lab': 0.0,
#  'properti invest': 0.0,
#  'photograph': 0.129,
#  'photographi school': 0.333,
#  'star hotel': 1.0,
#  'convent center': 0.0,
#  'real estat apprais': 0.887,
#  'photographi servic': 0.333,
#  'resort hotel': 0.893,
#  'real estat consult': 0.333,
#  'car rental agenc': 0.373,
#  'car leas servic': 0.0,
#  'ford dealer': 0.333,
#  'car financ loan compani': 0.837,
#  'trailer rental servic': 0.116,
#  'furnitur rental servic': 0.204,
#  'tuxedo shop': 0.0,
#  'dress tuxedo rental servic': 0.976,
#  'wed store': 0.0,
#  'video store': 0.1,
#  'movi rental': 0.0,
#  'photographi studio': 0.333,
#  'home health care servic': 1.0,
#  'skateboard shop': 0.0,
#  'event technolog servic': 0.0,
#  'parti equip rental servic': 0.976,
#  'construct machin rental servic': 0.025,
#  'audio visual equip rental servic': 0.0,
#  'ship equip industri': 0.0,
#  'physic therapi clinic': 0.069,
#  'plastic fabric compani': 0.909,
#  'plastic product supplier': 0.909,
#  'auto tag agenc': 0.257,
#  'depart motor vehicl': 0.0,
#  'notari public': 0.607,
#  'privat investig': 0.583,
#  'escrow servic': 0.0,
#  'real estat agent': 0.5,
#  'playground': 0.0,
#  'plumber': 0.056,
#  'port author': 0.775,
#  'portrait studio': 0.333,
#  'post offic': 0.333,
#  'profession servic': 0.042,
#  'univers hospit': 0.333,
#  'public relat firm': 0.025,
#  'civil engin compani': 0.167,
#  'draft servic': 0.838,
#  'pump supplier': 0.597,
#  'interior construct contractor': 0.0,
#  'carpet clean servic': 0.383,
#  'exhibit planner': 0.0,
#  'decal supplier': 0.0,
#  'stage light equip supplier': 1.0,
#  'event manag compani': 0.037,
#  'radio broadcast': 0.0,
#  'comput support servic': 1.0,
#  'ravin': 0.0,
#  'employ center': 0.05,
#  'nation health foundat': 0.333,
#  'real estat develop': 0.0,
#  'advertis agenc': 0.0,
#  'promot product supplier': 0.0,
#  'advertis servic': 0.021,
#  'record storag facil': 0.0,
#  'fund manag compani': 0.02,
#  'recreat center': 1.0,
#  'bakeri': 0.976,
#  'databas manag compani': 0.0,
#  'market research': 0.067,
#  'recycl center': 0.0,
#  'region govern offic': 0.512,
#  'rehabilit center': 0.0,
#  'religi institut': 1.0,
#  'religi organ': 1.0,
#  'repair servic': 0.768,
#  'emerg veterinarian servic': 0.222,
#  'pet sitter': 0.1,
#  'research product develop': 1.0,
#  'build societi': 0.833,
#  'valet park servic': 1.0,
#  'nurs agenc': 0.0,
#  'execut search firm': 0.375,
#  'recruit': 1.0,
#  'temp agenc': 0.125,
#  'health center': 0.0,
#  'restaur': 0.732,
#  'roof contractor': 0.269,
#  'sport nutrit store': 0.05,
#  'credit report agenc': 0.058,
#  'automobil storag facil': 1.0,
#  'debt collect agenc': 0.158,
#  'park': 0.267,
#  'court report': 0.334,
#  'tour agenc': 0.95,
#  'tour oper': 1.0,
#  'convent inform bureau': 0.028,
#  'balloon ride tour agenc': 0.5,
#  'secur guard servic': 1.0,
#  'locksmith': 0.4,
#  'commerci clean servic': 0.408,
#  'blast clean servic': 0.5,
#  'confer center': 0.0,
#  'safeti equip supplier': 0.0,
#  'garbag dump': 0.729,
#  'sanit servic': 0.04,
#  'garbag dump servic': 0.0,
#  'environment health servic': 0.0,
#  'portabl toilet supplier': 0.188,
#  'public work depart': 0.028,
#  'school district offic': 1.0,
#  'sailmak': 0.0,
#  'commun colleg': 0.5,
#  'salvag yard': 0.031,
#  'busi school': 0.0,
#  'trade school': 0.854,
#  'privat univers': 0.0,
#  'comput train school': 0.133,
#  'school suppli store': 0.0,
#  'screen printer': 0.583,
#  'media consult': 0.198,
#  'beauti school': 0.685,
#  'flight school': 0.95,
#  'seaport': 0.0,
#  'secur system supplier': 0.333,
#  'middl school': 0.5,
#  'nonprofit': 0.0,
#  'shoot rang': 0.083,
#  'soccer club': 0.167,
#  'camp': 0.833,
#  'dive contractor': 0.0,
#  'languag school': 0.495,
#  'english languag school': 0.495,
#  'preschool': 1.0,
#  'self storag facil': 0.042,
#  'semi conductor supplier': 0.0,
#  'drive school': 0.359,
#  'truck school': 0.024,
#  'senior citizen center': 0.0,
#  'servic': 0.0,
#  'children hospit': 0.333,
#  'dental suppli store': 0.244,
#  'shipyard': 1.0,
#  'orthodox synagogu': 1.0,
#  'short term apart rental agenc': 0.0,
#  'nutritionist': 0.167,
#  'ophthalmologist': 0.0,
#  'ophthalmolog clinic': 0.054,
#  'social servic organ': 1.0,
#  'social welfar center': 1.0,
#  'solar energi compani': 0.8,
#  'solar energi equip supplier': 0.8,
#  'special educ school': 1.0,
#  'podiatrist': 0.333,
#  'reproduct health clinic': 0.833,
#  'sport good store': 0.75,
#  'dialysi center': 0.786,
#  'sport complex': 0.0,
#  'well program': 0.0,
#  'sportswear store': 0.0,
#  'privat hospit': 0.25,
#  'radiologist': 0.0,
#  'medic diagnost imag center': 1.0,
#  'ray lab': 0.292,
#  'blood bank': 0.556,
#  'stainless steel plant': 0.25,
#  'state agenc': 0.12,
#  'heliport': 0.0,
#  'health care compani': 0.0,
#  'psychiatr hospit': 1.0,
#  'state govern offic': 0.696,
#  'medic institut': 0.25,
#  'steel construct compani': 0.125,
#  'clean servic': 0.5,
#  'steel drum supplier': 0.0,
#  'assist live facil': 1.0,
#  'steel erector': 0.016,
#  ...}

# %%
calc_avg_pre(ret_docs_dic, queries_dic, cutoff=-1)[1]
# Out:
# 0.34

# %%
calc_NDCG_at_n(ret_docs_dic, queries_dic, n=-1, base=2)
# Out:
# {'home improv store': 0.375,
#  'diesel fuel supplier': 0.637,
#  'church': 1.0,
#  'farm': 0.244,
#  'seed supplier': 0.244,
#  'account': 0.991,
#  'truck compani': 0.768,
#  'export': 0.203,
#  'grain elev': 0.477,
#  'popcorn store': 0.709,
#  'agricultur servic': 0.51,
#  'warehous': 0.876,
#  'agricultur product': 0.203,
#  'ranch': 1.0,
#  'hold compani': 1.0,
#  'farm equip supplier': 0.244,
#  'store': 0.637,
#  'groceri store': 0.915,
#  'rice mill': 0.924,
#  'food product supplier': 0.148,
#  'account firm': 0.94,
#  'produc market': 0.457,
#  'pet suppli store': 0.895,
#  'wholesal': 0.637,
#  'produc wholesal': 0.411,
#  'distribut servic': 0.203,
#  'crop grower': 0.69,
#  'addict treatment center': 0.637,
#  'natur good store': 0.299,
#  'orchard': 0.438,
#  'lumber store': 0.375,
#  'mine': 0.508,
#  'transport servic': 0.783,
#  'invest compani': 0.375,
#  'fruit wholesal': 0.233,
#  'real estat agenc': 0.941,
#  'event venu': 0.483,
#  'frozen dessert supplier': 0.667,
#  'wine wholesal import': 0.85,
#  'wineri': 0.887,
#  'aerospac compani': 0.722,
#  'cold storag facil': 0.929,
#  'employ agenc': 0.798,
#  'plant nurseri': 0.758,
#  'air condit contractor': 0.942,
#  'air condit repair servic': 0.483,
#  'fruit veget wholesal': 0.523,
#  'aircraft rental servic': 0.375,
#  'monasteri': 1.0,
#  'allergist': 0.879,
#  'herb shop': 0.299,
#  'aluminum supplier': 0.938,
#  'ambul servic': 0.57,
#  'wholesal plant nurseri': 0.688,
#  'amus machin supplier': 0.637,
#  'anim hospit': 0.244,
#  'farmer market': 0.337,
#  'vapor store': 0.965,
#  'cigar shop': 0.421,
#  'tobacco shop': 0.299,
#  'well drill contractor': 0.299,
#  'librari': 0.824,
#  'apart build': 0.375,
#  'apart rental agenc': 0.375,
#  'dairi farm': 0.375,
#  'architect': 0.665,
#  'organ farm': 0.278,
#  'architectur design': 0.492,
#  'architectur firm': 0.772,
#  'livestock produc': 0.375,
#  'dairi supplier': 0.148,
#  'biotechnolog compani': 0.803,
#  'artist': 1.0,
#  'egg supplier': 0.945,
#  'poultri farm': 0.375,
#  'chicken hatcheri': 0.905,
#  'art organ': 0.733,
#  'associ organ': 0.862,
#  'food store': 0.801,
#  'deli': 0.375,
#  'bank': 0.63,
#  'fish process': 0.84,
#  'fish farm': 0.57,
#  'seafood wholesal': 0.544,
#  'tropic fish store': 0.708,
#  'non profit organ': 0.84,
#  'econom develop agenc': 0.709,
#  'seafood market': 0.539,
#  'honey farm': 0.375,
#  'hors breeder': 0.375,
#  'asphalt contractor': 0.801,
#  'livestock dealer': 0.483,
#  'depart store': 1.0,
#  'mill': 0.637,
#  'atv dealer': 0.988,
#  'audio visual consult': 0.888,
#  'pallet supplier': 0.487,
#  'wood supplier': 0.375,
#  'hardwar store': 0.66,
#  'furnitur wholesal': 0.637,
#  'auditor': 0.66,
#  'oil natur compani': 0.457,
#  'auto bodi shop': 0.369,
#  'boat repair shop': 0.697,
#  'associ': 0.763,
#  'rail contractor': 0.244,
#  'publish': 0.883,
#  'pond suppli store': 0.483,
#  'agricultur cooper': 0.299,
#  'print equip supplier': 0.389,
#  'auto insur agenc': 0.819,
#  'altern fuel station': 1.0,
#  'auto part manufactur': 0.172,
#  'foundat': 0.852,
#  'fertil supplier': 0.974,
#  'farm compani': 0.244,
#  'financ broker': 0.483,
#  'fire station': 0.374,
#  'environment consult': 0.834,
#  'civil engin': 0.941,
#  'fire protect servic': 0.474,
#  'compani': 0.375,
#  'oilfield': 0.299,
#  'banquet hall': 0.758,
#  'mine compani': 0.508,
#  'coalfield': 0.483,
#  'steel fabric': 0.244,
#  'quarri': 0.858,
#  'gold mine compani': 0.835,
#  'high rise build': 0.939,
#  'basketbal club': 0.589,
#  'gold dealer': 0.299,
#  'batteri manufactur': 0.685,
#  'electr util compani': 0.299,
#  'environment program': 0.483,
#  'offic': 0.84,
#  'stone supplier': 0.498,
#  'aggreg supplier': 0.375,
#  'sand gravel supplier': 0.445,
#  'build materi supplier': 0.991,
#  'beauti suppli store': 0.681,
#  'crush stone supplier': 0.465,
#  'rock shop': 0.299,
#  'road construct compani': 1.0,
#  'market consult': 0.934,
#  'blood test servic': 0.639,
#  'contractor': 0.879,
#  'excav contractor': 0.939,
#  'asphalt mix plant': 0.811,
#  'readi mix concret supplier': 0.914,
#  'sand plant': 0.312,
#  'bmw dealer': 0.836,
#  'bookbind': 0.79,
#  'garden center': 0.955,
#  'abras supplier': 0.299,
#  'granit supplier': 0.583,
#  'drill contractor': 0.299,
#  'bpo compani': 0.287,
#  'oil explor servic': 0.7,
#  'build complex': 0.375,
#  'construct equip supplier': 0.244,
#  'mine equip': 0.299,
#  'ticket agenc': 0.843,
#  'busi center': 0.235,
#  'skyscrap': 0.637,
#  'softwar compani': 1.0,
#  'busi develop servic': 0.264,
#  'busi manag consult': 0.928,
#  'cabinet maker': 0.826,
#  'call center': 0.506,
#  'cancer treatment center': 0.84,
#  'power plant consult': 0.483,
#  'busi park': 0.605,
#  'petroleum product compani': 0.75,
#  'park lot': 0.583,
#  'water util compani': 0.942,
#  'car repair mainten': 0.678,
#  'water treatment plant': 1.0,
#  'car servic': 0.273,
#  'cattl market': 0.589,
#  'sewag dispos servic': 0.966,
#  'certifi public account': 0.66,
#  'govern offic': 0.907,
#  'chariti': 0.758,
#  'air condit system supplier': 0.375,
#  'chemic industri': 0.45,
#  'chemic manufactur': 0.511,
#  'titl compani': 0.555,
#  'chemic plant': 0.518,
#  'properti manag compani': 0.375,
#  'custom home builder': 0.696,
#  'window instal servic': 0.172,
#  'fire damag restor servic': 0.375,
#  'equip rental agenc': 0.487,
#  'chemic wholesal': 0.637,
#  'financi planner': 0.299,
#  'telecommun servic provid': 0.842,
#  'energi equip solut': 0.637,
#  'chiropractor': 0.628,
#  'steel distributor': 0.637,
#  'citi govern offic': 0.878,
#  'crane servic': 0.312,
#  'garag door supplier': 0.332,
#  'industri door supplier': 0.513,
#  'citi town hall': 0.383,
#  'cloth wholesal': 0.418,
#  'coin oper laundri equip supplier': 1.0,
#  'metal supplier': 0.637,
#  'glass shop': 0.172,
#  'colleg': 1.0,
#  'side contractor': 0.622,
#  'commerci printer': 0.47,
#  'storag facil': 0.893,
#  'commun tower': 0.758,
#  'janitori servic': 0.64,
#  'comput consult': 0.465,
#  'fire protect system supplier': 0.474,
#  'elev servic': 0.312,
#  'industri equip supplier': 0.244,
#  'dri wall contractor': 0.652,
#  'insul contractor': 0.606,
#  'concret contractor': 0.814,
#  'scaffold rental servic': 0.462,
#  'construct compani': 1.0,
#  'floor store': 0.862,
#  'floor contractor': 0.701,
#  'tile contractor': 0.798,
#  'tile manufactur': 0.244,
#  'glass mirror shop': 0.172,
#  'construct materi wholesal': 0.375,
#  'gutter clean servic': 0.776,
#  'sheet metal contractor': 0.756,
#  'consult': 0.958,
#  'contain servic': 0.375,
#  'septic system servic': 0.767,
#  'corpor campu': 0.657,
#  'water damag restor servic': 0.375,
#  'welder': 0.085,
#  'corpor offic': 0.657,
#  'anim': 0.929,
#  'anim feed store': 0.299,
#  'anim protect organ': 0.483,
#  'brew suppli store': 0.637,
#  'cosmet store': 0.689,
#  'counti govern offic': 0.882,
#  'sugar factori': 0.974,
#  'confectioneri wholesal': 0.445,
#  'financi institut': 0.244,
#  'candi store': 0.616,
#  'confectioneri': 0.457,
#  'chocol factori': 0.962,
#  'chocol shop': 0.944,
#  'courier servic': 1.0,
#  'cowork space': 0.43,
#  'frozen food manufactur': 0.811,
#  'beverag distributor': 0.637,
#  'agricultur organ': 0.299,
#  'dairi store': 0.148,
#  'dairi': 0.604,
#  'ice cream shop': 0.652,
#  'medic laboratori': 1.0,
#  'demolit contractor': 0.955,
#  'meat processor': 0.914,
#  'fmcg manufactur': 0.244,
#  'garbag collect servic': 0.789,
#  'wholesal bakeri': 0.989,
#  'dentist': 0.902,
#  'dessert shop': 0.244,
#  'cupcak shop': 0.244,
#  'nut store': 0.809,
#  'wholesal grocer': 0.297,
#  'design engin': 0.435,
#  'busi busi servic': 0.629,
#  'condiment supplier': 0.83,
#  'digit print servic': 0.974,
#  'culinari school': 0.884,
#  'import': 0.203,
#  'bottl water supplier': 0.656,
#  'coffe roaster': 0.172,
#  'packag suppli store': 0.483,
#  'ice supplier': 0.87,
#  'breweri': 0.876,
#  'winemak compani': 0.244,
#  'distilleri': 0.899,
#  'disabl servic support organis': 0.85,
#  'district govern offic': 0.812,
#  'air filter supplier': 0.852,
#  'tire shop': 0.879,
#  'fasten supplier': 0.677,
#  'fabric product manufactur': 0.637,
#  'textil': 0.801,
#  'textil export': 0.801,
#  'textil engin': 0.801,
#  'fabric store': 0.375,
#  'knit shop': 0.576,
#  'doctor': 1.0,
#  'lamin servic': 0.114,
#  'plastic resin manufactur': 0.758,
#  'carpet manufactur': 0.879,
#  'upholsteri shop': 0.299,
#  'busi administr servic': 0.203,
#  'furnitur store': 1.0,
#  'dri cleaner': 0.375,
#  'packag compani': 0.621,
#  'duti free store': 0.965,
#  'commerc servic': 0.84,
#  'cabl compani': 0.84,
#  'educ': 1.0,
#  'outlet store': 0.637,
#  'lingeri store': 0.523,
#  'cloth fabric manufactur': 0.637,
#  'educ center': 1.0,
#  'uniform store': 0.383,
#  'men cloth store': 0.874,
#  'cloth store': 0.93,
#  'women cloth store': 0.889,
#  'western apparel store': 0.244,
#  'costum store': 0.244,
#  'game store': 0.732,
#  'hat shop': 0.244,
#  'leather good manufactur': 0.741,
#  'educ consult': 0.897,
#  'leather export': 1.0,
#  'shoe store': 1.0,
#  'boutiqu': 0.244,
#  'leather wholesal': 0.777,
#  'handbag shop': 0.741,
#  'electron store': 0.83,
#  'luggag store': 0.915,
#  'build materi store': 0.733,
#  'saw mill': 0.834,
#  'electr engin': 0.172,
#  'deck builder': 0.286,
#  'concret product supplier': 0.808,
#  'plywood supplier': 0.985,
#  'electr instal servic': 0.483,
#  'truss manufactur': 0.842,
#  'door supplier': 0.308,
#  'wood lamin floor supplier': 0.873,
#  'aircraft suppli store': 0.244,
#  'modular home builder': 0.203,
#  'portabl build manufactur': 0.244,
#  'modular home dealer': 0.412,
#  'mulch supplier': 0.244,
#  'electrician': 0.657,
#  'paper mill': 0.826,
#  'energi supplier': 0.92,
#  'engin': 0.487,
#  'print shop': 0.974,
#  'custom label printer': 0.555,
#  'market': 0.474,
#  'market agenc': 0.172,
#  'engin consult': 0.266,
#  'entertain': 0.244,
#  'envelop supplier': 0.474,
#  'oil refineri': 0.619,
#  'record studio': 0.904,
#  'environ renew natur resourc': 0.129,
#  'finish materi supplier': 0.479,
#  'event ticket seller': 0.375,
#  'waterproof compani': 0.244,
#  'auto part store': 0.713,
#  'heat oil supplier': 0.723,
#  'famili practic physician': 0.801,
#  'machin manufactur': 0.299,
#  'industri supplier': 0.203,
#  'weld suppli store': 0.085,
#  'dri ice supplier': 0.695,
#  'privat equiti firm': 0.299,
#  'famili servic center': 0.758,
#  'feder govern offic': 0.914,
#  'vitamin supplement store': 0.811,
#  'feed manufactur': 1.0,
#  'medic equip supplier': 0.203,
#  'medic suppli store': 0.203,
#  'medic clinic': 0.673,
#  'research institut': 0.919,
#  'biochem supplier': 0.637,
#  'fiber optic product supplier': 0.435,
#  'paint manufactur': 1.0,
#  'equip supplier': 0.244,
#  'food': 0.242,
#  'pipe supplier': 0.506,
#  'oil field equip supplier': 0.697,
#  'food broker': 0.148,
#  'food manufactur': 0.85,
#  'food process compani': 0.242,
#  'fenc suppli store': 0.66,
#  'food produc': 0.242,
#  'forestri servic': 1.0,
#  'foundri': 0.961,
#  'wholesal jewel': 0.655,
#  'cooki shop': 0.691,
#  'truck rental agenc': 0.682,
#  'fruit veget process': 0.753,
#  'kitchen suppli store': 0.203,
#  'hydraul equip supplier': 0.244,
#  'irrig equip supplier': 0.758,
#  'bear supplier': 0.506,
#  'metallurgi compani': 0.583,
#  'plastic inject mold servic': 0.299,
#  'gener contractor': 0.637,
#  'gener hospit': 1.0,
#  'tool manufactur': 0.931,
#  'industri design compani': 0.503,
#  'hyundai dealer': 0.375,
#  'glass industri': 0.974,
#  'polym supplier': 0.637,
#  'print equip suppli': 0.299,
#  'toner cartridg supplier': 0.555,
#  'printer repair servic': 0.66,
#  'fuel supplier': 0.637,
#  'glass manufactur': 0.947,
#  'plastic bag supplier': 0.805,
#  'glasswar manufactur': 0.518,
#  'polythen plastic sheet supplier': 0.901,
#  'pvc industri': 0.114,
#  'countertop store': 0.375,
#  'cabinet store': 0.498,
#  'fiberglass supplier': 0.583,
#  'golf cart dealer': 0.988,
#  'auto repair shop': 0.66,
#  'hose supplier': 0.661,
#  'rubber product supplier': 0.981,
#  'automot': 0.375,
#  'commerci refriger supplier': 0.375,
#  'golf club': 0.696,
#  'golf cours': 0.552,
#  'green energi supplier': 0.878,
#  'greenhous': 0.375,
#  'auto glass shop': 0.258,
#  'light manufactur': 0.947,
#  'cement manufactur': 0.914,
#  'brick manufactur': 0.981,
#  'natur stone supplier': 0.375,
#  'gym': 0.523,
#  'marbl supplier': 0.583,
#  'corpor gift supplier': 1.0,
#  'shipbuild repair compani': 0.637,
#  'construct mainten offic': 1.0,
#  'boiler manufactur': 0.822,
#  'contain supplier': 0.975,
#  'home construct': 0.649,
#  'health': 0.753,
#  'heart hospit': 1.0,
#  'spring supplier': 1.0,
#  'electr util manufactur': 0.299,
#  'aircraft manufactur': 0.94,
#  'metal heat treat servic': 0.966,
#  'plate servic': 0.483,
#  'autom compani': 0.375,
#  'heat contractor': 0.942,
#  'plumb suppli store': 0.375,
#  'gun shop': 0.555,
#  'ammunit supplier': 0.888,
#  'pipe manufactur': 0.632,
#  'school': 1.0,
#  'fire protect equip supplier': 0.474,
#  'agricultur machineri manufactur': 0.532,
#  'lawn mower store': 0.637,
#  'lawn irrig equip supplier': 0.621,
#  'financi consult': 0.299,
#  'helicopt charter': 0.828,
#  'packag machineri': 0.173,
#  'histor landmark': 1.0,
#  'electron manufactur': 0.916,
#  'graphic design': 0.938,
#  'eye care center': 0.352,
#  'optic product manufactur': 0.66,
#  'imag consult': 0.439,
#  'clean product supplier': 0.244,
#  'fireplac store': 0.375,
#  'home builder': 0.734,
#  'tool die shop': 0.928,
#  'metal stamp servic': 0.673,
#  'environment organ': 0.908,
#  'food process equip': 0.299,
#  'loan agenc': 0.692,
#  'power plant equip supplier': 0.483,
#  'home good store': 0.837,
#  'engin rebuild servic': 0.148,
#  'air compressor supplier': 0.383,
#  'honda dealer': 0.807,
#  'elev manufactur': 0.387,
#  'crane dealer': 0.085,
#  'crane rental agenc': 0.553,
#  'compound build': 0.172,
#  'tractor dealer': 0.244,
#  'furnac part supplier': 0.375,
#  'heat equip supplier': 0.375,
#  'pneumat tool supplier': 0.375,
#  'truck stop': 0.68,
#  'comput hardwar manufactur': 0.966,
#  'satellit commun servic': 0.909,
#  'hospit': 0.941,
#  'electron compani': 0.717,
#  'electron part supplier': 0.483,
#  'hvac contractor': 0.942,
#  'industri engin': 0.516,
#  'contact lens supplier': 0.621,
#  'inform servic': 0.992,
#  'build': 0.955,
#  'water work equip supplier': 0.375,
#  'measur instrument supplier': 0.772,
#  'scientif equip supplier': 0.203,
#  'medic center': 0.84,
#  'watch manufactur': 0.299,
#  'corpor entertain servic': 0.84,
#  'insur': 0.7,
#  'record compani': 0.822,
#  'video duplic servic': 0.344,
#  'insur agenc': 0.819,
#  'light store': 0.939,
#  'light wholesal': 0.947,
#  'entertain agenc': 1.0,
#  'insur broker': 0.724,
#  'electr equip supplier': 0.483,
#  'electr motor store': 0.172,
#  'railroad compani': 1.0,
#  'electr suppli store': 0.483,
#  'insur compani': 0.7,
#  'factori equip supplier': 0.244,
#  'invest servic': 0.901,
#  'laser equip supplier': 0.148,
#  'execut suit rental agenc': 0.387,
#  'truck dealer': 0.375,
#  'motor vehicl dealer': 0.81,
#  'car dealer': 0.939,
#  'truck topper supplier': 0.244,
#  'polic suppli store': 0.981,
#  'iron steel contractor': 0.38,
#  'fire depart equip supplier': 0.32,
#  'tow equip provid': 1.0,
#  'logist servic': 0.519,
#  'trailer manufactur': 0.955,
#  'trailer dealer': 0.483,
#  'dealer': 0.896,
#  'auto spring shop': 0.148,
#  'auto upholster': 0.172,
#  'auto bodi part supplier': 0.637,
#  'car factori': 0.483,
#  'freight forward servic': 1.0,
#  'brake shop': 0.294,
#  'railroad equip supplier': 0.244,
#  'jewelri equip supplier': 0.816,
#  'boat builder': 0.955,
#  'ship build': 1.0,
#  'marin suppli store': 0.483,
#  'boat dealer': 0.982,
#  'kawasaki motorcycl dealer': 0.988,
#  'knife manufactur': 0.637,
#  'labor union': 0.918,
#  'furnitur maker': 0.89,
#  'bank financ': 0.516,
#  'furnitur manufactur': 0.891,
#  'logist': 0.554,
#  'massag suppli store': 0.244,
#  'telecommun equip supplier': 0.483,
#  'babi store': 0.244,
#  'mold supplier': 0.583,
#  'offic equip supplier': 0.203,
#  'offic furnitur store': 0.862,
#  'store equip supplier': 0.244,
#  'laboratori': 0.274,
#  'health beauti shop': 0.583,
#  'learn center': 0.383,
#  'dental laboratori': 0.592,
#  'land surveyor': 0.369,
#  'educ suppli store': 0.758,
#  'jewelri store': 0.919,
#  'playground equip supplier': 0.299,
#  'outdoor sport store': 0.805,
#  'toy store': 0.732,
#  'secur servic': 0.5,
#  'sign shop': 0.354,
#  'offic suppli store': 0.879,
#  'landscap': 0.801,
#  'gasket manufactur': 0.917,
#  'piano maker': 0.207,
#  'piano store': 0.498,
#  'funer home': 1.0,
#  'monument': 0.375,
#  'book publish': 0.863,
#  'wig shop': 0.523,
#  'laundromat': 0.66,
#  'auto wrecker': 0.723,
#  'auto part market': 0.833,
#  'jeep dealer': 0.807,
#  'restaur suppli store': 0.244,
#  'roof suppli store': 0.375,
#  'law firm': 0.66,
#  'build materi market': 0.991,
#  'camera store': 0.203,
#  'lawn care servic': 0.299,
#  'comput secur servic': 0.299,
#  'comput store': 0.203,
#  'design agenc': 0.963,
#  'diagnost center': 0.939,
#  'laboratori equip supplier': 0.309,
#  'home theater store': 0.84,
#  'metal industri supplier': 0.637,
#  'landscap suppli store': 0.637,
#  'applianc part supplier': 0.483,
#  'vacuum cleaner store': 0.789,
#  'audio visual equip supplier': 1.0,
#  'lawyer': 0.929,
#  'cell phone store': 0.637,
#  'bathroom suppli store': 0.375,
#  'leas servic': 0.375,
#  'construct machin dealer': 0.244,
#  'dairi farm equip supplier': 0.244,
#  'propan supplier': 0.637,
#  'legal servic': 0.879,
#  'janitori equip supplier': 0.601,
#  'life insur agenc': 0.681,
#  'railroad contractor': 0.84,
#  'swim pool suppli store': 0.981,
#  'light bulb supplier': 0.974,
#  'linen store': 0.485,
#  'metal construct compani': 0.518,
#  'local govern offic': 0.919,
#  'log contractor': 0.84,
#  'machin shop': 0.87,
#  'hotel suppli store': 0.375,
#  'import export compani': 0.203,
#  'sew compani': 0.66,
#  'research foundat': 0.811,
#  'machineri part manufactur': 0.918,
#  'sport accessori wholesal': 0.299,
#  'fashion design': 1.0,
#  'chees manufactur': 0.299,
#  'chees shop': 0.299,
#  'ship mail': 0.941,
#  'wholesal food store': 0.148,
#  'organ food store': 0.299,
#  'pie shop': 0.523,
#  'auction hous': 0.943,
#  'livestock auction hous': 0.657,
#  'cotton export': 0.513,
#  'plastic wholesal': 0.637,
#  'mail servic': 1.0,
#  'manufactur': 0.9,
#  'station': 1.0,
#  'beer distributor': 0.85,
#  'alcohol beverag wholesal': 0.709,
#  'religi good store': 1.0,
#  'book wholesal': 0.662,
#  'masonri suppli store': 0.47,
#  'wholesal florist': 0.537,
#  'florist': 1.0,
#  'marin engin': 0.286,
#  'paint store': 0.477,
#  'use auto part store': 0.713,
#  'masonri contractor': 0.62,
#  'use car dealer': 0.939,
#  'use truck dealer': 0.939,
#  'massag therapist': 0.716,
#  'materi handl equip supplier': 0.244,
#  'marina': 0.875,
#  'meat packer': 0.247,
#  'mattress store': 0.84,
#  'blind shop': 0.879,
#  'interior design': 0.875,
#  'window treatment store': 0.942,
#  'applianc store': 0.939,
#  'health food store': 0.727,
#  'direct mail advertis': 0.447,
#  'meat wholesal': 0.315,
#  'butcher shop deli': 0.523,
#  'italian groceri store': 0.442,
#  'food servic': 1.0,
#  'groceri deliveri servic': 1.0,
#  'wine store': 1.0,
#  'liquor store': 1.0,
#  'kiosk': 0.483,
#  'optometrist': 0.628,
#  'optician': 0.352,
#  'mechan contractor': 0.785,
#  'mechan engin': 0.435,
#  'cafe': 0.495,
#  'jewel': 0.583,
#  'leather good store': 0.758,
#  'gift shop': 1.0,
#  'craft store': 0.465,
#  'hobbi store': 0.784,
#  'fabric wholesal': 0.375,
#  'scrap metal dealer': 0.299,
#  'quilt shop': 0.442,
#  'sheet music store': 0.955,
#  'music instrument manufactur': 0.2,
#  'music store': 0.955,
#  'music instrument store': 0.955,
#  'band': 0.498,
#  'bookstor': 0.637,
#  'art museum': 0.955,
#  'newsstand': 0.879,
#  'medic equip manufactur': 0.863,
#  'fashion accessori store': 0.792,
#  'discount store': 0.637,
#  'cemeteri': 0.879,
#  'stop': 0.375,
#  'varieti store': 0.637,
#  'thrift store': 1.0,
#  'medic group': 0.637,
#  'donat center': 0.84,
#  'pet store': 0.874,
#  'art galleri': 0.583,
#  'art dealer': 0.417,
#  'hous develop': 0.783,
#  'mobil home dealer': 0.496,
#  'conveni store': 0.919,
#  'medic offic': 0.637,
#  'medic technolog manufactur': 0.299,
#  'children furnitur store': 1.0,
#  'mental health clinic': 0.551,
#  'airlin': 0.637,
#  'aviat consult': 0.483,
#  'travel agenc': 0.876,
#  'travel servic': 0.876,
#  'airport': 0.942,
#  'mental health servic': 0.551,
#  'ship compani': 0.84,
#  'metal fabric': 0.846,
#  'cruis line compani': 0.375,
#  'tow servic': 1.0,
#  'ferri termin': 0.375,
#  'ferri servic': 0.637,
#  'metal finish': 0.932,
#  'boat tour agenc': 0.909,
#  'move compani': 0.601,
#  'move storag servic': 0.601,
#  'state depart transport': 0.299,
#  'depart transport': 0.299,
#  'handicap transport servic': 0.939,
#  'railway servic': 0.84,
#  'train station': 0.375,
#  'depot': 0.84,
#  'charter': 1.0,
#  'metal process compani': 0.615,
#  'mix use': 0.375,
#  'motorcycl shop': 0.824,
#  'limousin servic': 1.0,
#  'chauffeur servic': 0.637,
#  'school servic': 0.84,
#  'airport shuttl servic': 0.939,
#  'tourist inform center': 0.375,
#  'carriag ride servic': 0.84,
#  'cruis agenc': 0.4,
#  'tourist attract': 0.66,
#  'ski resort': 0.875,
#  'ski area': 0.523,
#  'fix base oper': 0.483,
#  'aircraft mainten compani': 0.657,
#  'motorsport store': 0.483,
#  'boat rental servic': 0.774,
#  'util trailer dealer': 0.483,
#  'forklift dealer': 0.244,
#  'municip administr offic': 0.244,
#  'nephrologist': 0.879,
#  'coach compani': 0.84,
#  'ship servic': 0.84,
#  'ship mail servic': 0.84,
#  'newspap publish': 0.862,
#  'shred servic': 0.483,
#  'nuclear power compani': 0.891,
#  'nurs home': 0.84,
#  'media compani': 0.692,
#  'multimedia electron book publish': 0.375,
#  'internet market servic': 0.185,
#  'greet card shop': 0.879,
#  'theme park': 0.919,
#  'film product compani': 0.293,
#  'obstetrician gynecologist': 0.879,
#  'movi studio': 0.244,
#  'video product servic': 0.719,
#  'movi theater': 0.83,
#  'theater compani': 0.78,
#  'perform art theater': 0.847,
#  'occup safeti health': 0.84,
#  'offic space rental agenc': 0.375,
#  'commerci real estat agenc': 0.941,
#  'art school': 0.537,
#  'music publish': 0.461,
#  'print music publish': 0.375,
#  'home audio store': 0.84,
#  'musician': 0.66,
#  'music manag promot': 0.909,
#  'video edit servic': 0.755,
#  'offic suppli wholesal': 0.483,
#  'offici resid': 0.375,
#  'orthoped clinic': 0.77,
#  'painter': 0.244,
#  'paint': 0.364,
#  'telephon compani': 0.637,
#  'media hous': 0.891,
#  'paper distributor': 0.483,
#  'news servic': 0.879,
#  'public librari': 0.375,
#  'law librari': 0.824,
#  'museum': 0.955,
#  'feder reserv bank': 1.0,
#  'credit union': 0.54,
#  'atm': 0.758,
#  'pave contractor': 0.939,
#  'mortgag lender': 0.762,
#  'invest bank': 0.375,
#  'check cash servic': 0.816,
#  'stock broker': 0.375,
#  'health consult': 0.78,
#  'health insur agenc': 0.747,
#  'payrol servic': 0.929,
#  'pediatrician': 1.0,
#  'human resourc consult': 0.937,
#  'pest control servic': 0.738,
#  'pet board servic': 0.838,
#  'pet care': 0.583,
#  'loss adjust': 0.938,
#  'pharmaceut compani': 0.953,
#  'pharmaceut product wholesal': 0.909,
#  'pharmaci': 0.583,
#  'educ institut': 0.893,
#  'retir commun': 0.805,
#  'fratern organ': 1.0,
#  'photo lab': 0.244,
#  'properti invest': 0.375,
#  'photograph': 0.462,
#  'photographi school': 0.755,
#  'star hotel': 0.991,
#  'convent center': 0.375,
#  'real estat apprais': 0.895,
#  'photographi servic': 0.755,
#  'resort hotel': 0.97,
#  'real estat consult': 0.941,
#  'car rental agenc': 0.853,
#  'car leas servic': 0.483,
#  'ford dealer': 0.807,
#  'car financ loan compani': 0.73,
#  'trailer rental servic': 0.633,
#  'furnitur rental servic': 0.567,
#  'tuxedo shop': 0.244,
#  'dress tuxedo rental servic': 0.916,
#  'wed store': 0.244,
#  'video store': 0.741,
#  'movi rental': 0.244,
#  'photographi studio': 0.755,
#  'home health care servic': 1.0,
#  'skateboard shop': 0.114,
#  'event technolog servic': 0.483,
#  'parti equip rental servic': 0.942,
#  'construct machin rental servic': 0.461,
#  'audio visual equip rental servic': 0.84,
#  'ship equip industri': 0.244,
#  'physic therapi clinic': 0.414,
#  'plastic fabric compani': 0.982,
#  'plastic product supplier': 0.976,
#  'auto tag agenc': 0.547,
#  'depart motor vehicl': 0.299,
#  'notari public': 0.782,
#  'privat investig': 0.824,
#  'escrow servic': 0.299,
#  'real estat agent': 1.0,
#  'playground': 0.244,
#  'plumber': 0.589,
#  'port author': 0.871,
#  'portrait studio': 0.755,
#  'post offic': 0.941,
#  'profession servic': 0.383,
#  'univers hospit': 0.941,
#  'public relat firm': 0.286,
#  'civil engin compani': 0.902,
#  'draft servic': 0.974,
#  'pump supplier': 0.741,
#  'interior construct contractor': 0.637,
#  'carpet clean servic': 0.621,
#  'exhibit planner': 0.483,
#  'decal supplier': 0.114,
#  'stage light equip supplier': 1.0,
#  'event manag compani': 0.57,
#  'radio broadcast': 0.085,
#  'comput support servic': 0.955,
#  'ravin': 0.375,
#  'employ center': 0.498,
#  'nation health foundat': 0.666,
#  'real estat develop': 0.375,
#  'advertis agenc': 0.172,
#  'promot product supplier': 0.172,
#  'advertis servic': 0.185,
#  'record storag facil': 0.375,
#  'fund manag compani': 0.385,
#  'recreat center': 0.887,
#  'bakeri': 0.989,
#  'databas manag compani': 0.84,
#  'market research': 0.378,
#  'recycl center': 0.299,
#  'region govern offic': 0.842,
#  'rehabilit center': 0.637,
#  'religi institut': 1.0,
#  'religi organ': 1.0,
#  'repair servic': 0.732,
#  'emerg veterinarian servic': 0.541,
#  'pet sitter': 0.583,
#  'research product develop': 0.947,
#  'build societi': 0.955,
#  'valet park servic': 0.918,
#  'nurs agenc': 0.84,
#  'execut search firm': 0.767,
#  'recruit': 1.0,
#  'temp agenc': 0.66,
#  'health center': 0.84,
#  'restaur': 0.949,
#  'roof contractor': 0.616,
#  'sport nutrit store': 0.441,
#  'credit report agenc': 0.301,
#  'automobil storag facil': 0.955,
#  'debt collect agenc': 0.407,
#  'park': 0.605,
#  'court report': 0.692,
#  'tour agenc': 0.914,
#  'tour oper': 0.955,
#  'convent inform bureau': 0.465,
#  'balloon ride tour agenc': 1.0,
#  'secur guard servic': 1.0,
#  'locksmith': 0.811,
#  'commerci clean servic': 0.573,
#  'blast clean servic': 0.684,
#  'confer center': 0.483,
#  'safeti equip supplier': 0.203,
#  'garbag dump': 0.769,
#  'sanit servic': 0.421,
#  'garbag dump servic': 0.483,
#  'environment health servic': 0.203,
#  'portabl toilet supplier': 0.732,
#  'public work depart': 0.352,
#  'school district offic': 1.0,
#  'sailmak': 0.375,
#  'commun colleg': 1.0,
#  'salvag yard': 0.47,
#  'busi school': 0.483,
#  'trade school': 0.973,
#  'privat univers': 0.84,
#  'comput train school': 0.629,
#  'school suppli store': 0.483,
#  'screen printer': 0.919,
#  'media consult': 0.562,
#  'beauti school': 0.76,
#  'flight school': 0.928,
#  'seaport': 0.375,
#  'secur system supplier': 0.727,
#  'middl school': 1.0,
#  'nonprofit': 0.84,
#  'shoot rang': 0.523,
#  'soccer club': 0.758,
#  'camp': 0.955,
#  'dive contractor': 0.483,
#  'languag school': 0.703,
#  'english languag school': 0.703,
#  'preschool': 1.0,
#  'self storag facil': 0.485,
#  'semi conductor supplier': 0.244,
#  'drive school': 0.742,
#  'truck school': 0.294,
#  'senior citizen center': 0.483,
#  'servic': 0.375,
#  'children hospit': 0.941,
#  'dental suppli store': 0.601,
#  'shipyard': 1.0,
#  'orthodox synagogu': 1.0,
#  'short term apart rental agenc': 0.375,
#  'nutritionist': 0.523,
#  'ophthalmologist': 0.244,
#  'ophthalmolog clinic': 0.331,
#  'social servic organ': 1.0,
#  'social welfar center': 1.0,
#  'solar energi compani': 0.878,
#  'solar energi equip supplier': 0.878,
#  'special educ school': 1.0,
#  'podiatrist': 0.755,
#  'reproduct health clinic': 0.711,
#  'sport good store': 0.938,
#  'dialysi center': 0.912,
#  'sport complex': 0.244,
#  'well program': 0.483,
#  'sportswear store': 0.375,
#  'privat hospit': 0.92,
#  'radiologist': 0.637,
#  'medic diagnost imag center': 1.0,
#  'ray lab': 0.83,
#  'blood bank': 0.874,
#  'stainless steel plant': 0.92,
#  'state agenc': 0.518,
#  'heliport': 0.483,
#  'health care compani': 0.84,
#  'psychiatr hospit': 1.0,
#  'state govern offic': 0.939,
#  'medic institut': 0.92,
#  'steel construct compani': 0.435,
#  'clean servic': 0.684,
#  'steel drum supplier': 0.375,
#  'assist live facil': 1.0,
#  'steel erector': 0.26,
#  ...}

# %%
tfidf_maps = []
for i in range(1, 11):
    tfidf_maps.append(calc_avg_pre(ret_docs_dic, queries_dic, cutoff=i)[1])
