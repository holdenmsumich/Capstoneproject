# %% [markdown]
# #### The final version of the Recommender system demonstrates the "improvement" of the system after receiving user feedback. It uses the LSI model from before, but takes the relevance judgments as feedback to imrpove the next iteration. The only drawback in this scenario is that Rocchio feedback only works with queries that have been seen before. While the system improves greatly, it does nothing to improve the results of the LSI model if the query has not been seen before.

# %%
import pandas as pd
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import re
from sklearn.decomposition import TruncatedSVD
import json

# %%
stop_words = set(stopwords.words("english"))

PATTERN_S = re.compile("\'s")  # matches `'s` from text  
PATTERN_RN = re.compile("\\r\\n\\b") #matches `\r` and `\n`
PATTERN_PUNC = re.compile(r"[^\w\s]") # matches all non 0-9 A-z whitespace 


def clean_text(text):
    """
    Series of cleaning. String to lower case, remove non words characters and numbers (punctuation, curly brackets etc).
        text (str): input text
    return (str): modified initial text
    """
    text = text.lower()  # lowercase text
    # replace the matched string with ' '
    text = re.sub(PATTERN_S, ' ', text)
    text = re.sub(PATTERN_RN, ' ', text)
    text = re.sub(PATTERN_PUNC, ' ', text)
    return text

def tokenizer(description, stop_words, normalization):
    
    if normalization == 'lemmatize':
        # tokenize and lemmatize text
        lemmatizer = WordNetLemmatizer()
        tokens = [lemmatizer.lemmatize(w) for w in word_tokenize(description)]
        
    elif normalization == 'stem':
        # tokenize and stem text
        stemmer = PorterStemmer()
        tokens = [stemmer.stem(w) for w in word_tokenize(description)]
    
   # remove tokens length of 2 or below and make all lowercase and remove stop words
    tokens = [w.lower() for w in tokens if (w.lower() not in stop_words) and (len(w) > 2) and(w.isalpha())]
    
    return tokens    
    
def process_query(query, normalization):
    stop_words = set(stopwords.words("english"))
    
    return tokenizer(clean_text(query), stop_words, normalization)

# %%
# code example taken from https://towardsdatascience.com/build-a-text-recommendation-system-with-python-e8b95d9f251c
def retrieve_top_n(m, max_docs):
    # return the sum on all tokens of cosinus for each sentence
    if len(m.shape) > 1:
        cos_sim = np.mean(m, axis=0) 
    else: 
        cos_sim = m
    index = np.argsort(cos_sim)[::-1] # from highest idx to smallest score \
    mask = np.ones(len(cos_sim))
    mask = np.logical_or(cos_sim[index] != 0, mask) #eliminate 0 cosine distance
    best_index = index[mask][:max_docs]  
    return best_index

# %%
class RocchioRecommenderSystem:
    def __init__(self, docs, num_concepts=100, alpha=1.0, beta=0.75, gamma=0.15):
        self.alpha, self.beta, self.gamma = alpha, beta, gamma
        
        # create a doc-term matrix out of our doc collection
        self.vec = TfidfVectorizer()
        doc_term_mat = self.vec.fit_transform([" ".join(docs[doc_id]) for doc_id in docs])
        self.svd = TruncatedSVD(n_components=num_concepts, random_state=42)
        result = self.svd.fit_transform(doc_term_mat)
        
        self.q_vecs = {}
        
        self.doc_vecs = result # document vectors in a matrix
        
    def retrieve_docs(self, query, max_docs=10, normalization='lemmatize'):
        query = ' '.join(process_query(query, normalization))
        
        if query not in self.q_vecs:
            q_vec = self.vec.transform([query])
            lsi_transform = self.svd.transform(q_vec)
            self.q_vecs[query] = lsi_transform
        
        ret_docs = {}
        
        mat = cosine_similarity(self.q_vecs[query], self.doc_vecs)
        best_index = retrieve_top_n(mat, max_docs=max_docs)
        
        return best_index
    
    def gather_feedback(self, query, max_docs=10, feedback=None, normalization='lemmatize'):
        """
        This function models the interactive relevance feedback loop
        """
        query = ' '.join(process_query(query, normalization))
        # Step 2: Retrieve the required number of docs in reponse to the queries
        ret_docs = self.retrieve_docs(query, max_docs=max_docs)
        
        
        # display docs to user
        # receive feedback from user

        # Step 3: Obtain feedback from the user in the form of precisions at each rank
        # user_feedback = feedback
        # map index to user feedback
        idx_dic = {}
        # for i, doc in enumerate(ret_docs):
        #     try:
        #         idx_dic[doc] = user_feedback[i]
        #     except:
        #         idx_dic[doc] = 0
        
        for feed in feedback:
            if feed[0] == 1:
                idx_dic[feed[1]] = 1
            else:
                idx_dic[feed[1]] = 0
                

        self.q_vecs[query] = np.dot(self.alpha, self.q_vecs[query])
        for key, value in idx_dic.items():
            if value == 1:
                self.q_vecs[query] += np.dot(self.beta, self.doc_vecs[key])
            else:
                self.q_vecs[query] -= np.dot(self.gamma, self.doc_vecs[key])
        self.q_vecs[query][self.q_vecs[query] < 0] = 0

# %%
df = pd.read_pickle(r'assets/processed_df.pkl')
docs = dict(zip(df['naics'], df['lemmatized']))
model = RocchioRecommenderSystem(docs, beta=1.2, gamma=.05)
best_index = model.retrieve_docs('Church', max_docs=100)
naics_titles = pd.read_excel('assets/6-digit_2017_Codes.xlsx')
naics_titles['naics'] = naics_titles['naics'].astype(str)
df = df.merge(naics_titles, on='naics', how='outer')
df.iloc[best_index][['naics', 'title']]
# Out:
#       naics                                              title
# 474  337127             Institutional Furniture Manufacturing
# 470  337121     Upholstered Household Furniture Manufacturing
# 472  337124           Metal Household Furniture Manufacturing
# 471  337122  Nonupholstered Wood Household Furniture Manufa...
# 473  337125  Household Furniture (except Wood and Metal) Ma...
# ..      ...                                                ...
# 135  238910                       Site Preparation Contractors
# 996  811430                  Footwear and Leather Goods Repair
# 529  423910  Sporting and Recreational Goods and Supplies M...
# 504  423320  Brick, Stone, and Related Construction Materia...
# 530  423920  Toy and Hobby Goods and Supplies Merchant Whol...
#
# [100 rows x 2 columns]

# %%
relevant_naics = pd.read_pickle('assets/relevant_naics_df.pkl')

# %%
relevant_naics
# Out:
#                                           query  \
# 0                        Home improvement store
# 1                          Diesel fuel supplier
# 2                                        Church
# 3                                          Farm
# 4                                 Seed supplier
# ...                                         ...
# 1149  State department agricultural development
# 1150                              Military base
# 1151                                    Embassy
# 1152                            Window supplier
# 1153                         Customs department
#
#                                          relevant_naics
# 0     [444110, 444120, 444130, 444190, 444210, 44422...
# 1     [424710, 424720, 424110, 424120, 424130, 42421...
# 2     [813110, 813211, 813212, 813219, 813311, 81331...
# 3     [115116, 115111, 115112, 115113, 115114, 11511...
# 4     [424910, 424920, 424930, 424940, 424950, 42499...
# ...                                                 ...
# 1149  [926140, 926110, 926120, 926130, 926150, 92111...
# 1150  [928110, 928120, 921110, 921120, 921130, 92114...
# 1151  [928120, 928110, 921110, 921120, 921130, 92114...
# 1152  [321911, 321912, 321918, 321920, 321991, 32199...
# 1153  [926120, 926110, 926130, 926140, 926150, 92111...
#
# [1154 rows x 2 columns]

# %%
for row in relevant_naics.iterrows():
    best_index = model.retrieve_docs(row[1]['query'], normalization='lemmatize')
    feedback = []
    for rel_code in row[1]['relevant_naics']:
        try:
            idx = np.where(df['naics'].values == str(rel_code))[0][0]
        except:
            print(idx, rel_code)
        if rel_code in df.iloc[best_index]['naics'].values:
            feedback.append((1, idx))
        else:
            feedback.append((0, idx))
    model.gather_feedback(row[1]['query'], feedback=feedback, max_docs=max_docs, normalization='lemmatize')

# %%
df.iloc[model.retrieve_docs('Home improvement store', normalization='lemmatize')][['naics', 'title']]
# Out:
#       naics                                              title
# 576  442210                             Floor Covering Stores
# 578  442299                 All Other Home Furnishings Stores
# 577  442291                           Window Treatment Stores
# 575  442110                                  Furniture Stores
# 627  453930                Manufactured (Mobile) Home Dealers
# 629  453998  All Other Miscellaneous Store Retailers (excep...
# 628  453991                                    Tobacco Stores
# 624  453310                           Used Merchandise Stores
# 618  452210                                 Department Stores
# 626  453920                                       Art Dealers

# %%
def calc_pre_rec_at_n(ret_docs, reljudges, n=-1):
    """
    Calculate precision and recall at n for each query in ret_docs
    """
    
    pre_at_n, rec_at_n = {}, {}
    
    for k, v in ret_docs.items():
        if n > -1 and n <= len(ret_docs):
            s1 = set(v[:n])
        else:
            s1 = set(v)
        s2 = reljudges[k]
        precision = len(s1.intersection(s2)) / len(s1)
        recall = len(s1.intersection(s2)) / len(reljudges[k])
        pre_at_n[k] = round(precision, 3)
        rec_at_n[k] = round(recall, 3)
    return pre_at_n, rec_at_n

# %%
def calc_avg_pre(ret_docs, reljudges, cutoff=-1):
    """
    Calculate (mean) average precision for each query in ret_docs
    """
    
    avg_pre, mean_avg_pre = {}, None
    for k, v in ret_docs.items():
        total_rel = 0
        total = 0
        avg_prec = 0
        for i, doc in enumerate(v):
            if doc in reljudges[k] and cutoff == -1:
                total_rel += 1
                total += 1
                precision = total_rel/total
            elif doc in reljudges[k] and i+1 <= cutoff:
                total_rel += 1
                total += 1
                precision = total_rel/total
            else:
                total += 1
                precision = 0
            avg_prec += precision

        avg_pre[k] = round(avg_prec/len(reljudges[k]), 3,)
    
    mean_avg_pre = round(sum(avg_pre.values()) / len(avg_pre), 3)
        
    return avg_pre, mean_avg_pre

# %%
import math

def calc_NDCG_at_n(ret_docs, reljudges, n=-1, base=2):
    """
    Calculate NDCG at n for each query in ret_docs
    """
    
    ndcg = {}
    
    for k, v in ret_docs.items():
        
        counts = list(reversed([x for x in range(2,len(reljudges[k])+2)]))
        ideals = {reljudges[k][i]: counts[i] for i in range(len(reljudges[k]))}
        
        add_ons = {}
        if len(v) > len(reljudges[k]):
            for i in range(len(v)-len(reljudges[k])):
                add_ons[i] = 1
        ideals.update(add_ons)
        nums = list(map(ideals.get, v))
        
        systems = {}
        for i, doc in enumerate(v):
            if nums[i] == None:
                systems[doc] = 1
            else:
                systems[doc] = nums[i]
                
        ideal_order = {}
        if n != -1:
            for i, (key, value) in enumerate(ideals.items()):
                if i < n:
                    ideal_order[key] = value
        else:
            ideal_order = ideals
        
        add_ons = {}
        
        
        log = 0
        for i, (doc, rank) in enumerate(ideal_order.items()):
            if i >= len(v):
                break
            elif i < base:
                log += rank
            else:
                log += rank/math.log(i+1, base)

                
        system_order = {}
        if n != -1:
            for i, (key, value) in enumerate(systems.items()):
                if i < n:
                    system_order[key] = value
        else:
            system_order = systems
        
        
        
        system_log = 0
        for i, (doc, rank) in enumerate(system_order.items()):
            if i >= len(v):
                break
            elif i < base:
                system_log += rank
            else:
                system_log += rank/math.log(i+1, base)
        system_log / log
        ndcg[k] = round(system_log / log, 3)
        
    
    return ndcg

# %%
max_docs = 10

# %%
ret_docs_dic = {}
queries_dic = {}

for query in relevant_naics.iterrows():
    query_name =  ' '.join(process_query(query[1]['query'], 'lemmatize'))
    ret_docs_index = model.retrieve_docs(query_name, max_docs=max_docs, normalization='lemmatize')
    ret_docs = df.iloc[ret_docs_index]['naics'].tolist()

    query_docs = query[1]['relevant_naics']
    ret_docs_dic[query_name] = ret_docs
    queries_dic[query_name] = query_docs

# %%
ret_docs_dic
# Out:
# {'home improvement store': ['442210',
#   '442299',
#   '442291',
#   '442110',
#   '453930',
#   '453998',
#   '453991',
#   '453310',
#   '452210',
#   '453920'],
#  'diesel fuel supplier': ['332216',
#   '332993',
#   '332410',
#   '332991',
#   '332992',
#   '332994',
#   '332999',
#   '332613',
#   '332111',
#   '332117'],
#  'church': ['423310',
#   '423520',
#   '423210',
#   '423390',
#   '423510',
#   '423940',
#   '423320',
#   '423990',
#   '423330',
#   '423910'],
#  'farm': ['115210',
#   '115115',
#   '115113',
#   '115114',
#   '115116',
#   '115112',
#   '115111',
#   '115310',
#   '111310',
#   '111320'],
#  'seed supplier': ['332216',
#   '332410',
#   '332999',
#   '332215',
#   '332993',
#   '332991',
#   '332992',
#   '332994',
#   '332111',
#   '332439'],
#  'accountant': ['541191',
#   '541199',
#   '541110',
#   '541120',
#   '541211',
#   '541420',
#   '541350',
#   '541219',
#   '541410',
#   '541213'],
#  'trucking company': ['484122',
#   '484110',
#   '484121',
#   '484220',
#   '484230',
#   '484210',
#   '492210',
#   '493110',
#   '336214',
#   '336212'],
#  'exporter': ['522220',
#   '522120',
#   '522110',
#   '522190',
#   '522310',
#   '522130',
#   '522293',
#   '522294',
#   '522292',
#   '522210'],
#  'grain elevator': ['311224',
#   '311221',
#   '311212',
#   '311225',
#   '311213',
#   '111191',
#   '311211',
#   '111199',
#   '311230',
#   '316998'],
#  'popcorn store': ['445299',
#   '445291',
#   '445292',
#   '445110',
#   '445230',
#   '445120',
#   '445220',
#   '445310',
#   '445210',
#   '453991'],
#  'agricultural service': ['525990',
#   '525920',
#   '525910',
#   '525110',
#   '525190',
#   '521110',
#   '522120',
#   '522293',
#   '522310',
#   '522220'],
#  'warehouse': ['493130',
#   '493190',
#   '493110',
#   '493120',
#   '335911',
#   '486210',
#   '334112',
#   '445310',
#   '445230',
#   '452311'],
#  'agricultural production': ['111310',
#   '111320',
#   '111130',
#   '111140',
#   '111110',
#   '111422',
#   '111211',
#   '111150',
#   '111411',
#   '111160'],
#  'ranch': ['112340',
#   '112330',
#   '112390',
#   '112310',
#   '112511',
#   '112512',
#   '112320',
#   '112210',
#   '112420',
#   '112519'],
#  'holding company': ['551114',
#   '551112',
#   '551111',
#   '561622',
#   '561621',
#   '561110',
#   '561612',
#   '561613',
#   '561710',
#   '561611'],
#  'farm equipment supplier': ['332216',
#   '332410',
#   '332215',
#   '332999',
#   '332993',
#   '332991',
#   '332992',
#   '332994',
#   '332439',
#   '332111'],
#  'store': ['453930',
#   '453998',
#   '453991',
#   '453910',
#   '453920',
#   '453310',
#   '453210',
#   '453110',
#   '453220',
#   '452319'],
#  'grocery store': ['445299',
#   '445291',
#   '445292',
#   '445110',
#   '445230',
#   '445220',
#   '445120',
#   '445310',
#   '445210',
#   '452210'],
#  'rice mill': ['311221',
#   '311224',
#   '311225',
#   '311213',
#   '311212',
#   '311230',
#   '311211',
#   '311119',
#   '311111',
#   '316998'],
#  'food product supplier': ['332216',
#   '332993',
#   '332991',
#   '332999',
#   '332992',
#   '332994',
#   '332410',
#   '332215',
#   '332117',
#   '332111'],
#  'accounting firm': ['541110',
#   '541199',
#   '541120',
#   '541420',
#   '541211',
#   '541191',
#   '541350',
#   '541219',
#   '541410',
#   '541213'],
#  'produce market': ['445310',
#   '312130',
#   '312140',
#   '312120',
#   '445220',
#   '445230',
#   '312112',
#   '312111',
#   '312113',
#   '493190'],
#  'pet supply store': ['453930',
#   '453998',
#   '453991',
#   '453910',
#   '453310',
#   '453920',
#   '453210',
#   '453110',
#   '453220',
#   '452319'],
#  'wholesaler': ['423990',
#   '423840',
#   '423720',
#   '423830',
#   '423440',
#   '423740',
#   '423460',
#   '423410',
#   '423710',
#   '423520'],
#  'produce wholesaler': ['423990',
#   '423840',
#   '423720',
#   '423830',
#   '423440',
#   '423520',
#   '423740',
#   '423710',
#   '423320',
#   '423460'],
#  'distribution service': ['541890',
#   '812332',
#   '541870',
#   '812320',
#   '541860',
#   '812331',
#   '541199',
#   '812191',
#   '812210',
#   '812310'],
#  'crop grower': ['111310',
#   '111320',
#   '111130',
#   '111140',
#   '111110',
#   '111211',
#   '111920',
#   '111150',
#   '111940',
#   '111910'],
#  'addiction treatment center': ['621493',
#   '621492',
#   '621491',
#   '621498',
#   '621420',
#   '621410',
#   '621210',
#   '621111',
#   '621330',
#   '621112'],
#  'natural good store': ['486210',
#   '486110',
#   '486990',
#   '486910',
#   '922190',
#   '921120',
#   '921110',
#   '921140',
#   '924120',
#   '922150'],
#  'orchard': ['111310',
#   '111320',
#   '111130',
#   '111140',
#   '111110',
#   '111422',
#   '111211',
#   '111150',
#   '111411',
#   '111160'],
#  'lumber store': ['332216',
#   '332999',
#   '332410',
#   '332215',
#   '332993',
#   '332991',
#   '332994',
#   '332992',
#   '332111',
#   '332117'],
#  'mine': ['212324',
#   '212322',
#   '212321',
#   '212325',
#   '212311',
#   '212312',
#   '212391',
#   '212230',
#   '212313',
#   '212392'],
#  'transportation service': ['488510',
#   '488410',
#   '488490',
#   '488320',
#   '488310',
#   '488390',
#   '488991',
#   '488330',
#   '488210',
#   '488999'],
#  'investment company': ['523110',
#   '523130',
#   '523120',
#   '523140',
#   '523920',
#   '523910',
#   '523991',
#   '523210',
#   '523930',
#   '523999'],
#  'fruit wholesaler': ['423830',
#   '423840',
#   '423810',
#   '423720',
#   '423820',
#   '423520',
#   '423740',
#   '423710',
#   '423320',
#   '423440'],
#  'real estate agency': ['531130',
#   '531120',
#   '531110',
#   '531190',
#   '531210',
#   '531320',
#   '531311',
#   '531312',
#   '531390',
#   '533110'],
#  'event venue': ['332216',
#   '332999',
#   '332993',
#   '332991',
#   '332992',
#   '332994',
#   '332215',
#   '332439',
#   '332410',
#   '332613'],
#  'frozen dessert supplier': ['311520',
#   '311512',
#   '311514',
#   '311513',
#   '311511',
#   '311411',
#   '311412',
#   '311813',
#   '311830',
#   '311710'],
#  'wine wholesaler importer': ['423830',
#   '423840',
#   '423810',
#   '423520',
#   '423720',
#   '423820',
#   '423740',
#   '423930',
#   '423320',
#   '423440'],
#  'winery': ['312112',
#   '312111',
#   '312113',
#   '312130',
#   '312120',
#   '312140',
#   '312230',
#   '448120',
#   '448130',
#   '448110'],
#  'aerospace company': ['336419',
#   '336415',
#   '336414',
#   '336413',
#   '336411',
#   '336412',
#   '336992',
#   '336991',
#   '336120',
#   '336111'],
#  'cold storage facility': ['493130',
#   '493120',
#   '493190',
#   '493110',
#   '335911',
#   '486210',
#   '334112',
#   '445310',
#   '445230',
#   '486110'],
#  'employment agency': ['332216',
#   '332999',
#   '332993',
#   '332991',
#   '332992',
#   '332994',
#   '332215',
#   '423510',
#   '332996',
#   '332613'],
#  'plant nursery': ['922190',
#   '922150',
#   '923110',
#   '922140',
#   '924120',
#   '922130',
#   '922120',
#   '922160',
#   '926140',
#   '923140'],
#  'air conditioning contractor': ['238190',
#   '238390',
#   '238120',
#   '238160',
#   '238170',
#   '238340',
#   '238130',
#   '238140',
#   '238320',
#   '238330'],
#  'air conditioning repair service': ['811198',
#   '811420',
#   '811192',
#   '811490',
#   '811191',
#   '811118',
#   '811430',
#   '811111',
#   '811112',
#   '811113'],
#  'fruit vegetable wholesaler': ['311421',
#   '423210',
#   '311423',
#   '337125',
#   '337110',
#   '337122',
#   '922190',
#   '337124',
#   '337211',
#   '311422'],
#  'aircraft rental service': ['532210',
#   '532284',
#   '532281',
#   '532310',
#   '532282',
#   '532283',
#   '532289',
#   '532120',
#   '532420',
#   '532112'],
#  'monastery': ['813910',
#   '813410',
#   '813990',
#   '813940',
#   '813930',
#   '813110',
#   '813311',
#   '813319',
#   '813312',
#   '813211'],
#  'allergist': ['621340',
#   '621391',
#   '621320',
#   '621310',
#   '621399',
#   '621210',
#   '621111',
#   '621112',
#   '621330',
#   '621991'],
#  'herb shop': ['922190',
#   '921140',
#   '922150',
#   '921120',
#   '922130',
#   '922140',
#   '921110',
#   '922120',
#   '922110',
#   '921130'],
#  'aluminum supplier': ['331222',
#   '331221',
#   '331492',
#   '331491',
#   '331420',
#   '331410',
#   '331315',
#   '331314',
#   '331210',
#   '331318'],
#  'ambulance service': ['445291',
#   '921130',
#   '445299',
#   '445292',
#   '922140',
#   '924110',
#   '924120',
#   '926150',
#   '921120',
#   '921140'],
#  'wholesale plant nursery': ['424450',
#   '424610',
#   '424510',
#   '424410',
#   '424480',
#   '424440',
#   '424940',
#   '424460',
#   '424520',
#   '424910'],
#  'amusement machine supplier': ['713920',
#   '713110',
#   '713910',
#   '713930',
#   '713120',
#   '713950',
#   '713290',
#   '713990',
#   '713940',
#   '713210'],
#  'animal hospital': ['112910',
#   '112930',
#   '112990',
#   '112920',
#   '112320',
#   '112310',
#   '112130',
#   '112340',
#   '112410',
#   '112330'],
#  'farmer market': ['922190',
#   '922150',
#   '922130',
#   '922140',
#   '921130',
#   '921110',
#   '921140',
#   '923110',
#   '922120',
#   '922110'],
#  'vaporizer store': ['453930',
#   '453998',
#   '453991',
#   '453910',
#   '453310',
#   '453920',
#   '453110',
#   '453210',
#   '453220',
#   '452319'],
#  'cigar shop': ['453220',
#   '453110',
#   '453310',
#   '453210',
#   '453910',
#   '453930',
#   '453998',
#   '453991',
#   '453920',
#   '442299'],
#  'tobacco shop': ['453220',
#   '453110',
#   '453310',
#   '453210',
#   '312130',
#   '312113',
#   '312140',
#   '453910',
#   '312111',
#   '312120'],
#  'well drilling contractor': ['332618',
#   '332312',
#   '332313',
#   '332996',
#   '332311',
#   '332321',
#   '332322',
#   '332323',
#   '332991',
#   '332994'],
#  'library': ['512230',
#   '512250',
#   '512240',
#   '512290',
#   '512110',
#   '512120',
#   '512132',
#   '512131',
#   '512191',
#   '512199'],
#  'apartment building': ['332311',
#   '332312',
#   '332321',
#   '332313',
#   '332323',
#   '332322',
#   '332811',
#   '332510',
#   '332813',
#   '332112'],
#  'apartment rental agency': ['532210',
#   '532284',
#   '532281',
#   '532310',
#   '532282',
#   '532283',
#   '532289',
#   '532120',
#   '532420',
#   '532112'],
#  'dairy farm': ['115210',
#   '115115',
#   '115113',
#   '115114',
#   '115112',
#   '115116',
#   '115111',
#   '115310',
#   '111310',
#   '111320'],
#  'architect': ['541350',
#   '541320',
#   '541360',
#   '541310',
#   '541330',
#   '541380',
#   '541340',
#   '541420',
#   '541370',
#   '541410'],
#  'organic farm': ['115210',
#   '115115',
#   '115113',
#   '115114',
#   '115112',
#   '115116',
#   '115111',
#   '115310',
#   '111310',
#   '111320'],
#  'architectural designer': ['541350',
#   '541320',
#   '541360',
#   '541310',
#   '541330',
#   '541380',
#   '541340',
#   '541420',
#   '541370',
#   '541410'],
#  'architecture firm': ['332111',
#   '332216',
#   '332112',
#   '332117',
#   '332215',
#   '332114',
#   '332613',
#   '332313',
#   '332510',
#   '332311'],
#  'livestock producer': ['424490',
#   '424320',
#   '423320',
#   '424470',
#   '424330',
#   '424440',
#   '423390',
#   '424340',
#   '424430',
#   '423520'],
#  'dairy supplier': ['332216',
#   '332999',
#   '332410',
#   '332993',
#   '332991',
#   '332992',
#   '332994',
#   '332215',
#   '332111',
#   '332117'],
#  'biotechnology company': ['541714',
#   '541713',
#   '541715',
#   '541720',
#   '482111',
#   '482112',
#   '925120',
#   '492210',
#   '492110',
#   '448310'],
#  'artist': ['711212',
#   '711211',
#   '711310',
#   '711320',
#   '711219',
#   '711410',
#   '711120',
#   '711110',
#   '711190',
#   '711510'],
#  'egg supplier': ['112930',
#   '112910',
#   '112920',
#   '112990',
#   '112310',
#   '112130',
#   '112340',
#   '112330',
#   '112410',
#   '112112'],
#  'poultry farm': ['453310',
#   '453210',
#   '453930',
#   '453998',
#   '453991',
#   '448190',
#   '448150',
#   '453910',
#   '442110',
#   '448310'],
#  'chicken hatchery': ['112310',
#   '112910',
#   '112920',
#   '112930',
#   '112340',
#   '112330',
#   '112320',
#   '112130',
#   '112410',
#   '112390'],
#  'art organization': ['711212',
#   '711211',
#   '711310',
#   '711320',
#   '711219',
#   '711410',
#   '711120',
#   '711190',
#   '711110',
#   '711510'],
#  'association organization': ['813910',
#   '813990',
#   '813410',
#   '813940',
#   '813930',
#   '813311',
#   '813312',
#   '813319',
#   '813110',
#   '813920'],
#  'food store': ['445291',
#   '445292',
#   '445299',
#   '445110',
#   '445120',
#   '445230',
#   '445220',
#   '445310',
#   '445210',
#   '453991'],
#  'deli': ['448320',
#   '448310',
#   '448190',
#   '448150',
#   '448210',
#   '448110',
#   '448120',
#   '448140',
#   '448130',
#   '453310'],
#  'bank': ['522220',
#   '522120',
#   '522110',
#   '522190',
#   '522310',
#   '522130',
#   '522293',
#   '522294',
#   '522292',
#   '522210'],
#  'fish processing': ['453310',
#   '448190',
#   '453210',
#   '453998',
#   '453930',
#   '448150',
#   '453991',
#   '448310',
#   '453910',
#   '442110'],
#  'fish farm': ['114210',
#   '115210',
#   '114119',
#   '112512',
#   '112511',
#   '115115',
#   '112210',
#   '112340',
#   '112330',
#   '112390'],
#  'seafood wholesaler': ['424430',
#   '424440',
#   '424480',
#   '424450',
#   '424460',
#   '424520',
#   '424590',
#   '424510',
#   '424610',
#   '424410'],
#  'tropical fish store': ['453930',
#   '453998',
#   '453991',
#   '453910',
#   '453920',
#   '453310',
#   '453210',
#   '453110',
#   '453220',
#   '452319'],
#  'non profit organization': ['813910',
#   '813990',
#   '813410',
#   '813940',
#   '813930',
#   '813311',
#   '813312',
#   '813319',
#   '813110',
#   '813920'],
#  'economic development agency': ['926110',
#   '924120',
#   '926140',
#   '923110',
#   '925120',
#   '926150',
#   '925110',
#   '922140',
#   '927110',
#   '922190'],
#  'seafood market': ['445291',
#   '445292',
#   '445299',
#   '445110',
#   '445230',
#   '445220',
#   '445120',
#   '445310',
#   '445210',
#   '311111'],
#  'honey farm': ['115210',
#   '115115',
#   '115113',
#   '115114',
#   '115116',
#   '115112',
#   '115111',
#   '115310',
#   '111310',
#   '111320'],
#  'horse breeder': ['423320',
#   '423520',
#   '424470',
#   '424320',
#   '423390',
#   '424710',
#   '424720',
#   '424490',
#   '424330',
#   '424340'],
#  'asphalt contractor': ['238190',
#   '238120',
#   '238390',
#   '238160',
#   '238170',
#   '238340',
#   '238130',
#   '238140',
#   '238150',
#   '238320'],
#  'livestock dealer': ['332216',
#   '332410',
#   '332439',
#   '332215',
#   '332999',
#   '332993',
#   '332994',
#   '332991',
#   '332992',
#   '332613'],
#  'department store': ['453998',
#   '453930',
#   '453991',
#   '453920',
#   '453310',
#   '453910',
#   '453110',
#   '453210',
#   '453220',
#   '452319'],
#  'mill': ['322299',
#   '322291',
#   '322219',
#   '322121',
#   '322230',
#   '322122',
#   '322211',
#   '322212',
#   '322130',
#   '322110'],
#  'atv dealer': ['441110',
#   '441210',
#   '441222',
#   '441228',
#   '441120',
#   '441320',
#   '441310',
#   '444190',
#   '336112',
#   '444130'],
#  'audio visual consultant': ['334112',
#   '334111',
#   '334614',
#   '334310',
#   '334118',
#   '334413',
#   '334417',
#   '334418',
#   '334613',
#   '334412'],
#  'pallet supplier': ['321114',
#   '321113',
#   '321920',
#   '321912',
#   '321918',
#   '321911',
#   '321992',
#   '321991',
#   '321999',
#   '321213'],
#  'wood supplier': ['321219',
#   '321214',
#   '321213',
#   '321211',
#   '321212',
#   '321999',
#   '332216',
#   '321991',
#   '321992',
#   '321918'],
#  'hardware store': ['921140',
#   '921120',
#   '921110',
#   '923110',
#   '922190',
#   '921150',
#   '921130',
#   '921190',
#   '922130',
#   '922150'],
#  'furniture wholesaler': ['337910',
#   '337920',
#   '337212',
#   '337215',
#   '337214',
#   '337124',
#   '337110',
#   '337211',
#   '337125',
#   '337127'],
#  'auditor': ['541611',
#   '541613',
#   '541614',
#   '541612',
#   '541618',
#   '541690',
#   '541620',
#   '541420',
#   '541410',
#   '541320'],
#  'oil natural gas company': ['211130',
#   '211120',
#   '213111',
#   '213113',
#   '213114',
#   '213115',
#   '213112',
#   '212113',
#   '212230',
#   '212112'],
#  'auto body shop': ['811121',
#   '811122',
#   '811198',
#   '811192',
#   '811191',
#   '811118',
#   '811112',
#   '811111',
#   '811113',
#   '811310'],
#  'boat repair shop': ['111310',
#   '111422',
#   '111320',
#   '111421',
#   '111411',
#   '111910',
#   '111331',
#   '111930',
#   '111332',
#   '111940'],
#  'association': ['813910',
#   '813990',
#   '813410',
#   '813940',
#   '813930',
#   '813311',
#   '813312',
#   '813110',
#   '813319',
#   '813920'],
#  'railing contractor': ['111310',
#   '111130',
#   '111150',
#   '111910',
#   '111110',
#   '111411',
#   '111160',
#   '111140',
#   '111930',
#   '111120'],
#  'publisher': ['511191',
#   '511110',
#   '511199',
#   '511140',
#   '511120',
#   '511130',
#   '511210',
#   '519130',
#   '519120',
#   '519190'],
#  'pond supply store': ['453920',
#   '453998',
#   '453310',
#   '453991',
#   '453930',
#   '453910',
#   '442110',
#   '453110',
#   '453210',
#   '453220'],
#  'agriculture cooperative': ['332215',
#   '332999',
#   '332216',
#   '332111',
#   '332112',
#   '332510',
#   '332991',
#   '332992',
#   '332994',
#   '332993'],
#  'printing equipment supplier': ['336992',
#   '336991',
#   '336999',
#   '336510',
#   '336370',
#   '336360',
#   '336120',
#   '336111',
#   '336112',
#   '336390'],
#  'auto insurance agency': ['524127',
#   '524113',
#   '524126',
#   '524128',
#   '524114',
#   '524130',
#   '524298',
#   '524292',
#   '524291',
#   '524210'],
#  'alternative fuel station': ['447110',
#   '447190',
#   '445120',
#   '441310',
#   '336310',
#   '811121',
#   '445110',
#   '811122',
#   '445291',
#   '445292'],
#  'auto part manufacturer': ['111310',
#   '111910',
#   '111130',
#   '111930',
#   '111411',
#   '111150',
#   '111940',
#   '111920',
#   '111110',
#   '111320'],
#  'foundation': ['813410',
#   '813910',
#   '813990',
#   '813930',
#   '813110',
#   '813940',
#   '813211',
#   '813920',
#   '813311',
#   '813312'],
#  'fertilizer supplier': ['325320',
#   '325314',
#   '325312',
#   '325311',
#   '325920',
#   '325910',
#   '325992',
#   '325510',
#   '325520',
#   '325998'],
#  'farming company': ['111310',
#   '111130',
#   '111140',
#   '111110',
#   '111940',
#   '111150',
#   '111910',
#   '111930',
#   '111320',
#   '111920'],
#  'finance broker': ['525910',
#   '525920',
#   '525110',
#   '523210',
#   '525190',
#   '525120',
#   '525990',
#   '523120',
#   '523130',
#   '521110'],
#  'agricultural cooperative': ['332215',
#   '332216',
#   '332999',
#   '332112',
#   '332111',
#   '332510',
#   '332991',
#   '332992',
#   '332994',
#   '332993'],
#  'fire station': ['332613',
#   '332999',
#   '332991',
#   '332994',
#   '332992',
#   '332618',
#   '332993',
#   '332216',
#   '332215',
#   '332111'],
#  'environmental consultant': ['541613',
#   '541611',
#   '541614',
#   '541612',
#   '541618',
#   '541690',
#   '541620',
#   '541713',
#   '541715',
#   '541720'],
#  'civil engineer': ['238190',
#   '238120',
#   '238390',
#   '238160',
#   '238170',
#   '238910',
#   '238130',
#   '238340',
#   '238350',
#   '238320'],
#  'fire protection service': ['332999',
#   '332215',
#   '332994',
#   '332991',
#   '332992',
#   '332993',
#   '332996',
#   '332613',
#   '332510',
#   '332216'],
#  'gas company': ['211130',
#   '211120',
#   '486110',
#   '551111',
#   '551114',
#   '551112',
#   '213111',
#   '486990',
#   '212230',
#   '212210'],
#  'oilfield': ['924110',
#   '922190',
#   '924120',
#   '922140',
#   '921110',
#   '923110',
#   '921140',
#   '922150',
#   '921120',
#   '926140'],
#  'banquet hall': ['722513',
#   '722514',
#   '722511',
#   '722515',
#   '722410',
#   '722330',
#   '722320',
#   '722310',
#   '445120',
#   '445230'],
#  'mining company': ['212230',
#   '212210',
#   '212222',
#   '212221',
#   '212324',
#   '212311',
#   '212322',
#   '212313',
#   '212312',
#   '212321'],
#  'coalfield': ['924110',
#   '922190',
#   '924120',
#   '922140',
#   '921110',
#   '923110',
#   '921140',
#   '922150',
#   '921120',
#   '926140'],
#  'steel fabricator': ['331513',
#   '331511',
#   '331523',
#   '331529',
#   '331512',
#   '331524',
#   '331110',
#   '331210',
#   '331410',
#   '331222'],
#  'quarry': ['212324',
#   '212322',
#   '212321',
#   '212325',
#   '212311',
#   '212312',
#   '212391',
#   '212313',
#   '212230',
#   '212392'],
#  'gold mining company': ['212230',
#   '212324',
#   '212210',
#   '212222',
#   '212221',
#   '212322',
#   '212311',
#   '212321',
#   '212312',
#   '212313'],
#  'high rise building': ['236210',
#   '236117',
#   '236118',
#   '236220',
#   '238190',
#   '238390',
#   '236116',
#   '238910',
#   '238350',
#   '238130'],
#  'basketball club': ['713920',
#   '713910',
#   '713110',
#   '713930',
#   '713120',
#   '713950',
#   '713290',
#   '713990',
#   '713940',
#   '713210'],
#  'gold dealer': ['332216',
#   '332410',
#   '332439',
#   '332215',
#   '332999',
#   '332993',
#   '332994',
#   '332991',
#   '332992',
#   '332613'],
#  'battery manufacturer': ['335220',
#   '335932',
#   '335991',
#   '335921',
#   '335931',
#   '335911',
#   '335912',
#   '335999',
#   '335314',
#   '335929'],
#  'electric utility company': ['335210',
#   '332216',
#   '335110',
#   '332410',
#   '332215',
#   '335313',
#   '332999',
#   '332439',
#   '335129',
#   '332992'],
#  'environmental program': ['423310',
#   '423520',
#   '423210',
#   '423510',
#   '423390',
#   '423940',
#   '423990',
#   '423320',
#   '423910',
#   '423920'],
#  'office': ['423990',
#   '423510',
#   '423520',
#   '423940',
#   '423210',
#   '423450',
#   '423490',
#   '423440',
#   '423910',
#   '423310'],
#  'stone supplier': ['332216',
#   '332410',
#   '332999',
#   '332215',
#   '332993',
#   '332991',
#   '332992',
#   '332994',
#   '332439',
#   '332111'],
#  'aggregate supplier': ['332216',
#   '332410',
#   '332999',
#   '332215',
#   '332993',
#   '332991',
#   '332992',
#   '332994',
#   '332439',
#   '332111'],
#  'sand gravel supplier': ['924110',
#   '922190',
#   '924120',
#   '922140',
#   '921110',
#   '923110',
#   '921140',
#   '922150',
#   '922110',
#   '926140'],
#  'building material supplier': ['444110',
#   '444130',
#   '444120',
#   '444220',
#   '444190',
#   '444210',
#   '453210',
#   '453930',
#   '453110',
#   '453998'],
#  'beauty supply store': ['446130',
#   '446120',
#   '446199',
#   '446191',
#   '446110',
#   '453991',
#   '453998',
#   '453910',
#   '453310',
#   '453920'],
#  'crushed stone supplier': ['332216',
#   '332410',
#   '332999',
#   '332215',
#   '332993',
#   '332991',
#   '332992',
#   '332994',
#   '332439',
#   '332111'],
#  'rock shop': ['332216',
#   '332999',
#   '332993',
#   '332991',
#   '332994',
#   '332992',
#   '332722',
#   '332410',
#   '332215',
#   '332996'],
#  'road construction company': ['238190',
#   '238390',
#   '238160',
#   '238120',
#   '238170',
#   '238130',
#   '238350',
#   '238910',
#   '238340',
#   '238320'],
#  'marketing consultant': ['541611',
#   '541614',
#   '541618',
#   '541613',
#   '541612',
#   '541690',
#   '541620',
#   '541420',
#   '541513',
#   '541512'],
#  'blood testing service': ['541350',
#   '541320',
#   '541360',
#   '541330',
#   '541310',
#   '541380',
#   '541340',
#   '541370',
#   '541420',
#   '541410'],
#  'contractor': ['238190',
#   '238120',
#   '238390',
#   '238160',
#   '238170',
#   '238340',
#   '238130',
#   '238140',
#   '238320',
#   '238910'],
#  'excavating contractor': ['238190',
#   '238120',
#   '238390',
#   '238160',
#   '238170',
#   '238130',
#   '238340',
#   '238910',
#   '238140',
#   '238320'],
#  'asphalt mixing plant': ['325314',
#   '325312',
#   '325311',
#   '325320',
#   '324110',
#   '324191',
#   '324199',
#   '325110',
#   '324121',
#   '324122'],
#  'ready mix concrete supplier': ['327410',
#   '327910',
#   '327420',
#   '327991',
#   '327310',
#   '327390',
#   '327993',
#   '327999',
#   '327992',
#   '327110'],
#  'sand plant': ['924110',
#   '922190',
#   '924120',
#   '922140',
#   '923110',
#   '921110',
#   '922150',
#   '926140',
#   '921140',
#   '922110'],
#  'bmw dealer': ['441222',
#   '441110',
#   '441210',
#   '441228',
#   '441120',
#   '441320',
#   '444190',
#   '441310',
#   '444130',
#   '444110'],
#  'bookbinder': ['325613',
#   '325611',
#   '325612',
#   '325620',
#   '325180',
#   '325120',
#   '325520',
#   '325920',
#   '325130',
#   '325910'],
#  'garden center': ['444110',
#   '444220',
#   '444130',
#   '444120',
#   '444190',
#   '444210',
#   '453210',
#   '453930',
#   '453110',
#   '453998'],
#  'abrasive supplier': ['327410',
#   '327910',
#   '327420',
#   '327991',
#   '327213',
#   '327993',
#   '327992',
#   '327999',
#   '327215',
#   '327310'],
#  'granite supplier': ['453210',
#   '442110',
#   '453310',
#   '453910',
#   '453920',
#   '453991',
#   '453998',
#   '453930',
#   '445299',
#   '445291'],
#  'drilling contractor': ['332312',
#   '332313',
#   '332618',
#   '332311',
#   '332321',
#   '332996',
#   '332322',
#   '332323',
#   '332812',
#   '332813'],
#  'bpo company': ['561440',
#   '561520',
#   '561110',
#   '561421',
#   '561510',
#   '561410',
#   '561210',
#   '561422',
#   '561740',
#   '561710'],
#  'oil gas exploration service': ['211120',
#   '211130',
#   '212113',
#   '212230',
#   '212112',
#   '212111',
#   '212210',
#   '212222',
#   '212221',
#   '212311'],
#  'building complex': ['332311',
#   '332312',
#   '332321',
#   '332313',
#   '332323',
#   '332322',
#   '332510',
#   '332111',
#   '332112',
#   '332811'],
#  'construction equipment supplier': ['332216',
#   '332410',
#   '332993',
#   '332999',
#   '332991',
#   '332992',
#   '332215',
#   '332994',
#   '333111',
#   '332439'],
#  'mining equipment': ['212324',
#   '212325',
#   '212321',
#   '212322',
#   '212399',
#   '212393',
#   '212391',
#   '212312',
#   '212311',
#   '212313'],
#  'bus ticket agency': ['332999',
#   '332216',
#   '332993',
#   '332991',
#   '332992',
#   '332994',
#   '332215',
#   '332996',
#   '332613',
#   '332439'],
#  'business center': ['423510',
#   '423990',
#   '423520',
#   '423310',
#   '423390',
#   '423940',
#   '423210',
#   '423690',
#   '423450',
#   '423220'],
#  'skyscraper': ['212299',
#   '212210',
#   '212291',
#   '212230',
#   '212325',
#   '212322',
#   '212399',
#   '212324',
#   '212391',
#   '212311'],
#  'software company': ['511199',
#   '511130',
#   '511120',
#   '511191',
#   '511140',
#   '511110',
#   '511210',
#   '519130',
#   '519120',
#   '519190'],
#  'business development service': ['541714',
#   '541713',
#   '541715',
#   '541720',
#   '925120',
#   '541910',
#   '926110',
#   '927110',
#   '541620',
#   '541613'],
#  'business management consultant': ['424490',
#   '423510',
#   '423520',
#   '424430',
#   '423310',
#   '423940',
#   '423450',
#   '423220',
#   '423210',
#   '423910'],
#  'cabinet maker': ['337127',
#   '337122',
#   '337121',
#   '337124',
#   '337125',
#   '337214',
#   '337211',
#   '337110',
#   '337215',
#   '337212'],
#  'call center': ['332216',
#   '332999',
#   '332993',
#   '332992',
#   '332991',
#   '332994',
#   '332215',
#   '423510',
#   '332439',
#   '332613'],
#  'cancer treatment center': ['621493',
#   '621492',
#   '621491',
#   '621498',
#   '621420',
#   '621410',
#   '621210',
#   '621111',
#   '621330',
#   '621112'],
#  'power plant consultant': ['926130',
#   '924110',
#   '922140',
#   '924120',
#   '212299',
#   '921120',
#   '922190',
#   '926120',
#   '921140',
#   '921110'],
#  'business park': ['423310',
#   '423520',
#   '423510',
#   '423390',
#   '423210',
#   '423940',
#   '423990',
#   '423910',
#   '423320',
#   '423920'],
#  'petroleum product company': ['332216',
#   '332993',
#   '332991',
#   '332992',
#   '332994',
#   '332999',
#   '332410',
#   '332111',
#   '332117',
#   '332215'],
#  'parking lot': ['812310',
#   '812332',
#   '812320',
#   '812331',
#   '812220',
#   '812922',
#   '812921',
#   '812210',
#   '812930',
#   '812111'],
#  'water utility company': ['221210',
#   '221320',
#   '221310',
#   '221330',
#   '221122',
#   '221121',
#   '221111',
#   '221116',
#   '221114',
#   '221117'],
#  'car repair maintenance': ['811113',
#   '811111',
#   '811112',
#   '811490',
#   '811420',
#   '811118',
#   '811191',
#   '811192',
#   '811198',
#   '811310'],
#  'water treatment plant': ['221320',
#   '221210',
#   '221310',
#   '221330',
#   '221122',
#   '221121',
#   '221111',
#   '221116',
#   '221114',
#   '221117'],
#  'car service': ['812310',
#   '812332',
#   '812320',
#   '812331',
#   '812112',
#   '812111',
#   '812220',
#   '812922',
#   '812921',
#   '812210'],
#  'cattle market': ['332216',
#   '332410',
#   '332999',
#   '332991',
#   '332993',
#   '332215',
#   '332992',
#   '332994',
#   '332111',
#   '332439'],
#  'sewage disposal service': ['221320',
#   '221210',
#   '221330',
#   '221310',
#   '221122',
#   '221121',
#   '221111',
#   '221116',
#   '221114',
#   '221117'],
#  'certified public accountant': ['332111',
#   '332216',
#   '332112',
#   '332117',
#   '332613',
#   '332215',
#   '332114',
#   '332510',
#   '332993',
#   '332313'],
#  'government office': ['922190',
#   '921110',
#   '922150',
#   '926140',
#   '922140',
#   '921140',
#   '926150',
#   '922110',
#   '921120',
#   '922120'],
#  'charity': ['813410',
#   '813910',
#   '813990',
#   '813930',
#   '813110',
#   '813940',
#   '813211',
#   '813920',
#   '813311',
#   '813312'],
#  'air conditioning system supplier': ['332216',
#   '332410',
#   '333415',
#   '332999',
#   '332993',
#   '332991',
#   '332992',
#   '332994',
#   '332215',
#   '332439'],
#  'chemical industry': ['325194',
#   '325193',
#   '325180',
#   '325130',
#   '325120',
#   '325520',
#   '325199',
#   '325920',
#   '325910',
#   '325510'],
#  'chemical manufacturer': ['325194',
#   '325193',
#   '325180',
#   '325130',
#   '325120',
#   '325199',
#   '325520',
#   '325920',
#   '325910',
#   '325510'],
#  'title company': ['423510',
#   '423520',
#   '423940',
#   '423990',
#   '423310',
#   '423320',
#   '423390',
#   '423910',
#   '423920',
#   '424590'],
#  'chemical plant': ['325194',
#   '325193',
#   '325180',
#   '325130',
#   '325120',
#   '325199',
#   '325520',
#   '325920',
#   '325910',
#   '325510'],
#  'property management company': ['551114',
#   '551111',
#   '551112',
#   '561110',
#   '561410',
#   '561440',
#   '561450',
#   '561330',
#   '561510',
#   '561520'],
#  'custom home builder': ['238190',
#   '238390',
#   '238350',
#   '238120',
#   '238170',
#   '238160',
#   '238130',
#   '238340',
#   '238910',
#   '238330'],
#  'window installation service': ['212299',
#   '212325',
#   '212291',
#   '212210',
#   '212322',
#   '212399',
#   '212324',
#   '212230',
#   '212391',
#   '212392'],
#  'fire damage restoration service': ['332216',
#   '332999',
#   '332993',
#   '332992',
#   '332991',
#   '332994',
#   '332215',
#   '332439',
#   '332613',
#   '332996'],
#  'equipment rental agency': ['532210',
#   '532310',
#   '532284',
#   '532281',
#   '532282',
#   '532283',
#   '532289',
#   '532420',
#   '532120',
#   '532112'],
#  'chemical wholesaler': ['325180',
#   '325520',
#   '325510',
#   '325194',
#   '325193',
#   '325120',
#   '325920',
#   '325130',
#   '325199',
#   '325910'],
#  'financial planner': ['525910',
#   '523210',
#   '523120',
#   '523130',
#   '525920',
#   '523140',
#   '523920',
#   '525110',
#   '523110',
#   '525990'],
#  'telecommunication service provider': ['517919',
#   '517911',
#   '517312',
#   '517311',
#   '517410',
#   '515111',
#   '515112',
#   '515120',
#   '515210',
#   '518210'],
#  'energy equipment solution': ['922190',
#   '922150',
#   '922140',
#   '922130',
#   '923110',
#   '922110',
#   '926130',
#   '922120',
#   '921110',
#   '921140'],
#  'chiropractor': ['621340',
#   '621391',
#   '621320',
#   '621310',
#   '621399',
#   '621111',
#   '621210',
#   '621112',
#   '621330',
#   '621991'],
#  'steel distributor': ['332216',
#   '332999',
#   '332993',
#   '332991',
#   '332992',
#   '332994',
#   '332215',
#   '332410',
#   '332111',
#   '332613'],
#  'city government office': ['922190',
#   '921110',
#   '922150',
#   '926140',
#   '922140',
#   '926150',
#   '921140',
#   '922110',
#   '922120',
#   '921120'],
#  'crane service': ['111910',
#   '111310',
#   '111130',
#   '111150',
#   '111930',
#   '111411',
#   '111940',
#   '111920',
#   '111110',
#   '111160'],
#  'garage door supplier': ['212299',
#   '212210',
#   '212291',
#   '212325',
#   '212322',
#   '212230',
#   '212324',
#   '212399',
#   '212391',
#   '212311'],
#  'industrial door supplier': ['333515',
#   '333514',
#   '333519',
#   '333517',
#   '333511',
#   '333243',
#   '333241',
#   '333314',
#   '333244',
#   '611610'],
#  'city town hall': ['332215',
#   '332999',
#   '332216',
#   '332112',
#   '332111',
#   '332991',
#   '332992',
#   '332994',
#   '332510',
#   '332993'],
#  'clothing wholesaler': ['448120',
#   '448130',
#   '448110',
#   '448140',
#   '448210',
#   '448150',
#   '448190',
#   '448310',
#   '448320',
#   '332216'],
#  'coin operated laundry equipment supplier': ['812310',
#   '812332',
#   '812320',
#   '812331',
#   '812220',
#   '812922',
#   '812921',
#   '812210',
#   '812930',
#   '812111'],
#  'metal supplier': ['332216',
#   '332215',
#   '332410',
#   '332111',
#   '332439',
#   '332112',
#   '332117',
#   '332999',
#   '332510',
#   '332114'],
#  'glass shop': ['327215',
#   '327212',
#   '327211',
#   '327213',
#   '327992',
#   '327993',
#   '327991',
#   '327410',
#   '327120',
#   '327110'],
#  'college': ['611620',
#   '611610',
#   '611699',
#   '611630',
#   '611410',
#   '611692',
#   '611210',
#   '611512',
#   '611511',
#   '611310'],
#  'siding contractor': ['238190',
#   '238120',
#   '238390',
#   '238160',
#   '238170',
#   '238340',
#   '238130',
#   '238140',
#   '238320',
#   '238910'],
#  'commercial printer': ['453210',
#   '442110',
#   '453910',
#   '453991',
#   '453920',
#   '453998',
#   '453310',
#   '445299',
#   '445291',
#   '453930'],
#  'storage facility': ['493130',
#   '493120',
#   '493190',
#   '493110',
#   '335911',
#   '486210',
#   '334112',
#   '445310',
#   '486110',
#   '445230'],
#  'communication tower': ['212299',
#   '212210',
#   '212291',
#   '212325',
#   '212322',
#   '212324',
#   '212399',
#   '212230',
#   '212391',
#   '212392'],
#  'janitorial service': ['332999',
#   '332216',
#   '332993',
#   '332992',
#   '332991',
#   '332994',
#   '332215',
#   '332439',
#   '332996',
#   '332613'],
#  'computer consultant': ['332216',
#   '332111',
#   '332112',
#   '332117',
#   '332215',
#   '332114',
#   '332510',
#   '332313',
#   '332119',
#   '332311'],
#  'fire protection system supplier': ['332999',
#   '332215',
#   '332216',
#   '332991',
#   '332993',
#   '332992',
#   '332994',
#   '332613',
#   '332996',
#   '332510'],
#  'elevator service': ['111910',
#   '111310',
#   '111130',
#   '111150',
#   '111930',
#   '111940',
#   '111411',
#   '111110',
#   '111920',
#   '111160'],
#  'industrial equipment supplier': ['332216',
#   '332999',
#   '332993',
#   '332410',
#   '332991',
#   '332992',
#   '332994',
#   '332215',
#   '332613',
#   '332439'],
#  'dry wall contractor': ['238190',
#   '238120',
#   '238390',
#   '238160',
#   '238170',
#   '238340',
#   '238130',
#   '238140',
#   '238150',
#   '238320'],
#  'insulation contractor': ['238190',
#   '238120',
#   '238390',
#   '238160',
#   '238170',
#   '238340',
#   '238130',
#   '238140',
#   '238150',
#   '238320'],
#  'concrete contractor': ['238190',
#   '238120',
#   '238390',
#   '238160',
#   '238170',
#   '238340',
#   '238130',
#   '238140',
#   '238150',
#   '238320'],
#  'scaffolding rental service': ['532210',
#   '532284',
#   '532281',
#   '532310',
#   '532282',
#   '532283',
#   '532289',
#   '532120',
#   '532420',
#   '532112'],
#  'construction company': ['238190',
#   '238390',
#   '238120',
#   '238160',
#   '238170',
#   '238130',
#   '238910',
#   '238340',
#   '238350',
#   '238140'],
#  'flooring store': ['445299',
#   '445291',
#   '445292',
#   '445110',
#   '445120',
#   '445230',
#   '443142',
#   '445220',
#   '445210',
#   '443141'],
#  'flooring contractor': ['238190',
#   '238120',
#   '238390',
#   '238160',
#   '238170',
#   '238130',
#   '238340',
#   '238140',
#   '238320',
#   '238910'],
#  'tile contractor': ['238190',
#   '238120',
#   '238390',
#   '238160',
#   '238170',
#   '238340',
#   '238130',
#   '238140',
#   '238320',
#   '238150'],
#  'tile manufacturer': ['212299',
#   '212325',
#   '212291',
#   '212210',
#   '212399',
#   '212322',
#   '212324',
#   '212391',
#   '212230',
#   '212392'],
#  'glass mirror shop': ['212325',
#   '212399',
#   '212322',
#   '212324',
#   '327215',
#   '212391',
#   '212392',
#   '327212',
#   '212321',
#   '212393'],
#  'construction material wholesaler': ['423840',
#   '423320',
#   '423830',
#   '423720',
#   '423990',
#   '423330',
#   '423520',
#   '423390',
#   '423810',
#   '423740'],
#  'gutter cleaning service': ['332216',
#   '332999',
#   '332993',
#   '332992',
#   '332991',
#   '332994',
#   '332215',
#   '332439',
#   '332996',
#   '332410'],
#  'sheet metal contractor': ['332313',
#   '332312',
#   '332811',
#   '332323',
#   '332322',
#   '332813',
#   '332311',
#   '332321',
#   '332812',
#   '332119'],
#  'consultant': ['541611',
#   '541613',
#   '541614',
#   '541612',
#   '541618',
#   '541690',
#   '541620',
#   '541513',
#   '541512',
#   '541420'],
#  'container service': ['111910',
#   '111310',
#   '212324',
#   '212325',
#   '111930',
#   '111940',
#   '111130',
#   '111920',
#   '111150',
#   '111411'],
#  'septic system service': ['332999',
#   '332216',
#   '332993',
#   '332992',
#   '332994',
#   '332991',
#   '332439',
#   '332410',
#   '332215',
#   '332996'],
#  'corporate campus': ['551114',
#   '551112',
#   '551111',
#   '561622',
#   '561621',
#   '561110',
#   '561612',
#   '561613',
#   '561710',
#   '561611'],
#  'water damage restoration service': ['332999',
#   '332216',
#   '332993',
#   '332992',
#   '332991',
#   '332994',
#   '332215',
#   '332996',
#   '332439',
#   '332613'],
#  'welder': ['111310',
#   '111910',
#   '111130',
#   '111150',
#   '111411',
#   '111110',
#   '111930',
#   '111160',
#   '111422',
#   '111940'],
#  'corporate office': ['551114',
#   '551112',
#   '551111',
#   '561622',
#   '561621',
#   '561110',
#   '561612',
#   '561613',
#   '561710',
#   '561611'],
#  'animal': ['112930',
#   '112910',
#   '112920',
#   '112990',
#   '112310',
#   '112130',
#   '112112',
#   '112340',
#   '112330',
#   '112410'],
#  'animal feed store': ['112990',
#   '112930',
#   '112910',
#   '112920',
#   '112112',
#   '112111',
#   '112130',
#   '112310',
#   '112410',
#   '112340'],
#  'animal protection organization': ['112910',
#   '112930',
#   '112920',
#   '112990',
#   '112310',
#   '112340',
#   '112330',
#   '112320',
#   '112130',
#   '112410'],
#  'brewing supply store': ['332216',
#   '332999',
#   '332410',
#   '332991',
#   '332993',
#   '332994',
#   '332215',
#   '332992',
#   '332111',
#   '332613'],
#  'cosmetic store': ['446130',
#   '446120',
#   '446191',
#   '446199',
#   '446110',
#   '453991',
#   '453998',
#   '453910',
#   '453920',
#   '453310'],
#  'county government office': ['922190',
#   '921110',
#   '922150',
#   '926140',
#   '922140',
#   '926150',
#   '921140',
#   '922110',
#   '922120',
#   '921120'],
#  'sugar factory': ['311340',
#   '311314',
#   '311313',
#   '311352',
#   '311351',
#   '311930',
#   '311999',
#   '311920',
#   '311911',
#   '311991'],
#  'confectionery wholesaler': ['424590',
#   '424520',
#   '424690',
#   '424610',
#   '424510',
#   '424430',
#   '424450',
#   '424340',
#   '424310',
#   '424480'],
#  'financial institution': ['332215',
#   '332216',
#   '332613',
#   '332999',
#   '332313',
#   '332311',
#   '332992',
#   '332991',
#   '332510',
#   '332994'],
#  'candy store': ['445299',
#   '445291',
#   '445292',
#   '445110',
#   '445230',
#   '445120',
#   '445220',
#   '445210',
#   '445310',
#   '453991'],
#  'confectionery': ['922190',
#   '922150',
#   '311351',
#   '922130',
#   '923110',
#   '922140',
#   '921110',
#   '922110',
#   '921130',
#   '923140'],
#  'chocolate factory': ['311313',
#   '311314',
#   '311351',
#   '311352',
#   '311340',
#   '311999',
#   '311930',
#   '311920',
#   '311991',
#   '311911'],
#  'chocolate shop': ['311351',
#   '311352',
#   '311313',
#   '311314',
#   '311340',
#   '311999',
#   '311930',
#   '311991',
#   '311920',
#   '311423'],
#  'courier service': ['492210',
#   '492110',
#   '491110',
#   '561439',
#   '561431',
#   '454110',
#   '332912',
#   '561499',
#   '332911',
#   '722513'],
#  'coworking space': ['332811',
#   '332112',
#   '332111',
#   '332321',
#   '332813',
#   '332312',
#   '332812',
#   '332510',
#   '332613',
#   '332323'],
#  'frozen food manufacturer': ['311520',
#   '311411',
#   '311412',
#   '311512',
#   '311513',
#   '311514',
#   '311511',
#   '311710',
#   '311111',
#   '311119'],
#  'beverage distributor': ['332216',
#   '332410',
#   '332999',
#   '332215',
#   '332994',
#   '332991',
#   '332993',
#   '332992',
#   '332439',
#   '332111'],
#  'agricultural organization': ['332215',
#   '332613',
#   '332510',
#   '332216',
#   '332999',
#   '332994',
#   '332991',
#   '332992',
#   '332993',
#   '332112'],
#  'dairy store': ['332216',
#   '332999',
#   '332993',
#   '332994',
#   '332991',
#   '332992',
#   '332410',
#   '332215',
#   '332111',
#   '332613'],
#  'dairy': ['112990',
#   '112930',
#   '112120',
#   '112112',
#   '112910',
#   '112111',
#   '112920',
#   '311511',
#   '311514',
#   '311513'],
#  'ice cream shop': ['312112',
#   '312111',
#   '312113',
#   '312130',
#   '312120',
#   '312140',
#   '312230',
#   '448120',
#   '448130',
#   '448110'],
#  'medical laboratory': ['622110',
#   '621511',
#   '622310',
#   '622210',
#   '621512',
#   '621910',
#   '621610',
#   '624310',
#   '624120',
#   '624410'],
#  'demolition contractor': ['238190',
#   '238120',
#   '238390',
#   '238160',
#   '238170',
#   '238340',
#   '238130',
#   '238140',
#   '238320',
#   '238910'],
#  'meat processor': ['311611',
#   '311613',
#   '311615',
#   '311612',
#   '311119',
#   '311111',
#   '311710',
#   '311930',
#   '445210',
#   '311920'],
#  'fmcg manufacturer': ['423510',
#   '423520',
#   '423940',
#   '423990',
#   '423210',
#   '423390',
#   '423310',
#   '423220',
#   '423910',
#   '423920'],
#  'garbage collection service': ['562112',
#   '562111',
#   '562212',
#   '562211',
#   '562119',
#   '562213',
#   '562219',
#   '562998',
#   '562991',
#   '562920'],
#  'wholesale bakery': ['311821',
#   '311830',
#   '311812',
#   '311813',
#   '311811',
#   '311824',
#   '311991',
#   '311520',
#   '311930',
#   '311942'],
#  'dentist': ['621340',
#   '621391',
#   '621320',
#   '621310',
#   '621399',
#   '621210',
#   '621111',
#   '621112',
#   '621330',
#   '621991'],
#  'dessert shop': ['453310',
#   '453210',
#   '453998',
#   '453930',
#   '453220',
#   '453991',
#   '453910',
#   '442110',
#   '453920',
#   '448190'],
#  'cupcake shop': ['453310',
#   '453220',
#   '453998',
#   '442299',
#   '453210',
#   '453930',
#   '442110',
#   '453991',
#   '453910',
#   '448190'],
#  'nut store': ['445299',
#   '445292',
#   '445291',
#   '445110',
#   '445230',
#   '445120',
#   '445220',
#   '445310',
#   '445210',
#   '453991'],
#  'wholesale grocer': ['424610',
#   '424310',
#   '424340',
#   '424690',
#   '424520',
#   '424510',
#   '424590',
#   '424450',
#   '424430',
#   '424480'],
#  'design engineer': ['541519',
#   '541513',
#   '541511',
#   '541512',
#   '541420',
#   '541410',
#   '541350',
#   '541490',
#   '541320',
#   '541310'],
#  'business business service': ['561439',
#   '561431',
#   '561491',
#   '561492',
#   '561499',
#   '561422',
#   '561421',
#   '561210',
#   '561910',
#   '561710'],
#  'condiment supplier': ['311930',
#   '311991',
#   '311920',
#   '311999',
#   '311911',
#   '311919',
#   '311111',
#   '311119',
#   '311942',
#   '311710'],
#  'digital printing service': ['323113',
#   '323117',
#   '323111',
#   '323120',
#   '313310',
#   '561439',
#   '313320',
#   '313210',
#   '313220',
#   '313230'],
#  'culinary school': ['611620',
#   '611610',
#   '611699',
#   '611410',
#   '611630',
#   '611692',
#   '611512',
#   '611511',
#   '611210',
#   '611513'],
#  'importer': ['237120',
#   '238910',
#   '238120',
#   '238190',
#   '238390',
#   '238150',
#   '238990',
#   '238130',
#   '236210',
#   '238140'],
#  'bottled water supplier': ['453310',
#   '453210',
#   '453930',
#   '453998',
#   '453991',
#   '453910',
#   '442110',
#   '453920',
#   '448190',
#   '448150'],
#  'coffee roaster': ['311930',
#   '311991',
#   '311920',
#   '311999',
#   '311911',
#   '311919',
#   '311111',
#   '311119',
#   '311942',
#   '311710'],
#  'packaging supply store': ['332216',
#   '332999',
#   '332215',
#   '332994',
#   '332991',
#   '332992',
#   '332993',
#   '332111',
#   '423990',
#   '332996'],
#  'ice supplier': ['312112',
#   '312111',
#   '312113',
#   '312130',
#   '312120',
#   '312140',
#   '312230',
#   '448120',
#   '448210',
#   '448130'],
#  'brewery': ['312112',
#   '312111',
#   '312113',
#   '312130',
#   '312120',
#   '312140',
#   '312230',
#   '448120',
#   '448130',
#   '448110'],
#  'winemaking company': ['453310',
#   '453210',
#   '551114',
#   '448190',
#   '453998',
#   '442110',
#   '453930',
#   '448150',
#   '551111',
#   '551112'],
#  'distillery': ['312112',
#   '312111',
#   '312113',
#   '312130',
#   '312120',
#   '312140',
#   '312230',
#   '448120',
#   '448130',
#   '448110'],
#  'disability service support organisation': ['921130',
#   '921120',
#   '922140',
#   '921140',
#   '924110',
#   '924120',
#   '926120',
#   '921190',
#   '921150',
#   '922120'],
#  'district government office': ['922190',
#   '926140',
#   '922150',
#   '921110',
#   '922140',
#   '926150',
#   '922110',
#   '922120',
#   '921140',
#   '921120'],
#  'air filter supplier': ['114210',
#   '212321',
#   '212325',
#   '212324',
#   '212322',
#   '212399',
#   '114111',
#   '111310',
#   '111320',
#   '114119'],
#  'tire shop': ['441310',
#   '441320',
#   '441210',
#   '811121',
#   '441120',
#   '441110',
#   '441228',
#   '441222',
#   '336350',
#   '811122'],
#  'fastener supplier': ['339950',
#   '339940',
#   '339920',
#   '339930',
#   '339991',
#   '339994',
#   '339995',
#   '339992',
#   '339993',
#   '339999'],
#  'fabric product manufacturer': ['313320',
#   '313310',
#   '313240',
#   '313230',
#   '313210',
#   '313220',
#   '313110',
#   '315190',
#   '315110',
#   '315240'],
#  'textile': ['313320',
#   '313310',
#   '313110',
#   '313230',
#   '313210',
#   '313240',
#   '313220',
#   '314999',
#   '314994',
#   '314910'],
#  'textile exporter': ['313320',
#   '313310',
#   '313110',
#   '313230',
#   '313210',
#   '313240',
#   '313220',
#   '314999',
#   '314994',
#   '314910'],
#  'textile engineer': ['313320',
#   '313310',
#   '313110',
#   '313230',
#   '313210',
#   '313240',
#   '313220',
#   '314999',
#   '314994',
#   '314910'],
#  'fabric store': ['453998',
#   '453991',
#   '453930',
#   '453910',
#   '453920',
#   '453310',
#   '453210',
#   '453110',
#   '453220',
#   '452319'],
#  'knit shop': ['315110',
#   '315240',
#   '315280',
#   '315220',
#   '315190',
#   '315210',
#   '315990',
#   '313320',
#   '313310',
#   '313240'],
#  'doctor': ['621410',
#   '621111',
#   '621210',
#   '621330',
#   '621112',
#   '621310',
#   '621491',
#   '621320',
#   '621910',
#   '621492'],
#  'lamination service': ['453210',
#   '442110',
#   '453310',
#   '453910',
#   '453991',
#   '453920',
#   '453998',
#   '453930',
#   '451110',
#   '445299'],
#  'plastic resin manufacturer': ['337215',
#   '337212',
#   '337110',
#   '337920',
#   '337211',
#   '337910',
#   '337214',
#   '326191',
#   '326199',
#   '326140'],
#  'carpet manufacturer': ['314910',
#   '314120',
#   '314999',
#   '314110',
#   '314994',
#   '313320',
#   '313310',
#   '313110',
#   '313230',
#   '313210'],
#  'upholstery shop': ['811121',
#   '811122',
#   '811191',
#   '811192',
#   '811198',
#   '811118',
#   '811112',
#   '811111',
#   '811113',
#   '811420'],
#  'business administration service': ['423510',
#   '423940',
#   '423520',
#   '922140',
#   '423310',
#   '924110',
#   '424310',
#   '424320',
#   '424330',
#   '424340'],
#  'furniture store': ['442110',
#   '442299',
#   '442291',
#   '442210',
#   '337127',
#   '337121',
#   '337124',
#   '337122',
#   '337125',
#   '337214'],
#  'dry cleaner': ['423310',
#   '423520',
#   '423210',
#   '423390',
#   '423510',
#   '423940',
#   '423320',
#   '423990',
#   '423330',
#   '423910'],
#  'packaging company': ['561440',
#   '561520',
#   '561421',
#   '561110',
#   '561510',
#   '561410',
#   '561210',
#   '561740',
#   '561422',
#   '561710'],
#  'duty free store': ['453930',
#   '453998',
#   '453991',
#   '453910',
#   '453310',
#   '453920',
#   '453110',
#   '453210',
#   '453220',
#   '452319'],
#  'commerce service': ['337110',
#   '337125',
#   '337122',
#   '337211',
#   '337920',
#   '337212',
#   '337124',
#   '337910',
#   '337214',
#   '337121'],
#  'cable company': ['551114',
#   '551111',
#   '551112',
#   '922190',
#   '926150',
#   '928110',
#   '922150',
#   '928120',
#   '332618',
#   '921110'],
#  'education': ['611620',
#   '611610',
#   '611410',
#   '611699',
#   '611630',
#   '611692',
#   '611512',
#   '611430',
#   '611210',
#   '611511'],
#  'outlet store': ['453930',
#   '453998',
#   '453991',
#   '453910',
#   '453920',
#   '453310',
#   '453210',
#   '453110',
#   '453220',
#   '452319'],
#  'lingerie store': ['445299',
#   '445291',
#   '445292',
#   '446191',
#   '446199',
#   '445120',
#   '445110',
#   '445230',
#   '446120',
#   '446130'],
#  'clothes fabric manufacturer': ['313320',
#   '313310',
#   '313240',
#   '313230',
#   '313210',
#   '313220',
#   '313110',
#   '315190',
#   '315110',
#   '315240'],
#  'education center': ['713940',
#   '713990',
#   '713950',
#   '713930',
#   '713110',
#   '713120',
#   '713920',
#   '713910',
#   '713290',
#   '713210'],
#  'uniform store': ['445299',
#   '445292',
#   '445291',
#   '445230',
#   '445110',
#   '445220',
#   '445120',
#   '445310',
#   '445210',
#   '452210'],
#  'men clothing store': ['448120',
#   '448130',
#   '448110',
#   '448140',
#   '448210',
#   '448150',
#   '448190',
#   '448310',
#   '448320',
#   '453310'],
#  'clothing store': ['448120',
#   '448130',
#   '448110',
#   '448140',
#   '448210',
#   '448150',
#   '448190',
#   '448310',
#   '448320',
#   '453310'],
#  'woman clothing store': ['448120',
#   '448130',
#   '448110',
#   '448140',
#   '448210',
#   '448150',
#   '448190',
#   '448310',
#   '448320',
#   '453310'],
#  'western apparel store': ['315240',
#   '315280',
#   '315220',
#   '315210',
#   '315190',
#   '315990',
#   '315110',
#   '922190',
#   '922150',
#   '922130'],
#  'costume store': ['453998',
#   '453991',
#   '453310',
#   '453930',
#   '453910',
#   '453920',
#   '453210',
#   '453110',
#   '453220',
#   '442299'],
#  'game store': ['453930',
#   '453998',
#   '453991',
#   '453920',
#   '453910',
#   '453310',
#   '453210',
#   '453110',
#   '453220',
#   '451110'],
#  'hat shop': ['441310',
#   '811121',
#   '811122',
#   '441320',
#   '336350',
#   '811198',
#   '336310',
#   '811192',
#   '811191',
#   '336340'],
#  'leather good manufacturer': ['316992',
#   '316998',
#   '316110',
#   '316210',
#   '448320',
#   '448310',
#   '448210',
#   '325613',
#   '448120',
#   '448190'],
#  'educational consultant': ['611620',
#   '611610',
#   '611699',
#   '611630',
#   '611410',
#   '611692',
#   '611210',
#   '611512',
#   '611691',
#   '611511'],
#  'leather exporter': ['316110',
#   '316992',
#   '316998',
#   '316210',
#   '448320',
#   '448310',
#   '811430',
#   '325613',
#   '493130',
#   '493190'],
#  'shoe store': ['445299',
#   '445291',
#   '445292',
#   '453991',
#   '453998',
#   '453910',
#   '453920',
#   '453310',
#   '453930',
#   '443142'],
#  'boutique': ['922190',
#   '922150',
#   '922130',
#   '922140',
#   '921110',
#   '921140',
#   '923110',
#   '922120',
#   '921130',
#   '922160'],
#  'leather wholesaler': ['316992',
#   '316998',
#   '316110',
#   '316210',
#   '448320',
#   '448310',
#   '448210',
#   '448120',
#   '448190',
#   '448130'],
#  'handbag shop': ['316110',
#   '316992',
#   '316998',
#   '316210',
#   '448320',
#   '448310',
#   '811430',
#   '493190',
#   '493110',
#   '493120'],
#  'electronics store': ['443141',
#   '443142',
#   '453310',
#   '453991',
#   '453930',
#   '453998',
#   '453920',
#   '453910',
#   '453210',
#   '453220'],
#  'luggage store': ['448320',
#   '445299',
#   '445291',
#   '445292',
#   '443142',
#   '448310',
#   '453991',
#   '453910',
#   '453998',
#   '453920'],
#  'building material store': ['444110',
#   '444190',
#   '444120',
#   '444130',
#   '444220',
#   '444210',
#   '236220',
#   '236210',
#   '236117',
#   '236116'],
#  'saw mill': ['322299',
#   '322291',
#   '322219',
#   '322121',
#   '322230',
#   '322122',
#   '322211',
#   '322212',
#   '322130',
#   '322110'],
#  'electrical engineer': ['332216',
#   '332111',
#   '332613',
#   '332112',
#   '332215',
#   '332117',
#   '332510',
#   '332311',
#   '332313',
#   '332114'],
#  'deck builder': ['238190',
#   '238390',
#   '238120',
#   '238160',
#   '238170',
#   '238130',
#   '238910',
#   '238340',
#   '238350',
#   '238140'],
#  'concrete product supplier': ['327410',
#   '327910',
#   '327420',
#   '327991',
#   '327310',
#   '327993',
#   '327999',
#   '327390',
#   '327992',
#   '327110'],
#  'plywood supplier': ['321918',
#   '321999',
#   '321920',
#   '321992',
#   '321991',
#   '321911',
#   '321912',
#   '321114',
#   '321214',
#   '321213'],
#  'electrical installation service': ['335929',
#   '335921',
#   '335991',
#   '335220',
#   '335911',
#   '335999',
#   '335932',
#   '335912',
#   '335314',
#   '335931'],
#  'truss manufacturer': ['442110',
#   '453210',
#   '453310',
#   '453910',
#   '453920',
#   '453991',
#   '453998',
#   '453930',
#   '445299',
#   '445291'],
#  'door supplier': ['321911',
#   '321113',
# ...
#  'promotional product supplier': ['332111',
#   '332112',
#   '332117',
#   '332216',
#   '332114',
#   '332613',
#   '332215',
#   '332119',
#   '332313',
#   '332311'],
#  'advertising service': ['541860',
#   '541870',
#   '541850',
#   '541830',
#   '541820',
#   '541810',
#   '541890',
#   '541840',
#   '541420',
#   '541199'],
#  'record storage facility': ['493190',
#   '493130',
#   '493120',
#   '493110',
#   '334112',
#   '335911',
#   '332439',
#   '332811',
#   '332431',
#   '332420'],
#  'fund management company': ['522220',
#   '522120',
#   '522110',
#   '522190',
#   '522310',
#   '522130',
#   '522293',
#   '522294',
#   '522292',
#   '522210'],
#  'recreation center': ['713920',
#   '713910',
#   '713930',
#   '713110',
#   '713120',
#   '713950',
#   '713940',
#   '713990',
#   '713290',
#   '713210'],
#  'bakery': ['311830',
#   '311813',
#   '311821',
#   '311812',
#   '311811',
#   '311824',
#   '311991',
#   '311930',
#   '311111',
#   '311119'],
#  'database management company': ['551114',
#   '551111',
#   '551112',
#   '561510',
#   '561520',
#   '561110',
#   '561440',
#   '561740',
#   '561622',
#   '561920'],
#  'market researcher': ['423510',
#   '424590',
#   '424430',
#   '423520',
#   '423940',
#   '424440',
#   '424450',
#   '424480',
#   '424490',
#   '424420'],
#  'recycling center': ['332216',
#   '332410',
#   '332999',
#   '332993',
#   '332991',
#   '332215',
#   '332992',
#   '332994',
#   '332439',
#   '332613'],
#  'regional government office': ['922190',
#   '926140',
#   '922150',
#   '921110',
#   '926150',
#   '922140',
#   '922110',
#   '922120',
#   '921140',
#   '921120'],
#  'rehabilitation center': ['621410',
#   '621491',
#   '621492',
#   '621210',
#   '621330',
#   '621111',
#   '621493',
#   '621112',
#   '621420',
#   '621910'],
#  'religious institution': ['813910',
#   '813410',
#   '813990',
#   '813930',
#   '813940',
#   '813110',
#   '813311',
#   '813211',
#   '813312',
#   '813319'],
#  'religious organization': ['813910',
#   '813990',
#   '813410',
#   '813940',
#   '813930',
#   '813311',
#   '813312',
#   '813319',
#   '813110',
#   '813920'],
#  'repair service': ['811490',
#   '811420',
#   '811412',
#   '811411',
#   '811310',
#   '811430',
#   '811211',
#   '811213',
#   '811113',
#   '811212'],
#  'emergency veterinarian service': ['332216',
#   '332111',
#   '332112',
#   '332215',
#   '332117',
#   '332613',
#   '332114',
#   '332510',
#   '332313',
#   '423510'],
#  'pet sitter': ['423310',
#   '423520',
#   '423210',
#   '423320',
#   '423510',
#   '423390',
#   '423940',
#   '423330',
#   '423990',
#   '423920'],
#  'research product development': ['541714',
#   '541713',
#   '541715',
#   '541720',
#   '925120',
#   '541910',
#   '541620',
#   '926110',
#   '927110',
#   '541940'],
#  'building society': ['236210',
#   '236220',
#   '236117',
#   '236118',
#   '236116',
#   '237210',
#   '238910',
#   '236115',
#   '238190',
#   '238130'],
#  'valet parking service': ['812310',
#   '812332',
#   '812320',
#   '812331',
#   '812220',
#   '812922',
#   '812921',
#   '812210',
#   '812930',
#   '812111'],
#  'nursing agency': ['623990',
#   '623210',
#   '623110',
#   '623311',
#   '623312',
#   '623220',
#   '624120',
#   '624410',
#   '624110',
#   '624190'],
#  'executive search firm': ['332999',
#   '332216',
#   '332993',
#   '332992',
#   '332991',
#   '332994',
#   '332215',
#   '423510',
#   '332996',
#   '332439'],
#  'recruiter': ['332216',
#   '332999',
#   '332993',
#   '332992',
#   '332991',
#   '332215',
#   '332994',
#   '332439',
#   '423510',
#   '332613'],
#  'temp agency': ['332216',
#   '332999',
#   '332993',
#   '332991',
#   '332992',
#   '332994',
#   '332215',
#   '332613',
#   '332996',
#   '423510'],
#  'health center': ['621410',
#   '621210',
#   '621330',
#   '621111',
#   '621112',
#   '621491',
#   '621310',
#   '621320',
#   '621910',
#   '621492'],
#  'restaurant': ['722513',
#   '722514',
#   '722511',
#   '722515',
#   '722410',
#   '722330',
#   '722320',
#   '722310',
#   '445120',
#   '445230'],
#  'roofing contractor': ['238190',
#   '238120',
#   '238390',
#   '238160',
#   '238170',
#   '238340',
#   '238130',
#   '238140',
#   '238320',
#   '238150'],
#  'sport nutrition store': ['446199',
#   '446130',
#   '446191',
#   '446120',
#   '446110',
#   '453991',
#   '453998',
#   '453910',
#   '443142',
#   '453920'],
#  'credit reporting agency': ['332999',
#   '332993',
#   '332216',
#   '332991',
#   '332992',
#   '332994',
#   '332996',
#   '423510',
#   '332215',
#   '332613'],
#  'automobile storage facility': ['493130',
#   '493120',
#   '493190',
#   '493110',
#   '335911',
#   '486210',
#   '334112',
#   '445310',
#   '445230',
#   '486110'],
#  'debt collection agency': ['562111',
#   '562112',
#   '562212',
#   '562119',
#   '562211',
#   '562213',
#   '562219',
#   '562920',
#   '562910',
#   '562991'],
#  'park': ['721211',
#   '721214',
#   '721120',
#   '721110',
#   '721199',
#   '721310',
#   '721191',
#   '713210',
#   '713920',
#   '713290'],
#  'court reporter': ['332216',
#   '332999',
#   '332993',
#   '332992',
#   '332991',
#   '332994',
#   '332215',
#   '332439',
#   '423510',
#   '332613'],
#  'bus tour agency': ['332999',
#   '332216',
#   '332993',
#   '332991',
#   '332992',
#   '332994',
#   '332215',
#   '332996',
#   '332613',
#   '332439'],
#  'tour operator': ['332216',
#   '332999',
#   '332993',
#   '332992',
#   '332991',
#   '332994',
#   '332215',
#   '332439',
#   '332613',
#   '332996'],
#  'convention information bureau': ['332216',
#   '332999',
#   '332993',
#   '332992',
#   '332991',
#   '332994',
#   '332215',
#   '332439',
#   '332996',
#   '332613'],
#  'balloon ride tour agency': ['487990',
#   '487110',
#   '487210',
#   '482112',
#   '482111',
#   '483211',
#   '483212',
#   '483111',
#   '483112',
#   '336510'],
#  'security guard service': ['561621',
#   '561622',
#   '561612',
#   '561613',
#   '561611',
#   '561110',
#   '561710',
#   '561210',
#   '561510',
#   '561520'],
#  'locksmith': ['561520',
#   '561510',
#   '561421',
#   '561440',
#   '561110',
#   '561410',
#   '561422',
#   '561740',
#   '561210',
#   '561613'],
#  'commercial cleaning service': ['332999',
#   '332216',
#   '332993',
#   '332992',
#   '332994',
#   '332991',
#   '332215',
#   '332439',
#   '332996',
#   '332111'],
#  'blast cleaning service': ['332216',
#   '332999',
#   '332993',
#   '332992',
#   '332991',
#   '332215',
#   '332994',
#   '332439',
#   '332996',
#   '332410'],
#  'conference center': ['332216',
#   '332999',
#   '332993',
#   '332992',
#   '332991',
#   '332994',
#   '332215',
#   '332439',
#   '423510',
#   '332613'],
#  'safety equipment supplier': ['332216',
#   '332410',
#   '332999',
#   '332993',
#   '332991',
#   '332215',
#   '332992',
#   '332994',
#   '332439',
#   '332613'],
#  'garbage dump': ['562111',
#   '562112',
#   '562212',
#   '562119',
#   '562211',
#   '562213',
#   '562219',
#   '562920',
#   '562910',
#   '562991'],
#  'sanitation service': ['332999',
#   '332216',
#   '332993',
#   '332992',
#   '332991',
#   '332994',
#   '332215',
#   '332439',
#   '332996',
#   '332410'],
#  'garbage dump service': ['332216',
#   '332999',
#   '332993',
#   '332992',
#   '332991',
#   '332994',
#   '332215',
#   '332439',
#   '332613',
#   '332996'],
#  'environmental health service': ['332111',
#   '332112',
#   '332216',
#   '332117',
#   '332215',
#   '332613',
#   '332114',
#   '332313',
#   '332119',
#   '332311'],
#  'portable toilet supplier': ['332216',
#   '332999',
#   '332993',
#   '332992',
#   '332991',
#   '332994',
#   '332215',
#   '332996',
#   '332439',
#   '332410'],
#  'public work department': ['452311',
#   '452319',
#   '452210',
#   '238150',
#   '238390',
#   '238190',
#   '238990',
#   '238220',
#   '238130',
#   '238310'],
#  'school district office': ['611620',
#   '611610',
#   '611699',
#   '611410',
#   '611630',
#   '611692',
#   '611512',
#   '611511',
#   '611210',
#   '611513'],
#  'sailmaker': ['453310',
#   '453210',
#   '453930',
#   '453998',
#   '453991',
#   '453910',
#   '453920',
#   '442110',
#   '448190',
#   '448150'],
#  'community college': ['611620',
#   '611610',
#   '611699',
#   '611410',
#   '611630',
#   '611692',
#   '611512',
#   '611210',
#   '611511',
#   '611310'],
#  'salvage yard': ['332216',
#   '332410',
#   '332999',
#   '332993',
#   '332215',
#   '332991',
#   '332992',
#   '332994',
#   '332111',
#   '332439'],
#  'business school': ['611620',
#   '611610',
#   '611699',
#   '611630',
#   '611410',
#   '611692',
#   '611512',
#   '611511',
#   '611210',
#   '611691'],
#  'trade school': ['611620',
#   '611610',
#   '611699',
#   '611630',
#   '611410',
#   '611692',
#   '611512',
#   '611511',
#   '611210',
#   '611691'],
#  'private university': ['611620',
#   '611610',
#   '611699',
#   '611630',
#   '611410',
#   '611692',
#   '611210',
#   '611512',
#   '611511',
#   '611310'],
#  'computer training school': ['611620',
#   '611610',
#   '611410',
#   '611699',
#   '611630',
#   '611692',
#   '611512',
#   '611511',
#   '611420',
#   '611430'],
#  'school supply store': ['332216',
#   '332999',
#   '332994',
#   '332991',
#   '332993',
#   '332410',
#   '332215',
#   '332992',
#   '332111',
#   '332613'],
#  'screen printer': ['323113',
#   '323117',
#   '323111',
#   '323120',
#   '313310',
#   '561439',
#   '313320',
#   '511130',
#   '313210',
#   '511199'],
#  'medium consultant': ['541860',
#   '541870',
#   '541850',
#   '541810',
#   '541830',
#   '541820',
#   '541840',
#   '541890',
#   '541420',
#   '541120'],
#  'beauty school': ['611620',
#   '611610',
#   '611699',
#   '611630',
#   '611410',
#   '611692',
#   '611512',
#   '611511',
#   '611210',
#   '611310'],
#  'flight school': ['611620',
#   '611610',
#   '611699',
#   '611410',
#   '611630',
#   '611692',
#   '611512',
#   '611511',
#   '611210',
#   '611513'],
#  'seaport': ['533110',
#   '532289',
#   '532284',
#   '532281',
#   '531130',
#   '532210',
#   '532283',
#   '332321',
#   '332811',
#   '532282'],
#  'security system supplier': ['332999',
#   '332993',
#   '332992',
#   '332991',
#   '332994',
#   '332216',
#   '332996',
#   '332410',
#   '332613',
#   '332439'],
#  'middle school': ['611620',
#   '611610',
#   '611699',
#   '611410',
#   '611630',
#   '611692',
#   '611512',
#   '611511',
#   '611210',
#   '611513'],
#  'nonprofit': ['423310',
#   '423520',
#   '423510',
#   '423210',
#   '423390',
#   '423940',
#   '423990',
#   '423320',
#   '423330',
#   '423910'],
#  'shooting range': ['321999',
#   '321214',
#   '321918',
#   '321213',
#   '321920',
#   '321992',
#   '321911',
#   '321991',
#   '321219',
#   '321211'],
#  'soccer club': ['713920',
#   '713910',
#   '713110',
#   '713930',
#   '713120',
#   '713950',
#   '713290',
#   '713990',
#   '713940',
#   '713210'],
#  'camp': ['721211',
#   '721214',
#   '721110',
#   '721120',
#   '721310',
#   '721199',
#   '721191',
#   '713920',
#   '713210',
#   '722410'],
#  'diving contractor': ['332216',
#   '332999',
#   '423510',
#   '332993',
#   '423990',
#   '332991',
#   '332992',
#   '332994',
#   '423520',
#   '332215'],
#  'language school': ['611620',
#   '611610',
#   '611699',
#   '611410',
#   '611630',
#   '611692',
#   '611512',
#   '611511',
#   '611210',
#   '611513'],
#  'english language school': ['611620',
#   '611610',
#   '611699',
#   '611410',
#   '611630',
#   '611692',
#   '611512',
#   '611511',
#   '611210',
#   '611513'],
#  'preschool': ['624120',
#   '624110',
#   '624190',
#   '624210',
#   '624310',
#   '624410',
#   '623990',
#   '624230',
#   '623210',
#   '623220'],
#  'self storage facility': ['493190',
#   '493130',
#   '493120',
#   '493110',
#   '334112',
#   '335911',
#   '332439',
#   '332431',
#   '332420',
#   '332811'],
#  'semi conductor supplier': ['336212',
#   '336211',
#   '336213',
#   '336214',
#   '336112',
#   '336111',
#   '336120',
#   '336370',
#   '336360',
#   '336390'],
#  'driving school': ['611620',
#   '611610',
#   '611699',
#   '611410',
#   '611630',
#   '611692',
#   '611512',
#   '611511',
#   '611210',
#   '611513'],
#  'trucking school': ['611620',
#   '611610',
#   '611410',
#   '611420',
#   '611630',
#   '611699',
#   '611430',
#   '611692',
#   '611512',
#   '611511'],
#  'senior citizen center': ['621410',
#   '621491',
#   '621492',
#   '621210',
#   '621330',
#   '621111',
#   '621112',
#   '621493',
#   '621420',
#   '621910'],
#  'service': ['423510',
#   '332999',
#   '332613',
#   '332215',
#   '332994',
#   '332216',
#   '332993',
#   '332992',
#   '332510',
#   '332991'],
#  'childrens hospital': ['622110',
#   '622310',
#   '622210',
#   '621511',
#   '621512',
#   '621910',
#   '621610',
#   '624310',
#   '624120',
#   '624410'],
#  'dental supply store': ['111310',
#   '111411',
#   '111130',
#   '111910',
#   '111110',
#   '111150',
#   '111422',
#   '111160',
#   '111320',
#   '111140'],
#  'shipyard': ['336612',
#   '336611',
#   '113210',
#   '113310',
#   '113110',
#   '111421',
#   '111331',
#   '111332',
#   '111336',
#   '111333'],
#  'orthodox synagogue': ['813910',
#   '813410',
#   '813990',
#   '813940',
#   '813930',
#   '813110',
#   '813311',
#   '813319',
#   '813312',
#   '813211'],
#  'short term apartment rental agency': ['532210',
#   '532284',
#   '532281',
#   '532310',
#   '532282',
#   '532283',
#   '532289',
#   '532120',
#   '532420',
#   '532112'],
#  'nutritionist': ['621340',
#   '621391',
#   '621320',
#   '621310',
#   '621399',
#   '621210',
#   '621111',
#   '621112',
#   '621330',
#   '621991'],
#  'ophthalmologist': ['445291',
#   '445299',
#   '445292',
#   '332215',
#   '332999',
#   '332613',
#   '332994',
#   '332216',
#   '332111',
#   '332993'],
#  'ophthalmology clinic': ['621410',
#   '621491',
#   '621492',
#   '621210',
#   '621330',
#   '621493',
#   '621111',
#   '621420',
#   '621112',
#   '621910'],
#  'social service organization': ['624110',
#   '624120',
#   '624190',
#   '624210',
#   '624310',
#   '624230',
#   '624410',
#   '624221',
#   '622310',
#   '624229'],
#  'social welfare center': ['624110',
#   '624210',
#   '624120',
#   '624190',
#   '624310',
#   '624410',
#   '624230',
#   '624221',
#   '623220',
#   '624229'],
#  'solar energy company': ['221117',
#   '221113',
#   '221115',
#   '221114',
#   '221118',
#   '221116',
#   '221111',
#   '221112',
#   '221122',
#   '221121'],
#  'solar energy equipment supplier': ['221117',
#   '221114',
#   '221113',
#   '221116',
#   '221115',
#   '221118',
#   '221111',
#   '221112',
#   '221122',
#   '221121'],
#  'special education school': ['611620',
#   '611610',
#   '611699',
#   '611410',
#   '611630',
#   '611692',
#   '611512',
#   '611511',
#   '611210',
#   '611513'],
#  'podiatrist': ['621340',
#   '621391',
#   '621320',
#   '621310',
#   '621399',
#   '621111',
#   '621210',
#   '621112',
#   '621330',
#   '621991'],
#  'reproductive health clinic': ['621410',
#   '621491',
#   '621492',
#   '621210',
#   '621330',
#   '621111',
#   '621112',
#   '621493',
#   '621420',
#   '621910'],
#  'sporting good store': ['451110',
#   '451130',
#   '451211',
#   '451140',
#   '451120',
#   '453991',
#   '453310',
#   '453998',
#   '453930',
#   '451212'],
#  'dialysis center': ['621410',
#   '621491',
#   '621492',
#   '621210',
#   '621493',
#   '621330',
#   '621420',
#   '621111',
#   '621112',
#   '621910'],
#  'sport complex': ['711212',
#   '711211',
#   '711310',
#   '711320',
#   '711219',
#   '711410',
#   '711120',
#   '711190',
#   '711110',
#   '711510'],
#  'wellness program': ['237120',
#   '238910',
#   '238120',
#   '238190',
#   '238390',
#   '238150',
#   '238990',
#   '238130',
#   '238340',
#   '238140'],
#  'sportswear store': ['453930',
#   '453998',
#   '453991',
#   '453910',
#   '453310',
#   '453920',
#   '453110',
#   '453210',
#   '453220',
#   '452319'],
#  'private hospital': ['921130',
#   '922140',
#   '921120',
#   '924110',
#   '921140',
#   '924120',
#   '926140',
#   '926150',
#   '926110',
#   '922120'],
#  'radiologist': ['621340',
#   '621391',
#   '621320',
#   '621310',
#   '621399',
#   '621210',
#   '621111',
#   '621112',
#   '621330',
#   '621991'],
#  'medical diagnostic imaging center': ['622110',
#   '622210',
#   '622310',
#   '621512',
#   '621410',
#   '621511',
#   '621420',
#   '621910',
#   '621491',
#   '621210'],
#  'ray lab': ['622110',
#   '622310',
#   '621511',
#   '622210',
#   '621512',
#   '621910',
#   '621610',
#   '624310',
#   '624120',
#   '624410'],
#  'blood bank': ['621511',
#   '621399',
#   '621512',
#   '621391',
#   '621340',
#   '621999',
#   '621991',
#   '621320',
#   '621310',
#   '339114'],
#  'stainless steel plant': ['331523',
#   '331513',
#   '331511',
#   '331529',
#   '331524',
#   '331512',
#   '331110',
#   '331210',
#   '331410',
#   '331222'],
#  'state agency': ['922190',
#   '926140',
#   '922140',
#   '926150',
#   '922150',
#   '922120',
#   '921110',
#   '922110',
#   '923110',
#   '921120'],
#  'heliport': ['533110',
#   '532284',
#   '532289',
#   '532281',
#   '531130',
#   '532210',
#   '532283',
#   '532282',
#   '531110',
#   '332321'],
#  'health care company': ['621320',
#   '621310',
#   '621210',
#   '621330',
#   '621340',
#   '621910',
#   '621991',
#   '621111',
#   '621112',
#   '621391'],
#  'psychiatric hospital': ['622310',
#   '622110',
#   '622210',
#   '623220',
#   '624410',
#   '623210',
#   '621610',
#   '624120',
#   '621512',
#   '621511'],
#  'state government office': ['922190',
#   '922150',
#   '926140',
#   '921110',
#   '922140',
#   '926150',
#   '922110',
#   '922120',
#   '921140',
#   '921120'],
#  'medical institution': ['622110',
#   '621511',
#   '622310',
#   '622210',
#   '621512',
#   '621910',
#   '621610',
#   '624310',
#   '624120',
#   '624410'],
#  'steel construction company': ['238190',
#   '238120',
#   '238390',
#   '238160',
#   '238170',
#   '238130',
#   '238340',
#   '238910',
#   '238350',
#   '238140'],
#  'cleaning service': ['332999',
#   '332216',
#   '332993',
#   '332994',
#   '332992',
#   '332991',
#   '332215',
#   '332996',
#   '332439',
#   '332111'],
#  ...}

# %%
queries_dic
# Out:
# {'home improvement store': ['444110',
#   '444120',
#   '444130',
#   '444190',
#   '444210',
#   '444220',
#   '441110',
#   '441120',
#   '441210',
#   '441222',
#   '441228',
#   '441310',
#   '441320',
#   '442110',
#   '442210',
#   '442291',
#   '442299',
#   '443141',
#   '443142',
#   '445110',
#   '445120',
#   '445210',
#   '445220',
#   '445230',
#   '445291',
#   '445292',
#   '445299',
#   '445310',
#   '446110',
#   '446120',
#   '446130',
#   '446191',
#   '446199',
#   '447110',
#   '447190',
#   '448110',
#   '448120',
#   '448130',
#   '448140',
#   '448150',
#   '448190',
#   '448210',
#   '448310',
#   '448320'],
#  'diesel fuel supplier': ['424710',
#   '424720',
#   '424110',
#   '424120',
#   '424130',
#   '424210',
#   '424310',
#   '424320',
#   '424330',
#   '424340',
#   '424410',
#   '424420',
#   '424430',
#   '424440',
#   '424450',
#   '424460',
#   '424470',
#   '424480',
#   '424490',
#   '424510',
#   '424520',
#   '424590',
#   '424610',
#   '424690',
#   '424810',
#   '424820',
#   '424910',
#   '424920',
#   '424930',
#   '424940',
#   '424950',
#   '424990',
#   '423110',
#   '423120',
#   '423130',
#   '423140',
#   '423210',
#   '423220',
#   '423310',
#   '423320',
#   '423330',
#   '423390',
#   '423410',
#   '423420',
#   '423430',
#   '423440',
#   '423450',
#   '423460',
#   '423490',
#   '423510',
#   '423520',
#   '423610',
#   '423620',
#   '423690',
#   '423710',
#   '423720',
#   '423730',
#   '423740',
#   '423810',
#   '423820',
#   '423830',
#   '423840',
#   '423850',
#   '423860',
#   '423910',
#   '423920',
#   '423930',
#   '423940',
#   '423990',
#   '425110',
#   '425120'],
#  'church': ['813110',
#   '813211',
#   '813212',
#   '813219',
#   '813311',
#   '813312',
#   '813319',
#   '813410',
#   '813910',
#   '813920',
#   '813930',
#   '813940',
#   '813990',
#   '811111',
#   '811112',
#   '811113',
#   '811118',
#   '811121',
#   '811122',
#   '811191',
#   '811192',
#   '811198',
#   '811211',
#   '811212',
#   '811213',
#   '811219',
#   '811310',
#   '811411',
#   '811412',
#   '811420',
#   '811430',
#   '811490',
#   '812111',
#   '812112',
#   '812113',
#   '812191',
#   '812199',
#   '812210',
#   '812220',
#   '812310',
#   '812320',
#   '812331',
#   '812332',
#   '812910',
#   '812921',
#   '812922',
#   '812930',
#   '812990',
#   '814110'],
#  'farm': ['115116',
#   '115111',
#   '115112',
#   '115113',
#   '115114',
#   '115115',
#   '115210',
#   '115310',
#   '111110',
#   '111120',
#   '111130',
#   '111140',
#   '111150',
#   '111160',
#   '111191',
#   '111199',
#   '111211',
#   '111219',
#   '111310',
#   '111320',
#   '111331',
#   '111332',
#   '111333',
#   '111334',
#   '111335',
#   '111336',
#   '111339',
#   '111411',
#   '111419',
#   '111421',
#   '111422',
#   '111910',
#   '111920',
#   '111930',
#   '111940',
#   '111991',
#   '111992',
#   '111998',
#   '112111',
#   '112112',
#   '112120',
#   '112130',
#   '112210',
#   '112310',
#   '112320',
#   '112330',
#   '112340',
#   '112390',
#   '112410',
#   '112420',
#   '112511',
#   '112512',
#   '112519',
#   '112910',
#   '112920',
#   '112930',
#   '112990',
#   '113110',
#   '113210',
#   '113310',
#   '114111',
#   '114112',
#   '114119',
#   '114210'],
#  'seed supplier': ['424910',
#   '424920',
#   '424930',
#   '424940',
#   '424950',
#   '424990',
#   '424110',
#   '424120',
#   '424130',
#   '424210',
#   '424310',
#   '424320',
#   '424330',
#   '424340',
#   '424410',
#   '424420',
#   '424430',
#   '424440',
#   '424450',
#   '424460',
#   '424470',
#   '424480',
#   '424490',
#   '424510',
#   '424520',
#   '424590',
#   '424610',
#   '424690',
#   '424710',
#   '424720',
#   '424810',
#   '424820',
#   '423110',
#   '423120',
#   '423130',
#   '423140',
#   '423210',
#   '423220',
#   '423310',
#   '423320',
#   '423330',
#   '423390',
#   '423410',
#   '423420',
#   '423430',
#   '423440',
#   '423450',
#   '423460',
#   '423490',
#   '423510',
#   '423520',
#   '423610',
#   '423620',
#   '423690',
#   '423710',
#   '423720',
#   '423730',
#   '423740',
#   '423810',
#   '423820',
#   '423830',
#   '423840',
#   '423850',
#   '423860',
#   '423910',
#   '423920',
#   '423930',
#   '423940',
#   '423990',
#   '425110',
#   '425120'],
#  'accountant': ['541219',
#   '541211',
#   '541213',
#   '541214',
#   '541110',
#   '541120',
#   '541191',
#   '541199',
#   '541310',
#   '541320',
#   '541330',
#   '541340',
#   '541350',
#   '541360',
#   '541370',
#   '541380',
#   '541410',
#   '541420',
#   '541430',
#   '541490',
#   '541511',
#   '541512',
#   '541513',
#   '541519',
#   '541611',
#   '541612',
#   '541613',
#   '541614',
#   '541618',
#   '541620',
#   '541690',
#   '541713',
#   '541714',
#   '541715',
#   '541720',
#   '541810',
#   '541820',
#   '541830',
#   '541840',
#   '541850',
#   '541860',
#   '541870',
#   '541890',
#   '541910',
#   '541921',
#   '541922',
#   '541930',
#   '541940',
#   '541990'],
#  'trucking company': ['484110',
#   '484121',
#   '484122',
#   '484210',
#   '484220',
#   '484230',
#   '481111',
#   '481112',
#   '481211',
#   '481212',
#   '481219',
#   '482111',
#   '482112',
#   '483111',
#   '483112',
#   '483113',
#   '483114',
#   '483211',
#   '483212',
#   '485111',
#   '485112',
#   '485113',
#   '485119',
#   '485210',
#   '485310',
#   '485320',
#   '485410',
#   '485510',
#   '485991',
#   '485999',
#   '486110',
#   '486210',
#   '486910',
#   '486990',
#   '487110',
#   '487210',
#   '487990',
#   '488111',
#   '488119',
#   '488190',
#   '488210',
#   '488310',
#   '488320',
#   '488330',
#   '488390',
#   '488410',
#   '488490',
#   '488510',
#   '488991',
#   '488999'],
#  'exporter': ['522293',
#   '522291',
#   '522292',
#   '522294',
#   '522298',
#   '522210',
#   '522220',
#   '522110',
#   '522120',
#   '522130',
#   '522190',
#   '522310',
#   '522320',
#   '522390',
#   '521110',
#   '523110',
#   '523120',
#   '523130',
#   '523140',
#   '523210',
#   '523910',
#   '523920',
#   '523930',
#   '523991',
#   '523999',
#   '524113',
#   '524114',
#   '524126',
#   '524127',
#   '524128',
#   '524130',
#   '524210',
#   '524291',
#   '524292',
#   '524298',
#   '525110',
#   '525120',
#   '525190',
#   '525910',
#   '525920',
#   '525990'],
#  'grain elevator': ['493130',
#   '493110',
#   '493120',
#   '493190',
#   '491110',
#   '492110',
#   '492210'],
#  'popcorn store': ['445299',
#   '445291',
#   '445292',
#   '445210',
#   '445220',
#   '445230',
#   '445110',
#   '445120',
#   '445310',
#   '441110',
#   '441120',
#   '441210',
#   '441222',
#   '441228',
#   '441310',
#   '441320',
#   '442110',
#   '442210',
#   '442291',
#   '442299',
#   '443141',
#   '443142',
#   '444110',
#   '444120',
#   '444130',
#   '444190',
#   '444210',
#   '444220',
#   '446110',
#   '446120',
#   '446130',
#   '446191',
#   '446199',
#   '447110',
#   '447190',
#   '448110',
#   '448120',
#   '448130',
#   '448140',
#   '448150',
#   '448190',
#   '448210',
#   '448310',
#   '448320'],
#  'agricultural service': ['115116',
#   '115111',
#   '115112',
#   '115113',
#   '115114',
#   '115115',
#   '115210',
#   '115310',
#   '111110',
#   '111120',
#   '111130',
#   '111140',
#   '111150',
#   '111160',
#   '111191',
#   '111199',
#   '111211',
#   '111219',
#   '111310',
#   '111320',
#   '111331',
#   '111332',
#   '111333',
#   '111334',
#   '111335',
#   '111336',
#   '111339',
#   '111411',
#   '111419',
#   '111421',
#   '111422',
#   '111910',
#   '111920',
#   '111930',
#   '111940',
#   '111991',
#   '111992',
#   '111998',
#   '112111',
#   '112112',
#   '112120',
#   '112130',
#   '112210',
#   '112310',
#   '112320',
#   '112330',
#   '112340',
#   '112390',
#   '112410',
#   '112420',
#   '112511',
#   '112512',
#   '112519',
#   '112910',
#   '112920',
#   '112930',
#   '112990',
#   '113110',
#   '113210',
#   '113310',
#   '114111',
#   '114112',
#   '114119',
#   '114210'],
#  'warehouse': ['493110',
#   '493120',
#   '493130',
#   '493190',
#   '491110',
#   '492110',
#   '492210'],
#  'agricultural production': ['111998',
#   '111991',
#   '111992',
#   '111910',
#   '111920',
#   '111930',
#   '111940',
#   '111110',
#   '111120',
#   '111130',
#   '111140',
#   '111150',
#   '111160',
#   '111191',
#   '111199',
#   '111211',
#   '111219',
#   '111310',
#   '111320',
#   '111331',
#   '111332',
#   '111333',
#   '111334',
#   '111335',
#   '111336',
#   '111339',
#   '111411',
#   '111419',
#   '111421',
#   '111422',
#   '112111',
#   '112112',
#   '112120',
#   '112130',
#   '112210',
#   '112310',
#   '112320',
#   '112330',
#   '112340',
#   '112390',
#   '112410',
#   '112420',
#   '112511',
#   '112512',
#   '112519',
#   '112910',
#   '112920',
#   '112930',
#   '112990',
#   '113110',
#   '113210',
#   '113310',
#   '114111',
#   '114112',
#   '114119',
#   '114210',
#   '115111',
#   '115112',
#   '115113',
#   '115114',
#   '115115',
#   '115116',
#   '115210',
#   '115310'],
#  'ranch': ['112130',
#   '112111',
#   '112112',
#   '112120',
#   '112210',
#   '112310',
#   '112320',
#   '112330',
#   '112340',
#   '112390',
#   '112410',
#   '112420',
#   '112511',
#   '112512',
#   '112519',
#   '112910',
#   '112920',
#   '112930',
#   '112990',
#   '111110',
#   '111120',
#   '111130',
#   '111140',
#   '111150',
#   '111160',
#   '111191',
#   '111199',
#   '111211',
#   '111219',
#   '111310',
#   '111320',
#   '111331',
#   '111332',
#   '111333',
#   '111334',
#   '111335',
#   '111336',
#   '111339',
#   '111411',
#   '111419',
#   '111421',
#   '111422',
#   '111910',
#   '111920',
#   '111930',
#   '111940',
#   '111991',
#   '111992',
#   '111998',
#   '113110',
#   '113210',
#   '113310',
#   '114111',
#   '114112',
#   '114119',
#   '114210',
#   '115111',
#   '115112',
#   '115113',
#   '115114',
#   '115115',
#   '115116',
#   '115210',
#   '115310'],
#  'holding company': ['551112', '551111', '551114'],
#  'farm equipment supplier': ['423820',
#   '423810',
#   '423830',
#   '423840',
#   '423850',
#   '423860',
#   '423110',
#   '423120',
#   '423130',
#   '423140',
#   '423210',
#   '423220',
#   '423310',
#   '423320',
#   '423330',
#   '423390',
#   '423410',
#   '423420',
#   '423430',
#   '423440',
#   '423450',
#   '423460',
#   '423490',
#   '423510',
#   '423520',
#   '423610',
#   '423620',
#   '423690',
#   '423710',
#   '423720',
#   '423730',
#   '423740',
#   '423910',
#   '423920',
#   '423930',
#   '423940',
#   '423990',
#   '424110',
#   '424120',
#   '424130',
#   '424210',
#   '424310',
#   '424320',
#   '424330',
#   '424340',
#   '424410',
#   '424420',
#   '424430',
#   '424440',
#   '424450',
#   '424460',
#   '424470',
#   '424480',
#   '424490',
#   '424510',
#   '424520',
#   '424590',
#   '424610',
#   '424690',
#   '424710',
#   '424720',
#   '424810',
#   '424820',
#   '424910',
#   '424920',
#   '424930',
#   '424940',
#   '424950',
#   '424990',
#   '425110',
#   '425120'],
#  'store': ['452319',
#   '452311',
#   '452210',
#   '451110',
#   '451120',
#   '451130',
#   '451140',
#   '451211',
#   '451212',
#   '453110',
#   '453210',
#   '453220',
#   '453310',
#   '453910',
#   '453920',
#   '453930',
#   '453991',
#   '453998',
#   '454110',
#   '454210',
#   '454310',
#   '454390'],
#  'grocery store': ['445110',
#   '445120',
#   '445210',
#   '445220',
#   '445230',
#   '445291',
#   '445292',
#   '445299',
#   '445310',
#   '441110',
#   '441120',
#   '441210',
#   '441222',
#   '441228',
#   '441310',
#   '441320',
#   '442110',
#   '442210',
#   '442291',
#   '442299',
#   '443141',
#   '443142',
#   '444110',
#   '444120',
#   '444130',
#   '444190',
#   '444210',
#   '444220',
#   '446110',
#   '446120',
#   '446130',
#   '446191',
#   '446199',
#   '447110',
#   '447190',
#   '448110',
#   '448120',
#   '448130',
#   '448140',
#   '448150',
#   '448190',
#   '448210',
#   '448310',
#   '448320'],
#  'rice mill': ['311212',
#   '311211',
#   '311213',
#   '311221',
#   '311224',
#   '311225',
#   '311230',
#   '311111',
#   '311119',
#   '311313',
#   '311314',
#   '311340',
#   '311351',
#   '311352',
#   '311411',
#   '311412',
#   '311421',
#   '311422',
#   '311423',
#   '311511',
#   '311512',
#   '311513',
#   '311514',
#   '311520',
#   '311611',
#   '311612',
#   '311613',
#   '311615',
#   '311710',
#   '311811',
#   '311812',
#   '311813',
#   '311821',
#   '311824',
#   '311830',
#   '311911',
#   '311919',
#   '311920',
#   '311930',
#   '311941',
#   '311942',
#   '311991',
#   '311999',
#   '312111',
#   '312112',
#   '312113',
#   '312120',
#   '312130',
#   '312140',
#   '312230',
#   '313110',
#   '313210',
#   '313220',
#   '313230',
#   '313240',
#   '313310',
#   '313320',
#   '314110',
#   '314120',
#   '314910',
#   '314994',
#   '314999',
#   '315110',
#   '315190',
#   '315210',
#   '315220',
#   '315240',
#   '315280',
#   '315990',
#   '316110',
#   '316210',
#   '316992',
#   '316998'],
#  'food product supplier': ['424490',
#   '424410',
#   '424420',
#   '424430',
#   '424440',
#   '424450',
#   '424460',
#   '424470',
#   '424480',
#   '424110',
#   '424120',
#   '424130',
#   '424210',
#   '424310',
#   '424320',
#   '424330',
#   '424340',
#   '424510',
#   '424520',
#   '424590',
#   '424610',
#   '424690',
#   '424710',
#   '424720',
#   '424810',
#   '424820',
#   '424910',
#   '424920',
#   '424930',
#   '424940',
#   '424950',
#   '424990',
#   '423110',
#   '423120',
#   '423130',
#   '423140',
#   '423210',
#   '423220',
#   '423310',
#   '423320',
#   '423330',
#   '423390',
#   '423410',
#   '423420',
#   '423430',
#   '423440',
#   '423450',
#   '423460',
#   '423490',
#   '423510',
#   '423520',
#   '423610',
#   '423620',
#   '423690',
#   '423710',
#   '423720',
#   '423730',
#   '423740',
#   '423810',
#   '423820',
#   '423830',
#   '423840',
#   '423850',
#   '423860',
#   '423910',
#   '423920',
#   '423930',
#   '423940',
#   '423990',
#   '425110',
#   '425120'],
#  'accounting firm': ['541219',
#   '541211',
#   '541213',
#   '541214',
#   '541110',
#   '541120',
#   '541191',
#   '541199',
#   '541310',
#   '541320',
#   '541330',
#   '541340',
#   '541350',
#   '541360',
#   '541370',
#   '541380',
#   '541410',
#   '541420',
#   '541430',
#   '541490',
#   '541511',
#   '541512',
#   '541513',
#   '541519',
#   '541611',
#   '541612',
#   '541613',
#   '541614',
#   '541618',
#   '541620',
#   '541690',
#   '541713',
#   '541714',
#   '541715',
#   '541720',
#   '541810',
#   '541820',
#   '541830',
#   '541840',
#   '541850',
#   '541860',
#   '541870',
#   '541890',
#   '541910',
#   '541921',
#   '541922',
#   '541930',
#   '541940',
#   '541990'],
#  'produce market': ['445230',
#   '445210',
#   '445220',
#   '445291',
#   '445292',
#   '445299',
#   '445110',
#   '445120',
#   '445310',
#   '441110',
#   '441120',
#   '441210',
#   '441222',
#   '441228',
#   '441310',
#   '441320',
#   '442110',
#   '442210',
#   '442291',
#   '442299',
#   '443141',
#   '443142',
#   '444110',
#   '444120',
#   '444130',
#   '444190',
#   '444210',
#   '444220',
#   '446110',
#   '446120',
#   '446130',
#   '446191',
#   '446199',
#   '447110',
#   '447190',
#   '448110',
#   '448120',
#   '448130',
#   '448140',
#   '448150',
#   '448190',
#   '448210',
#   '448310',
#   '448320'],
#  'pet supply store': ['453910',
#   '453920',
#   '453930',
#   '453991',
#   '453998',
#   '453110',
#   '453210',
#   '453220',
#   '453310',
#   '451110',
#   '451120',
#   '451130',
#   '451140',
#   '451211',
#   '451212',
#   '452210',
#   '452311',
#   '452319',
#   '454110',
#   '454210',
#   '454310',
#   '454390'],
#  'wholesaler': ['425120',
#   '425110',
#   '423110',
#   '423120',
#   '423130',
#   '423140',
#   '423210',
#   '423220',
#   '423310',
#   '423320',
#   '423330',
#   '423390',
#   '423410',
#   '423420',
#   '423430',
#   '423440',
#   '423450',
#   '423460',
#   '423490',
#   '423510',
#   '423520',
#   '423610',
#   '423620',
#   '423690',
#   '423710',
#   '423720',
#   '423730',
#   '423740',
#   '423810',
#   '423820',
#   '423830',
#   '423840',
#   '423850',
#   '423860',
#   '423910',
#   '423920',
#   '423930',
#   '423940',
#   '423990',
#   '424110',
#   '424120',
#   '424130',
#   '424210',
#   '424310',
#   '424320',
#   '424330',
#   '424340',
#   '424410',
#   '424420',
#   '424430',
#   '424440',
#   '424450',
#   '424460',
#   '424470',
#   '424480',
#   '424490',
#   '424510',
#   '424520',
#   '424590',
#   '424610',
#   '424690',
#   '424710',
#   '424720',
#   '424810',
#   '424820',
#   '424910',
#   '424920',
#   '424930',
#   '424940',
#   '424950',
#   '424990'],
#  'produce wholesaler': ['424480',
#   '424410',
#   '424420',
#   '424430',
#   '424440',
#   '424450',
#   '424460',
#   '424470',
#   '424490',
#   '424110',
#   '424120',
#   '424130',
#   '424210',
#   '424310',
#   '424320',
#   '424330',
#   '424340',
#   '424510',
#   '424520',
#   '424590',
#   '424610',
#   '424690',
#   '424710',
#   '424720',
#   '424810',
#   '424820',
#   '424910',
#   '424920',
#   '424930',
#   '424940',
#   '424950',
#   '424990',
#   '423110',
#   '423120',
#   '423130',
#   '423140',
#   '423210',
#   '423220',
#   '423310',
#   '423320',
#   '423330',
#   '423390',
#   '423410',
#   '423420',
#   '423430',
#   '423440',
#   '423450',
#   '423460',
#   '423490',
#   '423510',
#   '423520',
#   '423610',
#   '423620',
#   '423690',
#   '423710',
#   '423720',
#   '423730',
#   '423740',
#   '423810',
#   '423820',
#   '423830',
#   '423840',
#   '423850',
#   '423860',
#   '423910',
#   '423920',
#   '423930',
#   '423940',
#   '423990',
#   '425110',
#   '425120'],
#  'distribution service': ['541614',
#   '541611',
#   '541612',
#   '541613',
#   '541618',
#   '541620',
#   '541690',
#   '541110',
#   '541120',
#   '541191',
#   '541199',
#   '541211',
#   '541213',
#   '541214',
#   '541219',
#   '541310',
#   '541320',
#   '541330',
#   '541340',
#   '541350',
#   '541360',
#   '541370',
#   '541380',
#   '541410',
#   '541420',
#   '541430',
#   '541490',
#   '541511',
#   '541512',
#   '541513',
#   '541519',
#   '541713',
#   '541714',
#   '541715',
#   '541720',
#   '541810',
#   '541820',
#   '541830',
#   '541840',
#   '541850',
#   '541860',
#   '541870',
#   '541890',
#   '541910',
#   '541921',
#   '541922',
#   '541930',
#   '541940',
#   '541990'],
#  'crop grower': ['111998',
#   '111991',
#   '111992',
#   '111910',
#   '111920',
#   '111930',
#   '111940',
#   '111110',
#   '111120',
#   '111130',
#   '111140',
#   '111150',
#   '111160',
#   '111191',
#   '111199',
#   '111211',
#   '111219',
#   '111310',
#   '111320',
#   '111331',
#   '111332',
#   '111333',
#   '111334',
#   '111335',
#   '111336',
#   '111339',
#   '111411',
#   '111419',
#   '111421',
#   '111422',
#   '112111',
#   '112112',
#   '112120',
#   '112130',
#   '112210',
#   '112310',
#   '112320',
#   '112330',
#   '112340',
#   '112390',
#   '112410',
#   '112420',
#   '112511',
#   '112512',
#   '112519',
#   '112910',
#   '112920',
#   '112930',
#   '112990',
#   '113110',
#   '113210',
#   '113310',
#   '114111',
#   '114112',
#   '114119',
#   '114210',
#   '115111',
#   '115112',
#   '115113',
#   '115114',
#   '115115',
#   '115116',
#   '115210',
#   '115310'],
#  'addiction treatment center': ['623220',
#   '623210',
#   '623110',
#   '623311',
#   '623312',
#   '623990',
#   '621111',
#   '621112',
#   '621210',
#   '621310',
#   '621320',
#   '621330',
#   '621340',
#   '621391',
#   '621399',
#   '621410',
#   '621420',
#   '621491',
#   '621492',
#   '621493',
#   '621498',
#   '621511',
#   '621512',
#   '621610',
#   '621910',
#   '621991',
#   '621999',
#   '622110',
#   '622210',
#   '622310',
#   '624110',
#   '624120',
#   '624190',
#   '624210',
#   '624221',
#   '624229',
#   '624230',
#   '624310',
#   '624410'],
#  'natural good store': ['446191',
#   '446199',
#   '446110',
#   '446120',
#   '446130',
#   '441110',
#   '441120',
#   '441210',
#   '441222',
#   '441228',
#   '441310',
#   '441320',
#   '442110',
#   '442210',
#   '442291',
#   '442299',
#   '443141',
#   '443142',
#   '444110',
#   '444120',
#   '444130',
#   '444190',
#   '444210',
#   '444220',
#   '445110',
#   '445120',
#   '445210',
#   '445220',
#   '445230',
#   '445291',
#   '445292',
#   '445299',
#   '445310',
#   '447110',
#   '447190',
#   '448110',
#   '448120',
#   '448130',
#   '448140',
#   '448150',
#   '448190',
#   '448210',
#   '448310',
#   '448320'],
#  'orchard': ['111331',
#   '111332',
#   '111333',
#   '111334',
#   '111335',
#   '111336',
#   '111339',
#   '111310',
#   '111320',
#   '111110',
#   '111120',
#   '111130',
#   '111140',
#   '111150',
#   '111160',
#   '111191',
#   '111199',
#   '111211',
#   '111219',
#   '111411',
#   '111419',
#   '111421',
#   '111422',
#   '111910',
#   '111920',
#   '111930',
#   '111940',
#   '111991',
#   '111992',
#   '111998',
#   '112111',
#   '112112',
#   '112120',
#   '112130',
#   '112210',
#   '112310',
#   '112320',
#   '112330',
#   '112340',
#   '112390',
#   '112410',
#   '112420',
#   '112511',
#   '112512',
#   '112519',
#   '112910',
#   '112920',
#   '112930',
#   '112990',
#   '113110',
#   '113210',
#   '113310',
#   '114111',
#   '114112',
#   '114119',
#   '114210',
#   '115111',
#   '115112',
#   '115113',
#   '115114',
#   '115115',
#   '115116',
#   '115210',
#   '115310'],
#  'lumber store': ['423310',
#   '423320',
#   '423330',
#   '423390',
#   '423110',
#   '423120',
#   '423130',
#   '423140',
#   '423210',
#   '423220',
#   '423410',
#   '423420',
#   '423430',
#   '423440',
#   '423450',
#   '423460',
#   '423490',
#   '423510',
#   '423520',
#   '423610',
#   '423620',
#   '423690',
#   '423710',
#   '423720',
#   '423730',
#   '423740',
#   '423810',
#   '423820',
#   '423830',
#   '423840',
#   '423850',
#   '423860',
#   '423910',
#   '423920',
#   '423930',
#   '423940',
#   '423990',
#   '424110',
#   '424120',
#   '424130',
#   '424210',
#   '424310',
#   '424320',
#   '424330',
#   '424340',
#   '424410',
#   '424420',
#   '424430',
#   '424440',
#   '424450',
#   '424460',
#   '424470',
#   '424480',
#   '424490',
#   '424510',
#   '424520',
#   '424590',
#   '424610',
#   '424690',
#   '424710',
#   '424720',
#   '424810',
#   '424820',
#   '424910',
#   '424920',
#   '424930',
#   '424940',
#   '424950',
#   '424990',
#   '425110',
#   '425120'],
#  'mine': ['212299',
#   '212291',
#   '212210',
#   '212221',
#   '212222',
#   '212230',
#   '212111',
#   '212112',
#   '212113',
#   '212311',
#   '212312',
#   '212313',
#   '212319',
#   '212321',
#   '212322',
#   '212324',
#   '212325',
#   '212391',
#   '212392',
#   '212393',
#   '212399',
#   '211120',
#   '211130',
#   '213111',
#   '213112',
#   '213113',
#   '213114',
#   '213115'],
#  'transportation service': ['485999',
#   '485991',
#   '485111',
#   '485112',
#   '485113',
#   '485119',
#   '485210',
#   '485310',
#   '485320',
#   '485410',
#   '485510',
#   '481111',
#   '481112',
#   '481211',
#   '481212',
#   '481219',
#   '482111',
#   '482112',
#   '483111',
#   '483112',
#   '483113',
#   '483114',
#   '483211',
#   '483212',
#   '484110',
#   '484121',
#   '484122',
#   '484210',
#   '484220',
#   '484230',
#   '486110',
#   '486210',
#   '486910',
#   '486990',
#   '487110',
#   '487210',
#   '487990',
#   '488111',
#   '488119',
#   '488190',
#   '488210',
#   '488310',
#   '488320',
#   '488330',
#   '488390',
#   '488410',
#   '488490',
#   '488510',
#   '488991',
#   '488999'],
#  'investment company': ['523110',
#   '523120',
#   '523130',
#   '523140',
#   '523210',
#   '523910',
#   '523920',
#   '523930',
#   '523991',
#   '523999',
#   '521110',
#   '522110',
#   '522120',
#   '522130',
#   '522190',
#   '522210',
#   '522220',
#   '522291',
#   '522292',
#   '522293',
#   '522294',
#   '522298',
#   '522310',
#   '522320',
#   '522390',
#   '524113',
#   '524114',
#   '524126',
#   '524127',
#   '524128',
#   '524130',
#   '524210',
#   '524291',
#   '524292',
#   '524298',
#   '525110',
#   '525120',
#   '525190',
#   '525910',
#   '525920',
#   '525990'],
#  'fruit wholesaler': ['424480',
#   '424410',
#   '424420',
#   '424430',
#   '424440',
#   '424450',
#   '424460',
#   '424470',
#   '424490',
#   '424110',
#   '424120',
#   '424130',
#   '424210',
#   '424310',
#   '424320',
#   '424330',
#   '424340',
#   '424510',
#   '424520',
#   '424590',
#   '424610',
#   '424690',
#   '424710',
#   '424720',
#   '424810',
#   '424820',
#   '424910',
#   '424920',
#   '424930',
#   '424940',
#   '424950',
#   '424990',
#   '423110',
#   '423120',
#   '423130',
#   '423140',
#   '423210',
#   '423220',
#   '423310',
#   '423320',
#   '423330',
#   '423390',
#   '423410',
#   '423420',
#   '423430',
#   '423440',
#   '423450',
#   '423460',
#   '423490',
#   '423510',
#   '423520',
#   '423610',
#   '423620',
#   '423690',
#   '423710',
#   '423720',
#   '423730',
#   '423740',
#   '423810',
#   '423820',
#   '423830',
#   '423840',
#   '423850',
#   '423860',
#   '423910',
#   '423920',
#   '423930',
#   '423940',
#   '423990',
#   '425110',
#   '425120'],
#  'real estate agency': ['531210',
#   '531110',
#   '531120',
#   '531130',
#   '531190',
#   '531311',
#   '531312',
#   '531320',
#   '531390',
#   '532111',
#   '532112',
#   '532120',
#   '532210',
#   '532281',
#   '532282',
#   '532283',
#   '532284',
#   '532289',
#   '532310',
#   '532411',
#   '532412',
#   '532420',
#   '532490',
#   '533110'],
#  'event venue': ['561920',
#   '561910',
#   '561990',
#   '561110',
#   '561210',
#   '561311',
#   '561312',
#   '561320',
#   '561330',
#   '561410',
#   '561421',
#   '561422',
#   '561431',
#   '561439',
#   '561440',
#   '561450',
#   '561491',
#   '561492',
#   '561499',
#   '561510',
#   '561520',
#   '561591',
#   '561599',
#   '561611',
#   '561612',
#   '561613',
#   '561621',
#   '561622',
#   '561710',
#   '561720',
#   '561730',
#   '561740',
#   '561790',
#   '562111',
#   '562112',
#   '562119',
#   '562211',
#   '562212',
#   '562213',
#   '562219',
#   '562910',
#   '562920',
#   '562991',
#   '562998'],
#  'frozen dessert supplier': ['311520',
#   '311511',
#   '311512',
#   '311513',
#   '311514',
#   '311111',
#   '311119',
#   '311211',
#   '311212',
#   '311213',
#   '311221',
#   '311224',
#   '311225',
#   '311230',
#   '311313',
#   '311314',
#   '311340',
#   '311351',
#   '311352',
#   '311411',
#   '311412',
#   '311421',
#   '311422',
#   '311423',
#   '311611',
#   '311612',
#   '311613',
#   '311615',
#   '311710',
#   '311811',
#   '311812',
#   '311813',
#   '311821',
#   '311824',
#   '311830',
#   '311911',
#   '311919',
#   '311920',
#   '311930',
#   '311941',
#   '311942',
#   '311991',
#   '311999',
#   '312111',
#   '312112',
#   '312113',
#   '312120',
#   '312130',
#   '312140',
#   '312230',
#   '313110',
#   '313210',
#   '313220',
#   '313230',
#   '313240',
#   '313310',
#   '313320',
#   '314110',
#   '314120',
#   '314910',
#   '314994',
#   '314999',
#   '315110',
#   '315190',
#   '315210',
#   '315220',
#   '315240',
#   '315280',
#   '315990',
#   '316110',
#   '316210',
#   '316992',
#   '316998'],
#  'wine wholesaler importer': ['424820',
#   '424810',
#   '424110',
#   '424120',
#   '424130',
#   '424210',
#   '424310',
#   '424320',
#   '424330',
#   '424340',
#   '424410',
#   '424420',
#   '424430',
#   '424440',
#   '424450',
#   '424460',
#   '424470',
#   '424480',
#   '424490',
#   '424510',
#   '424520',
#   '424590',
#   '424610',
#   '424690',
#   '424710',
#   '424720',
#   '424910',
#   '424920',
#   '424930',
#   '424940',
#   '424950',
#   '424990',
#   '423110',
#   '423120',
#   '423130',
#   '423140',
#   '423210',
#   '423220',
#   '423310',
#   '423320',
#   '423330',
#   '423390',
#   '423410',
#   '423420',
#   '423430',
#   '423440',
#   '423450',
#   '423460',
#   '423490',
#   '423510',
#   '423520',
#   '423610',
#   '423620',
#   '423690',
#   '423710',
#   '423720',
#   '423730',
#   '423740',
#   '423810',
#   '423820',
#   '423830',
#   '423840',
#   '423850',
#   '423860',
#   '423910',
#   '423920',
#   '423930',
#   '423940',
#   '423990',
#   '425110',
#   '425120'],
#  'winery': ['312130',
#   '312111',
#   '312112',
#   '312113',
#   '312120',
#   '312140',
#   '312230',
#   '311111',
#   '311119',
#   '311211',
#   '311212',
#   '311213',
#   '311221',
#   '311224',
#   '311225',
#   '311230',
#   '311313',
#   '311314',
#   '311340',
#   '311351',
#   '311352',
#   '311411',
#   '311412',
#   '311421',
#   '311422',
#   '311423',
#   '311511',
#   '311512',
#   '311513',
#   '311514',
#   '311520',
#   '311611',
#   '311612',
#   '311613',
#   '311615',
#   '311710',
#   '311811',
#   '311812',
#   '311813',
#   '311821',
#   '311824',
#   '311830',
#   '311911',
#   '311919',
#   '311920',
#   '311930',
#   '311941',
#   '311942',
#   '311991',
#   '311999',
#   '313110',
#   '313210',
#   '313220',
#   '313230',
#   '313240',
#   '313310',
#   '313320',
#   '314110',
#   '314120',
#   '314910',
#   '314994',
#   '314999',
#   '315110',
#   '315190',
#   '315210',
#   '315220',
#   '315240',
#   '315280',
#   '315990',
#   '316110',
#   '316210',
#   '316992',
#   '316998'],
#  'aerospace company': ['336411',
#   '336412',
#   '336413',
#   '336414',
#   '336415',
#   '336419',
#   '336111',
#   '336112',
#   '336120',
#   '336211',
#   '336212',
#   '336213',
#   '336214',
#   '336310',
#   '336320',
#   '336330',
#   '336340',
#   '336350',
#   '336360',
#   '336370',
#   '336390',
#   '336510',
#   '336611',
#   '336612',
#   '336991',
#   '336992',
#   '336999',
#   '331110',
#   '331210',
#   '331221',
#   '331222',
#   '331313',
#   '331314',
#   '331315',
#   '331318',
#   '331410',
#   '331420',
#   '331491',
#   '331492',
#   '331511',
#   '331512',
#   '331513',
#   '331523',
#   '331524',
#   '331529',
#   '332111',
#   '332112',
#   '332114',
#   '332117',
#   '332119',
#   '332215',
#   '332216',
#   '332311',
#   '332312',
#   '332313',
#   '332321',
#   '332322',
#   '332323',
#   '332410',
#   '332420',
#   '332431',
#   '332439',
#   '332510',
#   '332613',
#   '332618',
#   '332710',
#   '332721',
#   '332722',
#   '332811',
#   '332812',
#   '332813',
#   '332911',
#   '332912',
#   '332913',
#   '332919',
#   '332991',
#   '332992',
#   '332993',
#   '332994',
#   '332996',
#   '332999',
#   '333111',
#   '333112',
#   '333120',
#   '333131',
#   '333132',
#   '333241',
#   '333242',
#   '333243',
#   '333244',
#   '333249',
#   '333314',
#   '333316',
#   '333318',
#   '333413',
#   '333414',
#   '333415',
#   '333511',
#   '333514',
#   '333515',
#   '333517',
#   '333519',
#   '333611',
#   '333612',
#   '333613',
#   '333618',
#   '333912',
#   '333914',
#   '333921',
#   '333922',
#   '333923',
#   '333924',
#   '333991',
#   '333992',
#   '333993',
#   '333994',
#   '333995',
#   '333996',
#   '333997',
#   '333999',
#   '334111',
#   '334112',
#   '334118',
#   '334210',
#   '334220',
#   '334290',
#   '334310',
#   '334412',
#   '334413',
#   '334416',
#   '334417',
#   '334418',
#   '334419',
#   '334510',
#   '334511',
#   '334512',
#   '334513',
#   '334514',
#   '334515',
#   '334516',
#   '334517',
#   '334519',
#   '334613',
#   '334614',
#   '335110',
#   '335121',
#   '335122',
#   '335129',
#   '335210',
#   '335220',
#   '335311',
#   '335312',
#   '335313',
#   '335314',
#   '335911',
#   '335912',
#   '335921',
#   '335929',
#   '335931',
#   '335932',
#   '335991',
#   '335999',
#   '337110',
#   '337121',
#   '337122',
#   '337124',
#   '337125',
#   '337127',
#   '337211',
#   '337212',
#   '337214',
#   '337215',
#   '337910',
#   '337920',
#   '339112',
#   '339113',
#   '339114',
#   '339115',
#   '339116',
#   '339910',
#   '339920',
#   '339930',
#   '339940',
#   '339950',
#   '339991',
#   '339992',
#   '339993',
#   '339994',
#   '339995',
#   '339999'],
#  'cold storage facility': ['493120',
#   '493110',
#   '493130',
#   '493190',
#   '491110',
#   '492110',
#   '492210'],
#  'employment agency': ['561311',
#   '561312',
#   '561320',
#   '561330',
#   '561110',
#   '561210',
#   '561410',
#   '561421',
#   '561422',
#   '561431',
#   '561439',
#   '561440',
#   '561450',
#   '561491',
#   '561492',
#   '561499',
#   '561510',
#   '561520',
#   '561591',
#   '561599',
#   '561611',
#   '561612',
#   '561613',
#   '561621',
#   '561622',
#   '561710',
#   '561720',
#   '561730',
#   '561740',
#   '561790',
#   '561910',
#   '561920',
#   '561990',
#   '562111',
#   '562112',
#   '562119',
#   '562211',
#   '562212',
#   '562213',
#   '562219',
#   '562910',
#   '562920',
#   '562991',
#   '562998'],
#  'plant nursery': ['444220',
#   '444210',
#   '444110',
#   '444120',
#   '444130',
#   '444190',
#   '441110',
#   '441120',
#   '441210',
#   '441222',
#   '441228',
#   '441310',
#   '441320',
#   '442110',
#   '442210',
#   '442291',
#   '442299',
#   '443141',
#   '443142',
#   '445110',
#   '445120',
#   '445210',
#   '445220',
#   '445230',
#   '445291',
#   '445292',
#   '445299',
#   '445310',
#   '446110',
#   '446120',
#   '446130',
#   '446191',
#   '446199',
#   '447110',
#   '447190',
#   '448110',
#   '448120',
#   '448130',
#   '448140',
#   '448150',
#   '448190',
#   '448210',
#   '448310',
#   '448320'],
#  'air conditioning contractor': ['238220',
#   '238210',
#   '238290',
#   '238110',
#   '238120',
#   '238130',
#   '238140',
#   '238150',
#   '238160',
#   '238170',
#   '238190',
#   '238310',
#   '238320',
#   '238330',
#   '238340',
#   '238350',
#   '238390',
#   '238910',
#   '238990',
#   '236115',
#   '236116',
#   '236117',
#   '236118',
#   '236210',
#   '236220',
#   '237110',
#   '237120',
#   '237130',
#   '237210',
#   '237310',
#   '237990'],
#  'air conditioning repair service': ['238220',
#   '238210',
#   '238290',
#   '238110',
#   '238120',
#   '238130',
#   '238140',
#   '238150',
#   '238160',
#   '238170',
#   '238190',
#   '238310',
#   '238320',
#   '238330',
#   '238340',
#   '238350',
#   '238390',
#   '238910',
#   '238990',
#   '236115',
#   '236116',
#   '236117',
#   '236118',
#   '236210',
#   '236220',
#   '237110',
#   '237120',
#   '237130',
#   '237210',
#   '237310',
#   '237990'],
#  'fruit vegetable wholesaler': ['445230',
#   '445210',
#   '445220',
#   '445291',
#   '445292',
#   '445299',
#   '445110',
#   '445120',
#   '445310',
#   '441110',
#   '441120',
#   '441210',
#   '441222',
#   '441228',
#   '441310',
#   '441320',
#   '442110',
#   '442210',
#   '442291',
#   '442299',
#   '443141',
#   '443142',
#   '444110',
#   '444120',
#   '444130',
#   '444190',
#   '444210',
#   '444220',
#   '446110',
#   '446120',
#   '446130',
#   '446191',
#   '446199',
#   '447110',
#   '447190',
#   '448110',
#   '448120',
#   '448130',
#   '448140',
#   '448150',
#   '448190',
#   '448210',
#   '448310',
#   '448320'],
#  'aircraft rental service': ['532411',
#   '532412',
#   '532420',
#   '532490',
#   '532111',
#   '532112',
#   '532120',
#   '532210',
#   '532281',
#   '532282',
#   '532283',
#   '532284',
#   '532289',
#   '532310',
#   '531110',
#   '531120',
#   '531130',
#   '531190',
#   '531210',
#   '531311',
#   '531312',
#   '531320',
#   '531390',
#   '533110'],
#  'monastery': ['813110',
#   '813211',
#   '813212',
#   '813219',
#   '813311',
#   '813312',
#   '813319',
#   '813410',
#   '813910',
#   '813920',
#   '813930',
#   '813940',
#   '813990',
#   '811111',
#   '811112',
#   '811113',
#   '811118',
#   '811121',
#   '811122',
#   '811191',
#   '811192',
#   '811198',
#   '811211',
#   '811212',
#   '811213',
#   '811219',
#   '811310',
#   '811411',
#   '811412',
#   '811420',
#   '811430',
#   '811490',
#   '812111',
#   '812112',
#   '812113',
#   '812191',
#   '812199',
#   '812210',
#   '812220',
#   '812310',
#   '812320',
#   '812331',
#   '812332',
#   '812910',
#   '812921',
#   '812922',
#   '812930',
#   '812990',
#   '814110'],
#  'allergist': ['621111',
#   '621112',
#   '621210',
#   '621310',
#   '621320',
#   '621330',
#   '621340',
#   '621391',
#   '621399',
#   '621410',
#   '621420',
#   '621491',
#   '621492',
#   '621493',
#   '621498',
#   '621511',
#   '621512',
#   '621610',
#   '621910',
#   '621991',
#   '621999',
#   '622110',
#   '622210',
#   '622310',
#   '623110',
#   '623210',
#   '623220',
#   '623311',
#   '623312',
#   '623990',
#   '624110',
#   '624120',
#   '624190',
#   '624210',
#   '624221',
#   '624229',
#   '624230',
#   '624310',
#   '624410'],
#  'herb shop': ['446191',
#   '446199',
#   '446110',
#   '446120',
#   '446130',
#   '441110',
#   '441120',
#   '441210',
#   '441222',
#   '441228',
#   '441310',
#   '441320',
#   '442110',
#   '442210',
#   '442291',
#   '442299',
#   '443141',
#   '443142',
#   '444110',
#   '444120',
#   '444130',
#   '444190',
#   '444210',
#   '444220',
#   '445110',
#   '445120',
#   '445210',
#   '445220',
#   '445230',
#   '445291',
#   '445292',
#   '445299',
#   '445310',
#   '447110',
#   '447190',
#   '448110',
#   '448120',
#   '448130',
#   '448140',
#   '448150',
#   '448190',
#   '448210',
#   '448310',
#   '448320'],
#  'aluminum supplier': ['331313',
#   '331314',
#   '331315',
#   '331318',
#   '331110',
#   '331210',
#   '331221',
#   '331222',
#   '331410',
#   '331420',
#   '331491',
#   '331492',
#   '331511',
#   '331512',
#   '331513',
#   '331523',
#   '331524',
#   '331529',
#   '332111',
#   '332112',
#   '332114',
#   '332117',
#   '332119',
#   '332215',
#   '332216',
#   '332311',
#   '332312',
#   '332313',
#   '332321',
#   '332322',
#   '332323',
#   '332410',
#   '332420',
#   '332431',
#   '332439',
#   '332510',
#   '332613',
#   '332618',
#   '332710',
#   '332721',
#   '332722',
#   '332811',
#   '332812',
#   '332813',
#   '332911',
#   '332912',
#   '332913',
#   '332919',
#   '332991',
#   '332992',
#   '332993',
#   '332994',
#   '332996',
#   '332999',
#   '333111',
#   '333112',
#   '333120',
#   '333131',
#   '333132',
#   '333241',
#   '333242',
#   '333243',
#   '333244',
#   '333249',
#   '333314',
#   '333316',
#   '333318',
#   '333413',
#   '333414',
#   '333415',
#   '333511',
#   '333514',
#   '333515',
#   '333517',
#   '333519',
#   '333611',
#   '333612',
#   '333613',
#   '333618',
#   '333912',
#   '333914',
#   '333921',
#   '333922',
#   '333923',
#   '333924',
#   '333991',
#   '333992',
#   '333993',
#   '333994',
#   '333995',
#   '333996',
#   '333997',
#   '333999',
#   '334111',
#   '334112',
#   '334118',
#   '334210',
#   '334220',
#   '334290',
#   '334310',
#   '334412',
#   '334413',
#   '334416',
#   '334417',
#   '334418',
#   '334419',
#   '334510',
#   '334511',
#   '334512',
#   '334513',
#   '334514',
#   '334515',
#   '334516',
#   '334517',
#   '334519',
#   '334613',
#   '334614',
#   '335110',
#   '335121',
#   '335122',
#   '335129',
#   '335210',
#   '335220',
#   '335311',
#   '335312',
#   '335313',
#   '335314',
#   '335911',
#   '335912',
#   '335921',
#   '335929',
#   '335931',
#   '335932',
#   '335991',
#   '335999',
#   '336111',
#   '336112',
#   '336120',
#   '336211',
#   '336212',
#   '336213',
#   '336214',
#   '336310',
#   '336320',
#   '336330',
#   '336340',
#   '336350',
#   '336360',
#   '336370',
#   '336390',
#   '336411',
#   '336412',
#   '336413',
#   '336414',
#   '336415',
#   '336419',
#   '336510',
#   '336611',
#   '336612',
#   '336991',
#   '336992',
#   '336999',
#   '337110',
#   '337121',
#   '337122',
#   '337124',
#   '337125',
#   '337127',
#   '337211',
#   '337212',
#   '337214',
#   '337215',
#   '337910',
#   '337920',
#   '339112',
#   '339113',
#   '339114',
#   '339115',
#   '339116',
#   '339910',
#   '339920',
#   '339930',
#   '339940',
#   '339950',
#   '339991',
#   '339992',
#   '339993',
#   '339994',
#   '339995',
#   '339999'],
#  'ambulance service': ['621910',
#   '621991',
#   '621999',
#   '621111',
#   '621112',
#   '621210',
#   '621310',
#   '621320',
#   '621330',
#   '621340',
#   '621391',
#   '621399',
#   '621410',
#   '621420',
#   '621491',
#   '621492',
#   '621493',
#   '621498',
#   '621511',
#   '621512',
#   '621610',
#   '622110',
#   '622210',
#   '622310',
#   '623110',
#   '623210',
#   '623220',
#   '623311',
#   '623312',
#   '623990',
#   '624110',
#   '624120',
#   '624190',
#   '624210',
#   '624221',
#   '624229',
#   '624230',
#   '624310',
#   '624410'],
#  'wholesale plant nursery': ['424930',
#   '424910',
#   '424920',
#   '424940',
#   '424950',
#   '424990',
#   '424110',
#   '424120',
#   '424130',
#   '424210',
#   '424310',
#   '424320',
#   '424330',
#   '424340',
#   '424410',
#   '424420',
#   '424430',
#   '424440',
#   '424450',
#   '424460',
#   '424470',
#   '424480',
#   '424490',
#   '424510',
#   '424520',
#   '424590',
#   '424610',
#   '424690',
#   '424710',
#   '424720',
#   '424810',
#   '424820',
#   '423110',
#   '423120',
#   '423130',
#   '423140',
#   '423210',
#   '423220',
#   '423310',
#   '423320',
#   '423330',
#   '423390',
#   '423410',
#   '423420',
#   '423430',
#   '423440',
#   '423450',
#   '423460',
#   '423490',
#   '423510',
#   '423520',
#   '423610',
#   '423620',
#   '423690',
#   '423710',
#   '423720',
#   '423730',
#   '423740',
#   '423810',
#   '423820',
#   '423830',
#   '423840',
#   '423850',
#   '423860',
#   '423910',
#   '423920',
#   '423930',
#   '423940',
#   '423990',
#   '425110',
#   '425120'],
#  'amusement machine supplier': ['713120',
#   '713110',
#   '713210',
#   '713290',
#   '713910',
#   '713920',
#   '713930',
#   '713940',
#   '713950',
#   '713990',
#   '711110',
#   '711120',
#   '711130',
#   '711190',
#   '711211',
#   '711212',
#   '711219',
#   '711310',
#   '711320',
#   '711410',
#   '711510',
#   '712110',
#   '712120',
#   '712130',
#   '712190'],
#  'animal hospital': ['541940',
#   '541910',
#   '541921',
#   '541922',
#   '541930',
#   '541990',
#   '541110',
#   '541120',
#   '541191',
#   '541199',
#   '541211',
#   '541213',
#   '541214',
#   '541219',
#   '541310',
#   '541320',
#   '541330',
#   '541340',
#   '541350',
#   '541360',
#   '541370',
#   '541380',
#   '541410',
#   '541420',
#   '541430',
#   '541490',
#   '541511',
#   '541512',
#   '541513',
#   '541519',
#   '541611',
#   '541612',
#   '541613',
#   '541614',
#   '541618',
#   '541620',
#   '541690',
#   '541713',
#   '541714',
#   '541715',
#   '541720',
#   '541810',
#   '541820',
#   '541830',
#   '541840',
#   '541850',
#   '541860',
#   '541870',
#   '541890'],
#  'farmer market': ['445230',
#   '445210',
#   '445220',
#   '445291',
#   '445292',
#   '445299',
#   '445110',
#   '445120',
#   '445310',
#   '441110',
#   '441120',
#   '441210',
#   '441222',
#   '441228',
#   '441310',
#   '441320',
#   '442110',
#   '442210',
#   '442291',
#   '442299',
#   '443141',
#   '443142',
#   '444110',
#   '444120',
#   '444130',
#   '444190',
#   '444210',
#   '444220',
#   '446110',
#   '446120',
#   '446130',
#   '446191',
#   '446199',
#   '447110',
#   '447190',
#   '448110',
#   '448120',
#   '448130',
#   '448140',
#   '448150',
#   '448190',
#   '448210',
#   '448310',
#   '448320'],
#  'vaporizer store': ['453991',
#   '453998',
#   '453910',
#   '453920',
#   '453930',
#   '453110',
#   '453210',
#   '453220',
#   '453310',
#   '451110',
#   '451120',
#   '451130',
#   '451140',
#   '451211',
#   '451212',
#   '452210',
#   '452311',
#   '452319',
#   '454110',
#   '454210',
#   '454310',
#   '454390'],
#  'cigar shop': ['453991',
#   '453998',
#   '453910',
#   '453920',
#   '453930',
#   '453110',
#   '453210',
#   '453220',
#   '453310',
#   '451110',
#   '451120',
#   '451130',
#   '451140',
#   '451211',
#   '451212',
#   '452210',
#   '452311',
#   '452319',
#   '454110',
#   '454210',
#   '454310',
#   '454390'],
#  'tobacco shop': ['453991',
#   '453998',
#   '453910',
#   '453920',
#   '453930',
#   '453110',
#   '453210',
#   '453220',
#   '453310',
#   '451110',
#   '451120',
#   '451130',
#   '451140',
#   '451211',
#   '451212',
#   '452210',
#   '452311',
#   '452319',
#   '454110',
#   '454210',
#   '454310',
#   '454390'],
#  'well drilling contractor': ['213111',
#   '213112',
#   '213113',
#   '213114',
#   '213115',
#   '211120',
#   '211130',
#   '212111',
#   '212112',
#   '212113',
#   '212210',
#   '212221',
#   '212222',
#   '212230',
#   '212291',
#   '212299',
#   '212311',
#   '212312',
#   '212313',
#   '212319',
#   '212321',
#   '212322',
#   '212324',
#   '212325',
#   '212391',
#   '212392',
#   '212393',
#   '212399'],
#  'library': ['519120',
#   '519110',
#   '519130',
#   '519190',
#   '511110',
#   '511120',
#   '511130',
#   '511140',
#   '511191',
#   '511199',
#   '511210',
#   '512110',
#   '512120',
#   '512131',
#   '512132',
#   '512191',
#   '512199',
#   '512230',
#   '512240',
#   '512250',
#   '512290',
#   '515111',
#   '515112',
#   '515120',
#   '515210',
#   '517311',
#   '517312',
#   '517410',
#   '517911',
#   '517919',
#   '518210'],
#  'apartment building': ['531110',
#   '531120',
#   '531130',
#   '531190',
#   '531210',
#   '531311',
#   '531312',
#   '531320',
#   '531390',
#   '532111',
#   '532112',
#   '532120',
#   '532210',
#   '532281',
#   '532282',
#   '532283',
#   '532284',
#   '532289',
#   '532310',
#   '532411',
#   '532412',
#   '532420',
#   '532490',
#   '533110'],
#  'apartment rental agency': ['531110',
#   '531120',
#   '531130',
#   '531190',
#   '531210',
#   '531311',
#   '531312',
#   '531320',
#   '531390',
#   '532111',
#   '532112',
#   '532120',
#   '532210',
#   '532281',
#   '532282',
#   '532283',
#   '532284',
#   '532289',
#   '532310',
#   '532411',
#   '532412',
#   '532420',
#   '532490',
#   '533110'],
#  'dairy farm': ['112120',
#   '112111',
#   '112112',
#   '112130',
#   '112210',
#   '112310',
#   '112320',
#   '112330',
#   '112340',
#   '112390',
#   '112410',
#   '112420',
#   '112511',
#   '112512',
#   '112519',
#   '112910',
#   '112920',
#   '112930',
#   '112990',
#   '111110',
#   '111120',
#   '111130',
#   '111140',
#   '111150',
#   '111160',
#   '111191',
#   '111199',
#   '111211',
#   '111219',
#   '111310',
#   '111320',
#   '111331',
#   '111332',
#   '111333',
#   '111334',
#   '111335',
#   '111336',
#   '111339',
#   '111411',
#   '111419',
#   '111421',
#   '111422',
#   '111910',
#   '111920',
#   '111930',
#   '111940',
#   '111991',
#   '111992',
#   '111998',
#   '113110',
#   '113210',
#   '113310',
#   '114111',
#   '114112',
#   '114119',
#   '114210',
#   '115111',
#   '115112',
#   '115113',
#   '115114',
#   '115115',
#   '115116',
#   '115210',
#   '115310'],
#  'architect': ['541310',
#   '541320',
#   '541330',
#   '541340',
#   '541350',
#   '541360',
#   '541370',
#   '541380',
#   '541110',
#   '541120',
#   '541191',
#   '541199',
#   '541211',
#   '541213',
#   '541214',
#   '541219',
#   '541410',
#   '541420',
#   '541430',
#   '541490',
#   '541511',
#   '541512',
#   '541513',
#   '541519',
#   '541611',
#   '541612',
#   '541613',
#   '541614',
#   '541618',
#   '541620',
#   '541690',
#   '541713',
#   '541714',
#   '541715',
#   '541720',
#   '541810',
#   '541820',
#   '541830',
#   '541840',
#   '541850',
#   '541860',
#   '541870',
#   '541890',
#   '541910',
#   '541921',
#   '541922',
#   '541930',
#   '541940',
#   '541990'],
#  'organic farm': ['111998',
#   '111991',
#   '111992',
#   '111910',
#   '111920',
#   '111930',
#   '111940',
#   '111110',
#   '111120',
#   '111130',
#   '111140',
#   '111150',
#   '111160',
#   '111191',
#   '111199',
#   '111211',
#   '111219',
#   '111310',
#   '111320',
#   '111331',
#   '111332',
#   '111333',
#   '111334',
#   '111335',
#   '111336',
#   '111339',
#   '111411',
#   '111419',
#   '111421',
#   '111422',
#   '112111',
#   '112112',
#   '112120',
#   '112130',
#   '112210',
#   '112310',
#   '112320',
#   '112330',
#   '112340',
#   '112390',
#   '112410',
#   '112420',
#   '112511',
#   '112512',
#   '112519',
#   '112910',
#   '112920',
#   '112930',
#   '112990',
#   '113110',
#   '113210',
#   '113310',
#   '114111',
#   '114112',
#   '114119',
#   '114210',
#   '115111',
#   '115112',
#   '115113',
#   '115114',
#   '115115',
#   '115116',
#   '115210',
#   '115310'],
#  'architectural designer': ['541310',
#   '541320',
#   '541330',
#   '541340',
#   '541350',
#   '541360',
#   '541370',
#   '541380',
#   '541110',
#   '541120',
#   '541191',
#   '541199',
#   '541211',
#   '541213',
#   '541214',
#   '541219',
#   '541410',
#   '541420',
#   '541430',
#   '541490',
#   '541511',
#   '541512',
#   '541513',
#   '541519',
#   '541611',
#   '541612',
#   '541613',
#   '541614',
#   '541618',
#   '541620',
#   '541690',
#   '541713',
#   '541714',
#   '541715',
#   '541720',
#   '541810',
#   '541820',
#   '541830',
#   '541840',
#   '541850',
#   '541860',
#   '541870',
#   '541890',
#   '541910',
#   '541921',
#   '541922',
#   '541930',
#   '541940',
#   '541990'],
#  'architecture firm': ['541310',
#   '541320',
#   '541330',
#   '541340',
#   '541350',
#   '541360',
#   '541370',
#   '541380',
#   '541110',
#   '541120',
#   '541191',
#   '541199',
#   '541211',
#   '541213',
#   '541214',
#   '541219',
#   '541410',
#   '541420',
#   '541430',
#   '541490',
#   '541511',
#   '541512',
#   '541513',
#   '541519',
#   '541611',
#   '541612',
#   '541613',
#   '541614',
#   '541618',
#   '541620',
#   '541690',
#   '541713',
#   '541714',
#   '541715',
#   '541720',
#   '541810',
#   '541820',
#   '541830',
#   '541840',
#   '541850',
#   '541860',
#   '541870',
#   '541890',
#   '541910',
#   '541921',
#   '541922',
#   '541930',
#   '541940',
#   '541990'],
#  'livestock producer': ['112111',
#   '112112',
#   '112120',
#   '112130',
#   '112210',
#   '112310',
#   '112320',
#   '112330',
#   '112340',
#   '112390',
#   '112410',
#   '112420',
#   '112511',
#   '112512',
#   '112519',
#   '112910',
#   '112920',
#   '112930',
#   '112990',
#   '111110',
#   '111120',
#   '111130',
#   '111140',
#   '111150',
#   '111160',
#   '111191',
#   '111199',
#   '111211',
#   '111219',
#   '111310',
#   '111320',
#   '111331',
#   '111332',
#   '111333',
#   '111334',
#   '111335',
#   '111336',
#   '111339',
#   '111411',
#   '111419',
#   '111421',
#   '111422',
#   '111910',
#   '111920',
#   '111930',
#   '111940',
#   '111991',
#   '111992',
#   '111998',
#   '113110',
#   '113210',
#   '113310',
#   '114111',
#   '114112',
#   '114119',
#   '114210',
#   '115111',
#   '115112',
#   '115113',
#   '115114',
#   '115115',
#   '115116',
#   '115210',
#   '115310'],
#  'dairy supplier': ['424430',
#   '424410',
#   '424420',
#   '424440',
#   '424450',
#   '424460',
#   '424470',
#   '424480',
#   '424490',
#   '424110',
#   '424120',
#   '424130',
#   '424210',
#   '424310',
#   '424320',
#   '424330',
#   '424340',
#   '424510',
#   '424520',
#   '424590',
#   '424610',
#   '424690',
#   '424710',
#   '424720',
#   '424810',
#   '424820',
#   '424910',
#   '424920',
#   '424930',
#   '424940',
#   '424950',
#   '424990',
#   '423110',
#   '423120',
#   '423130',
#   '423140',
#   '423210',
#   '423220',
#   '423310',
#   '423320',
#   '423330',
#   '423390',
#   '423410',
#   '423420',
#   '423430',
#   '423440',
#   '423450',
#   '423460',
#   '423490',
#   '423510',
#   '423520',
#   '423610',
#   '423620',
#   '423690',
#   '423710',
#   '423720',
#   '423730',
#   '423740',
#   '423810',
#   '423820',
#   '423830',
#   '423840',
#   '423850',
#   '423860',
#   '423910',
#   '423920',
#   '423930',
#   '423940',
#   '423990',
#   '425110',
#   '425120'],
#  'biotechnology company': ['541714',
#   '541713',
#   '541715',
#   '541720',
#   '541110',
#   '541120',
#   '541191',
#   '541199',
#   '541211',
#   '541213',
#   '541214',
#   '541219',
#   '541310',
#   '541320',
#   '541330',
#   '541340',
#   '541350',
#   '541360',
#   '541370',
#   '541380',
#   '541410',
#   '541420',
#   '541430',
#   '541490',
#   '541511',
#   '541512',
#   '541513',
#   '541519',
#   '541611',
#   '541612',
#   '541613',
#   '541614',
#   '541618',
#   '541620',
#   '541690',
#   '541810',
#   '541820',
#   '541830',
#   '541840',
#   '541850',
#   '541860',
#   '541870',
#   '541890',
#   '541910',
#   '541921',
#   '541922',
#   '541930',
#   '541940',
#   '541990'],
#  'artist': ['711510',
#   '711110',
#   '711120',
#   '711130',
#   '711190',
#   '711211',
#   '711212',
#   '711219',
#   '711310',
#   '711320',
#   '711410',
#   '712110',
#   '712120',
#   '712130',
#   '712190',
#   '713110',
#   '713120',
#   '713210',
#   '713290',
#   '713910',
#   '713920',
#   '713930',
#   '713940',
#   '713950',
#   '713990'],
#  'egg supplier': ['112310',
#   '112320',
#   '112330',
#   '112340',
#   '112390',
#   '112111',
#   '112112',
#   '112120',
#   '112130',
#   '112210',
#   '112410',
#   '112420',
#   '112511',
#   '112512',
#   '112519',
#   '112910',
#   '112920',
#   '112930',
#   '112990',
#   '111110',
#   '111120',
#   '111130',
#   '111140',
#   '111150',
#   '111160',
#   '111191',
#   '111199',
#   '111211',
#   '111219',
#   '111310',
#   '111320',
#   '111331',
#   '111332',
#   '111333',
#   '111334',
#   '111335',
#   '111336',
#   '111339',
#   '111411',
#   '111419',
#   '111421',
#   '111422',
#   '111910',
#   '111920',
#   '111930',
#   '111940',
#   '111991',
#   '111992',
#   '111998',
#   '113110',
#   '113210',
#   '113310',
#   '114111',
#   '114112',
#   '114119',
#   '114210',
#   '115111',
#   '115112',
#   '115113',
#   '115114',
#   '115115',
#   '115116',
#   '115210',
#   '115310'],
#  'poultry farm': ['311615',
#   '311611',
#   '311612',
#   '311613',
#   '311111',
#   '311119',
#   '311211',
#   '311212',
#   '311213',
#   '311221',
#   '311224',
#   '311225',
#   '311230',
#   '311313',
#   '311314',
#   '311340',
#   '311351',
#   '311352',
#   '311411',
#   '311412',
#   '311421',
#   '311422',
#   '311423',
#   '311511',
#   '311512',
#   '311513',
#   '311514',
#   '311520',
#   '311710',
#   '311811',
#   '311812',
#   '311813',
#   '311821',
#   '311824',
#   '311830',
#   '311911',
#   '311919',
#   '311920',
#   '311930',
#   '311941',
#   '311942',
#   '311991',
#   '311999',
#   '312111',
#   '312112',
#   '312113',
#   '312120',
#   '312130',
#   '312140',
#   '312230',
#   '313110',
#   '313210',
#   '313220',
#   '313230',
#   '313240',
#   '313310',
#   '313320',
#   '314110',
#   '314120',
#   '314910',
#   '314994',
#   '314999',
#   '315110',
#   '315190',
#   '315210',
#   '315220',
#   '315240',
#   '315280',
#   '315990',
#   '316110',
#   '316210',
#   '316992',
#   '316998'],
#  'chicken hatchery': ['112340',
#   '112310',
#   '112320',
#   '112330',
#   '112390',
#   '112111',
#   '112112',
#   '112120',
#   '112130',
#   '112210',
#   '112410',
#   '112420',
#   '112511',
#   '112512',
#   '112519',
#   '112910',
#   '112920',
#   '112930',
#   '112990',
#   '111110',
#   '111120',
#   '111130',
#   '111140',
#   '111150',
#   '111160',
#   '111191',
#   '111199',
#   '111211',
#   '111219',
#   '111310',
#   '111320',
#   '111331',
#   '111332',
#   '111333',
#   '111334',
#   '111335',
#   '111336',
#   '111339',
#   '111411',
#   '111419',
#   '111421',
#   '111422',
#   '111910',
#   '111920',
#   '111930',
#   '111940',
#   '111991',
#   '111992',
#   '111998',
#   '113110',
#   '113210',
#   '113310',
#   '114111',
#   '114112',
#   '114119',
#   '114210',
#   '115111',
#   '115112',
#   '115113',
#   '115114',
#   '115115',
#   '115116',
#   '115210',
#   '115310'],
#  'art organization': ['711190',
#   '711110',
#   '711120',
#   '711130',
#   '711211',
#   '711212',
#   '711219',
#   '711310',
#   '711320',
#   '711410',
# ...
#   '335110',
#   '335121',
#   '335122',
#   '335129',
#   '335210',
#   '335220',
#   '335311',
#   '335312',
#   '335313',
#   '335314',
#   '335911',
#   '335912',
#   '335921',
#   '335929',
#   '335931',
#   '335932',
#   '335991',
#   '335999',
#   '337110',
#   '337121',
#   '337122',
#   '337124',
#   '337125',
#   '337127',
#   '337211',
#   '337212',
#   '337214',
#   '337215',
#   '337910',
#   '337920',
#   '339112',
#   '339113',
#   '339114',
#   '339115',
#   '339116',
#   '339910',
#   '339920',
#   '339930',
#   '339940',
#   '339950',
#   '339991',
#   '339992',
#   '339993',
#   '339994',
#   '339995',
#   '339999'],
#  'orthodox synagogue': ['813110',
#   '813211',
#   '813212',
#   '813219',
#   '813311',
#   '813312',
#   '813319',
#   '813410',
#   '813910',
#   '813920',
#   '813930',
#   '813940',
#   '813990',
#   '811111',
#   '811112',
#   '811113',
#   '811118',
#   '811121',
#   '811122',
#   '811191',
#   '811192',
#   '811198',
#   '811211',
#   '811212',
#   '811213',
#   '811219',
#   '811310',
#   '811411',
#   '811412',
#   '811420',
#   '811430',
#   '811490',
#   '812111',
#   '812112',
#   '812113',
#   '812191',
#   '812199',
#   '812210',
#   '812220',
#   '812310',
#   '812320',
#   '812331',
#   '812332',
#   '812910',
#   '812921',
#   '812922',
#   '812930',
#   '812990',
#   '814110'],
#  'short term apartment rental agency': ['531110',
#   '531120',
#   '531130',
#   '531190',
#   '531210',
#   '531311',
#   '531312',
#   '531320',
#   '531390',
#   '532111',
#   '532112',
#   '532120',
#   '532210',
#   '532281',
#   '532282',
#   '532283',
#   '532284',
#   '532289',
#   '532310',
#   '532411',
#   '532412',
#   '532420',
#   '532490',
#   '533110'],
#  'nutritionist': ['621399',
#   '621391',
#   '621310',
#   '621320',
#   '621330',
#   '621340',
#   '621111',
#   '621112',
#   '621210',
#   '621410',
#   '621420',
#   '621491',
#   '621492',
#   '621493',
#   '621498',
#   '621511',
#   '621512',
#   '621610',
#   '621910',
#   '621991',
#   '621999',
#   '622110',
#   '622210',
#   '622310',
#   '623110',
#   '623210',
#   '623220',
#   '623311',
#   '623312',
#   '623990',
#   '624110',
#   '624120',
#   '624190',
#   '624210',
#   '624221',
#   '624229',
#   '624230',
#   '624310',
#   '624410'],
#  'ophthalmologist': ['621320',
#   '621310',
#   '621330',
#   '621340',
#   '621391',
#   '621399',
#   '621111',
#   '621112',
#   '621210',
#   '621410',
#   '621420',
#   '621491',
#   '621492',
#   '621493',
#   '621498',
#   '621511',
#   '621512',
#   '621610',
#   '621910',
#   '621991',
#   '621999',
#   '622110',
#   '622210',
#   '622310',
#   '623110',
#   '623210',
#   '623220',
#   '623311',
#   '623312',
#   '623990',
#   '624110',
#   '624120',
#   '624190',
#   '624210',
#   '624221',
#   '624229',
#   '624230',
#   '624310',
#   '624410'],
#  'ophthalmology clinic': ['621320',
#   '621310',
#   '621330',
#   '621340',
#   '621391',
#   '621399',
#   '621111',
#   '621112',
#   '621210',
#   '621410',
#   '621420',
#   '621491',
#   '621492',
#   '621493',
#   '621498',
#   '621511',
#   '621512',
#   '621610',
#   '621910',
#   '621991',
#   '621999',
#   '622110',
#   '622210',
#   '622310',
#   '623110',
#   '623210',
#   '623220',
#   '623311',
#   '623312',
#   '623990',
#   '624110',
#   '624120',
#   '624190',
#   '624210',
#   '624221',
#   '624229',
#   '624230',
#   '624310',
#   '624410'],
#  'social service organization': ['624190',
#   '624110',
#   '624120',
#   '624210',
#   '624221',
#   '624229',
#   '624230',
#   '624310',
#   '624410',
#   '621111',
#   '621112',
#   '621210',
#   '621310',
#   '621320',
#   '621330',
#   '621340',
#   '621391',
#   '621399',
#   '621410',
#   '621420',
#   '621491',
#   '621492',
#   '621493',
#   '621498',
#   '621511',
#   '621512',
#   '621610',
#   '621910',
#   '621991',
#   '621999',
#   '622110',
#   '622210',
#   '622310',
#   '623110',
#   '623210',
#   '623220',
#   '623311',
#   '623312',
#   '623990'],
#  'social welfare center': ['624190',
#   '624110',
#   '624120',
#   '624210',
#   '624221',
#   '624229',
#   '624230',
#   '624310',
#   '624410',
#   '621111',
#   '621112',
#   '621210',
#   '621310',
#   '621320',
#   '621330',
#   '621340',
#   '621391',
#   '621399',
#   '621410',
#   '621420',
#   '621491',
#   '621492',
#   '621493',
#   '621498',
#   '621511',
#   '621512',
#   '621610',
#   '621910',
#   '621991',
#   '621999',
#   '622110',
#   '622210',
#   '622310',
#   '623110',
#   '623210',
#   '623220',
#   '623311',
#   '623312',
#   '623990'],
#  'solar energy company': ['221114',
#   '221111',
#   '221112',
#   '221113',
#   '221115',
#   '221116',
#   '221117',
#   '221118',
#   '221121',
#   '221122',
#   '221210',
#   '221310',
#   '221320',
#   '221330'],
#  'solar energy equipment supplier': ['221114',
#   '221111',
#   '221112',
#   '221113',
#   '221115',
#   '221116',
#   '221117',
#   '221118',
#   '221121',
#   '221122',
#   '221210',
#   '221310',
#   '221320',
#   '221330'],
#  'special education school': ['611110',
#   '611210',
#   '611310',
#   '611410',
#   '611420',
#   '611430',
#   '611511',
#   '611512',
#   '611513',
#   '611519',
#   '611610',
#   '611620',
#   '611630',
#   '611691',
#   '611692',
#   '611699',
#   '611710'],
#  'podiatrist': ['621391',
#   '621399',
#   '621310',
#   '621320',
#   '621330',
#   '621340',
#   '621111',
#   '621112',
#   '621210',
#   '621410',
#   '621420',
#   '621491',
#   '621492',
#   '621493',
#   '621498',
#   '621511',
#   '621512',
#   '621610',
#   '621910',
#   '621991',
#   '621999',
#   '622110',
#   '622210',
#   '622310',
#   '623110',
#   '623210',
#   '623220',
#   '623311',
#   '623312',
#   '623990',
#   '624110',
#   '624120',
#   '624190',
#   '624210',
#   '624221',
#   '624229',
#   '624230',
#   '624310',
#   '624410'],
#  'reproductive health clinic': ['621410',
#   '621420',
#   '621491',
#   '621492',
#   '621493',
#   '621498',
#   '621111',
#   '621112',
#   '621210',
#   '621310',
#   '621320',
#   '621330',
#   '621340',
#   '621391',
#   '621399',
#   '621511',
#   '621512',
#   '621610',
#   '621910',
#   '621991',
#   '621999',
#   '622110',
#   '622210',
#   '622310',
#   '623110',
#   '623210',
#   '623220',
#   '623311',
#   '623312',
#   '623990',
#   '624110',
#   '624120',
#   '624190',
#   '624210',
#   '624221',
#   '624229',
#   '624230',
#   '624310',
#   '624410'],
#  'sporting good store': ['451110',
#   '451120',
#   '451130',
#   '451140',
#   '451211',
#   '451212',
#   '452210',
#   '452311',
#   '452319',
#   '453110',
#   '453210',
#   '453220',
#   '453310',
#   '453910',
#   '453920',
#   '453930',
#   '453991',
#   '453998',
#   '454110',
#   '454210',
#   '454310',
#   '454390'],
#  'dialysis center': ['621492',
#   '621491',
#   '621493',
#   '621498',
#   '621410',
#   '621420',
#   '621111',
#   '621112',
#   '621210',
#   '621310',
#   '621320',
#   '621330',
#   '621340',
#   '621391',
#   '621399',
#   '621511',
#   '621512',
#   '621610',
#   '621910',
#   '621991',
#   '621999',
#   '622110',
#   '622210',
#   '622310',
#   '623110',
#   '623210',
#   '623220',
#   '623311',
#   '623312',
#   '623990',
#   '624110',
#   '624120',
#   '624190',
#   '624210',
#   '624221',
#   '624229',
#   '624230',
#   '624310',
#   '624410'],
#  'sport complex': ['713940',
#   '713910',
#   '713920',
#   '713930',
#   '713950',
#   '713990',
#   '713110',
#   '713120',
#   '713210',
#   '713290',
#   '711110',
#   '711120',
#   '711130',
#   '711190',
#   '711211',
#   '711212',
#   '711219',
#   '711310',
#   '711320',
#   '711410',
#   '711510',
#   '712110',
#   '712120',
#   '712130',
#   '712190'],
#  'wellness program': ['525120',
#   '525110',
#   '525190',
#   '525910',
#   '525920',
#   '525990',
#   '521110',
#   '522110',
#   '522120',
#   '522130',
#   '522190',
#   '522210',
#   '522220',
#   '522291',
#   '522292',
#   '522293',
#   '522294',
#   '522298',
#   '522310',
#   '522320',
#   '522390',
#   '523110',
#   '523120',
#   '523130',
#   '523140',
#   '523210',
#   '523910',
#   '523920',
#   '523930',
#   '523991',
#   '523999',
#   '524113',
#   '524114',
#   '524126',
#   '524127',
#   '524128',
#   '524130',
#   '524210',
#   '524291',
#   '524292',
#   '524298'],
#  'sportswear store': ['451110',
#   '451120',
#   '451130',
#   '451140',
#   '451211',
#   '451212',
#   '452210',
#   '452311',
#   '452319',
#   '453110',
#   '453210',
#   '453220',
#   '453310',
#   '453910',
#   '453920',
#   '453930',
#   '453991',
#   '453998',
#   '454110',
#   '454210',
#   '454310',
#   '454390'],
#  'private hospital': ['622110',
#   '622210',
#   '622310',
#   '621111',
#   '621112',
#   '621210',
#   '621310',
#   '621320',
#   '621330',
#   '621340',
#   '621391',
#   '621399',
#   '621410',
#   '621420',
#   '621491',
#   '621492',
#   '621493',
#   '621498',
#   '621511',
#   '621512',
#   '621610',
#   '621910',
#   '621991',
#   '621999',
#   '623110',
#   '623210',
#   '623220',
#   '623311',
#   '623312',
#   '623990',
#   '624110',
#   '624120',
#   '624190',
#   '624210',
#   '624221',
#   '624229',
#   '624230',
#   '624310',
#   '624410'],
#  'radiologist': ['621512',
#   '621511',
#   '621111',
#   '621112',
#   '621210',
#   '621310',
#   '621320',
#   '621330',
#   '621340',
#   '621391',
#   '621399',
#   '621410',
#   '621420',
#   '621491',
#   '621492',
#   '621493',
#   '621498',
#   '621610',
#   '621910',
#   '621991',
#   '621999',
#   '622110',
#   '622210',
#   '622310',
#   '623110',
#   '623210',
#   '623220',
#   '623311',
#   '623312',
#   '623990',
#   '624110',
#   '624120',
#   '624190',
#   '624210',
#   '624221',
#   '624229',
#   '624230',
#   '624310',
#   '624410'],
#  'medical diagnostic imaging center': ['621512',
#   '621511',
#   '621111',
#   '621112',
#   '621210',
#   '621310',
#   '621320',
#   '621330',
#   '621340',
#   '621391',
#   '621399',
#   '621410',
#   '621420',
#   '621491',
#   '621492',
#   '621493',
#   '621498',
#   '621610',
#   '621910',
#   '621991',
#   '621999',
#   '622110',
#   '622210',
#   '622310',
#   '623110',
#   '623210',
#   '623220',
#   '623311',
#   '623312',
#   '623990',
#   '624110',
#   '624120',
#   '624190',
#   '624210',
#   '624221',
#   '624229',
#   '624230',
#   '624310',
#   '624410'],
#  'ray lab': ['621512',
#   '621511',
#   '621111',
#   '621112',
#   '621210',
#   '621310',
#   '621320',
#   '621330',
#   '621340',
#   '621391',
#   '621399',
#   '621410',
#   '621420',
#   '621491',
#   '621492',
#   '621493',
#   '621498',
#   '621610',
#   '621910',
#   '621991',
#   '621999',
#   '622110',
#   '622210',
#   '622310',
#   '623110',
#   '623210',
#   '623220',
#   '623311',
#   '623312',
#   '623990',
#   '624110',
#   '624120',
#   '624190',
#   '624210',
#   '624221',
#   '624229',
#   '624230',
#   '624310',
#   '624410'],
#  'blood bank': ['621991',
#   '621999',
#   '621910',
#   '621111',
#   '621112',
#   '621210',
#   '621310',
#   '621320',
#   '621330',
#   '621340',
#   '621391',
#   '621399',
#   '621410',
#   '621420',
#   '621491',
#   '621492',
#   '621493',
#   '621498',
#   '621511',
#   '621512',
#   '621610',
#   '622110',
#   '622210',
#   '622310',
#   '623110',
#   '623210',
#   '623220',
#   '623311',
#   '623312',
#   '623990',
#   '624110',
#   '624120',
#   '624190',
#   '624210',
#   '624221',
#   '624229',
#   '624230',
#   '624310',
#   '624410'],
#  'stainless steel plant': ['331110',
#   '331210',
#   '331221',
#   '331222',
#   '331313',
#   '331314',
#   '331315',
#   '331318',
#   '331410',
#   '331420',
#   '331491',
#   '331492',
#   '331511',
#   '331512',
#   '331513',
#   '331523',
#   '331524',
#   '331529',
#   '332111',
#   '332112',
#   '332114',
#   '332117',
#   '332119',
#   '332215',
#   '332216',
#   '332311',
#   '332312',
#   '332313',
#   '332321',
#   '332322',
#   '332323',
#   '332410',
#   '332420',
#   '332431',
#   '332439',
#   '332510',
#   '332613',
#   '332618',
#   '332710',
#   '332721',
#   '332722',
#   '332811',
#   '332812',
#   '332813',
#   '332911',
#   '332912',
#   '332913',
#   '332919',
#   '332991',
#   '332992',
#   '332993',
#   '332994',
#   '332996',
#   '332999',
#   '333111',
#   '333112',
#   '333120',
#   '333131',
#   '333132',
#   '333241',
#   '333242',
#   '333243',
#   '333244',
#   '333249',
#   '333314',
#   '333316',
#   '333318',
#   '333413',
#   '333414',
#   '333415',
#   '333511',
#   '333514',
#   '333515',
#   '333517',
#   '333519',
#   '333611',
#   '333612',
#   '333613',
#   '333618',
#   '333912',
#   '333914',
#   '333921',
#   '333922',
#   '333923',
#   '333924',
#   '333991',
#   '333992',
#   '333993',
#   '333994',
#   '333995',
#   '333996',
#   '333997',
#   '333999',
#   '334111',
#   '334112',
#   '334118',
#   '334210',
#   '334220',
#   '334290',
#   '334310',
#   '334412',
#   '334413',
#   '334416',
#   '334417',
#   '334418',
#   '334419',
#   '334510',
#   '334511',
#   '334512',
#   '334513',
#   '334514',
#   '334515',
#   '334516',
#   '334517',
#   '334519',
#   '334613',
#   '334614',
#   '335110',
#   '335121',
#   '335122',
#   '335129',
#   '335210',
#   '335220',
#   '335311',
#   '335312',
#   '335313',
#   '335314',
#   '335911',
#   '335912',
#   '335921',
#   '335929',
#   '335931',
#   '335932',
#   '335991',
#   '335999',
#   '336111',
#   '336112',
#   '336120',
#   '336211',
#   '336212',
#   '336213',
#   '336214',
#   '336310',
#   '336320',
#   '336330',
#   '336340',
#   '336350',
#   '336360',
#   '336370',
#   '336390',
#   '336411',
#   '336412',
#   '336413',
#   '336414',
#   '336415',
#   '336419',
#   '336510',
#   '336611',
#   '336612',
#   '336991',
#   '336992',
#   '336999',
#   '337110',
#   '337121',
#   '337122',
#   '337124',
#   '337125',
#   '337127',
#   '337211',
#   '337212',
#   '337214',
#   '337215',
#   '337910',
#   '337920',
#   '339112',
#   '339113',
#   '339114',
#   '339115',
#   '339116',
#   '339910',
#   '339920',
#   '339930',
#   '339940',
#   '339950',
#   '339991',
#   '339992',
#   '339993',
#   '339994',
#   '339995',
#   '339999'],
#  'state agency': ['921190',
#   '921110',
#   '921120',
#   '921130',
#   '921140',
#   '921150',
#   '922110',
#   '922120',
#   '922130',
#   '922140',
#   '922150',
#   '922160',
#   '922190',
#   '923110',
#   '923120',
#   '923130',
#   '923140',
#   '924110',
#   '924120',
#   '925110',
#   '925120',
#   '926110',
#   '926120',
#   '926130',
#   '926140',
#   '926150',
#   '927110',
#   '928110',
#   '928120'],
#  'heliport': ['488119',
#   '488111',
#   '488190',
#   '488210',
#   '488310',
#   '488320',
#   '488330',
#   '488390',
#   '488410',
#   '488490',
#   '488510',
#   '488991',
#   '488999',
#   '481111',
#   '481112',
#   '481211',
#   '481212',
#   '481219',
#   '482111',
#   '482112',
#   '483111',
#   '483112',
#   '483113',
#   '483114',
#   '483211',
#   '483212',
#   '484110',
#   '484121',
#   '484122',
#   '484210',
#   '484220',
#   '484230',
#   '485111',
#   '485112',
#   '485113',
#   '485119',
#   '485210',
#   '485310',
#   '485320',
#   '485410',
#   '485510',
#   '485991',
#   '485999',
#   '486110',
#   '486210',
#   '486910',
#   '486990',
#   '487110',
#   '487210',
#   '487990'],
#  'health care company': ['622110',
#   '622210',
#   '622310',
#   '621111',
#   '621112',
#   '621210',
#   '621310',
#   '621320',
#   '621330',
#   '621340',
#   '621391',
#   '621399',
#   '621410',
#   '621420',
#   '621491',
#   '621492',
#   '621493',
#   '621498',
#   '621511',
#   '621512',
#   '621610',
#   '621910',
#   '621991',
#   '621999',
#   '623110',
#   '623210',
#   '623220',
#   '623311',
#   '623312',
#   '623990',
#   '624110',
#   '624120',
#   '624190',
#   '624210',
#   '624221',
#   '624229',
#   '624230',
#   '624310',
#   '624410'],
#  'psychiatric hospital': ['622210',
#   '622110',
#   '622310',
#   '621111',
#   '621112',
#   '621210',
#   '621310',
#   '621320',
#   '621330',
#   '621340',
#   '621391',
#   '621399',
#   '621410',
#   '621420',
#   '621491',
#   '621492',
#   '621493',
#   '621498',
#   '621511',
#   '621512',
#   '621610',
#   '621910',
#   '621991',
#   '621999',
#   '623110',
#   '623210',
#   '623220',
#   '623311',
#   '623312',
#   '623990',
#   '624110',
#   '624120',
#   '624190',
#   '624210',
#   '624221',
#   '624229',
#   '624230',
#   '624310',
#   '624410'],
#  'state government office': ['921190',
#   '921110',
#   '921120',
#   '921130',
#   '921140',
#   '921150',
#   '922110',
#   '922120',
#   '922130',
#   '922140',
#   '922150',
#   '922160',
#   '922190',
#   '923110',
#   '923120',
#   '923130',
#   '923140',
#   '924110',
#   '924120',
#   '925110',
#   '925120',
#   '926110',
#   '926120',
#   '926130',
#   '926140',
#   '926150',
#   '927110',
#   '928110',
#   '928120'],
#  'medical institution': ['622110',
#   '622210',
#   '622310',
#   '621111',
#   '621112',
#   '621210',
#   '621310',
#   '621320',
#   '621330',
#   '621340',
#   '621391',
#   '621399',
#   '621410',
#   '621420',
#   '621491',
#   '621492',
#   '621493',
#   '621498',
#   '621511',
#   '621512',
#   '621610',
#   '621910',
#   '621991',
#   '621999',
#   '623110',
#   '623210',
#   '623220',
#   '623311',
#   '623312',
#   '623990',
#   '624110',
#   '624120',
#   '624190',
#   '624210',
#   '624221',
#   '624229',
#   '624230',
#   '624310',
#   '624410'],
#  'steel construction company': ['238120',
#   '238110',
#   '238130',
#   '238140',
#   '238150',
#   '238160',
#   '238170',
#   '238190',
#   '238210',
#   '238220',
#   '238290',
#   '238310',
#   '238320',
#   '238330',
#   '238340',
#   '238350',
#   '238390',
#   '238910',
#   '238990',
#   '236115',
#   '236116',
#   '236117',
#   '236118',
#   '236210',
#   '236220',
#   '237110',
#   '237120',
#   '237130',
#   '237210',
#   '237310',
#   '237990'],
#  'cleaning service': ['561720',
#   '561710',
#   '561730',
#   '561740',
#   '561790',
#   '561110',
#   '561210',
#   '561311',
#   '561312',
#   '561320',
#   '561330',
#   '561410',
#   '561421',
#   '561422',
#   '561431',
#   '561439',
#   '561440',
#   '561450',
#   '561491',
#   '561492',
#   '561499',
#   '561510',
#   '561520',
#   '561591',
#   '561599',
#   '561611',
#   '561612',
#   '561613',
#   '561621',
#   '561622',
#   '561910',
#   '561920',
#   '561990',
#   '562111',
#   '562112',
#   '562119',
#   '562211',
#   '562212',
#   '562213',
#   '562219',
#   '562910',
#   '562920',
#   '562991',
#   '562998'],
#  ...}

# %%
calc_pre_rec_at_n(ret_docs_dic, queries_dic, n=-1)[0]
# Out:
# {'home improvement store': 0.4,
#  'diesel fuel supplier': 0.0,
#  'church': 0.0,
#  'farm': 1.0,
#  'seed supplier': 0.0,
#  'accountant': 1.0,
#  'trucking company': 0.6,
#  'exporter': 1.0,
#  'grain elevator': 0.0,
#  'popcorn store': 0.9,
#  'agricultural service': 0.0,
#  'warehouse': 0.4,
#  'agricultural production': 1.0,
#  'ranch': 1.0,
#  'holding company': 0.3,
#  'farm equipment supplier': 0.0,
#  'store': 1.0,
#  'grocery store': 0.9,
#  'rice mill': 1.0,
#  'food product supplier': 0.0,
#  'accounting firm': 1.0,
#  'produce market': 0.3,
#  'pet supply store': 1.0,
#  'wholesaler': 1.0,
#  'produce wholesaler': 1.0,
#  'distribution service': 0.4,
#  'crop grower': 1.0,
#  'addiction treatment center': 1.0,
#  'natural good store': 0.0,
#  'orchard': 1.0,
#  'lumber store': 0.0,
#  'mine': 1.0,
#  'transportation service': 1.0,
#  'investment company': 1.0,
#  'fruit wholesaler': 1.0,
#  'real estate agency': 1.0,
#  'event venue': 0.0,
#  'frozen dessert supplier': 1.0,
#  'wine wholesaler importer': 1.0,
#  'winery': 0.7,
#  'aerospace company': 1.0,
#  'cold storage facility': 0.4,
#  'employment agency': 0.0,
#  'plant nursery': 0.0,
#  'air conditioning contractor': 1.0,
#  'air conditioning repair service': 0.0,
#  'fruit vegetable wholesaler': 0.0,
#  'aircraft rental service': 1.0,
#  'monastery': 1.0,
#  'allergist': 1.0,
#  'herb shop': 0.0,
#  'aluminum supplier': 1.0,
#  'ambulance service': 0.0,
#  'wholesale plant nursery': 1.0,
#  'amusement machine supplier': 1.0,
#  'animal hospital': 0.0,
#  'farmer market': 0.0,
#  'vaporizer store': 1.0,
#  'cigar shop': 0.9,
#  'tobacco shop': 0.5,
#  'well drilling contractor': 0.0,
#  'library': 1.0,
#  'apartment building': 0.0,
#  'apartment rental agency': 1.0,
#  'dairy farm': 1.0,
#  'architect': 1.0,
#  'organic farm': 1.0,
#  'architectural designer': 1.0,
#  'architecture firm': 0.0,
#  'livestock producer': 0.0,
#  'dairy supplier': 0.0,
#  'biotechnology company': 0.4,
#  'artist': 1.0,
#  'egg supplier': 1.0,
#  'poultry farm': 0.0,
#  'chicken hatchery': 1.0,
#  'art organization': 1.0,
#  'association organization': 1.0,
#  'food store': 0.9,
#  'deli': 0.0,
#  'bank': 1.0,
#  'fish processing': 0.0,
#  'fish farm': 1.0,
#  'seafood wholesaler': 1.0,
#  'tropical fish store': 1.0,
#  'non profit organization': 1.0,
#  'economic development agency': 1.0,
#  'seafood market': 0.9,
#  'honey farm': 1.0,
#  'horse breeder': 0.0,
#  'asphalt contractor': 1.0,
#  'livestock dealer': 0.0,
#  'department store': 1.0,
#  'mill': 1.0,
#  'atv dealer': 0.9,
#  'audio visual consultant': 1.0,
#  'pallet supplier': 1.0,
#  'wood supplier': 0.0,
#  'hardware store': 0.0,
#  'furniture wholesaler': 0.0,
#  'auditor': 1.0,
#  'oil natural gas company': 1.0,
#  'auto body shop': 1.0,
#  'boat repair shop': 0.0,
#  'association': 1.0,
#  'railing contractor': 0.0,
#  'publisher': 1.0,
#  'pond supply store': 0.0,
#  'agriculture cooperative': 0.0,
#  'printing equipment supplier': 1.0,
#  'auto insurance agency': 1.0,
#  'alternative fuel station': 0.7,
#  'auto part manufacturer': 0.0,
#  'foundation': 1.0,
#  'fertilizer supplier': 1.0,
#  'farming company': 1.0,
#  'finance broker': 1.0,
#  'agricultural cooperative': 0.0,
#  'fire station': 0.0,
#  'environmental consultant': 1.0,
#  'civil engineer': 1.0,
#  'fire protection service': 0.0,
#  'gas company': 0.0,
#  'oilfield': 0.0,
#  'banquet hall': 0.8,
#  'mining company': 1.0,
#  'coalfield': 0.0,
#  'steel fabricator': 1.0,
#  'quarry': 1.0,
#  'gold mining company': 1.0,
#  'high rise building': 1.0,
#  'basketball club': 1.0,
#  'gold dealer': 0.0,
#  'battery manufacturer': 1.0,
#  'electric utility company': 0.0,
#  'environmental program': 0.0,
#  'office': 0.0,
#  'stone supplier': 0.0,
#  'aggregate supplier': 0.0,
#  'sand gravel supplier': 0.0,
#  'building material supplier': 0.6,
#  'beauty supply store': 0.5,
#  'crushed stone supplier': 0.0,
#  'rock shop': 0.0,
#  'road construction company': 1.0,
#  'marketing consultant': 1.0,
#  'blood testing service': 1.0,
#  'contractor': 1.0,
#  'excavating contractor': 1.0,
#  'asphalt mixing plant': 1.0,
#  'ready mix concrete supplier': 1.0,
#  'sand plant': 0.0,
#  'bmw dealer': 1.0,
#  'bookbinder': 1.0,
#  'garden center': 0.6,
#  'abrasive supplier': 1.0,
#  'granite supplier': 0.0,
#  'drilling contractor': 0.0,
#  'bpo company': 1.0,
#  'oil gas exploration service': 1.0,
#  'building complex': 0.0,
#  'construction equipment supplier': 0.0,
#  'mining equipment': 0.0,
#  'bus ticket agency': 0.0,
#  'business center': 0.0,
#  'skyscraper': 0.0,
#  'software company': 1.0,
#  'business development service': 0.7,
#  'business management consultant': 0.0,
#  'cabinet maker': 1.0,
#  'call center': 0.0,
#  'cancer treatment center': 1.0,
#  'power plant consultant': 0.0,
#  'business park': 0.0,
#  'petroleum product company': 0.0,
#  'parking lot': 1.0,
#  'water utility company': 1.0,
#  'car repair maintenance': 1.0,
#  'water treatment plant': 1.0,
#  'car service': 1.0,
#  'cattle market': 0.0,
#  'sewage disposal service': 1.0,
#  'certified public accountant': 0.0,
#  'government office': 1.0,
#  'charity': 1.0,
#  'air conditioning system supplier': 0.0,
#  'chemical industry': 1.0,
#  'chemical manufacturer': 1.0,
#  'title company': 0.0,
#  'chemical plant': 1.0,
#  'property management company': 0.0,
#  'custom home builder': 1.0,
#  'window installation service': 0.0,
#  'fire damage restoration service': 0.0,
#  'equipment rental agency': 1.0,
#  'chemical wholesaler': 0.0,
#  'financial planner': 1.0,
#  'telecommunication service provider': 1.0,
#  'energy equipment solution': 0.0,
#  'chiropractor': 1.0,
#  'steel distributor': 0.0,
#  'city government office': 1.0,
#  'crane service': 0.0,
#  'garage door supplier': 0.0,
#  'industrial door supplier': 0.9,
#  'city town hall': 0.0,
#  'clothing wholesaler': 0.0,
#  'coin operated laundry equipment supplier': 1.0,
#  'metal supplier': 0.0,
#  'glass shop': 0.0,
#  'college': 1.0,
#  'siding contractor': 1.0,
#  'commercial printer': 0.0,
#  'storage facility': 0.4,
#  'communication tower': 0.0,
#  'janitorial service': 0.0,
#  'computer consultant': 0.0,
#  'fire protection system supplier': 0.0,
#  'elevator service': 0.0,
#  'industrial equipment supplier': 0.0,
#  'dry wall contractor': 1.0,
#  'insulation contractor': 1.0,
#  'concrete contractor': 1.0,
#  'scaffolding rental service': 1.0,
#  'construction company': 1.0,
#  'flooring store': 1.0,
#  'flooring contractor': 1.0,
#  'tile contractor': 1.0,
#  'tile manufacturer': 0.0,
#  'glass mirror shop': 0.0,
#  'construction material wholesaler': 1.0,
#  'gutter cleaning service': 0.0,
#  'sheet metal contractor': 1.0,
#  'consultant': 1.0,
#  'container service': 0.0,
#  'septic system service': 0.0,
#  'corporate campus': 0.3,
#  'water damage restoration service': 0.0,
#  'welder': 0.0,
#  'corporate office': 0.3,
#  'animal': 1.0,
#  'animal feed store': 0.0,
#  'animal protection organization': 0.0,
#  'brewing supply store': 0.0,
#  'cosmetic store': 0.5,
#  'county government office': 1.0,
#  'sugar factory': 1.0,
#  'confectionery wholesaler': 1.0,
#  'financial institution': 0.0,
#  'candy store': 0.9,
#  'confectionery': 0.0,
#  'chocolate factory': 1.0,
#  'chocolate shop': 1.0,
#  'courier service': 0.3,
#  'coworking space': 0.0,
#  'frozen food manufacturer': 1.0,
#  'beverage distributor': 0.0,
#  'agricultural organization': 0.0,
#  'dairy store': 0.0,
#  'dairy': 0.7,
#  'ice cream shop': 0.7,
#  'medical laboratory': 1.0,
#  'demolition contractor': 1.0,
#  'meat processor': 0.9,
#  'fmcg manufacturer': 0.0,
#  'garbage collection service': 1.0,
#  'wholesale bakery': 1.0,
#  'dentist': 1.0,
#  'dessert shop': 0.0,
#  'cupcake shop': 0.0,
#  'nut store': 0.9,
#  'wholesale grocer': 1.0,
#  'design engineer': 1.0,
#  'business business service': 1.0,
#  'condiment supplier': 1.0,
#  'digital printing service': 0.4,
#  'culinary school': 1.0,
#  'importer': 0.0,
#  'bottled water supplier': 0.0,
#  'coffee roaster': 1.0,
#  'packaging supply store': 0.0,
#  'ice supplier': 0.7,
#  'brewery': 0.7,
#  'winemaking company': 0.0,
#  'distillery': 0.7,
#  'disability service support organisation': 0.0,
#  'district government office': 1.0,
#  'air filter supplier': 0.0,
#  'tire shop': 0.7,
#  'fastener supplier': 1.0,
#  'fabric product manufacturer': 1.0,
#  'textile': 1.0,
#  'textile exporter': 1.0,
#  'textile engineer': 1.0,
#  'fabric store': 1.0,
#  'knit shop': 1.0,
#  'doctor': 1.0,
#  'lamination service': 0.0,
#  'plastic resin manufacturer': 0.3,
#  'carpet manufacturer': 1.0,
#  'upholstery shop': 1.0,
#  'business administration service': 0.0,
#  'furniture store': 0.4,
#  'dry cleaner': 0.0,
#  'packaging company': 1.0,
#  'duty free store': 1.0,
#  'commerce service': 0.0,
#  'cable company': 0.0,
#  'education': 1.0,
#  'outlet store': 1.0,
#  'lingerie store': 1.0,
#  'clothes fabric manufacturer': 1.0,
#  'education center': 0.0,
#  'uniform store': 0.9,
#  'men clothing store': 0.9,
#  'clothing store': 0.9,
#  'woman clothing store': 0.9,
#  'western apparel store': 0.0,
#  'costume store': 0.0,
#  'game store': 1.0,
#  'hat shop': 0.2,
#  'leather good manufacturer': 0.5,
#  'educational consultant': 1.0,
#  'leather exporter': 0.4,
#  'shoe store': 0.4,
#  'boutique': 0.0,
#  'leather wholesaler': 0.6,
#  'handbag shop': 0.4,
#  'electronics store': 0.2,
#  'luggage store': 0.6,
#  'building material store': 0.6,
#  'saw mill': 1.0,
#  'electrical engineer': 0.0,
#  'deck builder': 1.0,
#  'concrete product supplier': 1.0,
#  'plywood supplier': 1.0,
#  'electrical installation service': 0.0,
#  'truss manufacturer': 0.0,
#  'door supplier': 1.0,
#  'wood laminate flooring supplier': 1.0,
#  'aircraft supply store': 0.0,
#  'modular home builder': 0.0,
#  'portable building manufacturer': 0.2,
#  'modular home dealer': 0.0,
#  'mulch supplier': 0.0,
#  'electrician': 0.0,
#  'paper mill': 1.0,
#  'energy supplier': 1.0,
#  'engineer': 0.0,
#  'print shop': 0.4,
#  'custom label printer': 0.4,
#  'marketing': 0.9,
#  'marketing agency': 0.0,
#  'engineering consultant': 1.0,
#  'entertainer': 1.0,
#  'envelope supplier': 0.0,
#  'oil refinery': 0.5,
#  'recording studio': 1.0,
#  'environment renewable natural resource': 0.0,
#  'finishing material supplier': 0.0,
#  'event ticket seller': 0.0,
#  'waterproofing company': 0.0,
#  'auto part store': 0.0,
#  'heating oil supplier': 0.4,
#  'family practice physician': 1.0,
#  'machining manufacturer': 0.0,
#  'industrial gas supplier': 0.0,
#  'welding supply store': 0.0,
#  'dry ice supplier': 0.9,
#  'private equity firm': 0.0,
#  'family service center': 1.0,
#  'federal government office': 1.0,
#  'vitamin supplement store': 0.5,
#  'feed manufacturer': 0.0,
#  'medical equipment supplier': 0.0,
#  'medical supply store': 0.0,
#  'medical clinic': 1.0,
#  'research institute': 1.0,
#  'biochemical supplier': 0.0,
#  'fiber optic product supplier': 0.0,
#  'paint manufacturer': 0.0,
#  'equipment supplier': 0.0,
#  'food': 0.0,
#  'pipe supplier': 1.0,
#  'oil field equipment supplier': 0.3,
#  'food broker': 0.0,
#  'food manufacturer': 0.0,
#  'food processing company': 0.0,
#  'fence supply store': 0.5,
#  'food producer': 0.0,
#  'forestry service': 1.0,
#  'foundry': 1.0,
#  'wholesale jeweler': 1.0,
#  'cookie shop': 0.0,
#  'truck rental agency': 1.0,
#  'fruit vegetable processing': 1.0,
#  'kitchen supply store': 0.0,
#  'hydraulic equipment supplier': 0.0,
#  'irrigation equipment supplier': 0.0,
#  'bearing supplier': 1.0,
#  'metallurgy company': 0.0,
#  'plastic injection molding service': 0.0,
#  'general contractor': 1.0,
#  'general hospital': 1.0,
#  'tool manufacturer': 0.5,
#  'industrial design company': 0.0,
#  'hyundai dealer': 0.0,
#  'glass industry': 1.0,
#  'polymer supplier': 0.0,
#  'printing equipment supply': 0.0,
#  'toner cartridge supplier': 1.0,
#  'printer repair service': 1.0,
#  'fuel supplier': 0.0,
#  'glass manufacturer': 1.0,
#  'plastic bag supplier': 0.2,
#  'glassware manufacturer': 0.0,
#  'polythene plastic sheeting supplier': 0.2,
#  'pvc industry': 0.0,
#  'countertop store': 1.0,
#  'cabinet store': 1.0,
#  'fiberglass supplier': 0.0,
#  'golf cart dealer': 1.0,
#  'auto repair shop': 1.0,
#  'hose supplier': 0.1,
#  'rubber product supplier': 0.3,
#  'automotive': 0.0,
#  'commercial refrigerator supplier': 0.0,
#  'golf club': 1.0,
#  'golf course': 1.0,
#  'green energy supplier': 1.0,
#  'greenhouse': 1.0,
#  'auto glass shop': 0.0,
#  'lighting manufacturer': 1.0,
#  'cement manufacturer': 1.0,
#  'brick manufacturer': 1.0,
#  'natural stone supplier': 0.0,
#  'gym': 1.0,
#  'marble supplier': 0.0,
#  'corporate gift supplier': 1.0,
#  'shipbuilding repair company': 0.0,
#  'construction maintenance office': 1.0,
#  'boiler manufacturer': 0.0,
#  'container supplier': 0.0,
#  'home construction': 1.0,
#  'health': 1.0,
#  'heart hospital': 1.0,
#  'spring supplier': 1.0,
#  'electric utility manufacturer': 0.0,
#  'aircraft manufacturer': 1.0,
#  'metal heat treating service': 1.0,
#  'plating service': 0.0,
#  'automation company': 0.0,
#  'heating contractor': 1.0,
#  'plumbing supply store': 0.0,
#  'gun shop': 0.9,
#  'ammunition supplier': 1.0,
#  'pipe manufacturer': 1.0,
#  'school': 1.0,
#  'fire protection equipment supplier': 0.0,
#  'agricultural machinery manufacturer': 1.0,
#  'lawn mower store': 0.9,
#  'lawn irrigation equipment supplier': 0.0,
#  'financial consultant': 1.0,
#  'helicopter charter': 1.0,
#  'packaging machinery': 1.0,
#  'historical landmark': 1.0,
#  'electronics manufacturer': 0.0,
#  'graphic designer': 0.0,
#  'eye care center': 1.0,
#  'optical product manufacturer': 0.0,
#  'image consultant': 0.9,
#  'cleaning product supplier': 0.0,
#  'fireplace store': 0.0,
#  'home builder': 1.0,
#  'tool die shop': 1.0,
#  'metal stamping service': 1.0,
#  'environmental organization': 1.0,
#  'food processing equipment': 0.0,
#  'loan agency': 1.0,
#  'power plant equipment supplier': 0.0,
#  'home good store': 0.4,
#  'engine rebuilding service': 1.0,
#  'air compressor supplier': 0.4,
#  'honda dealer': 1.0,
#  'elevator manufacturer': 0.0,
#  'crane dealer': 0.0,
#  'crane rental agency': 1.0,
#  'compound building': 0.0,
#  'tractor dealer': 0.0,
#  'furnace part supplier': 0.0,
#  'heating equipment supplier': 0.0,
#  'pneumatic tool supplier': 0.0,
#  'truck stop': 0.4,
#  'computer hardware manufacturer': 1.0,
#  'satellite communication service': 1.0,
#  'hospital': 1.0,
#  'electronics company': 0.0,
#  'electronic part supplier': 0.0,
#  'hvac contractor': 1.0,
#  'industrial engineer': 0.0,
#  'contact lens supplier': 0.0,
#  'information service': 1.0,
#  'building': 1.0,
#  'water work equipment supplier': 0.0,
#  'measuring instrument supplier': 1.0,
#  'scientific equipment supplier': 0.0,
#  'medical center': 1.0,
#  'watch manufacturer': 1.0,
#  'corporate entertainment service': 0.0,
#  'insurance': 1.0,
#  'record company': 0.0,
#  'video duplication service': 0.0,
#  'insurance agency': 1.0,
#  'lighting store': 1.0,
#  'lighting wholesaler': 1.0,
#  'entertainment agency': 1.0,
#  'insurance broker': 1.0,
#  'electrical equipment supplier': 0.0,
#  'electric motor store': 0.0,
#  'railroad company': 0.6,
#  'electrical supply store': 0.0,
#  'insurance company': 1.0,
#  'factory equipment supplier': 0.0,
#  'investment service': 1.0,
#  'laser equipment supplier': 1.0,
#  'executive suite rental agency': 0.0,
#  'truck dealer': 0.0,
#  'motor vehicle dealer': 0.7,
#  'car dealer': 0.9,
#  'truck topper supplier': 0.0,
#  'police supply store': 1.0,
#  'iron steel contractor': 1.0,
#  'fire department equipment supplier': 0.0,
#  'towing equipment provider': 1.0,
#  'logistics service': 1.0,
#  'trailer manufacturer': 1.0,
#  'trailer dealer': 0.0,
#  'dealer': 1.0,
#  'auto spring shop': 0.0,
#  'auto upholsterer': 0.0,
#  'auto body part supplier': 0.7,
#  'car factory': 0.0,
#  'freight forwarding service': 0.9,
#  'brake shop': 0.9,
#  'railroad equipment supplier': 0.0,
#  'jewelry equipment supplier': 1.0,
#  'boat builder': 0.2,
#  'ship building': 0.2,
#  'marine supply store': 0.5,
#  'boat dealer': 0.7,
#  'kawasaki motorcycle dealer': 0.9,
#  'knife manufacturing': 1.0,
#  'labor union': 1.0,
#  'furniture maker': 1.0,
#  'banking finance': 1.0,
#  'furniture manufacturer': 1.0,
#  'logistics': 1.0,
#  'massage supply store': 0.0,
#  'telecommunication equipment supplier': 0.0,
#  'baby store': 1.0,
#  'molding supplier': 0.0,
#  'office equipment supplier': 0.0,
#  'office furniture store': 1.0,
#  'store equipment supplier': 0.0,
#  'laboratory': 0.0,
#  'health beauty shop': 0.0,
#  'learning center': 1.0,
#  'dental laboratory': 1.0,
#  'land surveyor': 0.0,
#  'educational supply store': 1.0,
#  'jewelry store': 0.0,
#  'playground equipment supplier': 0.0,
#  'outdoor sport store': 1.0,
#  'toy store': 1.0,
#  'security service': 0.0,
#  'sign shop': 1.0,
#  'office supply store': 1.0,
#  'landscaper': 0.0,
#  'gasket manufacturer': 0.0,
#  'piano maker': 0.0,
#  'piano store': 1.0,
#  'funeral home': 0.0,
#  'monument': 0.0,
#  'book publisher': 1.0,
#  'wig shop': 0.2,
#  'laundromat': 1.0,
#  'auto wrecker': 0.0,
#  'auto part market': 0.7,
#  'jeep dealer': 1.0,
#  'restaurant supply store': 0.0,
#  'roofing supply store': 0.0,
#  'law firm': 0.0,
#  'building material market': 0.6,
#  'camera store': 0.0,
#  'lawn care service': 0.0,
#  'computer security service': 0.0,
#  'computer store': 0.0,
#  'design agency': 0.0,
#  'diagnostic center': 1.0,
#  'laboratory equipment supplier': 1.0,
#  'home theater store': 0.0,
#  'metal industry supplier': 0.0,
#  'landscaping supply store': 0.5,
#  'appliance part supplier': 0.0,
#  'vacuum cleaner store': 1.0,
#  'audio visual equipment supplier': 1.0,
#  'lawyer': 1.0,
#  'cell phone store': 0.0,
#  'bathroom supply store': 0.0,
#  'leasing service': 1.0,
#  'construction machine dealer': 0.0,
#  'dairy farm equipment supplier': 0.0,
#  'propane supplier': 0.0,
#  'legal service': 1.0,
#  'janitorial equipment supplier': 0.0,
#  'life insurance agency': 1.0,
#  'railroad contractor': 0.4,
#  'swimming pool supply store': 1.0,
#  'light bulb supplier': 1.0,
#  'linen store': 0.0,
#  'metal construction company': 1.0,
#  'local government office': 1.0,
#  'logging contractor': 0.0,
#  'machine shop': 1.0,
#  'hotel supply store': 0.0,
#  'import export company': 0.0,
#  'sewing company': 0.0,
#  'research foundation': 1.0,
#  'machinery part manufacturer': 1.0,
#  'sport accessory wholesaler': 1.0,
#  'fashion designer': 0.0,
#  'cheese manufacturer': 1.0,
#  'cheese shop': 1.0,
#  'shipping mailing': 0.0,
#  'wholesale food store': 0.0,
#  'organic food store': 0.9,
#  'pie shop': 0.0,
#  'auction house': 0.4,
#  'livestock auction house': 0.0,
#  'cotton exporter': 1.0,
#  'plastic wholesaler': 0.0,
#  'mailing service': 0.0,
#  'manufacturer': 0.0,
#  'gas station': 0.2,
#  'beer distributor': 0.0,
#  'alcoholic beverage wholesaler': 0.3,
#  'religious good store': 0.0,
#  'book wholesaler': 1.0,
#  'masonry supply store': 0.5,
#  'wholesale florist': 1.0,
#  'florist': 1.0,
#  'marine engineer': 0.0,
#  'paint store': 0.5,
#  'used auto part store': 0.0,
#  'masonry contractor': 1.0,
#  'used car dealer': 0.9,
#  'used truck dealer': 0.9,
#  'massage therapist': 1.0,
#  'material handling equipment supplier': 0.0,
#  'marina': 1.0,
#  'meat packer': 0.0,
#  'mattress store': 0.7,
#  'blind shop': 0.6,
#  'interior designer': 0.0,
#  'window treatment store': 0.4,
#  'appliance store': 0.2,
#  'health food store': 1.0,
#  'direct mail advertising': 1.0,
#  'meat wholesaler': 1.0,
#  'butcher shop deli': 0.2,
#  'italian grocery store': 0.9,
#  'market': 0.0,
#  'food service': 0.8,
#  'grocery delivery service': 0.3,
#  'wine store': 0.9,
#  'liquor store': 0.9,
#  'kiosk': 0.0,
#  'optometrist': 1.0,
#  'optician': 1.0,
#  'mechanical contractor': 1.0,
#  'mechanical engineer': 0.0,
#  'cafe': 0.0,
#  'jeweler': 1.0,
#  'leather good store': 0.6,
#  'gift shop': 1.0,
#  'craft store': 1.0,
#  'hobby store': 1.0,
#  'fabric wholesaler': 0.8,
#  'scrap metal dealer': 0.0,
#  'quilt shop': 0.9,
#  'sheet music store': 1.0,
#  'musical instrument manufacturer': 0.9,
#  'music store': 1.0,
#  'musical instrument store': 1.0,
#  'band': 0.0,
#  'bookstore': 0.0,
#  'art museum': 1.0,
#  'newsstand': 1.0,
#  'medical equipment manufacturer': 1.0,
#  'fashion accessory store': 0.9,
#  'discount store': 1.0,
#  'cemetery': 1.0,
#  'bus stop': 1.0,
#  'variety store': 1.0,
#  'thrift store': 1.0,
#  'medical group': 1.0,
#  'donation center': 0.0,
#  'pet store': 1.0,
#  'art gallery': 0.0,
#  'art dealer': 0.0,
#  'housing development': 0.0,
#  'mobile home dealer': 0.0,
#  'convenience store': 1.0,
#  'medical office': 1.0,
#  'medical technology manufacturer': 1.0,
#  'childrens furniture store': 0.4,
#  'mental health clinic': 1.0,
#  'airline': 0.0,
#  'aviation consultant': 0.0,
#  'travel agency': 1.0,
#  'travel service': 1.0,
#  'airport': 0.0,
#  'mental health service': 1.0,
#  'shipping company': 0.0,
#  'metal fabricator': 1.0,
#  'cruise line company': 0.0,
#  'towing service': 1.0,
#  'ferry terminal': 1.0,
#  'ferry service': 0.0,
#  'metal finisher': 1.0,
#  'boat tour agency': 0.9,
#  'bus company': 1.0,
#  'moving company': 0.0,
#  'moving storage service': 0.0,
#  'state department transportation': 0.0,
#  'department transportation': 0.0,
#  'handicapped transportation service': 1.0,
#  'railway service': 0.0,
#  'train station': 0.6,
#  'bus depot': 1.0,
#  'bus charter': 1.0,
#  'metal processing company': 1.0,
#  'mixed use': 0.0,
#  'motorcycle shop': 0.7,
#  'limousine service': 0.0,
#  'chauffeur service': 0.0,
#  'school bus service': 1.0,
#  'airport shuttle service': 0.0,
#  'tourist information center': 0.0,
#  'carriage ride service': 0.0,
#  'cruise agency': 0.0,
#  'tourist attraction': 0.0,
#  'ski resort': 1.0,
#  'ski area': 0.0,
#  'fixed base operator': 0.0,
#  'aircraft maintenance company': 0.0,
#  'motorsports store': 0.7,
#  'boat rental service': 1.0,
#  'utility trailer dealer': 0.0,
#  'forklift dealer': 0.0,
#  'municipal administration office': 1.0,
#  'nephrologist': 0.0,
#  'bus coach company': 1.0,
#  'shipping service': 0.0,
#  'shipping mailing service': 0.0,
#  'newspaper publisher': 1.0,
#  'shredding service': 0.0,
#  'nuclear power company': 1.0,
#  'nursing home': 1.0,
#  'medium company': 0.0,
#  'multimedia electronic book publisher': 1.0,
#  'internet marketing service': 0.0,
#  'greeting card shop': 0.9,
#  'theme park': 1.0,
#  'film production company': 0.0,
#  'obstetrician gynecologist': 1.0,
#  'movie studio': 1.0,
#  'video production service': 0.0,
#  'movie theater': 1.0,
#  'theater company': 0.0,
#  'performing art theater': 1.0,
#  'occupational safety health': 0.0,
#  'office space rental agency': 1.0,
#  'commercial real estate agency': 1.0,
#  'art school': 1.0,
#  'music publisher': 1.0,
#  'printed music publisher': 1.0,
#  'home audio store': 0.0,
#  'musician': 1.0,
#  'music management promotion': 0.0,
#  'video editing service': 0.0,
#  'office supply wholesaler': 1.0,
#  'official residence': 0.0,
#  'orthopedic clinic': 1.0,
#  'painter': 0.0,
#  'painting': 1.0,
#  'telephone company': 0.0,
#  'medium house': 1.0,
#  'paper distributor': 0.0,
#  'news service': 0.0,
#  'public library': 0.0,
#  'law library': 1.0,
#  'museum': 1.0,
#  'federal reserve bank': 1.0,
#  'credit union': 1.0,
#  'atm': 0.0,
#  'paving contractor': 1.0,
#  'mortgage lender': 1.0,
#  'investment bank': 1.0,
#  'check cashing service': 0.0,
#  'stock broker': 0.0,
#  'health consultant': 0.0,
#  'health insurance agency': 1.0,
#  'payroll service': 1.0,
#  'pediatrician': 1.0,
#  'human resource consulting': 1.0,
#  'pest control service': 0.0,
#  'pet boarding service': 1.0,
#  'pet care': 1.0,
#  'loss adjuster': 1.0,
#  'pharmaceutical company': 1.0,
#  'pharmaceutical product wholesaler': 1.0,
#  'pharmacy': 0.5,
#  'educational institution': 1.0,
#  'retirement community': 1.0,
#  'fraternal organization': 1.0,
#  'photo lab': 0.0,
#  'property investment': 0.0,
#  'photographer': 1.0,
#  'photography school': 0.0,
#  'star hotel': 1.0,
#  'convention center': 0.0,
#  'real estate appraiser': 1.0,
#  'photography service': 0.0,
#  'resort hotel': 0.7,
#  'real estate consultant': 1.0,
#  'car rental agency': 1.0,
#  'car leasing service': 1.0,
#  'ford dealer': 1.0,
#  'car finance loan company': 1.0,
#  'trailer rental service': 1.0,
#  'furniture rental service': 0.0,
#  'tuxedo shop': 0.0,
#  'dress tuxedo rental service': 1.0,
#  'wedding store': 1.0,
#  'video store': 1.0,
#  'movie rental': 0.0,
#  'photography studio': 0.0,
#  'home health care service': 1.0,
#  'skateboard shop': 1.0,
#  'event technology service': 0.0,
#  'party equipment rental service': 1.0,
#  'construction machine rental service': 1.0,
#  'audio visual equipment rental service': 0.0,
#  'shipping equipment industry': 0.0,
#  'physical therapy clinic': 1.0,
#  'plastic fabrication company': 0.2,
#  'plastic product supplier': 0.3,
#  'auto tag agency': 1.0,
#  'department motor vehicle': 0.0,
#  'notary public': 0.0,
#  'private investigator': 0.0,
#  'escrow service': 0.0,
#  'real estate agent': 1.0,
#  'playground': 0.0,
#  'plumber': 0.0,
#  'port authority': 1.0,
#  'portrait studio': 0.0,
#  'post office': 0.0,
#  'professional service': 1.0,
#  'university hospital': 0.0,
#  'public relation firm': 0.3,
#  'civil engineering company': 0.0,
#  'drafting service': 1.0,
#  'pump supplier': 1.0,
#  'interior construction contractor': 1.0,
#  'carpet cleaning service': 0.0,
#  'exhibition planner': 0.0,
#  'decal supplier': 0.0,
#  'stage lighting equipment supplier': 1.0,
#  'event management company': 0.0,
#  'radio broadcaster': 0.0,
#  'computer support service': 0.5,
#  'ravine': 0.0,
#  'employment center': 0.0,
#  'national health foundation': 0.0,
#  'real estate developer': 0.0,
#  'advertising agency': 1.0,
#  'promotional product supplier': 0.0,
#  'advertising service': 1.0,
#  'record storage facility': 0.0,
#  'fund management company': 1.0,
#  'recreation center': 1.0,
#  'bakery': 1.0,
#  'database management company': 0.0,
#  'market researcher': 0.0,
#  'recycling center': 0.0,
#  'regional government office': 1.0,
#  'rehabilitation center': 1.0,
#  'religious institution': 1.0,
#  'religious organization': 1.0,
#  'repair service': 1.0,
#  'emergency veterinarian service': 0.0,
#  'pet sitter': 0.0,
#  'research product development': 0.7,
#  'building society': 1.0,
#  'valet parking service': 1.0,
#  'nursing agency': 1.0,
#  'executive search firm': 0.0,
#  'recruiter': 0.0,
#  'temp agency': 0.0,
#  'health center': 1.0,
#  'restaurant': 0.8,
#  'roofing contractor': 1.0,
#  'sport nutrition store': 0.6,
#  'credit reporting agency': 0.0,
#  'automobile storage facility': 0.4,
#  'debt collection agency': 1.0,
#  'park': 0.0,
#  'court reporter': 0.0,
#  'bus tour agency': 0.0,
#  'tour operator': 0.0,
#  'convention information bureau': 0.0,
#  'balloon ride tour agency': 0.9,
#  'security guard service': 1.0,
#  'locksmith': 1.0,
#  'commercial cleaning service': 0.0,
#  'blast cleaning service': 0.0,
#  'conference center': 0.0,
#  'safety equipment supplier': 0.0,
#  'garbage dump': 1.0,
#  'sanitation service': 0.0,
#  'garbage dump service': 0.0,
#  'environmental health service': 0.0,
#  'portable toilet supplier': 0.0,
#  'public work department': 0.0,
#  'school district office': 1.0,
#  'sailmaker': 0.0,
#  'community college': 1.0,
#  'salvage yard': 0.0,
#  'business school': 1.0,
#  'trade school': 1.0,
#  'private university': 1.0,
#  'computer training school': 1.0,
#  'school supply store': 0.0,
#  'screen printer': 0.4,
#  'medium consultant': 1.0,
#  'beauty school': 1.0,
#  'flight school': 1.0,
#  'seaport': 0.0,
#  'security system supplier': 0.0,
#  'middle school': 1.0,
#  'nonprofit': 0.0,
#  'shooting range': 0.0,
#  'soccer club': 1.0,
#  'camp': 0.8,
#  'diving contractor': 0.0,
#  'language school': 1.0,
#  'english language school': 1.0,
#  'preschool': 1.0,
#  'self storage facility': 0.0,
#  'semi conductor supplier': 1.0,
#  'driving school': 1.0,
#  'trucking school': 1.0,
#  'senior citizen center': 1.0,
#  'service': 0.0,
#  'childrens hospital': 1.0,
#  'dental supply store': 0.0,
#  'shipyard': 0.2,
#  'orthodox synagogue': 1.0,
#  'short term apartment rental agency': 1.0,
#  'nutritionist': 1.0,
#  'ophthalmologist': 0.0,
#  'ophthalmology clinic': 1.0,
#  'social service organization': 1.0,
#  'social welfare center': 1.0,
#  'solar energy company': 1.0,
#  'solar energy equipment supplier': 1.0,
#  'special education school': 1.0,
#  'podiatrist': 1.0,
#  'reproductive health clinic': 1.0,
#  'sporting good store': 1.0,
#  'dialysis center': 1.0,
#  'sport complex': 1.0,
#  'wellness program': 0.0,
#  'sportswear store': 1.0,
#  'private hospital': 0.0,
#  'radiologist': 1.0,
#  'medical diagnostic imaging center': 1.0,
#  'ray lab': 1.0,
#  'blood bank': 0.9,
#  'stainless steel plant': 1.0,
#  'state agency': 1.0,
#  'heliport': 0.0,
#  'health care company': 1.0,
#  'psychiatric hospital': 1.0,
#  'state government office': 1.0,
#  'medical institution': 1.0,
#  'steel construction company': 1.0,
#  'cleaning service': 0.0,
#  ...}

# %%
# IMPORT INVERTED_INDEXES
with open(r'assets/rocchio-pre.json', 'w') as f:
    json.dump(calc_pre_rec_at_n(ret_docs_dic, queries_dic, n=-1)[0], f)
    
# IMPORT INVERTED_INDEXES
with open(r'assets/rocchio-re.json', 'w') as f:
    json.dump(calc_pre_rec_at_n(ret_docs_dic, queries_dic, n=-1)[1], f)

# %%
calc_pre_rec_at_n(ret_docs_dic, queries_dic, n=-1)[1]
# Out:
# {'home improvement store': 0.091,
#  'diesel fuel supplier': 0.0,
#  'church': 0.0,
#  'farm': 0.156,
#  'seed supplier': 0.0,
#  'accountant': 0.204,
#  'trucking company': 0.12,
#  'exporter': 0.244,
#  'grain elevator': 0.0,
#  'popcorn store': 0.205,
#  'agricultural service': 0.0,
#  'warehouse': 0.571,
#  'agricultural production': 0.156,
#  'ranch': 0.156,
#  'holding company': 1.0,
#  'farm equipment supplier': 0.0,
#  'store': 0.455,
#  'grocery store': 0.205,
#  'rice mill': 0.137,
#  'food product supplier': 0.0,
#  'accounting firm': 0.204,
#  'produce market': 0.068,
#  'pet supply store': 0.455,
#  'wholesaler': 0.141,
#  'produce wholesaler': 0.141,
#  'distribution service': 0.082,
#  'crop grower': 0.156,
#  'addiction treatment center': 0.256,
#  'natural good store': 0.0,
#  'orchard': 0.156,
#  'lumber store': 0.0,
#  'mine': 0.357,
#  'transportation service': 0.2,
#  'investment company': 0.244,
#  'fruit wholesaler': 0.141,
#  'real estate agency': 0.417,
#  'event venue': 0.0,
#  'frozen dessert supplier': 0.137,
#  'wine wholesaler importer': 0.141,
#  'winery': 0.096,
#  'aerospace company': 0.053,
#  'cold storage facility': 0.571,
#  'employment agency': 0.0,
#  'plant nursery': 0.0,
#  'air conditioning contractor': 0.323,
#  'air conditioning repair service': 0.0,
#  'fruit vegetable wholesaler': 0.0,
#  'aircraft rental service': 0.417,
#  'monastery': 0.204,
#  'allergist': 0.256,
#  'herb shop': 0.0,
#  'aluminum supplier': 0.053,
#  'ambulance service': 0.0,
#  'wholesale plant nursery': 0.141,
#  'amusement machine supplier': 0.4,
#  'animal hospital': 0.0,
#  'farmer market': 0.0,
#  'vaporizer store': 0.455,
#  'cigar shop': 0.409,
#  'tobacco shop': 0.227,
#  'well drilling contractor': 0.0,
#  'library': 0.323,
#  'apartment building': 0.0,
#  'apartment rental agency': 0.417,
#  'dairy farm': 0.156,
#  'architect': 0.204,
#  'organic farm': 0.156,
#  'architectural designer': 0.204,
#  'architecture firm': 0.0,
#  'livestock producer': 0.0,
#  'dairy supplier': 0.0,
#  'biotechnology company': 0.082,
#  'artist': 0.4,
#  'egg supplier': 0.156,
#  'poultry farm': 0.0,
#  'chicken hatchery': 0.156,
#  'art organization': 0.4,
#  'association organization': 0.204,
#  'food store': 0.205,
#  'deli': 0.0,
#  'bank': 0.244,
#  'fish processing': 0.0,
#  'fish farm': 0.156,
#  'seafood wholesaler': 0.141,
#  'tropical fish store': 0.455,
#  'non profit organization': 0.204,
#  'economic development agency': 0.345,
#  'seafood market': 0.205,
#  'honey farm': 0.156,
#  'horse breeder': 0.0,
#  'asphalt contractor': 0.323,
#  'livestock dealer': 0.0,
#  'department store': 0.455,
#  'mill': 0.103,
#  'atv dealer': 0.205,
#  'audio visual consultant': 0.053,
#  'pallet supplier': 0.103,
#  'wood supplier': 0.0,
#  'hardware store': 0.0,
#  'furniture wholesaler': 0.0,
#  'auditor': 0.204,
#  'oil natural gas company': 0.357,
#  'auto body shop': 0.204,
#  'boat repair shop': 0.0,
#  'association': 0.204,
#  'railing contractor': 0.0,
#  'publisher': 0.323,
#  'pond supply store': 0.0,
#  'agriculture cooperative': 0.0,
#  'printing equipment supplier': 0.053,
#  'auto insurance agency': 0.244,
#  'alternative fuel station': 0.159,
#  'auto part manufacturer': 0.0,
#  'foundation': 0.204,
#  'fertilizer supplier': 0.103,
#  'farming company': 0.156,
#  'finance broker': 0.244,
#  'agricultural cooperative': 0.0,
#  'fire station': 0.0,
#  'environmental consultant': 0.204,
#  'civil engineer': 0.323,
#  'fire protection service': 0.0,
#  'gas company': 0.0,
#  'oilfield': 0.0,
#  'banquet hall': 0.533,
#  'mining company': 0.357,
#  'coalfield': 0.0,
#  'steel fabricator': 0.053,
#  'quarry': 0.357,
#  'gold mining company': 0.357,
#  'high rise building': 0.323,
#  'basketball club': 0.4,
#  'gold dealer': 0.0,
#  'battery manufacturer': 0.053,
#  'electric utility company': 0.0,
#  'environmental program': 0.0,
#  'office': 0.0,
#  'stone supplier': 0.0,
#  'aggregate supplier': 0.0,
#  'sand gravel supplier': 0.0,
#  'building material supplier': 0.136,
#  'beauty supply store': 0.114,
#  'crushed stone supplier': 0.0,
#  'rock shop': 0.0,
#  'road construction company': 0.323,
#  'marketing consultant': 0.204,
#  'blood testing service': 0.204,
#  'contractor': 0.323,
#  'excavating contractor': 0.323,
#  'asphalt mixing plant': 0.103,
#  'ready mix concrete supplier': 0.103,
#  'sand plant': 0.0,
#  'bmw dealer': 0.227,
#  'bookbinder': 0.103,
#  'garden center': 0.136,
#  'abrasive supplier': 0.103,
#  'granite supplier': 0.0,
#  'drilling contractor': 0.0,
#  'bpo company': 0.227,
#  'oil gas exploration service': 0.357,
#  'building complex': 0.0,
#  'construction equipment supplier': 0.0,
#  'mining equipment': 0.0,
#  'bus ticket agency': 0.0,
#  'business center': 0.0,
#  'skyscraper': 0.0,
#  'software company': 0.323,
#  'business development service': 0.143,
#  'business management consultant': 0.0,
#  'cabinet maker': 0.053,
#  'call center': 0.0,
#  'cancer treatment center': 0.256,
#  'power plant consultant': 0.0,
#  'business park': 0.0,
#  'petroleum product company': 0.0,
#  'parking lot': 0.204,
#  'water utility company': 0.714,
#  'car repair maintenance': 0.204,
#  'water treatment plant': 0.714,
#  'car service': 0.204,
#  'cattle market': 0.0,
#  'sewage disposal service': 0.714,
#  'certified public accountant': 0.0,
#  'government office': 0.345,
#  'charity': 0.204,
#  'air conditioning system supplier': 0.0,
#  'chemical industry': 0.103,
#  'chemical manufacturer': 0.103,
#  'title company': 0.0,
#  'chemical plant': 0.103,
#  'property management company': 0.0,
#  'custom home builder': 0.323,
#  'window installation service': 0.0,
#  'fire damage restoration service': 0.0,
#  'equipment rental agency': 0.417,
#  'chemical wholesaler': 0.0,
#  'financial planner': 0.244,
#  'telecommunication service provider': 0.323,
#  'energy equipment solution': 0.0,
#  'chiropractor': 0.256,
#  'steel distributor': 0.0,
#  'city government office': 0.345,
#  'crane service': 0.0,
#  'garage door supplier': 0.0,
#  'industrial door supplier': 0.047,
#  'city town hall': 0.0,
#  'clothing wholesaler': 0.0,
#  'coin operated laundry equipment supplier': 0.204,
#  'metal supplier': 0.0,
#  'glass shop': 0.0,
#  'college': 0.588,
#  'siding contractor': 0.323,
#  'commercial printer': 0.0,
#  'storage facility': 0.571,
#  'communication tower': 0.0,
#  'janitorial service': 0.0,
#  'computer consultant': 0.0,
#  'fire protection system supplier': 0.0,
#  'elevator service': 0.0,
#  'industrial equipment supplier': 0.0,
#  'dry wall contractor': 0.323,
#  'insulation contractor': 0.323,
#  'concrete contractor': 0.323,
#  'scaffolding rental service': 0.417,
#  'construction company': 0.323,
#  'flooring store': 0.227,
#  'flooring contractor': 0.323,
#  'tile contractor': 0.323,
#  'tile manufacturer': 0.0,
#  'glass mirror shop': 0.0,
#  'construction material wholesaler': 0.141,
#  'gutter cleaning service': 0.0,
#  'sheet metal contractor': 0.053,
#  'consultant': 0.204,
#  'container service': 0.0,
#  'septic system service': 0.0,
#  'corporate campus': 1.0,
#  'water damage restoration service': 0.0,
#  'welder': 0.0,
#  'corporate office': 1.0,
#  'animal': 0.156,
#  'animal feed store': 0.0,
#  'animal protection organization': 0.0,
#  'brewing supply store': 0.0,
#  'cosmetic store': 0.114,
#  'county government office': 0.345,
#  'sugar factory': 0.137,
#  'confectionery wholesaler': 0.141,
#  'financial institution': 0.0,
#  'candy store': 0.205,
#  'confectionery': 0.0,
#  'chocolate factory': 0.137,
#  'chocolate shop': 0.137,
#  'courier service': 0.429,
#  'coworking space': 0.0,
#  'frozen food manufacturer': 0.137,
#  'beverage distributor': 0.0,
#  'agricultural organization': 0.0,
#  'dairy store': 0.0,
#  'dairy': 0.109,
#  'ice cream shop': 0.096,
#  'medical laboratory': 0.256,
#  'demolition contractor': 0.323,
#  'meat processor': 0.123,
#  'fmcg manufacturer': 0.0,
#  'garbage collection service': 0.227,
#  'wholesale bakery': 0.137,
#  'dentist': 0.256,
#  'dessert shop': 0.0,
#  'cupcake shop': 0.0,
#  'nut store': 0.205,
#  'wholesale grocer': 0.141,
#  'design engineer': 0.204,
#  'business business service': 0.227,
#  'condiment supplier': 0.137,
#  'digital printing service': 0.041,
#  'culinary school': 0.588,
#  'importer': 0.0,
#  'bottled water supplier': 0.0,
#  'coffee roaster': 0.137,
#  'packaging supply store': 0.0,
#  'ice supplier': 0.096,
#  'brewery': 0.096,
#  'winemaking company': 0.0,
#  'distillery': 0.096,
#  'disability service support organisation': 0.0,
#  'district government office': 0.345,
#  'air filter supplier': 0.0,
#  'tire shop': 0.159,
#  'fastener supplier': 0.053,
#  'fabric product manufacturer': 0.137,
#  'textile': 0.137,
#  'textile exporter': 0.137,
#  'textile engineer': 0.137,
#  'fabric store': 0.455,
#  'knit shop': 0.137,
#  'doctor': 0.256,
#  'lamination service': 0.0,
#  'plastic resin manufacturer': 0.031,
#  'carpet manufacturer': 0.137,
#  'upholstery shop': 0.204,
#  'business administration service': 0.0,
#  'furniture store': 0.091,
#  'dry cleaner': 0.0,
#  'packaging company': 0.227,
#  'duty free store': 0.455,
#  'commerce service': 0.0,
#  'cable company': 0.0,
#  'education': 0.588,
#  'outlet store': 0.455,
#  'lingerie store': 0.227,
#  'clothes fabric manufacturer': 0.137,
#  'education center': 0.0,
#  'uniform store': 0.205,
#  'men clothing store': 0.205,
#  'clothing store': 0.205,
#  'woman clothing store': 0.205,
#  'western apparel store': 0.0,
#  'costume store': 0.0,
#  'game store': 0.455,
#  'hat shop': 0.045,
#  'leather good manufacturer': 0.114,
#  'educational consultant': 0.588,
#  'leather exporter': 0.055,
#  'shoe store': 0.091,
#  'boutique': 0.0,
#  'leather wholesaler': 0.136,
#  'handbag shop': 0.055,
#  'electronics store': 0.045,
#  'luggage store': 0.136,
#  'building material store': 0.136,
#  'saw mill': 0.103,
#  'electrical engineer': 0.0,
#  'deck builder': 0.323,
#  'concrete product supplier': 0.103,
#  'plywood supplier': 0.103,
#  'electrical installation service': 0.0,
#  'truss manufacturer': 0.0,
#  'door supplier': 0.103,
#  'wood laminate flooring supplier': 0.103,
#  'aircraft supply store': 0.0,
#  'modular home builder': 0.0,
#  'portable building manufacturer': 0.011,
#  'modular home dealer': 0.0,
#  'mulch supplier': 0.0,
#  'electrician': 0.0,
#  'paper mill': 0.103,
#  'energy supplier': 0.714,
#  'engineer': 0.0,
#  'print shop': 0.041,
#  'custom label printer': 0.041,
#  'marketing': 0.184,
#  'marketing agency': 0.0,
#  'engineering consultant': 0.204,
#  'entertainer': 0.4,
#  'envelope supplier': 0.0,
#  'oil refinery': 0.052,
#  'recording studio': 0.323,
#  'environment renewable natural resource': 0.0,
#  'finishing material supplier': 0.0,
#  'event ticket seller': 0.0,
#  'waterproofing company': 0.0,
#  'auto part store': 0.0,
#  'heating oil supplier': 0.182,
#  'family practice physician': 0.256,
#  'machining manufacturer': 0.0,
#  'industrial gas supplier': 0.0,
#  'welding supply store': 0.0,
#  'dry ice supplier': 0.123,
#  'private equity firm': 0.0,
#  'family service center': 0.256,
#  'federal government office': 0.345,
#  'vitamin supplement store': 0.114,
#  'feed manufacturer': 0.0,
#  'medical equipment supplier': 0.0,
#  'medical supply store': 0.0,
#  'medical clinic': 0.256,
#  'research institute': 0.204,
#  'biochemical supplier': 0.0,
#  'fiber optic product supplier': 0.0,
#  'paint manufacturer': 0.0,
#  'equipment supplier': 0.0,
#  'food': 0.0,
#  'pipe supplier': 0.053,
#  'oil field equipment supplier': 0.016,
#  'food broker': 0.0,
#  'food manufacturer': 0.0,
#  'food processing company': 0.0,
#  'fence supply store': 0.114,
#  'food producer': 0.0,
#  'forestry service': 0.156,
#  'foundry': 0.053,
#  'wholesale jeweler': 0.141,
#  'cookie shop': 0.0,
#  'truck rental agency': 0.417,
#  'fruit vegetable processing': 0.137,
#  'kitchen supply store': 0.0,
#  'hydraulic equipment supplier': 0.0,
#  'irrigation equipment supplier': 0.0,
#  'bearing supplier': 0.053,
#  'metallurgy company': 0.0,
#  'plastic injection molding service': 0.0,
#  'general contractor': 0.323,
#  'general hospital': 0.256,
#  'tool manufacturer': 0.026,
#  'industrial design company': 0.0,
#  'hyundai dealer': 0.0,
#  'glass industry': 0.103,
#  'polymer supplier': 0.0,
#  'printing equipment supply': 0.0,
#  'toner cartridge supplier': 0.103,
#  'printer repair service': 0.204,
#  'fuel supplier': 0.0,
#  'glass manufacturer': 0.103,
#  'plastic bag supplier': 0.021,
#  'glassware manufacturer': 0.0,
#  'polythene plastic sheeting supplier': 0.021,
#  'pvc industry': 0.0,
#  'countertop store': 0.227,
#  'cabinet store': 0.227,
#  'fiberglass supplier': 0.0,
#  'golf cart dealer': 0.227,
#  'auto repair shop': 0.204,
#  'hose supplier': 0.01,
#  'rubber product supplier': 0.031,
#  'automotive': 0.0,
#  'commercial refrigerator supplier': 0.0,
#  'golf club': 0.4,
#  'golf course': 0.4,
#  'green energy supplier': 0.714,
#  'greenhouse': 0.156,
#  'auto glass shop': 0.0,
#  'lighting manufacturer': 0.053,
#  'cement manufacturer': 0.103,
#  'brick manufacturer': 0.103,
#  'natural stone supplier': 0.0,
#  'gym': 0.4,
#  'marble supplier': 0.0,
#  'corporate gift supplier': 0.455,
#  'shipbuilding repair company': 0.0,
#  'construction maintenance office': 0.323,
#  'boiler manufacturer': 0.0,
#  'container supplier': 0.0,
#  'home construction': 0.323,
#  'health': 0.256,
#  'heart hospital': 0.256,
#  'spring supplier': 0.053,
#  'electric utility manufacturer': 0.0,
#  'aircraft manufacturer': 0.053,
#  'metal heat treating service': 0.053,
#  'plating service': 0.0,
#  'automation company': 0.0,
#  'heating contractor': 0.323,
#  'plumbing supply store': 0.0,
#  'gun shop': 0.409,
#  'ammunition supplier': 0.053,
#  'pipe manufacturer': 0.053,
#  'school': 0.588,
#  'fire protection equipment supplier': 0.0,
#  'agricultural machinery manufacturer': 0.053,
#  'lawn mower store': 0.205,
#  'lawn irrigation equipment supplier': 0.0,
#  'financial consultant': 0.244,
#  'helicopter charter': 0.2,
#  'packaging machinery': 0.053,
#  'historical landmark': 0.4,
#  'electronics manufacturer': 0.0,
#  'graphic designer': 0.0,
#  'eye care center': 0.256,
#  'optical product manufacturer': 0.0,
#  'image consultant': 0.184,
#  'cleaning product supplier': 0.0,
#  'fireplace store': 0.0,
#  'home builder': 0.323,
#  'tool die shop': 0.053,
#  'metal stamping service': 0.053,
#  'environmental organization': 0.204,
#  'food processing equipment': 0.0,
#  'loan agency': 0.244,
#  'power plant equipment supplier': 0.0,
#  'home good store': 0.091,
#  'engine rebuilding service': 0.204,
#  'air compressor supplier': 0.021,
#  'honda dealer': 0.227,
#  'elevator manufacturer': 0.0,
#  'crane dealer': 0.0,
#  'crane rental agency': 0.417,
#  'compound building': 0.0,
#  'tractor dealer': 0.0,
#  'furnace part supplier': 0.0,
#  'heating equipment supplier': 0.0,
#  'pneumatic tool supplier': 0.0,
#  'truck stop': 0.091,
#  'computer hardware manufacturer': 0.053,
#  'satellite communication service': 0.323,
#  'hospital': 0.256,
#  'electronics company': 0.0,
#  'electronic part supplier': 0.0,
#  'hvac contractor': 0.323,
#  'industrial engineer': 0.0,
#  'contact lens supplier': 0.0,
#  'information service': 0.323,
#  'building': 0.323,
#  'water work equipment supplier': 0.0,
#  'measuring instrument supplier': 0.053,
#  'scientific equipment supplier': 0.0,
#  'medical center': 0.256,
#  'watch manufacturer': 0.141,
#  'corporate entertainment service': 0.0,
#  'insurance': 0.244,
#  'record company': 0.0,
#  'video duplication service': 0.0,
#  'insurance agency': 0.244,
#  'lighting store': 0.053,
#  'lighting wholesaler': 0.053,
#  'entertainment agency': 0.4,
#  'insurance broker': 0.244,
#  'electrical equipment supplier': 0.0,
#  'electric motor store': 0.0,
#  'railroad company': 0.12,
#  'electrical supply store': 0.0,
#  'insurance company': 0.244,
#  'factory equipment supplier': 0.0,
#  'investment service': 0.244,
#  'laser equipment supplier': 0.053,
#  'executive suite rental agency': 0.0,
#  'truck dealer': 0.0,
#  'motor vehicle dealer': 0.159,
#  'car dealer': 0.205,
#  'truck topper supplier': 0.0,
#  'police supply store': 0.455,
#  'iron steel contractor': 0.323,
#  'fire department equipment supplier': 0.0,
#  'towing equipment provider': 0.2,
#  'logistics service': 0.204,
#  'trailer manufacturer': 0.053,
#  'trailer dealer': 0.0,
#  'dealer': 0.227,
#  'auto spring shop': 0.0,
#  'auto upholsterer': 0.0,
#  'auto body part supplier': 0.159,
#  'car factory': 0.0,
#  'freight forwarding service': 0.18,
#  'brake shop': 0.184,
#  'railroad equipment supplier': 0.0,
#  'jewelry equipment supplier': 0.053,
#  'boat builder': 0.011,
#  'ship building': 0.011,
#  'marine supply store': 0.114,
#  'boat dealer': 0.159,
#  'kawasaki motorcycle dealer': 0.205,
#  'knife manufacturing': 0.053,
#  'labor union': 0.204,
#  'furniture maker': 0.053,
#  'banking finance': 0.244,
#  'furniture manufacturer': 0.053,
#  'logistics': 0.204,
#  'massage supply store': 0.0,
#  'telecommunication equipment supplier': 0.0,
#  'baby store': 0.227,
#  'molding supplier': 0.0,
#  'office equipment supplier': 0.0,
#  'office furniture store': 0.053,
#  'store equipment supplier': 0.0,
#  'laboratory': 0.0,
#  'health beauty shop': 0.0,
#  'learning center': 0.588,
#  'dental laboratory': 0.053,
#  'land surveyor': 0.0,
#  'educational supply store': 0.455,
#  'jewelry store': 0.0,
#  'playground equipment supplier': 0.0,
#  'outdoor sport store': 0.455,
#  'toy store': 0.455,
#  'security service': 0.0,
#  'sign shop': 0.053,
#  'office supply store': 0.455,
#  'landscaper': 0.0,
#  'gasket manufacturer': 0.0,
#  'piano maker': 0.0,
#  'piano store': 0.455,
#  'funeral home': 0.0,
#  'monument': 0.0,
#  'book publisher': 0.323,
#  'wig shop': 0.045,
#  'laundromat': 0.204,
#  'auto wrecker': 0.0,
#  'auto part market': 0.159,
#  'jeep dealer': 0.227,
#  'restaurant supply store': 0.0,
#  'roofing supply store': 0.0,
#  'law firm': 0.0,
#  'building material market': 0.136,
#  'camera store': 0.0,
#  'lawn care service': 0.0,
#  'computer security service': 0.0,
#  'computer store': 0.0,
#  'design agency': 0.0,
#  'diagnostic center': 0.256,
#  'laboratory equipment supplier': 0.053,
#  'home theater store': 0.0,
#  'metal industry supplier': 0.0,
#  'landscaping supply store': 0.114,
#  'appliance part supplier': 0.0,
#  'vacuum cleaner store': 0.227,
#  'audio visual equipment supplier': 0.053,
#  'lawyer': 0.204,
#  'cell phone store': 0.0,
#  'bathroom supply store': 0.0,
#  'leasing service': 0.417,
#  'construction machine dealer': 0.0,
#  'dairy farm equipment supplier': 0.0,
#  'propane supplier': 0.0,
#  'legal service': 0.204,
#  'janitorial equipment supplier': 0.0,
#  'life insurance agency': 0.244,
#  'railroad contractor': 0.08,
#  'swimming pool supply store': 0.455,
#  'light bulb supplier': 0.053,
#  'linen store': 0.0,
#  'metal construction company': 0.053,
#  'local government office': 0.345,
#  'logging contractor': 0.0,
#  'machine shop': 0.053,
#  'hotel supply store': 0.0,
#  'import export company': 0.0,
#  'sewing company': 0.0,
#  'research foundation': 0.204,
#  'machinery part manufacturer': 0.053,
#  'sport accessory wholesaler': 0.141,
#  'fashion designer': 0.0,
#  'cheese manufacturer': 0.137,
#  'cheese shop': 0.137,
#  'shipping mailing': 0.0,
#  'wholesale food store': 0.0,
#  'organic food store': 0.205,
#  'pie shop': 0.0,
#  'auction house': 0.182,
#  'livestock auction house': 0.0,
#  'cotton exporter': 0.156,
#  'plastic wholesaler': 0.0,
#  'mailing service': 0.0,
#  'manufacturer': 0.0,
#  'gas station': 0.045,
#  'beer distributor': 0.0,
#  'alcoholic beverage wholesaler': 0.042,
#  'religious good store': 0.0,
#  'book wholesaler': 0.141,
#  'masonry supply store': 0.114,
#  'wholesale florist': 0.141,
#  'florist': 0.455,
#  'marine engineer': 0.0,
#  'paint store': 0.114,
#  'used auto part store': 0.0,
#  'masonry contractor': 0.323,
#  'used car dealer': 0.205,
#  'used truck dealer': 0.205,
#  'massage therapist': 0.256,
#  'material handling equipment supplier': 0.0,
#  'marina': 0.4,
#  'meat packer': 0.0,
#  'mattress store': 0.159,
#  'blind shop': 0.032,
#  'interior designer': 0.0,
#  'window treatment store': 0.091,
#  'appliance store': 0.045,
#  'health food store': 0.227,
#  'direct mail advertising': 0.204,
#  'meat wholesaler': 0.141,
#  'butcher shop deli': 0.045,
#  'italian grocery store': 0.205,
#  'market': 0.0,
#  'food service': 0.533,
#  'grocery delivery service': 0.429,
#  'wine store': 0.205,
#  'liquor store': 0.205,
#  'kiosk': 0.0,
#  'optometrist': 0.256,
#  'optician': 0.256,
#  'mechanical contractor': 0.323,
#  'mechanical engineer': 0.0,
#  'cafe': 0.0,
#  'jeweler': 0.141,
#  'leather good store': 0.136,
#  'gift shop': 0.455,
#  'craft store': 0.455,
#  'hobby store': 0.455,
#  'fabric wholesaler': 0.113,
#  'scrap metal dealer': 0.0,
#  'quilt shop': 0.409,
#  'sheet music store': 0.455,
#  'musical instrument manufacturer': 0.047,
#  'music store': 0.455,
#  'musical instrument store': 0.455,
#  'band': 0.0,
#  'bookstore': 0.0,
#  'art museum': 0.4,
#  'newsstand': 0.455,
#  'medical equipment manufacturer': 0.053,
#  'fashion accessory store': 0.205,
#  'discount store': 0.455,
#  'cemetery': 0.204,
#  'bus stop': 0.2,
#  'variety store': 0.455,
#  'thrift store': 0.455,
#  'medical group': 0.256,
#  'donation center': 0.0,
#  'pet store': 0.455,
#  'art gallery': 0.0,
#  'art dealer': 0.0,
#  'housing development': 0.0,
#  'mobile home dealer': 0.0,
#  'convenience store': 0.227,
#  'medical office': 0.256,
#  'medical technology manufacturer': 0.053,
#  'childrens furniture store': 0.091,
#  'mental health clinic': 0.256,
#  'airline': 0.0,
#  'aviation consultant': 0.0,
#  'travel agency': 0.227,
#  'travel service': 0.227,
#  'airport': 0.0,
#  'mental health service': 0.256,
#  'shipping company': 0.0,
#  'metal fabricator': 0.053,
#  'cruise line company': 0.0,
#  'towing service': 0.2,
#  'ferry terminal': 0.2,
#  'ferry service': 0.0,
#  'metal finisher': 0.053,
#  'boat tour agency': 0.18,
#  'bus company': 0.2,
#  'moving company': 0.0,
#  'moving storage service': 0.0,
#  'state department transportation': 0.0,
#  'department transportation': 0.0,
#  'handicapped transportation service': 0.2,
#  'railway service': 0.0,
#  'train station': 0.12,
#  'bus depot': 0.2,
#  'bus charter': 0.2,
#  'metal processing company': 0.053,
#  'mixed use': 0.0,
#  'motorcycle shop': 0.159,
#  'limousine service': 0.0,
#  'chauffeur service': 0.0,
#  'school bus service': 0.2,
#  'airport shuttle service': 0.0,
#  'tourist information center': 0.0,
#  'carriage ride service': 0.0,
#  'cruise agency': 0.0,
#  'tourist attraction': 0.0,
#  'ski resort': 0.4,
#  'ski area': 0.0,
#  'fixed base operator': 0.0,
#  'aircraft maintenance company': 0.0,
#  'motorsports store': 0.159,
#  'boat rental service': 0.417,
#  'utility trailer dealer': 0.0,
#  'forklift dealer': 0.0,
#  'municipal administration office': 0.345,
#  'nephrologist': 0.0,
#  'bus coach company': 0.2,
#  'shipping service': 0.0,
#  'shipping mailing service': 0.0,
#  'newspaper publisher': 0.323,
#  'shredding service': 0.0,
#  'nuclear power company': 0.714,
#  'nursing home': 0.256,
#  'medium company': 0.0,
#  'multimedia electronic book publisher': 0.323,
#  'internet marketing service': 0.0,
#  'greeting card shop': 0.409,
#  'theme park': 0.4,
#  'film production company': 0.0,
#  'obstetrician gynecologist': 0.256,
#  'movie studio': 0.323,
#  'video production service': 0.0,
#  'movie theater': 0.323,
#  'theater company': 0.0,
#  'performing art theater': 0.4,
#  'occupational safety health': 0.0,
#  'office space rental agency': 0.417,
#  'commercial real estate agency': 0.417,
#  'art school': 0.588,
#  'music publisher': 0.323,
#  'printed music publisher': 0.323,
#  'home audio store': 0.0,
#  'musician': 0.4,
#  'music management promotion': 0.0,
#  'video editing service': 0.0,
#  'office supply wholesaler': 0.141,
#  'official residence': 0.0,
#  'orthopedic clinic': 0.256,
#  'painter': 0.0,
#  'painting': 0.323,
#  'telephone company': 0.0,
#  'medium house': 0.204,
#  'paper distributor': 0.0,
#  'news service': 0.0,
#  'public library': 0.0,
#  'law library': 0.323,
#  'museum': 0.4,
#  'federal reserve bank': 0.244,
#  'credit union': 0.244,
#  'atm': 0.0,
#  'paving contractor': 0.323,
#  'mortgage lender': 0.244,
#  'investment bank': 0.244,
#  'check cashing service': 0.0,
#  'stock broker': 0.0,
#  'health consultant': 0.0,
#  'health insurance agency': 0.244,
#  'payroll service': 0.204,
#  'pediatrician': 0.256,
#  'human resource consulting': 0.204,
#  'pest control service': 0.0,
#  'pet boarding service': 0.204,
#  'pet care': 0.204,
#  'loss adjuster': 0.244,
#  'pharmaceutical company': 0.103,
#  'pharmaceutical product wholesaler': 0.141,
#  'pharmacy': 0.114,
#  'educational institution': 0.588,
#  'retirement community': 0.256,
#  'fraternal organization': 0.204,
#  'photo lab': 0.0,
#  'property investment': 0.0,
#  'photographer': 0.204,
#  'photography school': 0.0,
#  'star hotel': 0.667,
#  'convention center': 0.0,
#  'real estate appraiser': 0.417,
#  'photography service': 0.0,
#  'resort hotel': 0.467,
#  'real estate consultant': 0.417,
#  'car rental agency': 0.417,
#  'car leasing service': 0.417,
#  'ford dealer': 0.227,
#  'car finance loan company': 0.244,
#  'trailer rental service': 0.417,
#  'furniture rental service': 0.0,
#  'tuxedo shop': 0.0,
#  'dress tuxedo rental service': 0.417,
#  'wedding store': 0.227,
#  'video store': 0.227,
#  'movie rental': 0.0,
#  'photography studio': 0.0,
#  'home health care service': 0.256,
#  'skateboard shop': 0.053,
#  'event technology service': 0.0,
#  'party equipment rental service': 0.417,
#  'construction machine rental service': 0.417,
#  'audio visual equipment rental service': 0.0,
#  'shipping equipment industry': 0.0,
#  'physical therapy clinic': 0.256,
#  'plastic fabrication company': 0.021,
#  'plastic product supplier': 0.031,
#  'auto tag agency': 0.345,
#  'department motor vehicle': 0.0,
#  'notary public': 0.0,
#  'private investigator': 0.0,
#  'escrow service': 0.0,
#  'real estate agent': 0.417,
#  'playground': 0.0,
#  'plumber': 0.0,
#  'port authority': 0.2,
#  'portrait studio': 0.0,
#  'post office': 0.0,
#  'professional service': 0.204,
#  'university hospital': 0.0,
#  'public relation firm': 0.061,
#  'civil engineering company': 0.0,
#  'drafting service': 0.204,
#  'pump supplier': 0.053,
#  'interior construction contractor': 0.323,
#  'carpet cleaning service': 0.0,
#  'exhibition planner': 0.0,
#  'decal supplier': 0.0,
#  'stage lighting equipment supplier': 0.053,
#  'event management company': 0.0,
#  'radio broadcaster': 0.0,
#  'computer support service': 0.102,
#  'ravine': 0.0,
#  'employment center': 0.0,
#  'national health foundation': 0.0,
#  'real estate developer': 0.0,
#  'advertising agency': 0.204,
#  'promotional product supplier': 0.0,
#  'advertising service': 0.204,
#  'record storage facility': 0.0,
#  'fund management company': 0.244,
#  'recreation center': 0.4,
#  'bakery': 0.137,
#  'database management company': 0.0,
#  'market researcher': 0.0,
#  'recycling center': 0.0,
#  'regional government office': 0.345,
#  'rehabilitation center': 0.256,
#  'religious institution': 0.204,
#  'religious organization': 0.204,
#  'repair service': 0.204,
#  'emergency veterinarian service': 0.0,
#  'pet sitter': 0.0,
#  'research product development': 0.143,
#  'building society': 0.323,
#  'valet parking service': 0.204,
#  'nursing agency': 0.256,
#  'executive search firm': 0.0,
#  'recruiter': 0.0,
#  'temp agency': 0.0,
#  'health center': 0.256,
#  'restaurant': 0.533,
#  'roofing contractor': 0.323,
#  'sport nutrition store': 0.136,
#  'credit reporting agency': 0.0,
#  'automobile storage facility': 0.571,
#  'debt collection agency': 0.227,
#  'park': 0.0,
#  'court reporter': 0.0,
#  'bus tour agency': 0.0,
#  'tour operator': 0.0,
#  'convention information bureau': 0.0,
#  'balloon ride tour agency': 0.18,
#  'security guard service': 0.227,
#  'locksmith': 0.227,
#  'commercial cleaning service': 0.0,
#  'blast cleaning service': 0.0,
#  'conference center': 0.0,
#  'safety equipment supplier': 0.0,
#  'garbage dump': 0.227,
#  'sanitation service': 0.0,
#  'garbage dump service': 0.0,
#  'environmental health service': 0.0,
#  'portable toilet supplier': 0.0,
#  'public work department': 0.0,
#  'school district office': 0.588,
#  'sailmaker': 0.0,
#  'community college': 0.588,
#  'salvage yard': 0.0,
#  'business school': 0.588,
#  'trade school': 0.588,
#  'private university': 0.588,
#  'computer training school': 0.588,
#  'school supply store': 0.0,
#  'screen printer': 0.041,
#  'medium consultant': 0.204,
#  'beauty school': 0.588,
#  'flight school': 0.588,
#  'seaport': 0.0,
#  'security system supplier': 0.0,
#  'middle school': 0.588,
#  'nonprofit': 0.0,
#  'shooting range': 0.0,
#  'soccer club': 0.4,
#  'camp': 0.533,
#  'diving contractor': 0.0,
#  'language school': 0.588,
#  'english language school': 0.588,
#  'preschool': 0.256,
#  'self storage facility': 0.0,
#  'semi conductor supplier': 0.053,
#  'driving school': 0.588,
#  'trucking school': 0.588,
#  'senior citizen center': 0.256,
#  'service': 0.0,
#  'childrens hospital': 0.256,
#  'dental supply store': 0.0,
#  'shipyard': 0.011,
#  'orthodox synagogue': 0.204,
#  'short term apartment rental agency': 0.417,
#  'nutritionist': 0.256,
#  'ophthalmologist': 0.0,
#  'ophthalmology clinic': 0.256,
#  'social service organization': 0.256,
#  'social welfare center': 0.256,
#  'solar energy company': 0.714,
#  'solar energy equipment supplier': 0.714,
#  'special education school': 0.588,
#  'podiatrist': 0.256,
#  'reproductive health clinic': 0.256,
#  'sporting good store': 0.455,
#  'dialysis center': 0.256,
#  'sport complex': 0.4,
#  'wellness program': 0.0,
#  'sportswear store': 0.455,
#  'private hospital': 0.0,
#  'radiologist': 0.256,
#  'medical diagnostic imaging center': 0.256,
#  'ray lab': 0.256,
#  'blood bank': 0.231,
#  'stainless steel plant': 0.053,
#  'state agency': 0.345,
#  'heliport': 0.0,
#  'health care company': 0.256,
#  'psychiatric hospital': 0.256,
#  'state government office': 0.345,
#  'medical institution': 0.256,
#  'steel construction company': 0.323,
#  'cleaning service': 0.0,
#  ...}

# %%
calc_avg_pre(ret_docs_dic, queries_dic, cutoff=-1)[0]
# Out:
# {'home improvement store': 0.091,
#  'diesel fuel supplier': 0.0,
#  'church': 0.0,
#  'farm': 0.156,
#  'seed supplier': 0.0,
#  'accountant': 0.204,
#  'trucking company': 0.12,
#  'exporter': 0.244,
#  'grain elevator': 0.0,
#  'popcorn store': 0.205,
#  'agricultural service': 0.0,
#  'warehouse': 0.571,
#  'agricultural production': 0.156,
#  'ranch': 0.156,
#  'holding company': 1.0,
#  'farm equipment supplier': 0.0,
#  'store': 0.455,
#  'grocery store': 0.205,
#  'rice mill': 0.137,
#  'food product supplier': 0.0,
#  'accounting firm': 0.204,
#  'produce market': 0.043,
#  'pet supply store': 0.455,
#  'wholesaler': 0.141,
#  'produce wholesaler': 0.141,
#  'distribution service': 0.058,
#  'crop grower': 0.156,
#  'addiction treatment center': 0.256,
#  'natural good store': 0.0,
#  'orchard': 0.156,
#  'lumber store': 0.0,
#  'mine': 0.357,
#  'transportation service': 0.2,
#  'investment company': 0.244,
#  'fruit wholesaler': 0.141,
#  'real estate agency': 0.417,
#  'event venue': 0.0,
#  'frozen dessert supplier': 0.137,
#  'wine wholesaler importer': 0.141,
#  'winery': 0.096,
#  'aerospace company': 0.053,
#  'cold storage facility': 0.571,
#  'employment agency': 0.0,
#  'plant nursery': 0.0,
#  'air conditioning contractor': 0.323,
#  'air conditioning repair service': 0.0,
#  'fruit vegetable wholesaler': 0.0,
#  'aircraft rental service': 0.417,
#  'monastery': 0.204,
#  'allergist': 0.256,
#  'herb shop': 0.0,
#  'aluminum supplier': 0.053,
#  'ambulance service': 0.0,
#  'wholesale plant nursery': 0.141,
#  'amusement machine supplier': 0.4,
#  'animal hospital': 0.0,
#  'farmer market': 0.0,
#  'vaporizer store': 0.455,
#  'cigar shop': 0.409,
#  'tobacco shop': 0.21,
#  'well drilling contractor': 0.0,
#  'library': 0.323,
#  'apartment building': 0.0,
#  'apartment rental agency': 0.417,
#  'dairy farm': 0.156,
#  'architect': 0.204,
#  'organic farm': 0.156,
#  'architectural designer': 0.204,
#  'architecture firm': 0.0,
#  'livestock producer': 0.0,
#  'dairy supplier': 0.0,
#  'biotechnology company': 0.082,
#  'artist': 0.4,
#  'egg supplier': 0.156,
#  'poultry farm': 0.0,
#  'chicken hatchery': 0.156,
#  'art organization': 0.4,
#  'association organization': 0.204,
#  'food store': 0.205,
#  'deli': 0.0,
#  'bank': 0.244,
#  'fish processing': 0.0,
#  'fish farm': 0.156,
#  'seafood wholesaler': 0.141,
#  'tropical fish store': 0.455,
#  'non profit organization': 0.204,
#  'economic development agency': 0.345,
#  'seafood market': 0.205,
#  'honey farm': 0.156,
#  'horse breeder': 0.0,
#  'asphalt contractor': 0.323,
#  'livestock dealer': 0.0,
#  'department store': 0.455,
#  'mill': 0.103,
#  'atv dealer': 0.202,
#  'audio visual consultant': 0.053,
#  'pallet supplier': 0.103,
#  'wood supplier': 0.0,
#  'hardware store': 0.0,
#  'furniture wholesaler': 0.0,
#  'auditor': 0.204,
#  'oil natural gas company': 0.357,
#  'auto body shop': 0.204,
#  'boat repair shop': 0.0,
#  'association': 0.204,
#  'railing contractor': 0.0,
#  'publisher': 0.323,
#  'pond supply store': 0.0,
#  'agriculture cooperative': 0.0,
#  'printing equipment supplier': 0.053,
#  'auto insurance agency': 0.244,
#  'alternative fuel station': 0.138,
#  'auto part manufacturer': 0.0,
#  'foundation': 0.204,
#  'fertilizer supplier': 0.103,
#  'farming company': 0.156,
#  'finance broker': 0.244,
#  'agricultural cooperative': 0.0,
#  'fire station': 0.0,
#  'environmental consultant': 0.204,
#  'civil engineer': 0.323,
#  'fire protection service': 0.0,
#  'gas company': 0.0,
#  'oilfield': 0.0,
#  'banquet hall': 0.533,
#  'mining company': 0.357,
#  'coalfield': 0.0,
#  'steel fabricator': 0.053,
#  'quarry': 0.357,
#  'gold mining company': 0.357,
#  'high rise building': 0.323,
#  'basketball club': 0.4,
#  'gold dealer': 0.0,
#  'battery manufacturer': 0.053,
#  'electric utility company': 0.0,
#  'environmental program': 0.0,
#  'office': 0.0,
#  'stone supplier': 0.0,
#  'aggregate supplier': 0.0,
#  'sand gravel supplier': 0.0,
#  'building material supplier': 0.136,
#  'beauty supply store': 0.114,
#  'crushed stone supplier': 0.0,
#  'rock shop': 0.0,
#  'road construction company': 0.323,
#  'marketing consultant': 0.204,
#  'blood testing service': 0.204,
#  'contractor': 0.323,
#  'excavating contractor': 0.323,
#  'asphalt mixing plant': 0.103,
#  'ready mix concrete supplier': 0.103,
#  'sand plant': 0.0,
#  'bmw dealer': 0.227,
#  'bookbinder': 0.103,
#  'garden center': 0.136,
#  'abrasive supplier': 0.103,
#  'granite supplier': 0.0,
#  'drilling contractor': 0.0,
#  'bpo company': 0.227,
#  'oil gas exploration service': 0.357,
#  'building complex': 0.0,
#  'construction equipment supplier': 0.0,
#  'mining equipment': 0.0,
#  'bus ticket agency': 0.0,
#  'business center': 0.0,
#  'skyscraper': 0.0,
#  'software company': 0.323,
#  'business development service': 0.127,
#  'business management consultant': 0.0,
#  'cabinet maker': 0.053,
#  'call center': 0.0,
#  'cancer treatment center': 0.256,
#  'power plant consultant': 0.0,
#  'business park': 0.0,
#  'petroleum product company': 0.0,
#  'parking lot': 0.204,
#  'water utility company': 0.714,
#  'car repair maintenance': 0.204,
#  'water treatment plant': 0.714,
#  'car service': 0.204,
#  'cattle market': 0.0,
#  'sewage disposal service': 0.714,
#  'certified public accountant': 0.0,
#  'government office': 0.345,
#  'charity': 0.204,
#  'air conditioning system supplier': 0.0,
#  'chemical industry': 0.103,
#  'chemical manufacturer': 0.103,
#  'title company': 0.0,
#  'chemical plant': 0.103,
#  'property management company': 0.0,
#  'custom home builder': 0.323,
#  'window installation service': 0.0,
#  'fire damage restoration service': 0.0,
#  'equipment rental agency': 0.417,
#  'chemical wholesaler': 0.0,
#  'financial planner': 0.244,
#  'telecommunication service provider': 0.323,
#  'energy equipment solution': 0.0,
#  'chiropractor': 0.256,
#  'steel distributor': 0.0,
#  'city government office': 0.345,
#  'crane service': 0.0,
#  'garage door supplier': 0.0,
#  'industrial door supplier': 0.047,
#  'city town hall': 0.0,
#  'clothing wholesaler': 0.0,
#  'coin operated laundry equipment supplier': 0.204,
#  'metal supplier': 0.0,
#  'glass shop': 0.0,
#  'college': 0.588,
#  'siding contractor': 0.323,
#  'commercial printer': 0.0,
#  'storage facility': 0.571,
#  'communication tower': 0.0,
#  'janitorial service': 0.0,
#  'computer consultant': 0.0,
#  'fire protection system supplier': 0.0,
#  'elevator service': 0.0,
#  'industrial equipment supplier': 0.0,
#  'dry wall contractor': 0.323,
#  'insulation contractor': 0.323,
#  'concrete contractor': 0.323,
#  'scaffolding rental service': 0.417,
#  'construction company': 0.323,
#  'flooring store': 0.227,
#  'flooring contractor': 0.323,
#  'tile contractor': 0.323,
#  'tile manufacturer': 0.0,
#  'glass mirror shop': 0.0,
#  'construction material wholesaler': 0.141,
#  'gutter cleaning service': 0.0,
#  'sheet metal contractor': 0.053,
#  'consultant': 0.204,
#  'container service': 0.0,
#  'septic system service': 0.0,
#  'corporate campus': 1.0,
#  'water damage restoration service': 0.0,
#  'welder': 0.0,
#  'corporate office': 1.0,
#  'animal': 0.156,
#  'animal feed store': 0.0,
#  'animal protection organization': 0.0,
#  'brewing supply store': 0.0,
#  'cosmetic store': 0.114,
#  'county government office': 0.345,
#  'sugar factory': 0.137,
#  'confectionery wholesaler': 0.141,
#  'financial institution': 0.0,
#  'candy store': 0.205,
#  'confectionery': 0.0,
#  'chocolate factory': 0.137,
#  'chocolate shop': 0.137,
#  'courier service': 0.429,
#  'coworking space': 0.0,
#  'frozen food manufacturer': 0.137,
#  'beverage distributor': 0.0,
#  'agricultural organization': 0.0,
#  'dairy store': 0.0,
#  'dairy': 0.109,
#  'ice cream shop': 0.096,
#  'medical laboratory': 0.256,
#  'demolition contractor': 0.323,
#  'meat processor': 0.122,
#  'fmcg manufacturer': 0.0,
#  'garbage collection service': 0.227,
#  'wholesale bakery': 0.137,
#  'dentist': 0.256,
#  'dessert shop': 0.0,
#  'cupcake shop': 0.0,
#  'nut store': 0.205,
#  'wholesale grocer': 0.141,
#  'design engineer': 0.204,
#  'business business service': 0.227,
#  'condiment supplier': 0.137,
#  'digital printing service': 0.041,
#  'culinary school': 0.588,
#  'importer': 0.0,
#  'bottled water supplier': 0.0,
#  'coffee roaster': 0.137,
#  'packaging supply store': 0.0,
#  'ice supplier': 0.096,
#  'brewery': 0.096,
#  'winemaking company': 0.0,
#  'distillery': 0.096,
#  'disability service support organisation': 0.0,
#  'district government office': 0.345,
#  'air filter supplier': 0.0,
#  'tire shop': 0.145,
#  'fastener supplier': 0.053,
#  'fabric product manufacturer': 0.137,
#  'textile': 0.137,
#  'textile exporter': 0.137,
#  'textile engineer': 0.137,
#  'fabric store': 0.455,
#  'knit shop': 0.137,
#  'doctor': 0.256,
#  'lamination service': 0.0,
#  'plastic resin manufacturer': 0.007,
#  'carpet manufacturer': 0.137,
#  'upholstery shop': 0.204,
#  'business administration service': 0.0,
#  'furniture store': 0.091,
#  'dry cleaner': 0.0,
#  'packaging company': 0.227,
#  'duty free store': 0.455,
#  'commerce service': 0.0,
#  'cable company': 0.0,
#  'education': 0.588,
#  'outlet store': 0.455,
#  'lingerie store': 0.227,
#  'clothes fabric manufacturer': 0.137,
#  'education center': 0.0,
#  'uniform store': 0.205,
#  'men clothing store': 0.205,
#  'clothing store': 0.205,
#  'woman clothing store': 0.205,
#  'western apparel store': 0.0,
#  'costume store': 0.0,
#  'game store': 0.455,
#  'hat shop': 0.034,
#  'leather good manufacturer': 0.043,
#  'educational consultant': 0.588,
#  'leather exporter': 0.055,
#  'shoe store': 0.077,
#  'boutique': 0.0,
#  'leather wholesaler': 0.059,
#  'handbag shop': 0.055,
#  'electronics store': 0.045,
#  'luggage store': 0.136,
#  'building material store': 0.136,
#  'saw mill': 0.103,
#  'electrical engineer': 0.0,
#  'deck builder': 0.323,
#  'concrete product supplier': 0.103,
#  'plywood supplier': 0.103,
#  'electrical installation service': 0.0,
#  'truss manufacturer': 0.0,
#  'door supplier': 0.103,
#  'wood laminate flooring supplier': 0.103,
#  'aircraft supply store': 0.0,
#  'modular home builder': 0.0,
#  'portable building manufacturer': 0.011,
#  'modular home dealer': 0.0,
#  'mulch supplier': 0.0,
#  'electrician': 0.0,
#  'paper mill': 0.103,
#  'energy supplier': 0.714,
#  'engineer': 0.0,
#  'print shop': 0.041,
#  'custom label printer': 0.041,
#  'marketing': 0.182,
#  'marketing agency': 0.0,
#  'engineering consultant': 0.204,
#  'entertainer': 0.4,
#  'envelope supplier': 0.0,
#  'oil refinery': 0.036,
#  'recording studio': 0.323,
#  'environment renewable natural resource': 0.0,
#  'finishing material supplier': 0.0,
#  'event ticket seller': 0.0,
#  'waterproofing company': 0.0,
#  'auto part store': 0.0,
#  'heating oil supplier': 0.182,
#  'family practice physician': 0.256,
#  'machining manufacturer': 0.0,
#  'industrial gas supplier': 0.0,
#  'welding supply store': 0.0,
#  'dry ice supplier': 0.12,
#  'private equity firm': 0.0,
#  'family service center': 0.256,
#  'federal government office': 0.345,
#  'vitamin supplement store': 0.114,
#  'feed manufacturer': 0.0,
#  'medical equipment supplier': 0.0,
#  'medical supply store': 0.0,
#  'medical clinic': 0.256,
#  'research institute': 0.204,
#  'biochemical supplier': 0.0,
#  'fiber optic product supplier': 0.0,
#  'paint manufacturer': 0.0,
#  'equipment supplier': 0.0,
#  'food': 0.0,
#  'pipe supplier': 0.053,
#  'oil field equipment supplier': 0.013,
#  'food broker': 0.0,
#  'food manufacturer': 0.0,
#  'food processing company': 0.0,
#  'fence supply store': 0.114,
#  'food producer': 0.0,
#  'forestry service': 0.156,
#  'foundry': 0.053,
#  'wholesale jeweler': 0.141,
#  'cookie shop': 0.0,
#  'truck rental agency': 0.417,
#  'fruit vegetable processing': 0.137,
#  'kitchen supply store': 0.0,
#  'hydraulic equipment supplier': 0.0,
#  'irrigation equipment supplier': 0.0,
#  'bearing supplier': 0.053,
#  'metallurgy company': 0.0,
#  'plastic injection molding service': 0.0,
#  'general contractor': 0.323,
#  'general hospital': 0.256,
#  'tool manufacturer': 0.023,
#  'industrial design company': 0.0,
#  'hyundai dealer': 0.0,
#  'glass industry': 0.103,
#  'polymer supplier': 0.0,
#  'printing equipment supply': 0.0,
#  'toner cartridge supplier': 0.103,
#  'printer repair service': 0.204,
#  'fuel supplier': 0.0,
#  'glass manufacturer': 0.103,
#  'plastic bag supplier': 0.004,
#  'glassware manufacturer': 0.0,
#  'polythene plastic sheeting supplier': 0.004,
#  'pvc industry': 0.0,
#  'countertop store': 0.227,
#  'cabinet store': 0.227,
#  'fiberglass supplier': 0.0,
#  'golf cart dealer': 0.227,
#  'auto repair shop': 0.204,
#  'hose supplier': 0.001,
#  'rubber product supplier': 0.007,
#  'automotive': 0.0,
#  'commercial refrigerator supplier': 0.0,
#  'golf club': 0.4,
#  'golf course': 0.4,
#  'green energy supplier': 0.714,
#  'greenhouse': 0.156,
#  'auto glass shop': 0.0,
#  'lighting manufacturer': 0.053,
#  'cement manufacturer': 0.103,
#  'brick manufacturer': 0.103,
#  'natural stone supplier': 0.0,
#  'gym': 0.4,
#  'marble supplier': 0.0,
#  'corporate gift supplier': 0.455,
#  'shipbuilding repair company': 0.0,
#  'construction maintenance office': 0.323,
#  'boiler manufacturer': 0.0,
#  'container supplier': 0.0,
#  'home construction': 0.323,
#  'health': 0.256,
#  'heart hospital': 0.256,
#  'spring supplier': 0.053,
#  'electric utility manufacturer': 0.0,
#  'aircraft manufacturer': 0.053,
#  'metal heat treating service': 0.053,
#  'plating service': 0.0,
#  'automation company': 0.0,
#  'heating contractor': 0.323,
#  'plumbing supply store': 0.0,
#  'gun shop': 0.409,
#  'ammunition supplier': 0.053,
#  'pipe manufacturer': 0.053,
#  'school': 0.588,
#  'fire protection equipment supplier': 0.0,
#  'agricultural machinery manufacturer': 0.053,
#  'lawn mower store': 0.205,
#  'lawn irrigation equipment supplier': 0.0,
#  'financial consultant': 0.244,
#  'helicopter charter': 0.2,
#  'packaging machinery': 0.053,
#  'historical landmark': 0.4,
#  'electronics manufacturer': 0.0,
#  'graphic designer': 0.0,
#  'eye care center': 0.256,
#  'optical product manufacturer': 0.0,
#  'image consultant': 0.182,
#  'cleaning product supplier': 0.0,
#  'fireplace store': 0.0,
#  'home builder': 0.323,
#  'tool die shop': 0.053,
#  'metal stamping service': 0.053,
#  'environmental organization': 0.204,
#  'food processing equipment': 0.0,
#  'loan agency': 0.244,
#  'power plant equipment supplier': 0.0,
#  'home good store': 0.091,
#  'engine rebuilding service': 0.204,
#  'air compressor supplier': 0.006,
#  'honda dealer': 0.227,
#  'elevator manufacturer': 0.0,
#  'crane dealer': 0.0,
#  'crane rental agency': 0.417,
#  'compound building': 0.0,
#  'tractor dealer': 0.0,
#  'furnace part supplier': 0.0,
#  'heating equipment supplier': 0.0,
#  'pneumatic tool supplier': 0.0,
#  'truck stop': 0.081,
#  'computer hardware manufacturer': 0.053,
#  'satellite communication service': 0.323,
#  'hospital': 0.256,
#  'electronics company': 0.0,
#  'electronic part supplier': 0.0,
#  'hvac contractor': 0.323,
#  'industrial engineer': 0.0,
#  'contact lens supplier': 0.0,
#  'information service': 0.323,
#  'building': 0.323,
#  'water work equipment supplier': 0.0,
#  'measuring instrument supplier': 0.053,
#  'scientific equipment supplier': 0.0,
#  'medical center': 0.256,
#  'watch manufacturer': 0.141,
#  'corporate entertainment service': 0.0,
#  'insurance': 0.244,
#  'record company': 0.0,
#  'video duplication service': 0.0,
#  'insurance agency': 0.244,
#  'lighting store': 0.053,
#  'lighting wholesaler': 0.053,
#  'entertainment agency': 0.4,
#  'insurance broker': 0.244,
#  'electrical equipment supplier': 0.0,
#  'electric motor store': 0.0,
#  'railroad company': 0.09,
#  'electrical supply store': 0.0,
#  'insurance company': 0.244,
#  'factory equipment supplier': 0.0,
#  'investment service': 0.244,
#  'laser equipment supplier': 0.053,
#  'executive suite rental agency': 0.0,
#  'truck dealer': 0.0,
#  'motor vehicle dealer': 0.154,
#  'car dealer': 0.202,
#  'truck topper supplier': 0.0,
#  'police supply store': 0.455,
#  'iron steel contractor': 0.323,
#  'fire department equipment supplier': 0.0,
#  'towing equipment provider': 0.2,
#  'logistics service': 0.204,
#  'trailer manufacturer': 0.053,
#  'trailer dealer': 0.0,
#  'dealer': 0.227,
#  'auto spring shop': 0.0,
#  'auto upholsterer': 0.0,
#  'auto body part supplier': 0.159,
#  'car factory': 0.0,
#  'freight forwarding service': 0.18,
#  'brake shop': 0.184,
#  'railroad equipment supplier': 0.0,
#  'jewelry equipment supplier': 0.053,
#  'boat builder': 0.011,
#  'ship building': 0.011,
#  'marine supply store': 0.114,
#  'boat dealer': 0.159,
#  'kawasaki motorcycle dealer': 0.202,
#  'knife manufacturing': 0.053,
#  'labor union': 0.204,
#  'furniture maker': 0.053,
#  'banking finance': 0.244,
#  'furniture manufacturer': 0.053,
#  'logistics': 0.204,
#  'massage supply store': 0.0,
#  'telecommunication equipment supplier': 0.0,
#  'baby store': 0.227,
#  'molding supplier': 0.0,
#  'office equipment supplier': 0.0,
#  'office furniture store': 0.053,
#  'store equipment supplier': 0.0,
#  'laboratory': 0.0,
#  'health beauty shop': 0.0,
#  'learning center': 0.588,
#  'dental laboratory': 0.053,
#  'land surveyor': 0.0,
#  'educational supply store': 0.455,
#  'jewelry store': 0.0,
#  'playground equipment supplier': 0.0,
#  'outdoor sport store': 0.455,
#  'toy store': 0.455,
#  'security service': 0.0,
#  'sign shop': 0.053,
#  'office supply store': 0.455,
#  'landscaper': 0.0,
#  'gasket manufacturer': 0.0,
#  'piano maker': 0.0,
#  'piano store': 0.455,
#  'funeral home': 0.0,
#  'monument': 0.0,
#  'book publisher': 0.323,
#  'wig shop': 0.034,
#  'laundromat': 0.204,
#  'auto wrecker': 0.0,
#  'auto part market': 0.159,
#  'jeep dealer': 0.227,
#  'restaurant supply store': 0.0,
#  'roofing supply store': 0.0,
#  'law firm': 0.0,
#  'building material market': 0.136,
#  'camera store': 0.0,
#  'lawn care service': 0.0,
#  'computer security service': 0.0,
#  'computer store': 0.0,
#  'design agency': 0.0,
#  'diagnostic center': 0.256,
#  'laboratory equipment supplier': 0.053,
#  'home theater store': 0.0,
#  'metal industry supplier': 0.0,
#  'landscaping supply store': 0.114,
#  'appliance part supplier': 0.0,
#  'vacuum cleaner store': 0.227,
#  'audio visual equipment supplier': 0.053,
#  'lawyer': 0.204,
#  'cell phone store': 0.0,
#  'bathroom supply store': 0.0,
#  'leasing service': 0.417,
#  'construction machine dealer': 0.0,
#  'dairy farm equipment supplier': 0.0,
#  'propane supplier': 0.0,
#  'legal service': 0.204,
#  'janitorial equipment supplier': 0.0,
#  'life insurance agency': 0.244,
#  'railroad contractor': 0.068,
#  'swimming pool supply store': 0.455,
#  'light bulb supplier': 0.053,
#  'linen store': 0.0,
#  'metal construction company': 0.053,
#  'local government office': 0.345,
#  'logging contractor': 0.0,
#  'machine shop': 0.053,
#  'hotel supply store': 0.0,
#  'import export company': 0.0,
#  'sewing company': 0.0,
#  'research foundation': 0.204,
#  'machinery part manufacturer': 0.053,
#  'sport accessory wholesaler': 0.141,
#  'fashion designer': 0.0,
#  'cheese manufacturer': 0.137,
#  'cheese shop': 0.137,
#  'shipping mailing': 0.0,
#  'wholesale food store': 0.0,
#  'organic food store': 0.205,
#  'pie shop': 0.0,
#  'auction house': 0.182,
#  'livestock auction house': 0.0,
#  'cotton exporter': 0.156,
#  'plastic wholesaler': 0.0,
#  'mailing service': 0.0,
#  'manufacturer': 0.0,
#  'gas station': 0.045,
#  'beer distributor': 0.0,
#  'alcoholic beverage wholesaler': 0.009,
#  'religious good store': 0.0,
#  'book wholesaler': 0.141,
#  'masonry supply store': 0.114,
#  'wholesale florist': 0.141,
#  'florist': 0.455,
#  'marine engineer': 0.0,
#  'paint store': 0.114,
#  'used auto part store': 0.0,
#  'masonry contractor': 0.323,
#  'used car dealer': 0.202,
#  'used truck dealer': 0.202,
#  'massage therapist': 0.256,
#  'material handling equipment supplier': 0.0,
#  'marina': 0.4,
#  'meat packer': 0.0,
#  'mattress store': 0.159,
#  'blind shop': 0.029,
#  'interior designer': 0.0,
#  'window treatment store': 0.091,
#  'appliance store': 0.045,
#  'health food store': 0.227,
#  'direct mail advertising': 0.204,
#  'meat wholesaler': 0.141,
#  'butcher shop deli': 0.038,
#  'italian grocery store': 0.205,
#  'market': 0.0,
#  'food service': 0.533,
#  'grocery delivery service': 0.429,
#  'wine store': 0.205,
#  'liquor store': 0.205,
#  'kiosk': 0.0,
#  'optometrist': 0.256,
#  'optician': 0.256,
#  'mechanical contractor': 0.323,
#  'mechanical engineer': 0.0,
#  'cafe': 0.0,
#  'jeweler': 0.141,
#  'leather good store': 0.059,
#  'gift shop': 0.455,
#  'craft store': 0.455,
#  'hobby store': 0.455,
#  'fabric wholesaler': 0.099,
#  'scrap metal dealer': 0.0,
#  'quilt shop': 0.409,
#  'sheet music store': 0.455,
#  'musical instrument manufacturer': 0.045,
#  'music store': 0.455,
#  'musical instrument store': 0.455,
#  'band': 0.0,
#  'bookstore': 0.0,
#  'art museum': 0.4,
#  'newsstand': 0.455,
#  'medical equipment manufacturer': 0.053,
#  'fashion accessory store': 0.205,
#  'discount store': 0.455,
#  'cemetery': 0.204,
#  'bus stop': 0.2,
#  'variety store': 0.455,
#  'thrift store': 0.455,
#  'medical group': 0.256,
#  'donation center': 0.0,
#  'pet store': 0.455,
#  'art gallery': 0.0,
#  'art dealer': 0.0,
#  'housing development': 0.0,
#  'mobile home dealer': 0.0,
#  'convenience store': 0.227,
#  'medical office': 0.256,
#  'medical technology manufacturer': 0.053,
#  'childrens furniture store': 0.091,
#  'mental health clinic': 0.256,
#  'airline': 0.0,
#  'aviation consultant': 0.0,
#  'travel agency': 0.227,
#  'travel service': 0.227,
#  'airport': 0.0,
#  'mental health service': 0.256,
#  'shipping company': 0.0,
#  'metal fabricator': 0.053,
#  'cruise line company': 0.0,
#  'towing service': 0.2,
#  'ferry terminal': 0.2,
#  'ferry service': 0.0,
#  'metal finisher': 0.053,
#  'boat tour agency': 0.18,
#  'bus company': 0.2,
#  'moving company': 0.0,
#  'moving storage service': 0.0,
#  'state department transportation': 0.0,
#  'department transportation': 0.0,
#  'handicapped transportation service': 0.2,
#  'railway service': 0.0,
#  'train station': 0.112,
#  'bus depot': 0.2,
#  'bus charter': 0.2,
#  'metal processing company': 0.053,
#  'mixed use': 0.0,
#  'motorcycle shop': 0.159,
#  'limousine service': 0.0,
#  'chauffeur service': 0.0,
#  'school bus service': 0.2,
#  'airport shuttle service': 0.0,
#  'tourist information center': 0.0,
#  'carriage ride service': 0.0,
#  'cruise agency': 0.0,
#  'tourist attraction': 0.0,
#  'ski resort': 0.4,
#  'ski area': 0.0,
#  'fixed base operator': 0.0,
#  'aircraft maintenance company': 0.0,
#  'motorsports store': 0.159,
#  'boat rental service': 0.417,
#  'utility trailer dealer': 0.0,
#  'forklift dealer': 0.0,
#  'municipal administration office': 0.345,
#  'nephrologist': 0.0,
#  'bus coach company': 0.2,
#  'shipping service': 0.0,
#  'shipping mailing service': 0.0,
#  'newspaper publisher': 0.323,
#  'shredding service': 0.0,
#  'nuclear power company': 0.714,
#  'nursing home': 0.256,
#  'medium company': 0.0,
#  'multimedia electronic book publisher': 0.323,
#  'internet marketing service': 0.0,
#  'greeting card shop': 0.409,
#  'theme park': 0.4,
#  'film production company': 0.0,
#  'obstetrician gynecologist': 0.256,
#  'movie studio': 0.323,
#  'video production service': 0.0,
#  'movie theater': 0.323,
#  'theater company': 0.0,
#  'performing art theater': 0.4,
#  'occupational safety health': 0.0,
#  'office space rental agency': 0.417,
#  'commercial real estate agency': 0.417,
#  'art school': 0.588,
#  'music publisher': 0.323,
#  'printed music publisher': 0.323,
#  'home audio store': 0.0,
#  'musician': 0.4,
#  'music management promotion': 0.0,
#  'video editing service': 0.0,
#  'office supply wholesaler': 0.141,
#  'official residence': 0.0,
#  'orthopedic clinic': 0.256,
#  'painter': 0.0,
#  'painting': 0.323,
#  'telephone company': 0.0,
#  'medium house': 0.204,
#  'paper distributor': 0.0,
#  'news service': 0.0,
#  'public library': 0.0,
#  'law library': 0.323,
#  'museum': 0.4,
#  'federal reserve bank': 0.244,
#  'credit union': 0.244,
#  'atm': 0.0,
#  'paving contractor': 0.323,
#  'mortgage lender': 0.244,
#  'investment bank': 0.244,
#  'check cashing service': 0.0,
#  'stock broker': 0.0,
#  'health consultant': 0.0,
#  'health insurance agency': 0.244,
#  'payroll service': 0.204,
#  'pediatrician': 0.256,
#  'human resource consulting': 0.204,
#  'pest control service': 0.0,
#  'pet boarding service': 0.204,
#  'pet care': 0.204,
#  'loss adjuster': 0.244,
#  'pharmaceutical company': 0.103,
#  'pharmaceutical product wholesaler': 0.141,
#  'pharmacy': 0.114,
#  'educational institution': 0.588,
#  'retirement community': 0.256,
#  'fraternal organization': 0.204,
#  'photo lab': 0.0,
#  'property investment': 0.0,
#  'photographer': 0.204,
#  'photography school': 0.0,
#  'star hotel': 0.667,
#  'convention center': 0.0,
#  'real estate appraiser': 0.417,
#  'photography service': 0.0,
#  'resort hotel': 0.467,
#  'real estate consultant': 0.417,
#  'car rental agency': 0.417,
#  'car leasing service': 0.417,
#  'ford dealer': 0.227,
#  'car finance loan company': 0.244,
#  'trailer rental service': 0.417,
#  'furniture rental service': 0.0,
#  'tuxedo shop': 0.0,
#  'dress tuxedo rental service': 0.417,
#  'wedding store': 0.227,
#  'video store': 0.227,
#  'movie rental': 0.0,
#  'photography studio': 0.0,
#  'home health care service': 0.256,
#  'skateboard shop': 0.053,
#  'event technology service': 0.0,
#  'party equipment rental service': 0.417,
#  'construction machine rental service': 0.417,
#  'audio visual equipment rental service': 0.0,
#  'shipping equipment industry': 0.0,
#  'physical therapy clinic': 0.256,
#  'plastic fabrication company': 0.004,
#  'plastic product supplier': 0.007,
#  'auto tag agency': 0.345,
#  'department motor vehicle': 0.0,
#  'notary public': 0.0,
#  'private investigator': 0.0,
#  'escrow service': 0.0,
#  'real estate agent': 0.417,
#  'playground': 0.0,
#  'plumber': 0.0,
#  'port authority': 0.2,
#  'portrait studio': 0.0,
#  'post office': 0.0,
#  'professional service': 0.204,
#  'university hospital': 0.0,
#  'public relation firm': 0.014,
#  'civil engineering company': 0.0,
#  'drafting service': 0.204,
#  'pump supplier': 0.053,
#  'interior construction contractor': 0.323,
#  'carpet cleaning service': 0.0,
#  'exhibition planner': 0.0,
#  'decal supplier': 0.0,
#  'stage lighting equipment supplier': 0.053,
#  'event management company': 0.0,
#  'radio broadcaster': 0.0,
#  'computer support service': 0.05,
#  'ravine': 0.0,
#  'employment center': 0.0,
#  'national health foundation': 0.0,
#  'real estate developer': 0.0,
#  'advertising agency': 0.204,
#  'promotional product supplier': 0.0,
#  'advertising service': 0.204,
#  'record storage facility': 0.0,
#  'fund management company': 0.244,
#  'recreation center': 0.4,
#  'bakery': 0.137,
#  'database management company': 0.0,
#  'market researcher': 0.0,
#  'recycling center': 0.0,
#  'regional government office': 0.345,
#  'rehabilitation center': 0.256,
#  'religious institution': 0.204,
#  'religious organization': 0.204,
#  'repair service': 0.204,
#  'emergency veterinarian service': 0.0,
#  'pet sitter': 0.0,
#  'research product development': 0.13,
#  'building society': 0.323,
#  'valet parking service': 0.204,
#  'nursing agency': 0.256,
#  'executive search firm': 0.0,
#  'recruiter': 0.0,
#  'temp agency': 0.0,
#  'health center': 0.256,
#  'restaurant': 0.533,
#  'roofing contractor': 0.323,
#  'sport nutrition store': 0.129,
#  'credit reporting agency': 0.0,
#  'automobile storage facility': 0.571,
#  'debt collection agency': 0.227,
#  'park': 0.0,
#  'court reporter': 0.0,
#  'bus tour agency': 0.0,
#  'tour operator': 0.0,
#  'convention information bureau': 0.0,
#  'balloon ride tour agency': 0.18,
#  'security guard service': 0.227,
#  'locksmith': 0.227,
#  'commercial cleaning service': 0.0,
#  'blast cleaning service': 0.0,
#  'conference center': 0.0,
#  'safety equipment supplier': 0.0,
#  'garbage dump': 0.227,
#  'sanitation service': 0.0,
#  'garbage dump service': 0.0,
#  'environmental health service': 0.0,
#  'portable toilet supplier': 0.0,
#  'public work department': 0.0,
#  'school district office': 0.588,
#  'sailmaker': 0.0,
#  'community college': 0.588,
#  'salvage yard': 0.0,
#  'business school': 0.588,
#  'trade school': 0.588,
#  'private university': 0.588,
#  'computer training school': 0.588,
#  'school supply store': 0.0,
#  'screen printer': 0.041,
#  'medium consultant': 0.204,
#  'beauty school': 0.588,
#  'flight school': 0.588,
#  'seaport': 0.0,
#  'security system supplier': 0.0,
#  'middle school': 0.588,
#  'nonprofit': 0.0,
#  'shooting range': 0.0,
#  'soccer club': 0.4,
#  'camp': 0.52,
#  'diving contractor': 0.0,
#  'language school': 0.588,
#  'english language school': 0.588,
#  'preschool': 0.256,
#  'self storage facility': 0.0,
#  'semi conductor supplier': 0.053,
#  'driving school': 0.588,
#  'trucking school': 0.588,
#  'senior citizen center': 0.256,
#  'service': 0.0,
#  'childrens hospital': 0.256,
#  'dental supply store': 0.0,
#  'shipyard': 0.011,
#  'orthodox synagogue': 0.204,
#  'short term apartment rental agency': 0.417,
#  'nutritionist': 0.256,
#  'ophthalmologist': 0.0,
#  'ophthalmology clinic': 0.256,
#  'social service organization': 0.256,
#  'social welfare center': 0.256,
#  'solar energy company': 0.714,
#  'solar energy equipment supplier': 0.714,
#  'special education school': 0.588,
#  'podiatrist': 0.256,
#  'reproductive health clinic': 0.256,
#  'sporting good store': 0.455,
#  'dialysis center': 0.256,
#  'sport complex': 0.4,
#  'wellness program': 0.0,
#  'sportswear store': 0.455,
#  'private hospital': 0.0,
#  'radiologist': 0.256,
#  'medical diagnostic imaging center': 0.256,
#  'ray lab': 0.256,
#  'blood bank': 0.231,
#  'stainless steel plant': 0.053,
#  'state agency': 0.345,
#  'heliport': 0.0,
#  'health care company': 0.256,
#  'psychiatric hospital': 0.256,
#  'state government office': 0.345,
#  'medical institution': 0.256,
#  'steel construction company': 0.323,
#  'cleaning service': 0.0,
#  ...}

# %%
calc_avg_pre(ret_docs_dic, queries_dic, cutoff=-1)[1]
# Out:
# 0.151

# %%
rocchio_maps = []
for i in range(1, 11):
    rocchio_maps.append(calc_avg_pre(ret_docs_dic, queries_dic, cutoff=i)[1])

# %%
rocchio_maps
# Out:
# [0.017, 0.034, 0.051, 0.066, 0.081, 0.096, 0.11, 0.124, 0.138, 0.151]

# %%
calc_NDCG_at_n(ret_docs_dic, queries_dic, n=-1, base=2)
# Out:
# {'home improvement store': 0.442,
#  'diesel fuel supplier': 0.015,
#  'church': 0.021,
#  'farm': 0.961,
#  'seed supplier': 0.015,
#  'accountant': 0.927,
#  'trucking company': 0.776,
#  'exporter': 0.913,
#  'grain elevator': 0.203,
#  'popcorn store': 0.949,
#  'agricultural service': 0.016,
#  'warehouse': 0.839,
#  'agricultural production': 0.804,
#  'ranch': 0.916,
#  'holding company': 0.966,
#  'farm equipment supplier': 0.015,
#  'store': 0.497,
#  'grocery store': 0.916,
#  'rice mill': 0.937,
#  'food product supplier': 0.015,
#  'accounting firm': 0.926,
#  'produce market': 0.348,
#  'pet supply store': 0.945,
#  'wholesaler': 0.659,
#  'produce wholesaler': 0.225,
#  'distribution service': 0.143,
#  'crop grower': 0.86,
#  'addiction treatment center': 0.67,
#  'natural good store': 0.024,
#  'orchard': 0.865,
#  'lumber store': 0.015,
#  'mine': 0.612,
#  'transportation service': 0.129,
#  'investment company': 0.997,
#  'fruit wholesaler': 0.233,
#  'real estate agency': 0.944,
#  'event venue': 0.024,
#  'frozen dessert supplier': 0.91,
#  'wine wholesaler importer': 0.224,
#  'winery': 0.831,
#  'aerospace company': 0.983,
#  'cold storage facility': 0.882,
#  'employment agency': 0.024,
#  'plant nursery': 0.024,
#  'air conditioning contractor': 0.76,
#  'air conditioning repair service': 0.035,
#  'fruit vegetable wholesaler': 0.024,
#  'aircraft rental service': 0.75,
#  'monastery': 0.916,
#  'allergist': 0.939,
#  'herb shop': 0.024,
#  'aluminum supplier': 0.981,
#  'ambulance service': 0.027,
#  'wholesale plant nursery': 0.78,
#  'amusement machine supplier': 0.963,
#  'animal hospital': 0.021,
#  'farmer market': 0.024,
#  'vaporizer store': 0.956,
#  'cigar shop': 0.872,
#  'tobacco shop': 0.586,
#  'well drilling contractor': 0.039,
#  'library': 0.547,
#  'apartment building': 0.046,
#  'apartment rental agency': 0.481,
#  'dairy farm': 0.142,
#  'architect': 0.967,
#  'organic farm': 0.165,
#  'architectural designer': 0.967,
#  'architecture firm': 0.021,
#  'livestock producer': 0.016,
#  'dairy supplier': 0.015,
#  'biotechnology company': 0.631,
#  'artist': 0.894,
#  'egg supplier': 0.865,
#  'poultry farm': 0.014,
#  'chicken hatchery': 0.919,
#  'art organization': 0.913,
#  'association organization': 0.962,
#  'food store': 0.918,
#  'deli': 0.078,
#  'bank': 0.975,
#  'fish processing': 0.014,
#  'fish farm': 0.474,
#  'seafood wholesaler': 0.937,
#  'tropical fish store': 0.948,
#  'non profit organization': 0.91,
#  'economic development agency': 0.604,
#  'seafood market': 0.929,
#  'honey farm': 0.142,
#  'horse breeder': 0.016,
#  'asphalt contractor': 0.811,
#  'livestock dealer': 0.015,
#  'department store': 0.491,
#  'mill': 0.823,
#  'atv dealer': 0.918,
#  'audio visual consultant': 0.979,
#  'pallet supplier': 0.982,
#  'wood supplier': 0.015,
#  'hardware store': 0.024,
#  'furniture wholesaler': 0.015,
#  'auditor': 0.553,
#  'oil natural gas company': 0.944,
#  'auto body shop': 0.963,
#  'boat repair shop': 0.005,
#  'association': 0.962,
#  'railing contractor': 0.005,
#  'publisher': 0.847,
#  'pond supply store': 0.085,
#  'agriculture cooperative': 0.037,
#  'printing equipment supplier': 0.206,
#  'auto insurance agency': 0.954,
#  'alternative fuel station': 0.655,
#  'auto part manufacturer': 0.005,
#  'foundation': 0.911,
#  'fertilizer supplier': 0.922,
#  'farming company': 0.757,
#  'finance broker': 0.261,
#  'agricultural cooperative': 0.037,
#  'fire station': 0.037,
#  'environmental consultant': 0.895,
#  'civil engineer': 0.408,
#  'fire protection service': 0.037,
#  'gas company': 0.085,
#  'oilfield': 0.039,
#  'banquet hall': 0.828,
#  'mining company': 0.855,
#  'coalfield': 0.039,
#  'steel fabricator': 0.765,
#  'quarry': 0.91,
#  'gold mining company': 0.837,
#  'high rise building': 0.778,
#  'basketball club': 0.296,
#  'gold dealer': 0.015,
#  'battery manufacturer': 0.983,
#  'electric utility company': 0.037,
#  'environmental program': 0.021,
#  'office': 0.024,
#  'stone supplier': 0.015,
#  'aggregate supplier': 0.015,
#  'sand gravel supplier': 0.039,
#  'building material supplier': 0.774,
#  'beauty supply store': 0.709,
#  'crushed stone supplier': 0.015,
#  'rock shop': 0.015,
#  'road construction company': 0.371,
#  'marketing consultant': 0.919,
#  'blood testing service': 0.961,
#  'contractor': 0.82,
#  'excavating contractor': 0.826,
#  'asphalt mixing plant': 0.718,
#  'ready mix concrete supplier': 0.918,
#  'sand plant': 0.039,
#  'bmw dealer': 0.961,
#  'bookbinder': 0.492,
#  'garden center': 0.777,
#  'abrasive supplier': 0.952,
#  'granite supplier': 0.011,
#  'drilling contractor': 0.039,
#  'bpo company': 0.82,
#  'oil gas exploration service': 0.793,
#  'building complex': 0.046,
#  'construction equipment supplier': 0.015,
#  'mining equipment': 0.005,
#  'bus ticket agency': 0.024,
#  'business center': 0.024,
#  'skyscraper': 0.035,
#  'software company': 0.833,
#  'business development service': 0.359,
#  'business management consultant': 0.021,
#  'cabinet maker': 0.996,
#  'call center': 0.024,
#  'cancer treatment center': 0.752,
#  'power plant consultant': 0.035,
#  'business park': 0.021,
#  'petroleum product company': 0.015,
#  'parking lot': 0.851,
#  'water utility company': 0.747,
#  'car repair maintenance': 0.945,
#  'water treatment plant': 0.747,
#  'car service': 0.505,
#  'cattle market': 0.015,
#  'sewage disposal service': 0.75,
#  'certified public accountant': 0.021,
#  'government office': 0.763,
#  'charity': 0.91,
#  'air conditioning system supplier': 0.015,
#  'chemical industry': 0.929,
#  'chemical manufacturer': 0.93,
#  'title company': 0.021,
#  'chemical plant': 0.93,
#  'property management company': 0.046,
#  'custom home builder': 0.351,
#  'window installation service': 0.035,
#  'fire damage restoration service': 0.024,
#  'equipment rental agency': 0.735,
#  'chemical wholesaler': 0.015,
#  'financial planner': 0.592,
#  'telecommunication service provider': 0.79,
#  'energy equipment solution': 0.024,
#  'chiropractor': 0.966,
#  'steel distributor': 0.015,
#  'city government office': 0.758,
#  'crane service': 0.005,
#  'garage door supplier': 0.035,
#  'industrial door supplier': 0.613,
#  'city town hall': 0.037,
#  'clothing wholesaler': 0.015,
#  'coin operated laundry equipment supplier': 0.96,
#  'metal supplier': 0.015,
#  'glass shop': 0.035,
#  'college': 0.6,
#  'siding contractor': 0.856,
#  'commercial printer': 0.011,
#  'storage facility': 0.862,
#  'communication tower': 0.035,
#  'janitorial service': 0.024,
#  'computer consultant': 0.021,
#  'fire protection system supplier': 0.037,
#  'elevator service': 0.005,
#  'industrial equipment supplier': 0.015,
#  'dry wall contractor': 0.82,
#  'insulation contractor': 0.82,
#  'concrete contractor': 0.88,
#  'scaffolding rental service': 0.747,
#  'construction company': 0.392,
#  'flooring store': 0.557,
#  'flooring contractor': 0.804,
#  'tile contractor': 0.827,
#  'tile manufacturer': 0.035,
#  'glass mirror shop': 0.035,
#  'construction material wholesaler': 0.773,
#  'gutter cleaning service': 0.024,
#  'sheet metal contractor': 0.971,
#  'consultant': 0.918,
#  'container service': 0.005,
#  'septic system service': 0.024,
#  'corporate campus': 0.966,
#  'water damage restoration service': 0.024,
#  'welder': 0.005,
#  'corporate office': 0.966,
#  'animal': 0.975,
#  'animal feed store': 0.051,
#  'animal protection organization': 0.021,
#  'brewing supply store': 0.015,
#  'cosmetic store': 0.71,
#  'county government office': 0.758,
#  'sugar factory': 0.854,
#  'confectionery wholesaler': 0.825,
#  'financial institution': 0.037,
#  'candy store': 0.946,
#  'confectionery': 0.024,
#  'chocolate factory': 0.85,
#  'chocolate shop': 0.868,
#  'courier service': 0.829,
#  'coworking space': 0.046,
#  'frozen food manufacturer': 0.855,
#  'beverage distributor': 0.015,
#  'agricultural organization': 0.037,
#  'dairy store': 0.015,
#  'dairy': 0.716,
#  'ice cream shop': 0.336,
#  'medical laboratory': 0.604,
#  'demolition contractor': 0.822,
#  'meat processor': 0.87,
#  'fmcg manufacturer': 0.046,
#  'garbage collection service': 0.994,
#  'wholesale bakery': 0.887,
#  'dentist': 0.94,
#  'dessert shop': 0.014,
#  'cupcake shop': 0.014,
#  'nut store': 0.947,
#  'wholesale grocer': 0.827,
#  'design engineer': 0.702,
#  'business business service': 0.902,
#  'condiment supplier': 0.949,
#  'digital printing service': 0.612,
#  'culinary school': 0.6,
#  'importer': 0.026,
#  'bottled water supplier': 0.014,
#  'coffee roaster': 0.96,
#  'packaging supply store': 0.024,
#  'ice supplier': 0.832,
#  'brewery': 0.83,
#  'winemaking company': 0.014,
#  'distillery': 0.829,
#  'disability service support organisation': 0.027,
#  'district government office': 0.676,
#  'air filter supplier': 0.005,
#  'tire shop': 0.811,
#  'fastener supplier': 0.984,
#  'fabric product manufacturer': 0.854,
#  'textile': 0.866,
#  'textile exporter': 0.866,
#  'textile engineer': 0.866,
#  'fabric store': 0.47,
#  'knit shop': 0.286,
#  'doctor': 0.939,
#  'lamination service': 0.011,
#  'plastic resin manufacturer': 0.059,
#  'carpet manufacturer': 0.763,
#  'upholstery shop': 0.88,
#  'business administration service': 0.021,
#  'furniture store': 0.63,
#  'dry cleaner': 0.021,
#  'packaging company': 0.726,
#  'duty free store': 0.959,
#  'commerce service': 0.051,
#  'cable company': 0.035,
#  'education': 0.543,
#  'outlet store': 0.497,
#  'lingerie store': 0.245,
#  'clothes fabric manufacturer': 0.854,
#  'education center': 0.068,
#  'uniform store': 0.281,
#  'men clothing store': 0.948,
#  'clothing store': 0.94,
#  'woman clothing store': 0.95,
#  'western apparel store': 0.024,
#  'costume store': 0.046,
#  'game store': 0.493,
#  'hat shop': 0.227,
#  'leather good manufacturer': 0.354,
#  'educational consultant': 0.485,
#  'leather exporter': 0.617,
#  'shoe store': 0.175,
#  'boutique': 0.024,
#  'leather wholesaler': 0.415,
#  'handbag shop': 0.618,
#  'electronics store': 0.421,
#  'luggage store': 0.441,
#  'building material store': 0.782,
#  'saw mill': 0.823,
#  'electrical engineer': 0.021,
#  'deck builder': 0.807,
#  'concrete product supplier': 0.919,
#  'plywood supplier': 0.938,
#  'electrical installation service': 0.035,
#  'truss manufacturer': 0.011,
#  'door supplier': 0.988,
#  'wood laminate flooring supplier': 0.993,
#  'aircraft supply store': 0.015,
#  'modular home builder': 0.011,
#  'portable building manufacturer': 0.071,
#  'modular home dealer': 0.051,
#  'mulch supplier': 0.015,
#  'electrician': 0.035,
#  'paper mill': 0.972,
#  'energy supplier': 0.883,
#  'engineer': 0.021,
#  'print shop': 0.612,
#  'custom label printer': 0.612,
#  'marketing': 0.886,
#  'marketing agency': 0.021,
#  'engineering consultant': 0.669,
#  'entertainer': 0.471,
#  'envelope supplier': 0.011,
#  'oil refinery': 0.539,
#  'recording studio': 0.995,
#  'environment renewable natural resource': 0.085,
#  'finishing material supplier': 0.024,
#  'event ticket seller': 0.024,
#  'waterproofing company': 0.035,
#  'auto part store': 0.024,
#  'heating oil supplier': 0.677,
#  'family practice physician': 0.942,
#  'machining manufacturer': 0.005,
#  'industrial gas supplier': 0.011,
#  'welding supply store': 0.005,
#  'dry ice supplier': 0.888,
#  'private equity firm': 0.026,
#  'family service center': 0.589,
#  'federal government office': 0.676,
#  'vitamin supplement store': 0.7,
#  'feed manufacturer': 0.014,
#  'medical equipment supplier': 0.015,
#  'medical supply store': 0.015,
#  'medical clinic': 0.849,
#  'research institute': 0.764,
#  'biochemical supplier': 0.015,
#  'fiber optic product supplier': 0.005,
#  'paint manufacturer': 0.011,
#  'equipment supplier': 0.015,
#  'food': 0.014,
#  'pipe supplier': 0.995,
#  'oil field equipment supplier': 0.073,
#  'food broker': 0.015,
#  'food manufacturer': 0.014,
#  'food processing company': 0.014,
#  'fence supply store': 0.252,
#  'food producer': 0.014,
#  'forestry service': 0.957,
#  'foundry': 0.997,
#  'wholesale jeweler': 0.311,
#  'cookie shop': 0.014,
#  'truck rental agency': 0.898,
#  'fruit vegetable processing': 0.955,
#  'kitchen supply store': 0.015,
#  'hydraulic equipment supplier': 0.015,
#  'irrigation equipment supplier': 0.085,
#  'bearing supplier': 0.989,
#  'metallurgy company': 0.005,
#  'plastic injection molding service': 0.005,
#  'general contractor': 0.426,
#  'general hospital': 0.748,
#  'tool manufacturer': 0.646,
#  'industrial design company': 0.021,
#  'hyundai dealer': 0.015,
#  'glass industry': 0.92,
#  'polymer supplier': 0.015,
#  'printing equipment supply': 0.005,
#  'toner cartridge supplier': 0.974,
#  'printer repair service': 0.803,
#  'fuel supplier': 0.015,
#  'glass manufacturer': 0.919,
#  'plastic bag supplier': 0.125,
#  'glassware manufacturer': 0.011,
#  'polythene plastic sheeting supplier': 0.125,
#  'pvc industry': 0.011,
#  'countertop store': 0.461,
#  'cabinet store': 0.461,
#  'fiberglass supplier': 0.011,
#  'golf cart dealer': 0.963,
#  'auto repair shop': 0.958,
#  'hose supplier': 0.061,
#  'rubber product supplier': 0.17,
#  'automotive': 0.015,
#  'commercial refrigerator supplier': 0.015,
#  'golf club': 0.988,
#  'golf course': 0.988,
#  'green energy supplier': 0.936,
#  'greenhouse': 0.904,
#  'auto glass shop': 0.021,
#  'lighting manufacturer': 0.976,
#  'cement manufacturer': 0.918,
#  'brick manufacturer': 0.913,
#  'natural stone supplier': 0.015,
#  'gym': 0.976,
#  'marble supplier': 0.011,
#  'corporate gift supplier': 0.878,
#  'shipbuilding repair company': 0.005,
#  'construction maintenance office': 0.387,
#  'boiler manufacturer': 0.005,
#  'container supplier': 0.005,
#  'home construction': 0.37,
#  'health': 0.945,
#  'heart hospital': 0.735,
#  'spring supplier': 0.853,
#  'electric utility manufacturer': 0.037,
#  'aircraft manufacturer': 0.983,
#  'metal heat treating service': 0.975,
#  'plating service': 0.005,
#  'automation company': 0.005,
#  'heating contractor': 0.802,
#  'plumbing supply store': 0.015,
#  'gun shop': 0.525,
#  'ammunition supplier': 0.989,
#  'pipe manufacturer': 0.988,
#  'school': 0.579,
#  'fire protection equipment supplier': 0.037,
#  'agricultural machinery manufacturer': 0.942,
#  'lawn mower store': 0.484,
#  'lawn irrigation equipment supplier': 0.085,
#  'financial consultant': 0.592,
#  'helicopter charter': 0.624,
#  'packaging machinery': 0.868,
#  'historical landmark': 0.774,
#  'electronics manufacturer': 0.005,
#  'graphic designer': 0.021,
#  'eye care center': 0.828,
#  'optical product manufacturer': 0.005,
#  'image consultant': 0.509,
#  'cleaning product supplier': 0.015,
#  'fireplace store': 0.015,
#  'home builder': 0.436,
#  'tool die shop': 0.798,
#  'metal stamping service': 0.949,
#  'environmental organization': 0.911,
#  'food processing equipment': 0.005,
#  'loan agency': 0.927,
#  'power plant equipment supplier': 0.015,
#  'home good store': 0.635,
#  'engine rebuilding service': 0.494,
#  'air compressor supplier': 0.249,
#  'honda dealer': 0.964,
#  'elevator manufacturer': 0.005,
#  'crane dealer': 0.005,
#  'crane rental agency': 0.75,
#  'compound building': 0.035,
#  'tractor dealer': 0.015,
#  'furnace part supplier': 0.015,
#  'heating equipment supplier': 0.015,
#  'pneumatic tool supplier': 0.015,
#  'truck stop': 0.576,
#  'computer hardware manufacturer': 0.982,
#  'satellite communication service': 0.788,
#  'hospital': 0.733,
#  'electronics company': 0.024,
#  'electronic part supplier': 0.015,
#  'hvac contractor': 0.782,
#  'industrial engineer': 0.021,
#  'contact lens supplier': 0.005,
#  'information service': 0.283,
#  'building': 0.935,
#  'water work equipment supplier': 0.015,
#  'measuring instrument supplier': 0.993,
#  'scientific equipment supplier': 0.015,
#  'medical center': 0.767,
#  'watch manufacturer': 0.338,
#  'corporate entertainment service': 0.044,
#  'insurance': 0.95,
#  'record company': 0.035,
#  'video duplication service': 0.035,
#  'insurance agency': 0.954,
#  'lighting store': 0.99,
#  'lighting wholesaler': 0.99,
#  'entertainment agency': 0.323,
#  'insurance broker': 0.954,
#  'electrical equipment supplier': 0.015,
#  'electric motor store': 0.005,
#  'railroad company': 0.464,
#  'electrical supply store': 0.015,
#  'insurance company': 0.954,
#  'factory equipment supplier': 0.015,
#  'investment service': 0.676,
#  'laser equipment supplier': 0.199,
#  'executive suite rental agency': 0.037,
#  'truck dealer': 0.015,
#  'motor vehicle dealer': 0.825,
#  'car dealer': 0.92,
#  'truck topper supplier': 0.015,
#  'police supply store': 0.959,
#  'iron steel contractor': 0.863,
#  'fire department equipment supplier': 0.037,
#  'towing equipment provider': 0.954,
#  'logistics service': 0.723,
#  'trailer manufacturer': 0.994,
#  'trailer dealer': 0.046,
#  'dealer': 0.964,
#  'auto spring shop': 0.021,
#  'auto upholsterer': 0.005,
#  'auto body part supplier': 0.823,
#  'car factory': 0.005,
#  'freight forwarding service': 0.543,
#  'brake shop': 0.92,
#  'railroad equipment supplier': 0.015,
#  'jewelry equipment supplier': 0.996,
#  'boat builder': 0.39,
#  'ship building': 0.39,
#  'marine supply store': 0.248,
#  'boat dealer': 0.844,
#  'kawasaki motorcycle dealer': 0.918,
#  'knife manufacturing': 0.033,
#  'labor union': 0.96,
#  'furniture maker': 0.998,
#  'banking finance': 0.96,
#  'furniture manufacturer': 0.997,
#  'logistics': 0.925,
#  'massage supply store': 0.015,
#  'telecommunication equipment supplier': 0.005,
#  'baby store': 0.482,
#  'molding supplier': 0.005,
#  'office equipment supplier': 0.015,
#  'office furniture store': 0.989,
#  'store equipment supplier': 0.015,
#  'laboratory': 0.021,
#  'health beauty shop': 0.021,
#  'learning center': 0.91,
#  'dental laboratory': 0.999,
#  'land surveyor': 0.021,
#  'educational supply store': 0.878,
#  'jewelry store': 0.024,
#  'playground equipment supplier': 0.015,
#  'outdoor sport store': 0.474,
#  'toy store': 0.493,
#  'security service': 0.024,
#  'sign shop': 0.995,
#  'office supply store': 0.878,
#  'landscaper': 0.024,
#  'gasket manufacturer': 0.005,
#  'piano maker': 0.005,
#  'piano store': 0.475,
#  'funeral home': 0.021,
#  'monument': 0.044,
#  'book publisher': 0.851,
#  'wig shop': 0.227,
#  'laundromat': 0.96,
#  'auto wrecker': 0.021,
#  'auto part market': 0.822,
#  'jeep dealer': 0.964,
#  'restaurant supply store': 0.015,
#  'roofing supply store': 0.015,
#  'law firm': 0.021,
#  'building material market': 0.774,
#  'camera store': 0.015,
#  'lawn care service': 0.024,
#  'computer security service': 0.024,
#  'computer store': 0.015,
#  'design agency': 0.021,
#  'diagnostic center': 0.68,
#  'laboratory equipment supplier': 0.992,
#  'home theater store': 0.005,
#  'metal industry supplier': 0.015,
#  'landscaping supply store': 0.252,
#  'appliance part supplier': 0.015,
#  'vacuum cleaner store': 0.589,
#  'audio visual equipment supplier': 0.983,
#  'lawyer': 0.971,
#  'cell phone store': 0.035,
#  'bathroom supply store': 0.015,
#  'leasing service': 0.747,
#  'construction machine dealer': 0.015,
#  'dairy farm equipment supplier': 0.015,
#  'propane supplier': 0.051,
#  'legal service': 0.923,
#  'janitorial equipment supplier': 0.024,
#  'life insurance agency': 0.954,
#  'railroad contractor': 0.373,
#  'swimming pool supply store': 0.959,
#  'light bulb supplier': 0.977,
#  'linen store': 0.021,
#  'metal construction company': 0.971,
#  'local government office': 0.712,
#  'logging contractor': 0.016,
#  'machine shop': 0.916,
#  'hotel supply store': 0.078,
#  'import export company': 0.026,
#  'sewing company': 0.051,
#  'research foundation': 0.752,
#  'machinery part manufacturer': 0.949,
#  'sport accessory wholesaler': 0.851,
#  'fashion designer': 0.021,
#  'cheese manufacturer': 0.793,
#  'cheese shop': 0.793,
#  'shipping mailing': 0.203,
#  'wholesale food store': 0.015,
#  'organic food store': 0.376,
#  'pie shop': 0.014,
#  'auction house': 0.118,
#  'livestock auction house': 0.015,
#  'cotton exporter': 0.165,
#  'plastic wholesaler': 0.015,
#  'mailing service': 0.203,
#  'manufacturer': 0.005,
#  'gas station': 0.421,
#  'beer distributor': 0.015,
#  'alcoholic beverage wholesaler': 0.194,
#  'religious good store': 0.021,
#  'book wholesaler': 0.727,
#  'masonry supply store': 0.248,
#  'wholesale florist': 0.834,
#  'florist': 0.878,
#  'marine engineer': 0.021,
#  'paint store': 0.391,
#  'used auto part store': 0.024,
#  'masonry contractor': 0.878,
#  'used car dealer': 0.92,
#  'used truck dealer': 0.92,
#  'massage therapist': 0.968,
#  'material handling equipment supplier': 0.015,
#  'marina': 0.98,
#  'meat packer': 0.015,
#  'mattress store': 0.728,
#  'blind shop': 0.527,
#  'interior designer': 0.021,
#  'window treatment store': 0.635,
#  'appliance store': 0.421,
#  'health food store': 0.435,
#  'direct mail advertising': 0.977,
#  'meat wholesaler': 0.984,
#  'butcher shop deli': 0.244,
#  'italian grocery store': 0.947,
#  'market': 0.021,
#  'food service': 0.828,
#  'grocery delivery service': 0.829,
#  'wine store': 0.907,
#  'liquor store': 0.907,
#  'kiosk': 0.078,
#  'optometrist': 0.967,
#  'optician': 0.913,
#  'mechanical contractor': 0.802,
#  'mechanical engineer': 0.021,
#  'cafe': 0.078,
#  'jeweler': 0.874,
#  'leather good store': 0.415,
#  'gift shop': 0.884,
#  'craft store': 0.475,
#  'hobby store': 0.497,
#  'fabric wholesaler': 0.256,
#  'scrap metal dealer': 0.015,
#  'quilt shop': 0.525,
#  'sheet music store': 0.475,
#  'musical instrument manufacturer': 0.32,
#  'music store': 0.475,
#  'musical instrument store': 0.885,
#  'band': 0.044,
#  'bookstore': 0.051,
#  'art museum': 0.933,
#  'newsstand': 0.861,
#  'medical equipment manufacturer': 0.998,
#  'fashion accessory store': 0.942,
#  'discount store': 0.498,
#  'cemetery': 0.902,
#  'bus stop': 0.944,
#  'variety store': 0.496,
#  'thrift store': 0.881,
#  'medical group': 0.493,
#  'donation center': 0.021,
#  'pet store': 0.945,
#  'art gallery': 0.051,
#  'art dealer': 0.051,
#  'housing development': 0.037,
#  'mobile home dealer': 0.051,
#  'convenience store': 0.948,
#  'medical office': 0.835,
#  'medical technology manufacturer': 0.35,
#  'childrens furniture store': 0.63,
#  'mental health clinic': 0.833,
#  'airline': 0.021,
#  'aviation consultant': 0.021,
#  'travel agency': 0.901,
#  'travel service': 0.801,
#  'airport': 0.021,
#  'mental health service': 0.946,
#  'shipping company': 0.021,
#  'metal fabricator': 0.972,
#  'cruise line company': 0.021,
#  'towing service': 0.941,
#  'ferry terminal': 0.927,
#  'ferry service': 0.021,
#  'metal finisher': 0.971,
#  'boat tour agency': 0.895,
#  'bus company': 0.945,
#  'moving company': 0.021,
#  'moving storage service': 0.021,
#  'state department transportation': 0.037,
#  'department transportation': 0.037,
#  'handicapped transportation service': 0.129,
#  'railway service': 0.021,
#  'train station': 0.336,
#  'bus depot': 0.944,
#  'bus charter': 0.94,
#  'metal processing company': 0.972,
#  'mixed use': 0.046,
#  'motorcycle shop': 0.827,
#  'limousine service': 0.021,
#  'chauffeur service': 0.021,
#  'school bus service': 0.946,
#  'airport shuttle service': 0.021,
#  'tourist information center': 0.024,
#  'carriage ride service': 0.021,
#  'cruise agency': 0.024,
#  'tourist attraction': 0.024,
#  'ski resort': 0.988,
#  'ski area': 0.044,
#  'fixed base operator': 0.021,
#  'aircraft maintenance company': 0.021,
#  'motorsports store': 0.388,
#  'boat rental service': 0.963,
#  'utility trailer dealer': 0.046,
#  'forklift dealer': 0.015,
#  'municipal administration office': 0.605,
#  'nephrologist': 0.027,
#  'bus coach company': 0.942,
#  'shipping service': 0.203,
#  'shipping mailing service': 0.203,
#  'newspaper publisher': 0.852,
#  'shredding service': 0.024,
#  'nuclear power company': 0.935,
#  'nursing home': 0.797,
#  'medium company': 0.021,
#  'multimedia electronic book publisher': 0.903,
#  'internet marketing service': 0.021,
#  'greeting card shop': 0.955,
#  'theme park': 0.971,
#  'film production company': 0.035,
#  'obstetrician gynecologist': 0.939,
#  'movie studio': 0.345,
#  'video production service': 0.035,
#  'movie theater': 0.928,
#  'theater company': 0.044,
#  'performing art theater': 0.913,
#  'occupational safety health': 0.021,
#  'office space rental agency': 0.474,
#  'commercial real estate agency': 0.944,
#  'art school': 0.96,
#  'music publisher': 0.567,
#  'printed music publisher': 0.567,
#  'home audio store': 0.005,
#  'musician': 0.905,
#  'music management promotion': 0.044,
#  'video editing service': 0.035,
#  'office supply wholesaler': 0.247,
#  'official residence': 0.046,
#  'orthopedic clinic': 0.854,
#  'painter': 0.035,
#  'painting': 0.827,
#  'telephone company': 0.035,
#  'medium house': 0.948,
#  'paper distributor': 0.015,
#  'news service': 0.051,
#  'public library': 0.035,
#  'law library': 0.547,
#  'museum': 0.765,
#  'federal reserve bank': 0.949,
#  'credit union': 0.969,
#  'atm': 0.026,
#  'paving contractor': 0.813,
#  'mortgage lender': 0.927,
#  'investment bank': 0.658,
#  'check cashing service': 0.026,
#  'stock broker': 0.026,
#  'health consultant': 0.021,
#  'health insurance agency': 0.99,
#  'payroll service': 0.906,
#  'pediatrician': 0.939,
#  'human resource consulting': 0.922,
#  'pest control service': 0.024,
#  'pet boarding service': 0.85,
#  'pet care': 0.893,
#  'loss adjuster': 0.954,
#  'pharmaceutical company': 0.981,
#  'pharmaceutical product wholesaler': 0.81,
#  'pharmacy': 0.707,
#  'educational institution': 0.601,
#  'retirement community': 0.39,
#  'fraternal organization': 0.91,
#  'photo lab': 0.021,
#  'property investment': 0.046,
#  'photographer': 0.333,
#  'photography school': 0.021,
#  'star hotel': 0.949,
#  'convention center': 0.024,
#  'real estate appraiser': 0.893,
#  'photography service': 0.021,
#  'resort hotel': 0.834,
#  'real estate consultant': 0.944,
#  'car rental agency': 0.895,
#  'car leasing service': 0.898,
#  'ford dealer': 0.964,
#  'car finance loan company': 0.937,
#  'trailer rental service': 0.929,
#  'furniture rental service': 0.046,
#  'tuxedo shop': 0.046,
#  'dress tuxedo rental service': 0.943,
#  'wedding store': 0.245,
#  'video store': 0.606,
#  'movie rental': 0.035,
#  'photography studio': 0.021,
#  'home health care service': 0.523,
#  'skateboard shop': 0.697,
#  'event technology service': 0.024,
#  'party equipment rental service': 0.908,
#  'construction machine rental service': 0.745,
#  'audio visual equipment rental service': 0.005,
#  'shipping equipment industry': 0.015,
#  'physical therapy clinic': 0.825,
#  'plastic fabrication company': 0.136,
#  'plastic product supplier': 0.19,
#  'auto tag agency': 0.76,
#  'department motor vehicle': 0.037,
#  'notary public': 0.021,
#  'private investigator': 0.024,
#  'escrow service': 0.026,
#  'real estate agent': 0.944,
#  'playground': 0.044,
#  'plumber': 0.035,
#  'port authority': 0.684,
#  'portrait studio': 0.021,
#  'post office': 0.203,
#  'professional service': 0.726,
#  'university hospital': 0.027,
#  'public relation firm': 0.196,
#  'civil engineering company': 0.035,
#  'drafting service': 0.964,
#  'pump supplier': 0.994,
#  'interior construction contractor': 0.463,
#  'carpet cleaning service': 0.024,
#  'exhibition planner': 0.024,
#  'decal supplier': 0.005,
#  'stage lighting equipment supplier': 0.97,
#  'event management company': 0.024,
#  'radio broadcaster': 0.005,
#  'computer support service': 0.472,
#  'ravine': 0.044,
#  'employment center': 0.024,
#  'national health foundation': 0.021,
#  'real estate developer': 0.035,
#  'advertising agency': 0.953,
#  'promotional product supplier': 0.021,
#  'advertising service': 0.949,
#  'record storage facility': 0.046,
#  'fund management company': 0.691,
#  'recreation center': 0.981,
#  'bakery': 0.933,
#  'database management company': 0.035,
#  'market researcher': 0.021,
#  'recycling center': 0.015,
#  'regional government office': 0.671,
#  'rehabilitation center': 0.696,
#  'religious institution': 0.917,
#  'religious organization': 0.898,
#  'repair service': 0.943,
#  'emergency veterinarian service': 0.021,
#  'pet sitter': 0.021,
#  'research product development': 0.663,
#  'building society': 0.901,
#  'valet parking service': 0.851,
#  'nursing agency': 0.815,
#  'executive search firm': 0.024,
#  'recruiter': 0.024,
#  'temp agency': 0.024,
#  'health center': 0.849,
#  'restaurant': 0.924,
#  'roofing contractor': 0.883,
#  'sport nutrition store': 0.744,
#  'credit reporting agency': 0.024,
#  'automobile storage facility': 0.839,
#  'debt collection agency': 0.208,
#  'park': 0.021,
#  'court reporter': 0.024,
#  'bus tour agency': 0.024,
#  'tour operator': 0.024,
#  'convention information bureau': 0.024,
#  'balloon ride tour agency': 0.898,
#  'security guard service': 0.921,
#  'locksmith': 0.704,
#  'commercial cleaning service': 0.024,
#  'blast cleaning service': 0.024,
#  'conference center': 0.024,
#  'safety equipment supplier': 0.015,
#  'garbage dump': 0.978,
#  'sanitation service': 0.024,
#  'garbage dump service': 0.024,
#  'environmental health service': 0.021,
#  'portable toilet supplier': 0.024,
#  'public work department': 0.037,
#  'school district office': 0.579,
#  'sailmaker': 0.014,
#  'community college': 0.607,
#  'salvage yard': 0.015,
#  'business school': 0.556,
#  'trade school': 0.557,
#  'private university': 0.6,
#  'computer training school': 0.643,
#  'school supply store': 0.015,
#  'screen printer': 0.612,
#  'medium consultant': 0.952,
#  'beauty school': 0.593,
#  'flight school': 0.613,
#  'seaport': 0.021,
#  'security system supplier': 0.024,
#  'middle school': 0.579,
#  'nonprofit': 0.021,
#  'shooting range': 0.044,
#  'soccer club': 0.296,
#  'camp': 0.92,
#  'diving contractor': 0.024,
#  'language school': 0.869,
#  'english language school': 0.869,
#  'preschool': 0.843,
#  'self storage facility': 0.046,
#  'semi conductor supplier': 0.271,
#  'driving school': 0.834,
#  'trucking school': 0.805,
#  'senior citizen center': 0.616,
#  'service': 0.021,
#  'childrens hospital': 0.733,
#  'dental supply store': 0.005,
#  'shipyard': 0.39,
#  'orthodox synagogue': 0.916,
#  'short term apartment rental agency': 0.481,
#  'nutritionist': 0.967,
#  'ophthalmologist': 0.027,
#  'ophthalmology clinic': 0.827,
#  'social service organization': 0.956,
#  'social welfare center': 0.947,
#  'solar energy company': 0.909,
#  'solar energy equipment supplier': 0.936,
#  'special education school': 0.579,
#  'podiatrist': 0.971,
#  'reproductive health clinic': 0.962,
#  'sporting good store': 0.887,
#  'dialysis center': 0.956,
#  'sport complex': 0.471,
#  'wellness program': 0.026,
#  'sportswear store': 0.475,
#  'private hospital': 0.027,
#  'radiologist': 0.888,
#  'medical diagnostic imaging center': 0.684,
#  'ray lab': 0.559,
#  'blood bank': 0.746,
#  'stainless steel plant': 0.956,
#  'state agency': 0.636,
#  'heliport': 0.021,
#  'health care company': 0.854,
#  'psychiatric hospital': 0.721,
#  'state government office': 0.712,
#  'medical institution': 0.691,
#  'steel construction company': 0.854,
#  'cleaning service': 0.024,
#  ...}

# %%
test = model.retrieve_docs('agricultural production', normalization='stem')
df.iloc[test][['naics','title']]
# Out:
#       naics                                              title
# 306  327999  All Other Miscellaneous Nonmetallic Mineral Pr...
# 302  327910                     Abrasive Product Manufacturing
# 303  327991         Cut Stone and Stone Product Manufacturing
# 305  327993                        Mineral Wool Manufacturing
# 301  327420                       Gypsum Product Manufacturing
# 165  311710          Seafood Product Preparation and Packaging
# 304  327992  Ground or Treated Mineral and Earth Manufactur...
# 294  327215  Glass Product Manufacturing Made of Purchased ...
# 157  311512                     Creamery Butter Manufacturing
# 159  311514  Dry, Condensed, and Evaporated Dairy Product M...

# %%
relevant_naics[relevant_naics['query'] =='Agricultural production']
# Out:
#                       query                                     relevant_naics
# 12  Agricultural production  [111998, 111991, 111992, 111910, 111920, 11193...

# %% [markdown]
# # Stemming

# %%
df = pd.read_pickle(r'assets/processed_df.pkl')
docs = dict(zip(df['naics'], df['stemmed']))

# %%
model = RocchioRecommenderSystem(docs, beta=1.2, gamma=.05)

# %%
for row in relevant_naics.iterrows():
    best_index = model.retrieve_docs(row[1]['query'], normalization='stem')
    feedback = []
    for rel_code in row[1]['relevant_naics']:
        idx = np.where(df['naics'].values == str(rel_code))[0][0]
        if rel_code in df.iloc[best_index]['naics'].values:
            feedback.append((1, idx))
        else:
            feedback.append((0, idx))
    model.gather_feedback(row[1]['query'], feedback=feedback, max_docs=max_docs, normalization='stem')

# %%
ret_docs_dic = {}
queries_dic = {}

for query in relevant_naics.iterrows():
    query_name =  ' '.join(process_query(query[1]['query'], 'stem'))
    ret_docs_index = model.retrieve_docs(query_name, max_docs=max_docs, normalization='stem')
    ret_docs = df.iloc[ret_docs_index]['naics'].tolist()

    query_docs = query[1]['relevant_naics']
    ret_docs_dic[query_name] = ret_docs
    queries_dic[query_name] = query_docs

# %%
calc_pre_rec_at_n(ret_docs_dic, queries_dic, n=-1)[0]
# Out:
# {'home improv store': 0.4,
#  'diesel fuel supplier': 0.0,
#  'church': 0.0,
#  'farm': 1.0,
#  'seed supplier': 0.0,
#  'account': 1.0,
#  'truck compani': 0.6,
#  'export': 0.0,
#  'grain elev': 0.0,
#  'popcorn store': 0.9,
#  'agricultur servic': 0.0,
#  'warehous': 0.4,
#  'agricultur product': 1.0,
#  'ranch': 1.0,
#  'hold compani': 0.3,
#  'farm equip supplier': 0.0,
#  'store': 0.9,
#  'groceri store': 0.9,
#  'rice mill': 1.0,
#  'food product supplier': 0.0,
#  'account firm': 0.0,
#  'produc market': 0.0,
#  'pet suppli store': 0.9,
#  'wholesal': 1.0,
#  'produc wholesal': 1.0,
#  'distribut servic': 0.0,
#  'crop grower': 1.0,
#  'addict treatment center': 1.0,
#  'natur good store': 0.0,
#  'orchard': 1.0,
#  'lumber store': 0.0,
#  'mine': 1.0,
#  'transport servic': 1.0,
#  'invest compani': 1.0,
#  'fruit wholesal': 0.1,
#  'real estat agenc': 1.0,
#  'event venu': 0.0,
#  'frozen dessert supplier': 1.0,
#  'wine wholesal import': 0.3,
#  'wineri': 0.7,
#  'aerospac compani': 1.0,
#  'cold storag facil': 0.4,
#  'employ agenc': 0.0,
#  'plant nurseri': 0.0,
#  'air condit contractor': 1.0,
#  'air condit repair servic': 0.0,
#  'fruit veget wholesal': 0.0,
#  'aircraft rental servic': 1.0,
#  'monasteri': 1.0,
#  'allergist': 1.0,
#  'herb shop': 0.2,
#  'aluminum supplier': 1.0,
#  'ambul servic': 0.0,
#  'wholesal plant nurseri': 1.0,
#  'amus machin supplier': 0.0,
#  'anim hospit': 0.0,
#  'farmer market': 0.0,
#  'vapor store': 0.9,
#  'cigar shop': 0.9,
#  'tobacco shop': 0.0,
#  'well drill contractor': 0.0,
#  'librari': 1.0,
#  'apart build': 0.0,
#  'apart rental agenc': 1.0,
#  'dairi farm': 1.0,
#  'architect': 1.0,
#  'organ farm': 1.0,
#  'architectur design': 1.0,
#  'architectur firm': 1.0,
#  'livestock produc': 0.0,
#  'dairi supplier': 0.0,
#  'biotechnolog compani': 0.4,
#  'artist': 1.0,
#  'egg supplier': 1.0,
#  'poultri farm': 0.0,
#  'chicken hatcheri': 1.0,
#  'art organ': 1.0,
#  'associ organ': 1.0,
#  'food store': 0.9,
#  'deli': 0.0,
#  'bank': 1.0,
#  'fish process': 0.0,
#  'fish farm': 1.0,
#  'seafood wholesal': 0.6,
#  'tropic fish store': 0.9,
#  'non profit organ': 1.0,
#  'econom develop agenc': 1.0,
#  'seafood market': 0.9,
#  'honey farm': 1.0,
#  'hors breeder': 0.0,
#  'asphalt contractor': 1.0,
#  'livestock dealer': 0.0,
#  'depart store': 1.0,
#  'mill': 0.0,
#  'atv dealer': 1.0,
#  'audio visual consult': 0.0,
#  'pallet supplier': 0.0,
#  'wood supplier': 0.0,
#  'hardwar store': 0.0,
#  'furnitur wholesal': 0.0,
#  'auditor': 0.8,
#  'oil natur compani': 1.0,
#  'auto bodi shop': 1.0,
#  'boat repair shop': 0.0,
#  'associ': 1.0,
#  'rail contractor': 0.0,
#  'publish': 1.0,
#  'pond suppli store': 0.0,
#  'agricultur cooper': 0.0,
#  'print equip supplier': 1.0,
#  'auto insur agenc': 1.0,
#  'altern fuel station': 0.4,
#  'auto part manufactur': 1.0,
#  'foundat': 1.0,
#  'fertil supplier': 1.0,
#  'farm compani': 1.0,
#  'financ broker': 1.0,
#  'fire station': 0.0,
#  'environment consult': 1.0,
#  'civil engin': 1.0,
#  'fire protect servic': 0.0,
#  'compani': 0.0,
#  'oilfield': 0.0,
#  'banquet hall': 0.8,
#  'mine compani': 1.0,
#  'coalfield': 0.0,
#  'steel fabric': 0.0,
#  'quarri': 1.0,
#  'gold mine compani': 1.0,
#  'high rise build': 1.0,
#  'basketbal club': 0.7,
#  'gold dealer': 0.0,
#  'batteri manufactur': 1.0,
#  'electr util compani': 0.0,
#  'environment program': 0.0,
#  'offic': 0.0,
#  'stone supplier': 0.0,
#  'aggreg supplier': 0.0,
#  'sand gravel supplier': 0.0,
#  'build materi supplier': 0.6,
#  'beauti suppli store': 0.5,
#  'crush stone supplier': 0.0,
#  'rock shop': 0.0,
#  'road construct compani': 1.0,
#  'market consult': 0.9,
#  'blood test servic': 1.0,
#  'contractor': 1.0,
#  'excav contractor': 1.0,
#  'asphalt mix plant': 0.9,
#  'readi mix concret supplier': 1.0,
#  'sand plant': 0.0,
#  'bmw dealer': 1.0,
#  'bookbind': 0.4,
#  'garden center': 0.6,
#  'abras supplier': 0.0,
#  'granit supplier': 0.0,
#  'drill contractor': 0.0,
#  'bpo compani': 1.0,
#  'oil explor servic': 1.0,
#  'build complex': 0.0,
#  'construct equip supplier': 0.0,
#  'mine equip': 0.0,
#  'ticket agenc': 0.0,
#  'busi center': 0.0,
#  'skyscrap': 0.0,
#  'softwar compani': 1.0,
#  'busi develop servic': 0.4,
#  'busi manag consult': 0.8,
#  'cabinet maker': 1.0,
#  'call center': 0.0,
#  'cancer treatment center': 1.0,
#  'power plant consult': 0.0,
#  'busi park': 1.0,
#  'petroleum product compani': 0.0,
#  'park lot': 0.0,
#  'water util compani': 1.0,
#  'car repair mainten': 1.0,
#  'water treatment plant': 1.0,
#  'car servic': 1.0,
#  'cattl market': 0.0,
#  'sewag dispos servic': 0.9,
#  'certifi public account': 0.0,
#  'govern offic': 1.0,
#  'chariti': 1.0,
#  'air condit system supplier': 0.0,
#  'chemic industri': 1.0,
#  'chemic manufactur': 1.0,
#  'titl compani': 0.0,
#  'chemic plant': 1.0,
#  'properti manag compani': 0.0,
#  'custom home builder': 1.0,
#  'window instal servic': 0.0,
#  'fire damag restor servic': 0.0,
#  'equip rental agenc': 1.0,
#  'chemic wholesal': 0.0,
#  'financi planner': 1.0,
#  'telecommun servic provid': 1.0,
#  'energi equip solut': 0.0,
#  'chiropractor': 1.0,
#  'steel distributor': 0.0,
#  'citi govern offic': 1.0,
#  'crane servic': 0.0,
#  'garag door supplier': 0.0,
#  'industri door supplier': 0.0,
#  'citi town hall': 0.0,
#  'cloth wholesal': 0.1,
#  'coin oper laundri equip supplier': 1.0,
#  'metal supplier': 0.0,
#  'glass shop': 0.0,
#  'colleg': 1.0,
#  'side contractor': 1.0,
#  'commerci printer': 0.0,
#  'storag facil': 0.4,
#  'commun tower': 0.0,
#  'janitori servic': 0.0,
#  'comput consult': 1.0,
#  'fire protect system supplier': 0.0,
#  'elev servic': 0.0,
#  'industri equip supplier': 0.0,
#  'dri wall contractor': 1.0,
#  'insul contractor': 1.0,
#  'concret contractor': 1.0,
#  'scaffold rental servic': 1.0,
#  'construct compani': 1.0,
#  'floor store': 0.4,
#  'floor contractor': 1.0,
#  'tile contractor': 1.0,
#  'tile manufactur': 0.0,
#  'glass mirror shop': 0.0,
#  'construct materi wholesal': 0.0,
#  'gutter clean servic': 0.0,
#  'sheet metal contractor': 1.0,
#  'consult': 0.9,
#  'contain servic': 0.0,
#  'septic system servic': 0.0,
#  'corpor campu': 0.0,
#  'water damag restor servic': 0.0,
#  'welder': 0.0,
#  'corpor offic': 0.0,
#  'anim': 1.0,
#  'anim feed store': 0.0,
#  'anim protect organ': 0.0,
#  'brew suppli store': 0.0,
#  'cosmet store': 0.5,
#  'counti govern offic': 1.0,
#  'sugar factori': 1.0,
#  'confectioneri wholesal': 0.5,
#  'financi institut': 0.0,
#  'candi store': 0.9,
#  'confectioneri': 0.0,
#  'chocol factori': 1.0,
#  'chocol shop': 0.6,
#  'courier servic': 0.3,
#  'cowork space': 0.0,
#  'frozen food manufactur': 1.0,
#  'beverag distributor': 0.0,
#  'agricultur organ': 0.0,
#  'dairi store': 0.0,
#  'dairi': 1.0,
#  'ice cream shop': 0.7,
#  'medic laboratori': 1.0,
#  'demolit contractor': 1.0,
#  'meat processor': 0.9,
#  'fmcg manufactur': 0.0,
#  'garbag collect servic': 0.0,
#  'wholesal bakeri': 0.9,
#  'dentist': 1.0,
#  'dessert shop': 0.0,
#  'cupcak shop': 0.0,
#  'nut store': 0.9,
#  'wholesal grocer': 1.0,
#  'design engin': 1.0,
#  'busi busi servic': 1.0,
#  'condiment supplier': 1.0,
#  'digit print servic': 0.4,
#  'culinari school': 1.0,
#  'import': 0.0,
#  'bottl water supplier': 0.7,
#  'coffe roaster': 0.0,
#  'packag suppli store': 0.0,
#  'ice supplier': 0.7,
#  'breweri': 0.7,
#  'winemak compani': 0.0,
#  'distilleri': 0.7,
#  'disabl servic support organis': 0.0,
#  'district govern offic': 1.0,
#  'air filter supplier': 0.0,
#  'tire shop': 0.7,
#  'fasten supplier': 1.0,
#  'fabric product manufactur': 1.0,
#  'textil': 1.0,
#  'textil export': 1.0,
#  'textil engin': 1.0,
#  'fabric store': 0.9,
#  'knit shop': 1.0,
#  'doctor': 1.0,
#  'lamin servic': 0.0,
#  'plastic resin manufactur': 0.8,
#  'carpet manufactur': 1.0,
#  'upholsteri shop': 1.0,
#  'busi administr servic': 0.0,
#  'furnitur store': 0.1,
#  'dri cleaner': 0.0,
#  'packag compani': 1.0,
#  'duti free store': 0.9,
#  'commerc servic': 0.0,
#  'cabl compani': 0.0,
#  'educ': 1.0,
#  'outlet store': 0.9,
#  'lingeri store': 1.0,
#  'cloth fabric manufactur': 0.1,
#  'educ center': 1.0,
#  'uniform store': 0.9,
#  'men cloth store': 0.9,
#  'cloth store': 0.9,
#  'women cloth store': 0.9,
#  'western apparel store': 0.0,
#  'costum store': 0.0,
#  'game store': 1.0,
#  'hat shop': 0.2,
#  'leather good manufactur': 0.5,
#  'educ consult': 1.0,
#  'leather export': 0.4,
#  'shoe store': 1.0,
#  'boutiqu': 0.0,
#  'leather wholesal': 0.2,
#  'handbag shop': 0.4,
#  'electron store': 0.2,
#  'luggag store': 0.6,
#  'build materi store': 0.6,
#  'saw mill': 1.0,
#  'electr engin': 0.0,
#  'deck builder': 1.0,
#  'concret product supplier': 1.0,
#  'plywood supplier': 1.0,
#  'electr instal servic': 0.0,
#  'truss manufactur': 0.9,
#  'door supplier': 0.0,
#  'wood lamin floor supplier': 1.0,
#  'aircraft suppli store': 0.0,
#  'modular home builder': 0.0,
#  'portabl build manufactur': 1.0,
#  'modular home dealer': 0.1,
#  'mulch supplier': 0.0,
#  'electrician': 0.0,
#  'paper mill': 1.0,
#  'energi supplier': 1.0,
#  'engin': 0.0,
#  'print shop': 0.4,
#  'custom label printer': 0.0,
#  'market': 0.0,
#  'market agenc': 0.0,
#  'engin consult': 0.9,
#  'entertain': 1.0,
#  'envelop supplier': 0.0,
#  'oil refineri': 0.5,
#  'record studio': 1.0,
#  'environ renew natur resourc': 0.0,
#  'finish materi supplier': 0.6,
#  'event ticket seller': 0.0,
#  'waterproof compani': 0.0,
#  'auto part store': 0.0,
#  'heat oil supplier': 0.0,
#  'famili practic physician': 1.0,
#  'machin manufactur': 1.0,
#  'industri supplier': 0.0,
#  'weld suppli store': 0.0,
#  'dri ice supplier': 1.0,
#  'privat equiti firm': 0.0,
#  'famili servic center': 1.0,
#  'feder govern offic': 1.0,
#  'vitamin supplement store': 0.5,
#  'feed manufactur': 0.5,
#  'medic equip supplier': 0.0,
#  'medic suppli store': 0.0,
#  'medic clinic': 1.0,
#  'research institut': 1.0,
#  'biochem supplier': 0.0,
#  'fiber optic product supplier': 0.0,
#  'paint manufactur': 1.0,
#  'equip supplier': 0.0,
#  'food': 0.0,
#  'pipe supplier': 1.0,
#  'oil field equip supplier': 0.0,
#  'food broker': 0.0,
#  'food manufactur': 1.0,
#  'food process compani': 0.0,
#  'fenc suppli store': 0.5,
#  'food produc': 0.0,
#  'forestri servic': 1.0,
#  'foundri': 1.0,
#  'wholesal jewel': 1.0,
#  'cooki shop': 0.9,
#  'truck rental agenc': 1.0,
#  'fruit veget process': 1.0,
#  'kitchen suppli store': 0.0,
#  'hydraul equip supplier': 0.0,
#  'irrig equip supplier': 0.0,
#  'bear supplier': 1.0,
#  'metallurgi compani': 0.0,
#  'plastic inject mold servic': 0.0,
#  'gener contractor': 1.0,
#  'gener hospit': 0.9,
#  'tool manufactur': 0.0,
#  'industri design compani': 0.0,
#  'hyundai dealer': 0.0,
#  'glass industri': 1.0,
#  'polym supplier': 0.0,
#  'print equip suppli': 0.0,
#  'toner cartridg supplier': 1.0,
#  'printer repair servic': 1.0,
#  'fuel supplier': 0.0,
#  'glass manufactur': 1.0,
#  'plastic bag supplier': 1.0,
#  'glasswar manufactur': 0.0,
#  'polythen plastic sheet supplier': 1.0,
#  'pvc industri': 0.0,
#  'countertop store': 1.0,
#  'cabinet store': 1.0,
#  'fiberglass supplier': 0.0,
#  'golf cart dealer': 1.0,
#  'auto repair shop': 1.0,
#  'hose supplier': 1.0,
#  'rubber product supplier': 0.9,
#  'automot': 0.0,
#  'commerci refriger supplier': 0.0,
#  'golf club': 1.0,
#  'golf cours': 0.0,
#  'green energi supplier': 1.0,
#  'greenhous': 0.0,
#  'auto glass shop': 0.0,
#  'light manufactur': 1.0,
#  'cement manufactur': 1.0,
#  'brick manufactur': 1.0,
#  'natur stone supplier': 0.0,
#  'gym': 1.0,
#  'marbl supplier': 0.0,
#  'corpor gift supplier': 0.9,
#  'shipbuild repair compani': 0.0,
#  'construct mainten offic': 1.0,
#  'boiler manufactur': 1.0,
#  'contain supplier': 0.0,
#  'home construct': 1.0,
#  'health': 1.0,
#  'heart hospit': 1.0,
#  'spring supplier': 1.0,
#  'electr util manufactur': 0.0,
#  'aircraft manufactur': 1.0,
#  'metal heat treat servic': 1.0,
#  'plate servic': 0.0,
#  'autom compani': 0.0,
#  'heat contractor': 1.0,
#  'plumb suppli store': 0.0,
#  'gun shop': 0.0,
#  'ammunit supplier': 1.0,
#  'pipe manufactur': 1.0,
#  'school': 1.0,
#  'fire protect equip supplier': 0.0,
#  'agricultur machineri manufactur': 0.0,
#  'lawn mower store': 0.5,
#  'lawn irrig equip supplier': 0.0,
#  'financi consult': 0.3,
#  'helicopt charter': 1.0,
#  'packag machineri': 0.0,
#  'histor landmark': 1.0,
#  'electron manufactur': 1.0,
#  'graphic design': 0.9,
#  'eye care center': 1.0,
#  'optic product manufactur': 1.0,
#  'imag consult': 0.9,
#  'clean product supplier': 0.0,
#  'fireplac store': 0.0,
#  'home builder': 1.0,
#  'tool die shop': 1.0,
#  'metal stamp servic': 1.0,
#  'environment organ': 1.0,
#  'food process equip': 0.0,
#  'loan agenc': 1.0,
#  'power plant equip supplier': 0.0,
#  'home good store': 0.4,
#  'engin rebuild servic': 0.0,
#  'air compressor supplier': 0.0,
#  'honda dealer': 1.0,
#  'elev manufactur': 1.0,
#  'crane dealer': 0.0,
#  'crane rental agenc': 1.0,
#  'compound build': 0.0,
#  'tractor dealer': 0.0,
#  'furnac part supplier': 0.0,
#  'heat equip supplier': 0.0,
#  'pneumat tool supplier': 0.0,
#  'truck stop': 0.0,
#  'comput hardwar manufactur': 1.0,
#  'satellit commun servic': 1.0,
#  'hospit': 1.0,
#  'electron compani': 0.0,
#  'electron part supplier': 0.0,
#  'hvac contractor': 1.0,
#  'industri engin': 0.3,
#  'contact lens supplier': 0.0,
#  'inform servic': 1.0,
#  'build': 1.0,
#  'water work equip supplier': 0.0,
#  'measur instrument supplier': 1.0,
#  'scientif equip supplier': 0.0,
#  'medic center': 1.0,
#  'watch manufactur': 0.0,
#  'corpor entertain servic': 0.0,
#  'insur': 1.0,
#  'record compani': 1.0,
#  'video duplic servic': 0.0,
#  'insur agenc': 1.0,
#  'light store': 1.0,
#  'light wholesal': 1.0,
#  'entertain agenc': 1.0,
#  'insur broker': 1.0,
#  'electr equip supplier': 0.0,
#  'electr motor store': 1.0,
#  'railroad compani': 0.9,
#  'electr suppli store': 0.0,
#  'insur compani': 1.0,
#  'factori equip supplier': 0.0,
#  'invest servic': 1.0,
#  'laser equip supplier': 1.0,
#  'execut suit rental agenc': 0.0,
#  'truck dealer': 0.0,
#  'motor vehicl dealer': 0.7,
#  'car dealer': 1.0,
#  'truck topper supplier': 0.0,
#  'polic suppli store': 0.9,
#  'iron steel contractor': 1.0,
#  'fire depart equip supplier': 0.0,
#  'tow equip provid': 1.0,
#  'logist servic': 0.9,
#  'trailer manufactur': 1.0,
#  'trailer dealer': 0.0,
#  'dealer': 1.0,
#  'auto spring shop': 0.0,
#  'auto upholster': 1.0,
#  'auto bodi part supplier': 0.7,
#  'car factori': 0.0,
#  'freight forward servic': 1.0,
#  'brake shop': 1.0,
#  'railroad equip supplier': 0.0,
#  'jewelri equip supplier': 1.0,
#  'boat builder': 0.0,
#  'ship build': 0.0,
#  'marin suppli store': 0.5,
#  'boat dealer': 0.8,
#  'kawasaki motorcycl dealer': 1.0,
#  'knife manufactur': 1.0,
#  'labor union': 1.0,
#  'furnitur maker': 1.0,
#  'bank financ': 1.0,
#  'furnitur manufactur': 1.0,
#  'logist': 0.9,
#  'massag suppli store': 0.0,
#  'telecommun equip supplier': 0.0,
#  'babi store': 0.8,
#  'mold supplier': 0.0,
#  'offic equip supplier': 0.0,
#  'offic furnitur store': 1.0,
#  'store equip supplier': 0.0,
#  'laboratori': 0.0,
#  'health beauti shop': 0.0,
#  'learn center': 1.0,
#  'dental laboratori': 1.0,
#  'land surveyor': 0.0,
#  'educ suppli store': 0.9,
#  'jewelri store': 0.9,
#  'playground equip supplier': 0.0,
#  'outdoor sport store': 1.0,
#  'toy store': 1.0,
#  'secur servic': 0.0,
#  'sign shop': 1.0,
#  'offic suppli store': 0.9,
#  'landscap': 1.0,
#  'gasket manufactur': 1.0,
#  'piano maker': 0.0,
#  'piano store': 0.9,
#  'funer home': 0.0,
#  'monument': 0.0,
#  'book publish': 1.0,
#  'wig shop': 0.2,
#  'laundromat': 1.0,
#  'auto wrecker': 0.0,
#  'auto part market': 0.7,
#  'jeep dealer': 1.0,
#  'restaur suppli store': 0.0,
#  'roof suppli store': 0.0,
#  'law firm': 0.0,
#  'build materi market': 0.6,
#  'camera store': 0.0,
#  'lawn care servic': 0.0,
#  'comput secur servic': 0.0,
#  'comput store': 0.0,
#  'design agenc': 0.0,
#  'diagnost center': 1.0,
#  'laboratori equip supplier': 1.0,
#  'home theater store': 0.0,
#  'metal industri supplier': 0.0,
#  'landscap suppli store': 0.5,
#  'applianc part supplier': 0.0,
#  'vacuum cleaner store': 0.6,
#  'audio visual equip supplier': 1.0,
#  'lawyer': 0.9,
#  'cell phone store': 0.0,
#  'bathroom suppli store': 0.0,
#  'leas servic': 0.0,
#  'construct machin dealer': 0.0,
#  'dairi farm equip supplier': 0.0,
#  'propan supplier': 0.0,
#  'legal servic': 0.0,
#  'janitori equip supplier': 0.0,
#  'life insur agenc': 1.0,
#  'railroad contractor': 0.5,
#  'swim pool suppli store': 0.9,
#  'light bulb supplier': 1.0,
#  'linen store': 0.0,
#  'metal construct compani': 1.0,
#  'local govern offic': 1.0,
#  'log contractor': 0.0,
#  'machin shop': 0.8,
#  'hotel suppli store': 0.0,
#  'import export compani': 0.0,
#  'sew compani': 0.0,
#  'research foundat': 1.0,
#  'machineri part manufactur': 0.0,
#  'sport accessori wholesal': 0.0,
#  'fashion design': 0.0,
#  'chees manufactur': 0.0,
#  'chees shop': 0.0,
#  'ship mail': 0.3,
#  'wholesal food store': 0.0,
#  'organ food store': 0.9,
#  'pie shop': 0.0,
#  'auction hous': 1.0,
#  'livestock auction hous': 0.0,
#  'cotton export': 1.0,
#  'plastic wholesal': 0.0,
#  'mail servic': 0.3,
#  'manufactur': 1.0,
#  'station': 0.4,
#  'beer distributor': 0.0,
#  'alcohol beverag wholesal': 0.0,
#  'religi good store': 0.0,
#  'book wholesal': 0.4,
#  'masonri suppli store': 0.5,
#  'wholesal florist': 0.1,
#  'florist': 0.9,
#  'marin engin': 0.0,
#  'paint store': 0.5,
#  'use auto part store': 0.0,
#  'masonri contractor': 1.0,
#  'use car dealer': 1.0,
#  'use truck dealer': 0.7,
#  'massag therapist': 1.0,
#  'materi handl equip supplier': 0.0,
#  'marina': 1.0,
#  'meat packer': 0.0,
#  'mattress store': 0.8,
#  'blind shop': 0.0,
#  'interior design': 0.8,
#  'window treatment store': 0.4,
#  'applianc store': 0.2,
#  'health food store': 0.8,
#  'direct mail advertis': 0.4,
#  'meat wholesal': 0.3,
#  'butcher shop deli': 0.2,
#  'italian groceri store': 0.9,
#  'food servic': 0.8,
#  'groceri deliveri servic': 0.3,
#  'wine store': 0.9,
#  'liquor store': 0.9,
#  'kiosk': 0.0,
#  'optometrist': 1.0,
#  'optician': 1.0,
#  'mechan contractor': 1.0,
#  'mechan engin': 0.0,
#  'cafe': 0.0,
#  'jewel': 1.0,
#  'leather good store': 0.9,
#  'gift shop': 0.9,
#  'craft store': 0.9,
#  'hobbi store': 1.0,
#  'fabric wholesal': 0.0,
#  'scrap metal dealer': 0.0,
#  'quilt shop': 0.0,
#  'sheet music store': 1.0,
#  'music instrument manufactur': 1.0,
#  'music store': 1.0,
#  'music instrument store': 1.0,
#  'band': 0.0,
#  'bookstor': 0.0,
#  'art museum': 1.0,
#  'newsstand': 1.0,
#  'medic equip manufactur': 1.0,
#  'fashion accessori store': 0.9,
#  'discount store': 0.9,
#  'cemeteri': 1.0,
#  'stop': 0.0,
#  'varieti store': 0.9,
#  'thrift store': 0.9,
#  'medic group': 1.0,
#  'donat center': 0.0,
#  'pet store': 0.9,
#  'art galleri': 0.0,
#  'art dealer': 0.0,
#  'hous develop': 0.0,
#  'mobil home dealer': 0.2,
#  'conveni store': 1.0,
#  'medic offic': 1.0,
#  'medic technolog manufactur': 1.0,
#  'children furnitur store': 0.1,
#  'mental health clinic': 1.0,
#  'airlin': 0.0,
#  'aviat consult': 0.0,
#  'travel agenc': 1.0,
#  'travel servic': 1.0,
#  'airport': 0.0,
#  'mental health servic': 1.0,
#  'ship compani': 0.0,
#  'metal fabric': 1.0,
#  'cruis line compani': 0.0,
#  'tow servic': 1.0,
#  'ferri termin': 1.0,
#  'ferri servic': 0.0,
#  'metal finish': 1.0,
#  'boat tour agenc': 0.8,
#  'move compani': 0.0,
#  'move storag servic': 0.0,
#  'state depart transport': 0.0,
#  'depart transport': 0.0,
#  'handicap transport servic': 1.0,
#  'railway servic': 0.0,
#  'train station': 0.0,
#  'depot': 0.0,
#  'charter': 1.0,
#  'metal process compani': 1.0,
#  'mix use': 0.0,
#  'motorcycl shop': 0.7,
#  'limousin servic': 0.0,
#  'chauffeur servic': 0.0,
#  'school servic': 0.0,
#  'airport shuttl servic': 0.0,
#  'tourist inform center': 0.0,
#  'carriag ride servic': 0.0,
#  'cruis agenc': 0.0,
#  'tourist attract': 0.0,
#  'ski resort': 1.0,
#  'ski area': 0.0,
#  'fix base oper': 0.0,
#  'aircraft mainten compani': 0.0,
#  'motorsport store': 0.7,
#  'boat rental servic': 1.0,
#  'util trailer dealer': 0.0,
#  'forklift dealer': 0.0,
#  'municip administr offic': 1.0,
#  'nephrologist': 1.0,
#  'coach compani': 0.0,
#  'ship servic': 0.0,
#  'ship mail servic': 0.3,
#  'newspap publish': 1.0,
#  'shred servic': 0.0,
#  'nuclear power compani': 1.0,
#  'nurs home': 0.0,
#  'media compani': 0.8,
#  'multimedia electron book publish': 1.0,
#  'internet market servic': 0.0,
#  'greet card shop': 0.9,
#  'theme park': 1.0,
#  'film product compani': 0.0,
#  'obstetrician gynecologist': 1.0,
#  'movi studio': 1.0,
#  'video product servic': 1.0,
#  'movi theater': 1.0,
#  'theater compani': 0.0,
#  'perform art theater': 1.0,
#  'occup safeti health': 0.0,
#  'offic space rental agenc': 1.0,
#  'commerci real estat agenc': 1.0,
#  'art school': 1.0,
#  'music publish': 1.0,
#  'print music publish': 1.0,
#  'home audio store': 0.0,
#  'musician': 1.0,
#  'music manag promot': 1.0,
#  'video edit servic': 0.0,
#  'offic suppli wholesal': 0.2,
#  'offici resid': 0.0,
#  'orthoped clinic': 1.0,
#  'painter': 0.0,
#  'paint': 0.0,
#  'telephon compani': 0.0,
#  'media hous': 0.8,
#  'paper distributor': 0.0,
#  'news servic': 0.0,
#  'public librari': 0.0,
#  'law librari': 1.0,
#  'museum': 1.0,
#  'feder reserv bank': 1.0,
#  'credit union': 1.0,
#  'atm': 0.0,
#  'pave contractor': 1.0,
#  'mortgag lender': 1.0,
#  'invest bank': 1.0,
#  'check cash servic': 0.0,
#  'stock broker': 0.0,
#  'health consult': 0.9,
#  'health insur agenc': 1.0,
#  'payrol servic': 1.0,
#  'pediatrician': 1.0,
#  'human resourc consult': 0.9,
#  'pest control servic': 0.0,
#  'pet board servic': 1.0,
#  'pet care': 1.0,
#  'loss adjust': 1.0,
#  'pharmaceut compani': 1.0,
#  'pharmaceut product wholesal': 0.6,
#  'pharmaci': 0.5,
#  'educ institut': 1.0,
#  'retir commun': 0.0,
#  'fratern organ': 1.0,
#  'photo lab': 0.0,
#  'properti invest': 0.0,
#  'photograph': 1.0,
#  'photographi school': 0.0,
#  'star hotel': 0.7,
#  'convent center': 0.0,
#  'real estat apprais': 1.0,
#  'photographi servic': 0.0,
#  'resort hotel': 0.7,
#  'real estat consult': 1.0,
#  'car rental agenc': 1.0,
#  'car leas servic': 0.0,
#  'ford dealer': 1.0,
#  'car financ loan compani': 1.0,
#  'trailer rental servic': 1.0,
#  'furnitur rental servic': 0.0,
#  'tuxedo shop': 0.0,
#  'dress tuxedo rental servic': 1.0,
#  'wed store': 1.0,
#  'video store': 0.5,
#  'movi rental': 0.0,
#  'photographi studio': 0.0,
#  'home health care servic': 1.0,
#  'skateboard shop': 0.0,
#  'event technolog servic': 0.0,
#  'parti equip rental servic': 1.0,
#  'construct machin rental servic': 1.0,
#  'audio visual equip rental servic': 0.0,
#  'ship equip industri': 0.0,
#  'physic therapi clinic': 1.0,
#  'plastic fabric compani': 1.0,
#  'plastic product supplier': 1.0,
#  'auto tag agenc': 1.0,
#  'depart motor vehicl': 0.0,
#  'notari public': 0.0,
#  'privat investig': 0.0,
#  'escrow servic': 0.0,
#  'real estat agent': 1.0,
#  'playground': 0.4,
#  'plumber': 0.0,
#  'port author': 1.0,
#  'portrait studio': 0.0,
#  'post offic': 0.0,
#  'profession servic': 0.0,
#  'univers hospit': 0.7,
#  'public relat firm': 0.0,
#  'civil engin compani': 0.0,
#  'draft servic': 1.0,
#  'pump supplier': 0.0,
#  'interior construct contractor': 1.0,
#  'carpet clean servic': 0.0,
#  'exhibit planner': 0.0,
#  'decal supplier': 0.0,
#  'stage light equip supplier': 1.0,
#  'event manag compani': 0.0,
#  'radio broadcast': 0.0,
#  'comput support servic': 0.4,
#  'ravin': 0.0,
#  'employ center': 0.0,
#  'nation health foundat': 0.0,
#  'real estat develop': 0.0,
#  'advertis agenc': 0.0,
#  'promot product supplier': 0.0,
#  'advertis servic': 0.0,
#  'record storag facil': 0.0,
#  'fund manag compani': 1.0,
#  'recreat center': 1.0,
#  'bakeri': 1.0,
#  'databas manag compani': 0.0,
#  'market research': 1.0,
#  'recycl center': 0.0,
#  'region govern offic': 1.0,
#  'rehabilit center': 1.0,
#  'religi institut': 1.0,
#  'religi organ': 1.0,
#  'repair servic': 1.0,
#  'emerg veterinarian servic': 0.0,
#  'pet sitter': 0.0,
#  'research product develop': 1.0,
#  'build societi': 1.0,
#  'valet park servic': 1.0,
#  'nurs agenc': 0.0,
#  'execut search firm': 0.0,
#  'recruit': 1.0,
#  'temp agenc': 0.0,
#  'health center': 1.0,
#  'restaur': 0.8,
#  'roof contractor': 1.0,
#  'sport nutrit store': 0.0,
#  'credit report agenc': 0.0,
#  'automobil storag facil': 0.4,
#  'debt collect agenc': 1.0,
#  'park': 0.0,
#  'court report': 1.0,
#  'tour agenc': 0.0,
#  'tour oper': 1.0,
#  'convent inform bureau': 0.0,
#  'balloon ride tour agenc': 0.8,
#  'secur guard servic': 0.5,
#  'locksmith': 1.0,
#  'commerci clean servic': 0.0,
#  'blast clean servic': 0.0,
#  'confer center': 0.0,
#  'safeti equip supplier': 0.0,
#  'garbag dump': 1.0,
#  'sanit servic': 0.0,
#  'garbag dump servic': 0.0,
#  'environment health servic': 0.0,
#  'portabl toilet supplier': 0.0,
#  'public work depart': 1.0,
#  'school district offic': 1.0,
#  'sailmak': 0.0,
#  'commun colleg': 1.0,
#  'salvag yard': 0.0,
#  'busi school': 1.0,
#  'trade school': 1.0,
#  'privat univers': 0.0,
#  'comput train school': 1.0,
#  'school suppli store': 0.0,
#  'screen printer': 0.4,
#  'media consult': 0.7,
#  'beauti school': 1.0,
#  'flight school': 1.0,
#  'seaport': 0.0,
#  'secur system supplier': 0.0,
#  'middl school': 1.0,
#  'nonprofit': 0.0,
#  'shoot rang': 0.0,
#  'soccer club': 1.0,
#  'camp': 0.7,
#  'dive contractor': 0.0,
#  'languag school': 1.0,
#  'english languag school': 1.0,
#  'preschool': 1.0,
#  'self storag facil': 0.0,
#  'semi conductor supplier': 1.0,
#  'drive school': 1.0,
#  'truck school': 1.0,
#  'senior citizen center': 1.0,
#  'servic': 0.0,
#  'children hospit': 1.0,
#  'dental suppli store': 0.0,
#  'shipyard': 0.0,
#  'orthodox synagogu': 1.0,
#  'short term apart rental agenc': 1.0,
#  'nutritionist': 1.0,
#  'ophthalmologist': 0.0,
#  'ophthalmolog clinic': 1.0,
#  'social servic organ': 1.0,
#  'social welfar center': 1.0,
#  'solar energi compani': 1.0,
#  'solar energi equip supplier': 1.0,
#  'special educ school': 1.0,
#  'podiatrist': 1.0,
#  'reproduct health clinic': 1.0,
#  'sport good store': 1.0,
#  'dialysi center': 1.0,
#  'sport complex': 1.0,
#  'well program': 0.0,
#  'sportswear store': 0.9,
#  'privat hospit': 0.0,
#  'radiologist': 1.0,
#  'medic diagnost imag center': 1.0,
#  'ray lab': 1.0,
#  'blood bank': 0.7,
#  'stainless steel plant': 1.0,
#  'state agenc': 1.0,
#  'heliport': 0.0,
#  'health care compani': 1.0,
#  'psychiatr hospit': 1.0,
#  'state govern offic': 1.0,
#  'medic institut': 1.0,
#  'steel construct compani': 1.0,
#  'clean servic': 0.0,
#  'steel drum supplier': 1.0,
#  'assist live facil': 1.0,
#  'steel erector': 0.0,
#  ...}

# %%
calc_pre_rec_at_n(ret_docs_dic, queries_dic, n=-1)[1]
# Out:
# {'home improv store': 0.091,
#  'diesel fuel supplier': 0.0,
#  'church': 0.0,
#  'farm': 0.156,
#  'seed supplier': 0.0,
#  'account': 0.204,
#  'truck compani': 0.12,
#  'export': 0.0,
#  'grain elev': 0.0,
#  'popcorn store': 0.205,
#  'agricultur servic': 0.0,
#  'warehous': 0.571,
#  'agricultur product': 0.156,
#  'ranch': 0.156,
#  'hold compani': 1.0,
#  'farm equip supplier': 0.0,
#  'store': 0.409,
#  'groceri store': 0.205,
#  'rice mill': 0.137,
#  'food product supplier': 0.0,
#  'account firm': 0.0,
#  'produc market': 0.0,
#  'pet suppli store': 0.409,
#  'wholesal': 0.141,
#  'produc wholesal': 0.141,
#  'distribut servic': 0.0,
#  'crop grower': 0.156,
#  'addict treatment center': 0.256,
#  'natur good store': 0.0,
#  'orchard': 0.156,
#  'lumber store': 0.0,
#  'mine': 0.357,
#  'transport servic': 0.2,
#  'invest compani': 0.244,
#  'fruit wholesal': 0.014,
#  'real estat agenc': 0.417,
#  'event venu': 0.0,
#  'frozen dessert supplier': 0.137,
#  'wine wholesal import': 0.042,
#  'wineri': 0.096,
#  'aerospac compani': 0.053,
#  'cold storag facil': 0.571,
#  'employ agenc': 0.0,
#  'plant nurseri': 0.0,
#  'air condit contractor': 0.323,
#  'air condit repair servic': 0.0,
#  'fruit veget wholesal': 0.0,
#  'aircraft rental servic': 0.417,
#  'monasteri': 0.204,
#  'allergist': 0.256,
#  'herb shop': 0.045,
#  'aluminum supplier': 0.053,
#  'ambul servic': 0.0,
#  'wholesal plant nurseri': 0.141,
#  'amus machin supplier': 0.0,
#  'anim hospit': 0.0,
#  'farmer market': 0.0,
#  'vapor store': 0.409,
#  'cigar shop': 0.409,
#  'tobacco shop': 0.0,
#  'well drill contractor': 0.0,
#  'librari': 0.323,
#  'apart build': 0.0,
#  'apart rental agenc': 0.417,
#  'dairi farm': 0.156,
#  'architect': 0.204,
#  'organ farm': 0.156,
#  'architectur design': 0.204,
#  'architectur firm': 0.204,
#  'livestock produc': 0.0,
#  'dairi supplier': 0.0,
#  'biotechnolog compani': 0.082,
#  'artist': 0.4,
#  'egg supplier': 0.156,
#  'poultri farm': 0.0,
#  'chicken hatcheri': 0.156,
#  'art organ': 0.4,
#  'associ organ': 0.204,
#  'food store': 0.205,
#  'deli': 0.0,
#  'bank': 0.244,
#  'fish process': 0.0,
#  'fish farm': 0.156,
#  'seafood wholesal': 0.085,
#  'tropic fish store': 0.409,
#  'non profit organ': 0.204,
#  'econom develop agenc': 0.345,
#  'seafood market': 0.205,
#  'honey farm': 0.156,
#  'hors breeder': 0.0,
#  'asphalt contractor': 0.323,
#  'livestock dealer': 0.0,
#  'depart store': 0.455,
#  'mill': 0.0,
#  'atv dealer': 0.227,
#  'audio visual consult': 0.0,
#  'pallet supplier': 0.0,
#  'wood supplier': 0.0,
#  'hardwar store': 0.0,
#  'furnitur wholesal': 0.0,
#  'auditor': 0.163,
#  'oil natur compani': 0.357,
#  'auto bodi shop': 0.204,
#  'boat repair shop': 0.0,
#  'associ': 0.204,
#  'rail contractor': 0.0,
#  'publish': 0.323,
#  'pond suppli store': 0.0,
#  'agricultur cooper': 0.0,
#  'print equip supplier': 0.053,
#  'auto insur agenc': 0.244,
#  'altern fuel station': 0.091,
#  'auto part manufactur': 0.053,
#  'foundat': 0.204,
#  'fertil supplier': 0.103,
#  'farm compani': 0.156,
#  'financ broker': 0.244,
#  'fire station': 0.0,
#  'environment consult': 0.204,
#  'civil engin': 0.323,
#  'fire protect servic': 0.0,
#  'compani': 0.0,
#  'oilfield': 0.0,
#  'banquet hall': 0.533,
#  'mine compani': 0.357,
#  'coalfield': 0.0,
#  'steel fabric': 0.0,
#  'quarri': 0.357,
#  'gold mine compani': 0.357,
#  'high rise build': 0.323,
#  'basketbal club': 0.28,
#  'gold dealer': 0.0,
#  'batteri manufactur': 0.053,
#  'electr util compani': 0.0,
#  'environment program': 0.0,
#  'offic': 0.0,
#  'stone supplier': 0.0,
#  'aggreg supplier': 0.0,
#  'sand gravel supplier': 0.0,
#  'build materi supplier': 0.136,
#  'beauti suppli store': 0.114,
#  'crush stone supplier': 0.0,
#  'rock shop': 0.0,
#  'road construct compani': 0.323,
#  'market consult': 0.184,
#  'blood test servic': 0.204,
#  'contractor': 0.323,
#  'excav contractor': 0.323,
#  'asphalt mix plant': 0.093,
#  'readi mix concret supplier': 0.103,
#  'sand plant': 0.0,
#  'bmw dealer': 0.227,
#  'bookbind': 0.041,
#  'garden center': 0.136,
#  'abras supplier': 0.0,
#  'granit supplier': 0.0,
#  'drill contractor': 0.0,
#  'bpo compani': 0.227,
#  'oil explor servic': 0.357,
#  'build complex': 0.0,
#  'construct equip supplier': 0.0,
#  'mine equip': 0.0,
#  'ticket agenc': 0.0,
#  'busi center': 0.0,
#  'skyscrap': 0.0,
#  'softwar compani': 0.323,
#  'busi develop servic': 0.082,
#  'busi manag consult': 0.163,
#  'cabinet maker': 0.053,
#  'call center': 0.0,
#  'cancer treatment center': 0.256,
#  'power plant consult': 0.0,
#  'busi park': 0.204,
#  'petroleum product compani': 0.0,
#  'park lot': 0.0,
#  'water util compani': 0.714,
#  'car repair mainten': 0.204,
#  'water treatment plant': 0.714,
#  'car servic': 0.204,
#  'cattl market': 0.0,
#  'sewag dispos servic': 0.643,
#  'certifi public account': 0.0,
#  'govern offic': 0.345,
#  'chariti': 0.204,
#  'air condit system supplier': 0.0,
#  'chemic industri': 0.103,
#  'chemic manufactur': 0.103,
#  'titl compani': 0.0,
#  'chemic plant': 0.103,
#  'properti manag compani': 0.0,
#  'custom home builder': 0.323,
#  'window instal servic': 0.0,
#  'fire damag restor servic': 0.0,
#  'equip rental agenc': 0.417,
#  'chemic wholesal': 0.0,
#  'financi planner': 0.244,
#  'telecommun servic provid': 0.323,
#  'energi equip solut': 0.0,
#  'chiropractor': 0.256,
#  'steel distributor': 0.0,
#  'citi govern offic': 0.345,
#  'crane servic': 0.0,
#  'garag door supplier': 0.0,
#  'industri door supplier': 0.0,
#  'citi town hall': 0.0,
#  'cloth wholesal': 0.014,
#  'coin oper laundri equip supplier': 0.204,
#  'metal supplier': 0.0,
#  'glass shop': 0.0,
#  'colleg': 0.588,
#  'side contractor': 0.323,
#  'commerci printer': 0.0,
#  'storag facil': 0.571,
#  'commun tower': 0.0,
#  'janitori servic': 0.0,
#  'comput consult': 0.204,
#  'fire protect system supplier': 0.0,
#  'elev servic': 0.0,
#  'industri equip supplier': 0.0,
#  'dri wall contractor': 0.323,
#  'insul contractor': 0.323,
#  'concret contractor': 0.323,
#  'scaffold rental servic': 0.417,
#  'construct compani': 0.323,
#  'floor store': 0.091,
#  'floor contractor': 0.323,
#  'tile contractor': 0.323,
#  'tile manufactur': 0.0,
#  'glass mirror shop': 0.0,
#  'construct materi wholesal': 0.0,
#  'gutter clean servic': 0.0,
#  'sheet metal contractor': 0.053,
#  'consult': 0.184,
#  'contain servic': 0.0,
#  'septic system servic': 0.0,
#  'corpor campu': 0.0,
#  'water damag restor servic': 0.0,
#  'welder': 0.0,
#  'corpor offic': 0.0,
#  'anim': 0.156,
#  'anim feed store': 0.0,
#  'anim protect organ': 0.0,
#  'brew suppli store': 0.0,
#  'cosmet store': 0.114,
#  'counti govern offic': 0.345,
#  'sugar factori': 0.137,
#  'confectioneri wholesal': 0.07,
#  'financi institut': 0.0,
#  'candi store': 0.205,
#  'confectioneri': 0.0,
#  'chocol factori': 0.137,
#  'chocol shop': 0.082,
#  'courier servic': 0.429,
#  'cowork space': 0.0,
#  'frozen food manufactur': 0.137,
#  'beverag distributor': 0.0,
#  'agricultur organ': 0.0,
#  'dairi store': 0.0,
#  'dairi': 0.156,
#  'ice cream shop': 0.096,
#  'medic laboratori': 0.256,
#  'demolit contractor': 0.323,
#  'meat processor': 0.123,
#  'fmcg manufactur': 0.0,
#  'garbag collect servic': 0.0,
#  'wholesal bakeri': 0.123,
#  'dentist': 0.256,
#  'dessert shop': 0.0,
#  'cupcak shop': 0.0,
#  'nut store': 0.205,
#  'wholesal grocer': 0.141,
#  'design engin': 0.204,
#  'busi busi servic': 0.227,
#  'condiment supplier': 0.137,
#  'digit print servic': 0.041,
#  'culinari school': 0.588,
#  'import': 0.0,
#  'bottl water supplier': 0.096,
#  'coffe roaster': 0.0,
#  'packag suppli store': 0.0,
#  'ice supplier': 0.096,
#  'breweri': 0.096,
#  'winemak compani': 0.0,
#  'distilleri': 0.096,
#  'disabl servic support organis': 0.0,
#  'district govern offic': 0.345,
#  'air filter supplier': 0.0,
#  'tire shop': 0.159,
#  'fasten supplier': 0.053,
#  'fabric product manufactur': 0.137,
#  'textil': 0.137,
#  'textil export': 0.137,
#  'textil engin': 0.137,
#  'fabric store': 0.409,
#  'knit shop': 0.137,
#  'doctor': 0.256,
#  'lamin servic': 0.0,
#  'plastic resin manufactur': 0.082,
#  'carpet manufactur': 0.137,
#  'upholsteri shop': 0.204,
#  'busi administr servic': 0.0,
#  'furnitur store': 0.023,
#  'dri cleaner': 0.0,
#  'packag compani': 0.227,
#  'duti free store': 0.409,
#  'commerc servic': 0.0,
#  'cabl compani': 0.0,
#  'educ': 0.588,
#  'outlet store': 0.409,
#  'lingeri store': 0.227,
#  'cloth fabric manufactur': 0.014,
#  'educ center': 0.588,
#  'uniform store': 0.205,
#  'men cloth store': 0.205,
#  'cloth store': 0.205,
#  'women cloth store': 0.205,
#  'western apparel store': 0.0,
#  'costum store': 0.0,
#  'game store': 0.455,
#  'hat shop': 0.045,
#  'leather good manufactur': 0.114,
#  'educ consult': 0.588,
#  'leather export': 0.055,
#  'shoe store': 0.227,
#  'boutiqu': 0.0,
#  'leather wholesal': 0.045,
#  'handbag shop': 0.055,
#  'electron store': 0.045,
#  'luggag store': 0.136,
#  'build materi store': 0.136,
#  'saw mill': 0.103,
#  'electr engin': 0.0,
#  'deck builder': 0.323,
#  'concret product supplier': 0.103,
#  'plywood supplier': 0.103,
#  'electr instal servic': 0.0,
#  'truss manufactur': 0.093,
#  'door supplier': 0.0,
#  'wood lamin floor supplier': 0.103,
#  'aircraft suppli store': 0.0,
#  'modular home builder': 0.0,
#  'portabl build manufactur': 0.053,
#  'modular home dealer': 0.045,
#  'mulch supplier': 0.0,
#  'electrician': 0.0,
#  'paper mill': 0.103,
#  'energi supplier': 0.714,
#  'engin': 0.0,
#  'print shop': 0.041,
#  'custom label printer': 0.0,
#  'market': 0.0,
#  'market agenc': 0.0,
#  'engin consult': 0.184,
#  'entertain': 0.4,
#  'envelop supplier': 0.0,
#  'oil refineri': 0.052,
#  'record studio': 0.323,
#  'environ renew natur resourc': 0.0,
#  'finish materi supplier': 0.136,
#  'event ticket seller': 0.0,
#  'waterproof compani': 0.0,
#  'auto part store': 0.0,
#  'heat oil supplier': 0.0,
#  'famili practic physician': 0.256,
#  'machin manufactur': 0.053,
#  'industri supplier': 0.0,
#  'weld suppli store': 0.0,
#  'dri ice supplier': 0.137,
#  'privat equiti firm': 0.0,
#  'famili servic center': 0.256,
#  'feder govern offic': 0.345,
#  'vitamin supplement store': 0.114,
#  'feed manufactur': 0.068,
#  'medic equip supplier': 0.0,
#  'medic suppli store': 0.0,
#  'medic clinic': 0.256,
#  'research institut': 0.204,
#  'biochem supplier': 0.0,
#  'fiber optic product supplier': 0.0,
#  'paint manufactur': 0.103,
#  'equip supplier': 0.0,
#  'food': 0.0,
#  'pipe supplier': 0.053,
#  'oil field equip supplier': 0.0,
#  'food broker': 0.0,
#  'food manufactur': 0.137,
#  'food process compani': 0.0,
#  'fenc suppli store': 0.114,
#  'food produc': 0.0,
#  'forestri servic': 0.156,
#  'foundri': 0.053,
#  'wholesal jewel': 0.141,
#  'cooki shop': 0.123,
#  'truck rental agenc': 0.417,
#  'fruit veget process': 0.137,
#  'kitchen suppli store': 0.0,
#  'hydraul equip supplier': 0.0,
#  'irrig equip supplier': 0.0,
#  'bear supplier': 0.053,
#  'metallurgi compani': 0.0,
#  'plastic inject mold servic': 0.0,
#  'gener contractor': 0.323,
#  'gener hospit': 0.231,
#  'tool manufactur': 0.0,
#  'industri design compani': 0.0,
#  'hyundai dealer': 0.0,
#  'glass industri': 0.103,
#  'polym supplier': 0.0,
#  'print equip suppli': 0.0,
#  'toner cartridg supplier': 0.103,
#  'printer repair servic': 0.204,
#  'fuel supplier': 0.0,
#  'glass manufactur': 0.103,
#  'plastic bag supplier': 0.103,
#  'glasswar manufactur': 0.0,
#  'polythen plastic sheet supplier': 0.103,
#  'pvc industri': 0.0,
#  'countertop store': 0.227,
#  'cabinet store': 0.227,
#  'fiberglass supplier': 0.0,
#  'golf cart dealer': 0.227,
#  'auto repair shop': 0.204,
#  'hose supplier': 0.103,
#  'rubber product supplier': 0.093,
#  'automot': 0.0,
#  'commerci refriger supplier': 0.0,
#  'golf club': 0.4,
#  'golf cours': 0.0,
#  'green energi supplier': 0.714,
#  'greenhous': 0.0,
#  'auto glass shop': 0.0,
#  'light manufactur': 0.053,
#  'cement manufactur': 0.103,
#  'brick manufactur': 0.103,
#  'natur stone supplier': 0.0,
#  'gym': 0.4,
#  'marbl supplier': 0.0,
#  'corpor gift supplier': 0.409,
#  'shipbuild repair compani': 0.0,
#  'construct mainten offic': 0.323,
#  'boiler manufactur': 0.053,
#  'contain supplier': 0.0,
#  'home construct': 0.323,
#  'health': 0.256,
#  'heart hospit': 0.256,
#  'spring supplier': 0.053,
#  'electr util manufactur': 0.0,
#  'aircraft manufactur': 0.053,
#  'metal heat treat servic': 0.053,
#  'plate servic': 0.0,
#  'autom compani': 0.0,
#  'heat contractor': 0.323,
#  'plumb suppli store': 0.0,
#  'gun shop': 0.0,
#  'ammunit supplier': 0.053,
#  'pipe manufactur': 0.053,
#  'school': 0.588,
#  'fire protect equip supplier': 0.0,
#  'agricultur machineri manufactur': 0.0,
#  'lawn mower store': 0.114,
#  'lawn irrig equip supplier': 0.0,
#  'financi consult': 0.073,
#  'helicopt charter': 0.2,
#  'packag machineri': 0.0,
#  'histor landmark': 0.4,
#  'electron manufactur': 0.053,
#  'graphic design': 0.184,
#  'eye care center': 0.256,
#  'optic product manufactur': 0.053,
#  'imag consult': 0.184,
#  'clean product supplier': 0.0,
#  'fireplac store': 0.0,
#  'home builder': 0.323,
#  'tool die shop': 0.053,
#  'metal stamp servic': 0.053,
#  'environment organ': 0.204,
#  'food process equip': 0.0,
#  'loan agenc': 0.244,
#  'power plant equip supplier': 0.0,
#  'home good store': 0.091,
#  'engin rebuild servic': 0.0,
#  'air compressor supplier': 0.0,
#  'honda dealer': 0.227,
#  'elev manufactur': 0.053,
#  'crane dealer': 0.0,
#  'crane rental agenc': 0.417,
#  'compound build': 0.0,
#  'tractor dealer': 0.0,
#  'furnac part supplier': 0.0,
#  'heat equip supplier': 0.0,
#  'pneumat tool supplier': 0.0,
#  'truck stop': 0.0,
#  'comput hardwar manufactur': 0.053,
#  'satellit commun servic': 0.323,
#  'hospit': 0.256,
#  'electron compani': 0.0,
#  'electron part supplier': 0.0,
#  'hvac contractor': 0.323,
#  'industri engin': 0.061,
#  'contact lens supplier': 0.0,
#  'inform servic': 0.323,
#  'build': 0.323,
#  'water work equip supplier': 0.0,
#  'measur instrument supplier': 0.053,
#  'scientif equip supplier': 0.0,
#  'medic center': 0.256,
#  'watch manufactur': 0.0,
#  'corpor entertain servic': 0.0,
#  'insur': 0.244,
#  'record compani': 0.323,
#  'video duplic servic': 0.0,
#  'insur agenc': 0.244,
#  'light store': 0.053,
#  'light wholesal': 0.053,
#  'entertain agenc': 0.4,
#  'insur broker': 0.244,
#  'electr equip supplier': 0.0,
#  'electr motor store': 0.053,
#  'railroad compani': 0.18,
#  'electr suppli store': 0.0,
#  'insur compani': 0.244,
#  'factori equip supplier': 0.0,
#  'invest servic': 0.244,
#  'laser equip supplier': 0.053,
#  'execut suit rental agenc': 0.0,
#  'truck dealer': 0.0,
#  'motor vehicl dealer': 0.159,
#  'car dealer': 0.227,
#  'truck topper supplier': 0.0,
#  'polic suppli store': 0.409,
#  'iron steel contractor': 0.323,
#  'fire depart equip supplier': 0.0,
#  'tow equip provid': 0.2,
#  'logist servic': 0.184,
#  'trailer manufactur': 0.053,
#  'trailer dealer': 0.0,
#  'dealer': 0.227,
#  'auto spring shop': 0.0,
#  'auto upholster': 0.053,
#  'auto bodi part supplier': 0.159,
#  'car factori': 0.0,
#  'freight forward servic': 0.2,
#  'brake shop': 0.204,
#  'railroad equip supplier': 0.0,
#  'jewelri equip supplier': 0.053,
#  'boat builder': 0.0,
#  'ship build': 0.0,
#  'marin suppli store': 0.114,
#  'boat dealer': 0.182,
#  'kawasaki motorcycl dealer': 0.227,
#  'knife manufactur': 0.053,
#  'labor union': 0.204,
#  'furnitur maker': 0.053,
#  'bank financ': 0.244,
#  'furnitur manufactur': 0.053,
#  'logist': 0.184,
#  'massag suppli store': 0.0,
#  'telecommun equip supplier': 0.0,
#  'babi store': 0.182,
#  'mold supplier': 0.0,
#  'offic equip supplier': 0.0,
#  'offic furnitur store': 0.053,
#  'store equip supplier': 0.0,
#  'laboratori': 0.0,
#  'health beauti shop': 0.0,
#  'learn center': 0.588,
#  'dental laboratori': 0.053,
#  'land surveyor': 0.0,
#  'educ suppli store': 0.409,
#  'jewelri store': 0.205,
#  'playground equip supplier': 0.0,
#  'outdoor sport store': 0.455,
#  'toy store': 0.455,
#  'secur servic': 0.0,
#  'sign shop': 0.053,
#  'offic suppli store': 0.409,
#  'landscap': 0.227,
#  'gasket manufactur': 0.053,
#  'piano maker': 0.0,
#  'piano store': 0.409,
#  'funer home': 0.0,
#  'monument': 0.0,
#  'book publish': 0.323,
#  'wig shop': 0.045,
#  'laundromat': 0.204,
#  'auto wrecker': 0.0,
#  'auto part market': 0.159,
#  'jeep dealer': 0.227,
#  'restaur suppli store': 0.0,
#  'roof suppli store': 0.0,
#  'law firm': 0.0,
#  'build materi market': 0.136,
#  'camera store': 0.0,
#  'lawn care servic': 0.0,
#  'comput secur servic': 0.0,
#  'comput store': 0.0,
#  'design agenc': 0.0,
#  'diagnost center': 0.256,
#  'laboratori equip supplier': 0.053,
#  'home theater store': 0.0,
#  'metal industri supplier': 0.0,
#  'landscap suppli store': 0.114,
#  'applianc part supplier': 0.0,
#  'vacuum cleaner store': 0.136,
#  'audio visual equip supplier': 0.053,
#  'lawyer': 0.184,
#  'cell phone store': 0.0,
#  'bathroom suppli store': 0.0,
#  'leas servic': 0.0,
#  'construct machin dealer': 0.0,
#  'dairi farm equip supplier': 0.0,
#  'propan supplier': 0.0,
#  'legal servic': 0.0,
#  'janitori equip supplier': 0.0,
#  'life insur agenc': 0.244,
#  'railroad contractor': 0.1,
#  'swim pool suppli store': 0.409,
#  'light bulb supplier': 0.053,
#  'linen store': 0.0,
#  'metal construct compani': 0.053,
#  'local govern offic': 0.345,
#  'log contractor': 0.0,
#  'machin shop': 0.042,
#  'hotel suppli store': 0.0,
#  'import export compani': 0.0,
#  'sew compani': 0.0,
#  'research foundat': 0.204,
#  'machineri part manufactur': 0.0,
#  'sport accessori wholesal': 0.0,
#  'fashion design': 0.0,
#  'chees manufactur': 0.0,
#  'chees shop': 0.0,
#  'ship mail': 0.429,
#  'wholesal food store': 0.0,
#  'organ food store': 0.205,
#  'pie shop': 0.0,
#  'auction hous': 0.455,
#  'livestock auction hous': 0.0,
#  'cotton export': 0.156,
#  'plastic wholesal': 0.0,
#  'mail servic': 0.429,
#  'manufactur': 0.053,
#  'station': 0.091,
#  'beer distributor': 0.0,
#  'alcohol beverag wholesal': 0.0,
#  'religi good store': 0.0,
#  'book wholesal': 0.056,
#  'masonri suppli store': 0.114,
#  'wholesal florist': 0.014,
#  'florist': 0.409,
#  'marin engin': 0.0,
#  'paint store': 0.114,
#  'use auto part store': 0.0,
#  'masonri contractor': 0.323,
#  'use car dealer': 0.227,
#  'use truck dealer': 0.159,
#  'massag therapist': 0.256,
#  'materi handl equip supplier': 0.0,
#  'marina': 0.4,
#  'meat packer': 0.0,
#  'mattress store': 0.182,
#  'blind shop': 0.0,
#  'interior design': 0.163,
#  'window treatment store': 0.091,
#  'applianc store': 0.045,
#  'health food store': 0.182,
#  'direct mail advertis': 0.082,
#  'meat wholesal': 0.042,
#  'butcher shop deli': 0.045,
#  'italian groceri store': 0.205,
#  'food servic': 0.533,
#  'groceri deliveri servic': 0.429,
#  'wine store': 0.205,
#  'liquor store': 0.205,
#  'kiosk': 0.0,
#  'optometrist': 0.256,
#  'optician': 0.256,
#  'mechan contractor': 0.323,
#  'mechan engin': 0.0,
#  'cafe': 0.0,
#  'jewel': 0.141,
#  'leather good store': 0.205,
#  'gift shop': 0.409,
#  'craft store': 0.409,
#  'hobbi store': 0.455,
#  'fabric wholesal': 0.0,
#  'scrap metal dealer': 0.0,
#  'quilt shop': 0.0,
#  'sheet music store': 0.455,
#  'music instrument manufactur': 0.053,
#  'music store': 0.455,
#  'music instrument store': 0.455,
#  'band': 0.0,
#  'bookstor': 0.0,
#  'art museum': 0.4,
#  'newsstand': 0.455,
#  'medic equip manufactur': 0.053,
#  'fashion accessori store': 0.205,
#  'discount store': 0.409,
#  'cemeteri': 0.204,
#  'stop': 0.0,
#  'varieti store': 0.409,
#  'thrift store': 0.409,
#  'medic group': 0.256,
#  'donat center': 0.0,
#  'pet store': 0.409,
#  'art galleri': 0.0,
#  'art dealer': 0.0,
#  'hous develop': 0.0,
#  'mobil home dealer': 0.091,
#  'conveni store': 0.227,
#  'medic offic': 0.256,
#  'medic technolog manufactur': 0.053,
#  'children furnitur store': 0.023,
#  'mental health clinic': 0.256,
#  'airlin': 0.0,
#  'aviat consult': 0.0,
#  'travel agenc': 0.227,
#  'travel servic': 0.227,
#  'airport': 0.0,
#  'mental health servic': 0.256,
#  'ship compani': 0.0,
#  'metal fabric': 0.053,
#  'cruis line compani': 0.0,
#  'tow servic': 0.2,
#  'ferri termin': 0.2,
#  'ferri servic': 0.0,
#  'metal finish': 0.053,
#  'boat tour agenc': 0.16,
#  'move compani': 0.0,
#  'move storag servic': 0.0,
#  'state depart transport': 0.0,
#  'depart transport': 0.0,
#  'handicap transport servic': 0.2,
#  'railway servic': 0.0,
#  'train station': 0.0,
#  'depot': 0.0,
#  'charter': 0.2,
#  'metal process compani': 0.053,
#  'mix use': 0.0,
#  'motorcycl shop': 0.159,
#  'limousin servic': 0.0,
#  'chauffeur servic': 0.0,
#  'school servic': 0.0,
#  'airport shuttl servic': 0.0,
#  'tourist inform center': 0.0,
#  'carriag ride servic': 0.0,
#  'cruis agenc': 0.0,
#  'tourist attract': 0.0,
#  'ski resort': 0.4,
#  'ski area': 0.0,
#  'fix base oper': 0.0,
#  'aircraft mainten compani': 0.0,
#  'motorsport store': 0.159,
#  'boat rental servic': 0.417,
#  'util trailer dealer': 0.0,
#  'forklift dealer': 0.0,
#  'municip administr offic': 0.345,
#  'nephrologist': 0.256,
#  'coach compani': 0.0,
#  'ship servic': 0.0,
#  'ship mail servic': 0.429,
#  'newspap publish': 0.323,
#  'shred servic': 0.0,
#  'nuclear power compani': 0.714,
#  'nurs home': 0.0,
#  'media compani': 0.163,
#  'multimedia electron book publish': 0.323,
#  'internet market servic': 0.0,
#  'greet card shop': 0.409,
#  'theme park': 0.4,
#  'film product compani': 0.0,
#  'obstetrician gynecologist': 0.256,
#  'movi studio': 0.323,
#  'video product servic': 0.323,
#  'movi theater': 0.323,
#  'theater compani': 0.0,
#  'perform art theater': 0.4,
#  'occup safeti health': 0.0,
#  'offic space rental agenc': 0.417,
#  'commerci real estat agenc': 0.417,
#  'art school': 0.588,
#  'music publish': 0.323,
#  'print music publish': 0.323,
#  'home audio store': 0.0,
#  'musician': 0.4,
#  'music manag promot': 0.4,
#  'video edit servic': 0.0,
#  'offic suppli wholesal': 0.028,
#  'offici resid': 0.0,
#  'orthoped clinic': 0.256,
#  'painter': 0.0,
#  'paint': 0.0,
#  'telephon compani': 0.0,
#  'media hous': 0.163,
#  'paper distributor': 0.0,
#  'news servic': 0.0,
#  'public librari': 0.0,
#  'law librari': 0.323,
#  'museum': 0.4,
#  'feder reserv bank': 0.244,
#  'credit union': 0.244,
#  'atm': 0.0,
#  'pave contractor': 0.323,
#  'mortgag lender': 0.244,
#  'invest bank': 0.244,
#  'check cash servic': 0.0,
#  'stock broker': 0.0,
#  'health consult': 0.184,
#  'health insur agenc': 0.244,
#  'payrol servic': 0.204,
#  'pediatrician': 0.256,
#  'human resourc consult': 0.184,
#  'pest control servic': 0.0,
#  'pet board servic': 0.204,
#  'pet care': 0.204,
#  'loss adjust': 0.244,
#  'pharmaceut compani': 0.103,
#  'pharmaceut product wholesal': 0.085,
#  'pharmaci': 0.114,
#  'educ institut': 0.588,
#  'retir commun': 0.0,
#  'fratern organ': 0.204,
#  'photo lab': 0.0,
#  'properti invest': 0.0,
#  'photograph': 0.204,
#  'photographi school': 0.0,
#  'star hotel': 0.467,
#  'convent center': 0.0,
#  'real estat apprais': 0.417,
#  'photographi servic': 0.0,
#  'resort hotel': 0.467,
#  'real estat consult': 0.417,
#  'car rental agenc': 0.417,
#  'car leas servic': 0.0,
#  'ford dealer': 0.227,
#  'car financ loan compani': 0.244,
#  'trailer rental servic': 0.417,
#  'furnitur rental servic': 0.0,
#  'tuxedo shop': 0.0,
#  'dress tuxedo rental servic': 0.417,
#  'wed store': 0.227,
#  'video store': 0.114,
#  'movi rental': 0.0,
#  'photographi studio': 0.0,
#  'home health care servic': 0.256,
#  'skateboard shop': 0.0,
#  'event technolog servic': 0.0,
#  'parti equip rental servic': 0.417,
#  'construct machin rental servic': 0.417,
#  'audio visual equip rental servic': 0.0,
#  'ship equip industri': 0.0,
#  'physic therapi clinic': 0.256,
#  'plastic fabric compani': 0.103,
#  'plastic product supplier': 0.103,
#  'auto tag agenc': 0.345,
#  'depart motor vehicl': 0.0,
#  'notari public': 0.0,
#  'privat investig': 0.0,
#  'escrow servic': 0.0,
#  'real estat agent': 0.417,
#  'playground': 0.16,
#  'plumber': 0.0,
#  'port author': 0.2,
#  'portrait studio': 0.0,
#  'post offic': 0.0,
#  'profession servic': 0.0,
#  'univers hospit': 0.179,
#  'public relat firm': 0.0,
#  'civil engin compani': 0.0,
#  'draft servic': 0.204,
#  'pump supplier': 0.0,
#  'interior construct contractor': 0.323,
#  'carpet clean servic': 0.0,
#  'exhibit planner': 0.0,
#  'decal supplier': 0.0,
#  'stage light equip supplier': 0.053,
#  'event manag compani': 0.0,
#  'radio broadcast': 0.0,
#  'comput support servic': 0.082,
#  'ravin': 0.0,
#  'employ center': 0.0,
#  'nation health foundat': 0.0,
#  'real estat develop': 0.0,
#  'advertis agenc': 0.0,
#  'promot product supplier': 0.0,
#  'advertis servic': 0.0,
#  'record storag facil': 0.0,
#  'fund manag compani': 0.244,
#  'recreat center': 0.4,
#  'bakeri': 0.137,
#  'databas manag compani': 0.0,
#  'market research': 0.204,
#  'recycl center': 0.0,
#  'region govern offic': 0.345,
#  'rehabilit center': 0.256,
#  'religi institut': 0.204,
#  'religi organ': 0.204,
#  'repair servic': 0.204,
#  'emerg veterinarian servic': 0.0,
#  'pet sitter': 0.0,
#  'research product develop': 0.204,
#  'build societi': 0.323,
#  'valet park servic': 0.204,
#  'nurs agenc': 0.0,
#  'execut search firm': 0.0,
#  'recruit': 0.227,
#  'temp agenc': 0.0,
#  'health center': 0.256,
#  'restaur': 0.533,
#  'roof contractor': 0.323,
#  'sport nutrit store': 0.0,
#  'credit report agenc': 0.0,
#  'automobil storag facil': 0.571,
#  'debt collect agenc': 0.227,
#  'park': 0.0,
#  'court report': 0.227,
#  'tour agenc': 0.0,
#  'tour oper': 0.227,
#  'convent inform bureau': 0.0,
#  'balloon ride tour agenc': 0.16,
#  'secur guard servic': 0.114,
#  'locksmith': 0.227,
#  'commerci clean servic': 0.0,
#  'blast clean servic': 0.0,
#  'confer center': 0.0,
#  'safeti equip supplier': 0.0,
#  'garbag dump': 0.227,
#  'sanit servic': 0.0,
#  'garbag dump servic': 0.0,
#  'environment health servic': 0.0,
#  'portabl toilet supplier': 0.0,
#  'public work depart': 0.345,
#  'school district offic': 0.588,
#  'sailmak': 0.0,
#  'commun colleg': 0.588,
#  'salvag yard': 0.0,
#  'busi school': 0.588,
#  'trade school': 0.588,
#  'privat univers': 0.0,
#  'comput train school': 0.588,
#  'school suppli store': 0.0,
#  'screen printer': 0.041,
#  'media consult': 0.143,
#  'beauti school': 0.588,
#  'flight school': 0.588,
#  'seaport': 0.0,
#  'secur system supplier': 0.0,
#  'middl school': 0.588,
#  'nonprofit': 0.0,
#  'shoot rang': 0.0,
#  'soccer club': 0.4,
#  'camp': 0.467,
#  'dive contractor': 0.0,
#  'languag school': 0.588,
#  'english languag school': 0.588,
#  'preschool': 0.256,
#  'self storag facil': 0.0,
#  'semi conductor supplier': 0.053,
#  'drive school': 0.588,
#  'truck school': 0.588,
#  'senior citizen center': 0.256,
#  'servic': 0.0,
#  'children hospit': 0.256,
#  'dental suppli store': 0.0,
#  'shipyard': 0.0,
#  'orthodox synagogu': 0.204,
#  'short term apart rental agenc': 0.417,
#  'nutritionist': 0.256,
#  'ophthalmologist': 0.0,
#  'ophthalmolog clinic': 0.256,
#  'social servic organ': 0.256,
#  'social welfar center': 0.256,
#  'solar energi compani': 0.714,
#  'solar energi equip supplier': 0.714,
#  'special educ school': 0.588,
#  'podiatrist': 0.256,
#  'reproduct health clinic': 0.256,
#  'sport good store': 0.455,
#  'dialysi center': 0.256,
#  'sport complex': 0.4,
#  'well program': 0.0,
#  'sportswear store': 0.409,
#  'privat hospit': 0.0,
#  'radiologist': 0.256,
#  'medic diagnost imag center': 0.256,
#  'ray lab': 0.256,
#  'blood bank': 0.179,
#  'stainless steel plant': 0.053,
#  'state agenc': 0.345,
#  'heliport': 0.0,
#  'health care compani': 0.256,
#  'psychiatr hospit': 0.256,
#  'state govern offic': 0.345,
#  'medic institut': 0.256,
#  'steel construct compani': 0.323,
#  'clean servic': 0.0,
#  'steel drum supplier': 0.053,
#  'assist live facil': 0.256,
#  'steel erector': 0.0,
#  ...}

# %%
calc_avg_pre(ret_docs_dic, queries_dic, cutoff=-1)[0]
# Out:
# {'home improv store': 0.091,
#  'diesel fuel supplier': 0.0,
#  'church': 0.0,
#  'farm': 0.156,
#  'seed supplier': 0.0,
#  'account': 0.204,
#  'truck compani': 0.12,
#  'export': 0.0,
#  'grain elev': 0.0,
#  'popcorn store': 0.205,
#  'agricultur servic': 0.0,
#  'warehous': 0.571,
#  'agricultur product': 0.156,
#  'ranch': 0.156,
#  'hold compani': 1.0,
#  'farm equip supplier': 0.0,
#  'store': 0.409,
#  'groceri store': 0.205,
#  'rice mill': 0.137,
#  'food product supplier': 0.0,
#  'account firm': 0.0,
#  'produc market': 0.0,
#  'pet suppli store': 0.409,
#  'wholesal': 0.141,
#  'produc wholesal': 0.141,
#  'distribut servic': 0.0,
#  'crop grower': 0.156,
#  'addict treatment center': 0.256,
#  'natur good store': 0.0,
#  'orchard': 0.156,
#  'lumber store': 0.0,
#  'mine': 0.357,
#  'transport servic': 0.2,
#  'invest compani': 0.244,
#  'fruit wholesal': 0.002,
#  'real estat agenc': 0.417,
#  'event venu': 0.0,
#  'frozen dessert supplier': 0.137,
#  'wine wholesal import': 0.024,
#  'wineri': 0.096,
#  'aerospac compani': 0.053,
#  'cold storag facil': 0.571,
#  'employ agenc': 0.0,
#  'plant nurseri': 0.0,
#  'air condit contractor': 0.323,
#  'air condit repair servic': 0.0,
#  'fruit veget wholesal': 0.0,
#  'aircraft rental servic': 0.417,
#  'monasteri': 0.204,
#  'allergist': 0.256,
#  'herb shop': 0.034,
#  'aluminum supplier': 0.053,
#  'ambul servic': 0.0,
#  'wholesal plant nurseri': 0.141,
#  'amus machin supplier': 0.0,
#  'anim hospit': 0.0,
#  'farmer market': 0.0,
#  'vapor store': 0.409,
#  'cigar shop': 0.409,
#  'tobacco shop': 0.0,
#  'well drill contractor': 0.0,
#  'librari': 0.323,
#  'apart build': 0.0,
#  'apart rental agenc': 0.417,
#  'dairi farm': 0.156,
#  'architect': 0.204,
#  'organ farm': 0.156,
#  'architectur design': 0.204,
#  'architectur firm': 0.204,
#  'livestock produc': 0.0,
#  'dairi supplier': 0.0,
#  'biotechnolog compani': 0.082,
#  'artist': 0.4,
#  'egg supplier': 0.156,
#  'poultri farm': 0.0,
#  'chicken hatcheri': 0.156,
#  'art organ': 0.4,
#  'associ organ': 0.204,
#  'food store': 0.205,
#  'deli': 0.0,
#  'bank': 0.244,
#  'fish process': 0.0,
#  'fish farm': 0.156,
#  'seafood wholesal': 0.051,
#  'tropic fish store': 0.409,
#  'non profit organ': 0.204,
#  'econom develop agenc': 0.345,
#  'seafood market': 0.205,
#  'honey farm': 0.156,
#  'hors breeder': 0.0,
#  'asphalt contractor': 0.323,
#  'livestock dealer': 0.0,
#  'depart store': 0.455,
#  'mill': 0.0,
#  'atv dealer': 0.227,
#  'audio visual consult': 0.0,
#  'pallet supplier': 0.0,
#  'wood supplier': 0.0,
#  'hardwar store': 0.0,
#  'furnitur wholesal': 0.0,
#  'auditor': 0.161,
#  'oil natur compani': 0.357,
#  'auto bodi shop': 0.204,
#  'boat repair shop': 0.0,
#  'associ': 0.204,
#  'rail contractor': 0.0,
#  'publish': 0.323,
#  'pond suppli store': 0.0,
#  'agricultur cooper': 0.0,
#  'print equip supplier': 0.053,
#  'auto insur agenc': 0.244,
#  'altern fuel station': 0.081,
#  'auto part manufactur': 0.053,
#  'foundat': 0.204,
#  'fertil supplier': 0.103,
#  'farm compani': 0.156,
#  'financ broker': 0.244,
#  'fire station': 0.0,
#  'environment consult': 0.204,
#  'civil engin': 0.323,
#  'fire protect servic': 0.0,
#  'compani': 0.0,
#  'oilfield': 0.0,
#  'banquet hall': 0.533,
#  'mine compani': 0.357,
#  'coalfield': 0.0,
#  'steel fabric': 0.0,
#  'quarri': 0.357,
#  'gold mine compani': 0.357,
#  'high rise build': 0.323,
#  'basketbal club': 0.149,
#  'gold dealer': 0.0,
#  'batteri manufactur': 0.053,
#  'electr util compani': 0.0,
#  'environment program': 0.0,
#  'offic': 0.0,
#  'stone supplier': 0.0,
#  'aggreg supplier': 0.0,
#  'sand gravel supplier': 0.0,
#  'build materi supplier': 0.136,
#  'beauti suppli store': 0.114,
#  'crush stone supplier': 0.0,
#  'rock shop': 0.0,
#  'road construct compani': 0.323,
#  'market consult': 0.184,
#  'blood test servic': 0.204,
#  'contractor': 0.323,
#  'excav contractor': 0.323,
#  'asphalt mix plant': 0.093,
#  'readi mix concret supplier': 0.103,
#  'sand plant': 0.0,
#  'bmw dealer': 0.227,
#  'bookbind': 0.041,
#  'garden center': 0.136,
#  'abras supplier': 0.0,
#  'granit supplier': 0.0,
#  'drill contractor': 0.0,
#  'bpo compani': 0.227,
#  'oil explor servic': 0.357,
#  'build complex': 0.0,
#  'construct equip supplier': 0.0,
#  'mine equip': 0.0,
#  'ticket agenc': 0.0,
#  'busi center': 0.0,
#  'skyscrap': 0.0,
#  'softwar compani': 0.323,
#  'busi develop servic': 0.082,
#  'busi manag consult': 0.163,
#  'cabinet maker': 0.053,
#  'call center': 0.0,
#  'cancer treatment center': 0.256,
#  'power plant consult': 0.0,
#  'busi park': 0.204,
#  'petroleum product compani': 0.0,
#  'park lot': 0.0,
#  'water util compani': 0.714,
#  'car repair mainten': 0.204,
#  'water treatment plant': 0.714,
#  'car servic': 0.204,
#  'cattl market': 0.0,
#  'sewag dispos servic': 0.643,
#  'certifi public account': 0.0,
#  'govern offic': 0.345,
#  'chariti': 0.204,
#  'air condit system supplier': 0.0,
#  'chemic industri': 0.103,
#  'chemic manufactur': 0.103,
#  'titl compani': 0.0,
#  'chemic plant': 0.103,
#  'properti manag compani': 0.0,
#  'custom home builder': 0.323,
#  'window instal servic': 0.0,
#  'fire damag restor servic': 0.0,
#  'equip rental agenc': 0.417,
#  'chemic wholesal': 0.0,
#  'financi planner': 0.244,
#  'telecommun servic provid': 0.323,
#  'energi equip solut': 0.0,
#  'chiropractor': 0.256,
#  'steel distributor': 0.0,
#  'citi govern offic': 0.345,
#  'crane servic': 0.0,
#  'garag door supplier': 0.0,
#  'industri door supplier': 0.0,
#  'citi town hall': 0.0,
#  'cloth wholesal': 0.001,
#  'coin oper laundri equip supplier': 0.204,
#  'metal supplier': 0.0,
#  'glass shop': 0.0,
#  'colleg': 0.588,
#  'side contractor': 0.323,
#  'commerci printer': 0.0,
#  'storag facil': 0.571,
#  'commun tower': 0.0,
#  'janitori servic': 0.0,
#  'comput consult': 0.204,
#  'fire protect system supplier': 0.0,
#  'elev servic': 0.0,
#  'industri equip supplier': 0.0,
#  'dri wall contractor': 0.323,
#  'insul contractor': 0.323,
#  'concret contractor': 0.323,
#  'scaffold rental servic': 0.417,
#  'construct compani': 0.323,
#  'floor store': 0.091,
#  'floor contractor': 0.323,
#  'tile contractor': 0.323,
#  'tile manufactur': 0.0,
#  'glass mirror shop': 0.0,
#  'construct materi wholesal': 0.0,
#  'gutter clean servic': 0.0,
#  'sheet metal contractor': 0.053,
#  'consult': 0.184,
#  'contain servic': 0.0,
#  'septic system servic': 0.0,
#  'corpor campu': 0.0,
#  'water damag restor servic': 0.0,
#  'welder': 0.0,
#  'corpor offic': 0.0,
#  'anim': 0.156,
#  'anim feed store': 0.0,
#  'anim protect organ': 0.0,
#  'brew suppli store': 0.0,
#  'cosmet store': 0.114,
#  'counti govern offic': 0.345,
#  'sugar factori': 0.137,
#  'confectioneri wholesal': 0.025,
#  'financi institut': 0.0,
#  'candi store': 0.205,
#  'confectioneri': 0.0,
#  'chocol factori': 0.137,
#  'chocol shop': 0.08,
#  'courier servic': 0.429,
#  'cowork space': 0.0,
#  'frozen food manufactur': 0.137,
#  'beverag distributor': 0.0,
#  'agricultur organ': 0.0,
#  'dairi store': 0.0,
#  'dairi': 0.156,
#  'ice cream shop': 0.096,
#  'medic laboratori': 0.256,
#  'demolit contractor': 0.323,
#  'meat processor': 0.119,
#  'fmcg manufactur': 0.0,
#  'garbag collect servic': 0.0,
#  'wholesal bakeri': 0.123,
#  'dentist': 0.256,
#  'dessert shop': 0.0,
#  'cupcak shop': 0.0,
#  'nut store': 0.205,
#  'wholesal grocer': 0.141,
#  'design engin': 0.204,
#  'busi busi servic': 0.227,
#  'condiment supplier': 0.137,
#  'digit print servic': 0.041,
#  'culinari school': 0.588,
#  'import': 0.0,
#  'bottl water supplier': 0.096,
#  'coffe roaster': 0.0,
#  'packag suppli store': 0.0,
#  'ice supplier': 0.096,
#  'breweri': 0.096,
#  'winemak compani': 0.0,
#  'distilleri': 0.096,
#  'disabl servic support organis': 0.0,
#  'district govern offic': 0.345,
#  'air filter supplier': 0.0,
#  'tire shop': 0.147,
#  'fasten supplier': 0.053,
#  'fabric product manufactur': 0.137,
#  'textil': 0.137,
#  'textil export': 0.137,
#  'textil engin': 0.137,
#  'fabric store': 0.409,
#  'knit shop': 0.137,
#  'doctor': 0.256,
#  'lamin servic': 0.0,
#  'plastic resin manufactur': 0.069,
#  'carpet manufactur': 0.137,
#  'upholsteri shop': 0.204,
#  'busi administr servic': 0.0,
#  'furnitur store': 0.023,
#  'dri cleaner': 0.0,
#  'packag compani': 0.227,
#  'duti free store': 0.409,
#  'commerc servic': 0.0,
#  'cabl compani': 0.0,
#  'educ': 0.588,
#  'outlet store': 0.409,
#  'lingeri store': 0.227,
#  'cloth fabric manufactur': 0.001,
#  'educ center': 0.588,
#  'uniform store': 0.205,
#  'men cloth store': 0.205,
#  'cloth store': 0.205,
#  'women cloth store': 0.205,
#  'western apparel store': 0.0,
#  'costum store': 0.0,
#  'game store': 0.455,
#  'hat shop': 0.034,
#  'leather good manufactur': 0.046,
#  'educ consult': 0.588,
#  'leather export': 0.055,
#  'shoe store': 0.227,
#  'boutiqu': 0.0,
#  'leather wholesal': 0.011,
#  'handbag shop': 0.055,
#  'electron store': 0.045,
#  'luggag store': 0.106,
#  'build materi store': 0.136,
#  'saw mill': 0.103,
#  'electr engin': 0.0,
#  'deck builder': 0.323,
#  'concret product supplier': 0.103,
#  'plywood supplier': 0.103,
#  'electr instal servic': 0.0,
#  'truss manufactur': 0.081,
#  'door supplier': 0.0,
#  'wood lamin floor supplier': 0.103,
#  'aircraft suppli store': 0.0,
#  'modular home builder': 0.0,
#  'portabl build manufactur': 0.053,
#  'modular home dealer': 0.005,
#  'mulch supplier': 0.0,
#  'electrician': 0.0,
#  'paper mill': 0.103,
#  'energi supplier': 0.714,
#  'engin': 0.0,
#  'print shop': 0.041,
#  'custom label printer': 0.0,
#  'market': 0.0,
#  'market agenc': 0.0,
#  'engin consult': 0.184,
#  'entertain': 0.4,
#  'envelop supplier': 0.0,
#  'oil refineri': 0.042,
#  'record studio': 0.323,
#  'environ renew natur resourc': 0.0,
#  'finish materi supplier': 0.136,
#  'event ticket seller': 0.0,
#  'waterproof compani': 0.0,
#  'auto part store': 0.0,
#  'heat oil supplier': 0.0,
#  'famili practic physician': 0.256,
#  'machin manufactur': 0.053,
#  'industri supplier': 0.0,
#  'weld suppli store': 0.0,
#  'dri ice supplier': 0.137,
#  'privat equiti firm': 0.0,
#  'famili servic center': 0.256,
#  'feder govern offic': 0.345,
#  'vitamin supplement store': 0.114,
#  'feed manufactur': 0.066,
#  'medic equip supplier': 0.0,
#  'medic suppli store': 0.0,
#  'medic clinic': 0.256,
#  'research institut': 0.204,
#  'biochem supplier': 0.0,
#  'fiber optic product supplier': 0.0,
#  'paint manufactur': 0.103,
#  'equip supplier': 0.0,
#  'food': 0.0,
#  'pipe supplier': 0.053,
#  'oil field equip supplier': 0.0,
#  'food broker': 0.0,
#  'food manufactur': 0.137,
#  'food process compani': 0.0,
#  'fenc suppli store': 0.114,
#  'food produc': 0.0,
#  'forestri servic': 0.156,
#  'foundri': 0.053,
#  'wholesal jewel': 0.141,
#  'cooki shop': 0.123,
#  'truck rental agenc': 0.417,
#  'fruit veget process': 0.137,
#  'kitchen suppli store': 0.0,
#  'hydraul equip supplier': 0.0,
#  'irrig equip supplier': 0.0,
#  'bear supplier': 0.053,
#  'metallurgi compani': 0.0,
#  'plastic inject mold servic': 0.0,
#  'gener contractor': 0.323,
#  'gener hospit': 0.228,
#  'tool manufactur': 0.0,
#  'industri design compani': 0.0,
#  'hyundai dealer': 0.0,
#  'glass industri': 0.103,
#  'polym supplier': 0.0,
#  'print equip suppli': 0.0,
#  'toner cartridg supplier': 0.103,
#  'printer repair servic': 0.204,
#  'fuel supplier': 0.0,
#  'glass manufactur': 0.103,
#  'plastic bag supplier': 0.103,
#  'glasswar manufactur': 0.0,
#  'polythen plastic sheet supplier': 0.103,
#  'pvc industri': 0.0,
#  'countertop store': 0.227,
#  'cabinet store': 0.227,
#  'fiberglass supplier': 0.0,
#  'golf cart dealer': 0.227,
#  'auto repair shop': 0.204,
#  'hose supplier': 0.103,
#  'rubber product supplier': 0.081,
#  'automot': 0.0,
#  'commerci refriger supplier': 0.0,
#  'golf club': 0.4,
#  'golf cours': 0.0,
#  'green energi supplier': 0.714,
#  'greenhous': 0.0,
#  'auto glass shop': 0.0,
#  'light manufactur': 0.053,
#  'cement manufactur': 0.103,
#  'brick manufactur': 0.103,
#  'natur stone supplier': 0.0,
#  'gym': 0.4,
#  'marbl supplier': 0.0,
#  'corpor gift supplier': 0.409,
#  'shipbuild repair compani': 0.0,
#  'construct mainten offic': 0.323,
#  'boiler manufactur': 0.053,
#  'contain supplier': 0.0,
#  'home construct': 0.323,
#  'health': 0.256,
#  'heart hospit': 0.256,
#  'spring supplier': 0.053,
#  'electr util manufactur': 0.0,
#  'aircraft manufactur': 0.053,
#  'metal heat treat servic': 0.053,
#  'plate servic': 0.0,
#  'autom compani': 0.0,
#  'heat contractor': 0.323,
#  'plumb suppli store': 0.0,
#  'gun shop': 0.0,
#  'ammunit supplier': 0.053,
#  'pipe manufactur': 0.053,
#  'school': 0.588,
#  'fire protect equip supplier': 0.0,
#  'agricultur machineri manufactur': 0.0,
#  'lawn mower store': 0.114,
#  'lawn irrig equip supplier': 0.0,
#  'financi consult': 0.016,
#  'helicopt charter': 0.2,
#  'packag machineri': 0.0,
#  'histor landmark': 0.4,
#  'electron manufactur': 0.053,
#  'graphic design': 0.179,
#  'eye care center': 0.256,
#  'optic product manufactur': 0.053,
#  'imag consult': 0.184,
#  'clean product supplier': 0.0,
#  'fireplac store': 0.0,
#  'home builder': 0.323,
#  'tool die shop': 0.053,
#  'metal stamp servic': 0.053,
#  'environment organ': 0.204,
#  'food process equip': 0.0,
#  'loan agenc': 0.244,
#  'power plant equip supplier': 0.0,
#  'home good store': 0.091,
#  'engin rebuild servic': 0.0,
#  'air compressor supplier': 0.0,
#  'honda dealer': 0.227,
#  'elev manufactur': 0.053,
#  'crane dealer': 0.0,
#  'crane rental agenc': 0.417,
#  'compound build': 0.0,
#  'tractor dealer': 0.0,
#  'furnac part supplier': 0.0,
#  'heat equip supplier': 0.0,
#  'pneumat tool supplier': 0.0,
#  'truck stop': 0.0,
#  'comput hardwar manufactur': 0.053,
#  'satellit commun servic': 0.323,
#  'hospit': 0.256,
#  'electron compani': 0.0,
#  'electron part supplier': 0.0,
#  'hvac contractor': 0.323,
#  'industri engin': 0.018,
#  'contact lens supplier': 0.0,
#  'inform servic': 0.323,
#  'build': 0.323,
#  'water work equip supplier': 0.0,
#  'measur instrument supplier': 0.053,
#  'scientif equip supplier': 0.0,
#  'medic center': 0.256,
#  'watch manufactur': 0.0,
#  'corpor entertain servic': 0.0,
#  'insur': 0.244,
#  'record compani': 0.323,
#  'video duplic servic': 0.0,
#  'insur agenc': 0.244,
#  'light store': 0.053,
#  'light wholesal': 0.053,
#  'entertain agenc': 0.4,
#  'insur broker': 0.244,
#  'electr equip supplier': 0.0,
#  'electr motor store': 0.053,
#  'railroad compani': 0.163,
#  'electr suppli store': 0.0,
#  'insur compani': 0.244,
#  'factori equip supplier': 0.0,
#  'invest servic': 0.244,
#  'laser equip supplier': 0.053,
#  'execut suit rental agenc': 0.0,
#  'truck dealer': 0.0,
#  'motor vehicl dealer': 0.159,
#  'car dealer': 0.227,
#  'truck topper supplier': 0.0,
#  'polic suppli store': 0.409,
#  'iron steel contractor': 0.323,
#  'fire depart equip supplier': 0.0,
#  'tow equip provid': 0.2,
#  'logist servic': 0.182,
#  'trailer manufactur': 0.053,
#  'trailer dealer': 0.0,
#  'dealer': 0.227,
#  'auto spring shop': 0.0,
#  'auto upholster': 0.053,
#  'auto bodi part supplier': 0.159,
#  'car factori': 0.0,
#  'freight forward servic': 0.2,
#  'brake shop': 0.204,
#  'railroad equip supplier': 0.0,
#  'jewelri equip supplier': 0.053,
#  'boat builder': 0.0,
#  'ship build': 0.0,
#  'marin suppli store': 0.114,
#  'boat dealer': 0.182,
#  'kawasaki motorcycl dealer': 0.227,
#  'knife manufactur': 0.053,
#  'labor union': 0.204,
#  'furnitur maker': 0.053,
#  'bank financ': 0.244,
#  'furnitur manufactur': 0.053,
#  'logist': 0.182,
#  'massag suppli store': 0.0,
#  'telecommun equip supplier': 0.0,
#  'babi store': 0.182,
#  'mold supplier': 0.0,
#  'offic equip supplier': 0.0,
#  'offic furnitur store': 0.053,
#  'store equip supplier': 0.0,
#  'laboratori': 0.0,
#  'health beauti shop': 0.0,
#  'learn center': 0.588,
#  'dental laboratori': 0.053,
#  'land surveyor': 0.0,
#  'educ suppli store': 0.409,
#  'jewelri store': 0.205,
#  'playground equip supplier': 0.0,
#  'outdoor sport store': 0.455,
#  'toy store': 0.455,
#  'secur servic': 0.0,
#  'sign shop': 0.053,
#  'offic suppli store': 0.409,
#  'landscap': 0.227,
#  'gasket manufactur': 0.053,
#  'piano maker': 0.0,
#  'piano store': 0.409,
#  'funer home': 0.0,
#  'monument': 0.0,
#  'book publish': 0.323,
#  'wig shop': 0.034,
#  'laundromat': 0.204,
#  'auto wrecker': 0.0,
#  'auto part market': 0.159,
#  'jeep dealer': 0.227,
#  'restaur suppli store': 0.0,
#  'roof suppli store': 0.0,
#  'law firm': 0.0,
#  'build materi market': 0.136,
#  'camera store': 0.0,
#  'lawn care servic': 0.0,
#  'comput secur servic': 0.0,
#  'comput store': 0.0,
#  'design agenc': 0.0,
#  'diagnost center': 0.256,
#  'laboratori equip supplier': 0.053,
#  'home theater store': 0.0,
#  'metal industri supplier': 0.0,
#  'landscap suppli store': 0.114,
#  'applianc part supplier': 0.0,
#  'vacuum cleaner store': 0.129,
#  'audio visual equip supplier': 0.053,
#  'lawyer': 0.184,
#  'cell phone store': 0.0,
#  'bathroom suppli store': 0.0,
#  'leas servic': 0.0,
#  'construct machin dealer': 0.0,
#  'dairi farm equip supplier': 0.0,
#  'propan supplier': 0.0,
#  'legal servic': 0.0,
#  'janitori equip supplier': 0.0,
#  'life insur agenc': 0.244,
#  'railroad contractor': 0.088,
#  'swim pool suppli store': 0.409,
#  'light bulb supplier': 0.053,
#  'linen store': 0.0,
#  'metal construct compani': 0.053,
#  'local govern offic': 0.345,
#  'log contractor': 0.0,
#  'machin shop': 0.036,
#  'hotel suppli store': 0.0,
#  'import export compani': 0.0,
#  'sew compani': 0.0,
#  'research foundat': 0.204,
#  'machineri part manufactur': 0.0,
#  'sport accessori wholesal': 0.0,
#  'fashion design': 0.0,
#  'chees manufactur': 0.0,
#  'chees shop': 0.0,
#  'ship mail': 0.429,
#  'wholesal food store': 0.0,
#  'organ food store': 0.205,
#  'pie shop': 0.0,
#  'auction hous': 0.455,
#  'livestock auction hous': 0.0,
#  'cotton export': 0.156,
#  'plastic wholesal': 0.0,
#  'mail servic': 0.429,
#  'manufactur': 0.053,
#  'station': 0.081,
#  'beer distributor': 0.0,
#  'alcohol beverag wholesal': 0.0,
#  'religi good store': 0.0,
#  'book wholesal': 0.016,
#  'masonri suppli store': 0.114,
#  'wholesal florist': 0.001,
#  'florist': 0.409,
#  'marin engin': 0.0,
#  'paint store': 0.114,
#  'use auto part store': 0.0,
#  'masonri contractor': 0.323,
#  'use car dealer': 0.227,
#  'use truck dealer': 0.159,
#  'massag therapist': 0.256,
#  'materi handl equip supplier': 0.0,
#  'marina': 0.4,
#  'meat packer': 0.0,
#  'mattress store': 0.182,
#  'blind shop': 0.0,
#  'interior design': 0.144,
#  'window treatment store': 0.091,
#  'applianc store': 0.045,
#  'health food store': 0.182,
#  'direct mail advertis': 0.026,
#  'meat wholesal': 0.009,
#  'butcher shop deli': 0.034,
#  'italian groceri store': 0.205,
#  'food servic': 0.533,
#  'groceri deliveri servic': 0.429,
#  'wine store': 0.205,
#  'liquor store': 0.205,
#  'kiosk': 0.0,
#  'optometrist': 0.256,
#  'optician': 0.256,
#  'mechan contractor': 0.323,
#  'mechan engin': 0.0,
#  'cafe': 0.0,
#  'jewel': 0.141,
#  'leather good store': 0.205,
#  'gift shop': 0.409,
#  'craft store': 0.409,
#  'hobbi store': 0.455,
#  'fabric wholesal': 0.0,
#  'scrap metal dealer': 0.0,
#  'quilt shop': 0.0,
#  'sheet music store': 0.455,
#  'music instrument manufactur': 0.053,
#  'music store': 0.455,
#  'music instrument store': 0.455,
#  'band': 0.0,
#  'bookstor': 0.0,
#  'art museum': 0.4,
#  'newsstand': 0.455,
#  'medic equip manufactur': 0.053,
#  'fashion accessori store': 0.205,
#  'discount store': 0.409,
#  'cemeteri': 0.204,
#  'stop': 0.0,
#  'varieti store': 0.409,
#  'thrift store': 0.409,
#  'medic group': 0.256,
#  'donat center': 0.0,
#  'pet store': 0.409,
#  'art galleri': 0.0,
#  'art dealer': 0.0,
#  'hous develop': 0.0,
#  'mobil home dealer': 0.018,
#  'conveni store': 0.227,
#  'medic offic': 0.256,
#  'medic technolog manufactur': 0.053,
#  'children furnitur store': 0.023,
#  'mental health clinic': 0.256,
#  'airlin': 0.0,
#  'aviat consult': 0.0,
#  'travel agenc': 0.227,
#  'travel servic': 0.227,
#  'airport': 0.0,
#  'mental health servic': 0.256,
#  'ship compani': 0.0,
#  'metal fabric': 0.053,
#  'cruis line compani': 0.0,
#  'tow servic': 0.2,
#  'ferri termin': 0.2,
#  'ferri servic': 0.0,
#  'metal finish': 0.053,
#  'boat tour agenc': 0.143,
#  'move compani': 0.0,
#  'move storag servic': 0.0,
#  'state depart transport': 0.0,
#  'depart transport': 0.0,
#  'handicap transport servic': 0.2,
#  'railway servic': 0.0,
#  'train station': 0.0,
#  'depot': 0.0,
#  'charter': 0.2,
#  'metal process compani': 0.053,
#  'mix use': 0.0,
#  'motorcycl shop': 0.159,
#  'limousin servic': 0.0,
#  'chauffeur servic': 0.0,
#  'school servic': 0.0,
#  'airport shuttl servic': 0.0,
#  'tourist inform center': 0.0,
#  'carriag ride servic': 0.0,
#  'cruis agenc': 0.0,
#  'tourist attract': 0.0,
#  'ski resort': 0.4,
#  'ski area': 0.0,
#  'fix base oper': 0.0,
#  'aircraft mainten compani': 0.0,
#  'motorsport store': 0.159,
#  'boat rental servic': 0.417,
#  'util trailer dealer': 0.0,
#  'forklift dealer': 0.0,
#  'municip administr offic': 0.345,
#  'nephrologist': 0.256,
#  'coach compani': 0.0,
#  'ship servic': 0.0,
#  'ship mail servic': 0.429,
#  'newspap publish': 0.323,
#  'shred servic': 0.0,
#  'nuclear power compani': 0.714,
#  'nurs home': 0.0,
#  'media compani': 0.163,
#  'multimedia electron book publish': 0.323,
#  'internet market servic': 0.0,
#  'greet card shop': 0.409,
#  'theme park': 0.4,
#  'film product compani': 0.0,
#  'obstetrician gynecologist': 0.256,
#  'movi studio': 0.323,
#  'video product servic': 0.323,
#  'movi theater': 0.323,
#  'theater compani': 0.0,
#  'perform art theater': 0.4,
#  'occup safeti health': 0.0,
#  'offic space rental agenc': 0.417,
#  'commerci real estat agenc': 0.417,
#  'art school': 0.588,
#  'music publish': 0.323,
#  'print music publish': 0.323,
#  'home audio store': 0.0,
#  'musician': 0.4,
#  'music manag promot': 0.4,
#  'video edit servic': 0.0,
#  'offic suppli wholesal': 0.005,
#  'offici resid': 0.0,
#  'orthoped clinic': 0.256,
#  'painter': 0.0,
#  'paint': 0.0,
#  'telephon compani': 0.0,
#  'media hous': 0.163,
#  'paper distributor': 0.0,
#  'news servic': 0.0,
#  'public librari': 0.0,
#  'law librari': 0.323,
#  'museum': 0.4,
#  'feder reserv bank': 0.244,
#  'credit union': 0.244,
#  'atm': 0.0,
#  'pave contractor': 0.323,
#  'mortgag lender': 0.244,
#  'invest bank': 0.244,
#  'check cash servic': 0.0,
#  'stock broker': 0.0,
#  'health consult': 0.182,
#  'health insur agenc': 0.244,
#  'payrol servic': 0.204,
#  'pediatrician': 0.256,
#  'human resourc consult': 0.184,
#  'pest control servic': 0.0,
#  'pet board servic': 0.204,
#  'pet care': 0.204,
#  'loss adjust': 0.244,
#  'pharmaceut compani': 0.103,
#  'pharmaceut product wholesal': 0.037,
#  'pharmaci': 0.114,
#  'educ institut': 0.588,
#  'retir commun': 0.0,
#  'fratern organ': 0.204,
#  'photo lab': 0.0,
#  'properti invest': 0.0,
#  'photograph': 0.204,
#  'photographi school': 0.0,
#  'star hotel': 0.467,
#  'convent center': 0.0,
#  'real estat apprais': 0.417,
#  'photographi servic': 0.0,
#  'resort hotel': 0.467,
#  'real estat consult': 0.417,
#  'car rental agenc': 0.417,
#  'car leas servic': 0.0,
#  'ford dealer': 0.227,
#  'car financ loan compani': 0.244,
#  'trailer rental servic': 0.417,
#  'furnitur rental servic': 0.0,
#  'tuxedo shop': 0.0,
#  'dress tuxedo rental servic': 0.417,
#  'wed store': 0.227,
#  'video store': 0.114,
#  'movi rental': 0.0,
#  'photographi studio': 0.0,
#  'home health care servic': 0.256,
#  'skateboard shop': 0.0,
#  'event technolog servic': 0.0,
#  'parti equip rental servic': 0.417,
#  'construct machin rental servic': 0.417,
#  'audio visual equip rental servic': 0.0,
#  'ship equip industri': 0.0,
#  'physic therapi clinic': 0.256,
#  'plastic fabric compani': 0.103,
#  'plastic product supplier': 0.103,
#  'auto tag agenc': 0.345,
#  'depart motor vehicl': 0.0,
#  'notari public': 0.0,
#  'privat investig': 0.0,
#  'escrow servic': 0.0,
#  'real estat agent': 0.417,
#  'playground': 0.067,
#  'plumber': 0.0,
#  'port author': 0.2,
#  'portrait studio': 0.0,
#  'post offic': 0.0,
#  'profession servic': 0.0,
#  'univers hospit': 0.176,
#  'public relat firm': 0.0,
#  'civil engin compani': 0.0,
#  'draft servic': 0.204,
#  'pump supplier': 0.0,
#  'interior construct contractor': 0.323,
#  'carpet clean servic': 0.0,
#  'exhibit planner': 0.0,
#  'decal supplier': 0.0,
#  'stage light equip supplier': 0.053,
#  'event manag compani': 0.0,
#  'radio broadcast': 0.0,
#  'comput support servic': 0.037,
#  'ravin': 0.0,
#  'employ center': 0.0,
#  'nation health foundat': 0.0,
#  'real estat develop': 0.0,
#  'advertis agenc': 0.0,
#  'promot product supplier': 0.0,
#  'advertis servic': 0.0,
#  'record storag facil': 0.0,
#  'fund manag compani': 0.244,
#  'recreat center': 0.4,
#  'bakeri': 0.137,
#  'databas manag compani': 0.0,
#  'market research': 0.204,
#  'recycl center': 0.0,
#  'region govern offic': 0.345,
#  'rehabilit center': 0.256,
#  'religi institut': 0.204,
#  'religi organ': 0.204,
#  'repair servic': 0.204,
#  'emerg veterinarian servic': 0.0,
#  'pet sitter': 0.0,
#  'research product develop': 0.204,
#  'build societi': 0.323,
#  'valet park servic': 0.204,
#  'nurs agenc': 0.0,
#  'execut search firm': 0.0,
#  'recruit': 0.227,
#  'temp agenc': 0.0,
#  'health center': 0.256,
#  'restaur': 0.533,
#  'roof contractor': 0.323,
#  'sport nutrit store': 0.0,
#  'credit report agenc': 0.0,
#  'automobil storag facil': 0.571,
#  'debt collect agenc': 0.227,
#  'park': 0.0,
#  'court report': 0.227,
#  'tour agenc': 0.0,
#  'tour oper': 0.227,
#  'convent inform bureau': 0.0,
#  'balloon ride tour agenc': 0.156,
#  'secur guard servic': 0.114,
#  'locksmith': 0.227,
#  'commerci clean servic': 0.0,
#  'blast clean servic': 0.0,
#  'confer center': 0.0,
#  'safeti equip supplier': 0.0,
#  'garbag dump': 0.227,
#  'sanit servic': 0.0,
#  'garbag dump servic': 0.0,
#  'environment health servic': 0.0,
#  'portabl toilet supplier': 0.0,
#  'public work depart': 0.345,
#  'school district offic': 0.588,
#  'sailmak': 0.0,
#  'commun colleg': 0.588,
#  'salvag yard': 0.0,
#  'busi school': 0.588,
#  'trade school': 0.588,
#  'privat univers': 0.0,
#  'comput train school': 0.588,
#  'school suppli store': 0.0,
#  'screen printer': 0.041,
#  'media consult': 0.143,
#  'beauti school': 0.588,
#  'flight school': 0.588,
#  'seaport': 0.0,
#  'secur system supplier': 0.0,
#  'middl school': 0.588,
#  'nonprofit': 0.0,
#  'shoot rang': 0.0,
#  'soccer club': 0.4,
#  'camp': 0.467,
#  'dive contractor': 0.0,
#  'languag school': 0.588,
#  'english languag school': 0.588,
#  'preschool': 0.256,
#  'self storag facil': 0.0,
#  'semi conductor supplier': 0.053,
#  'drive school': 0.588,
#  'truck school': 0.588,
#  'senior citizen center': 0.256,
#  'servic': 0.0,
#  'children hospit': 0.256,
#  'dental suppli store': 0.0,
#  'shipyard': 0.0,
#  'orthodox synagogu': 0.204,
#  'short term apart rental agenc': 0.417,
#  'nutritionist': 0.256,
#  'ophthalmologist': 0.0,
#  'ophthalmolog clinic': 0.256,
#  'social servic organ': 0.256,
#  'social welfar center': 0.256,
#  'solar energi compani': 0.714,
#  'solar energi equip supplier': 0.714,
#  'special educ school': 0.588,
#  'podiatrist': 0.256,
#  'reproduct health clinic': 0.256,
#  'sport good store': 0.455,
#  'dialysi center': 0.256,
#  'sport complex': 0.4,
#  'well program': 0.0,
#  'sportswear store': 0.409,
#  'privat hospit': 0.0,
#  'radiologist': 0.256,
#  'medic diagnost imag center': 0.256,
#  'ray lab': 0.256,
#  'blood bank': 0.145,
#  'stainless steel plant': 0.053,
#  'state agenc': 0.345,
#  'heliport': 0.0,
#  'health care compani': 0.256,
#  'psychiatr hospit': 0.256,
#  'state govern offic': 0.345,
#  'medic institut': 0.256,
#  'steel construct compani': 0.323,
#  'clean servic': 0.0,
#  'steel drum supplier': 0.053,
#  'assist live facil': 0.256,
#  'steel erector': 0.0,
#  ...}

# %%
calc_avg_pre(ret_docs_dic, queries_dic, cutoff=-1)[1]
# Out:
# 0.143

# %%
calc_NDCG_at_n(ret_docs_dic, queries_dic, n=-1, base=2)
# Out:
# {'home improv store': 0.442,
#  'diesel fuel supplier': 0.015,
#  'church': 0.021,
#  'farm': 0.842,
#  'seed supplier': 0.015,
#  'account': 0.957,
#  'truck compani': 0.775,
#  'export': 0.026,
#  'grain elev': 0.203,
#  'popcorn store': 0.949,
#  'agricultur servic': 0.016,
#  'warehous': 0.834,
#  'agricultur product': 0.188,
#  'ranch': 0.913,
#  'hold compani': 0.966,
#  'farm equip supplier': 0.015,
#  'store': 0.469,
#  'groceri store': 0.914,
#  'rice mill': 0.978,
#  'food product supplier': 0.015,
#  'account firm': 0.021,
#  'produc market': 0.024,
#  'pet suppli store': 0.93,
#  'wholesal': 0.315,
#  'produc wholesal': 0.744,
#  'distribut servic': 0.021,
#  'crop grower': 0.864,
#  'addict treatment center': 0.604,
#  'natur good store': 0.024,
#  'orchard': 0.855,
#  'lumber store': 0.015,
#  'mine': 0.546,
#  'transport servic': 0.122,
#  'invest compani': 0.972,
#  'fruit wholesal': 0.078,
#  'real estat agenc': 0.942,
#  'event venu': 0.024,
#  'frozen dessert supplier': 0.85,
#  'wine wholesal import': 0.33,
#  'wineri': 0.83,
#  'aerospac compani': 0.979,
#  'cold storag facil': 0.848,
#  'employ agenc': 0.024,
#  'plant nurseri': 0.024,
#  'air condit contractor': 0.754,
#  'air condit repair servic': 0.035,
#  'fruit veget wholesal': 0.024,
#  'aircraft rental servic': 0.757,
#  'monasteri': 0.914,
#  'allergist': 0.948,
#  'herb shop': 0.254,
#  'aluminum supplier': 0.986,
#  'ambul servic': 0.027,
#  'wholesal plant nurseri': 0.938,
#  'amus machin supplier': 0.044,
#  'anim hospit': 0.021,
#  'farmer market': 0.024,
#  'vapor store': 0.909,
#  'cigar shop': 0.872,
#  'tobacco shop': 0.051,
#  'well drill contractor': 0.039,
#  'librari': 0.543,
#  'apart build': 0.046,
#  'apart rental agenc': 0.494,
#  'dairi farm': 0.655,
#  'architect': 0.973,
#  'organ farm': 0.882,
#  'architectur design': 0.907,
#  'architectur firm': 0.967,
#  'livestock produc': 0.016,
#  'dairi supplier': 0.015,
#  'biotechnolog compani': 0.629,
#  'artist': 0.911,
#  'egg supplier': 0.975,
#  'poultri farm': 0.014,
#  'chicken hatcheri': 0.967,
#  'art organ': 0.922,
#  'associ organ': 0.96,
#  'food store': 0.917,
#  'deli': 0.078,
#  'bank': 0.94,
#  'fish process': 0.014,
#  'fish farm': 0.659,
#  'seafood wholesal': 0.57,
#  'tropic fish store': 0.949,
#  'non profit organ': 0.915,
#  'econom develop agenc': 0.639,
#  'seafood market': 0.928,
#  'honey farm': 0.664,
#  'hors breeder': 0.016,
#  'asphalt contractor': 0.802,
#  'livestock dealer': 0.015,
#  'depart store': 0.518,
#  'mill': 0.011,
#  'atv dealer': 0.963,
#  'audio visual consult': 0.005,
#  'pallet supplier': 0.011,
#  'wood supplier': 0.015,
#  'hardwar store': 0.024,
#  'furnitur wholesal': 0.015,
#  'auditor': 0.46,
#  'oil natur compani': 0.895,
#  'auto bodi shop': 0.958,
#  'boat repair shop': 0.005,
#  'associ': 0.96,
#  'rail contractor': 0.005,
#  'publish': 0.839,
#  'pond suppli store': 0.085,
#  'agricultur cooper': 0.037,
#  'print equip supplier': 0.481,
#  'auto insur agenc': 0.951,
#  'altern fuel station': 0.543,
#  'auto part manufactur': 0.031,
#  'foundat': 0.918,
#  'fertil supplier': 0.945,
#  'farm compani': 0.838,
#  'financ broker': 0.931,
#  'fire station': 0.037,
#  'environment consult': 0.924,
#  'civil engin': 0.467,
#  'fire protect servic': 0.037,
#  'compani': 0.021,
#  'oilfield': 0.039,
#  'banquet hall': 0.822,
#  'mine compani': 0.545,
#  'coalfield': 0.039,
#  'steel fabric': 0.005,
#  'quarri': 0.895,
#  'gold mine compani': 0.546,
#  'high rise build': 0.86,
#  'basketbal club': 0.153,
#  'gold dealer': 0.015,
#  'batteri manufactur': 0.967,
#  'electr util compani': 0.037,
#  'environment program': 0.021,
#  'offic': 0.024,
#  'stone supplier': 0.015,
#  'aggreg supplier': 0.015,
#  'sand gravel supplier': 0.039,
#  'build materi supplier': 0.773,
#  'beauti suppli store': 0.7,
#  'crush stone supplier': 0.015,
#  'rock shop': 0.015,
#  'road construct compani': 0.42,
#  'market consult': 0.903,
#  'blood test servic': 0.959,
#  'contractor': 0.809,
#  'excav contractor': 0.812,
#  'asphalt mix plant': 0.682,
#  'readi mix concret supplier': 0.914,
#  'sand plant': 0.039,
#  'bmw dealer': 0.963,
#  'bookbind': 0.613,
#  'garden center': 0.779,
#  'abras supplier': 0.011,
#  'granit supplier': 0.011,
#  'drill contractor': 0.039,
#  'bpo compani': 0.804,
#  'oil explor servic': 0.898,
#  'build complex': 0.046,
#  'construct equip supplier': 0.015,
#  'mine equip': 0.005,
#  'ticket agenc': 0.024,
#  'busi center': 0.024,
#  'skyscrap': 0.035,
#  'softwar compani': 0.825,
#  'busi develop servic': 0.233,
#  'busi manag consult': 0.87,
#  'cabinet maker': 0.996,
#  'call center': 0.024,
#  'cancer treatment center': 0.719,
#  'power plant consult': 0.035,
#  'busi park': 0.85,
#  'petroleum product compani': 0.015,
#  'park lot': 0.021,
#  'water util compani': 0.751,
#  'car repair mainten': 0.883,
#  'water treatment plant': 0.751,
#  'car servic': 0.511,
#  'cattl market': 0.015,
#  'sewag dispos servic': 0.803,
#  'certifi public account': 0.021,
#  'govern offic': 0.81,
#  'chariti': 0.917,
#  'air condit system supplier': 0.015,
#  'chemic industri': 0.95,
#  'chemic manufactur': 0.951,
#  'titl compani': 0.021,
#  'chemic plant': 0.95,
#  'properti manag compani': 0.046,
#  'custom home builder': 0.738,
#  'window instal servic': 0.035,
#  'fire damag restor servic': 0.024,
#  'equip rental agenc': 0.741,
#  'chemic wholesal': 0.015,
#  'financi planner': 0.616,
#  'telecommun servic provid': 0.799,
#  'energi equip solut': 0.024,
#  'chiropractor': 0.96,
#  'steel distributor': 0.015,
#  'citi govern offic': 0.811,
#  'crane servic': 0.005,
#  'garag door supplier': 0.035,
#  'industri door supplier': 0.005,
#  'citi town hall': 0.037,
#  'cloth wholesal': 0.072,
#  'coin oper laundri equip supplier': 0.977,
#  'metal supplier': 0.015,
#  'glass shop': 0.035,
#  'colleg': 0.568,
#  'side contractor': 0.82,
#  'commerci printer': 0.011,
#  'storag facil': 0.868,
#  'commun tower': 0.035,
#  'janitori servic': 0.024,
#  'comput consult': 0.577,
#  'fire protect system supplier': 0.037,
#  'elev servic': 0.005,
#  'industri equip supplier': 0.015,
#  'dri wall contractor': 0.791,
#  'insul contractor': 0.791,
#  'concret contractor': 0.862,
#  'scaffold rental servic': 0.762,
#  'construct compani': 0.477,
#  'floor store': 0.633,
#  'floor contractor': 0.798,
#  'tile contractor': 0.808,
#  'tile manufactur': 0.035,
#  'glass mirror shop': 0.035,
#  'construct materi wholesal': 0.015,
#  'gutter clean servic': 0.024,
#  'sheet metal contractor': 0.944,
#  'consult': 0.899,
#  'contain servic': 0.005,
#  'septic system servic': 0.024,
#  'corpor campu': 0.483,
#  'water damag restor servic': 0.024,
#  'welder': 0.005,
#  'corpor offic': 0.483,
#  'anim': 0.88,
#  'anim feed store': 0.051,
#  'anim protect organ': 0.021,
#  'brew suppli store': 0.015,
#  'cosmet store': 0.7,
#  'counti govern offic': 0.811,
#  'sugar factori': 0.853,
#  'confectioneri wholesal': 0.277,
#  'financi institut': 0.037,
#  'candi store': 0.947,
#  'confectioneri': 0.024,
#  'chocol factori': 0.855,
#  'chocol shop': 0.729,
#  'courier servic': 0.829,
#  'cowork space': 0.046,
#  'frozen food manufactur': 0.757,
#  'beverag distributor': 0.015,
#  'agricultur organ': 0.037,
#  'dairi store': 0.015,
#  'dairi': 0.875,
#  'ice cream shop': 0.328,
#  'medic laboratori': 0.659,
#  'demolit contractor': 0.849,
#  'meat processor': 0.864,
#  'fmcg manufactur': 0.046,
#  'garbag collect servic': 0.024,
#  'wholesal bakeri': 0.903,
#  'dentist': 0.945,
#  'dessert shop': 0.014,
#  'cupcak shop': 0.014,
#  'nut store': 0.947,
#  'wholesal grocer': 0.824,
#  'design engin': 0.947,
#  'busi busi servic': 0.863,
#  'condiment supplier': 0.946,
#  'digit print servic': 0.612,
#  'culinari school': 0.497,
#  'import': 0.026,
#  'bottl water supplier': 0.828,
#  'coffe roaster': 0.014,
#  'packag suppli store': 0.024,
#  'ice supplier': 0.827,
#  'breweri': 0.825,
#  'winemak compani': 0.014,
#  'distilleri': 0.825,
#  'disabl servic support organis': 0.027,
#  'district govern offic': 0.809,
#  'air filter supplier': 0.005,
#  'tire shop': 0.819,
#  'fasten supplier': 0.996,
#  'fabric product manufactur': 0.84,
#  'textil': 0.465,
#  'textil export': 0.465,
#  'textil engin': 0.465,
#  'fabric store': 0.453,
#  'knit shop': 0.287,
#  'doctor': 0.878,
#  'lamin servic': 0.011,
#  'plastic resin manufactur': 0.202,
#  'carpet manufactur': 0.738,
#  'upholsteri shop': 0.875,
#  'busi administr servic': 0.021,
#  'furnitur store': 0.225,
#  'dri cleaner': 0.021,
#  'packag compani': 0.789,
#  'duti free store': 0.909,
#  'commerc servic': 0.051,
#  'cabl compani': 0.035,
#  'educ': 0.494,
#  'outlet store': 0.49,
#  'lingeri store': 0.237,
#  'cloth fabric manufactur': 0.068,
#  'educ center': 0.492,
#  'uniform store': 0.281,
#  'men cloth store': 0.948,
#  'cloth store': 0.94,
#  'women cloth store': 0.949,
#  'western apparel store': 0.024,
#  'costum store': 0.046,
#  'game store': 0.52,
#  'hat shop': 0.227,
#  'leather good manufactur': 0.36,
#  'educ consult': 0.493,
#  'leather export': 0.617,
#  'shoe store': 0.247,
#  'boutiqu': 0.024,
#  'leather wholesal': 0.18,
#  'handbag shop': 0.618,
#  'electron store': 0.421,
#  'luggag store': 0.608,
#  'build materi store': 0.779,
#  'saw mill': 0.971,
#  'electr engin': 0.021,
#  'deck builder': 0.755,
#  'concret product supplier': 0.913,
#  'plywood supplier': 0.939,
#  'electr instal servic': 0.035,
#  'truss manufactur': 0.836,
#  'door supplier': 0.011,
#  'wood lamin floor supplier': 0.98,
#  'aircraft suppli store': 0.015,
#  'modular home builder': 0.011,
#  'portabl build manufactur': 0.031,
#  'modular home dealer': 0.057,
#  'mulch supplier': 0.015,
#  'electrician': 0.035,
#  'paper mill': 0.981,
#  'energi supplier': 0.878,
#  'engin': 0.021,
#  'print shop': 0.612,
#  'custom label printer': 0.011,
#  'market': 0.021,
#  'market agenc': 0.021,
#  'engin consult': 0.502,
#  'entertain': 0.492,
#  'envelop supplier': 0.011,
#  'oil refineri': 0.637,
#  'record studio': 0.952,
#  'environ renew natur resourc': 0.085,
#  'finish materi supplier': 0.768,
#  'event ticket seller': 0.024,
#  'waterproof compani': 0.035,
#  'auto part store': 0.024,
#  'heat oil supplier': 0.051,
#  'famili practic physician': 0.948,
#  'machin manufactur': 0.03,
#  'industri supplier': 0.011,
#  'weld suppli store': 0.005,
#  'dri ice supplier': 0.931,
#  'privat equiti firm': 0.026,
#  'famili servic center': 0.466,
#  'feder govern offic': 0.811,
#  'vitamin supplement store': 0.705,
#  'feed manufactur': 0.353,
#  'medic equip supplier': 0.015,
#  'medic suppli store': 0.015,
#  'medic clinic': 0.773,
#  'research institut': 0.906,
#  'biochem supplier': 0.015,
#  'fiber optic product supplier': 0.005,
#  'paint manufactur': 0.968,
#  'equip supplier': 0.015,
#  'food': 0.014,
#  'pipe supplier': 0.98,
#  'oil field equip supplier': 0.005,
#  'food broker': 0.015,
#  'food manufactur': 0.584,
#  'food process compani': 0.014,
#  'fenc suppli store': 0.248,
#  'food produc': 0.014,
#  'forestri servic': 0.928,
#  'foundri': 0.996,
#  'wholesal jewel': 0.344,
#  'cooki shop': 0.873,
#  'truck rental agenc': 0.911,
#  'fruit veget process': 0.956,
#  'kitchen suppli store': 0.015,
#  'hydraul equip supplier': 0.015,
#  'irrig equip supplier': 0.085,
#  'bear supplier': 0.978,
#  'metallurgi compani': 0.005,
#  'plastic inject mold servic': 0.005,
#  'gener contractor': 0.402,
#  'gener hospit': 0.75,
#  'tool manufactur': 0.005,
#  'industri design compani': 0.021,
#  'hyundai dealer': 0.015,
#  'glass industri': 0.969,
#  'polym supplier': 0.015,
#  'print equip suppli': 0.005,
#  'toner cartridg supplier': 0.993,
#  'printer repair servic': 0.881,
#  'fuel supplier': 0.015,
#  'glass manufactur': 0.971,
#  'plastic bag supplier': 0.942,
#  'glasswar manufactur': 0.011,
#  'polythen plastic sheet supplier': 0.938,
#  'pvc industri': 0.011,
#  'countertop store': 0.453,
#  'cabinet store': 0.463,
#  'fiberglass supplier': 0.011,
#  'golf cart dealer': 0.963,
#  'auto repair shop': 0.959,
#  'hose supplier': 0.931,
#  'rubber product supplier': 0.86,
#  'automot': 0.015,
#  'commerci refriger supplier': 0.015,
#  'golf club': 0.982,
#  'golf cours': 0.044,
#  'green energi supplier': 0.927,
#  'greenhous': 0.016,
#  'auto glass shop': 0.021,
#  'light manufactur': 0.966,
#  'cement manufactur': 0.923,
#  'brick manufactur': 0.917,
#  'natur stone supplier': 0.015,
#  'gym': 0.99,
#  'marbl supplier': 0.011,
#  'corpor gift supplier': 0.906,
#  'shipbuild repair compani': 0.005,
#  'construct mainten offic': 0.401,
#  'boiler manufactur': 0.031,
#  'contain supplier': 0.005,
#  'home construct': 0.393,
#  'health': 0.947,
#  'heart hospit': 0.812,
#  'spring supplier': 0.893,
#  'electr util manufactur': 0.037,
#  'aircraft manufactur': 0.987,
#  'metal heat treat servic': 0.982,
#  'plate servic': 0.005,
#  'autom compani': 0.005,
#  'heat contractor': 0.755,
#  'plumb suppli store': 0.015,
#  'gun shop': 0.051,
#  'ammunit supplier': 0.977,
#  'pipe manufactur': 0.032,
#  'school': 0.574,
#  'fire protect equip supplier': 0.037,
#  'agricultur machineri manufactur': 0.005,
#  'lawn mower store': 0.248,
#  'lawn irrig equip supplier': 0.085,
#  'financi consult': 0.13,
#  'helicopt charter': 0.595,
#  'packag machineri': 0.005,
#  'histor landmark': 0.95,
#  'electron manufactur': 0.987,
#  'graphic design': 0.689,
#  'eye care center': 0.804,
#  'optic product manufactur': 0.031,
#  'imag consult': 0.541,
#  'clean product supplier': 0.015,
#  'fireplac store': 0.015,
#  'home builder': 0.671,
#  'tool die shop': 0.655,
#  'metal stamp servic': 0.93,
#  'environment organ': 0.965,
#  'food process equip': 0.005,
#  'loan agenc': 0.923,
#  'power plant equip supplier': 0.015,
#  'home good store': 0.635,
#  'engin rebuild servic': 0.021,
#  'air compressor supplier': 0.005,
#  'honda dealer': 0.965,
#  'elev manufactur': 0.031,
#  'crane dealer': 0.005,
#  'crane rental agenc': 0.765,
#  'compound build': 0.035,
#  'tractor dealer': 0.015,
#  'furnac part supplier': 0.015,
#  'heat equip supplier': 0.015,
#  'pneumat tool supplier': 0.015,
#  'truck stop': 0.024,
#  'comput hardwar manufactur': 0.991,
#  'satellit commun servic': 0.788,
#  'hospit': 0.78,
#  'electron compani': 0.024,
#  'electron part supplier': 0.015,
#  'hvac contractor': 0.753,
#  'industri engin': 0.236,
#  'contact lens supplier': 0.005,
#  'inform servic': 0.416,
#  'build': 0.943,
#  'water work equip supplier': 0.015,
#  'measur instrument supplier': 0.994,
#  'scientif equip supplier': 0.015,
#  'medic center': 0.761,
#  'watch manufactur': 0.015,
#  'corpor entertain servic': 0.044,
#  'insur': 0.951,
#  'record compani': 0.99,
#  'video duplic servic': 0.035,
#  'insur agenc': 0.951,
#  'light store': 0.988,
#  'light wholesal': 0.984,
#  'entertain agenc': 0.927,
#  'insur broker': 0.951,
#  'electr equip supplier': 0.015,
#  'electr motor store': 0.195,
#  'railroad compani': 0.524,
#  'electr suppli store': 0.015,
#  'insur compani': 0.951,
#  'factori equip supplier': 0.015,
#  'invest servic': 0.97,
#  'laser equip supplier': 0.201,
#  'execut suit rental agenc': 0.037,
#  'truck dealer': 0.015,
#  'motor vehicl dealer': 0.831,
#  'car dealer': 0.955,
#  'truck topper supplier': 0.015,
#  'polic suppli store': 0.913,
#  'iron steel contractor': 0.862,
#  'fire depart equip supplier': 0.037,
#  'tow equip provid': 0.919,
#  'logist servic': 0.677,
#  'trailer manufactur': 0.995,
#  'trailer dealer': 0.046,
#  'dealer': 0.965,
#  'auto spring shop': 0.021,
#  'auto upholster': 0.132,
#  'auto bodi part supplier': 0.827,
#  'car factori': 0.005,
#  'freight forward servic': 0.587,
#  'brake shop': 0.958,
#  'railroad equip supplier': 0.015,
#  'jewelri equip supplier': 0.992,
#  'boat builder': 0.005,
#  'ship build': 0.005,
#  'marin suppli store': 0.248,
#  'boat dealer': 0.886,
#  'kawasaki motorcycl dealer': 0.964,
#  'knife manufactur': 0.033,
#  'labor union': 0.958,
#  'furnitur maker': 0.997,
#  'bank financ': 0.952,
#  'furnitur manufactur': 0.996,
#  'logist': 0.899,
#  'massag suppli store': 0.015,
#  'telecommun equip supplier': 0.005,
#  'babi store': 0.453,
#  'mold supplier': 0.005,
#  'offic equip supplier': 0.015,
#  'offic furnitur store': 0.986,
#  'store equip supplier': 0.015,
#  'laboratori': 0.021,
#  'health beauti shop': 0.021,
#  'learn center': 0.915,
#  'dental laboratori': 0.998,
#  'land surveyor': 0.021,
#  'educ suppli store': 0.905,
#  'jewelri store': 0.946,
#  'playground equip supplier': 0.015,
#  'outdoor sport store': 0.797,
#  'toy store': 0.52,
#  'secur servic': 0.024,
#  'sign shop': 0.989,
#  'offic suppli store': 0.905,
#  'landscap': 0.891,
#  'gasket manufactur': 0.993,
#  'piano maker': 0.005,
#  'piano store': 0.466,
#  'funer home': 0.021,
#  'monument': 0.044,
#  'book publish': 0.841,
#  'wig shop': 0.227,
#  'laundromat': 0.977,
#  'auto wrecker': 0.021,
#  'auto part market': 0.818,
#  'jeep dealer': 0.965,
#  'restaur suppli store': 0.015,
#  'roof suppli store': 0.015,
#  'law firm': 0.021,
#  'build materi market': 0.768,
#  'camera store': 0.015,
#  'lawn care servic': 0.024,
#  'comput secur servic': 0.024,
#  'comput store': 0.015,
#  'design agenc': 0.021,
#  'diagnost center': 0.735,
#  'laboratori equip supplier': 0.997,
#  'home theater store': 0.005,
#  'metal industri supplier': 0.015,
#  'landscap suppli store': 0.248,
#  'applianc part supplier': 0.015,
#  'vacuum cleaner store': 0.524,
#  'audio visual equip supplier': 0.983,
#  'lawyer': 0.927,
#  'cell phone store': 0.035,
#  'bathroom suppli store': 0.015,
#  'leas servic': 0.046,
#  'construct machin dealer': 0.015,
#  'dairi farm equip supplier': 0.015,
#  'propan supplier': 0.051,
#  'legal servic': 0.021,
#  'janitori equip supplier': 0.024,
#  'life insur agenc': 0.951,
#  'railroad contractor': 0.282,
#  'swim pool suppli store': 0.91,
#  'light bulb supplier': 0.969,
#  'linen store': 0.021,
#  'metal construct compani': 0.944,
#  'local govern offic': 0.808,
#  'log contractor': 0.016,
#  'machin shop': 0.792,
#  'hotel suppli store': 0.078,
#  'import export compani': 0.026,
#  'sew compani': 0.051,
#  'research foundat': 0.904,
#  'machineri part manufactur': 0.005,
#  'sport accessori wholesal': 0.015,
#  'fashion design': 0.021,
#  'chees manufactur': 0.014,
#  'chees shop': 0.014,
#  'ship mail': 0.829,
#  'wholesal food store': 0.015,
#  'organ food store': 0.375,
#  'pie shop': 0.014,
#  'auction hous': 0.896,
#  'livestock auction hous': 0.015,
#  'cotton export': 0.143,
#  'plastic wholesal': 0.015,
#  'mail servic': 0.829,
#  'manufactur': 0.994,
#  'station': 0.543,
#  'beer distributor': 0.015,
#  'alcohol beverag wholesal': 0.015,
#  'religi good store': 0.021,
#  'book wholesal': 0.262,
#  'masonri suppli store': 0.248,
#  'wholesal florist': 0.074,
#  'florist': 0.919,
#  'marin engin': 0.021,
#  'paint store': 0.373,
#  'use auto part store': 0.024,
#  'masonri contractor': 0.855,
#  'use car dealer': 0.955,
#  'use truck dealer': 0.831,
#  'massag therapist': 0.96,
#  'materi handl equip supplier': 0.015,
#  'marina': 0.99,
#  'meat packer': 0.015,
#  'mattress store': 0.734,
#  'blind shop': 0.005,
#  'interior design': 0.624,
#  'window treatment store': 0.635,
#  'applianc store': 0.421,
#  'health food store': 0.358,
#  'direct mail advertis': 0.276,
#  'meat wholesal': 0.196,
#  'butcher shop deli': 0.227,
#  'italian groceri store': 0.947,
#  'food servic': 0.823,
#  'groceri deliveri servic': 0.829,
#  'wine store': 0.908,
#  'liquor store': 0.908,
#  'kiosk': 0.078,
#  'optometrist': 0.961,
#  'optician': 0.871,
#  'mechan contractor': 0.755,
#  'mechan engin': 0.021,
#  'cafe': 0.078,
#  'jewel': 0.936,
#  'leather good store': 0.94,
#  'gift shop': 0.906,
#  'craft store': 0.466,
#  'hobbi store': 0.558,
#  'fabric wholesal': 0.015,
#  'scrap metal dealer': 0.015,
#  'quilt shop': 0.051,
#  'sheet music store': 0.82,
#  'music instrument manufactur': 0.351,
#  'music store': 0.822,
#  'music instrument store': 0.896,
#  'band': 0.044,
#  'bookstor': 0.051,
#  'art museum': 0.724,
#  'newsstand': 0.88,
#  'medic equip manufactur': 0.971,
#  'fashion accessori store': 0.94,
#  'discount store': 0.488,
#  'cemeteri': 0.904,
#  'stop': 0.021,
#  'varieti store': 0.467,
#  'thrift store': 0.916,
#  'medic group': 0.571,
#  'donat center': 0.021,
#  'pet store': 0.93,
#  'art galleri': 0.051,
#  'art dealer': 0.051,
#  'hous develop': 0.037,
#  'mobil home dealer': 0.061,
#  'conveni store': 0.943,
#  'medic offic': 0.811,
#  'medic technolog manufactur': 0.351,
#  'children furnitur store': 0.225,
#  'mental health clinic': 0.823,
#  'airlin': 0.021,
#  'aviat consult': 0.021,
#  'travel agenc': 0.884,
#  'travel servic': 0.818,
#  'airport': 0.021,
#  'mental health servic': 0.948,
#  'ship compani': 0.021,
#  'metal fabric': 0.944,
#  'cruis line compani': 0.021,
#  'tow servic': 0.92,
#  'ferri termin': 0.947,
#  'ferri servic': 0.021,
#  'metal finish': 0.983,
#  'boat tour agenc': 0.813,
#  'move compani': 0.021,
#  'move storag servic': 0.021,
#  'state depart transport': 0.037,
#  'depart transport': 0.037,
#  'handicap transport servic': 0.116,
#  'railway servic': 0.021,
#  'train station': 0.021,
#  'depot': 0.021,
#  'charter': 0.948,
#  'metal process compani': 0.944,
#  'mix use': 0.046,
#  'motorcycl shop': 0.828,
#  'limousin servic': 0.021,
#  'chauffeur servic': 0.021,
#  'school servic': 0.021,
#  'airport shuttl servic': 0.021,
#  'tourist inform center': 0.024,
#  'carriag ride servic': 0.021,
#  'cruis agenc': 0.024,
#  'tourist attract': 0.024,
#  'ski resort': 0.984,
#  'ski area': 0.044,
#  'fix base oper': 0.021,
#  'aircraft mainten compani': 0.021,
#  'motorsport store': 0.39,
#  'boat rental servic': 0.965,
#  'util trailer dealer': 0.046,
#  'forklift dealer': 0.015,
#  'municip administr offic': 0.523,
#  'nephrologist': 0.948,
#  'coach compani': 0.021,
#  'ship servic': 0.203,
#  'ship mail servic': 0.815,
#  'newspap publish': 0.843,
#  'shred servic': 0.024,
#  'nuclear power compani': 0.905,
#  'nurs home': 0.027,
#  'media compani': 0.873,
#  'multimedia electron book publish': 0.898,
#  'internet market servic': 0.021,
#  'greet card shop': 0.955,
#  'theme park': 0.926,
#  'film product compani': 0.035,
#  'obstetrician gynecologist': 0.948,
#  'movi studio': 0.39,
#  'video product servic': 0.968,
#  'movi theater': 0.876,
#  'theater compani': 0.044,
#  'perform art theater': 0.924,
#  'occup safeti health': 0.021,
#  'offic space rental agenc': 0.494,
#  'commerci real estat agenc': 0.942,
#  'art school': 0.96,
#  'music publish': 0.552,
#  'print music publish': 0.557,
#  'home audio store': 0.005,
#  'musician': 0.937,
#  'music manag promot': 0.918,
#  'video edit servic': 0.035,
#  'offic suppli wholesal': 0.043,
#  'offici resid': 0.046,
#  'orthoped clinic': 0.828,
#  'painter': 0.035,
#  'paint': 0.035,
#  'telephon compani': 0.035,
#  'media hous': 0.88,
#  'paper distributor': 0.015,
#  'news servic': 0.051,
#  'public librari': 0.035,
#  'law librari': 0.577,
#  'museum': 0.95,
#  'feder reserv bank': 0.941,
#  'credit union': 0.949,
#  'atm': 0.026,
#  'pave contractor': 0.846,
#  'mortgag lender': 0.923,
#  'invest bank': 0.997,
#  'check cash servic': 0.026,
#  'stock broker': 0.026,
#  'health consult': 0.895,
#  'health insur agenc': 0.987,
#  'payrol servic': 0.932,
#  'pediatrician': 0.948,
#  'human resourc consult': 0.901,
#  'pest control servic': 0.024,
#  'pet board servic': 0.848,
#  'pet care': 0.93,
#  'loss adjust': 0.947,
#  'pharmaceut compani': 0.97,
#  'pharmaceut product wholesal': 0.33,
#  'pharmaci': 0.709,
#  'educ institut': 0.568,
#  'retir commun': 0.027,
#  'fratern organ': 0.915,
#  'photo lab': 0.021,
#  'properti invest': 0.046,
#  'photograph': 0.762,
#  'photographi school': 0.021,
#  'star hotel': 0.838,
#  'convent center': 0.024,
#  'real estat apprais': 0.95,
#  'photographi servic': 0.021,
#  'resort hotel': 0.838,
#  'real estat consult': 0.942,
#  'car rental agenc': 0.908,
#  'car leas servic': 0.046,
#  'ford dealer': 0.965,
#  'car financ loan compani': 0.914,
#  'trailer rental servic': 0.905,
#  'furnitur rental servic': 0.046,
#  'tuxedo shop': 0.046,
#  'dress tuxedo rental servic': 0.959,
#  'wed store': 0.237,
#  'video store': 0.492,
#  'movi rental': 0.035,
#  'photographi studio': 0.021,
#  'home health care servic': 0.414,
#  'skateboard shop': 0.005,
#  'event technolog servic': 0.024,
#  'parti equip rental servic': 0.94,
#  'construct machin rental servic': 0.763,
#  'audio visual equip rental servic': 0.005,
#  'ship equip industri': 0.015,
#  'physic therapi clinic': 0.821,
#  'plastic fabric compani': 0.97,
#  'plastic product supplier': 0.965,
#  'auto tag agenc': 0.932,
#  'depart motor vehicl': 0.037,
#  'notari public': 0.021,
#  'privat investig': 0.024,
#  'escrow servic': 0.026,
#  'real estat agent': 0.942,
#  'playground': 0.373,
#  'plumber': 0.035,
#  'port author': 0.675,
#  'portrait studio': 0.021,
#  'post offic': 0.203,
#  'profession servic': 0.021,
#  'univers hospit': 0.718,
#  'public relat firm': 0.021,
#  'civil engin compani': 0.035,
#  'draft servic': 0.961,
#  'pump supplier': 0.005,
#  'interior construct contractor': 0.403,
#  'carpet clean servic': 0.024,
#  'exhibit planner': 0.024,
#  'decal supplier': 0.005,
#  'stage light equip supplier': 0.966,
#  'event manag compani': 0.024,
#  'radio broadcast': 0.005,
#  'comput support servic': 0.37,
#  'ravin': 0.044,
#  'employ center': 0.024,
#  'nation health foundat': 0.021,
#  'real estat develop': 0.035,
#  'advertis agenc': 0.021,
#  'promot product supplier': 0.021,
#  'advertis servic': 0.021,
#  'record storag facil': 0.046,
#  'fund manag compani': 0.693,
#  'recreat center': 0.99,
#  'bakeri': 0.89,
#  'databas manag compani': 0.035,
#  'market research': 0.48,
#  'recycl center': 0.015,
#  'region govern offic': 0.809,
#  'rehabilit center': 0.684,
#  'religi institut': 0.922,
#  'religi organ': 0.908,
#  'repair servic': 0.874,
#  'emerg veterinarian servic': 0.021,
#  'pet sitter': 0.021,
#  'research product develop': 0.906,
#  'build societi': 0.943,
#  'valet park servic': 0.849,
#  'nurs agenc': 0.027,
#  'execut search firm': 0.024,
#  'recruit': 0.829,
#  'temp agenc': 0.024,
#  'health center': 0.767,
#  'restaur': 0.918,
#  'roof contractor': 0.856,
#  'sport nutrit store': 0.024,
#  'credit report agenc': 0.024,
#  'automobil storag facil': 0.858,
#  'debt collect agenc': 0.189,
#  'park': 0.021,
#  'court report': 0.793,
#  'tour agenc': 0.024,
#  'tour oper': 0.974,
#  'convent inform bureau': 0.024,
#  'balloon ride tour agenc': 0.843,
#  'secur guard servic': 0.7,
#  'locksmith': 0.833,
#  'commerci clean servic': 0.024,
#  'blast clean servic': 0.024,
#  'confer center': 0.024,
#  'safeti equip supplier': 0.015,
#  'garbag dump': 0.998,
#  'sanit servic': 0.024,
#  'garbag dump servic': 0.024,
#  'environment health servic': 0.021,
#  'portabl toilet supplier': 0.024,
#  'public work depart': 0.824,
#  'school district offic': 0.577,
#  'sailmak': 0.014,
#  'commun colleg': 0.588,
#  'salvag yard': 0.015,
#  'busi school': 0.606,
#  'trade school': 0.497,
#  'privat univers': 0.068,
#  'comput train school': 0.637,
#  'school suppli store': 0.015,
#  'screen printer': 0.612,
#  'media consult': 0.276,
#  'beauti school': 0.498,
#  'flight school': 0.498,
#  'seaport': 0.021,
#  'secur system supplier': 0.024,
#  'middl school': 0.574,
#  'nonprofit': 0.021,
#  'shoot rang': 0.044,
#  'soccer club': 0.264,
#  'camp': 0.805,
#  'dive contractor': 0.024,
#  'languag school': 0.929,
#  'english languag school': 0.929,
#  'preschool': 0.915,
#  'self storag facil': 0.046,
#  'semi conductor supplier': 0.271,
#  'drive school': 0.905,
#  'truck school': 0.831,
#  'senior citizen center': 0.602,
#  'servic': 0.021,
#  'children hospit': 0.518,
#  'dental suppli store': 0.005,
#  'shipyard': 0.005,
#  'orthodox synagogu': 0.914,
#  'short term apart rental agenc': 0.494,
#  'nutritionist': 0.96,
#  'ophthalmologist': 0.027,
#  'ophthalmolog clinic': 0.823,
#  'social servic organ': 0.936,
#  'social welfar center': 0.937,
#  'solar energi compani': 0.922,
#  'solar energi equip supplier': 0.927,
#  'special educ school': 0.577,
#  'podiatrist': 0.964,
#  'reproduct health clinic': 0.991,
#  'sport good store': 0.825,
#  'dialysi center': 0.992,
#  'sport complex': 0.473,
#  'well program': 0.026,
#  'sportswear store': 0.488,
#  'privat hospit': 0.027,
#  'radiologist': 0.897,
#  'medic diagnost imag center': 0.68,
#  'ray lab': 0.59,
#  'blood bank': 0.564,
#  'stainless steel plant': 0.956,
#  'state agenc': 0.676,
#  'heliport': 0.021,
#  'health care compani': 0.842,
#  'psychiatr hospit': 0.645,
#  'state govern offic': 0.811,
#  'medic institut': 0.751,
#  'steel construct compani': 0.782,
#  'clean servic': 0.024,
#  'steel drum supplier': 0.764,
#  'assist live facil': 0.828,
#  'steel erector': 0.035,
#  ...}
