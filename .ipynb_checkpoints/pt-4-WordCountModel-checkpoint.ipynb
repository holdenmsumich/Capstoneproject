# %% [markdown]
# ## Pt 4 - Our first Recommender System - Bag Of Words
# With the data finallly prepared, I began exploring different methods for building a Recommender system, starting with the Bag of Words approach. When looking at the dataset, I noticed that each class code had several indicative words that might help determine which class it belongs to, so that is why I chose to test out this approach. However, I know that there are a lot of filler words that are difficult to parse out, as well as semantic terms like "musical instrument store", rather than just "musical", "instrument", and "store."

# %% [markdown]
# #### Load in and process data from previous steps

# %%
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from nltk import word_tokenize
import json
import pandas as pd
import re
stop_words = set(stopwords.words("english"))

PATTERN_S = re.compile("\'s")  # matches `'s` from text  
PATTERN_RN = re.compile("\\r\\n\\b") #matches `\r` and `\n`
PATTERN_PUNC = re.compile(r"[^\w\s]") # matches all non 0-9 A-z whitespace 

def clean_text(text):
    """
    Series of cleaning. String to lower case, remove non words characters and numbers (punctuation, curly brackets etc).
        text (str): input text
    return (str): modified initial text
    """
    text = text.lower()  # lowercase text
    # replace the matched string with ' '
    text = re.sub(PATTERN_S, ' ', text)
    text = re.sub(PATTERN_RN, ' ', text)
    text = re.sub(PATTERN_PUNC, ' ', text)
    return text

def tokenizer(description, stop_words, normalization):
    
    if normalization == 'lemmatize':
        # tokenize and lemmatize text
        lemmatizer = WordNetLemmatizer()
        tokens = [lemmatizer.lemmatize(w) for w in word_tokenize(description)]
        
    elif normalization == 'stem':
        # tokenize and stem text
        stemmer = PorterStemmer()
        tokens = [stemmer.stem(w) for w in word_tokenize(description)]
    
   # remove tokens length of 2 or below and make all lowercase and remove stop words
    tokens = [w.lower() for w in tokens if (w.lower() not in stop_words) and (len(w) > 2) and(w.isalpha())]
    
    return tokens    
    
def process_query(query, normalization):
    
    stop_words = set(stopwords.words("english"))
    
    return tokenizer(clean_text(query), stop_words, normalization)

# %%
# this function returns the top n_rank docs based on word count from the inverted index
def retrieve_n_rank_docs(inverted_index, query, normalization, max_docs=-1):
    ret_docs = {}
    
    counts = {}
    query = process_query(query, normalization)
    
    for word in query:
        try:
            docs = inverted_index.get(word)
            for k, v in docs.items():
                if k in counts:
                    counts[k] += v
                else:
                    counts[k] = v

        except:
            pass
        break
    counts = sorted(counts.items(), key=lambda x: (x[1], -int(x[0][1:])), reverse=True)
    if max_docs > -1:
        ret_docs[' '.join(query)] = [x[0] for x in counts][:max_docs]
    else:
        ret_docs[' '.join(query)] = [x[0] for x in counts]
        
    return ret_docs

# %%
# IMPORT INVERTED_INDEXES
with open(r'assets/inverted_index_stem.json') as f:
    inverted_index_stem = json.load(f)
    
with open(r'assets/inverted_index_lem.json') as f:
    inverted_index_lem = json.load(f)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Input In [138], in <cell line: 2>()
#       1 # IMPORT INVERTED_INDEXES
#       2 with open(r'assets/inverted_index_stem.json') as f:
# ----> 3     inverted_index_stem = json.load(f)
#       5 with open(r'assets/inverted_index_lem.json') as f:
#       6     inverted_index_lem = json.load(f)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\json\__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     276     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     277     a JSON document) to a Python object.
#     278
#    (...)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#     296         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook, **kw)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File ~\AppData\Local\Programs\Python\Python39\lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File ~\AppData\Local\Programs\Python\Python39\lib\json\decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %% [markdown]
# The [6-digit_2017_Codes.xlsx](https://www.census.gov/naics/2017NAICS/6-digit_2017_Codes.xlsx) file provides a NAICS code with the official "Title" of that NAICS code, rather than the description of the NAICS codes we collected before. We will use this file to neatly display class codes/titles so we know what industry we're looking at when exploring the data.

# %%
naics_titles = pd.read_excel('assets/6-digit_2017_Codes.xlsx')
naics_titles['naics'] = naics_titles['naics'].astype(str)

# %%
naics_titles.head()

# %% [markdown]
# ### Text Normalization
# There are two popular methods of normalizing text - lemmatization and stemming. Lemmatization takes the morphological base of a word. For example, studies and "studying", would be lemmatized to "study". Stemming takes the root of the word, for example, "studies" would become "studi" and "studying" would become "study". There are certain cases where one is more useful than the other, so I decided to try them both out. They produced very similar results, with lemmatizing getting a slightly higher score for Mean Average Precision.

# %%
# Here we display the results of the query "Home improvement store" using stemming on a BoW model
stem_df = pd.DataFrame(retrieve_n_rank_docs(inverted_index_lem, 'Home improvement store', 'stem'))
stem_df.columns.values[0] = 'naics'
stem_df = stem_df.merge(naics_titles, on='naics', how='outer')
stem_df[['naics', 'title']].head(10)

# %%
# Here we display the results of the query "musical instrument store" using stemming on a BoW model
stem_df = pd.DataFrame(retrieve_n_rank_docs(inverted_index_lem, 'musical instrument store', 'stem'))
stem_df.columns.values[0] = 'naics'
stem_df = stem_df.merge(naics_titles, on='naics', how='outer')
stem_df[['naics', 'title']].head(10)

# %% [markdown]
# At a high-level glance, these results don't seem too relevant to our queries. There are a few that seem relevant, but should probably be higher up on the list. Let's give lemmatization a try!

# %%
# Here we display the results of the query "musical instrument store" using lemmatize on a BoW model
lem_df = pd.DataFrame(retrieve_n_rank_docs(inverted_index_lem, 'Home improvement store', 'lemmatize'))
lem_df.columns.values[0] = 'naics'
lem_df = lem_df.merge(naics_titles, on='naics', how='outer')
lem_df[['naics', 'title']].head(10)

# %%
lem_df = pd.DataFrame(retrieve_n_rank_docs(inverted_index_lem, 'musical instrument store', 'lemmatize'))
lem_df.columns.values[0] = 'naics'
lem_df = lem_df.merge(naics_titles, on='naics', how='outer')
lem_df[['naics', 'title']].head(10)

# %% [markdown]
# There wasn't really any difference for "Home improvement store" with lemmatizing, but it looks like there are some new results for "musical instrument store". This makes intuitive sense, as lemmatization is keeping the word "musical" rather than just taking the stem "music".
# The results returned for the stemming example show industries that are broadly related to "music," however, the lemmatized example shows industries that are broadly related to things that are "musical". This clearly demonstrates the significance of lemmatizing vs. stemming words in NLP.

# %% [markdown]
# #### Testing
# Finally, we will test different metrics of our recommender system to see how it performs across queries. We will measure Precision and Recall at N, Mean Average Precision at N (mAP@N), and Normalized Discounted Cumulative Gain (NDCG).
#
# The maximum documents returned will be 10, due to the nature of how this recommender system should work. I thought for awhile about increasing the number of documents, but from a functional perspective, returning more than 10 documents to a user defeats the purpose of the Recommender system. You might as well just return all documents to the user, as they are only likely to read through the first few results anyway.
#
# I also experimented with different values for N, but I ultimately concluded that 10 is the ideal number for N, to match the max_docs returned. In the case of this recommender system, N = 10 works because order is not of utmost importance. As long as the retrieved documents contain relevant documents, then the "goal" of this recommender system is complete. There is certainly room for improvemenent in that area, but as I said earlier, there is not always a single best matched NAICS code to a query, and therefore the cutoff should be measured within the range of the max docs returned.

# %%
# load the relevance judgments from Pt 3
relevance_judgments = pd.read_pickle('assets/relevant_naics_df.pkl')
relevance_judgments = dict(zip(relevance_judgments['query'], relevance_judgments['relevant_naics']))

# %%
relevance_judgments

# %%
max_docs = 10
def create_testing_dicts(normalization='lemmatize'):
    ret_docs_dic = {}
    queries_dic = {}

    if normalization == 'lemmatize':
        invert_index = inverted_index_lem
    else:
        invert_index = inverted_index_stem
        
    for query, value in relevance_judgments.items():
        
        ret_docs = retrieve_n_rank_docs(invert_index, query, normalization, max_docs=max_docs)
        if list(ret_docs.keys())[0] not in ret_docs_dic:
            ret_docs_dic[list(ret_docs.keys())[0]] = list(ret_docs.values())[0]
            
        queries_dic[' '.join(process_query(query, normalization))] = value
    
        
    return ret_docs_dic, queries_dic

# %%
# function to calculate precision and recall
def calc_pre_rec_at_n(ret_docs, reljudges, n=-1):
    """
    Calculate precision and recall at n for each query in ret_docs
    """
    
    pre_at_n, rec_at_n = {}, {}
    
    count = 0
    for k, v in ret_docs.items():
        if n > -1 and n <= len(ret_docs):
            s1 = set(v[:n])
        else:
            s1 = set(v)
        s2 = reljudges[k]
        try:
            precision = len(s1.intersection(s2)) / len(s1)
        except:
            pass
        recall = len(s1.intersection(s2)) / len(reljudges[k])
        pre_at_n[k] = round(precision, 3)
        rec_at_n[k] = round(recall, 3)
        count += 1
    return pre_at_n, rec_at_n

# %%
#function to calculate avg precision and mAP
def calc_avg_pre(ret_docs, reljudges, cutoff=-1):
    """
    Calculate (mean) average precision for each query in ret_docs
    """
    
    avg_pre, mean_avg_pre = {}, None
    for k, v in ret_docs.items():
        total_rel = 0
        total = 0
        avg_prec = 0
        for i, doc in enumerate(v):
            if doc in reljudges[k] and cutoff == -1:
                total_rel += 1
                total += 1
                precision = total_rel/total
            elif doc in reljudges[k] and i+1 <= cutoff:
                total_rel += 1
                total += 1
                precision = total_rel/total
            else:
                total += 1
                precision = 0
            avg_prec += precision

        avg_pre[k] = round(avg_prec/len(reljudges[k]), 3)
    
    mean_avg_pre = round(sum(avg_pre.values()) / len(avg_pre), 3)
        
    return avg_pre, mean_avg_pre

# %%
import math

# function to calculate NDCG
def calc_NDCG_at_n(ret_docs, reljudges, n=-1, base=2):
    """
    Calculate NDCG at n for each query in ret_docs
    """
    
    ndcg = {}
    
    for k, v in ret_docs.items():
        
        counts = list(reversed([x for x in range(2,len(reljudges[k])+2)]))
        ideals = {reljudges[k][i]: counts[i] for i in range(len(reljudges[k]))}
        
        add_ons = {}
        if len(v) > len(reljudges[k]):
            for i in range(len(v)-len(reljudges[k])):
                add_ons[i] = 1
        ideals.update(add_ons)
        nums = list(map(ideals.get, v))
        
        systems = {}
        for i, doc in enumerate(v):
            if nums[i] == None:
                systems[doc] = 1
            else:
                systems[doc] = nums[i]
                
        ideal_order = {}
        if n != -1:
            for i, (key, value) in enumerate(ideals.items()):
                if i < n:
                    ideal_order[key] = value
        else:
            ideal_order = ideals
        
        add_ons = {}
        
        
        log = 0
        for i, (doc, rank) in enumerate(ideal_order.items()):
            if i >= len(v):
                break
            elif i < base:
                log += rank
            else:
                log += rank/math.log(i+1, base)

                
        system_order = {}
        if n != -1:
            for i, (key, value) in enumerate(systems.items()):
                if i < n:
                    system_order[key] = value
        else:
            system_order = systems
        
        
        
        system_log = 0
        for i, (doc, rank) in enumerate(system_order.items()):
            if i >= len(v):
                break
            elif i < base:
                system_log += rank
            else:
                system_log += rank/math.log(i+1, base)
        try:
            ndcg[k] = system_log / log
        except:
            ndcg[k] = 0
        
    
    return ndcg

# %% [markdown]
# ## Stemming Test Results

# %%
# IMPORT INVERTED_INDEX
with open(r'assets/inverted_index_stem.json') as f:
    inverted_index_stem = json.load(f)

# %% [markdown]
# #### Precision/Recall

# %%
pre_at_n, rec_at_n = calc_pre_rec_at_n(create_testing_dicts(normalization='stem')[0], create_testing_dicts(normalization='stem')[1])

# %%
pre_at_n

# %%
rec_at_n

# %%
avg_pre, mean_avg_pre = calc_avg_pre(create_testing_dicts(normalization='stem')[0], create_testing_dicts(normalization='stem')[1])

# %%
avg_pre

# %%
mean_avg_pre

# %%
calc_NDCG_at_n(create_testing_dicts(normalization='stem')[0], create_testing_dicts(normalization='stem')[1], n=-1, base=2)
# Out:
# {'home improv store': 0.062387011628009956,
#  'diesel fuel supplier': 0.08387095630361062,
#  'church': 0.09034884889711046,
#  'farm': 0.5178737847929384,
#  'seed supplier': 0.1254333888595897,
#  'account': 0.021394318627208773,
#  'truck compani': 0.4425032659424683,
#  'export': 0.025812192854352625,
#  'grain elev': 0.20341748548710972,
#  'popcorn store': 0.16539480028020273,
#  'agricultur servic': 0.6202800711515095,
#  'warehous': 0.20341748548710972,
#  'agricultur product': 0.3756497272114066,
#  'ranch': 0.3512314498260458,
#  'hold compani': 0.9293020998846204,
#  'farm equip supplier': 0.017505799826600107,
#  'store': 0.2493704428958166,
#  'groceri store': 0.0239570415260799,
#  'rice mill': 0.6434691377083236,
#  'food product supplier': 0.014547278280154294,
#  'account firm': 0.021394318627208773,
#  'produc market': 0.0239570415260799,
#  'pet suppli store': 0.27225613333912835,
#  'wholesal': 0.46171023274441414,
#  'produc wholesal': 0.014547278280154294,
#  'distribut servic': 0.021394318627208773,
#  'crop grower': 0.6663981205506385,
#  'addict treatment center': 0.5862810837208018,
#  'natur good store': 0.0239570415260799,
#  'orchard': 0.5544201778342831,
#  'lumber store': 0.11373509708218703,
#  'mine': 0.6201104867650151,
#  'transport servic': 0.3251850899774444,
#  'invest compani': 0.6675134612228566,
#  'fruit wholesal': 0.16793030350493562,
#  'real estat agenc': 0.8989739059351857,
#  'event venu': 0.0239570415260799,
#  'frozen dessert supplier': 0.547417771643236,
#  'wine wholesal import': 0.33277260117725815,
#  'wineri': 0.9966828540224155,
#  'aerospac compani': 0.9318992578092412,
#  'cold storag facil': 0.29374792515294096,
#  'employ agenc': 0.3061427827935241,
#  'plant nurseri': 0.0239570415260799,
#  'air condit contractor': 0.24006192174891539,
#  'air condit repair servic': 0.24006192174891539,
#  'fruit veget wholesal': 0.0239570415260799,
#  'aircraft rental servic': 0.045995238117956,
#  'monasteri': 1.0,
#  'allergist': 1.0,
#  'herb shop': 0.0239570415260799,
#  'aluminum supplier': 0.7537312022418973,
#  'ambul servic': 0.6540576884737525,
#  'wholesal plant nurseri': 0.4962838333472859,
#  'amus machin supplier': 0.695488025727903,
#  'anim hospit': 0.021394318627208773,
#  'farmer market': 0.022222222222222223,
#  'vapor store': 0.048932003196367375,
#  'cigar shop': 0.3351482532243254,
#  'tobacco shop': 0.05065501728141138,
#  'well drill contractor': 0.5180265966271922,
#  'librari': 0.43823819028948136,
#  'apart build': 0.045995238117956,
#  'apart rental agenc': 0.045995238117956,
#  'dairi farm': 0.06132058872957222,
#  'architect': 0.6553730630624757,
#  'organ farm': 0.016196592664967396,
#  'architectur design': 0.22218011520630648,
#  'architectur firm': 0.22218011520630648,
#  'livestock produc': 0.022361445489034806,
#  'dairi supplier': 0.19011491052801935,
#  'biotechnolog compani': 0.9971452890289545,
#  'artist': 0.920241564164822,
#  'egg supplier': 0.4253288417386337,
#  'poultri farm': 0.2704765666824035,
#  'chicken hatcheri': 0.5839459964853606,
#  'art organ': 0.8173692367039833,
#  'associ organ': 0.3780812898357447,
#  'food store': 0.0239570415260799,
#  'deli': 0.0625,
#  'bank': 0.6899355701957616,
#  'fish process': 0.026624849773160538,
#  'fish farm': 0.17189149620713742,
#  'seafood wholesal': 0.25448741234807787,
#  'tropic fish store': 0.0451665444735485,
#  'non profit organ': 0.09463018976719483,
#  'econom develop agenc': 0.29991021711350524,
#  'seafood market': 0.0800512291427166,
#  'honey farm': 0.5492088102944677,
#  'hors breeder': 0.1141001873050885,
#  'asphalt contractor': 0.03479303924387127,
#  'livestock dealer': 0.2055765388650011,
#  'depart store': 0.3419603603845232,
#  'mill': 0.177866792687122,
#  'atv dealer': 0.5415366463273121,
#  'audio visual consult': 0.7028162721020352,
#  'pallet supplier': 0.5011520262415489,
#  'wood supplier': 0.014547278280154294,
#  'hardwar store': 0.0239570415260799,
#  'furnitur wholesal': 0.014547278280154294,
#  'auditor': 0.5067221467758423,
#  'oil natur compani': 0.505942420487099,
#  'auto bodi shop': 0.021394318627208773,
#  'boat repair shop': 0.4419634027400717,
#  'associ': 0.3780812898357447,
#  'rail contractor': 0.11661086130301077,
#  'publish': 0.657214097660171,
#  'pond suppli store': 0.06896551724137931,
#  'agricultur cooper': 0.03739522640344854,
#  'print equip supplier': 0.0681758186705343,
#  'auto insur agenc': 0.025812192854352625,
#  'altern fuel station': 0.08434699454339854,
#  'auto part manufactur': 0.025792809191106617,
#  'foundat': 0.1073183866635404,
#  'fertil supplier': 0.6621559363389965,
#  'farm compani': 0.5178737847929384,
#  'financ broker': 0.7034634075897617,
#  'fire station': 0.03739522640344854,
#  'environment consult': 0.26766798019117366,
#  'civil engin': 0.6989349648125436,
#  'fire protect servic': 0.03739522640344854,
#  'compani': 0.020946189181826974,
#  'oilfield': 0,
#  'banquet hall': 0.3913177061114813,
#  'mine compani': 0.6201104867650151,
#  'coalfield': 0,
#  'steel fabric': 0.7789430695539075,
#  'quarri': 0.6398386856578465,
#  'gold mine compani': 0.6438894609589608,
#  'high rise build': 0.03479303924387127,
#  'basketbal club': 0.30919904176883256,
#  'gold dealer': 0.014547278280154294,
#  'batteri manufactur': 0.9807100434910057,
#  'electr util compani': 0.03739522640344854,
#  'environment program': 0.08956035666137592,
#  'offic': 0.0239570415260799,
#  'stone supplier': 0.1197589944859298,
#  'aggreg supplier': 0.014056733846481465,
#  'sand gravel supplier': 0.39101152132583167,
#  'build materi supplier': 0.0239570415260799,
#  'beauti suppli store': 0.2517216694815243,
#  'crush stone supplier': 0.014547278280154294,
#  'rock shop': 0.014547278280154294,
#  'road construct compani': 0.5447839019311549,
#  'market consult': 0.021394318627208773,
#  'blood test servic': 0.021394318627208773,
#  'contractor': 0.633205427448652,
#  'excav contractor': 0.2564472191127583,
#  'asphalt mix plant': 0.7366619976190448,
#  'readi mix concret supplier': 0.1699510014489267,
#  'sand plant': 0.3917312071400989,
#  'bmw dealer': 0,
#  'bookbind': 0.7977122367924687,
#  'garden center': 0.15313498187859803,
#  'abras supplier': 0.9763445137893869,
#  'granit supplier': 0.1280730279049056,
#  'drill contractor': 0.5075990059743072,
#  'bpo compani': 0,
#  'oil explor servic': 0.505942420487099,
#  'build complex': 0.045995238117956,
#  'construct equip supplier': 0.014547278280154294,
#  'mine equip': 0.00532647621010794,
#  'ticket agenc': 0.6276450698297413,
#  'busi center': 0.0239570415260799,
#  'skyscrap': 0,
#  'softwar compani': 0.762707296834603,
#  'busi develop servic': 0.021394318627208773,
#  'busi manag consult': 0.021394318627208773,
#  'cabinet maker': 0.5984973626932727,
#  'call center': 0.5341682208648078,
#  'cancer treatment center': 0.4042806126143422,
#  'power plant consult': 0.24006192174891539,
#  'busi park': 0.021394318627208773,
#  'petroleum product compani': 0.1718098725503,
#  'park lot': 0.1811196709626546,
#  'water util compani': 0.1729545332169022,
#  'car repair mainten': 0.24122558867435906,
#  'water treatment plant': 0.1729545332169022,
#  'car servic': 0.26136144185173676,
#  'cattl market': 0.09058951894978126,
#  'sewag dispos servic': 0.5015555662194072,
#  'certifi public account': 0.39935861272779805,
#  'govern offic': 0.5708247814532948,
#  'chariti': 1.0,
#  'air condit system supplier': 0.11283044858105375,
#  'chemic industri': 0.8598472150233708,
#  'chemic manufactur': 0.8598472150233708,
#  'titl compani': 0.021394318627208773,
#  'chemic plant': 0.8598472150233708,
#  'properti manag compani': 0.2729183583511302,
#  'custom home builder': 0.03479303924387127,
#  'window instal servic': 0.07577824875869636,
#  'fire damag restor servic': 0.0239570415260799,
#  'equip rental agenc': 0.15103728472759256,
#  'chemic wholesal': 0.09058951894978126,
#  'financi planner': 0.6335503749166084,
#  'telecommun servic provid': 0.5081798519153662,
#  'energi equip solut': 0.0239570415260799,
#  'chiropractor': 0.9345654881488668,
#  'steel distributor': 0.014547278280154294,
#  'citi govern offic': 0.7698798193331705,
#  'crane servic': 0.3285017901501872,
#  'garag door supplier': 0.32179275872002,
#  'industri door supplier': 0.2729155935246062,
#  'citi town hall': 0.7935744299102608,
#  'cloth wholesal': 0.26671293815051894,
#  'coin oper laundri equip supplier': 0.4111527541056231,
#  'metal supplier': 0.07655705469832237,
#  'glass shop': 0.03479303924387127,
#  'colleg': 0.7041181202744449,
#  'side contractor': 0.16204092072564,
#  'commerci printer': 0.1334919020030731,
#  'storag facil': 0.6244187901606009,
#  'commun tower': 0.03479303924387127,
#  'janitori servic': 0.6864869380854477,
#  'comput consult': 0.021394318627208773,
#  'fire protect system supplier': 0.03739522640344854,
#  'elev servic': 0.2713234500172541,
#  'industri equip supplier': 0.014547278280154294,
#  'dri wall contractor': 0.03479303924387127,
#  'insul contractor': 0.27544172073501005,
#  'concret contractor': 0.3782937826945411,
#  'scaffold rental servic': 0.20306869734326108,
#  'construct compani': 0.6485154689477213,
#  'floor store': 0.0239570415260799,
#  'floor contractor': 0.1231975350407154,
#  'tile contractor': 0.35602931992448156,
#  'tile manufactur': 0.35602931992448156,
#  'glass mirror shop': 0.03479303924387127,
#  'construct materi wholesal': 0.014547278280154294,
#  'gutter clean servic': 0.24711846824028882,
#  'sheet metal contractor': 0.605993710376087,
#  'consult': 0.7887948323424976,
#  'contain servic': 0.3118014956273482,
#  'septic system servic': 0.8057205221348274,
#  'corpor campu': 0.48270920670499107,
#  'water damag restor servic': 0.0239570415260799,
#  'welder': 0.01485183529125322,
#  'corpor offic': 0.48270920670499107,
#  'anim': 0.7388469436129654,
#  'anim feed store': 0.05065501728141138,
#  'anim protect organ': 0.021394318627208773,
#  'brew suppli store': 0.013986013986013986,
#  'cosmet store': 0.2593377539480699,
#  'counti govern offic': 0.4995428326701289,
#  'sugar factori': 0.6754345205755689,
#  'confectioneri wholesal': 0.2650075394837718,
#  'financi institut': 0.03739522640344854,
#  'candi store': 0.0239570415260799,
#  'confectioneri': 0.0239570415260799,
#  'chocol factori': 0.7837445845868326,
#  'chocol shop': 0.7837445845868326,
#  'courier servic': 0.6823277116070922,
#  'cowork space': 0,
#  'frozen food manufactur': 0.570146342760253,
#  'beverag distributor': 0.014547278280154294,
#  'agricultur organ': 0.03739522640344854,
#  'dairi store': 0.19011491052801935,
#  'dairi': 0.06132058872957222,
#  'ice cream shop': 0.26702835108354545,
#  'medic laboratori': 0.3135490271939764,
#  'demolit contractor': 0.6415253790640321,
#  'meat processor': 0.6314624913433112,
#  'fmcg manufactur': 0,
#  'garbag collect servic': 0.29338794836693366,
#  'wholesal bakeri': 0.01413599769566148,
#  'dentist': 0.6124622004687721,
#  'dessert shop': 0.42374876811328527,
#  'cupcak shop': 0,
#  'nut store': 0.0239570415260799,
#  'wholesal grocer': 0.5290610876174225,
#  'design engin': 0.06121239024387546,
#  'busi busi servic': 0.0239570415260799,
#  'condiment supplier': 0.986827925971056,
#  'digit print servic': 0.38452119991704087,
#  'culinari school': 1.0,
#  'import': 0.025812192854352625,
#  'bottl water supplier': 0.22866405333755874,
#  'coffe roaster': 0.5984760153069322,
#  'packag suppli store': 0.10156400159656136,
#  'ice supplier': 0.41034367575629876,
#  'breweri': 0.9171495629741175,
#  'winemak compani': 0,
#  'distilleri': 0.01413599769566148,
#  'disabl servic support organis': 0.4890415640012455,
#  'district govern offic': 0.32638813404770023,
#  'air filter supplier': 0.32989242547024744,
#  'tire shop': 0.08434699454339854,
#  'fasten supplier': 0.8343515741547773,
#  'fabric product manufactur': 0.2898331751751221,
#  'textil': 0.5900375271946684,
#  'textil export': 0.5900375271946684,
#  'textil engin': 0.5900375271946684,
#  'fabric store': 0.05065501728141138,
#  'knit shop': 0.30444917577079544,
#  'doctor': 0.8688730297404473,
#  'lamin servic': 0.7187456321794632,
#  'plastic resin manufactur': 0.3262068044892306,
#  'carpet manufactur': 0.3437528081966204,
#  'upholsteri shop': 0.19212515488075507,
#  'busi administr servic': 0.021394318627208773,
#  'furnitur store': 0.0239570415260799,
#  'dri cleaner': 0.021394318627208773,
#  'packag compani': 0.10156400159656136,
#  'duti free store': 0.05065501728141138,
#  'commerc servic': 0.043478260869565216,
#  'cabl compani': 0.19065964802055702,
#  'educ': 0.6590399694227262,
#  'outlet store': 0.05065501728141138,
#  'lingeri store': 0.3436953025046801,
#  'cloth fabric manufactur': 0.03364972845868323,
#  'educ center': 0.6590399694227262,
#  'uniform store': 0.09082740205179946,
#  'men cloth store': 0.08322849744660404,
#  'cloth store': 0.18353403823518336,
#  'women cloth store': 0.0774844998823396,
#  'western apparel store': 0.5168539325842697,
#  'costum store': 0.2877103903945859,
#  'game store': 0.05065501728141138,
#  'hat shop': 0.24798952434135307,
#  'leather good manufactur': 0.0239570415260799,
#  'educ consult': 0.6590399694227262,
#  'leather export': 0.5966079570841738,
#  'shoe store': 0.10156400159656136,
#  'boutiqu': 0,
#  'leather wholesal': 0.0239570415260799,
#  'handbag shop': 0.39978208115139363,
#  'electron store': 0.0239570415260799,
#  'luggag store': 0.2001057478380843,
#  'build materi store': 0.0239570415260799,
#  'saw mill': 0.6608086270140744,
#  'electr engin': 0.021394318627208773,
#  'deck builder': 0.23174018682803124,
#  'concret product supplier': 0.5576616541702233,
#  'plywood supplier': 0.812722895420229,
#  'electr instal servic': 0.09658513005431495,
#  'truss manufactur': 0.698974909259179,
#  'door supplier': 0.12002040732905359,
#  'wood lamin floor supplier': 0.8923903163695349,
#  'aircraft suppli store': 0.014547278280154294,
#  'modular home builder': 0.010440585775759762,
#  'portabl build manufactur': 0.44847358422068495,
#  'modular home dealer': 0.04812304135526803,
#  'mulch supplier': 0.3934009948421892,
#  'electrician': 0.41049426127481037,
#  'paper mill': 0.904911851252025,
#  'energi supplier': 0.3773609820760421,
#  'engin': 0.09246103913091494,
#  'print shop': 0.634977279900254,
#  'custom label printer': 0.08243784457695263,
#  'market': 0.021394318627208773,
#  'market agenc': 0.021394318627208773,
#  'engin consult': 0.09246103913091494,
#  'entertain': 0.46092699359018413,
#  'envelop supplier': 0.3301549706384365,
#  'oil refineri': 0.01055504984782632,
#  'record studio': 0.3907230514478411,
#  'environ renew natur resourc': 0.08516885643976688,
#  'finish materi supplier': 0.0239570415260799,
#  'event ticket seller': 0.0239570415260799,
#  'waterproof compani': 0.24006192174891539,
#  'auto part store': 0.177813521187302,
#  'heat oil supplier': 0.05065501728141138,
#  'famili practic physician': 0.07164615265449159,
#  'machin manufactur': 0.799120133325771,
#  'industri supplier': 0.3454796491965177,
#  'weld suppli store': 0.7277441051908099,
#  'dri ice supplier': 0.45118470184265186,
#  'privat equiti firm': 0.025812192854352625,
#  'famili servic center': 0.28642139291208907,
#  'feder govern offic': 0.3534826560330413,
#  'vitamin supplement store': 0.307269897371324,
#  'feed manufactur': 0.21052555133810855,
#  'medic equip supplier': 0.09058951894978126,
#  'medic suppli store': 0.09058951894978126,
#  'medic clinic': 0.22894715336424243,
#  'research institut': 0.5806625393727737,
#  'biochem supplier': 0,
#  'fiber optic product supplier': 0.00532647621010794,
#  'paint manufactur': 0.3440102034909122,
#  'equip supplier': 0.31675465563520455,
#  'food': 0.776159044578813,
#  'pipe supplier': 0.5675432071882394,
#  'oil field equip supplier': 0.00532647621010794,
#  'food broker': 0.014547278280154294,
#  'food manufactur': 0.5994924450756731,
#  'food process compani': 0.776159044578813,
#  'fenc suppli store': 0.12426258231465923,
#  'food produc': 0.776159044578813,
#  'forestri servic': 0.7993293019583756,
#  'foundri': 0.8047482327409224,
#  'wholesal jewel': 0.4519331049572754,
#  'cooki shop': 0.6855216377802857,
#  'truck rental agenc': 0.045995238117956,
#  'fruit veget process': 0.2756952051356151,
#  'kitchen suppli store': 0.014547278280154294,
#  'hydraul equip supplier': 0.014547278280154294,
#  'irrig equip supplier': 0.3327278940159191,
#  'bear supplier': 0.7498479217487455,
#  'metallurgi compani': 0.9969333463154176,
#  'plastic inject mold servic': 0.014111868166941733,
#  'gener contractor': 0.32834961314893435,
#  'gener hospit': 0.027217267573504244,
#  'tool manufactur': 0.675775127281301,
#  'industri design compani': 0.021394318627208773,
#  'hyundai dealer': 0,
#  'glass industri': 0.9677904018975994,
#  'polym supplier': 0.013888888888888888,
#  'print equip suppli': 0.0681758186705343,
#  'toner cartridg supplier': 0.7302557922037227,
#  'printer repair servic': 0.09857513171247102,
#  'fuel supplier': 0.014547278280154294,
#  'glass manufactur': 0.9677904018975994,
#  'plastic bag supplier': 0.694478597090638,
#  'glasswar manufactur': 0.38850260968350536,
#  'polythen plastic sheet supplier': 0,
#  'pvc industri': 0.7128205128205128,
#  'countertop store': 0.1353415378237015,
#  'cabinet store': 0.08724279165767003,
#  'fiberglass supplier': 0.2006890464852133,
#  'golf cart dealer': 0.0239570415260799,
#  'auto repair shop': 0.021394318627208773,
#  'hose supplier': 0.5290777723894221,
#  'rubber product supplier': 0.628675717301508,
#  'automot': 0.014547278280154294,
#  'commerci refriger supplier': 0.0892978585090074,
#  'golf club': 0.2113444762888627,
#  'golf cours': 0.2113444762888627,
#  'green energi supplier': 0.07429372775974477,
#  'greenhous': 0.6543401164759842,
#  'auto glass shop': 0.021394318627208773,
#  'light manufactur': 0.9139188824381588,
#  'cement manufactur': 0.5586045177194144,
#  'brick manufactur': 0.692634403074841,
#  'natur stone supplier': 0.014547278280154294,
#  'gym': 1.0,
#  'marbl supplier': 0.13099567421789765,
#  'corpor gift supplier': 0.05065501728141138,
#  'shipbuild repair compani': 0,
#  'construct mainten offic': 0.6485154689477213,
#  'boiler manufactur': 0.8066925622408357,
#  'contain supplier': 0.3118014956273482,
#  'home construct': 0.09537041211788873,
#  'health': 0.764688790073319,
#  'heart hospit': 0.02531645569620253,
#  'spring supplier': 0.8568239870256023,
#  'electr util manufactur': 0.03739522640344854,
#  'aircraft manufactur': 0.6231825632546019,
#  'metal heat treat servic': 0.8364949492896679,
#  'plate servic': 0.6651382145164805,
#  'autom compani': 0.03947942829573169,
#  'heat contractor': 0.3040704980139291,
#  'plumb suppli store': 0.11283044858105375,
#  'gun shop': 0.2627420939154603,
#  'ammunit supplier': 0.6966837629843294,
#  'pipe manufactur': 0.5675432071882394,
#  'school': 0.6673535127776675,
#  'fire protect equip supplier': 0.03739522640344854,
#  'agricultur machineri manufactur': 0.1291658289872038,
#  'lawn mower store': 0.0239570415260799,
#  'lawn irrig equip supplier': 0.08516885643976688,
#  'financi consult': 0.6335503749166084,
#  'helicopt charter': 0.35058528164797814,
#  'packag machineri': 0.00532647621010794,
#  'histor landmark': 0.42557968744659824,
#  'electron manufactur': 0.4907642200879454,
#  'graphic design': 0.20970234968889742,
#  'eye care center': 0.30590733686899285,
#  'optic product manufactur': 0.5979859418406737,
#  'imag consult': 0.021394318627208773,
#  'clean product supplier': 0.014547278280154294,
#  'fireplac store': 0.2071030977458488,
#  'home builder': 0.09537041211788873,
#  'tool die shop': 0.6745320338007601,
#  'metal stamp servic': 0.8360173938278104,
#  'environment organ': 0.08956035666137592,
#  'food process equip': 0.06480675643613534,
#  'loan agenc': 0.789547955134028,
#  'power plant equip supplier': 0.014547278280154294,
#  'home good store': 0.08434699454339854,
#  'engin rebuild servic': 0.021394318627208773,
#  'air compressor supplier': 0.285254082075086,
#  'honda dealer': 0,
#  'elev manufactur': 0.2713234500172541,
#  'crane dealer': 0.3285017901501872,
#  'crane rental agenc': 0.21814748117263819,
#  'compound build': 0.03479303924387127,
#  'tractor dealer': 0.014547278280154294,
#  'furnac part supplier': 0.014547278280154294,
#  'heat equip supplier': 0.08456562154603849,
#  'pneumat tool supplier': 0.014547278280154294,
#  'truck stop': 0.0239570415260799,
#  'comput hardwar manufactur': 0.9377941275355056,
#  'satellit commun servic': 0.7589117286254478,
#  'hospit': 0.30167442985891973,
#  'electron compani': 0.0239570415260799,
#  'electron part supplier': 0.4199710782775281,
#  'hvac contractor': 0.5238095238095238,
#  'industri engin': 0.021394318627208773,
#  'contact lens supplier': 0.00532647621010794,
#  'inform servic': 0.7369333338876747,
#  'build': 0.5727629672985575,
#  'water work equip supplier': 0.014547278280154294,
#  'measur instrument supplier': 0.9366935477955844,
#  'scientif equip supplier': 0.014547278280154294,
#  'medic center': 0.20647101817190763,
#  'watch manufactur': 0.192717582457563,
#  'corpor entertain servic': 0.0439727031651832,
#  'insur': 0.8423704529684763,
#  'record compani': 0.3973446283028425,
#  'video duplic servic': 0.5341443963452341,
#  'insur agenc': 0.8423704529684763,
#  'light store': 0.9139188824381588,
#  'light wholesal': 0.9139188824381588,
#  'entertain agenc': 0.7311479550021914,
#  'insur broker': 0.8423704529684763,
#  'electr equip supplier': 0.07655705469832237,
#  'electr motor store': 0.1824619787405354,
#  'railroad compani': 0.3773435656254629,
#  'electr suppli store': 0.07655705469832237,
#  'insur compani': 0.8423704529684763,
#  'factori equip supplier': 0.014547278280154294,
#  'invest servic': 0.7180436123615461,
#  'laser equip supplier': 0.3508372858202275,
#  'execut suit rental agenc': 0.381440932567727,
#  'truck dealer': 0.06060102967161852,
#  'motor vehicl dealer': 0.0239570415260799,
#  'car dealer': 0.0239570415260799,
#  'truck topper supplier': 0.08737646652712097,
#  'polic suppli store': 0.11449958904094557,
#  'iron steel contractor': 0.03479303924387127,
#  'fire depart equip supplier': 0.03739522640344854,
#  'tow equip provid': 0.2742889735223676,
#  'logist servic': 0.6305353742923101,
#  'trailer manufactur': 0.5442476684905098,
#  'trailer dealer': 0.12082870201973281,
#  'dealer': 0.537951797396162,
#  'auto spring shop': 0.021394318627208773,
#  'auto upholster': 0.025792809191106617,
#  'auto bodi part supplier': 0.177813521187302,
#  'car factori': 0.17145001418807504,
#  'freight forward servic': 0.466941702391982,
#  'brake shop': 0.09857513171247102,
#  'railroad equip supplier': 0.09920379328361931,
#  'jewelri equip supplier': 0.8692673069552886,
#  'boat builder': 0.4419634027400717,
#  'ship build': 0.5893939195157388,
#  'marin suppli store': 0.0239570415260799,
#  'boat dealer': 0.20838140105813197,
#  'kawasaki motorcycl dealer': 0,
#  'knife manufactur': 0.4074768301908944,
#  'labor union': 0.3196157363133781,
#  'furnitur maker': 0.9974039129284556,
#  'bank financ': 0.6899355701957616,
#  'furnitur manufactur': 0.9956725449943076,
#  'logist': 0.6305353742923101,
#  'massag suppli store': 0.1247028080381595,
#  'telecommun equip supplier': 0.00532647621010794,
#  'babi store': 0.08778784020972129,
#  'mold supplier': 0.1071575543376307,
#  'offic equip supplier': 0.3802999964499482,
#  'offic furnitur store': 0.00532647621010794,
#  'store equip supplier': 0.014547278280154294,
#  'laboratori': 0.1283855226638514,
#  'health beauti shop': 0.021394318627208773,
#  'learn center': 0.7124900842352783,
#  'dental laboratori': 0.3537565939440528,
#  'land surveyor': 0.09542489444368481,
#  'educ suppli store': 0.05065501728141138,
#  'jewelri store': 0.0239570415260799,
#  'playground equip supplier': 0.2971160902237764,
#  'outdoor sport store': 0.12135070949276103,
#  'toy store': 0.05065501728141138,
#  'secur servic': 0.0239570415260799,
#  'sign shop': 0.7446720891195652,
#  'offic suppli store': 0.05065501728141138,
#  'landscap': 0.6495755642432828,
#  'gasket manufactur': 0.6805981594263228,
#  'piano maker': 0.2716465998288585,
#  'piano store': 0.33443426075191063,
#  'funer home': 0.6553730630624757,
#  'monument': 0.04032504428081571,
#  'book publish': 0.44048552483849523,
#  'wig shop': 0.3436953025046801,
#  'laundromat': 1.0,
#  'auto wrecker': 0.020946189181826974,
#  'auto part market': 0.177813521187302,
#  'jeep dealer': 0,
#  'restaur suppli store': 0.15048483342201338,
#  'roof suppli store': 0.39008293203152444,
#  'law firm': 0.22090382622778035,
#  'build materi market': 0.0239570415260799,
#  'camera store': 0.36110596659875216,
#  'lawn care servic': 0.11035553165111127,
#  'comput secur servic': 0.0239570415260799,
#  'comput store': 0.014547278280154294,
#  'design agenc': 0.08047919909064966,
#  'diagnost center': 0.547286924318816,
#  'laboratori equip supplier': 0.5053518984515419,
#  'home theater store': 0.054223036059456754,
#  'metal industri supplier': 0.07655705469832237,
#  'landscap suppli store': 0.02356460740711419,
#  'applianc part supplier': 0.24506960537453762,
#  'vacuum cleaner store': 0.08434699454339854,
#  'audio visual equip supplier': 0.7028162721020352,
#  'lawyer': 0.8306404473071374,
#  'cell phone store': 0.033579508618031884,
#  'bathroom suppli store': 0.1287739105207725,
#  'leas servic': 0.8663889018848393,
#  'construct machin dealer': 0.014547278280154294,
#  'dairi farm equip supplier': 0.0681371751233718,
#  'propan supplier': 0.046598134694753365,
#  'legal servic': 0.48691172427504076,
#  'janitori equip supplier': 0.6864869380854477,
#  'life insur agenc': 0.09055601888714586,
#  'railroad contractor': 0.41167479074802943,
#  'swim pool suppli store': 0.14199594945801153,
#  'light bulb supplier': 0.9149325815101012,
#  'linen store': 0.4166668600292181,
#  'metal construct compani': 0.8381015985429763,
#  'local govern offic': 0.03739522640344854,
#  'log contractor': 0.016196592664967396,
#  'machin shop': 0.682312932298291,
#  'hotel suppli store': 0.3718731563884756,
#  'import export compani': 0.025812192854352625,
#  'sew compani': 0.05065501728141138,
#  'research foundat': 0.5806625393727737,
#  'machineri part manufactur': 0.9093869774247815,
#  'sport accessori wholesal': 0.07371964293919847,
#  'fashion design': 0.0843325608600045,
#  'chees manufactur': 0.5037930911871518,
#  'chees shop': 0.5037930911871518,
#  'ship mail': 0.20341748548710972,
#  'wholesal food store': 0.5290610876174225,
#  'organ food store': 0.0239570415260799,
#  'pie shop': 0.6772620578379892,
#  'auction hous': 0.2627420939154603,
#  'livestock auction hous': 0.2055765388650011,
#  'cotton export': 0.22758207412885925,
#  'plastic wholesal': 0.014547278280154294,
#  'mail servic': 0.28499400106990175,
#  'manufactur': 0.22387035569654343,
#  'station': 0.0239570415260799,
#  'beer distributor': 0.41875411951765634,
#  'alcohol beverag wholesal': 0.5007072895117318,
#  'religi good store': 0.7027404797102157,
#  'book wholesal': 0.10590909855986365,
#  'masonri suppli store': 0.0239570415260799,
#  'wholesal florist': 0.4962838333472859,
#  'florist': 0.6704090454881116,
#  'marin engin': 0.02275152616190654,
#  'paint store': 0.0239570415260799,
#  'use auto part store': 0.0239570415260799,
#  'masonri contractor': 0.6200094392289581,
#  'use car dealer': 0.0239570415260799,
#  'use truck dealer': 0.0239570415260799,
#  'massag therapist': 0.15578349429569122,
#  'materi handl equip supplier': 0.07655705469832237,
#  'marina': 0.9597928220731767,
#  'meat packer': 0.3084806127178629,
#  'mattress store': 0.0239570415260799,
#  'blind shop': 0.8044745546190173,
#  'interior design': 0.12114907242749458,
#  'window treatment store': 0.0239570415260799,
#  'applianc store': 0.0239570415260799,
#  'health food store': 0.0239570415260799,
#  'direct mail advertis': 0.021394318627208773,
#  'meat wholesal': 0.3084806127178629,
#  'butcher shop deli': 0.40154084236526516,
#  'italian groceri store': 0.022222222222222223,
#  'food servic': 0.14281298093830908,
#  'groceri deliveri servic': 0.20341748548710972,
#  'wine store': 0.08724279165767003,
#  'liquor store': 0.1353415378237015,
#  'kiosk': 0,
#  'optometrist': 0.44812203297658654,
#  'optician': 0.11360475324281138,
#  'mechan contractor': 0.16430328469866723,
#  'mechan engin': 0.021394318627208773,
#  'cafe': 0.2361298364737614,
#  'jewel': 0.2971160902237764,
#  'leather good store': 0.0239570415260799,
#  'gift shop': 0.6815625660511855,
#  'craft store': 0.21594736537058573,
#  'hobbi store': 0.07475582144437148,
#  'fabric wholesal': 0.014547278280154294,
#  'scrap metal dealer': 0.014547278280154294,
#  'quilt shop': 0.044444444444444446,
#  'sheet music store': 0.05065501728141138,
#  'music instrument manufactur': 0.13038644429612936,
#  'music store': 0.05065501728141138,
#  'music instrument store': 0.05065501728141138,
#  'band': 0.13407657712461712,
#  'bookstor': 0,
#  'art museum': 0.66114270979097,
#  'newsstand': 1.0,
#  'medic equip manufactur': 0.6123882249197924,
#  'fashion accessori store': 0.14768575031113965,
#  'discount store': 0.046598134694753365,
#  'cemeteri': 0.30453592489685327,
#  'stop': 0.02008093223818946,
#  'varieti store': 0.05065501728141138,
#  'thrift store': 0.5333333333333333,
#  'medic group': 0.22894715336424243,
#  'donat center': 0.020635538910365018,
#  'pet store': 0.27225613333912835,
#  'art galleri': 0.05065501728141138,
#  'art dealer': 0.05065501728141138,
#  'hous develop': 0.03739522640344854,
#  'mobil home dealer': 0.12538850724408424,
#  'conveni store': 0.3465915522638911,
#  'medic offic': 0.22894715336424243,
#  'medic technolog manufactur': 0.6123882249197924,
#  'children furnitur store': 0.029447037254927047,
#  'mental health clinic': 0.6903714258105265,
#  'airlin': 0.02008093223818946,
#  'aviat consult': 0.13520166626708474,
#  'travel agenc': 0.5289873198700825,
#  'travel servic': 0.5289873198700825,
#  'airport': 0.2202630705193748,
#  'mental health servic': 0.6903714258105265,
#  'ship compani': 0.020946189181826974,
#  'metal fabric': 0.8381015985429763,
#  'cruis line compani': 0.0440780777042263,
#  'tow servic': 0.2742889735223676,
#  'ferri termin': 0.6961010702876438,
#  'ferri servic': 0.3919069880096045,
#  'metal finish': 0.8361897954624365,
#  'boat tour agenc': 0.13791586052400095,
#  'move compani': 0.5269417001675027,
#  'move storag servic': 0.5269417001675027,
#  'state depart transport': 0.14833932134036837,
#  'depart transport': 0.47624780445003334,
#  'handicap transport servic': 0.7704241361079802,
#  'railway servic': 0.23027532827928807,
#  'train station': 0.020946189181826974,
#  'depot': 0.0196078431372549,
#  'charter': 0.7387375806282661,
#  'metal process compani': 0.8381015985429763,
#  'mix use': 0.045995238117956,
#  'motorcycl shop': 0.30041128862666366,
#  'limousin servic': 0.9838302736884682,
#  'chauffeur servic': 0.02021832292102586,
#  'school servic': 0.020946189181826974,
#  'airport shuttl servic': 0.06878224070283845,
#  'tourist inform center': 0.12316314564754814,
#  'carriag ride servic': 0.38566343573292194,
#  'cruis agenc': 0.21089009481388682,
#  'tourist attract': 0.12316314564754814,
#  'ski resort': 0.4998506017777639,
#  'ski area': 0.4998506017777639,
#  'fix base oper': 0.020946189181826974,
#  'aircraft mainten compani': 0.17056869963022028,
#  'motorsport store': 0,
#  'boat rental servic': 0.045995238117956,
#  'util trailer dealer': 0.045995238117956,
#  'forklift dealer': 0.17427611635676576,
#  'municip administr offic': 0.03431675863729318,
#  'nephrologist': 1.0,
#  'coach compani': 0.2351714168689986,
#  'ship servic': 0.20341748548710972,
#  'ship mail servic': 0.20341748548710972,
#  'newspap publish': 0.6357766952501898,
#  'shred servic': 0.1832635712692065,
#  'nuclear power compani': 0.34086498661988857,
#  'nurs home': 0.8273418274167651,
#  'media compani': 0.4814002750796847,
#  'multimedia electron book publish': 0.734912660915478,
#  'internet market servic': 0.021394318627208773,
#  'greet card shop': 0.14199594945801153,
#  'theme park': 1.0,
#  'film product compani': 0.22041199951288692,
#  'obstetrician gynecologist': 1.0,
#  'movi studio': 0.5628662851036518,
#  'video product servic': 0.49756866636670777,
#  'movi theater': 0.5577431339142986,
#  'theater compani': 0.3285047174754383,
#  'perform art theater': 0.3996377210530021,
#  'occup safeti health': 0.021394318627208773,
#  'offic space rental agenc': 0.045995238117956,
#  'commerci real estat agenc': 0.045995238117956,
#  'art school': 0.06783624914519003,
#  'music publish': 0.03479303924387127,
#  'print music publish': 0.21411586490826578,
#  'home audio store': 0.054223036059456754,
#  'musician': 1.0,
#  'music manag promot': 0.7776303393741486,
#  'video edit servic': 0.5341443963452341,
#  'offic suppli wholesal': 0.4406537667147636,
#  'offici resid': 0.04081632653061224,
#  'orthoped clinic': 0.20811475199172694,
#  'painter': 0.03211274780601464,
#  'paint': 0.2855567668006668,
#  'telephon compani': 0.18876873794679966,
#  'media hous': 0.4814002750796847,
#  'paper distributor': 0.09058951894978126,
#  'news servic': 0.11449958904094557,
#  'public librari': 0.03479303924387127,
#  'law librari': 0.5728329066552857,
#  'museum': 0.7637857581251511,
#  'feder reserv bank': 0.17809667553722025,
#  'credit union': 0.8767894033305724,
#  'atm': 0.3454822335156774,
#  'pave contractor': 0.32717728625789955,
#  'mortgag lender': 0.48098606215933387,
#  'invest bank': 0.6675134612228566,
#  'check cash servic': 0.7043931085954033,
#  'stock broker': 0.025812192854352625,
#  'health consult': 0.021394318627208773,
#  'health insur agenc': 0.025812192854352625,
#  'payrol servic': 0.7802671942556128,
#  'pediatrician': 1.0,
#  'human resourc consult': 0.4554418157063502,
#  'pest control servic': 0.5818417637707372,
#  'pet board servic': 0.3894259502881483,
#  'pet care': 0.3894259502881483,
#  'loss adjust': 0.8774581677086933,
#  'pharmaceut compani': 0.8049163650744168,
#  'pharmaceut product wholesal': 0.09058951894978126,
#  'pharmaci': 0.18623885441105165,
#  'educ institut': 0.6387784394993854,
#  'retir commun': 0.48262692572851956,
#  'fratern organ': 0.39935861272779805,
#  'photo lab': 0.02049243952774123,
#  'properti invest': 0.270283291114844,
#  'photograph': 0.0779102912444131,
#  'photographi school': 0.4163417112242586,
#  'star hotel': 0,
#  'convent center': 0.2280889072684797,
#  'real estat apprais': 0.8232487657608085,
#  'photographi servic': 0.4163417112242586,
#  'resort hotel': 0.21984386861842378,
#  'real estat consult': 0.8989739059351857,
#  'car rental agenc': 0.18787340576973796,
#  'car leas servic': 0.18712215545530753,
#  'ford dealer': 0,
#  'car financ loan compani': 0.025812192854352625,
#  'trailer rental servic': 0.12082870201973281,
#  'furnitur rental servic': 0.045995238117956,
#  'tuxedo shop': 0.2798434332077892,
#  'dress tuxedo rental servic': 0.045995238117956,
#  'wed store': 0.02319051255098624,
#  'video store': 0.0239570415260799,
#  'movi rental': 0.5747855599712666,
#  'photographi studio': 0.4163417112242586,
#  'home health care servic': 0.044483290982946413,
#  'skateboard shop': 1.0,
#  'event technolog servic': 0.0239570415260799,
#  'parti equip rental servic': 0.21876363574192503,
#  'construct machin rental servic': 0.045995238117956,
#  'audio visual equip rental servic': 0.7028162721020352,
#  'ship equip industri': 0.044078371703898736,
#  'physic therapi clinic': 0.12822350451874096,
#  'plastic fabric compani': 0.7234379885474875,
#  'plastic product supplier': 0.7234379885474875,
#  'auto tag agenc': 0.03739522640344854,
#  'depart motor vehicl': 0.47624780445003334,
#  'notari public': 0.8790210933217081,
#  'privat investig': 0.0239570415260799,
#  'escrow servic': 0.6362703965756433,
#  'real estat agent': 0.8989739059351857,
#  'playground': 0.04088292987557831,
#  'plumber': 0.1340338566239383,
#  'port author': 0.7229618105935918,
#  'portrait studio': 0.2825576145374578,
#  'post offic': 0.2999465409578997,
#  'profession servic': 0.6424366876600714,
#  'univers hospit': 0.027217267573504244,
#  'public relat firm': 0.021394318627208773,
#  'civil engin compani': 0.6989349648125436,
#  'draft servic': 0.4661225856249517,
#  'pump supplier': 0.6583996411502349,
#  'interior construct contractor': 0.05292384186090035,
#  'carpet clean servic': 0.2573693955855347,
#  'exhibit planner': 0.0239570415260799,
#  'decal supplier': 0,
#  'stage light equip supplier': 0.00532647621010794,
#  'event manag compani': 0.0239570415260799,
#  'radio broadcast': 0.1276746420060354,
#  'comput support servic': 0.021394318627208773,
#  'ravin': 0,
#  'employ center': 0.3061427827935241,
#  'nation health foundat': 0.021394318627208773,
#  'real estat develop': 0.03479303924387127,
#  'advertis agenc': 0.1003041770279215,
#  'promot product supplier': 0.021394318627208773,
#  'advertis servic': 0.1003041770279215,
#  'record storag facil': 0.045995238117956,
#  'fund manag compani': 0.4494656368289822,
#  'recreat center': 0.7259501101973832,
#  'bakeri': 0.681397307980153,
#  'databas manag compani': 0.31247110082896545,
#  'market research': 0.021394318627208773,
#  'recycl center': 0.5999099125556863,
#  'region govern offic': 0.0795315520947573,
#  'rehabilit center': 0.19953820153972418,
#  'religi institut': 0.7027404797102157,
#  'religi organ': 0.7027404797102157,
#  'repair servic': 0.5247512679521412,
#  'emerg veterinarian servic': 0.021394318627208773,
#  'pet sitter': 0.3894259502881483,
#  'research product develop': 0.5806625393727737,
#  'build societi': 0.5727629672985575,
#  'valet park servic': 0.7474278351594896,
#  'nurs agenc': 0.8273418274167651,
#  'execut search firm': 0.3203143211287006,
#  'recruit': 1.0,
#  'temp agenc': 0,
#  'health center': 0.6931189359283341,
#  'restaur': 0.4188241274534948,
#  'roof contractor': 0.3184987591783573,
#  'sport nutrit store': 0.0239570415260799,
#  'credit report agenc': 0.0239570415260799,
#  'automobil storag facil': 0.20341748548710972,
#  'debt collect agenc': 0.25165583836553357,
#  'park': 0.1811196709626546,
#  'court report': 0.4382559463739368,
#  'tour agenc': 0.5288122412222338,
#  'tour oper': 0.5288122412222338,
#  'convent inform bureau': 0.2280889072684797,
#  'balloon ride tour agenc': 0.4990456588369781,
#  'secur guard servic': 0.0239570415260799,
#  'locksmith': 0.7718156001912975,
#  'commerci clean servic': 0.0239570415260799,
#  'blast clean servic': 0.0239570415260799,
#  'confer center': 0.41804785976943154,
#  'safeti equip supplier': 0.014547278280154294,
#  'garbag dump': 0.2879605720271646,
#  'sanit servic': 0.16461138973253694,
#  'garbag dump servic': 0.29338794836693366,
#  'environment health servic': 0.26766798019117366,
#  'portabl toilet supplier': 0.0239570415260799,
#  'public work depart': 0.532741136579011,
#  'school district offic': 0.6673535127776675,
#  'sailmak': 0,
#  'commun colleg': 0.06783624914519003,
#  'salvag yard': 0.1194384352612484,
#  'busi school': 0.06783624914519003,
#  'trade school': 0.06783624914519003,
#  'privat univers': 0.06783624914519003,
#  'comput train school': 0.06783624914519003,
#  'school suppli store': 0.014547278280154294,
#  'screen printer': 0.32633343664003844,
#  'media consult': 0.4814002750796847,
#  'beauti school': 0.06783624914519003,
#  'flight school': 0.456753520586574,
#  'seaport': 0.020946189181826974,
#  'secur system supplier': 0.0239570415260799,
#  'middl school': 1.0,
#  'nonprofit': 0,
#  'shoot rang': 0.27266224123746,
#  'soccer club': 0.427288641133993,
#  'camp': 0.5776520199581306,
#  'dive contractor': 0.3436953025046801,
#  'languag school': 0.7268163610089875,
#  'english languag school': 0.05714285714285714,
#  'preschool': 0.5189873417721519,
#  'self storag facil': 0.6632873639187739,
#  'semi conductor supplier': 0.15399568936041008,
#  'drive school': 0.17705793192013347,
#  'truck school': 0.06783624914519003,
#  'senior citizen center': 0.1954302651035053,
#  'servic': 0.1127256908397368,
#  'children hospit': 0.07035915560227082,
#  'dental suppli store': 0.3567976911598799,
#  'shipyard': 0.38951842447626256,
#  'orthodox synagogu': 0,
#  'short term apart rental agenc': 0.16580528224833752,
#  'nutritionist': 1.0,
#  'ophthalmologist': 0.2277400953864549,
#  'ophthalmolog clinic': 0.8481012658227848,
#  'social servic organ': 0.7361038910984106,
#  'social welfar center': 0.7361038910984106,
#  'solar energi compani': 0.5392291858397629,
#  'solar energi equip supplier': 0.5392291858397629,
#  'special educ school': 0.09892695937856197,
#  'podiatrist': 1.0,
#  'reproduct health clinic': 0.027217267573504244,
#  'sport good store': 0.05065501728141138,
#  'dialysi center': 0.8826564732573894,
#  'sport complex': 0.4725439772220916,
#  'well program': 0.025812192854352625,
#  'sportswear store': 0.043478260869565216,
#  'privat hospit': 0.20733166572037331,
#  'radiologist': 0.95,
#  'medic diagnost imag center': 0.31287083633692925,
#  'ray lab': 0.4729920758043497,
#  'blood bank': 0.3527477312236175,
#  'stainless steel plant': 0.6737560530868589,
#  'state agenc': 0.10750207954964741,
#  'heliport': 0,
#  'health care compani': 0.6931189359283341,
#  'psychiatr hospit': 0.7772048992246441,
#  'state govern offic': 0.10750207954964741,
#  'medic institut': 0.20647101817190763,
#  'steel construct compani': 0.1231975350407154,
#  'clean servic': 0.38233973447642877,
#  'steel drum supplier': 0.7762097232361422,
#  'assist live facil': 0.5005394279771398,
#  'steel erector': 0.1231975350407154,
#  ...}

# %% [markdown]
# ## Lemmatize

# %%
# IMPORT INVERTED_INDEX
with open(r'assets/inverted_index_lem.json') as f:
    inverted_index_lem = json.load(f)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Input In [140], in <cell line: 2>()
#       1 # IMPORT INVERTED_INDEX
#       2 with open(r'assets/inverted_index_lem.json') as f:
# ----> 3     inverted_index_lem = json.load(f)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\json\__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     276     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     277     a JSON document) to a Python object.
#     278
#    (...)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#     296         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook, **kw)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File ~\AppData\Local\Programs\Python\Python39\lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File ~\AppData\Local\Programs\Python\Python39\lib\json\decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
pre_at_n, rec_at_n = calc_pre_rec_at_n(create_testing_dicts(normalization='lemmatize')[0], create_testing_dicts(normalization='lemmatize')[1])

# %%
pre_at_n

# %%
rec_at_n

# %%
avg_pre, mean_avg_pre = calc_avg_pre(create_testing_dicts(normalization='lemmatize')[0], create_testing_dicts(normalization='lemmatize')[1])

# %%
avg_pre
# Out:
# {'home improvement store': 0.002,
#  'diesel fuel supplier': 0.005,
#  'church': 0.007,
#  'farm': 0.073,
#  'seed supplier': 0.006,
#  'accountant': 0.082,
#  'trucking company': 0.138,
#  'exporter': 0.024,
#  'grain elevator': 0.0,
#  'popcorn store': 0.009,
#  'agricultural service': 0.066,
#  'warehouse': 0.0,
#  'agricultural production': 0.066,
#  'ranch': 0.156,
#  'holding company': 0.867,
#  'farm equipment supplier': 0.006,
#  'store': 0.128,
#  'grocery store': 0.0,
#  'rice mill': 0.064,
#  'food product supplier': 0.0,
#  'accounting firm': 0.053,
#  'produce market': 0.0,
#  'pet supply store': 0.036,
#  'wholesaler': 0.141,
#  'produce wholesaler': 0.0,
#  'distribution service': 0.0,
#  'crop grower': 0.156,
#  'addiction treatment center': 0.128,
#  'natural good store': 0.0,
#  'orchard': 0.156,
#  'lumber store': 0.005,
#  'mine': 0.357,
#  'transportation service': 0.123,
#  'investment company': 0.22,
#  'fruit wholesaler': 0.008,
#  'real estate agency': 0.417,
#  'event venue': 0.0,
#  'frozen dessert supplier': 0.071,
#  'wine wholesaler importer': 0.025,
#  'winery': 0.096,
#  'aerospace company': 0.053,
#  'cold storage facility': 0.018,
#  'employment agency': 0.122,
#  'plant nursery': 0.0,
#  'air conditioning contractor': 0.016,
#  'air conditioning repair service': 0.016,
#  'fruit vegetable wholesaler': 0.0,
#  'aircraft rental service': 0.0,
#  'monastery': 0.02,
#  'allergist': 0.026,
#  'herb shop': 0.0,
#  'aluminum supplier': 0.032,
#  'ambulance service': 0.071,
#  'wholesale plant nursery': 0.141,
#  'amusement machine supplier': 0.286,
#  'animal hospital': 0.0,
#  'farmer market': 0.0,
#  'vaporizer store': 0.0,
#  'cigar shop': 0.038,
#  'tobacco shop': 0.0,
#  'well drilling contractor': 0.208,
#  'library': 0.092,
#  'apartment building': 0.022,
#  'apartment rental agency': 0.022,
#  'dairy farm': 0.007,
#  'architect': 0.041,
#  'organic farm': 0.0,
#  'architectural designer': 0.025,
#  'architecture firm': 0.02,
#  'livestock producer': 0.008,
#  'dairy supplier': 0.008,
#  'biotechnology company': 0.061,
#  'artist': 0.36,
#  'egg supplier': 0.036,
#  'poultry farm': 0.013,
#  'chicken hatchery': 0.055,
#  'art organization': 0.4,
#  'association organization': 0.043,
#  'food store': 0.0,
#  'deli': 0.0,
#  'bank': 0.208,
#  'fish processing': 0.002,
#  'fish farm': 0.065,
#  'seafood wholesaler': 0.018,
#  'tropical fish store': 0.0,
#  'non profit organization': 0.016,
#  'economic development agency': 0.017,
#  'seafood market': 0.003,
#  'honey farm': 0.035,
#  'horse breeder': 0.013,
#  'asphalt contractor': 0.0,
#  'livestock dealer': 0.014,
#  'department store': 0.056,
#  'mill': 0.009,
#  'atv dealer': 0.045,
#  'audio visual consultant': 0.031,
#  'pallet supplier': 0.057,
#  'wood supplier': 0.0,
#  'hardware store': 0.0,
#  'furniture wholesaler': 0.0,
#  'auditor': 0.034,
#  'oil natural gas company': 0.357,
#  'auto body shop': 0.0,
#  'boat repair shop': 0.013,
#  'association': 0.043,
#  'railing contractor': 0.005,
#  'publisher': 0.323,
#  'pond supply store': 0.0,
#  'agriculture cooperative': 0.0,
#  'printing equipment supplier': 0.001,
#  'auto insurance agency': 0.0,
#  'alternative fuel station': 0.008,
#  'auto part manufacturer': 0.001,
#  'foundation': 0.004,
#  'fertilizer supplier': 0.066,
#  'farming company': 0.156,
#  'finance broker': 0.244,
#  'agricultural cooperative': 0.0,
#  'fire station': 0.0,
#  'environmental consultant': 0.034,
#  'civil engineer': 0.323,
#  'fire protection service': 0.0,
#  'gas company': 0.0,
#  'oilfield': 0.0,
#  'banquet hall': 0.067,
#  'mining company': 0.357,
#  'coalfield': 0.0,
#  'steel fabricator': 0.044,
#  'quarry': 0.357,
#  'gold mining company': 0.357,
#  'high rise building': 0.0,
#  'basketball club': 0.04,
#  'gold dealer': 0.0,
#  'battery manufacturer': 0.053,
#  'electric utility company': 0.0,
#  'environmental program': 0.003,
#  'office': 0.0,
#  'stone supplier': 0.005,
#  'aggregate supplier': 0.0,
#  'sand gravel supplier': 0.086,
#  'building material supplier': 0.0,
#  'beauty supply store': 0.021,
#  'crushed stone supplier': 0.003,
#  'rock shop': 0.0,
#  'road construction company': 0.094,
#  'marketing consultant': 0.0,
#  'blood testing service': 0.0,
#  'contractor': 0.279,
#  'excavating contractor': 0.016,
#  'asphalt mixing plant': 0.058,
#  'ready mix concrete supplier': 0.007,
#  'sand plant': 0.086,
#  'bmw dealer': 0.0,
#  'bookbinder': 0.0,
#  'garden center': 0.008,
#  'abrasive supplier': 0.103,
#  'granite supplier': 0.003,
#  'drilling contractor': 0.154,
#  'bpo company': 0.0,
#  'oil gas exploration service': 0.357,
#  'building complex': 0.0,
#  'construction equipment supplier': 0.0,
#  'mining equipment': 0.0,
#  'bus ticket agency': 0.003,
#  'business center': 0.0,
#  'skyscraper': 0.0,
#  'software company': 0.284,
#  'business development service': 0.0,
#  'business management consultant': 0.0,
#  'cabinet maker': 0.022,
#  'call center': 0.045,
#  'cancer treatment center': 0.013,
#  'power plant consultant': 0.032,
#  'business park': 0.0,
#  'petroleum product company': 0.009,
#  'parking lot': 0.078,
#  'water utility company': 0.029,
#  'car repair maintenance': 0.021,
#  'water treatment plant': 0.029,
#  'car service': 0.021,
#  'cattle market': 0.002,
#  'sewage disposal service': 0.178,
#  'certified public accountant': 0.02,
#  'government office': 0.345,
#  'charity': 0.02,
#  'air conditioning system supplier': 0.004,
#  'chemical industry': 0.086,
#  'chemical manufacturer': 0.086,
#  'title company': 0.0,
#  'chemical plant': 0.086,
#  'property management company': 0.029,
#  'custom home builder': 0.0,
#  'window installation service': 0.005,
#  'fire damage restoration service': 0.0,
#  'equipment rental agency': 0.01,
#  'chemical wholesaler': 0.003,
#  'financial planner': 0.244,
#  'telecommunication service provider': 0.105,
#  'energy equipment solution': 0.0,
#  'chiropractor': 0.077,
#  'steel distributor': 0.0,
#  'city government office': 0.138,
#  'crane service': 0.008,
#  'garage door supplier': 0.078,
#  'industrial door supplier': 0.019,
#  'city town hall': 0.138,
#  'clothing wholesaler': 0.018,
#  'coin operated laundry equipment supplier': 0.046,
#  'metal supplier': 0.002,
#  'glass shop': 0.0,
#  'college': 0.588,
#  'siding contractor': 0.013,
#  'commercial printer': 0.003,
#  'storage facility': 0.26,
#  'communication tower': 0.0,
#  'janitorial service': 0.112,
#  'computer consultant': 0.0,
#  'fire protection system supplier': 0.0,
#  'elevator service': 0.008,
#  'industrial equipment supplier': 0.01,
#  'dry wall contractor': 0.0,
#  'insulation contractor': 0.065,
#  'concrete contractor': 0.078,
#  'scaffolding rental service': 0.014,
#  'construction company': 0.323,
#  'flooring store': 0.0,
#  'flooring contractor': 0.019,
#  'tile contractor': 0.056,
#  'tile manufacturer': 0.056,
#  'glass mirror shop': 0.0,
#  'construction material wholesaler': 0.0,
#  'gutter cleaning service': 0.011,
#  'sheet metal contractor': 0.028,
#  'consultant': 0.046,
#  'container service': 0.012,
#  'septic system service': 0.161,
#  'corporate campus': 0.111,
#  'water damage restoration service': 0.0,
#  'welder': 0.001,
#  'corporate office': 0.111,
#  'animal': 0.127,
#  'animal feed store': 0.0,
#  'animal protection organization': 0.0,
#  'brewing supply store': 0.0,
#  'cosmetic store': 0.023,
#  'county government office': 0.123,
#  'sugar factory': 0.076,
#  'confectionery wholesaler': 0.019,
#  'financial institution': 0.0,
#  'candy store': 0.0,
#  'confectionery': 0.0,
#  'chocolate factory': 0.11,
#  'chocolate shop': 0.11,
#  'courier service': 0.228,
#  'coworking space': 0.0,
#  'frozen food manufacturer': 0.071,
#  'beverage distributor': 0.0,
#  'agricultural organization': 0.0,
#  'dairy store': 0.008,
#  'dairy': 0.007,
#  'ice cream shop': 0.029,
#  'medical laboratory': 0.03,
#  'demolition contractor': 0.054,
#  'meat processor': 0.079,
#  'fmcg manufacturer': 0.0,
#  'garbage collection service': 0.027,
#  'wholesale bakery': 0.0,
#  'dentist': 0.162,
#  'dessert shop': 0.052,
#  'cupcake shop': 0.0,
#  'nut store': 0.0,
#  'wholesale grocer': 0.141,
#  'design engineer': 0.017,
#  'business business service': 0.0,
#  'condiment supplier': 0.11,
#  'digital printing service': 0.034,
#  'culinary school': 0.059,
#  'importer': 0.0,
#  'bottled water supplier': 0.007,
#  'coffee roaster': 0.053,
#  'packaging supply store': 0.006,
#  'ice supplier': 0.029,
#  'brewery': 0.082,
#  'winemaking company': 0.0,
#  'distillery': 0.0,
#  'disability service support organisation': 0.129,
#  'district government office': 0.078,
#  'air filter supplier': 0.011,
#  'tire shop': 0.002,
#  'fastener supplier': 0.044,
#  'fabric product manufacturer': 0.137,
#  'textile': 0.104,
#  'textile exporter': 0.104,
#  'textile engineer': 0.104,
#  'fabric store': 0.0,
#  'knit shop': 0.123,
#  'doctor': 0.214,
#  'lamination service': 0.103,
#  'plastic resin manufacturer': 0.073,
#  'carpet manufacturer': 0.022,
#  'upholstery shop': 0.019,
#  'business administration service': 0.0,
#  'furniture store': 0.0,
#  'dry cleaner': 0.0,
#  'packaging company': 0.006,
#  'duty free store': 0.0,
#  'commerce service': 0.0,
#  'cable company': 0.037,
#  'education': 0.343,
#  'outlet store': 0.0,
#  'lingerie store': 0.011,
#  'clothes fabric manufacturer': 0.004,
#  'education center': 0.343,
#  'uniform store': 0.004,
#  'men clothing store': 0.003,
#  'clothing store': 0.012,
#  'woman clothing store': 0.002,
#  'western apparel store': 0.011,
#  'costume store': 0.043,
#  'game store': 0.0,
#  'hat shop': 0.023,
#  'leather good manufacturer': 0.0,
#  'educational consultant': 0.517,
#  'leather exporter': 0.063,
#  'shoe store': 0.004,
#  'boutique': 0.0,
#  'leather wholesaler': 0.0,
#  'handbag shop': 0.029,
#  'electronics store': 0.006,
#  'luggage store': 0.013,
#  'building material store': 0.0,
#  'saw mill': 0.0,
#  'electrical engineer': 0.0,
#  'deck builder': 0.027,
#  'concrete product supplier': 0.037,
#  'plywood supplier': 0.075,
#  'electrical installation service': 0.006,
#  'truss manufacturer': 0.058,
#  'door supplier': 0.005,
#  'wood laminate flooring supplier': 0.088,
#  'aircraft supply store': 0.0,
#  'modular home builder': 0.0,
#  'portable building manufacturer': 0.04,
#  'modular home dealer': 0.0,
#  'mulch supplier': 0.014,
#  'electrician': 0.016,
#  'paper mill': 0.088,
#  'energy supplier': 0.129,
#  'engineer': 0.034,
#  'print shop': 0.025,
#  'custom label printer': 0.005,
#  'marketing': 0.0,
#  'marketing agency': 0.0,
#  'engineering consultant': 0.005,
#  'entertainer': 0.4,
#  'envelope supplier': 0.01,
#  'oil refinery': 0.0,
#  'recording studio': 0.12,
#  'environment renewable natural resource': 0.0,
#  'finishing material supplier': 0.0,
#  'event ticket seller': 0.0,
#  'waterproofing company': 0.032,
#  'auto part store': 0.01,
#  'heating oil supplier': 0.0,
#  'family practice physician': 0.031,
#  'machining manufacturer': 0.053,
#  'industrial gas supplier': 0.002,
#  'welding supply store': 0.042,
#  'dry ice supplier': 0.062,
#  'private equity firm': 0.0,
#  'family service center': 0.031,
#  'federal government office': 0.244,
#  'vitamin supplement store': 0.011,
#  'feed manufacturer': 0.053,
#  'medical equipment supplier': 0.002,
#  'medical supply store': 0.002,
#  'medical clinic': 0.03,
#  'research institute': 0.126,
#  'biochemical supplier': 0.0,
#  'fiber optic product supplier': 0.0,
#  'paint manufacturer': 0.029,
#  'equipment supplier': 0.016,
#  'food': 0.101,
#  'pipe supplier': 0.022,
#  'oil field equipment supplier': 0.0,
#  'food broker': 0.0,
#  'food manufacturer': 0.101,
#  'food processing company': 0.101,
#  'fence supply store': 0.0,
#  'food producer': 0.101,
#  'forestry service': 0.141,
#  'foundry': 0.037,
#  'wholesale jeweler': 0.141,
#  'cookie shop': 0.027,
#  'truck rental agency': 0.0,
#  'fruit vegetable processing': 0.021,
#  'kitchen supply store': 0.0,
#  'hydraulic equipment supplier': 0.0,
#  'irrigation equipment supplier': 0.036,
#  'bearing supplier': 0.038,
#  'metallurgy company': 0.026,
#  'plastic injection molding service': 0.001,
#  'general contractor': 0.24,
#  'general hospital': 0.0,
#  'tool manufacturer': 0.029,
#  'industrial design company': 0.0,
#  'hyundai dealer': 0.0,
#  'glass industry': 0.103,
#  'polymer supplier': 0.0,
#  'printing equipment supply': 0.001,
#  'toner cartridge supplier': 0.021,
#  'printer repair service': 0.003,
#  'fuel supplier': 0.0,
#  'glass manufacturer': 0.103,
#  'plastic bag supplier': 0.073,
#  'glassware manufacturer': 0.015,
#  'polythene plastic sheeting supplier': 0.0,
#  'pvc industry': 0.021,
#  'countertop store': 0.006,
#  'cabinet store': 0.003,
#  'fiberglass supplier': 0.033,
#  'golf cart dealer': 0.0,
#  'auto repair shop': 0.0,
#  'hose supplier': 0.033,
#  'rubber product supplier': 0.069,
#  'automotive': 0.0,
#  'commercial refrigerator supplier': 0.004,
#  'golf club': 0.04,
#  'golf course': 0.04,
#  'green energy supplier': 0.0,
#  'greenhouse': 0.156,
#  'auto glass shop': 0.0,
#  'lighting manufacturer': 0.04,
#  'cement manufacturer': 0.073,
#  'brick manufacturer': 0.053,
#  'natural stone supplier': 0.0,
#  'gym': 0.04,
#  'marble supplier': 0.01,
#  'corporate gift supplier': 0.0,
#  'shipbuilding repair company': 0.0,
#  'construction maintenance office': 0.323,
#  'boiler manufacturer': 0.046,
#  'container supplier': 0.012,
#  'home construction': 0.004,
#  'health': 0.256,
#  'heart hospital': 0.0,
#  'spring supplier': 0.046,
#  'electric utility manufacturer': 0.0,
#  'aircraft manufacturer': 0.038,
#  'metal heat treating service': 0.047,
#  'plating service': 0.016,
#  'automation company': 0.0,
#  'heating contractor': 0.057,
#  'plumbing supply store': 0.004,
#  'gun shop': 0.023,
#  'ammunition supplier': 0.03,
#  'pipe manufacturer': 0.022,
#  'school': 0.471,
#  'fire protection equipment supplier': 0.0,
#  'agricultural machinery manufacturer': 0.003,
#  'lawn mower store': 0.0,
#  'lawn irrigation equipment supplier': 0.0,
#  'financial consultant': 0.244,
#  'helicopter charter': 0.032,
#  'packaging machinery': 0.0,
#  'historical landmark': 0.161,
#  'electronics manufacturer': 0.013,
#  'graphic designer': 0.016,
#  'eye care center': 0.049,
#  'optical product manufacturer': 0.036,
#  'image consultant': 0.003,
#  'cleaning product supplier': 0.0,
#  'fireplace store': 0.012,
#  'home builder': 0.004,
#  'tool die shop': 0.029,
#  'metal stamping service': 0.047,
#  'environmental organization': 0.003,
#  'food processing equipment': 0.001,
#  'loan agency': 0.22,
#  'power plant equipment supplier': 0.0,
#  'home good store': 0.002,
#  'engine rebuilding service': 0.0,
#  'air compressor supplier': 0.011,
#  'honda dealer': 0.0,
#  'elevator manufacturer': 0.008,
#  'crane dealer': 0.008,
#  'crane rental agency': 0.021,
#  'compound building': 0.0,
#  'tractor dealer': 0.0,
#  'furnace part supplier': 0.0,
#  'heating equipment supplier': 0.008,
#  'pneumatic tool supplier': 0.0,
#  'truck stop': 0.0,
#  'computer hardware manufacturer': 0.053,
#  'satellite communication service': 0.231,
#  'hospital': 0.034,
#  'electronics company': 0.006,
#  'electronic part supplier': 0.037,
#  'hvac contractor': 0.032,
#  'industrial engineer': 0.0,
#  'contact lens supplier': 0.0,
#  'information service': 0.323,
#  'building': 0.287,
#  'water work equipment supplier': 0.0,
#  'measuring instrument supplier': 0.053,
#  'scientific equipment supplier': 0.0,
#  'medical center': 0.03,
#  'watch manufacturer': 0.009,
#  'corporate entertainment service': 0.0,
#  'insurance': 0.244,
#  'record company': 0.243,
#  'video duplication service': 0.169,
#  'insurance agency': 0.244,
#  'lighting store': 0.04,
#  'lighting wholesaler': 0.04,
#  'entertainment agency': 0.334,
#  'insurance broker': 0.244,
#  'electrical equipment supplier': 0.004,
#  'electric motor store': 0.043,
#  'railroad company': 0.062,
#  'electrical supply store': 0.004,
#  'insurance company': 0.244,
#  'factory equipment supplier': 0.0,
#  'investment service': 0.22,
#  'laser equipment supplier': 0.013,
#  'executive suite rental agency': 0.177,
#  'truck dealer': 0.004,
#  'motor vehicle dealer': 0.0,
#  'car dealer': 0.0,
#  'truck topper supplier': 0.004,
#  'police supply store': 0.005,
#  'iron steel contractor': 0.0,
#  'fire department equipment supplier': 0.0,
#  'towing equipment provider': 0.2,
#  'logistics service': 0.204,
#  'trailer manufacturer': 0.02,
#  'trailer dealer': 0.006,
#  'dealer': 0.086,
#  'auto spring shop': 0.0,
#  'auto upholsterer': 0.001,
#  'auto body part supplier': 0.01,
#  'car factory': 0.006,
#  'freight forwarding service': 0.176,
#  'brake shop': 0.003,
#  'railroad equipment supplier': 0.003,
#  'jewelry equipment supplier': 0.042,
#  'boat builder': 0.013,
#  'ship building': 0.016,
#  'marine supply store': 0.0,
#  'boat dealer': 0.019,
#  'kawasaki motorcycle dealer': 0.0,
#  'knife manufacturing': 0.021,
#  'labor union': 0.029,
#  'furniture maker': 0.053,
#  'banking finance': 0.087,
#  'furniture manufacturer': 0.053,
#  'logistics': 0.204,
#  'massage supply store': 0.003,
#  'telecommunication equipment supplier': 0.0,
#  'baby store': 0.006,
#  'molding supplier': 0.021,
#  'office equipment supplier': 0.1,
#  'office furniture store': 0.0,
#  'store equipment supplier': 0.0,
#  'laboratory': 0.011,
#  'health beauty shop': 0.0,
#  'learning center': 0.588,
#  'dental laboratory': 0.015,
#  'land surveyor': 0.003,
#  'educational supply store': 0.0,
#  'jewelry store': 0.0,
#  'playground equipment supplier': 0.007,
#  'outdoor sport store': 0.006,
#  'toy store': 0.0,
#  'security service': 0.0,
#  'sign shop': 0.032,
#  'office supply store': 0.0,
#  'landscaper': 0.0,
#  'gasket manufacturer': 0.028,
#  'piano maker': 0.004,
#  'piano store': 0.023,
#  'funeral home': 0.041,
#  'monument': 0.0,
#  'book publisher': 0.095,
#  'wig shop': 0.011,
#  'laundromat': 0.02,
#  'auto wrecker': 0.0,
#  'auto part market': 0.01,
#  'jeep dealer': 0.0,
#  'restaurant supply store': 0.007,
#  'roofing supply store': 0.036,
#  'law firm': 0.02,
#  'building material market': 0.0,
#  'camera store': 0.022,
#  'lawn care service': 0.005,
#  'computer security service': 0.0,
#  'computer store': 0.0,
#  'design agency': 0.017,
#  'diagnostic center': 0.112,
#  'laboratory equipment supplier': 0.017,
#  'home theater store': 0.001,
#  'metal industry supplier': 0.002,
#  'landscaping supply store': 0.0,
#  'appliance part supplier': 0.012,
#  'vacuum cleaner store': 0.002,
#  'audio visual equipment supplier': 0.031,
#  'lawyer': 0.102,
#  'cell phone store': 0.0,
#  'bathroom supply store': 0.005,
#  'leasing service': 0.417,
#  'construction machine dealer': 0.0,
#  'dairy farm equipment supplier': 0.008,
#  'propane supplier': 0.0,
#  'legal service': 0.102,
#  'janitorial equipment supplier': 0.112,
#  'life insurance agency': 0.003,
#  'railroad contractor': 0.062,
#  'swimming pool supply store': 0.009,
#  'light bulb supplier': 0.031,
#  'linen store': 0.034,
#  'metal construction company': 0.047,
#  'local government office': 0.0,
#  'logging contractor': 0.015,
#  'machine shop': 0.042,
#  'hotel supply store': 0.089,
#  'import export company': 0.0,
#  'sewing company': 0.0,
#  'research foundation': 0.126,
#  'machinery part manufacturer': 0.046,
#  'sport accessory wholesaler': 0.0,
#  'fashion designer': 0.002,
#  'cheese manufacturer': 0.044,
#  'cheese shop': 0.044,
#  'shipping mailing': 0.0,
#  'wholesale food store': 0.141,
#  'organic food store': 0.0,
#  'pie shop': 0.096,
#  'auction house': 0.045,
#  'livestock auction house': 0.014,
#  'cotton exporter': 0.043,
#  'plastic wholesaler': 0.0,
#  'mailing service': 0.0,
#  'manufacturer': 0.0,
#  'gas station': 0.0,
#  'beer distributor': 0.039,
#  'alcoholic beverage wholesaler': 0.079,
#  'religious good store': 0.148,
#  'book wholesaler': 0.004,
#  'masonry supply store': 0.0,
#  'wholesale florist': 0.141,
#  'florist': 0.272,
#  'marine engineer': 0.003,
#  'paint store': 0.0,
#  'used auto part store': 0.0,
#  'masonry contractor': 0.323,
#  'used car dealer': 0.0,
#  'used truck dealer': 0.0,
#  'massage therapist': 0.006,
#  'material handling equipment supplier': 0.002,
#  'marina': 0.24,
#  'meat packer': 0.014,
#  'mattress store': 0.0,
#  'blind shop': 0.035,
#  'interior designer': 0.005,
#  'window treatment store': 0.0,
#  'appliance store': 0.0,
#  'health food store': 0.0,
#  'direct mail advertising': 0.0,
#  'meat wholesaler': 0.014,
#  'butcher shop deli': 0.023,
#  'italian grocery store': 0.0,
#  'market': 0.0,
#  'food service': 0.013,
#  'grocery delivery service': 0.0,
#  'wine store': 0.003,
#  'liquor store': 0.006,
#  'kiosk': 0.0,
#  'optometrist': 0.054,
#  'optician': 0.004,
#  'mechanical contractor': 0.011,
#  'mechanical engineer': 0.0,
#  'cafe': 0.03,
#  'jeweler': 0.014,
#  'leather good store': 0.0,
#  'gift shop': 0.23,
#  'craft store': 0.028,
#  'hobby store': 0.011,
#  'fabric wholesaler': 0.0,
#  'scrap metal dealer': 0.0,
#  'quilt shop': 0.0,
#  'sheet music store': 0.0,
#  'musical instrument manufacturer': 0.002,
#  'music store': 0.057,
#  'musical instrument store': 0.0,
#  'band': 0.008,
#  'bookstore': 0.0,
#  'art museum': 0.4,
#  'newsstand': 0.045,
#  'medical equipment manufacturer': 0.023,
#  'fashion accessory store': 0.008,
#  'discount store': 0.0,
#  'cemetery': 0.01,
#  'bus stop': 0.026,
#  'variety store': 0.0,
#  'thrift store': 0.045,
#  'medical group': 0.03,
#  'donation center': 0.0,
#  'pet store': 0.036,
#  'art gallery': 0.0,
#  'art dealer': 0.0,
#  'housing development': 0.004,
#  'mobile home dealer': 0.009,
#  'convenience store': 0.081,
#  'medical office': 0.03,
#  'medical technology manufacturer': 0.023,
#  'childrens furniture store': 0.0,
#  'mental health clinic': 0.218,
#  'airline': 0.0,
#  'aviation consultant': 0.008,
#  'travel agency': 0.197,
#  'travel service': 0.197,
#  'airport': 0.02,
#  'mental health service': 0.218,
#  'shipping company': 0.0,
#  'metal fabricator': 0.047,
#  'cruise line company': 0.003,
#  'towing service': 0.2,
#  'ferry terminal': 0.04,
#  'ferry service': 0.04,
#  'metal finisher': 0.047,
#  'boat tour agency': 0.01,
#  'bus company': 0.026,
#  'moving company': 0.052,
#  'moving storage service': 0.052,
#  'state department transportation': 0.012,
#  'department transportation': 0.152,
#  'handicapped transportation service': 0.04,
#  'railway service': 0.036,
#  'train station': 0.009,
#  'bus depot': 0.026,
#  'bus charter': 0.026,
#  'metal processing company': 0.047,
#  'mixed use': 0.0,
#  'motorcycle shop': 0.03,
#  'limousine service': 0.2,
#  'chauffeur service': 0.0,
#  'school bus service': 0.0,
#  'airport shuttle service': 0.02,
#  'tourist information center': 0.004,
#  'carriage ride service': 0.02,
#  'cruise agency': 0.011,
#  'tourist attraction': 0.004,
#  'ski resort': 0.005,
#  'ski area': 0.005,
#  'fixed base operator': 0.0,
#  'aircraft maintenance company': 0.009,
#  'motorsports store': 0.0,
#  'boat rental service': 0.0,
#  'utility trailer dealer': 0.0,
#  'forklift dealer': 0.004,
#  'municipal administration office': 0.0,
#  'nephrologist': 0.0,
#  'bus coach company': 0.026,
#  'shipping service': 0.0,
#  'shipping mailing service': 0.0,
#  'newspaper publisher': 0.171,
#  'shredding service': 0.008,
#  'nuclear power company': 0.085,
#  'nursing home': 0.214,
#  'medium company': 0.004,
#  'multimedia electronic book publisher': 0.323,
#  'internet marketing service': 0.0,
#  'greeting card shop': 0.009,
#  'theme park': 0.04,
#  'film production company': 0.024,
#  'obstetrician gynecologist': 0.026,
#  'movie studio': 0.323,
#  'video production service': 0.169,
#  'movie theater': 0.323,
#  'theater company': 0.06,
#  'performing art theater': 0.143,
#  'occupational safety health': 0.004,
#  'office space rental agency': 0.0,
#  'commercial real estate agency': 0.0,
#  'art school': 0.0,
#  'music publisher': 0.11,
#  'printed music publisher': 0.027,
#  'home audio store': 0.001,
#  'musician': 0.04,
#  'music management promotion': 0.0,
#  'video editing service': 0.169,
#  'office supply wholesaler': 0.1,
#  'official residence': 0.0,
#  'orthopedic clinic': 0.019,
#  'painter': 0.0,
#  'painting': 0.323,
#  'telephone company': 0.015,
#  'medium house': 0.004,
#  'paper distributor': 0.002,
#  'news service': 0.005,
#  'public library': 0.0,
#  'law library': 0.186,
#  'museum': 0.16,
#  'federal reserve bank': 0.024,
#  'credit union': 0.244,
#  'atm': 0.012,
#  'paving contractor': 0.057,
#  'mortgage lender': 0.155,
#  'investment bank': 0.22,
#  'check cashing service': 0.149,
#  'stock broker': 0.0,
#  'health consultant': 0.0,
#  'health insurance agency': 0.0,
#  'payroll service': 0.204,
#  'pediatrician': 0.051,
#  'human resource consulting': 0.062,
#  'pest control service': 0.078,
#  'pet boarding service': 0.069,
#  'pet care': 0.069,
#  'loss adjuster': 0.192,
#  'pharmaceutical company': 0.076,
#  'pharmaceutical product wholesaler': 0.002,
#  'pharmacy': 0.008,
#  'educational institution': 0.517,
#  'retirement community': 0.058,
#  'fraternal organization': 0.02,
#  'photo lab': 0.0,
#  'property investment': 0.029,
#  'photographer': 0.01,
#  'photography school': 0.041,
#  'star hotel': 0.0,
#  'convention center': 0.086,
#  'real estate appraiser': 0.417,
#  'photography service': 0.041,
#  'resort hotel': 0.022,
#  'real estate consultant': 0.417,
#  'car rental agency': 0.015,
#  'car leasing service': 0.015,
#  'ford dealer': 0.0,
#  'car finance loan company': 0.0,
#  'trailer rental service': 0.006,
#  'furniture rental service': 0.0,
#  'tuxedo shop': 0.014,
#  'dress tuxedo rental service': 0.005,
#  'wedding store': 0.0,
#  'video store': 0.0,
#  'movie rental': 0.323,
#  'photography studio': 0.041,
#  'home health care service': 0.003,
#  'skateboard shop': 0.005,
#  'event technology service': 0.0,
#  'party equipment rental service': 0.024,
#  'construction machine rental service': 0.0,
#  'audio visual equipment rental service': 0.031,
#  'shipping equipment industry': 0.004,
#  'physical therapy clinic': 0.012,
#  'plastic fabrication company': 0.073,
#  'plastic product supplier': 0.073,
#  'auto tag agency': 0.0,
#  'department motor vehicle': 0.152,
#  'notary public': 0.082,
#  'private investigator': 0.0,
#  'escrow service': 0.028,
#  'real estate agent': 0.417,
#  'playground': 0.0,
#  'plumber': 0.005,
#  'port authority': 0.16,
#  'portrait studio': 0.025,
#  'post office': 0.02,
#  'professional service': 0.166,
#  'university hospital': 0.0,
#  'public relation firm': 0.0,
#  'civil engineering company': 0.323,
#  'drafting service': 0.077,
#  'pump supplier': 0.045,
#  'interior construction contractor': 0.017,
#  'carpet cleaning service': 0.025,
#  'exhibition planner': 0.0,
#  'decal supplier': 0.0,
#  'stage lighting equipment supplier': 0.0,
#  'event management company': 0.0,
#  'radio broadcaster': 0.004,
#  'computer support service': 0.0,
#  'ravine': 0.0,
#  'employment center': 0.122,
#  'national health foundation': 0.0,
#  'real estate developer': 0.0,
#  'advertising agency': 0.004,
#  'promotional product supplier': 0.0,
#  'advertising service': 0.004,
#  'record storage facility': 0.0,
#  'fund management company': 0.244,
#  'recreation center': 0.326,
#  'bakery': 0.094,
#  'database management company': 0.065,
#  'market researcher': 0.0,
#  'recycling center': 0.0,
#  'regional government office': 0.017,
#  'rehabilitation center': 0.043,
#  'religious institution': 0.148,
#  'religious organization': 0.148,
#  'repair service': 0.06,
#  'emergency veterinarian service': 0.0,
#  'pet sitter': 0.069,
#  'research product development': 0.126,
#  'building society': 0.287,
#  'valet parking service': 0.041,
#  'nursing agency': 0.214,
#  'executive search firm': 0.045,
#  'recruiter': 0.0,
#  'temp agency': 0.0,
#  'health center': 0.256,
#  'restaurant': 0.106,
#  'roofing contractor': 0.015,
#  'sport nutrition store': 0.0,
#  'credit reporting agency': 0.0,
#  'automobile storage facility': 0.0,
#  'debt collection agency': 0.022,
#  'park': 0.0,
#  'court reporter': 0.044,
#  'bus tour agency': 0.003,
#  'tour operator': 0.124,
#  'convention information bureau': 0.086,
#  'balloon ride tour agency': 0.07,
#  'security guard service': 0.0,
#  'locksmith': 0.045,
#  'commercial cleaning service': 0.0,
#  'blast cleaning service': 0.0,
#  'conference center': 0.065,
#  'safety equipment supplier': 0.0,
#  'garbage dump': 0.027,
#  'sanitation service': 0.008,
#  'garbage dump service': 0.027,
#  'environmental health service': 0.034,
#  'portable toilet supplier': 0.0,
#  'public work department': 0.307,
#  'school district office': 0.471,
#  'sailmaker': 0.0,
#  'community college': 0.0,
#  'salvage yard': 0.007,
#  'business school': 0.0,
#  'trade school': 0.0,
#  'private university': 0.0,
#  'computer training school': 0.0,
#  'school supply store': 0.0,
#  'screen printer': 0.048,
#  'medium consultant': 0.004,
#  'beauty school': 0.0,
#  'flight school': 0.122,
#  'seaport': 0.0,
#  'security system supplier': 0.0,
#  'middle school': 0.059,
#  'nonprofit': 0.0,
#  'shooting range': 0.02,
#  'soccer club': 0.067,
#  'camp': 0.22,
#  'diving contractor': 0.023,
#  'language school': 0.529,
#  'english language school': 0.0,
#  'preschool': 0.026,
#  'self storage facility': 0.213,
#  'semi conductor supplier': 0.017,
#  'driving school': 0.278,
#  'trucking school': 0.0,
#  'senior citizen center': 0.019,
#  'service': 0.018,
#  'childrens hospital': 0.0,
#  'dental supply store': 0.015,
#  'shipyard': 0.011,
#  'orthodox synagogue': 0.0,
#  'short term apartment rental agency': 0.057,
#  'nutritionist': 0.026,
#  'ophthalmologist': 0.009,
#  'ophthalmology clinic': 0.051,
#  'social service organization': 0.209,
#  'social welfare center': 0.209,
#  'solar energy company': 0.265,
#  'solar energy equipment supplier': 0.265,
#  'special education school': 0.0,
#  'podiatrist': 0.051,
#  'reproductive health clinic': 0.013,
#  'sporting good store': 0.009,
#  'dialysis center': 0.103,
#  'sport complex': 0.356,
#  'wellness program': 0.0,
#  'sportswear store': 0.0,
#  'private hospital': 0.021,
#  'radiologist': 0.026,
#  'medical diagnostic imaging center': 0.03,
#  'ray lab': 0.096,
#  'blood bank': 0.034,
#  'stainless steel plant': 0.01,
#  'state agency': 0.012,
#  'heliport': 0.0,
#  'health care company': 0.256,
#  'psychiatric hospital': 0.128,
#  'state government office': 0.012,
#  'medical institution': 0.03,
#  'steel construction company': 0.006,
#  'cleaning service': 0.047,
#  ...}

# %%
mean_avg_pre
# Out:
# 0.058

# %%
## BoW mAP results are going to be used later on the Charts.ipynb file
word_count_maps = []
for i in range(1, 11):
    word_count_maps.append(calc_avg_pre(create_testing_dicts(normalization='lemmatize')[0], create_testing_dicts(normalization='lemmatize')[1], cutoff=i)[1])

# %%
word_count_maps
# Out:
# [0.009, 0.017, 0.023, 0.029, 0.035, 0.04, 0.044, 0.05, 0.054, 0.058]

# %% [markdown]
# #### NDCG
# NDCG is a good way of measuring the order of results returned from the Recommender system. While I did say that order doesn't entirely matter in this project, it's still good to see how close results are to the top. Since users are more likely to only read the first few, it's probably good if we have a decent NDCG score.

# %%
calc_NDCG_at_n(create_testing_dicts(normalization='lemmatize')[0], create_testing_dicts(normalization='lemmatize')[1], n=-1, base=2)
# Out:
# {'home improvement store': 0.062387011628009956,
#  'diesel fuel supplier': 0.08387095630361062,
#  'church': 0.09034884889711046,
#  'farm': 0.47709029832625394,
#  'seed supplier': 0.1254333888595897,
#  'accountant': 0.8877119214641515,
#  'trucking company': 0.8541001297672974,
#  'exporter': 1.0,
#  'grain elevator': 0.20341748548710972,
#  'popcorn store': 0.16539480028020273,
#  'agricultural service': 0.3551836963652799,
#  'warehouse': 0.20341748548710972,
#  'agricultural production': 0.3813826423749301,
#  'ranch': 0.31597114306698204,
#  'holding company': 0.9816035470353093,
#  'farm equipment supplier': 0.07620562577841833,
#  'store': 0.28003533954638904,
#  'grocery store': 0.0239570415260799,
#  'rice mill': 0.6434691377083236,
#  'food product supplier': 0.014547278280154294,
#  'accounting firm': 0.2991508324014225,
#  'produce market': 0.0239570415260799,
#  'pet supply store': 0.27225613333912835,
#  'wholesaler': 0.4504652996471026,
#  'produce wholesaler': 0.014547278280154294,
#  'distribution service': 0.021394318627208773,
#  'crop grower': 0.6663981205506385,
#  'addiction treatment center': 0.5862810837208018,
#  'natural good store': 0.0239570415260799,
#  'orchard': 0.5544201778342831,
#  'lumber store': 0.11373509708218703,
#  'mine': 0.6220297813463143,
#  'transportation service': 0.40411081699202167,
#  'investment company': 0.6253574754919913,
#  'fruit wholesaler': 0.16793030350493562,
#  'real estate agency': 0.8989739059351857,
#  'event venue': 0.0239570415260799,
#  'frozen dessert supplier': 0.547417771643236,
#  'wine wholesaler importer': 0.33277260117725815,
#  'winery': 0.9966828540224155,
#  'aerospace company': 0.9318992578092412,
#  'cold storage facility': 0.29374792515294096,
#  'employment agency': 0.5766061029914185,
#  'plant nursery': 0.0239570415260799,
#  'air conditioning contractor': 0.24006192174891539,
#  'air conditioning repair service': 0.24006192174891539,
#  'fruit vegetable wholesaler': 0.0239570415260799,
#  'aircraft rental service': 0.045995238117956,
#  'monastery': 1.0,
#  'allergist': 1.0,
#  'herb shop': 0.0239570415260799,
#  'aluminum supplier': 0.7537312022418973,
#  'ambulance service': 0.6540576884737525,
#  'wholesale plant nursery': 0.49043829648561793,
#  'amusement machine supplier': 0.695488025727903,
#  'animal hospital': 0.021394318627208773,
#  'farmer market': 0.022222222222222223,
#  'vaporizer store': 0.043478260869565216,
#  'cigar shop': 0.3351482532243254,
#  'tobacco shop': 0.05065501728141138,
#  'well drilling contractor': 0.5180265966271922,
#  'library': 0.43823819028948136,
#  'apartment building': 0.2286098207715132,
#  'apartment rental agency': 0.2286098207715132,
#  'dairy farm': 0.06132058872957222,
#  'architect': 0.6553730630624757,
#  'organic farm': 0.016196592664967396,
#  'architectural designer': 0.22218011520630648,
#  'architecture firm': 0.62,
#  'livestock producer': 0.022361445489034806,
#  'dairy supplier': 0.19011491052801935,
#  'biotechnology company': 0.9971452890289545,
#  'artist': 0.8723768362340125,
#  'egg supplier': 0.4253288417386337,
#  'poultry farm': 0.2704765666824035,
#  'chicken hatchery': 0.5839459964853606,
#  'art organization': 0.8173692367039833,
#  'association organization': 0.43915562889714416,
#  'food store': 0.0239570415260799,
#  'deli': 0.0625,
#  'bank': 0.6990178804333254,
#  'fish processing': 0.08409136817603759,
#  'fish farm': 0.2564369454660383,
#  'seafood wholesaler': 0.25448741234807787,
#  'tropical fish store': 0.0451665444735485,
#  'non profit organization': 0.09463018976719483,
#  'economic development agency': 0.24378264640564537,
#  'seafood market': 0.0800512291427166,
#  'honey farm': 0.5492088102944677,
#  'horse breeder': 0.1141001873050885,
#  'asphalt contractor': 0.03479303924387127,
#  'livestock dealer': 0.2055765388650011,
#  'department store': 0.3419603603845232,
#  'mill': 0.19532184903064462,
#  'atv dealer': 1.0,
#  'audio visual consultant': 0.7028162721020352,
#  'pallet supplier': 0.6933756053265716,
#  'wood supplier': 0.014547278280154294,
#  'hardware store': 0.0239570415260799,
#  'furniture wholesaler': 0.014547278280154294,
#  'auditor': 0.5067221467758423,
#  'oil natural gas company': 0.505942420487099,
#  'auto body shop': 0.021394318627208773,
#  'boat repair shop': 0.444933973742445,
#  'association': 0.43915562889714416,
#  'railing contractor': 0.38507261678259963,
#  'publisher': 0.9032010817412047,
#  'pond supply store': 0.06896551724137931,
#  'agriculture cooperative': 0.03739522640344854,
#  'printing equipment supplier': 0.0724886386783597,
#  'auto insurance agency': 0.025812192854352625,
#  'alternative fuel station': 0.157263588225977,
#  'auto part manufacturer': 0.025792809191106617,
#  'foundation': 0.1073183866635404,
#  'fertilizer supplier': 0.72993824606461,
#  'farming company': 0.6505176166659584,
#  'finance broker': 0.5707481425435146,
#  'agricultural cooperative': 0.03739522640344854,
#  'fire station': 0.03739522640344854,
#  'environmental consultant': 0.26766798019117366,
#  'civil engineer': 0.6989349648125436,
#  'fire protection service': 0.03739522640344854,
#  'gas company': 0.08516885643976688,
#  'oilfield': 0,
#  'banquet hall': 0.3913177061114813,
#  'mining company': 0.6273471519579988,
#  'coalfield': 0,
#  'steel fabricator': 0.7789430695539075,
#  'quarry': 0.6450538229095466,
#  'gold mining company': 0.6438894609589608,
#  'high rise building': 0.03479303924387127,
#  'basketball club': 0.30919904176883256,
#  'gold dealer': 0.014547278280154294,
#  'battery manufacturer': 0.9807100434910057,
#  'electric utility company': 0.03739522640344854,
#  'environmental program': 0.08956035666137592,
#  'office': 0.0239570415260799,
#  'stone supplier': 0.1197589944859298,
#  'aggregate supplier': 0.014056733846481465,
#  'sand gravel supplier': 0.39101152132583167,
#  'building material supplier': 0.0239570415260799,
#  'beauty supply store': 0.2517216694815243,
#  'crushed stone supplier': 0.1247028080381595,
#  'rock shop': 0.014547278280154294,
#  'road construction company': 0.5447839019311549,
#  'marketing consultant': 0.021394318627208773,
#  'blood testing service': 0.021394318627208773,
#  'contractor': 0.633205427448652,
#  'excavating contractor': 0.26103341238083183,
#  'asphalt mixing plant': 0.7351792461042505,
#  'ready mix concrete supplier': 0.1699510014489267,
#  'sand plant': 0.3917312071400989,
#  'bmw dealer': 0,
#  'bookbinder': 0.01020408163265306,
#  'garden center': 0.15313498187859803,
#  'abrasive supplier': 0.9763445137893869,
#  'granite supplier': 0.1280730279049056,
#  'drilling contractor': 0.686527427695688,
#  'bpo company': 0,
#  'oil gas exploration service': 0.505942420487099,
#  'building complex': 0.045995238117956,
#  'construction equipment supplier': 0.014547278280154294,
#  'mining equipment': 0.00532647621010794,
#  'bus ticket agency': 0.08724279165767003,
#  'business center': 0.0239570415260799,
#  'skyscraper': 0,
#  'software company': 0.762707296834603,
#  'business development service': 0.021394318627208773,
#  'business management consultant': 0.021394318627208773,
#  'cabinet maker': 0.5984973626932727,
#  'call center': 0.657266413555833,
#  'cancer treatment center': 0.4042806126143422,
#  'power plant consultant': 0.24006192174891539,
#  'business park': 0.021394318627208773,
#  'petroleum product company': 0.1718098725503,
#  'parking lot': 0.43062473737546425,
#  'water utility company': 0.24145102273170593,
#  'car repair maintenance': 0.24122558867435906,
#  'water treatment plant': 0.24145102273170593,
#  'car service': 0.26136144185173676,
#  'cattle market': 0.09058951894978126,
#  'sewage disposal service': 0.5015555662194072,
#  'certified public accountant': 0.39935861272779805,
#  'government office': 0.5708247814532948,
#  'charity': 1.0,
#  'air conditioning system supplier': 0.11283044858105375,
#  'chemical industry': 0.8519243656183907,
#  'chemical manufacturer': 0.8519243656183907,
#  'title company': 0.021394318627208773,
#  'chemical plant': 0.8519243656183907,
#  'property management company': 0.2729183583511302,
#  'custom home builder': 0.03479303924387127,
#  'window installation service': 0.07577824875869636,
#  'fire damage restoration service': 0.0239570415260799,
#  'equipment rental agency': 0.15103728472759256,
#  'chemical wholesaler': 0.09920379328361931,
#  'financial planner': 0.6335503749166084,
#  'telecommunication service provider': 0.5081798519153662,
#  'energy equipment solution': 0.0239570415260799,
#  'chiropractor': 0.9345654881488668,
#  'steel distributor': 0.014547278280154294,
#  'city government office': 0.7698798193331705,
#  'crane service': 0.3285017901501872,
#  'garage door supplier': 0.32179275872002,
#  'industrial door supplier': 0.37292424791760254,
#  'city town hall': 0.7935744299102608,
#  'clothing wholesaler': 0.2701758057294421,
#  'coin operated laundry equipment supplier': 0.4111527541056231,
#  'metal supplier': 0.07655705469832237,
#  'glass shop': 0.03479303924387127,
#  'college': 0.7041181202744449,
#  'siding contractor': 0.16433488091941104,
#  'commercial printer': 0.1334919020030731,
#  'storage facility': 0.6244187901606009,
#  'communication tower': 0.03479303924387127,
#  'janitorial service': 0.6864869380854477,
#  'computer consultant': 0.021394318627208773,
#  'fire protection system supplier': 0.03739522640344854,
#  'elevator service': 0.293355861196367,
#  'industrial equipment supplier': 0.21964631027473863,
#  'dry wall contractor': 0.03479303924387127,
#  'insulation contractor': 0.3563247136230168,
#  'concrete contractor': 0.3782937826945411,
#  'scaffolding rental service': 0.2798434332077892,
#  'construction company': 0.6485154689477213,
#  'flooring store': 0.0239570415260799,
#  'flooring contractor': 0.22169028410867953,
#  'tile contractor': 0.35602931992448156,
#  'tile manufacturer': 0.35602931992448156,
#  'glass mirror shop': 0.03479303924387127,
#  'construction material wholesaler': 0.014547278280154294,
#  'gutter cleaning service': 0.24711846824028882,
#  'sheet metal contractor': 0.605993710376087,
#  'consultant': 0.3695284583126349,
#  'container service': 0.41981586700876344,
#  'septic system service': 0.8057205221348274,
#  'corporate campus': 0.623762835118414,
#  'water damage restoration service': 0.0239570415260799,
#  'welder': 0.01485183529125322,
#  'corporate office': 0.623762835118414,
#  'animal': 0.7388469436129654,
#  'animal feed store': 0.05065501728141138,
#  'animal protection organization': 0.021394318627208773,
#  'brewing supply store': 0.013986013986013986,
#  'cosmetic store': 0.2593377539480699,
#  'county government office': 0.4995428326701289,
#  'sugar factory': 0.6754345205755689,
#  'confectionery wholesaler': 0.2650075394837718,
#  'financial institution': 0.03739522640344854,
#  'candy store': 0.0239570415260799,
#  'confectionery': 0.0239570415260799,
#  'chocolate factory': 0.7837445845868326,
#  'chocolate shop': 0.7837445845868326,
#  'courier service': 0.6823277116070922,
#  'coworking space': 0,
#  'frozen food manufacturer': 0.570146342760253,
#  'beverage distributor': 0.014547278280154294,
#  'agricultural organization': 0.03739522640344854,
#  'dairy store': 0.19011491052801935,
#  'dairy': 0.06132058872957222,
#  'ice cream shop': 0.26702835108354545,
#  'medical laboratory': 0.3135490271939764,
#  'demolition contractor': 0.6415253790640321,
#  'meat processor': 0.6314624913433112,
#  'fmcg manufacturer': 0,
#  'garbage collection service': 0.29338794836693366,
#  'wholesale bakery': 0.01413599769566148,
#  'dentist': 0.6124622004687721,
#  'dessert shop': 0.42374876811328527,
#  'cupcake shop': 0,
#  'nut store': 0.0239570415260799,
#  'wholesale grocer': 0.5233354413934641,
#  'design engineer': 0.16103989765574075,
#  'business business service': 0.0239570415260799,
#  'condiment supplier': 0.986827925971056,
#  'digital printing service': 0.5566046036549276,
#  'culinary school': 1.0,
#  'importer': 0,
#  'bottled water supplier': 0.16640441045451637,
#  'coffee roaster': 0.5984760153069322,
#  'packaging supply store': 0.12426258231465923,
#  'ice supplier': 0.41034367575629876,
#  'brewery': 0.9171495629741175,
#  'winemaking company': 0,
#  'distillery': 0.01413599769566148,
#  'disability service support organisation': 0.5403301386278315,
#  'district government office': 0.32638813404770023,
#  'air filter supplier': 0.32989242547024744,
#  'tire shop': 0.08434699454339854,
#  'fastener supplier': 0.8343515741547773,
#  'fabric product manufacturer': 0.4720017466169693,
#  'textile': 0.5900375271946684,
#  'textile exporter': 0.5900375271946684,
#  'textile engineer': 0.5900375271946684,
#  'fabric store': 0.05065501728141138,
#  'knit shop': 0.25195579160025666,
#  'doctor': 0.8688730297404473,
#  'lamination service': 0.7412383437300966,
#  'plastic resin manufacturer': 0.28992487552947993,
#  'carpet manufacturer': 0.32463561573980365,
#  'upholstery shop': 0.19212515488075507,
#  'business administration service': 0.021394318627208773,
#  'furniture store': 0.0239570415260799,
#  'dry cleaner': 0.021394318627208773,
#  'packaging company': 0.12426258231465923,
#  'duty free store': 0.05065501728141138,
#  'commerce service': 0.043478260869565216,
#  'cable company': 0.19065964802055702,
#  'education': 0.5752231578664962,
#  'outlet store': 0.05065501728141138,
#  'lingerie store': 0.3436953025046801,
#  'clothes fabric manufacturer': 0.028252973434399368,
#  'education center': 0.5752231578664962,
#  'uniform store': 0.10156400159656136,
#  'men clothing store': 0.08322849744660404,
#  'clothing store': 0.18760133808240034,
#  'woman clothing store': 0.0774844998823396,
#  'western apparel store': 0.5168539325842697,
#  'costume store': 0.2877103903945859,
#  'game store': 0.05065501728141138,
#  'hat shop': 0.24798952434135307,
#  'leather good manufacturer': 0.0239570415260799,
#  'educational consultant': 0.6571944955070329,
#  'leather exporter': 0.5966079570841738,
#  'shoe store': 0.10156400159656136,
#  'boutique': 0,
#  'leather wholesaler': 0.0239570415260799,
#  'handbag shop': 0.39978208115139363,
#  'electronics store': 0.12426258231465923,
#  'luggage store': 0.2001057478380843,
#  'building material store': 0.0239570415260799,
#  'saw mill': 0.01051632041040194,
#  'electrical engineer': 0.021394318627208773,
#  'deck builder': 0.28038739935732937,
#  'concrete product supplier': 0.5576616541702233,
#  'plywood supplier': 0.812722895420229,
#  'electrical installation service': 0.1231975350407154,
#  'truss manufacturer': 0.698974909259179,
#  'door supplier': 0.12002040732905359,
#  'wood laminate flooring supplier': 0.8923903163695349,
#  'aircraft supply store': 0.014547278280154294,
#  'modular home builder': 0.010440585775759762,
#  'portable building manufacturer': 0.44847358422068495,
#  'modular home dealer': 0.04812304135526803,
#  'mulch supplier': 1.0,
#  'electrician': 0.41049426127481037,
#  'paper mill': 0.904911851252025,
#  'energy supplier': 0.3773609820760421,
#  'engineer': 0.42379606901519745,
#  'print shop': 0.4252232053484623,
#  'custom label printer': 0.08620062803322888,
#  'marketing': 0.021394318627208773,
#  'marketing agency': 0.021394318627208773,
#  'engineering consultant': 0.12114907242749458,
#  'entertainer': 0.433082007250775,
#  'envelope supplier': 0.3301549706384365,
#  'oil refinery': 0.01055504984782632,
#  'recording studio': 0.4105835307111446,
#  'environment renewable natural resource': 0.08516885643976688,
#  'finishing material supplier': 0.0239570415260799,
#  'event ticket seller': 0.0239570415260799,
#  'waterproofing company': 0.5238095238095238,
#  'auto part store': 0.177813521187302,
#  'heating oil supplier': 0.05065501728141138,
#  'family practice physician': 0.07164615265449159,
#  'machining manufacturer': 0.7658701492144827,
#  'industrial gas supplier': 0.08127085507013015,
#  'welding supply store': 0.7409293328460761,
#  'dry ice supplier': 0.33481994698851986,
#  'private equity firm': 0.025812192854352625,
#  'family service center': 0.28642139291208907,
#  'federal government office': 0.3534826560330413,
#  'vitamin supplement store': 0.3436953025046801,
#  'feed manufacturer': 0.5305761545703841,
#  'medical equipment supplier': 0.09058951894978126,
#  'medical supply store': 0.09058951894978126,
#  'medical clinic': 0.22894715336424243,
#  'research institute': 0.5806625393727737,
#  'biochemical supplier': 0,
#  'fiber optic product supplier': 0.00532647621010794,
#  'paint manufacturer': 0.4526493730307285,
#  'equipment supplier': 0.31675465563520455,
#  'food': 0.776159044578813,
#  'pipe supplier': 0.5675432071882394,
#  'oil field equipment supplier': 0.00532647621010794,
#  'food broker': 0.014547278280154294,
#  'food manufacturer': 0.5994924450756731,
#  'food processing company': 0.776159044578813,
#  'fence supply store': 0.0239570415260799,
#  'food producer': 0.776159044578813,
#  'forestry service': 0.7993293019583756,
#  'foundry': 0.8047482327409224,
#  'wholesale jeweler': 0.44840545375799035,
#  'cookie shop': 0.7672050910432727,
#  'truck rental agency': 0.045995238117956,
#  'fruit vegetable processing': 0.2756952051356151,
#  'kitchen supply store': 0.014547278280154294,
#  'hydraulic equipment supplier': 0.014547278280154294,
#  'irrigation equipment supplier': 0.3327278940159191,
#  'bearing supplier': 0.7498479217487455,
#  'metallurgy company': 0.9969333463154176,
#  'plastic injection molding service': 0.014111868166941733,
#  'general contractor': 0.5187391748027955,
#  'general hospital': 0.027217267573504244,
#  'tool manufacturer': 0.675775127281301,
#  'industrial design company': 0.021394318627208773,
#  'hyundai dealer': 0,
#  'glass industry': 0.9677904018975994,
#  'polymer supplier': 0.013888888888888888,
#  'printing equipment supply': 0.0724886386783597,
#  'toner cartridge supplier': 0.7302557922037227,
#  'printer repair service': 0.09857513171247102,
#  'fuel supplier': 0.014547278280154294,
#  'glass manufacturer': 0.9677904018975994,
#  'plastic bag supplier': 0.7247135378904302,
#  'glassware manufacturer': 0.38850260968350536,
#  'polythene plastic sheeting supplier': 0,
#  'pvc industry': 0.7128205128205128,
#  'countertop store': 0.1353415378237015,
#  'cabinet store': 0.08724279165767003,
#  'fiberglass supplier': 0.2006890464852133,
#  'golf cart dealer': 0.0239570415260799,
#  'auto repair shop': 0.021394318627208773,
#  'hose supplier': 0.5290777723894221,
#  'rubber product supplier': 0.628675717301508,
#  'automotive': 0.014547278280154294,
#  'commercial refrigerator supplier': 0.0892978585090074,
#  'golf club': 0.2113444762888627,
#  'golf course': 0.2113444762888627,
#  'green energy supplier': 0.07429372775974477,
#  'greenhouse': 0.6543401164759842,
#  'auto glass shop': 0.021394318627208773,
#  'lighting manufacturer': 0.8678774469993338,
#  'cement manufacturer': 0.7378564975421914,
#  'brick manufacturer': 0.692634403074841,
#  'natural stone supplier': 0.014547278280154294,
#  'gym': 1.0,
#  'marble supplier': 0.13099567421789765,
#  'corporate gift supplier': 0.04812304135526803,
#  'shipbuilding repair company': 0,
#  'construction maintenance office': 0.6485154689477213,
#  'boiler manufacturer': 0.8066925622408357,
#  'container supplier': 0.41981586700876344,
#  'home construction': 0.09537041211788873,
#  'health': 0.764688790073319,
#  'heart hospital': 0.02531645569620253,
#  'spring supplier': 0.8568239870256023,
#  'electric utility manufacturer': 0.03739522640344854,
#  'aircraft manufacturer': 0.6231825632546019,
#  'metal heat treating service': 0.8364949492896679,
#  'plating service': 0.9992622220857749,
#  'automation company': 0.005249343832020997,
#  'heating contractor': 0.3889786702379128,
#  'plumbing supply store': 0.11283044858105375,
#  'gun shop': 0.2627420939154603,
#  'ammunition supplier': 0.6966837629843294,
#  'pipe manufacturer': 0.5675432071882394,
#  'school': 0.6673535127776675,
#  'fire protection equipment supplier': 0.03739522640344854,
#  'agricultural machinery manufacturer': 0.15295331958628763,
#  'lawn mower store': 0.0239570415260799,
#  'lawn irrigation equipment supplier': 0.08516885643976688,
#  'financial consultant': 0.6335503749166084,
#  'helicopter charter': 0.35058528164797814,
#  'packaging machinery': 0.00532647621010794,
#  'historical landmark': 0.42557968744659824,
#  'electronics manufacturer': 0.28891713208008285,
#  'graphic designer': 0.287619523027178,
#  'eye care center': 0.30590733686899285,
#  'optical product manufacturer': 0.6262395981881947,
#  'image consultant': 0.04279579313484615,
#  'cleaning product supplier': 0.014547278280154294,
#  'fireplace store': 0.2071030977458488,
#  'home builder': 0.09537041211788873,
#  'tool die shop': 0.6745320338007601,
#  'metal stamping service': 0.8360173938278104,
#  'environmental organization': 0.08956035666137592,
#  'food processing equipment': 0.06480675643613534,
#  'loan agency': 0.789547955134028,
#  'power plant equipment supplier': 0.014547278280154294,
#  'home good store': 0.08434699454339854,
#  'engine rebuilding service': 0.021394318627208773,
#  'air compressor supplier': 0.285254082075086,
#  'honda dealer': 0,
#  'elevator manufacturer': 0.293355861196367,
#  'crane dealer': 0.3285017901501872,
#  'crane rental agency': 0.21814748117263819,
#  'compound building': 0.03479303924387127,
#  'tractor dealer': 0.014547278280154294,
#  'furnace part supplier': 0.014547278280154294,
#  'heating equipment supplier': 0.18673065430224053,
#  'pneumatic tool supplier': 0.014547278280154294,
#  'truck stop': 0.0239570415260799,
#  'computer hardware manufacturer': 0.9375453729003616,
#  'satellite communication service': 0.7589117286254478,
#  'hospital': 0.30167442985891973,
#  'electronics company': 0.12426258231465923,
#  'electronic part supplier': 0.42460600563382206,
#  'hvac contractor': 0.5238095238095238,
#  'industrial engineer': 0.021394318627208773,
#  'contact lens supplier': 0.00532647621010794,
#  'information service': 0.7369333338876747,
#  'building': 0.5682891843476016,
#  'water work equipment supplier': 0.014547278280154294,
#  'measuring instrument supplier': 0.9348229169641536,
#  'scientific equipment supplier': 0.014547278280154294,
#  'medical center': 0.20647101817190763,
#  'watch manufacturer': 0.192717582457563,
#  'corporate entertainment service': 0.042052027045515465,
#  'insurance': 0.8516421366983987,
#  'record company': 0.5085327259159483,
#  'video duplication service': 0.5341443963452341,
#  'insurance agency': 0.8516421366983987,
#  'lighting store': 0.8678774469993338,
#  'lighting wholesaler': 0.8678774469993338,
#  'entertainment agency': 0.6015609614773135,
#  'insurance broker': 0.8516421366983987,
#  'electrical equipment supplier': 0.13406259218387234,
#  'electric motor store': 0.20442744177439298,
#  'railroad company': 0.3773435656254629,
#  'electrical supply store': 0.13406259218387234,
#  'insurance company': 0.8516421366983987,
#  'factory equipment supplier': 0.014547278280154294,
#  'investment service': 0.6863399052364827,
#  'laser equipment supplier': 0.3508372858202275,
#  'executive suite rental agency': 0.5927078982263168,
#  'truck dealer': 0.07407088846238918,
#  'motor vehicle dealer': 0.0239570415260799,
#  'car dealer': 0.0239570415260799,
#  'truck topper supplier': 0.10867763856833969,
#  'police supply store': 0.11449958904094557,
#  'iron steel contractor': 0.03479303924387127,
#  'fire department equipment supplier': 0.03739522640344854,
#  'towing equipment provider': 0.9831640391617571,
#  'logistics service': 0.7560837731727272,
#  'trailer manufacturer': 0.5442476684905098,
#  'trailer dealer': 0.12082870201973281,
#  'dealer': 0.537951797396162,
#  'auto spring shop': 0.021394318627208773,
#  'auto upholsterer': 0.025792809191106617,
#  'auto body part supplier': 0.177813521187302,
#  'car factory': 0.17145001418807504,
#  'freight forwarding service': 0.466941702391982,
#  'brake shop': 0.09857513171247102,
#  'railroad equipment supplier': 0.09920379328361931,
#  'jewelry equipment supplier': 0.8692673069552886,
#  'boat builder': 0.444933973742445,
#  'ship building': 0.5235177306431842,
#  'marine supply store': 0.0239570415260799,
#  'boat dealer': 0.24795745757185808,
#  'kawasaki motorcycle dealer': 0,
#  'knife manufacturing': 0.4161497728190836,
#  'labor union': 0.3196157363133781,
#  'furniture maker': 0.9974039129284556,
#  'banking finance': 0.5304962198397665,
#  'furniture manufacturer': 0.9956725449943076,
#  'logistics': 0.7560837731727272,
#  'massage supply store': 0.1247028080381595,
#  'telecommunication equipment supplier': 0.00532647621010794,
#  'baby store': 0.08778784020972129,
#  'molding supplier': 0.13930270782890328,
#  'office equipment supplier': 0.3802999964499482,
#  'office furniture store': 0.00532647621010794,
#  'store equipment supplier': 0.014547278280154294,
#  'laboratory': 0.1283855226638514,
#  'health beauty shop': 0.021394318627208773,
#  'learning center': 0.7124900842352783,
#  'dental laboratory': 0.3537565939440528,
#  'land surveyor': 0.09542489444368481,
#  'educational supply store': 0.05065501728141138,
#  'jewelry store': 0.0239570415260799,
#  'playground equipment supplier': 0.2971160902237764,
#  'outdoor sport store': 0.12135070949276103,
#  'toy store': 0.05065501728141138,
#  'security service': 0.0239570415260799,
#  'sign shop': 0.7446720891195652,
#  'office supply store': 0.05065501728141138,
#  'landscaper': 0,
#  'gasket manufacturer': 0.6805981594263228,
#  'piano maker': 0.2716465998288585,
#  'piano store': 0.33443426075191063,
#  'funeral home': 0.6553730630624757,
#  'monument': 0.04032504428081571,
#  'book publisher': 0.44048552483849523,
#  'wig shop': 0.3436953025046801,
#  'laundromat': 1.0,
#  'auto wrecker': 0.020946189181826974,
#  'auto part market': 0.177813521187302,
#  'jeep dealer': 0,
#  'restaurant supply store': 0.15048483342201338,
#  'roofing supply store': 0.5003951977191856,
#  'law firm': 0.22090382622778035,
#  'building material market': 0.0239570415260799,
#  'camera store': 0.36110596659875216,
#  'lawn care service': 0.11035553165111127,
#  'computer security service': 0.0239570415260799,
#  'computer store': 0.014547278280154294,
#  'design agency': 0.21598169172568782,
#  'diagnostic center': 0.5551351374152153,
#  'laboratory equipment supplier': 0.5053518984515419,
#  'home theater store': 0.054223036059456754,
#  'metal industry supplier': 0.07655705469832237,
#  'landscaping supply store': 0.02300961827666929,
#  'appliance part supplier': 0.24506960537453762,
#  'vacuum cleaner store': 0.08434699454339854,
#  'audio visual equipment supplier': 0.7028162721020352,
#  'lawyer': 0.8306404473071374,
#  'cell phone store': 0.033579508618031884,
#  'bathroom supply store': 0.1287739105207725,
#  'leasing service': 0.8677699390736283,
#  'construction machine dealer': 0.014547278280154294,
#  'dairy farm equipment supplier': 0.0681371751233718,
#  'propane supplier': 0.046598134694753365,
#  'legal service': 0.48691172427504076,
#  'janitorial equipment supplier': 0.6864869380854477,
#  'life insurance agency': 0.09055601888714586,
#  'railroad contractor': 0.41167479074802943,
#  'swimming pool supply store': 0.14199594945801153,
#  'light bulb supplier': 0.6437082429004504,
#  'linen store': 0.4166668600292181,
#  'metal construction company': 0.8381015985429763,
#  'local government office': 0.03739522640344854,
#  'logging contractor': 0.2555989002995859,
#  'machine shop': 0.6288027002333912,
#  'hotel supply store': 0.3718731563884756,
#  'import export company': 0.025812192854352625,
#  'sewing company': 0.05065501728141138,
#  'research foundation': 0.5806625393727737,
#  'machinery part manufacturer': 0.9093869774247815,
#  'sport accessory wholesaler': 0.014547278280154294,
#  'fashion designer': 0.0843325608600045,
#  'cheese manufacturer': 0.5037930911871518,
#  'cheese shop': 0.5037930911871518,
#  'shipping mailing': 0.20341748548710972,
#  'wholesale food store': 0.5233354413934641,
#  'organic food store': 0.0239570415260799,
#  'pie shop': 0.6772620578379892,
#  'auction house': 0.2627420939154603,
#  'livestock auction house': 0.2055765388650011,
#  'cotton exporter': 0.22758207412885925,
#  'plastic wholesaler': 0.014547278280154294,
#  'mailing service': 0.20341748548710972,
#  'manufacturer': 0.00532647621010794,
#  'gas station': 0.0239570415260799,
#  'beer distributor': 0.41875411951765634,
#  'alcoholic beverage wholesaler': 0.5824806722118558,
#  'religious good store': 0.7027404797102157,
#  'book wholesaler': 0.10590909855986365,
#  'masonry supply store': 0.0239570415260799,
#  'wholesale florist': 0.49043829648561793,
#  'florist': 0.6704090454881116,
#  'marine engineer': 0.02275152616190654,
#  'paint store': 0.0239570415260799,
#  'used auto part store': 0.0239570415260799,
#  'masonry contractor': 0.6200094392289581,
#  'used car dealer': 0.0239570415260799,
#  'used truck dealer': 0.0239570415260799,
#  'massage therapist': 0.15578349429569122,
#  'material handling equipment supplier': 0.07655705469832237,
#  'marina': 0.9597928220731767,
#  'meat packer': 0.3084806127178629,
#  'mattress store': 0.0239570415260799,
#  'blind shop': 0.8044745546190173,
#  'interior designer': 0.12114907242749458,
#  'window treatment store': 0.0239570415260799,
#  'appliance store': 0.0239570415260799,
#  'health food store': 0.0239570415260799,
#  'direct mail advertising': 0.021394318627208773,
#  'meat wholesaler': 0.3084806127178629,
#  'butcher shop deli': 0.40154084236526516,
#  'italian grocery store': 0.022222222222222223,
#  'market': 0.021394318627208773,
#  'food service': 0.14281298093830908,
#  'grocery delivery service': 0.20341748548710972,
#  'wine store': 0.08724279165767003,
#  'liquor store': 0.1353415378237015,
#  'kiosk': 0,
#  'optometrist': 0.44812203297658654,
#  'optician': 0.11360475324281138,
#  'mechanical contractor': 0.16430328469866723,
#  'mechanical engineer': 0.021394318627208773,
#  'cafe': 0.2361298364737614,
#  'jeweler': 0.334427636657496,
#  'leather good store': 0.0239570415260799,
#  'gift shop': 0.6815625660511855,
#  'craft store': 0.21594736537058573,
#  'hobby store': 0.07475582144437148,
#  'fabric wholesaler': 0.014547278280154294,
#  'scrap metal dealer': 0.014547278280154294,
#  'quilt shop': 0.043478260869565216,
#  'sheet music store': 0.05065501728141138,
#  'musical instrument manufacturer': 0.13038644429612936,
#  'music store': 0.13099103115794508,
#  'musical instrument store': 0.05065501728141138,
#  'band': 0.13407657712461712,
#  'bookstore': 0,
#  'art museum': 0.66114270979097,
#  'newsstand': 1.0,
#  'medical equipment manufacturer': 0.6123882249197924,
#  'fashion accessory store': 0.14768575031113965,
#  'discount store': 0.046598134694753365,
#  'cemetery': 0.30453592489685327,
#  'bus stop': 0.29505606831602854,
#  'variety store': 0.05065501728141138,
#  'thrift store': 0.5333333333333333,
#  'medical group': 0.22894715336424243,
#  'donation center': 0.02049243952774123,
#  'pet store': 0.27225613333912835,
#  'art gallery': 0.05065501728141138,
#  'art dealer': 0.05065501728141138,
#  'housing development': 0.10025810559625162,
#  'mobile home dealer': 0.12538850724408424,
#  'convenience store': 0.38410386787013345,
#  'medical office': 0.22894715336424243,
#  'medical technology manufacturer': 0.6123882249197924,
#  'childrens furniture store': 0,
#  'mental health clinic': 0.6903714258105265,
#  'airline': 0.02008093223818946,
#  'aviation consultant': 0.13520166626708474,
#  'travel agency': 0.5529265647076685,
#  'travel service': 0.5529265647076685,
#  'airport': 0.2202630705193748,
#  'mental health service': 0.6903714258105265,
#  'shipping company': 0.020946189181826974,
#  'metal fabricator': 0.8381015985429763,
#  'cruise line company': 0.0440780777042263,
#  'towing service': 0.9831640391617571,
#  'ferry terminal': 0.5346534653465347,
#  'ferry service': 0.9603960396039604,
#  'metal finisher': 0.8361897954624365,
#  'boat tour agency': 0.1493861609888398,
#  'bus company': 0.29505606831602854,
#  'moving company': 0.5269417001675027,
#  'moving storage service': 0.5269417001675027,
#  'state department transportation': 0.14833932134036837,
#  'department transportation': 0.47624780445003334,
#  'handicapped transportation service': 0.7704241361079802,
#  'railway service': 0.23027532827928807,
#  'train station': 0.07170013281957421,
#  'bus depot': 0.29254781146096914,
#  'bus charter': 0.28654777546848914,
#  'metal processing company': 0.8381015985429763,
#  'mixed use': 0.045995238117956,
#  'motorcycle shop': 0.30041128862666366,
#  'limousine service': 0.9838302736884682,
#  'chauffeur service': 0.02021832292102586,
#  'school bus service': 0.020946189181826974,
#  'airport shuttle service': 0.06878224070283845,
#  'tourist information center': 0.12316314564754814,
#  'carriage ride service': 0.38566343573292194,
#  'cruise agency': 0.21089009481388682,
#  'tourist attraction': 0.12316314564754814,
#  'ski resort': 0.11371094196671633,
#  'ski area': 0.11371094196671633,
#  'fixed base operator': 0.020946189181826974,
#  'aircraft maintenance company': 0.17056869963022028,
#  'motorsports store': 0,
#  'boat rental service': 0.045995238117956,
#  'utility trailer dealer': 0.045995238117956,
#  'forklift dealer': 0.17427611635676576,
#  'municipal administration office': 0.03431675863729318,
#  'nephrologist': 0,
#  'bus coach company': 0.28654777546848914,
#  'shipping service': 0.20341748548710972,
#  'shipping mailing service': 0.20341748548710972,
#  'newspaper publisher': 0.6357766952501898,
#  'shredding service': 0.26170536726867444,
#  'nuclear power company': 0.34086498661988857,
#  'nursing home': 0.8203144712263348,
#  'medium company': 0.1073183866635404,
#  'multimedia electronic book publisher': 0.734912660915478,
#  'internet marketing service': 0.021394318627208773,
#  'greeting card shop': 0.14199594945801153,
#  'theme park': 1.0,
#  'film production company': 0.22041199951288692,
#  'obstetrician gynecologist': 1.0,
#  'movie studio': 0.5628662851036518,
#  'video production service': 0.49756866636670777,
#  'movie theater': 0.5577431339142986,
#  'theater company': 0.3285047174754383,
#  'performing art theater': 0.4989682801859357,
#  'occupational safety health': 0.12044716427556382,
#  'office space rental agency': 0.045995238117956,
#  'commercial real estate agency': 0.045995238117956,
#  'art school': 0.06783624914519003,
#  'music publisher': 0.44344558153630353,
#  'printed music publisher': 0.12524708540599708,
#  'home audio store': 0.054223036059456754,
#  'musician': 1.0,
#  'music management promotion': 0.0439727031651832,
#  'video editing service': 0.5341443963452341,
#  'office supply wholesaler': 0.4406537667147636,
#  'official residence': 0.04081632653061224,
#  'orthopedic clinic': 0.20811475199172694,
#  'painter': 0.03211274780601464,
#  'painting': 0.6049433151301511,
#  'telephone company': 0.18876873794679966,
#  'medium house': 0.1073183866635404,
#  'paper distributor': 0.09058951894978126,
#  'news service': 0.11449958904094557,
#  'public library': 0.03479303924387127,
#  'law library': 0.5728329066552857,
#  'museum': 0.7637857581251511,
#  'federal reserve bank': 0.17809667553722025,
#  'credit union': 0.8767894033305724,
#  'atm': 0.3454822335156774,
#  'paving contractor': 0.32717728625789955,
#  'mortgage lender': 0.48098606215933387,
#  'investment bank': 0.6253574754919913,
#  'check cashing service': 0.7043931085954033,
#  'stock broker': 0.025812192854352625,
#  'health consultant': 0.021394318627208773,
#  'health insurance agency': 0.025812192854352625,
#  'payroll service': 0.7802671942556128,
#  'pediatrician': 1.0,
#  'human resource consulting': 0.4530128062312359,
#  'pest control service': 0.5818417637707372,
#  'pet boarding service': 0.3894259502881483,
#  'pet care': 0.3894259502881483,
#  'loss adjuster': 0.8774581677086933,
#  'pharmaceutical company': 0.8049163650744168,
#  'pharmaceutical product wholesaler': 0.09058951894978126,
#  'pharmacy': 0.18623885441105165,
#  'educational institution': 0.6367022813442303,
#  'retirement community': 0.4860514665268807,
#  'fraternal organization': 0.5151515151515151,
#  'photo lab': 0.02049243952774123,
#  'property investment': 0.270283291114844,
#  'photographer': 0.5050505050505051,
#  'photography school': 0.4163417112242586,
#  'star hotel': 0,
#  'convention center': 0.4428344146111926,
#  'real estate appraiser': 0.8232487657608085,
#  'photography service': 0.4163417112242586,
#  'resort hotel': 0.21984386861842378,
#  'real estate consultant': 0.8989739059351857,
#  'car rental agency': 0.18787340576973796,
#  'car leasing service': 0.18712215545530753,
#  'ford dealer': 0,
#  'car finance loan company': 0.025812192854352625,
#  'trailer rental service': 0.12082870201973281,
#  'furniture rental service': 0.045995238117956,
#  'tuxedo shop': 0.2798434332077892,
#  'dress tuxedo rental service': 0.11837919621732351,
#  'wedding store': 0.02319051255098624,
#  'video store': 0.0239570415260799,
#  'movie rental': 0.5747855599712666,
#  'photography studio': 0.4163417112242586,
#  'home health care service': 0.044483290982946413,
#  'skateboard shop': 1.0,
#  'event technology service': 0.0239570415260799,
#  'party equipment rental service': 0.21876363574192503,
#  'construction machine rental service': 0.045995238117956,
#  'audio visual equipment rental service': 0.7028162721020352,
#  'shipping equipment industry': 0.058843918415770954,
#  'physical therapy clinic': 0.18378110878262063,
#  'plastic fabrication company': 0.7524635317152881,
#  'plastic product supplier': 0.7524635317152881,
#  'auto tag agency': 0.03739522640344854,
#  'department motor vehicle': 0.47624780445003334,
#  'notary public': 0.8790210933217081,
#  'private investigator': 0.0239570415260799,
#  'escrow service': 0.6362703965756433,
#  'real estate agent': 0.8989739059351857,
#  'playground': 0.04088292987557831,
#  'plumber': 0.1340338566239383,
#  'port authority': 0.7229618105935918,
#  'portrait studio': 0.2825576145374578,
#  'post office': 0.2999465409578997,
#  'professional service': 0.6424366876600714,
#  'university hospital': 0.027217267573504244,
#  'public relation firm': 0.021394318627208773,
#  'civil engineering company': 0.6989349648125436,
#  'drafting service': 0.5241581057183251,
#  'pump supplier': 0.9169567893826623,
#  'interior construction contractor': 0.05292384186090035,
#  'carpet cleaning service': 0.2697330927232545,
#  'exhibition planner': 0.0239570415260799,
#  'decal supplier': 0,
#  'stage lighting equipment supplier': 0.00532647621010794,
#  'event management company': 0.0239570415260799,
#  'radio broadcaster': 0.1276746420060354,
#  'computer support service': 0.021394318627208773,
#  'ravine': 0,
#  'employment center': 0.5766061029914185,
#  'national health foundation': 0.021394318627208773,
#  'real estate developer': 0.03479303924387127,
#  'advertising agency': 0.1003041770279215,
#  'promotional product supplier': 0.02,
#  'advertising service': 0.1003041770279215,
#  'record storage facility': 0.045995238117956,
#  'fund management company': 0.4494656368289822,
#  'recreation center': 0.7360844943149056,
#  'bakery': 0.681397307980153,
#  'database management company': 0.31247110082896545,
#  'market researcher': 0.021394318627208773,
#  'recycling center': 0.014124596056035483,
#  'regional government office': 0.1864406779661017,
#  'rehabilitation center': 0.15899699211351132,
#  'religious institution': 0.7027404797102157,
#  'religious organization': 0.7027404797102157,
#  'repair service': 0.4020910234229381,
#  'emergency veterinarian service': 0.021394318627208773,
#  'pet sitter': 0.3894259502881483,
#  'research product development': 0.5806625393727737,
#  'building society': 0.5682891843476016,
#  'valet parking service': 0.7474278351594896,
#  'nursing agency': 0.8203144712263348,
#  'executive search firm': 0.4206198619172799,
#  'recruiter': 0,
#  'temp agency': 0,
#  'health center': 0.6931189359283341,
#  'restaurant': 0.4188241274534948,
#  'roofing contractor': 0.1761701498807268,
#  'sport nutrition store': 0.0239570415260799,
#  'credit reporting agency': 0.0239570415260799,
#  'automobile storage facility': 0.20341748548710972,
#  'debt collection agency': 0.25165583836553357,
#  'park': 0.021394318627208773,
#  'court reporter': 0.4382559463739368,
#  'bus tour agency': 0.08292785414869797,
#  'tour operator': 0.5288122412222338,
#  'convention information bureau': 0.4428344146111926,
#  'balloon ride tour agency': 0.4990456588369781,
#  'security guard service': 0.0239570415260799,
#  'locksmith': 0.7718156001912975,
#  'commercial cleaning service': 0.0239570415260799,
#  'blast cleaning service': 0.023375372728297452,
#  'conference center': 0.41804785976943154,
#  'safety equipment supplier': 0.014547278280154294,
#  'garbage dump': 0.2879605720271646,
#  'sanitation service': 0.16461138973253694,
#  'garbage dump service': 0.29338794836693366,
#  'environmental health service': 0.26766798019117366,
#  'portable toilet supplier': 0.0239570415260799,
#  'public work department': 0.532741136579011,
#  'school district office': 0.6673535127776675,
#  'sailmaker': 0,
#  'community college': 0.06783624914519003,
#  'salvage yard': 0.2117431797174841,
#  'business school': 0.06783624914519003,
#  'trade school': 0.06783624914519003,
#  'private university': 0.06783624914519003,
#  'computer training school': 0.06783624914519003,
#  'school supply store': 0.014547278280154294,
#  'screen printer': 0.6706455830649932,
#  'medium consultant': 0.1073183866635404,
#  'beauty school': 0.06783624914519003,
#  'flight school': 0.456753520586574,
#  'seaport': 0.020946189181826974,
#  'security system supplier': 0.0239570415260799,
#  'middle school': 1.0,
#  'nonprofit': 0,
#  'shooting range': 0.27266224123746,
#  'soccer club': 0.427288641133993,
#  'camp': 0.5776520199581306,
#  'diving contractor': 0.3436953025046801,
#  'language school': 0.7268163610089875,
#  'english language school': 0.05714285714285714,
#  'preschool': 0.5189873417721519,
#  'self storage facility': 0.6632873639187739,
#  'semi conductor supplier': 0.15399568936041008,
#  'driving school': 0.41676229561485995,
#  'trucking school': 0.06478142853773612,
#  'senior citizen center': 0.1954302651035053,
#  'service': 0.1127256908397368,
#  'childrens hospital': 0,
#  'dental supply store': 0.3567976911598799,
#  'shipyard': 0.38951842447626256,
#  'orthodox synagogue': 0,
#  'short term apartment rental agency': 0.16580528224833752,
#  'nutritionist': 1.0,
#  'ophthalmologist': 0.2277400953864549,
#  'ophthalmology clinic': 0.8481012658227848,
#  'social service organization': 0.7361038910984106,
#  'social welfare center': 0.7361038910984106,
#  'solar energy company': 0.5392291858397629,
#  'solar energy equipment supplier': 0.5392291858397629,
#  'special education school': 0.06783624914519003,
#  'podiatrist': 1.0,
#  'reproductive health clinic': 0.5189873417721519,
#  'sporting good store': 0.14199594945801153,
#  'dialysis center': 0.8826564732573894,
#  'sport complex': 0.5305545961237076,
#  'wellness program': 0.023809523809523808,
#  'sportswear store': 0.043478260869565216,
#  'private hospital': 0.2173859631578477,
#  'radiologist': 0.95,
#  'medical diagnostic imaging center': 0.31287083633692925,
#  'ray lab': 0.4729920758043497,
#  'blood bank': 0.3527477312236175,
#  'stainless steel plant': 0.6737560530868589,
#  'state agency': 0.10750207954964741,
#  'heliport': 0,
#  'health care company': 0.6931189359283341,
#  'psychiatric hospital': 0.7772048992246441,
#  'state government office': 0.10750207954964741,
#  'medical institution': 0.20647101817190763,
#  'steel construction company': 0.1231975350407154,
#  'cleaning service': 0.38233973447642877,
#  ...}
