# %% [markdown]
# ## Pt 4 - Our first Recommender System - Bag Of Words
# With the data finallly prepared, I began exploring different methods for building a Recommender system, starting with the Bag of Words approach. When looking at the dataset, I noticed that each class code had several indicative words that might help determine which class it belongs to, so that is why I chose to test out this approach. However, I know that there are a lot of filler words that are difficult to parse out, as well as semantic terms like "musical instrument store", rather than just "musical", "instrument", and "store."

# %% [markdown]
# #### Load in and process data from previous steps

# %%
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from nltk import word_tokenize
import json
import pandas as pd
import re
stop_words = set(stopwords.words("english"))

PATTERN_S = re.compile("\'s")  # matches `'s` from text  
PATTERN_RN = re.compile("\\r\\n\\b") #matches `\r` and `\n`
PATTERN_PUNC = re.compile(r"[^\w\s]") # matches all non 0-9 A-z whitespace 

def clean_text(text):
    """
    Series of cleaning. String to lower case, remove non words characters and numbers (punctuation, curly brackets etc).
        text (str): input text
    return (str): modified initial text
    """
    text = text.lower()  # lowercase text
    # replace the matched string with ' '
    text = re.sub(PATTERN_S, ' ', text)
    text = re.sub(PATTERN_RN, ' ', text)
    text = re.sub(PATTERN_PUNC, ' ', text)
    return text

def tokenizer(description, stop_words, normalization):
    
    if normalization == 'lemmatize':
        # tokenize and lemmatize text
        lemmatizer = WordNetLemmatizer()
        tokens = [lemmatizer.lemmatize(w) for w in word_tokenize(description)]
        
    elif normalization == 'stem':
        # tokenize and stem text
        stemmer = PorterStemmer()
        tokens = [stemmer.stem(w) for w in word_tokenize(description)]
    
   # remove tokens length of 2 or below and make all lowercase and remove stop words
    tokens = [w.lower() for w in tokens if (w.lower() not in stop_words) and (len(w) > 2) and(w.isalpha())]
    
    return tokens    
    
def process_query(query, normalization):
    
    stop_words = set(stopwords.words("english"))
    
    return tokenizer(clean_text(query), stop_words, normalization)

# %%
# this function returns the top n_rank docs based on word count from the inverted index
def retrieve_n_rank_docs(inverted_index, query, normalization, max_docs=-1):
    ret_docs = {}
    
    counts = {}
    query = process_query(query, normalization)
    
    for word in query:
        try:
            docs = inverted_index.get(word)
            for k, v in docs.items():
                if k in counts:
                    counts[k] += v
                else:
                    counts[k] = v

        except:
            pass
        break
    counts = sorted(counts.items(), key=lambda x: (x[1], -int(x[0][1:])), reverse=True)
    if max_docs > -1:
        ret_docs[' '.join(query)] = [x[0] for x in counts][:max_docs]
    else:
        ret_docs[' '.join(query)] = [x[0] for x in counts]
        
    return ret_docs

# %%
# IMPORT INVERTED_INDEXES
with open(r'assets/inverted_index_stem.json') as f:
    inverted_index_stem = json.load(f)
    
with open(r'assets/inverted_index_lem.json') as f:
    inverted_index_lem = json.load(f)

# %% [markdown]
# The [6-digit_2017_Codes.xlsx](https://www.census.gov/naics/2017NAICS/6-digit_2017_Codes.xlsx) file provides a NAICS code with the official "Title" of that NAICS code, rather than the description of the NAICS codes we collected before. We will use this file to neatly display class codes/titles so we know what industry we're looking at when exploring the data.

# %%
naics_titles = pd.read_excel('assets/6-digit_2017_Codes.xlsx')
naics_titles['naics'] = naics_titles['naics'].astype(str)

# %%
naics_titles.head()
# Out:
#     naics                              title Unnamed: 2
# 0  111110                    Soybean Farming        NaN
# 1  111120  Oilseed (except Soybean) Farming         NaN
# 2  111130          Dry Pea and Bean Farming         NaN
# 3  111140                      Wheat Farming        NaN
# 4  111150                      Corn Farming         NaN

# %% [markdown]
# ### Text Normalization
# There are two popular methods of normalizing text - lemmatization and stemming. Lemmatization takes the morphological base of a word. For example, studies and "studying", would be lemmatized to "study". Stemming takes the root of the word, for example, "studies" would become "studi" and "studying" would become "study". There are certain cases where one is more useful than the other, so I decided to try them both out. They produced very similar results, with lemmatizing getting a slightly higher score for Mean Average Precision.

# %%
# Here we display the results of the query "Home improvement store" using stemming on a BoW model
stem_df = pd.DataFrame(retrieve_n_rank_docs(inverted_index_lem, 'Home improvement store', 'stem'))
stem_df.columns.values[0] = 'naics'
stem_df = stem_df.merge(naics_titles, on='naics', how='outer')
stem_df[['naics', 'title']].head(10)
# Out:
#     naics                                              title
# 0  321999  All Other Miscellaneous Wood Product Manufactu...
# 1  453998  All Other Miscellaneous Store Retailers (excep...
# 2  423220              Home Furnishing Merchant Wholesalers
# 3  454390               Other Direct Selling Establishments
# 4  333111        Farm Machinery and Equipment Manufacturing
# 5  321920            Wood Container and Pallet Manufacturing
# 6  423390  Other Construction Material Merchant Wholesalers
# 7  623990                 Other Residential Care Facilities
# 8  236117                     New Housing For-Sale Builders
# 9  442299                 All Other Home Furnishings Stores

# %%
# Here we display the results of the query "musical instrument store" using stemming on a BoW model
stem_df = pd.DataFrame(retrieve_n_rank_docs(inverted_index_lem, 'musical instrument store', 'stem'))
stem_df.columns.values[0] = 'naics'
stem_df = stem_df.merge(naics_titles, on='naics', how='outer')
stem_df[['naics', 'title']].head(10)
# Out:
#     naics                                              title
# 0  453998  All Other Miscellaneous Store Retailers (excep...
# 1  511199                              All Other Publishers
# 2  611610                                 Fine Arts Schools
# 3  512230                                   Music Publishers
# 4  511120                             Periodical Publishers
# 5  511130                                   Book Publishers
# 6  621340  Offices of Physical, Occupational and Speech T...
# 7  453310                           Used Merchandise Stores
# 8  512290                   Other Sound Recording Industries
# 9  511140             Directory and Mailing List Publishers

# %% [markdown]
# At a high-level glance, these results don't seem too relevant to our queries. There are a few that seem relevant, but should probably be higher up on the list. Let's give lemmatization a try!

# %%
# Here we display the results of the query "musical instrument store" using lemmatize on a BoW model
lem_df = pd.DataFrame(retrieve_n_rank_docs(inverted_index_lem, 'Home improvement store', 'lemmatize'))
lem_df.columns.values[0] = 'naics'
lem_df = lem_df.merge(naics_titles, on='naics', how='outer')
lem_df[['naics', 'title']].head(10)
# Out:
#     naics                                              title
# 0  321999  All Other Miscellaneous Wood Product Manufactu...
# 1  453998  All Other Miscellaneous Store Retailers (excep...
# 2  423220              Home Furnishing Merchant Wholesalers
# 3  454390               Other Direct Selling Establishments
# 4  333111        Farm Machinery and Equipment Manufacturing
# 5  321920            Wood Container and Pallet Manufacturing
# 6  423390  Other Construction Material Merchant Wholesalers
# 7  623990                 Other Residential Care Facilities
# 8  236117                     New Housing For-Sale Builders
# 9  442299                 All Other Home Furnishings Stores

# %%
lem_df = pd.DataFrame(retrieve_n_rank_docs(inverted_index_lem, 'musical instrument store', 'lemmatize'))
lem_df.columns.values[0] = 'naics'
lem_df = lem_df.merge(naics_titles, on='naics', how='outer')
lem_df[['naics', 'title']].head(10)
# Out:
#     naics                                              title
# 0  711510      Independent Artists, Writers, and Performers
# 1  711130                        Musical Groups and Artists
# 2  711310  Promoters of Performing Arts, Sports, and Simi...
# 3  711320  Promoters of Performing Arts, Sports, and Simi...
# 4  711110             Theater Companies and Dinner Theaters
# 5  711219                            Other Spectator Sports
# 6  339992                  Musical Instrument Manufacturing
# 7  711410  Agents and Managers for Artists, Athletes, Ent...
# 8  711211                            Sports Teams and Clubs
# 9  339999             All Other Miscellaneous Manufacturing

# %% [markdown]
# There wasn't really any difference for "Home improvement store" with lemmatizing, but it looks like there are some new results for "musical instrument store". This makes intuitive sense, as lemmatization is keeping the word "musical" rather than just taking the stem "music".
# The results returned for the stemming example show industries that are broadly related to "music," however, the lemmatized example shows industries that are broadly related to things that are "musical". This clearly demonstrates the significance of lemmatizing vs. stemming words in NLP.

# %% [markdown]
# #### Testing
# Finally, we will test different metrics of our recommender system to see how it performs across queries. We will measure Precision and Recall at N, Mean Average Precision at N (mAP@N), and Normalized Discounted Cumulative Gain (NDCG).
#
# The maximum documents returned will be 10, due to the nature of how this recommender system should work. I thought for awhile about increasing the number of documents, but from a functional perspective, returning more than 10 documents to a user defeats the purpose of the Recommender system. You might as well just return all documents to the user, as they are only likely to read through the first few results anyway.
#
# I also experimented with different values for N, but I ultimately concluded that 10 is the ideal number for N, to match the max_docs returned. In the case of this recommender system, N = 10 works because order is not of utmost importance. As long as the retrieved documents contain relevant documents, then the "goal" of this recommender system is complete. There is certainly room for improvemenent in that area, but as I said earlier, there is not always a single best matched NAICS code to a query, and therefore the cutoff should be measured within the range of the max docs returned.

# %%
# load the relevance judgments from Pt 3
relevance_judgments = pd.read_pickle('assets/relevant_naics_df.pkl')
relevance_judgments = dict(zip(relevance_judgments['query'], relevance_judgments['relevant_naics']))

# %%
relevance_judgments
# Out:
# {'Home improvement store': ['444110', '444120', '444130', '444190'],
#  'Diesel fuel supplier': ['424710', '424720'],
#  'Church': ['813110'],
#  'Farm': ['115116', '115111', '115112', '115113', '115114', '115115'],
#  'Seed supplier': ['424910', '424920', '424930', '424940', '424950', '424990'],
#  'Accountant': ['541219', '541211', '541213', '541214'],
#  'Trucking company': ['484110', '484121', '484122'],
#  'Exporter': ['522293',
#   '522291',
#   '522292',
#   '522294',
#   '522298',
#   '522210',
#   '522220'],
#  'Grain elevator': ['493130', '493110', '493120', '493190'],
#  'Popcorn store': ['445299', '445291', '445292', '445210', '445220', '445230'],
#  'Agricultural service': ['115116',
#   '115111',
#   '115112',
#   '115113',
#   '115114',
#   '115115'],
#  'Warehouse': ['493110', '493120', '493130', '493190'],
#  'Agricultural production': ['111998',
#   '111991',
#   '111992',
#   '111910',
#   '111920',
#   '111930',
#   '111940'],
#  'Ranch': ['112130', '112111', '112112', '112120'],
#  'Holding company': ['551112', '551111', '551114'],
#  'Farm equipment supplier': ['423820',
#   '423810',
#   '423830',
#   '423840',
#   '423850',
#   '423860'],
#  'Store': ['452319', '452311'],
#  'Grocery store': ['445110', '445120'],
#  'Rice mill': ['311212',
#   '311211',
#   '311213',
#   '311221',
#   '311224',
#   '311225',
#   '311230'],
#  'Food products supplier': ['424490',
#   '424410',
#   '424420',
#   '424430',
#   '424440',
#   '424450',
#   '424460',
#   '424470',
#   '424480'],
#  'Accounting firm': ['541219', '541211', '541213', '541214'],
#  'Produce market': ['445230',
#   '445210',
#   '445220',
#   '445291',
#   '445292',
#   '445299'],
#  'Pet supply store': ['453910', '453920', '453930', '453991', '453998'],
#  'Wholesaler': ['425120', '425110'],
#  'Produce wholesaler': ['424480',
#   '424410',
#   '424420',
#   '424430',
#   '424440',
#   '424450',
#   '424460',
#   '424470',
#   '424490'],
#  'Distribution service': ['541614',
#   '541611',
#   '541612',
#   '541613',
#   '541618',
#   '541620',
#   '541690'],
#  'Crop grower': ['111998',
#   '111991',
#   '111992',
#   '111910',
#   '111920',
#   '111930',
#   '111940'],
#  'Addiction treatment center': ['623220', '623210'],
#  'Natural goods store': ['446191', '446199', '446110', '446120', '446130'],
#  'Orchard': ['111331',
#   '111332',
#   '111333',
#   '111334',
#   '111335',
#   '111336',
#   '111339',
#   '111310',
#   '111320'],
#  'Lumber store': ['423310', '423320', '423330', '423390'],
#  'Mine': ['212299', '212291', '212210', '212221', '212222', '212230'],
#  'Transportation service': ['485999', '485991'],
#  'Investment company': ['523110', '523120', '523130', '523140'],
#  'Fruit wholesaler': ['424480',
#   '424410',
#   '424420',
#   '424430',
#   '424440',
#   '424450',
#   '424460',
#   '424470',
#   '424490'],
#  'Real estate agency': ['531210'],
#  'Event venue': ['561920', '561910', '561990'],
#  'Frozen dessert supplier': ['311520', '311511', '311512', '311513', '311514'],
#  'Wine wholesaler and importer': ['424820', '424810'],
#  'Winery': ['312130', '312111', '312112', '312113', '312120', '312140'],
#  'Aerospace company': ['336411',
#   '336412',
#   '336413',
#   '336414',
#   '336415',
#   '336419'],
#  'Cold storage facility': ['493120', '493110', '493130', '493190'],
#  'Employment agency': ['561311', '561312', '561320', '561330'],
#  'Plant nursery': ['444220', '444210'],
#  'Air conditioning contractor': ['238220', '238210', '238290'],
#  'Air conditioning repair service': ['238220', '238210', '238290'],
#  'Fruit and vegetable wholesaler': ['445230',
#   '445210',
#   '445220',
#   '445291',
#   '445292',
#   '445299'],
#  'Aircraft rental service': ['532411', '532412', '532420', '532490'],
#  'Monastery': ['813110'],
#  'Allergist': ['621111', '621112'],
#  'Herb shop': ['446191', '446199', '446110', '446120', '446130'],
#  'Aluminum supplier': ['331313', '331314', '331315', '331318'],
#  'Ambulance service': ['621910', '621991', '621999'],
#  'Wholesale plant nursery': ['424930',
#   '424910',
#   '424920',
#   '424940',
#   '424950',
#   '424990'],
#  'Amusement machine supplier': ['713120', '713110'],
#  'Animal hospital': ['541940',
#   '541910',
#   '541921',
#   '541922',
#   '541930',
#   '541990'],
#  'Farmers market': ['445230',
#   '445210',
#   '445220',
#   '445291',
#   '445292',
#   '445299'],
#  'Vaporizer store': ['453991', '453998', '453910', '453920', '453930'],
#  'Cigar shop': ['453991', '453998', '453910', '453920', '453930'],
#  'Tobacco shop': ['453991', '453998', '453910', '453920', '453930'],
#  'Well drilling contractor': ['213111',
#   '213112',
#   '213113',
#   '213114',
#   '213115'],
#  'Library': ['519120', '519110', '519130', '519190'],
#  'Apartment building': ['531110', '531120', '531130', '531190'],
#  'Apartment rental agency': ['531110', '531120', '531130', '531190'],
#  'Dairy farm': ['112120', '112111', '112112', '112130'],
#  'Architect': ['541310',
#   '541320',
#   '541330',
#   '541340',
#   '541350',
#   '541360',
#   '541370',
#   '541380'],
#  'Organic farm': ['111998',
#   '111991',
#   '111992',
#   '111910',
#   '111920',
#   '111930',
#   '111940'],
#  'Architectural designer': ['541310',
#   '541320',
#   '541330',
#   '541340',
#   '541350',
#   '541360',
#   '541370',
#   '541380'],
#  'Architecture firm': ['541310',
#   '541320',
#   '541330',
#   '541340',
#   '541350',
#   '541360',
#   '541370',
#   '541380'],
#  'Livestock producer': ['112111', '112112', '112120', '112130'],
#  'Dairy supplier': ['424430',
#   '424410',
#   '424420',
#   '424440',
#   '424450',
#   '424460',
#   '424470',
#   '424480',
#   '424490'],
#  'Biotechnology company': ['541714', '541713', '541715', '541720'],
#  'Artist': ['711510'],
#  'Egg supplier': ['112310', '112320', '112330', '112340', '112390'],
#  'Poultry farm': ['311615', '311611', '311612', '311613'],
#  'Chicken hatchery': ['112340', '112310', '112320', '112330', '112390'],
#  'Arts organization': ['711190', '711110', '711120', '711130'],
#  'Association or organization': ['813910',
#   '813920',
#   '813930',
#   '813940',
#   '813990'],
#  'Food store': ['445110', '445120'],
#  'Deli': ['722513', '722511', '722514', '722515'],
#  'Bank': ['522110', '522120', '522130', '522190'],
#  'Fish processing': ['311710'],
#  'Fish farm': ['112511', '112512', '112519'],
#  'Seafood wholesaler': ['424460',
#   '424410',
#   '424420',
#   '424430',
#   '424440',
#   '424450',
#   '424470',
#   '424480',
#   '424490'],
#  'Tropical fish store': ['453910', '453920', '453930', '453991', '453998'],
#  'Non-profit organization': ['813410'],
#  'Economic development agency': ['926110',
#   '926120',
#   '926130',
#   '926140',
#   '926150'],
#  'Seafood market': ['445220',
#   '445210',
#   '445230',
#   '445291',
#   '445292',
#   '445299'],
#  'Honey farm': ['112910', '112920', '112930', '112990'],
#  'Horse breeder': ['112920', '112910', '112930', '112990'],
#  'Asphalt contractor': ['238990', '238910'],
#  'Livestock dealer': ['424520', '424510', '424590'],
#  'Department store': ['452210'],
#  'Mill': ['321113', '321114'],
#  'ATV dealer': ['441228', '441222', '441210'],
#  'Audio visual consultant': ['334310'],
#  'Pallet supplier': ['321920',
#   '321911',
#   '321912',
#   '321918',
#   '321991',
#   '321992',
#   '321999'],
#  'Wood supplier': ['423310', '423320', '423330', '423390'],
#  'Hardware store': ['444130', '444110', '444120', '444190'],
#  'Furniture wholesaler': ['423210', '423220'],
#  'Auditor': ['541211', '541213', '541214', '541219'],
#  'Oil & natural gas company': ['213111',
#   '213112',
#   '213113',
#   '213114',
#   '213115'],
#  'Auto body shop': ['811111',
#   '811112',
#   '811113',
#   '811118',
#   '811121',
#   '811122',
#   '811191',
#   '811192',
#   '811198'],
#  'Boat repair shop': ['336611', '336612'],
#  'Association': ['813910', '813920', '813930', '813940', '813990'],
#  'Railing contractor': ['332323',
#   '332321',
#   '332322',
#   '332311',
#   '332312',
#   '332313'],
#  'Publisher': ['511130', '511110', '511120', '511140', '511191', '511199'],
#  'Pond supply store': ['221310', '221320', '221330'],
#  'Agriculture cooperative': ['926140', '926110', '926120', '926130', '926150'],
#  'Printing equipment supplier': ['333244',
#   '333241',
#   '333242',
#   '333243',
#   '333249'],
#  'Auto insurance agency': ['524210', '524291', '524292', '524298'],
#  'Alternative fuel station': ['447190', '447110'],
#  'Auto parts manufacturer': ['336390',
#   '336310',
#   '336320',
#   '336330',
#   '336340',
#   '336350',
#   '336360',
#   '336370'],
#  'Foundation': ['813211', '813212', '813219'],
#  'Fertilizer supplier': ['325311', '325312', '325314', '325320'],
#  'Farming company': ['115116',
#   '115111',
#   '115112',
#   '115113',
#   '115114',
#   '115115'],
#  'Finance broker': ['522310', '522320', '522390'],
#  'Agricultural cooperative': ['926140',
#   '926110',
#   '926120',
#   '926130',
#   '926150'],
#  'Fire station': ['922160',
#   '922110',
#   '922120',
#   '922130',
#   '922140',
#   '922150',
#   '922190'],
#  'Environmental consultant': ['541620',
#   '541611',
#   '541612',
#   '541613',
#   '541614',
#   '541618',
#   '541690'],
#  'Civil engineer': ['237990'],
#  'Fire protection service': ['922160',
#   '922110',
#   '922120',
#   '922130',
#   '922140',
#   '922150',
#   '922190'],
#  'Gas company': ['221210'],
#  'Oilfield': ['213111', '213112', '213113', '213114', '213115'],
#  'Banquet hall': ['722320', '722310', '722330'],
#  'Mining company': ['212299',
#   '212291',
#   '212210',
#   '212221',
#   '212222',
#   '212230'],
#  'Coalfield': ['212112', '212111', '212113'],
#  'Steel fabricator': ['332312',
#   '332311',
#   '332313',
#   '332321',
#   '332322',
#   '332323'],
#  'Quarry': ['212311',
#   '212312',
#   '212313',
#   '212319',
#   '212321',
#   '212322',
#   '212324',
#   '212325',
#   '212391',
#   '212392',
#   '212393',
#   '212399'],
#  'Gold mining company': ['212221',
#   '212222',
#   '212210',
#   '212230',
#   '212291',
#   '212299'],
#  'High-rise building': ['236220', '236210'],
#  'Basketball club': ['711211', '711212', '711219'],
#  'Gold dealer': ['423940', '423910', '423920', '423930', '423990'],
#  'Battery manufacturer': ['335911',
#   '335912',
#   '335921',
#   '335929',
#   '335931',
#   '335932',
#   '335991',
#   '335999'],
#  'Electric utility company': ['926130',
#   '926110',
#   '926120',
#   '926140',
#   '926150'],
#  'Environmental program': ['813312', '813311', '813319'],
#  'Office': ['561110'],
#  'Stone supplier': ['423320', '423310', '423330', '423390'],
#  'Aggregate supplier': ['423320', '423310', '423330', '423390'],
#  'Sand & gravel supplier': ['212321',
#   '212322',
#   '212324',
#   '212325',
#   '212311',
#   '212312',
#   '212313',
#   '212319',
#   '212391',
#   '212392',
#   '212393',
#   '212399'],
#  'Building materials supplier': ['444190', '444110', '444120', '444130'],
#  'Beauty supply store': ['446120', '446110', '446130', '446191', '446199'],
#  'Crushed stone supplier': ['423320', '423310', '423330', '423390'],
#  'Rock shop': ['423940', '423910', '423920', '423930', '423990'],
#  'Road construction company': ['237310'],
#  'Marketing consultant': ['541613',
#   '541611',
#   '541612',
#   '541614',
#   '541618',
#   '541620',
#   '541690'],
#  'Blood testing service': ['541380',
#   '541310',
#   '541320',
#   '541330',
#   '541340',
#   '541350',
#   '541360',
#   '541370'],
#  'Contractor': ['238990', '238910'],
#  'Excavating contractor': ['238910', '238990'],
#  'Asphalt mixing plant': ['324121', '324122', '324110', '324191', '324199'],
#  'Ready mix concrete supplier': ['327320',
#   '327310',
#   '327331',
#   '327332',
#   '327390'],
#  'Sand plant': ['212322',
#   '212321',
#   '212324',
#   '212325',
#   '212311',
#   '212312',
#   '212313',
#   '212319',
#   '212391',
#   '212392',
#   '212393',
#   '212399'],
#  'BMW dealer': ['441120', '441110'],
#  'Bookbinder': ['323117', '323111', '323113', '323120'],
#  'Garden center': ['444220', '444210'],
#  'Abrasives supplier': ['327910', '327991', '327992', '327993', '327999'],
#  'Granite supplier': ['327991', '327992', '327993', '327999', '327910'],
#  'Drilling contractor': ['213111', '213112', '213113', '213114', '213115'],
#  'BPO company': ['561421',
#   '561422',
#   '561410',
#   '561431',
#   '561439',
#   '561440',
#   '561450',
#   '561491',
#   '561492',
#   '561499'],
#  'Oil and gas exploration service': ['213111',
#   '213112',
#   '213113',
#   '213114',
#   '213115'],
#  'Building complex': ['531110', '531120', '531130', '531190'],
#  'Construction equipment supplier': ['423810',
#   '423820',
#   '423830',
#   '423840',
#   '423850',
#   '423860'],
#  'Mining equipment': ['333131', '333132', '333111', '333112', '333120'],
#  'Bus ticket agency': ['561599', '561591', '561510', '561520'],
#  'Business center': ['561439',
#   '561431',
#   '561410',
#   '561421',
#   '561422',
#   '561440',
#   '561450',
#   '561491',
#   '561492',
#   '561499'],
#  'Skyscraper': ['236220', '236210'],
#  'Software company': ['511210'],
#  'Business development service': ['541611',
#   '541612',
#   '541613',
#   '541614',
#   '541618',
#   '541620',
#   '541690'],
#  'Business management consultant': ['541611',
#   '541612',
#   '541613',
#   '541614',
#   '541618',
#   '541620',
#   '541690'],
#  'Cabinet maker': ['337110', '337121', '337122', '337124', '337125', '337127'],
#  'Call center': ['561421',
#   '561422',
#   '561410',
#   '561431',
#   '561439',
#   '561440',
#   '561450',
#   '561491',
#   '561492',
#   '561499'],
#  'Cancer treatment center': ['622310'],
#  'Power plant consultant': ['237130', '237110', '237120'],
#  'Business park': ['812930', '812910', '812921', '812922', '812990'],
#  'Petroleum products company': ['424720', '424710'],
#  'Parking lot': ['812930', '812910', '812921', '812922', '812990'],
#  'Water utility company': ['221310', '221320', '221330'],
#  'Car repair and maintenance': ['811111',
#   '811112',
#   '811113',
#   '811118',
#   '811121',
#   '811122',
#   '811191',
#   '811192',
#   '811198'],
#  'Water treatment plant': ['221310', '221320', '221330'],
#  'Car service': ['811198',
#   '811191',
#   '811192',
#   '811111',
#   '811112',
#   '811113',
#   '811118',
#   '811121',
#   '811122'],
#  'Cattle market': ['424520', '424510', '424590'],
#  'Sewage disposal service': ['221320', '221310', '221330'],
#  'Certified public accountant': ['541211', '541213', '541214', '541219'],
#  'Government office': ['921190',
#   '921110',
#   '921120',
#   '921130',
#   '921140',
#   '921150'],
#  'Charity': ['813219', '813211', '813212'],
#  'Air conditioning system supplier': ['423730', '423710', '423720', '423740'],
#  'Chemical industry': ['325998', '325991', '325992', '325910', '325920'],
#  'Chemical manufacturer': ['325998', '325991', '325992', '325910', '325920'],
#  'Title company': ['541191', '541199', '541110', '541120'],
#  'Chemical plant': ['325998', '325991', '325992', '325910', '325920'],
#  'Property management company': ['531311', '531312', '531320', '531390'],
#  'Custom home builder': ['236115', '236116', '236117', '236118'],
#  'Window installation service': ['238150',
#   '238110',
#   '238120',
#   '238130',
#   '238140',
#   '238160',
#   '238170',
#   '238190'],
#  'Fire damage restoration service': ['562910', '562920', '562991', '562998'],
#  'Equipment rental agency': ['532490', '532411', '532412', '532420'],
#  'Chemical wholesaler': ['424690', '424610'],
#  'Financial planner': ['523930', '523910', '523920', '523991', '523999'],
#  'Telecommunications service provider': ['517311', '517312'],
#  'Energy equipment and solutions': ['444210', '444220'],
#  'Chiropractor': ['621310', '621320', '621330', '621340', '621391', '621399'],
#  'Steel distributor': ['423510', '423520'],
#  'City government office': ['921190',
#   '921110',
#   '921120',
#   '921130',
#   '921140',
#   '921150'],
#  'Crane service': ['333923',
#   '333921',
#   '333922',
#   '333924',
#   '333912',
#   '333914',
#   '333991',
#   '333992',
#   '333993',
#   '333994',
#   '333995',
#   '333996',
#   '333997',
#   '333999'],
#  'Garage door supplier': ['238350',
#   '238310',
#   '238320',
#   '238330',
#   '238340',
#   '238390'],
#  'Industrial door supplier': ['332321',
#   '332322',
#   '332323',
#   '332311',
#   '332312',
#   '332313'],
#  'City or town hall': ['921110',
#   '921120',
#   '921130',
#   '921140',
#   '921150',
#   '921190'],
#  'Clothing wholesaler': ['424310', '424320', '424330', '424340'],
#  'Coin operated laundry equipment supplier': ['812310',
#   '812320',
#   '812331',
#   '812332'],
#  'Metal supplier': ['423510', '423520'],
#  'Glass shop': ['238150',
#   '238110',
#   '238120',
#   '238130',
#   '238140',
#   '238160',
#   '238170',
#   '238190'],
#  'College': ['611310'],
#  'Siding contractor': ['238170',
#   '238110',
#   '238120',
#   '238130',
#   '238140',
#   '238150',
#   '238160',
#   '238190'],
#  'Commercial printer': ['323111', '323113', '323117', '323120'],
#  'Storage facility': ['493110', '493120', '493130', '493190'],
#  'Communications tower': ['237130', '237110', '237120'],
#  'Janitorial service': ['561720', '561710', '561730', '561740', '561790'],
#  'Computer consultant': ['541512', '541511', '541513', '541519'],
#  'Fire protection system supplier': ['922160',
#   '922110',
#   '922120',
#   '922130',
#   '922140',
#   '922150',
#   '922190'],
#  'Elevator service': ['333921',
#   '333922',
#   '333923',
#   '333924',
#   '333912',
#   '333914',
#   '333991',
#   '333992',
#   '333993',
#   '333994',
#   '333995',
#   '333996',
#   '333997',
#   '333999'],
#  'Industrial equipment supplier': ['423830',
#   '423810',
#   '423820',
#   '423840',
#   '423850',
#   '423860'],
#  'Dry wall contractor': ['238310',
#   '238320',
#   '238330',
#   '238340',
#   '238350',
#   '238390'],
#  'Insulation contractor': ['238310',
#   '238320',
#   '238330',
#   '238340',
#   '238350',
#   '238390'],
#  'Concrete contractor': ['238110',
#   '238120',
#   '238130',
#   '238140',
#   '238150',
#   '238160',
#   '238170',
#   '238190'],
#  'Scaffolding rental service': ['532490', '532411', '532412', '532420'],
#  'Construction company': ['236220', '236210'],
#  'Flooring store': ['442210', '442291', '442299'],
#  'Flooring contractor': ['238330',
#   '238310',
#   '238320',
#   '238340',
#   '238350',
#   '238390'],
#  'Tile contractor': ['238340',
#   '238310',
#   '238320',
#   '238330',
#   '238350',
#   '238390'],
#  'Tile manufacturer': ['238340',
#   '238310',
#   '238320',
#   '238330',
#   '238350',
#   '238390'],
#  'Glass & mirror shop': ['238150',
#   '238110',
#   '238120',
#   '238130',
#   '238140',
#   '238160',
#   '238170',
#   '238190'],
#  'Construction material wholesaler': ['423390', '423310', '423320', '423330'],
#  'Gutter cleaning service': ['561790', '561710', '561720', '561730', '561740'],
#  'Sheet metal contractor': ['332322',
#   '332321',
#   '332323',
#   '332311',
#   '332312',
#   '332313'],
#  'Consultant': ['541618',
#   '541611',
#   '541612',
#   '541613',
#   '541614',
#   '541620',
#   '541690'],
#  'Container service': ['332439', '332431', '332410', '332420'],
#  'Septic system service': ['562991', '562998', '562910', '562920'],
#  'Corporate campus': ['551114', '551111', '551112'],
#  'Water damage restoration service': ['562910', '562920', '562991', '562998'],
#  'Welder': ['333992',
#   '333991',
#   '333993',
#   '333994',
#   '333995',
#   '333996',
#   '333997',
#   '333999',
#   '333912',
#   '333914',
#   '333921',
#   '333922',
#   '333923',
#   '333924'],
#  'Corporate office': ['551114', '551111', '551112'],
#  'Animals': ['112990', '112910', '112920', '112930'],
#  'Animal feed store': ['453910', '453920', '453930', '453991', '453998'],
#  'Animal protection organization': ['813312', '813311', '813319'],
#  'Brewing supply store': ['424810', '424820'],
#  'Cosmetics store': ['446120', '446110', '446130', '446191', '446199'],
#  'County government office': ['921190',
#   '921110',
#   '921120',
#   '921130',
#   '921140',
#   '921150'],
#  'Sugar factory': ['311314', '311313', '311340', '311351', '311352'],
#  'Confectionery wholesaler': ['424450',
#   '424410',
#   '424420',
#   '424430',
#   '424440',
#   '424460',
#   '424470',
#   '424480',
#   '424490'],
#  'Financial institution': ['921130',
#   '921110',
#   '921120',
#   '921140',
#   '921150',
#   '921190'],
#  'Candy store': ['445292', '445291', '445299', '445210', '445220', '445230'],
#  'Confectionery': ['445292', '445291', '445299', '445210', '445220', '445230'],
#  'Chocolate factory': ['311351', '311352', '311313', '311314', '311340'],
#  'Chocolate shop': ['311351', '311352', '311313', '311314', '311340'],
#  'Courier service': ['492110'],
#  'Coworking space': ['531120', '531110', '531130', '531190'],
#  'Frozen food manufacturer': ['311412',
#   '311411',
#   '311421',
#   '311422',
#   '311423'],
#  'Beverage distributor': ['424820', '424810'],
#  'Agricultural organization': ['926140',
#   '926110',
#   '926120',
#   '926130',
#   '926150'],
#  'Dairy store': ['424430',
#   '424410',
#   '424420',
#   '424440',
#   '424450',
#   '424460',
#   '424470',
#   '424480',
#   '424490'],
#  'Dairy': ['112120', '112111', '112112', '112130'],
#  'Ice cream shop': ['311520', '311511', '311512', '311513', '311514'],
#  'Medical laboratory': ['621511', '621512'],
#  'Demolition contractor': ['238910', '238990'],
#  'Meat processor': ['311612', '311611', '311613', '311615'],
#  'FMCG manufacturer': ['532289',
#   '532281',
#   '532282',
#   '532283',
#   '532284',
#   '532210'],
#  'Garbage collection service': ['562111', '562112', '562119'],
#  'Wholesale bakery': ['311812',
#   '311811',
#   '311813',
#   '311821',
#   '311824',
#   '311830'],
#  'Dentist': ['621210'],
#  'Dessert shop': ['311813', '311811', '311812', '311821', '311824', '311830'],
#  'Cupcake shop': ['311811', '311812', '311813', '311821', '311824', '311830'],
#  'Nut store': ['445292', '445291', '445299', '445210', '445220', '445230'],
#  'Wholesale grocer': ['424490',
#   '424410',
#   '424420',
#   '424430',
#   '424440',
#   '424450',
#   '424460',
#   '424470',
#   '424480'],
#  'Design engineer': ['541330',
#   '541310',
#   '541320',
#   '541340',
#   '541350',
#   '541360',
#   '541370',
#   '541380'],
#  'Business to business service': ['561499',
#   '561491',
#   '561492',
#   '561410',
#   '561421',
#   '561422',
#   '561431',
#   '561439',
#   '561440',
#   '561450'],
#  'Condiments supplier': ['311941',
#   '311942',
#   '311911',
#   '311919',
#   '311920',
#   '311930',
#   '311991',
#   '311999'],
#  'Digital printing service': ['323111', '323113', '323117', '323120'],
#  'Culinary school': ['611519', '611511', '611512', '611513'],
#  'Importer': ['522293',
#   '522291',
#   '522292',
#   '522294',
#   '522298',
#   '522210',
#   '522220'],
#  'Bottled water supplier': ['312112',
#   '312111',
#   '312113',
#   '312120',
#   '312130',
#   '312140'],
#  'Coffee roasters': ['311920',
#   '311911',
#   '311919',
#   '311930',
#   '311941',
#   '311942',
#   '311991',
#   '311999'],
#  'Packaging supply store': ['561910', '561920', '561990'],
#  'Ice supplier': ['312113', '312111', '312112', '312120', '312130', '312140'],
#  'Brewery': ['312120', '312111', '312112', '312113', '312130', '312140'],
#  'Winemaking company': ['312130',
#   '312111',
#   '312112',
#   '312113',
#   '312120',
#   '312140'],
#  'Distillery': ['312140', '312111', '312112', '312113', '312120', '312130'],
#  'Disability services & support organisation': ['624120', '624110', '624190'],
#  'District government office': ['921190',
#   '921110',
#   '921120',
#   '921130',
#   '921140',
#   '921150'],
#  'Air filter supplier': ['333413', '333414', '333415'],
#  'Tire shop': ['441320', '441310'],
#  'Fastener supplier': ['339993',
#   '339991',
#   '339992',
#   '339994',
#   '339995',
#   '339999',
#   '339910',
#   '339920',
#   '339930',
#   '339940',
#   '339950'],
#  'Fabric product manufacturer': ['313310', '313320'],
#  'Textiles': ['313310', '313320'],
#  'Textile exporter': ['313310', '313320'],
#  'Textile engineer': ['313310', '313320'],
#  'Fabric store': ['451130', '451110', '451120', '451140'],
#  'Knit shop': ['313240', '313210', '313220', '313230'],
#  'Doctor': ['621111', '621112'],
#  'Lamination service': ['326130',
#   '326111',
#   '326112',
#   '326113',
#   '326121',
#   '326122',
#   '326140',
#   '326150',
#   '326160',
#   '326191',
#   '326199'],
#  'Plastic resin manufacturer': ['325211', '325212', '325220'],
#  'Carpet manufacturer': ['314110', '314120'],
#  'Upholstery shop': ['811420', '811411', '811412', '811430', '811490'],
#  'Business administration service': ['541611',
#   '541612',
#   '541613',
#   '541614',
#   '541618',
#   '541620',
#   '541690'],
#  'Furniture store': ['442110'],
#  'Dry cleaner': ['812320', '812310', '812331', '812332'],
#  'Packaging company': ['561910', '561920', '561990'],
#  'Duty free store': ['453998', '453991', '453910', '453920', '453930'],
#  'E-commerce service': ['454110'],
#  'Cable company': ['515210'],
#  'Education': ['611710'],
#  'Outlet store': ['452319', '452311'],
#  'Lingerie store': ['448190',
#   '448110',
#   '448120',
#   '448130',
#   '448140',
#   '448150'],
#  'Clothes and fabric manufacturer': ['313310', '313320'],
#  'Education center': ['611710'],
#  'Uniform store': ['448190', '448110', '448120', '448130', '448140', '448150'],
#  'Mens clothing store': ['448110',
#   '448120',
#   '448130',
#   '448140',
#   '448150',
#   '448190'],
#  'Clothing store': ['448190',
#   '448110',
#   '448120',
#   '448130',
#   '448140',
#   '448150'],
#  'Womens clothing store': ['448120',
#   '448110',
#   '448130',
#   '448140',
#   '448150',
#   '448190'],
#  'Western apparel store': ['448140',
#   '448110',
#   '448120',
#   '448130',
#   '448150',
#   '448190'],
#  'Costume store': ['532281', '532282', '532283', '532284', '532289', '532210'],
#  'Game store': ['451120', '451110', '451130', '451140'],
#  'Hat shop': ['448150', '448110', '448120', '448130', '448140', '448190'],
#  'Leather goods manufacturer': ['448320', '448310'],
#  'Educational consultant': ['611710'],
#  'Leather exporter': ['316998', '316992'],
#  'Shoe store': ['448210'],
#  'Boutique': ['448120', '448110', '448130', '448140', '448150', '448190'],
#  'Leather wholesaler': ['448320', '448310'],
#  'Handbags shop': ['316992', '316998'],
#  'Electronics store': ['443142', '443141'],
#  'Luggage store': ['448320', '448310'],
#  'Building materials store': ['444190', '444110', '444120', '444130'],
#  'Saw mill': ['321113', '321114'],
#  'Electrical engineer': ['541330',
#   '541310',
#   '541320',
#   '541340',
#   '541350',
#   '541360',
#   '541370',
#   '541380'],
#  'Deck builder': ['238350', '238310', '238320', '238330', '238340', '238390'],
#  'Concrete product supplier': ['327390',
#   '327310',
#   '327320',
#   '327331',
#   '327332'],
#  'Plywood supplier': ['321211', '321212', '321213', '321214', '321219'],
#  'Electrical installation service': ['238210', '238220', '238290'],
#  'Truss manufacturer': ['321214', '321211', '321212', '321213', '321219'],
#  'Door supplier': ['321911',
#   '321912',
#   '321918',
#   '321920',
#   '321991',
#   '321992',
#   '321999'],
#  'Wood and laminate flooring supplier': ['321918',
#   '321911',
#   '321912',
#   '321920',
#   '321991',
#   '321992',
#   '321999'],
#  'Aircraft supply store': ['423860',
#   '423810',
#   '423820',
#   '423830',
#   '423840',
#   '423850'],
#  'Modular home builder': ['321991',
#   '321992',
#   '321999',
#   '321911',
#   '321912',
#   '321918',
#   '321920'],
#  'Portable building manufacturer': ['332311',
#   '332312',
#   '332313',
#   '332321',
#   '332322',
#   '332323'],
#  'Modular home dealer': ['453930', '453910', '453920', '453991', '453998'],
#  'Mulch supplier': ['424910',
#   '424920',
#   '424930',
#   '424940',
#   '424950',
#   '424990'],
#  'Electrician': ['238210', '238220', '238290'],
#  'Paper mill': ['322110', '322121', '322122', '322130'],
#  'Energy supplier': ['221118',
#   '221111',
#   '221112',
#   '221113',
#   '221114',
#   '221115',
#   '221116',
#   '221117',
#   '221121',
#   '221122'],
#  'Engineer': ['541330',
#   '541310',
#   '541320',
#   '541340',
#   '541350',
#   '541360',
#   '541370',
#   '541380'],
#  'Print shop': ['323111', '323113', '323117', '323120'],
#  'Custom label printer': ['323111', '323113', '323117', '323120'],
#  'Marketing': ['541613',
#   '541611',
#   '541612',
#   '541614',
#   '541618',
#   '541620',
#   '541690'],
#  'Marketing agency': ['541810',
#   '541820',
#   '541830',
#   '541840',
#   '541850',
#   '541860',
#   '541870',
#   '541890'],
#  'Engineering consultant': ['541330',
#   '541310',
#   '541320',
#   '541340',
#   '541350',
#   '541360',
#   '541370',
#   '541380'],
#  'Entertainer': ['713990', '713910', '713920', '713930', '713940', '713950'],
#  'Envelope supplier': ['322230',
#   '322211',
#   '322212',
#   '322219',
#   '322220',
#   '322291',
#   '322299'],
#  'Oil refinery': ['324110', '324121', '324122', '324191', '324199'],
#  'Recording studio': ['512240', '512230', '512250', '512290'],
#  'Environment renewable natural resources': ['221118',
#   '221111',
#   '221112',
#   '221113',
#   '221114',
#   '221115',
#   '221116',
#   '221117',
#   '221121',
#   '221122'],
#  'Finishing materials supplier': ['444190', '444110', '444120', '444130'],
#  'Event ticket seller': ['561599', '561591', '561510', '561520'],
#  'Waterproofing company': ['238390',
#   '238310',
#   '238320',
#   '238330',
#   '238340',
#   '238350'],
#  'Auto parts store': ['441310', '441320'],
#  'Heating oil supplier': ['454310', '454390'],
#  'Family practice physician': ['621111', '621112'],
#  'Machining manufacturer': ['333249', '333241', '333242', '333243', '333244'],
#  'Industrial gas supplier': ['325120',
#   '325110',
#   '325130',
#   '325180',
#   '325193',
#   '325194',
#   '325199'],
#  'Welding supply store': ['333992',
#   '333991',
#   '333993',
#   '333994',
#   '333995',
#   '333996',
#   '333997',
#   '333999',
#   '333912',
#   '333914',
#   '333921',
#   '333922',
#   '333923',
#   '333924'],
#  'Dry ice supplier': ['312113',
#   '312111',
#   '312112',
#   '312120',
#   '312130',
#   '312140'],
#  'Private equity firm': ['523920', '523910', '523930', '523991', '523999'],
#  'Family service center': ['624190', '624110', '624120'],
#  'Federal government office': ['921190',
#   '921110',
#   '921120',
#   '921130',
#   '921140',
#   '921150'],
#  'Vitamin & supplements store': ['446191',
#   '446199',
#   '446110',
#   '446120',
#   '446130'],
#  'Feed manufacturer': ['311119', '311111'],
#  'Medical equipment supplier': ['423450',
#   '423410',
#   '423420',
#   '423430',
#   '423440',
#   '423460',
#   '423490'],
#  'Medical supply store': ['423450',
#   '423410',
#   '423420',
#   '423430',
#   '423440',
#   '423460',
#   '423490'],
#  'Medical clinic': ['621111', '621112'],
#  'Research institute': ['541715', '541713', '541714', '541720'],
#  'Biochemical supplier': ['424690', '424610'],
#  'Fiber optic products supplier': ['335921',
#   '335929',
#   '335911',
#   '335912',
#   '335931',
#   '335932',
#   '335991',
#   '335999'],
#  'Paint manufacturer': ['325510', '325520'],
#  'Equipment supplier': ['423830',
#   '423810',
#   '423820',
#   '423840',
#   '423850',
#   '423860'],
#  'Food': ['311999',
#   '311991',
#   '311911',
#   '311919',
#   '311920',
#   '311930',
#   '311941',
#   '311942'],
#  'Pipe supplier': ['332996',
#   '332991',
#   '332992',
#   '332993',
#   '332994',
#   '332999',
#   '332911',
#   '332912',
#   '332913',
#   '332919'],
#  'Oil field equipment supplier': ['333132',
#   '333131',
#   '333111',
#   '333112',
#   '333120'],
#  'Food broker': ['424410',
#   '424420',
#   '424430',
#   '424440',
#   '424450',
#   '424460',
#   '424470',
#   '424480',
#   '424490'],
#  'Food manufacturer': ['311119', '311111'],
#  'Food processing company': ['311999',
#   '311991',
#   '311911',
#   '311919',
#   '311920',
#   '311930',
#   '311941',
#   '311942'],
#  'Fence supply store': ['444190', '444110', '444120', '444130'],
#  'Food producer': ['311999',
#   '311991',
#   '311911',
#   '311919',
#   '311920',
#   '311930',
#   '311941',
#   '311942'],
#  'Forestry service': ['115310'],
#  'Foundry': ['331513', '331511', '331512', '331523', '331524', '331529'],
#  'Wholesale jeweler': ['423940', '423910', '423920', '423930', '423990'],
#  'Cookie shop': ['311821', '311824', '311811', '311812', '311813', '311830'],
#  'Truck rental agency': ['532120', '532111', '532112'],
#  'Fruit and vegetable processing': ['311421',
#   '311422',
#   '311423',
#   '311411',
#   '311412'],
#  'Kitchen supply store': ['423440',
#   '423410',
#   '423420',
#   '423430',
#   '423450',
#   '423460',
#   '423490'],
#  'Hydraulic equipment supplier': ['423830',
#   '423810',
#   '423820',
#   '423840',
#   '423850',
#   '423860'],
#  'Irrigation equipment supplier': ['221310', '221320', '221330'],
#  'Bearing supplier': ['332991',
#   '332992',
#   '332993',
#   '332994',
#   '332996',
#   '332999',
#   '332911',
#   '332912',
#   '332913',
#   '332919'],
#  'Metallurgy company': ['332117', '332111', '332112', '332114', '332119'],
#  'Plastic injection molding service': ['333511',
#   '333514',
#   '333515',
#   '333517',
#   '333519'],
#  'General contractor': ['236220', '236210'],
#  'General hospital': ['622110'],
#  'Tool manufacturer': ['333515', '333511', '333514', '333517', '333519'],
#  'Industrial design company': ['541420', '541410', '541430', '541490'],
#  'Hyundai dealer': ['423110', '423120', '423130', '423140'],
#  'Glass industry': ['327215', '327211', '327212', '327213'],
#  'Polymer supplier': ['424610', '424690'],
#  'Printing equipment and supplies': ['333244',
#   '333241',
#   '333242',
#   '333243',
#   '333249'],
#  'Toner cartridge supplier': ['325910',
#   '325920',
#   '325991',
#   '325992',
#   '325998'],
#  'Printer repair service': ['811212', '811211', '811213', '811219'],
#  'Fuel supplier': ['424720', '424710'],
#  'Glass manufacturer': ['327215', '327211', '327212', '327213'],
#  'Plastic bag supplier': ['326111',
#   '326112',
#   '326113',
#   '326121',
#   '326122',
#   '326130',
#   '326140',
#   '326150',
#   '326160',
#   '326191',
#   '326199'],
#  'Glassware manufacturer': ['327215', '327211', '327212', '327213'],
#  'Polythene and plastic sheeting supplier': ['326112',
#   '326111',
#   '326113',
#   '326121',
#   '326122',
#   '326130',
#   '326140',
#   '326150',
#   '326160',
#   '326191',
#   '326199'],
#  'PVC industry': ['326122',
#   '326121',
#   '326111',
#   '326112',
#   '326113',
#   '326130',
#   '326140',
#   '326150',
#   '326160',
#   '326191',
#   '326199'],
#  'Countertop store': ['444190', '444110', '444120', '444130'],
#  'Cabinet store': ['444190', '444110', '444120', '444130'],
#  'Fiberglass supplier': ['327993', '327991', '327992', '327999', '327910'],
#  'Golf cart dealer': ['441228', '441222', '441210'],
#  'Auto repair shop': ['811111',
#   '811112',
#   '811113',
#   '811118',
#   '811121',
#   '811122',
#   '811191',
#   '811192',
#   '811198'],
#  'Hose supplier': ['326220', '326211', '326212', '326291', '326299'],
#  'Rubber products supplier': ['326299',
#   '326291',
#   '326211',
#   '326212',
#   '326220'],
#  'Automotive': ['423110', '423120', '423130', '423140'],
#  'Commercial refrigerator supplier': ['423740', '423710', '423720', '423730'],
#  'Golf club': ['713910', '713920', '713930', '713940', '713950', '713990'],
#  'Golf course': ['713910', '713920', '713930', '713940', '713950', '713990'],
#  'Green energy supplier': ['221114',
#   '221111',
#   '221112',
#   '221113',
#   '221115',
#   '221116',
#   '221117',
#   '221118',
#   '221121',
#   '221122'],
#  'Greenhouse': ['111411', '111419', '111421', '111422'],
#  'Auto glass shop': ['811122',
#   '811121',
#   '811111',
#   '811112',
#   '811113',
#   '811118',
#   '811191',
#   '811192',
#   '811198'],
#  'Lighting manufacturer': ['335122', '335121', '335129', '335110'],
#  'Cement manufacturer': ['327310', '327320', '327331', '327332', '327390'],
#  'Brick manufacturer': ['327331', '327332', '327310', '327320', '327390'],
#  'Natural stone supplier': ['423320', '423310', '423330', '423390'],
#  'Gym': ['713940', '713910', '713920', '713930', '713950', '713990'],
#  'Marble supplier': ['327991', '327992', '327993', '327999', '327910'],
#  'Corporate gift supplier': ['453220', '453210'],
#  'Shipbuilding and repair company': ['336611', '336612'],
#  'Construction and maintenance office': ['236220', '236210'],
#  'Boiler manufacturer': ['332410', '332420', '332431', '332439'],
#  'Containers supplier': ['332439', '332431', '332410', '332420'],
#  'Home and construction': ['236115', '236116', '236117', '236118'],
#  'Health': ['621111', '621112'],
#  'Heart hospital': ['622310'],
#  'Spring supplier': ['332613', '332618'],
#  'Electric utility manufacturer': ['926130',
#   '926110',
#   '926120',
#   '926140',
#   '926150'],
#  'Aircraft manufacturer': ['336411',
#   '336412',
#   '336413',
#   '336414',
#   '336415',
#   '336419'],
#  'Metal heat treating service': ['332811', '332812', '332813'],
#  'Plating service': ['332813', '332811', '332812'],
#  'Automation company': ['335314', '335311', '335312', '335313'],
#  'Heating contractor': ['238220', '238210', '238290'],
#  'Plumbing supply store': ['423720', '423710', '423730', '423740'],
#  'Gun shop': ['451110', '451120', '451130', '451140'],
#  'Ammunition supplier': ['332993',
#   '332991',
#   '332992',
#   '332994',
#   '332996',
#   '332999',
#   '332911',
#   '332912',
#   '332913',
#   '332919'],
#  'Pipe manufacturer': ['332996',
#   '332991',
#   '332992',
#   '332993',
#   '332994',
#   '332999',
#   '332911',
#   '332912',
#   '332913',
#   '332919'],
#  'School': ['611110'],
#  'Fire protection equipment supplier': ['922160',
#   '922110',
#   '922120',
#   '922130',
#   '922140',
#   '922150',
#   '922190'],
#  'Agricultural machinery manufacturer': ['333111',
#   '333112',
#   '333120',
#   '333131',
#   '333132'],
#  'Lawn mower store': ['444210', '444220'],
#  'Lawn irrigation equipment supplier': ['221310', '221320', '221330'],
#  'Financial consultant': ['523930', '523910', '523920', '523991', '523999'],
#  'Helicopter charter': ['481211', '481212', '481219'],
#  'Packaging machinery': ['333993',
#   '333991',
#   '333992',
#   '333994',
#   '333995',
#   '333996',
#   '333997',
#   '333999',
#   '333912',
#   '333914',
#   '333921',
#   '333922',
#   '333923',
#   '333924'],
#  'Historical landmark': ['712120', '712110', '712130', '712190'],
#  'Electronics manufacturer': ['334419',
#   '334412',
#   '334413',
#   '334416',
#   '334417',
#   '334418'],
#  'Graphic designer': ['541430', '541410', '541420', '541490'],
#  'Eye care center': ['621320',
#   '621310',
#   '621330',
#   '621340',
#   '621391',
#   '621399'],
#  'Optical products manufacturer': ['333314', '333316', '333318'],
#  'Image consultant': ['541430', '541410', '541420', '541490'],
#  'Cleaning products supplier': ['423850',
#   '423810',
#   '423820',
#   '423830',
#   '423840',
#   '423860'],
#  'Fireplace store': ['423720', '423710', '423730', '423740'],
#  'Home builder': ['236115', '236116', '236117', '236118'],
#  'Tool & die shop': ['333514', '333511', '333515', '333517', '333519'],
#  'Metal stamping service': ['332119', '332111', '332112', '332114', '332117'],
#  'Environmental organization': ['813312', '813311', '813319'],
#  'Food processing equipment': ['333241',
#   '333242',
#   '333243',
#   '333244',
#   '333249'],
#  'Loan agency': ['522310', '522320', '522390'],
#  'Power plant equipment supplier': ['423610', '423620', '423690'],
#  'Home goods store': ['442299', '442291', '442210'],
#  'Engine rebuilding service': ['811198',
#   '811191',
#   '811192',
#   '811111',
#   '811112',
#   '811113',
#   '811118',
#   '811121',
#   '811122'],
#  'Air compressor supplier': ['333912',
#   '333914',
#   '333921',
#   '333922',
#   '333923',
#   '333924',
#   '333991',
#   '333992',
#   '333993',
#   '333994',
#   '333995',
#   '333996',
#   '333997',
#   '333999'],
#  'Honda dealer': ['441110', '441120'],
#  'Elevator manufacturer': ['333921',
#   '333922',
#   '333923',
#   '333924',
#   '333912',
#   '333914',
#   '333991',
#   '333992',
#   '333993',
#   '333994',
#   '333995',
#   '333996',
#   '333997',
#   '333999'],
#  'Crane dealer': ['333923',
#   '333921',
#   '333922',
#   '333924',
#   '333912',
#   '333914',
#   '333991',
#   '333992',
#   '333993',
#   '333994',
#   '333995',
#   '333996',
#   '333997',
#   '333999'],
#  'Crane rental agency': ['532412', '532411', '532420', '532490'],
#  'Compound building': ['238190',
#   '238110',
#   '238120',
#   '238130',
#   '238140',
#   '238150',
#   '238160',
#   '238170'],
#  'Tractor dealer': ['423820',
#   '423810',
#   '423830',
#   '423840',
#   '423850',
#   '423860'],
#  'Furnace parts supplier': ['423730', '423710', '423720', '423740'],
#  'Heating equipment supplier': ['423720', '423710', '423730', '423740'],
#  'Pneumatic tools supplier': ['423730', '423710', '423720', '423740'],
#  'Truck stop': ['447110', '447190'],
#  'Computer hardware manufacturer': ['334111', '334112', '334118'],
#  'Satellite communication service': ['517410'],
#  'Hospital': ['622110'],
#  'Electronics company': ['443142', '443141'],
#  'Electronic parts supplier': ['423690', '423610', '423620'],
#  'HVAC contractor': ['238220', '238210', '238290'],
#  'Industrial engineer': ['541330',
#   '541310',
#   '541320',
#   '541340',
#   '541350',
#   '541360',
#   '541370',
#   '541380'],
#  'Contact lenses supplier': ['333314', '333316', '333318'],
#  'Information services': ['519190', '519110', '519120', '519130'],
#  'Building': ['236220', '236210'],
#  'Water works equipment supplier': ['423720', '423710', '423730', '423740'],
#  'Measuring instruments supplier': ['334513',
#   '334510',
#   '334511',
#   '334512',
#   '334514',
#   '334515',
#   '334516',
#   '334517',
#   '334519'],
#  'Scientific equipment supplier': ['423490',
#   '423410',
#   '423420',
#   '423430',
#   '423440',
#   '423450',
#   '423460'],
#  'Medical center': ['622110'],
#  'Watch manufacturer': ['423940', '423910', '423920', '423930', '423990'],
#  'Corporate entertainment service': ['711510'],
#  'Insurance': ['524210', '524291', '524292', '524298'],
#  'Record company': ['512250', '512230', '512240', '512290'],
#  'Video duplication service': ['512191',
#   '512199',
#   '512110',
#   '512120',
#   '512131',
#   '512132'],
#  'Insurance agency': ['524210', '524291', '524292', '524298'],
#  'Lighting store': ['335122', '335121', '335129', '335110'],
#  'Lighting wholesaler': ['335122', '335121', '335129', '335110'],
#  'Entertainment agency': ['711410'],
#  'Insurance broker': ['524210', '524291', '524292', '524298'],
#  'Electrical equipment supplier': ['423610', '423620', '423690'],
#  'Electric motor store': ['336320',
#   '336310',
#   '336330',
#   '336340',
#   '336350',
#   '336360',
#   '336370',
#   '336390'],
#  'Railroad company': ['482111', '482112'],
#  'Electrical supply store': ['423610', '423620', '423690'],
#  'Insurance company': ['524210', '524291', '524292', '524298'],
#  'Factory equipment supplier': ['423830',
#   '423810',
#   '423820',
#   '423840',
#   '423850',
#   '423860'],
#  'Investment service': ['523999', '523991', '523910', '523920', '523930'],
#  'Laser equipment supplier': ['334510',
#   '334511',
#   '334512',
#   '334513',
#   '334514',
#   '334515',
#   '334516',
#   '334517',
#   '334519'],
#  'Executive suite rental agency': ['921110',
#   '921120',
#   '921130',
#   '921140',
#   '921150',
#   '921190'],
#  'Truck dealer': ['423110', '423120', '423130', '423140'],
#  'Motor vehicle dealer': ['441120', '441110'],
#  'Car dealer': ['441120', '441110'],
#  'Truck topper supplier': ['423860',
#   '423810',
#   '423820',
#   '423830',
#   '423840',
#   '423850'],
#  'Police supply store': ['453998', '453991', '453910', '453920', '453930'],
#  'Iron steel contractor': ['238120',
#   '238110',
#   '238130',
#   '238140',
#   '238150',
#   '238160',
#   '238170',
#   '238190'],
#  'Fire department equipment supplier': ['922160',
#   '922110',
#   '922120',
#   '922130',
#   '922140',
#   '922150',
#   '922190'],
#  'Towing equipment provider': ['488410', '488490'],
#  'Logistics service': ['541614',
#   '541611',
#   '541612',
#   '541613',
#   '541618',
#   '541620',
#   '541690'],
#  'Trailer manufacturer': ['336214', '336211', '336212', '336213'],
#  'Trailer dealer': ['532120', '532111', '532112'],
#  'RV dealer': ['441210', '441222', '441228'],
#  'Auto spring shop': ['811198',
#   '811191',
#   '811192',
#   '811111',
#   '811112',
#   '811113',
#   '811118',
#   '811121',
#   '811122'],
#  'Auto upholsterer': ['336360',
#   '336310',
#   '336320',
#   '336330',
#   '336340',
#   '336350',
#   '336370',
#   '336390'],
#  'Auto body parts supplier': ['441310', '441320'],
#  'Car factory': ['336111', '336112', '336120'],
#  'Freight forwarding service': ['488510'],
#  'Brake shop': ['811118',
#   '811111',
#   '811112',
#   '811113',
#   '811121',
#   '811122',
#   '811191',
#   '811192',
#   '811198'],
#  'Railroad equipment supplier': ['423860',
#   '423810',
#   '423820',
#   '423830',
#   '423840',
#   '423850'],
#  'Jewelry equipment supplier': ['339910',
#   '339920',
#   '339930',
#   '339940',
#   '339950',
#   '339991',
#   '339992',
#   '339993',
#   '339994',
#   '339995',
#   '339999'],
#  'Boat builders': ['336612', '336611'],
#  'Ship building': ['336611', '336612'],
#  'Marine supply store': ['441222', '441228', '441210'],
#  'Boat dealer': ['441222', '441228', '441210'],
#  'Kawasaki motorcycle dealer': ['441228', '441222', '441210'],
#  'Knife manufacturing': ['332215', '332216'],
#  'Labor union': ['813930', '813910', '813920', '813940', '813990'],
#  'Furniture maker': ['337122',
#   '337121',
#   '337124',
#   '337125',
#   '337127',
#   '337110'],
#  'Banking and finance': ['522110', '522120', '522130', '522190'],
#  'Furniture manufacturer': ['337125',
#   '337121',
#   '337122',
#   '337124',
#   '337127',
#   '337110'],
#  'Logistics': ['541614',
#   '541611',
#   '541612',
#   '541613',
#   '541618',
#   '541620',
#   '541690'],
#  'Massage supply store': ['423850',
#   '423810',
#   '423820',
#   '423830',
#   '423840',
#   '423860'],
#  'Telecommunications equipment supplier': ['334290', '334210', '334220'],
#  'Baby store': ['448130', '448110', '448120', '448140', '448150', '448190'],
#  'Molding supplier': ['333511', '333514', '333515', '333517', '333519'],
#  'Office equipment supplier': ['423420',
#   '423410',
#   '423430',
#   '423440',
#   '423450',
#   '423460',
#   '423490'],
#  'Office furniture store': ['337214', '337211', '337212', '337215'],
#  'Store equipment supplier': ['423850',
#   '423810',
#   '423820',
#   '423830',
#   '423840',
#   '423860'],
#  'Laboratory': ['541380',
#   '541310',
#   '541320',
#   '541330',
#   '541340',
#   '541350',
#   '541360',
#   '541370'],
#  'Health and beauty shop': ['812112', '812111', '812113', '812191', '812199'],
#  'Learning center': ['611691',
#   '611692',
#   '611699',
#   '611610',
#   '611620',
#   '611630'],
#  'Dental laboratory': ['339116', '339112', '339113', '339114', '339115'],
#  'Land surveyor': ['541370',
#   '541310',
#   '541320',
#   '541330',
#   '541340',
#   '541350',
#   '541360',
#   '541380'],
#  'Educational supply store': ['453210', '453220'],
#  'Jewelry store': ['448310', '448320'],
#  'Playground equipment supplier': ['423910',
#   '423920',
#   '423930',
#   '423940',
#   '423990'],
#  'Outdoor sports store': ['451110', '451120', '451130', '451140'],
#  'Toy store': ['451120', '451110', '451130', '451140'],
#  'Security service': ['561612', '561611', '561613', '561621', '561622'],
#  'Sign shop': ['339950',
#   '339910',
#   '339920',
#   '339930',
#   '339940',
#   '339991',
#   '339992',
#   '339993',
#   '339994',
#   '339995',
#   '339999'],
#  'Office supply store': ['453210', '453220'],
#  'Landscaper': ['561730', '561710', '561720', '561740', '561790'],
#  'Gasket manufacturer': ['339991',
#   '339992',
#   '339993',
#   '339994',
#   '339995',
#   '339999',
#   '339910',
#   '339920',
#   '339930',
#   '339940',
#   '339950'],
#  'Piano maker': ['339992',
#   '339991',
#   '339993',
#   '339994',
#   '339995',
#   '339999',
#   '339910',
#   '339920',
#   '339930',
#   '339940',
#   '339950'],
#  'Piano store': ['451140', '451110', '451120', '451130'],
#  'Funeral home': ['812210', '812220'],
#  'Monument': ['712120', '712110', '712130', '712190'],
#  'Book publisher': ['511130',
#   '511110',
#   '511120',
#   '511140',
#   '511191',
#   '511199'],
#  'Wig shop': ['448150', '448110', '448120', '448130', '448140', '448190'],
#  'Laundromat': ['812310', '812320', '812331', '812332'],
#  'Auto wrecker': ['488410', '488490'],
#  'Auto parts market': ['441310', '441320'],
#  'Jeep dealer': ['441110', '441120'],
#  'Restaurant supply store': ['423850',
#   '423810',
#   '423820',
#   '423830',
#   '423840',
#   '423860'],
#  'Roofing supply store': ['423330', '423310', '423320', '423390'],
#  'Law firm': ['541110', '541120', '541191', '541199'],
#  'Building materials market': ['444190', '444110', '444120', '444130'],
#  'Camera store': ['423410',
#   '423420',
#   '423430',
#   '423440',
#   '423450',
#   '423460',
#   '423490'],
#  'Lawn care service': ['561730', '561710', '561720', '561740', '561790'],
#  'Computer security service': ['561621',
#   '561622',
#   '561611',
#   '561612',
#   '561613'],
#  'Computer store': ['423430',
#   '423410',
#   '423420',
#   '423440',
#   '423450',
#   '423460',
#   '423490'],
#  'Design agency': ['541490', '541410', '541420', '541430'],
#  'Diagnostic center': ['621512', '621511'],
#  'Laboratory equipment supplier': ['334516',
#   '334510',
#   '334511',
#   '334512',
#   '334513',
#   '334514',
#   '334515',
#   '334517',
#   '334519'],
#  'Home theater store': ['334310'],
#  'Metal industry suppliers': ['423510', '423520'],
#  'Landscaping supply store': ['444220', '444210'],
#  'Appliance parts supplier': ['423620', '423610', '423690'],
#  'Vacuum cleaner store': ['443141', '443142'],
#  'Audio visual equipment supplier': ['334310'],
#  'Lawyer': ['541110', '541120', '541191', '541199'],
#  'Cell phone store': ['517312', '517311'],
#  'Bathroom supply store': ['423720', '423710', '423730', '423740'],
#  'Leasing service': ['532490', '532411', '532412', '532420'],
#  'Construction machine dealer': ['423810',
#   '423820',
#   '423830',
#   '423840',
#   '423850',
#   '423860'],
#  'Dairy farm equipment supplier': ['423820',
#   '423810',
#   '423830',
#   '423840',
#   '423850',
#   '423860'],
#  'Propane supplier': ['454310', '454390'],
#  'Legal services': ['541199', '541191', '541110', '541120'],
#  'Janitorial equipment supplier': ['561720',
#   '561710',
#   '561730',
#   '561740',
#   '561790'],
#  'Life insurance agency': ['524210', '524291', '524292', '524298'],
#  'Railroad contractor': ['488210'],
#  'Swimming pool supply store': ['453998',
#   '453991',
#   '453910',
#   '453920',
#   '453930'],
#  'Light bulb supplier': ['335110', '335121', '335122', '335129'],
#  'Linens store': ['812331', '812332', '812310', '812320'],
#  'Metal construction company': ['332311',
#   '332312',
#   '332313',
#   '332321',
#   '332322',
#   '332323'],
#  'Local government office': ['921190',
#   '921110',
#   '921120',
#   '921130',
#   '921140',
#   '921150'],
#  'Logging contractor': ['113310'],
#  'Machine shop': ['332710', '332721', '332722'],
# ...
#   '512120',
#   '512131',
#   '512132',
#   '512191',
#   '512199'],
#  'Movie theater': ['512131', '512132', '512110', '512120', '512191', '512199'],
#  'Theater company': ['711110', '711120', '711130', '711190'],
#  'Performing arts theater': ['711190', '711110', '711120', '711130'],
#  'Occupational safety and health': ['813410'],
#  'Office space rental agency': ['531120', '531110', '531130', '531190'],
#  'Commercial real estate agency': ['531210'],
#  'Art school': ['611610', '611620', '611630', '611691', '611692', '611699'],
#  'Music publisher': ['512230', '512240', '512250', '512290'],
#  'Printed music publisher': ['512230', '512240', '512250', '512290'],
#  'Home audio store': ['334310'],
#  'Musician': ['711130', '711110', '711120', '711190'],
#  'Music management and promotion': ['711410'],
#  'Video editing service': ['512191',
#   '512199',
#   '512110',
#   '512120',
#   '512131',
#   '512132'],
#  'Office supply wholesaler': ['424120', '424110', '424130'],
#  'Official residence': ['531110', '531120', '531130', '531190'],
#  'Orthopedic clinic': ['621111', '621112'],
#  'Painter': ['238320', '238310', '238330', '238340', '238350', '238390'],
#  'Painting': ['238320', '238310', '238330', '238340', '238350', '238390'],
#  'Telephone company': ['517311', '517312'],
#  'Media house': ['541840',
#   '541810',
#   '541820',
#   '541830',
#   '541850',
#   '541860',
#   '541870',
#   '541890'],
#  'Paper distributor': ['424130', '424110', '424120'],
#  'News service': ['451212', '451211'],
#  'Public library': ['519120', '519110', '519130', '519190'],
#  'Law library': ['519120', '519110', '519130', '519190'],
#  'Museum': ['712110', '712120', '712130', '712190'],
#  'Federal reserve bank': ['521110'],
#  'Credit union': ['522130', '522110', '522120', '522190'],
#  'ATM': ['522320', '522310', '522390'],
#  'Paving contractor': ['238990', '238910'],
#  'Mortgage lender': ['522310', '522320', '522390'],
#  'Investment bank': ['523110', '523120', '523130', '523140'],
#  'Check cashing service': ['522390', '522310', '522320'],
#  'Stock broker': ['523120', '523110', '523130', '523140'],
#  'Health consultant': ['541611',
#   '541612',
#   '541613',
#   '541614',
#   '541618',
#   '541620',
#   '541690'],
#  'Health insurance agency': ['524114',
#   '524113',
#   '524126',
#   '524127',
#   '524128',
#   '524130'],
#  'Payroll service': ['541214', '541211', '541213', '541219'],
#  'Pediatrician': ['621111', '621112'],
#  'Human resource consulting': ['541612',
#   '541611',
#   '541613',
#   '541614',
#   '541618',
#   '541620',
#   '541690'],
#  'Pest control service': ['561710', '561720', '561730', '561740', '561790'],
#  'Pet boarding service': ['812910', '812921', '812922', '812930', '812990'],
#  'Pet care': ['812910', '812921', '812922', '812930', '812990'],
#  'Loss adjuster': ['524291', '524292', '524298', '524210'],
#  'Pharmaceutical company': ['325412', '325411', '325413', '325414'],
#  'Pharmaceutical products wholesaler': ['424210'],
#  'Pharmacy': ['446110', '446120', '446130', '446191', '446199'],
#  'Educational institution': ['611310'],
#  'Retirement community': ['623311', '623312'],
#  'Fraternal organization': ['813410'],
#  'Photo lab': ['541921', '541922', '541910', '541930', '541940', '541990'],
#  'Property investment': ['531390', '531311', '531312', '531320'],
#  'Photographer': ['541921', '541922', '541910', '541930', '541940', '541990'],
#  'Photography school': ['541921',
#   '541922',
#   '541910',
#   '541930',
#   '541940',
#   '541990'],
#  '4-star hotel': ['721110', '721120', '721191', '721199'],
#  'Convention center': ['561591', '561599', '561510', '561520'],
#  'Real estate appraiser': ['531320', '531311', '531312', '531390'],
#  'Photography service': ['541921',
#   '541922',
#   '541910',
#   '541930',
#   '541940',
#   '541990'],
#  'Resort hotel': ['721110', '721120', '721191', '721199'],
#  'Real estate consultant': ['531210'],
#  '3-star hotel': ['721110', '721120', '721191', '721199'],
#  'Car rental agency': ['532111', '532112', '532120'],
#  'Car leasing service': ['532112', '532111', '532120'],
#  'Ford dealer': ['441110', '441120'],
#  'Car finance and loan company': ['522220',
#   '522210',
#   '522291',
#   '522292',
#   '522293',
#   '522294',
#   '522298'],
#  'Trailer rental service': ['532120', '532111', '532112'],
#  'Furniture rental service': ['532289',
#   '532281',
#   '532282',
#   '532283',
#   '532284',
#   '532210'],
#  'Tuxedo shop': ['532281', '532282', '532283', '532284', '532289', '532210'],
#  'Dress and tuxedo rental service': ['532281',
#   '532282',
#   '532283',
#   '532284',
#   '532289',
#   '532210'],
#  'Wedding store': ['448190', '448110', '448120', '448130', '448140', '448150'],
#  'Video store': ['443142', '443141'],
#  'Movie rental': ['512199', '512191', '512110', '512120', '512131', '512132'],
#  'Photography studio': ['541921',
#   '541922',
#   '541910',
#   '541930',
#   '541940',
#   '541990'],
#  'Home health care service': ['621610'],
#  'Skateboard shop': ['339920',
#   '339910',
#   '339930',
#   '339940',
#   '339950',
#   '339991',
#   '339992',
#   '339993',
#   '339994',
#   '339995',
#   '339999'],
#  'Event technology service': ['561920', '561910', '561990'],
#  'Party equipment rental service': ['532289',
#   '532281',
#   '532282',
#   '532283',
#   '532284',
#   '532210'],
#  'Construction machine rental service': ['532412',
#   '532411',
#   '532420',
#   '532490'],
#  'Audio visual equipment rental service': ['334310'],
#  'Shipping equipment industry': ['423860',
#   '423810',
#   '423820',
#   '423830',
#   '423840',
#   '423850'],
#  'Physical therapy clinic': ['621340',
#   '621310',
#   '621320',
#   '621330',
#   '621391',
#   '621399'],
#  'Plastic fabrication company': ['326199',
#   '326191',
#   '326111',
#   '326112',
#   '326113',
#   '326121',
#   '326122',
#   '326130',
#   '326140',
#   '326150',
#   '326160'],
#  'Plastic products supplier': ['326199',
#   '326191',
#   '326111',
#   '326112',
#   '326113',
#   '326121',
#   '326122',
#   '326130',
#   '326140',
#   '326150',
#   '326160'],
#  'Auto tag agency': ['926120', '926110', '926130', '926140', '926150'],
#  'Department of motor vehicles': ['926120',
#   '926110',
#   '926130',
#   '926140',
#   '926150'],
#  'Notary public': ['541120', '541110', '541191', '541199'],
#  'Private investigator': ['561611', '561612', '561613', '561621', '561622'],
#  'Escrow service': ['523991', '523999', '523910', '523920', '523930'],
#  'Real estate agent': ['531210'],
#  'Playground': ['713990', '713910', '713920', '713930', '713940', '713950'],
#  'Plumber': ['238220', '238210', '238290'],
#  'Port authority': ['488310', '488320', '488330', '488390'],
#  'Portrait studio': ['541921',
#   '541922',
#   '541910',
#   '541930',
#   '541940',
#   '541990'],
#  'Post office': ['491110'],
#  'Professional services': ['541990',
#   '541910',
#   '541921',
#   '541922',
#   '541930',
#   '541940'],
#  'University hospital': ['622110'],
#  'Public relations firm': ['541820',
#   '541810',
#   '541830',
#   '541840',
#   '541850',
#   '541860',
#   '541870',
#   '541890'],
#  'Civil engineering company': ['237990'],
#  'Drafting service': ['541340',
#   '541310',
#   '541320',
#   '541330',
#   '541350',
#   '541360',
#   '541370',
#   '541380'],
#  'Pump supplier': ['333996',
#   '333991',
#   '333992',
#   '333993',
#   '333994',
#   '333995',
#   '333997',
#   '333999',
#   '333912',
#   '333914',
#   '333921',
#   '333922',
#   '333923',
#   '333924'],
#  'Interior construction contractor': ['236220', '236210'],
#  'Carpet cleaning service': ['561740', '561710', '561720', '561730', '561790'],
#  'Exhibition planner': ['561920', '561910', '561990'],
#  'Decal supplier': ['339950',
#   '339910',
#   '339920',
#   '339930',
#   '339940',
#   '339991',
#   '339992',
#   '339993',
#   '339994',
#   '339995',
#   '339999'],
#  'Stage lighting equipment supplier': ['335129', '335121', '335122', '335110'],
#  'Event management company': ['561920', '561910', '561990'],
#  'Radio broadcaster': ['333996',
#   '333991',
#   '333992',
#   '333993',
#   '333994',
#   '333995',
#   '333997',
#   '333999',
#   '333912',
#   '333914',
#   '333921',
#   '333922',
#   '333923',
#   '333924'],
#  'Computer support and services': ['541519', '541511', '541512', '541513'],
#  'Ravine': ['712190', '712110', '712120', '712130'],
#  'Employment center': ['561311', '561312', '561320', '561330'],
#  'National health foundation': ['813212', '813211', '813219'],
#  'Real estate developer': ['236117', '236115', '236116', '236118'],
#  'Advertising agency': ['541810',
#   '541820',
#   '541830',
#   '541840',
#   '541850',
#   '541860',
#   '541870',
#   '541890'],
#  'Promotional products supplier': ['541870',
#   '541810',
#   '541820',
#   '541830',
#   '541840',
#   '541850',
#   '541860',
#   '541890'],
#  'Advertising service': ['541810',
#   '541820',
#   '541830',
#   '541840',
#   '541850',
#   '541860',
#   '541870',
#   '541890'],
#  'Records storage facility': ['531130', '531110', '531120', '531190'],
#  'Fund management company': ['523920', '523910', '523930', '523991', '523999'],
#  'Recreation center': ['713940',
#   '713910',
#   '713920',
#   '713930',
#   '713950',
#   '713990'],
#  'Bakery': ['311811', '311812', '311813', '311821', '311824', '311830'],
#  'Database management company': ['518210'],
#  'Market researcher': ['541910',
#   '541921',
#   '541922',
#   '541930',
#   '541940',
#   '541990'],
#  'Recycling center': ['423930', '423910', '423920', '423940', '423990'],
#  'Regional government office': ['921190',
#   '921110',
#   '921120',
#   '921130',
#   '921140',
#   '921150'],
#  'Rehabilitation center': ['623220', '623210'],
#  'Religious institution': ['813110'],
#  'Religious organization': ['813110'],
#  'Repair service': ['811490', '811411', '811412', '811420', '811430'],
#  'Emergency veterinarian service': ['541940',
#   '541910',
#   '541921',
#   '541922',
#   '541930',
#   '541990'],
#  'Pet sitter': ['812910', '812921', '812922', '812930', '812990'],
#  'Research and product development': ['541715', '541713', '541714', '541720'],
#  'Building society': ['236220', '236210'],
#  'Valet parking service': ['812930', '812910', '812921', '812922', '812990'],
#  'Nursing agency': ['623110'],
#  'Executive search firm': ['561312', '561311', '561320', '561330'],
#  'Recruiter': ['561311', '561312', '561320', '561330'],
#  'Temp agency': ['561311', '561312', '561320', '561330'],
#  'Health center': ['622110'],
#  'Restaurant': ['722511', '722513', '722514', '722515'],
#  'Roofing contractor': ['238160',
#   '238110',
#   '238120',
#   '238130',
#   '238140',
#   '238150',
#   '238170',
#   '238190'],
#  'Sports nutrition store': ['446191', '446199', '446110', '446120', '446130'],
#  'Credit reporting agency': ['561450',
#   '561410',
#   '561421',
#   '561422',
#   '561431',
#   '561439',
#   '561440',
#   '561491',
#   '561492',
#   '561499'],
#  'Automobile storage facility': ['493190', '493110', '493120', '493130'],
#  'Debt collection agency': ['561440',
#   '561410',
#   '561421',
#   '561422',
#   '561431',
#   '561439',
#   '561450',
#   '561491',
#   '561492',
#   '561499'],
#  'RV park': ['721211', '721214'],
#  'Court reporter': ['561492',
#   '561491',
#   '561499',
#   '561410',
#   '561421',
#   '561422',
#   '561431',
#   '561439',
#   '561440',
#   '561450'],
#  'Bus tour agency': ['561520', '561510', '561591', '561599'],
#  'Tour operator': ['561520', '561510', '561591', '561599'],
#  'Convention information bureau': ['561591', '561599', '561510', '561520'],
#  'Balloon ride tour agency': ['487990'],
#  'Security guard service': ['561612', '561611', '561613', '561621', '561622'],
#  'Locksmith': ['561622', '561621', '561611', '561612', '561613'],
#  'Commercial cleaning service': ['561720',
#   '561710',
#   '561730',
#   '561740',
#   '561790'],
#  'Blast cleaning service': ['561720', '561710', '561730', '561740', '561790'],
#  'Conference center': ['561920', '561910', '561990'],
#  'Safety equipment supplier': ['423490',
#   '423410',
#   '423420',
#   '423430',
#   '423440',
#   '423450',
#   '423460'],
#  'Garbage dump': ['562212', '562211', '562213', '562219'],
#  'Sanitation service': ['561720', '561710', '561730', '561740', '561790'],
#  'Garbage dump service': ['562111', '562112', '562119'],
#  'Environmental health service': ['541620',
#   '541611',
#   '541612',
#   '541613',
#   '541614',
#   '541618',
#   '541690'],
#  'Portable toilet supplier': ['562991', '562998', '562910', '562920'],
#  'Public works department': ['921190',
#   '921110',
#   '921120',
#   '921130',
#   '921140',
#   '921150'],
#  'School district office': ['611110'],
#  'Sailmaker': ['313210', '313220', '313230', '313240'],
#  'Community college': ['611210'],
#  'Salvage yard': ['423140', '423110', '423120', '423130'],
#  'Business school': ['611410', '611420', '611430'],
#  'Trade school': ['611519', '611511', '611512', '611513'],
#  'Private university': ['611310'],
#  'Computer training school': ['611420', '611410', '611430'],
#  'School supply store': ['424120', '424110', '424130'],
#  'Screen printer': ['323113', '323111', '323117', '323120'],
#  'Media consultant': ['541840',
#   '541810',
#   '541820',
#   '541830',
#   '541850',
#   '541860',
#   '541870',
#   '541890'],
#  'Beauty school': ['611511', '611512', '611513', '611519'],
#  'Flight school': ['611512', '611511', '611513', '611519'],
#  'Seaport': ['488310', '488320', '488330', '488390'],
#  'Security system supplier': ['561621',
#   '561622',
#   '561611',
#   '561612',
#   '561613'],
#  'Middle school': ['611110'],
#  'Nonprofit': ['813410'],
#  'Shooting range': ['713990',
#   '713910',
#   '713920',
#   '713930',
#   '713940',
#   '713950'],
#  'Soccer club': ['711211', '711212', '711219'],
#  'Camp': ['721214', '721211'],
#  'Diving contractor': ['561990', '561910', '561920'],
#  'Language school': ['611630',
#   '611610',
#   '611620',
#   '611691',
#   '611692',
#   '611699'],
#  'English language school': ['611630',
#   '611610',
#   '611620',
#   '611691',
#   '611692',
#   '611699'],
#  'Preschool': ['624410'],
#  'Self-storage facility': ['531130', '531110', '531120', '531190'],
#  'Semi conductor supplier': ['334413',
#   '334412',
#   '334416',
#   '334417',
#   '334418',
#   '334419'],
#  'Driving school': ['611692',
#   '611691',
#   '611699',
#   '611610',
#   '611620',
#   '611630'],
#  'Trucking school': ['611692',
#   '611691',
#   '611699',
#   '611610',
#   '611620',
#   '611630'],
#  'Senior citizen center': ['624120', '624110', '624190'],
#  'Services': ['541519', '541511', '541512', '541513'],
#  'Childrens hospital': ['622110'],
#  'Dental supply store': ['339114', '339112', '339113', '339115', '339116'],
#  'Shipyard': ['336611', '336612'],
#  'Orthodox synagogue': ['813110'],
#  'Short term apartment rental agency': ['531110',
#   '531120',
#   '531130',
#   '531190'],
#  'Nutritionist': ['621399', '621391', '621310', '621320', '621330', '621340'],
#  'Ophthalmologist': ['621320',
#   '621310',
#   '621330',
#   '621340',
#   '621391',
#   '621399'],
#  'Ophthalmology clinic': ['621320',
#   '621310',
#   '621330',
#   '621340',
#   '621391',
#   '621399'],
#  'Social services organization': ['624190', '624110', '624120'],
#  'Social welfare center': ['624190', '624110', '624120'],
#  'Solar energy company': ['221114',
#   '221111',
#   '221112',
#   '221113',
#   '221115',
#   '221116',
#   '221117',
#   '221118',
#   '221121',
#   '221122'],
#  'Solar energy equipment supplier': ['221114',
#   '221111',
#   '221112',
#   '221113',
#   '221115',
#   '221116',
#   '221117',
#   '221118',
#   '221121',
#   '221122'],
#  'Special education school': ['611110'],
#  'Podiatrist': ['621391', '621399', '621310', '621320', '621330', '621340'],
#  'Reproductive health clinic': ['621410',
#   '621420',
#   '621491',
#   '621492',
#   '621493',
#   '621498'],
#  'Sporting goods store': ['451110', '451120', '451130', '451140'],
#  'Dialysis center': ['621492',
#   '621491',
#   '621493',
#   '621498',
#   '621410',
#   '621420'],
#  'Sports complex': ['713940',
#   '713910',
#   '713920',
#   '713930',
#   '713950',
#   '713990'],
#  'Wellness program': ['525120', '525110', '525190'],
#  'Sportswear store': ['451110', '451120', '451130', '451140'],
#  'Private hospital': ['622110'],
#  'Radiologist': ['621512', '621511'],
#  'Medical diagnostic imaging center': ['621512', '621511'],
#  'X-ray lab': ['621512', '621511'],
#  'Blood bank': ['621991', '621999', '621910'],
#  'Stainless steel plant': ['331110'],
#  'State agency': ['921190', '921110', '921120', '921130', '921140', '921150'],
#  'Heliport': ['488119', '488111', '488190'],
#  'Health care company': ['622110'],
#  'Psychiatric hospital': ['622210'],
#  'State government office': ['921190',
#   '921110',
#   '921120',
#   '921130',
#   '921140',
#   '921150'],
#  'Medical institution': ['622110'],
#  'Steel construction company': ['238120',
#   '238110',
#   '238130',
#   '238140',
#   '238150',
#   '238160',
#   '238170',
#   '238190'],
#  ...}

# %%
max_docs = 10
def create_testing_dicts(normalization='lemmatize'):
    ret_docs_dic = {}
    queries_dic = {}

    if normalization == 'lemmatize':
        invert_index = inverted_index_lem
    else:
        invert_index = inverted_index_stem
        
    for query, value in relevance_judgments.items():
        
        ret_docs = retrieve_n_rank_docs(invert_index, query, normalization, max_docs=max_docs)
        if list(ret_docs.keys())[0] not in ret_docs_dic:
            ret_docs_dic[list(ret_docs.keys())[0]] = list(ret_docs.values())[0]
            
        queries_dic[' '.join(process_query(query, normalization))] = value
    
        
    return ret_docs_dic, queries_dic

# %%
# function to calculate precision and recall
def calc_pre_rec_at_n(ret_docs, reljudges, n=-1):
    """
    Calculate precision and recall at n for each query in ret_docs
    """
    
    pre_at_n, rec_at_n = {}, {}
    
    count = 0
    for k, v in ret_docs.items():
        if n > -1 and n <= len(ret_docs):
            s1 = set(v[:n])
        else:
            s1 = set(v)
        s2 = reljudges[k]
        try:
            precision = len(s1.intersection(s2)) / len(s1)
        except:
            pass
        recall = len(s1.intersection(s2)) / len(reljudges[k])
        pre_at_n[k] = round(precision, 3)
        rec_at_n[k] = round(recall, 3)
        count += 1
    return pre_at_n, rec_at_n

# %%
#function to calculate avg precision and mAP
def calc_avg_pre(ret_docs, reljudges, cutoff=-1):
    """
    Calculate (mean) average precision for each query in ret_docs
    """
    
    avg_pre, mean_avg_pre = {}, None
    for k, v in ret_docs.items():
        total_rel = 0
        total = 0
        avg_prec = 0
        for i, doc in enumerate(v):
            if doc in reljudges[k] and cutoff == -1:
                total_rel += 1
                total += 1
                precision = total_rel/total
            elif doc in reljudges[k] and i+1 <= cutoff:
                total_rel += 1
                total += 1
                precision = total_rel/total
            else:
                total += 1
                precision = 0
            avg_prec += precision

        avg_pre[k] = round(avg_prec/len(reljudges[k]), 3)
    
    mean_avg_pre = round(sum(avg_pre.values()) / len(avg_pre), 3)
        
    return avg_pre, mean_avg_pre

# %%
import math

# function to calculate NDCG
def calc_NDCG_at_n(ret_docs, reljudges, n=-1, base=2):
    """
    Calculate NDCG at n for each query in ret_docs
    """
    
    ndcg = {}
    
    for k, v in ret_docs.items():
        
        counts = list(reversed([x for x in range(2,len(reljudges[k])+2)]))
        ideals = {reljudges[k][i]: counts[i] for i in range(len(reljudges[k]))}
        
        add_ons = {}
        if len(v) > len(reljudges[k]):
            for i in range(len(v)-len(reljudges[k])):
                add_ons[i] = 1
        ideals.update(add_ons)
        nums = list(map(ideals.get, v))
        
        systems = {}
        for i, doc in enumerate(v):
            if nums[i] == None:
                systems[doc] = 1
            else:
                systems[doc] = nums[i]
                
        ideal_order = {}
        if n != -1:
            for i, (key, value) in enumerate(ideals.items()):
                if i < n:
                    ideal_order[key] = value
        else:
            ideal_order = ideals
        
        add_ons = {}
        
        
        log = 0
        for i, (doc, rank) in enumerate(ideal_order.items()):
            if i >= len(v):
                break
            elif i < base:
                log += rank
            else:
                log += rank/math.log(i+1, base)

                
        system_order = {}
        if n != -1:
            for i, (key, value) in enumerate(systems.items()):
                if i < n:
                    system_order[key] = value
        else:
            system_order = systems
        
        
        
        system_log = 0
        for i, (doc, rank) in enumerate(system_order.items()):
            if i >= len(v):
                break
            elif i < base:
                system_log += rank
            else:
                system_log += rank/math.log(i+1, base)
        try:
            ndcg[k] = system_log / log
        except:
            ndcg[k] = 0
        
    
    return ndcg

# %% [markdown]
# ## Stemming Test Results

# %%
# IMPORT INVERTED_INDEX
with open(r'assets/inverted_index_stem.json') as f:
    inverted_index_stem = json.load(f)

# %% [markdown]
# #### Precision/Recall

# %%
pre_at_n, rec_at_n = calc_pre_rec_at_n(create_testing_dicts(normalization='stem')[0], create_testing_dicts(normalization='stem')[1])

# %%
pre_at_n
# Out:
# {'home improv store': 0.0,
#  'diesel fuel supplier': 0.1,
#  'church': 0.1,
#  'farm': 0.2,
#  'seed supplier': 0.1,
#  'account': 0.0,
#  'truck compani': 0.1,
#  'export': 0.0,
#  'grain elev': 0.0,
#  'popcorn store': 0.2,
#  'agricultur servic': 0.2,
#  'warehous': 0.0,
#  'agricultur product': 0.1,
#  'ranch': 0.1,
#  'hold compani': 0.3,
#  'farm equip supplier': 0.0,
#  'store': 0.0,
#  'groceri store': 0.0,
#  'rice mill': 0.4,
#  'food product supplier': 0.0,
#  'account firm': 0.0,
#  'produc market': 0.0,
#  'pet suppli store': 0.1,
#  'wholesal': 0.0,
#  'produc wholesal': 0.0,
#  'distribut servic': 0.0,
#  'crop grower': 0.1,
#  'addict treatment center': 0.2,
#  'natur good store': 0.0,
#  'orchard': 0.1,
#  'lumber store': 0.1,
#  'mine': 0.2,
#  'transport servic': 0.0,
#  'invest compani': 0.2,
#  'fruit wholesal': 0.1,
#  'real estat agenc': 0.1,
#  'event venu': 0.0,
#  'frozen dessert supplier': 0.3,
#  'wine wholesal import': 0.2,
#  'wineri': 0.857,
#  'aerospac compani': 0.6,
#  'cold storag facil': 0.1,
#  'employ agenc': 0.2,
#  'plant nurseri': 0.0,
#  'air condit contractor': 0.1,
#  'air condit repair servic': 0.1,
#  'fruit veget wholesal': 0.0,
#  'aircraft rental servic': 0.0,
#  'monasteri': 1.0,
#  'allergist': 1.0,
#  'herb shop': 0.0,
#  'aluminum supplier': 0.4,
#  'ambul servic': 0.5,
#  'wholesal plant nurseri': 0.1,
#  'amus machin supplier': 0.1,
#  'anim hospit': 0.0,
#  'farmer market': 0.0,
#  'vapor store': 0.0,
#  'cigar shop': 0.2,
#  'tobacco shop': 0.0,
#  'well drill contractor': 0.3,
#  'librari': 0.3,
#  'apart build': 0.0,
#  'apart rental agenc': 0.0,
#  'dairi farm': 0.0,
#  'architect': 0.5,
#  'organ farm': 0.0,
#  'architectur design': 0.3,
#  'architectur firm': 0.3,
#  'livestock produc': 0.0,
#  'dairi supplier': 0.2,
#  'biotechnolog compani': 1.0,
#  'artist': 0.1,
#  'egg supplier': 0.5,
#  'poultri farm': 0.3,
#  'chicken hatcheri': 0.4,
#  'art organ': 0.3,
#  'associ organ': 0.2,
#  'food store': 0.0,
#  'deli': 0.0,
#  'bank': 0.2,
#  'fish process': 0.0,
#  'fish farm': 0.0,
#  'seafood wholesal': 0.2,
#  'tropic fish store': 0.0,
#  'non profit organ': 0.0,
#  'econom develop agenc': 0.2,
#  'seafood market': 0.1,
#  'honey farm': 0.571,
#  'hors breeder': 0.1,
#  'asphalt contractor': 0.0,
#  'livestock dealer': 0.1,
#  'depart store': 0.1,
#  'mill': 0.0,
#  'atv dealer': 0.5,
#  'audio visual consult': 0.1,
#  'pallet supplier': 0.2,
#  'wood supplier': 0.0,
#  'hardwar store': 0.0,
#  'furnitur wholesal': 0.0,
#  'auditor': 0.333,
#  'oil natur compani': 0.1,
#  'auto bodi shop': 0.0,
#  'boat repair shop': 0.2,
#  'associ': 0.2,
#  'rail contractor': 0.1,
#  'publish': 0.4,
#  'pond suppli store': 0.0,
#  'agricultur cooper': 0.0,
#  'print equip supplier': 0.1,
#  'auto insur agenc': 0.0,
#  'altern fuel station': 0.1,
#  'auto part manufactur': 0.0,
#  'foundat': 0.1,
#  'fertil supplier': 0.4,
#  'farm compani': 0.2,
#  'financ broker': 0.1,
#  'fire station': 0.0,
#  'environment consult': 0.2,
#  'civil engin': 0.1,
#  'fire protect servic': 0.0,
#  'compani': 0.0,
#  'oilfield': 0.0,
#  'banquet hall': 0.25,
#  'mine compani': 0.2,
#  'coalfield': 0.2,
#  'steel fabric': 0.1,
#  'quarri': 0.6,
#  'gold mine compani': 0.3,
#  'high rise build': 0.0,
#  'basketbal club': 0.167,
#  'gold dealer': 0.0,
#  'batteri manufactur': 0.5,
#  'electr util compani': 0.0,
#  'environment program': 0.1,
#  'offic': 0.0,
#  'stone supplier': 0.1,
#  'aggreg supplier': 0.0,
#  'sand gravel supplier': 0.4,
#  'build materi supplier': 0.0,
#  'beauti suppli store': 0.3,
#  'crush stone supplier': 0.0,
#  'rock shop': 0.0,
#  'road construct compani': 0.1,
#  'market consult': 0.0,
#  'blood test servic': 0.0,
#  'contractor': 0.2,
#  'excav contractor': 0.111,
#  'asphalt mix plant': 0.5,
#  'readi mix concret supplier': 0.0,
#  'sand plant': 0.4,
#  'bmw dealer': 0.4,
#  'bookbind': 0.667,
#  'garden center': 0.1,
#  'abras supplier': 0.4,
#  'granit supplier': 0.143,
#  'drill contractor': 0.3,
#  'bpo compani': 0.3,
#  'oil explor servic': 0.1,
#  'build complex': 0.0,
#  'construct equip supplier': 0.0,
#  'mine equip': 0.0,
#  'ticket agenc': 0.2,
#  'busi center': 0.0,
#  'skyscrap': 0.0,
#  'softwar compani': 0.1,
#  'busi develop servic': 0.0,
#  'busi manag consult': 0.0,
#  'cabinet maker': 0.6,
#  'call center': 0.333,
#  'cancer treatment center': 0.333,
#  'power plant consult': 0.1,
#  'busi park': 0.0,
#  'petroleum product compani': 0.2,
#  'park lot': 0.1,
#  'water util compani': 0.1,
#  'car repair mainten': 0.3,
#  'water treatment plant': 0.1,
#  'car servic': 0.3,
#  'cattl market': 0.1,
#  'sewag dispos servic': 0.3,
#  'certifi public account': 0.333,
#  'govern offic': 0.2,
#  'chariti': 1.0,
#  'air condit system supplier': 0.1,
#  'chemic industri': 0.1,
#  'chemic manufactur': 0.1,
#  'titl compani': 0.0,
#  'chemic plant': 0.1,
#  'properti manag compani': 0.1,
#  'custom home builder': 0.0,
#  'window instal servic': 0.0,
#  'fire damag restor servic': 0.0,
#  'equip rental agenc': 0.1,
#  'chemic wholesal': 0.1,
#  'financi planner': 0.1,
#  'telecommun servic provid': 0.2,
#  'energi equip solut': 0.0,
#  'chiropractor': 1.0,
#  'steel distributor': 0.0,
#  'citi govern offic': 0.5,
#  'crane servic': 0.4,
#  'garag door supplier': 0.1,
#  'industri door supplier': 0.0,
#  'citi town hall': 0.5,
#  'cloth wholesal': 0.2,
#  'coin oper laundri equip supplier': 0.3,
#  'metal supplier': 0.1,
#  'glass shop': 0.0,
#  'colleg': 0.1,
#  'side contractor': 0.2,
#  'commerci printer': 0.1,
#  'storag facil': 0.4,
#  'commun tower': 0.0,
#  'janitori servic': 0.556,
#  'comput consult': 0.0,
#  'fire protect system supplier': 0.0,
#  'elev servic': 0.4,
#  'industri equip supplier': 0.0,
#  'dri wall contractor': 0.0,
#  'insul contractor': 0.1,
#  'concret contractor': 0.3,
#  'scaffold rental servic': 0.25,
#  'construct compani': 0.2,
#  'floor store': 0.0,
#  'floor contractor': 0.1,
#  'tile contractor': 0.4,
#  'tile manufactur': 0.4,
#  'glass mirror shop': 0.0,
#  'construct materi wholesal': 0.0,
#  'gutter clean servic': 0.125,
#  'sheet metal contractor': 0.2,
#  'consult': 0.5,
#  'contain servic': 0.1,
#  'septic system servic': 0.3,
#  'corpor campu': 0.0,
#  'water damag restor servic': 0.0,
#  'welder': 0.0,
#  'corpor offic': 0.0,
#  'anim': 0.2,
#  'anim feed store': 0.0,
#  'anim protect organ': 0.0,
#  'brew suppli store': 0.0,
#  'cosmet store': 0.3,
#  'counti govern offic': 0.375,
#  'sugar factori': 0.5,
#  'confectioneri wholesal': 0.2,
#  'financi institut': 0.0,
#  'candi store': 0.0,
#  'confectioneri': 0.0,
#  'chocol factori': 0.5,
#  'chocol shop': 0.5,
#  'courier servic': 0.125,
#  'cowork space': 0.125,
#  'frozen food manufactur': 0.2,
#  'beverag distributor': 0.0,
#  'agricultur organ': 0.0,
#  'dairi store': 0.2,
#  'dairi': 0.0,
#  'ice cream shop': 0.1,
#  'medic laboratori': 0.2,
#  'demolit contractor': 0.667,
#  'meat processor': 0.4,
#  'fmcg manufactur': 0.4,
#  'garbag collect servic': 0.1,
#  'wholesal bakeri': 0.0,
#  'dentist': 0.1,
#  'dessert shop': 0.143,
#  'cupcak shop': 0.143,
#  'nut store': 0.0,
#  'wholesal grocer': 0.1,
#  'design engin': 0.0,
#  'busi busi servic': 0.0,
#  'condiment supplier': 1.0,
#  'digit print servic': 0.3,
#  'culinari school': 1.0,
#  'import': 0.0,
#  'bottl water supplier': 0.3,
#  'coffe roaster': 0.5,
#  'packag suppli store': 0.1,
#  'ice supplier': 0.3,
#  'breweri': 0.857,
#  'winemak compani': 0.857,
#  'distilleri': 0.0,
#  'disabl servic support organis': 0.2,
#  'district govern offic': 0.0,
#  'air filter supplier': 0.2,
#  'tire shop': 0.1,
#  'fasten supplier': 0.6,
#  'fabric product manufactur': 0.1,
#  'textil': 0.2,
#  'textil export': 0.2,
#  'textil engin': 0.2,
#  'fabric store': 0.0,
#  'knit shop': 0.3,
#  'doctor': 0.2,
#  'lamin servic': 0.1,
#  'plastic resin manufactur': 0.1,
#  'carpet manufactur': 0.1,
#  'upholsteri shop': 0.1,
#  'busi administr servic': 0.0,
#  'furnitur store': 0.0,
#  'dri cleaner': 0.0,
#  'packag compani': 0.1,
#  'duti free store': 0.0,
#  'commerc servic': 0.0,
#  'cabl compani': 0.1,
#  'educ': 0.1,
#  'outlet store': 0.0,
#  'lingeri store': 0.25,
#  'cloth fabric manufactur': 0.0,
#  'educ center': 0.1,
#  'uniform store': 0.1,
#  'men cloth store': 0.1,
#  'cloth store': 0.2,
#  'women cloth store': 0.1,
#  'western apparel store': 0.5,
#  'costum store': 0.3,
#  'game store': 0.0,
#  'hat shop': 0.1,
#  'leather good manufactur': 0.0,
#  'educ consult': 0.1,
#  'leather export': 0.2,
#  'shoe store': 0.1,
#  'boutiqu': 0.1,
#  'leather wholesal': 0.0,
#  'handbag shop': 0.2,
#  'electron store': 0.0,
#  'luggag store': 0.2,
#  'build materi store': 0.0,
#  'saw mill': 0.2,
#  'electr engin': 0.0,
#  'deck builder': 0.167,
#  'concret product supplier': 0.3,
#  'plywood supplier': 0.4,
#  'electr instal servic': 0.1,
#  'truss manufactur': 0.2,
#  'door supplier': 0.1,
#  'wood lamin floor supplier': 0.5,
#  'aircraft suppli store': 0.0,
#  'modular home builder': 0.0,
#  'portabl build manufactur': 0.0,
#  'modular home dealer': 0.0,
#  'mulch supplier': 0.333,
#  'electrician': 0.333,
#  'paper mill': 0.3,
#  'energi supplier': 0.5,
#  'engin': 0.1,
#  'print shop': 0.4,
#  'custom label printer': 0.0,
#  'market': 0.0,
#  'market agenc': 0.0,
#  'engin consult': 0.1,
#  'entertain': 0.1,
#  'envelop supplier': 0.125,
#  'oil refineri': 0.0,
#  'record studio': 0.1,
#  'environ renew natur resourc': 0.0,
#  'finish materi supplier': 0.0,
#  'event ticket seller': 0.0,
#  'waterproof compani': 0.1,
#  'auto part store': 0.1,
#  'heat oil supplier': 0.0,
#  'famili practic physician': 0.0,
#  'machin manufactur': 0.1,
#  'industri supplier': 0.2,
#  'weld suppli store': 0.1,
#  'dri ice supplier': 0.0,
#  'privat equiti firm': 0.0,
#  'famili servic center': 0.1,
#  'feder govern offic': 0.1,
#  'vitamin supplement store': 0.2,
#  'feed manufactur': 0.1,
#  'medic equip supplier': 0.1,
#  'medic suppli store': 0.1,
#  'medic clinic': 0.1,
#  'research institut': 0.3,
#  'biochem supplier': 0.3,
#  'fiber optic product supplier': 0.0,
#  'paint manufactur': 0.1,
#  'equip supplier': 0.2,
#  'food': 0.4,
#  'pipe supplier': 0.4,
#  'oil field equip supplier': 0.0,
#  'food broker': 0.0,
#  'food manufactur': 0.1,
#  'food process compani': 0.4,
#  'fenc suppli store': 0.1,
#  'food produc': 0.4,
#  'forestri servic': 0.1,
#  'foundri': 0.6,
#  'wholesal jewel': 0.0,
#  'cooki shop': 0.6,
#  'truck rental agenc': 0.0,
#  'fruit veget process': 0.3,
#  'kitchen suppli store': 0.0,
#  'hydraul equip supplier': 0.0,
#  'irrig equip supplier': 0.143,
#  'bear supplier': 0.5,
#  'metallurgi compani': 1.0,
#  'plastic inject mold servic': 0.0,
#  'gener contractor': 0.1,
#  'gener hospit': 0.0,
#  'tool manufactur': 0.4,
#  'industri design compani': 0.0,
#  'hyundai dealer': 0.0,
#  'glass industri': 0.3,
#  'polym supplier': 0.0,
#  'print equip suppli': 0.1,
#  'toner cartridg supplier': 0.333,
#  'printer repair servic': 0.1,
#  'fuel supplier': 0.0,
#  'glass manufactur': 0.3,
#  'plastic bag supplier': 0.3,
#  'glasswar manufactur': 0.333,
#  'polythen plastic sheet supplier': 0.333,
#  'pvc industri': 0.5,
#  'countertop store': 0.125,
#  'cabinet store': 0.1,
#  'fiberglass supplier': 0.111,
#  'golf cart dealer': 0.0,
#  'auto repair shop': 0.0,
#  'hose supplier': 0.2,
#  'rubber product supplier': 0.2,
#  'automot': 0.0,
#  'commerci refriger supplier': 0.0,
#  'golf club': 0.1,
#  'golf cours': 0.1,
#  'green energi supplier': 0.0,
#  'greenhous': 0.3,
#  'auto glass shop': 0.0,
#  'light manufactur': 0.4,
#  'cement manufactur': 0.1,
#  'brick manufactur': 0.2,
#  'natur stone supplier': 0.0,
#  'gym': 1.0,
#  'marbl supplier': 0.125,
#  'corpor gift supplier': 0.0,
#  'shipbuild repair compani': 0.0,
#  'construct mainten offic': 0.2,
#  'boiler manufactur': 0.3,
#  'contain supplier': 0.1,
#  'home construct': 0.1,
#  'health': 0.1,
#  'heart hospit': 0.0,
#  'spring supplier': 0.2,
#  'electr util manufactur': 0.0,
#  'aircraft manufactur': 0.3,
#  'metal heat treat servic': 0.1,
#  'plate servic': 0.2,
#  'autom compani': 0.0,
#  'heat contractor': 0.2,
#  'plumb suppli store': 0.1,
#  'gun shop': 0.1,
#  'ammunit supplier': 0.6,
#  'pipe manufactur': 0.4,
#  'school': 0.1,
#  'fire protect equip supplier': 0.0,
#  'agricultur machineri manufactur': 0.1,
#  'lawn mower store': 0.0,
#  'lawn irrig equip supplier': 0.0,
#  'financi consult': 0.1,
#  'helicopt charter': 0.2,
#  'packag machineri': 0.0,
#  'histor landmark': 0.2,
#  'electron manufactur': 0.1,
#  'graphic design': 0.2,
#  'eye care center': 0.1,
#  'optic product manufactur': 0.3,
#  'imag consult': 0.0,
#  'clean product supplier': 0.0,
#  'fireplac store': 0.1,
#  'home builder': 0.1,
#  'tool die shop': 0.4,
#  'metal stamp servic': 0.0,
#  'environment organ': 0.1,
#  'food process equip': 0.1,
#  'loan agenc': 0.2,
#  'power plant equip supplier': 0.0,
#  'home good store': 0.1,
#  'engin rebuild servic': 0.0,
#  'air compressor supplier': 0.0,
#  'honda dealer': 0.0,
#  'elev manufactur': 0.4,
#  'crane dealer': 0.4,
#  'crane rental agenc': 0.2,
#  'compound build': 0.0,
#  'tractor dealer': 0.0,
#  'furnac part supplier': 0.0,
#  'heat equip supplier': 0.1,
#  'pneumat tool supplier': 0.0,
#  'truck stop': 0.0,
#  'comput hardwar manufactur': 0.2,
#  'satellit commun servic': 0.1,
#  'hospit': 0.0,
#  'electron compani': 0.0,
#  'electron part supplier': 0.3,
#  'hvac contractor': 0.5,
#  'industri engin': 0.0,
#  'contact lens supplier': 0.0,
#  'inform servic': 0.1,
#  'build': 0.2,
#  'water work equip supplier': 0.0,
#  'measur instrument supplier': 0.8,
#  'scientif equip supplier': 0.0,
#  'medic center': 0.0,
#  'watch manufactur': 0.2,
#  'corpor entertain servic': 0.0,
#  'insur': 0.3,
#  'record compani': 0.1,
#  'video duplic servic': 0.3,
#  'insur agenc': 0.3,
#  'light store': 0.4,
#  'light wholesal': 0.4,
#  'entertain agenc': 0.1,
#  'insur broker': 0.3,
#  'electr equip supplier': 0.1,
#  'electr motor store': 0.0,
#  'railroad compani': 0.2,
#  'electr suppli store': 0.1,
#  'insur compani': 0.3,
#  'factori equip supplier': 0.0,
#  'invest servic': 0.5,
#  'laser equip supplier': 0.2,
#  'execut suit rental agenc': 0.5,
#  'truck dealer': 0.0,
#  'motor vehicl dealer': 0.0,
#  'car dealer': 0.0,
#  'truck topper supplier': 0.1,
#  'polic suppli store': 0.1,
#  'iron steel contractor': 0.0,
#  'fire depart equip supplier': 0.0,
#  'tow equip provid': 0.2,
#  'logist servic': 0.2,
#  'trailer manufactur': 0.3,
#  'trailer dealer': 0.1,
#  'dealer': 0.3,
#  'auto spring shop': 0.0,
#  'auto upholster': 0.0,
#  'auto bodi part supplier': 0.1,
#  'car factori': 0.0,
#  'freight forward servic': 0.0,
#  'brake shop': 0.1,
#  'railroad equip supplier': 0.1,
#  'jewelri equip supplier': 0.6,
#  'boat builder': 0.2,
#  'ship build': 0.2,
#  'marin suppli store': 0.0,
#  'boat dealer': 0.2,
#  'kawasaki motorcycl dealer': 0.2,
#  'knife manufactur': 0.25,
#  'labor union': 0.4,
#  'furnitur maker': 0.6,
#  'bank financ': 0.2,
#  'furnitur manufactur': 0.6,
#  'logist': 0.2,
#  'massag suppli store': 0.167,
#  'telecommun equip supplier': 0.0,
#  'babi store': 0.0,
#  'mold supplier': 0.0,
#  'offic equip supplier': 0.0,
#  'offic furnitur store': 0.0,
#  'store equip supplier': 0.0,
#  'laboratori': 0.1,
#  'health beauti shop': 0.0,
#  'learn center': 0.4,
#  'dental laboratori': 0.3,
#  'land surveyor': 0.1,
#  'educ suppli store': 0.0,
#  'jewelri store': 0.0,
#  'playground equip supplier': 0.2,
#  'outdoor sport store': 0.1,
#  'toy store': 0.0,
#  'secur servic': 0.0,
#  'sign shop': 0.6,
#  'offic suppli store': 0.0,
#  'landscap': 0.625,
#  'gasket manufactur': 0.667,
#  'piano maker': 0.2,
#  'piano store': 0.2,
#  'funer home': 0.5,
#  'monument': 0.0,
#  'book publish': 0.3,
#  'wig shop': 0.25,
#  'laundromat': 1.0,
#  'auto wrecker': 0.0,
#  'auto part market': 0.1,
#  'jeep dealer': 0.1,
#  'restaur suppli store': 0.1,
#  'roof suppli store': 0.4,
#  'law firm': 0.1,
#  'build materi market': 0.0,
#  'camera store': 0.2,
#  'lawn care servic': 0.1,
#  'comput secur servic': 0.0,
#  'comput store': 0.0,
#  'design agenc': 0.1,
#  'diagnost center': 0.2,
#  'laboratori equip supplier': 0.5,
#  'home theater store': 0.0,
#  'metal industri supplier': 0.1,
#  'landscap suppli store': 0.0,
#  'applianc part supplier': 0.3,
#  'vacuum cleaner store': 0.1,
#  'audio visual equip supplier': 0.1,
#  'lawyer': 0.8,
#  'cell phone store': 0.0,
#  'bathroom suppli store': 0.0,
#  'leas servic': 0.4,
#  'construct machin dealer': 0.0,
#  'dairi farm equip supplier': 0.0,
#  'propan supplier': 0.0,
#  'legal servic': 0.2,
#  'janitori equip supplier': 0.556,
#  'life insur agenc': 0.0,
#  'railroad contractor': 0.1,
#  'swim pool suppli store': 0.1,
#  'light bulb supplier': 0.4,
#  'linen store': 0.3,
#  'metal construct compani': 0.3,
#  'local govern offic': 0.0,
#  'log contractor': 0.0,
#  'machin shop': 0.0,
#  'hotel suppli store': 0.2,
#  'import export compani': 0.0,
#  'sew compani': 0.0,
#  'research foundat': 0.3,
#  'machineri part manufactur': 0.3,
#  'sport accessori wholesal': 0.1,
#  'fashion design': 0.1,
#  'chees manufactur': 0.286,
#  'chees shop': 0.286,
#  'ship mail': 0.0,
#  'wholesal food store': 0.1,
#  'organ food store': 0.0,
#  'pie shop': 0.3,
#  'auction hous': 0.1,
#  'livestock auction hous': 0.1,
#  'cotton export': 0.1,
#  'plastic wholesal': 0.0,
#  'mail servic': 0.1,
#  'manufactur': 0.0,
#  'station': 0.0,
#  'beer distributor': 0.2,
#  'alcohol beverag wholesal': 0.1,
#  'religi good store': 0.1,
#  'book wholesal': 0.1,
#  'masonri suppli store': 0.0,
#  'wholesal florist': 0.1,
#  'florist': 0.1,
#  'marin engin': 0.0,
#  'paint store': 0.0,
#  'use auto part store': 0.0,
#  'masonri contractor': 0.2,
#  'use car dealer': 0.0,
#  'use truck dealer': 0.0,
#  'massag therapist': 0.167,
#  'materi handl equip supplier': 0.1,
#  'marina': 1.0,
#  'meat packer': 0.3,
#  'mattress store': 0.0,
#  'blind shop': 0.2,
#  'interior design': 0.1,
#  'window treatment store': 0.0,
#  'applianc store': 0.0,
#  'health food store': 0.0,
#  'direct mail advertis': 0.0,
#  'meat wholesal': 0.3,
#  'butcher shop deli': 0.333,
#  'italian groceri store': 0.0,
#  'food servic': 0.0,
#  'groceri deliveri servic': 0.0,
#  'wine store': 0.1,
#  'liquor store': 0.125,
#  'kiosk': 0.125,
#  'optometrist': 0.429,
#  'optician': 0.125,
#  'mechan contractor': 0.1,
#  'mechan engin': 0.0,
#  'cafe': 0.25,
#  'jewel': 0.2,
#  'leather good store': 0.0,
#  'gift shop': 0.2,
#  'craft store': 0.111,
#  'hobbi store': 0.0,
#  'fabric wholesal': 0.0,
#  'scrap metal dealer': 0.0,
#  'quilt shop': 0.0,
#  'sheet music store': 0.0,
#  'music instrument manufactur': 0.2,
#  'music store': 0.0,
#  'music instrument store': 0.0,
#  'band': 0.1,
#  'bookstor': 0.1,
#  'art museum': 0.0,
#  'newsstand': 1.0,
#  'medic equip manufactur': 0.3,
#  'fashion accessori store': 0.2,
#  'discount store': 0.0,
#  'cemeteri': 0.2,
#  'stop': 0.0,
#  'varieti store': 0.0,
#  'thrift store': 0.5,
#  'medic group': 0.1,
#  'donat center': 0.0,
#  'pet store': 0.1,
#  'art galleri': 0.0,
#  'art dealer': 0.0,
#  'hous develop': 0.0,
#  'mobil home dealer': 0.1,
#  'conveni store': 0.286,
#  'medic offic': 0.1,
#  'medic technolog manufactur': 0.3,
#  'children furnitur store': 0.0,
#  'mental health clinic': 0.3,
#  'airlin': 0.0,
#  'aviat consult': 0.1,
#  'travel agenc': 0.2,
#  'travel servic': 0.2,
#  'airport': 0.1,
#  'mental health servic': 0.3,
#  'ship compani': 0.0,
#  'metal fabric': 0.3,
#  'cruis line compani': 0.0,
#  'tow servic': 0.2,
#  'ferri termin': 0.0,
#  'ferri servic': 0.167,
#  'metal finish': 0.1,
#  'boat tour agenc': 0.1,
#  'move compani': 0.3,
#  'move storag servic': 0.3,
#  'state depart transport': 0.1,
#  'depart transport': 0.1,
#  'handicap transport servic': 0.667,
#  'railway servic': 0.1,
#  'train station': 0.0,
#  'depot': 0.0,
#  'charter': 0.0,
#  'metal process compani': 0.3,
#  'mix use': 0.0,
#  'motorcycl shop': 0.2,
#  'limousin servic': 0.2,
#  'chauffeur servic': 0.0,
#  'school servic': 0.0,
#  'airport shuttl servic': 0.0,
#  'tourist inform center': 0.167,
#  'carriag ride servic': 0.25,
#  'cruis agenc': 0.1,
#  'tourist attract': 0.167,
#  'ski resort': 0.3,
#  'ski area': 0.3,
#  'fix base oper': 0.0,
#  'aircraft mainten compani': 0.2,
#  'motorsport store': 0.2,
#  'boat rental servic': 0.0,
#  'util trailer dealer': 0.0,
#  'forklift dealer': 0.25,
#  'municip administr offic': 0.0,
#  'nephrologist': 1.0,
#  'coach compani': 0.0,
#  'ship servic': 0.0,
#  'ship mail servic': 0.0,
#  'newspap publish': 0.4,
#  'shred servic': 0.25,
#  'nuclear power compani': 0.4,
#  'nurs home': 0.1,
#  'media compani': 0.5,
#  'multimedia electron book publish': 0.1,
#  'internet market servic': 0.0,
#  'greet card shop': 0.1,
#  'theme park': 1.0,
#  'film product compani': 0.2,
#  'obstetrician gynecologist': 1.0,
#  'movi studio': 0.3,
#  'video product servic': 0.3,
#  'movi theater': 0.3,
#  'theater compani': 0.1,
#  'perform art theater': 0.0,
#  'occup safeti health': 0.0,
#  'offic space rental agenc': 0.0,
#  'commerci real estat agenc': 0.0,
#  'art school': 0.0,
#  'music publish': 0.0,
#  'print music publish': 0.0,
#  'home audio store': 0.0,
#  'musician': 1.0,
#  'music manag promot': 0.1,
#  'video edit servic': 0.3,
#  'offic suppli wholesal': 0.2,
#  'offici resid': 0.0,
#  'orthoped clinic': 0.125,
#  'painter': 0.0,
#  'paint': 0.1,
#  'telephon compani': 0.2,
#  'media hous': 0.5,
#  'paper distributor': 0.1,
#  'news servic': 0.1,
#  'public librari': 0.0,
#  'law librari': 0.1,
#  'museum': 0.571,
#  'feder reserv bank': 0.0,
#  'credit union': 0.1,
#  'atm': 0.25,
#  'pave contractor': 0.1,
#  'mortgag lender': 0.1,
#  'invest bank': 0.2,
#  'check cash servic': 0.3,
#  'stock broker': 0.0,
#  'health consult': 0.0,
#  'health insur agenc': 0.0,
#  'payrol servic': 0.2,
#  'pediatrician': 1.0,
#  'human resourc consult': 0.3,
#  'pest control servic': 0.5,
#  'pet board servic': 0.2,
#  'pet care': 0.2,
#  'loss adjust': 0.222,
#  'pharmaceut compani': 0.4,
#  'pharmaceut product wholesal': 0.1,
#  'pharmaci': 0.167,
#  'educ institut': 0.1,
#  'retir commun': 0.2,
#  'fratern organ': 0.333,
#  'photo lab': 0.0,
#  'properti invest': 0.1,
#  'photograph': 0.1,
#  'photographi school': 0.2,
#  'star hotel': 0.2,
#  'convent center': 0.1,
#  'real estat apprais': 0.3,
#  'photographi servic': 0.2,
#  'resort hotel': 0.1,
#  'real estat consult': 0.1,
#  'car rental agenc': 0.2,
#  'car leas servic': 0.2,
#  'ford dealer': 0.2,
#  'car financ loan compani': 0.0,
#  'trailer rental servic': 0.1,
#  'furnitur rental servic': 0.0,
#  'tuxedo shop': 0.333,
#  'dress tuxedo rental servic': 0.0,
#  'wed store': 0.0,
#  'video store': 0.0,
#  'movi rental': 0.3,
#  'photographi studio': 0.2,
#  'home health care servic': 0.0,
#  'skateboard shop': 1.0,
#  'event technolog servic': 0.0,
#  'parti equip rental servic': 0.2,
#  'construct machin rental servic': 0.0,
#  'audio visual equip rental servic': 0.1,
#  'ship equip industri': 0.0,
#  'physic therapi clinic': 0.1,
#  'plastic fabric compani': 0.3,
#  'plastic product supplier': 0.3,
#  'auto tag agenc': 0.0,
#  'depart motor vehicl': 0.1,
#  'notari public': 0.8,
#  'privat investig': 0.0,
#  'escrow servic': 0.667,
#  'real estat agent': 0.1,
#  'playground': 0.0,
#  'plumber': 0.167,
#  'port author': 0.4,
#  'portrait studio': 0.2,
#  'post offic': 0.1,
#  'profession servic': 0.2,
#  'univers hospit': 0.0,
#  'public relat firm': 0.0,
#  'civil engin compani': 0.1,
#  'draft servic': 0.6,
#  'pump supplier': 0.7,
#  'interior construct contractor': 0.0,
#  'carpet clean servic': 0.3,
#  'exhibit planner': 0.0,
#  'decal supplier': 0.0,
#  'stage light equip supplier': 0.0,
#  'event manag compani': 0.0,
#  'radio broadcast': 0.0,
#  'comput support servic': 0.0,
#  'ravin': 0.0,
#  'employ center': 0.2,
#  'nation health foundat': 0.0,
#  'real estat develop': 0.0,
#  'advertis agenc': 0.1,
#  'promot product supplier': 0.0,
#  'advertis servic': 0.1,
#  'record storag facil': 0.0,
#  'fund manag compani': 0.0,
#  'recreat center': 0.4,
#  'bakeri': 0.4,
#  'databas manag compani': 0.0,
#  'market research': 0.0,
#  'recycl center': 0.2,
#  'region govern offic': 0.0,
#  'rehabilit center': 0.1,
#  'religi institut': 0.1,
#  'religi organ': 0.1,
#  'repair servic': 0.1,
#  'emerg veterinarian servic': 0.0,
#  'pet sitter': 0.2,
#  'research product develop': 0.3,
#  'build societi': 0.2,
#  'valet park servic': 0.667,
#  'nurs agenc': 0.1,
#  'execut search firm': 0.2,
#  'recruit': 1.0,
#  'temp agenc': 1.0,
#  'health center': 0.0,
#  'restaur': 0.3,
#  'roof contractor': 0.2,
#  'sport nutrit store': 0.0,
#  'credit report agenc': 0.0,
#  'automobil storag facil': 0.0,
#  'debt collect agenc': 0.3,
#  'park': 0.1,
#  'court report': 0.3,
#  'tour agenc': 0.3,
#  'tour oper': 0.3,
#  'convent inform bureau': 0.1,
#  'balloon ride tour agenc': 0.1,
#  'secur guard servic': 0.0,
#  'locksmith': 0.667,
#  'commerci clean servic': 0.0,
#  'blast clean servic': 0.0,
#  'confer center': 0.111,
#  'safeti equip supplier': 0.0,
#  'garbag dump': 0.1,
#  'sanit servic': 0.125,
#  'garbag dump servic': 0.1,
#  'environment health servic': 0.2,
#  'portabl toilet supplier': 0.0,
#  'public work depart': 0.2,
#  'school district offic': 0.1,
#  'sailmak': 0.1,
#  'commun colleg': 0.0,
#  'salvag yard': 0.0,
#  'busi school': 0.0,
#  'trade school': 0.0,
#  'privat univers': 0.0,
#  'comput train school': 0.0,
#  'school suppli store': 0.0,
#  'screen printer': 0.2,
#  'media consult': 0.5,
#  'beauti school': 0.0,
#  'flight school': 0.4,
#  'seaport': 0.0,
#  'secur system supplier': 0.0,
#  'middl school': 1.0,
#  'nonprofit': 1.0,
#  'shoot rang': 0.125,
#  'soccer club': 0.333,
#  'camp': 0.2,
#  'dive contractor': 0.25,
#  'languag school': 0.5,
#  'english languag school': 0.0,
#  'preschool': 0.5,
#  'self storag facil': 0.4,
#  'semi conductor supplier': 0.0,
#  'drive school': 0.1,
#  'truck school': 0.0,
#  'senior citizen center': 0.167,
#  'servic': 0.0,
#  'children hospit': 0.0,
#  'dental suppli store': 0.3,
#  'shipyard': 0.2,
#  'orthodox synagogu': 0.2,
#  'short term apart rental agenc': 0.0,
#  'nutritionist': 1.0,
#  'ophthalmologist': 0.0,
#  'ophthalmolog clinic': 0.0,
#  'social servic organ': 0.3,
#  'social welfar center': 0.3,
#  'solar energi compani': 0.7,
#  'solar energi equip supplier': 0.7,
#  'special educ school': 0.0,
#  'podiatrist': 1.0,
#  'reproduct health clinic': 0.0,
#  'sport good store': 0.0,
#  'dialysi center': 0.8,
#  'sport complex': 0.2,
#  'well program': 0.0,
#  'sportswear store': 0.0,
#  'privat hospit': 0.0,
#  'radiologist': 0.0,
#  'medic diagnost imag center': 0.2,
#  'ray lab': 0.2,
#  'blood bank': 0.2,
#  'stainless steel plant': 0.25,
#  'state agenc': 0.1,
#  'heliport': 0.1,
#  'health care compani': 0.0,
#  'psychiatr hospit': 0.2,
#  'state govern offic': 0.1,
#  'medic institut': 0.0,
#  'steel construct compani': 0.1,
#  'clean servic': 0.3,
#  'steel drum supplier': 0.0,
#  'assist live facil': 0.1,
#  'steel erector': 0.1,
#  ...}

# %%
rec_at_n
# Out:
# {'home improv store': 0.0,
#  'diesel fuel supplier': 0.5,
#  'church': 1.0,
#  'farm': 0.333,
#  'seed supplier': 0.167,
#  'account': 0.0,
#  'truck compani': 0.333,
#  'export': 0.0,
#  'grain elev': 0.0,
#  'popcorn store': 0.333,
#  'agricultur servic': 0.333,
#  'warehous': 0.0,
#  'agricultur product': 0.143,
#  'ranch': 0.25,
#  'hold compani': 1.0,
#  'farm equip supplier': 0.0,
#  'store': 0.0,
#  'groceri store': 0.0,
#  'rice mill': 0.571,
#  'food product supplier': 0.0,
#  'account firm': 0.0,
#  'produc market': 0.0,
#  'pet suppli store': 0.2,
#  'wholesal': 0.0,
#  'produc wholesal': 0.0,
#  'distribut servic': 0.0,
#  'crop grower': 0.143,
#  'addict treatment center': 0.5,
#  'natur good store': 0.0,
#  'orchard': 0.111,
#  'lumber store': 0.25,
#  'mine': 0.333,
#  'transport servic': 0.0,
#  'invest compani': 0.5,
#  'fruit wholesal': 0.111,
#  'real estat agenc': 1.0,
#  'event venu': 0.0,
#  'frozen dessert supplier': 0.6,
#  'wine wholesal import': 1.0,
#  'wineri': 1.0,
#  'aerospac compani': 1.0,
#  'cold storag facil': 0.25,
#  'employ agenc': 0.5,
#  'plant nurseri': 0.0,
#  'air condit contractor': 0.333,
#  'air condit repair servic': 0.333,
#  'fruit veget wholesal': 0.0,
#  'aircraft rental servic': 0.0,
#  'monasteri': 1.0,
#  'allergist': 0.5,
#  'herb shop': 0.0,
#  'aluminum supplier': 1.0,
#  'ambul servic': 1.0,
#  'wholesal plant nurseri': 0.167,
#  'amus machin supplier': 0.5,
#  'anim hospit': 0.0,
#  'farmer market': 0.0,
#  'vapor store': 0.0,
#  'cigar shop': 0.4,
#  'tobacco shop': 0.0,
#  'well drill contractor': 0.6,
#  'librari': 0.75,
#  'apart build': 0.0,
#  'apart rental agenc': 0.0,
#  'dairi farm': 0.0,
#  'architect': 0.25,
#  'organ farm': 0.0,
#  'architectur design': 0.375,
#  'architectur firm': 0.375,
#  'livestock produc': 0.0,
#  'dairi supplier': 0.222,
#  'biotechnolog compani': 0.75,
#  'artist': 1.0,
#  'egg supplier': 1.0,
#  'poultri farm': 0.75,
#  'chicken hatcheri': 0.8,
#  'art organ': 0.75,
#  'associ organ': 0.4,
#  'food store': 0.0,
#  'deli': 0.0,
#  'bank': 0.5,
#  'fish process': 0.0,
#  'fish farm': 0.0,
#  'seafood wholesal': 0.222,
#  'tropic fish store': 0.0,
#  'non profit organ': 0.0,
#  'econom develop agenc': 0.4,
#  'seafood market': 0.167,
#  'honey farm': 1.0,
#  'hors breeder': 0.25,
#  'asphalt contractor': 0.0,
#  'livestock dealer': 0.333,
#  'depart store': 1.0,
#  'mill': 0.0,
#  'atv dealer': 0.667,
#  'audio visual consult': 1.0,
#  'pallet supplier': 0.286,
#  'wood supplier': 0.0,
#  'hardwar store': 0.0,
#  'furnitur wholesal': 0.0,
#  'auditor': 0.25,
#  'oil natur compani': 0.2,
#  'auto bodi shop': 0.0,
#  'boat repair shop': 1.0,
#  'associ': 0.4,
#  'rail contractor': 0.167,
#  'publish': 0.667,
#  'pond suppli store': 0.0,
#  'agricultur cooper': 0.0,
#  'print equip supplier': 0.2,
#  'auto insur agenc': 0.0,
#  'altern fuel station': 0.5,
#  'auto part manufactur': 0.0,
#  'foundat': 0.333,
#  'fertil supplier': 1.0,
#  'farm compani': 0.333,
#  'financ broker': 0.333,
#  'fire station': 0.0,
#  'environment consult': 0.286,
#  'civil engin': 1.0,
#  'fire protect servic': 0.0,
#  'compani': 0.0,
#  'oilfield': 0.0,
#  'banquet hall': 0.333,
#  'mine compani': 0.333,
#  'coalfield': 0.0,
#  'steel fabric': 0.167,
#  'quarri': 0.5,
#  'gold mine compani': 0.5,
#  'high rise build': 0.0,
#  'basketbal club': 0.333,
#  'gold dealer': 0.0,
#  'batteri manufactur': 0.625,
#  'electr util compani': 0.0,
#  'environment program': 0.333,
#  'offic': 0.0,
#  'stone supplier': 0.25,
#  'aggreg supplier': 0.0,
#  'sand gravel supplier': 0.333,
#  'build materi supplier': 0.0,
#  'beauti suppli store': 0.6,
#  'crush stone supplier': 0.0,
#  'rock shop': 0.0,
#  'road construct compani': 1.0,
#  'market consult': 0.0,
#  'blood test servic': 0.0,
#  'contractor': 1.0,
#  'excav contractor': 0.5,
#  'asphalt mix plant': 1.0,
#  'readi mix concret supplier': 0.0,
#  'sand plant': 0.333,
#  'bmw dealer': 0.0,
#  'bookbind': 1.0,
#  'garden center': 0.5,
#  'abras supplier': 0.8,
#  'granit supplier': 0.2,
#  'drill contractor': 0.6,
#  'bpo compani': 0.0,
#  'oil explor servic': 0.2,
#  'build complex': 0.0,
#  'construct equip supplier': 0.0,
#  'mine equip': 0.0,
#  'ticket agenc': 0.5,
#  'busi center': 0.0,
#  'skyscrap': 0.0,
#  'softwar compani': 1.0,
#  'busi develop servic': 0.0,
#  'busi manag consult': 0.0,
#  'cabinet maker': 1.0,
#  'call center': 0.2,
#  'cancer treatment center': 1.0,
#  'power plant consult': 0.333,
#  'busi park': 0.0,
#  'petroleum product compani': 1.0,
#  'park lot': 0.2,
#  'water util compani': 0.333,
#  'car repair mainten': 0.333,
#  'water treatment plant': 0.333,
#  'car servic': 0.333,
#  'cattl market': 0.333,
#  'sewag dispos servic': 1.0,
#  'certifi public account': 0.25,
#  'govern offic': 0.333,
#  'chariti': 0.333,
#  'air condit system supplier': 0.25,
#  'chemic industri': 0.2,
#  'chemic manufactur': 0.2,
#  'titl compani': 0.0,
#  'chemic plant': 0.2,
#  'properti manag compani': 0.25,
#  'custom home builder': 0.0,
#  'window instal servic': 0.0,
#  'fire damag restor servic': 0.0,
#  'equip rental agenc': 0.25,
#  'chemic wholesal': 0.5,
#  'financi planner': 0.2,
#  'telecommun servic provid': 1.0,
#  'energi equip solut': 0.0,
#  'chiropractor': 0.5,
#  'steel distributor': 0.0,
#  'citi govern offic': 0.5,
#  'crane servic': 0.286,
#  'garag door supplier': 0.167,
#  'industri door supplier': 0.0,
#  'citi town hall': 0.5,
#  'cloth wholesal': 0.5,
#  'coin oper laundri equip supplier': 0.75,
#  'metal supplier': 0.5,
#  'glass shop': 0.0,
#  'colleg': 1.0,
#  'side contractor': 0.25,
#  'commerci printer': 0.25,
#  'storag facil': 1.0,
#  'commun tower': 0.0,
#  'janitori servic': 1.0,
#  'comput consult': 0.0,
#  'fire protect system supplier': 0.0,
#  'elev servic': 0.286,
#  'industri equip supplier': 0.0,
#  'dri wall contractor': 0.0,
#  'insul contractor': 0.167,
#  'concret contractor': 0.375,
#  'scaffold rental servic': 0.25,
#  'construct compani': 1.0,
#  'floor store': 0.0,
#  'floor contractor': 0.167,
#  'tile contractor': 0.667,
#  'tile manufactur': 0.667,
#  'glass mirror shop': 0.0,
#  'construct materi wholesal': 0.0,
#  'gutter clean servic': 0.2,
#  'sheet metal contractor': 0.333,
#  'consult': 0.714,
#  'contain servic': 0.25,
#  'septic system servic': 0.75,
#  'corpor campu': 0.0,
#  'water damag restor servic': 0.0,
#  'welder': 0.0,
#  'corpor offic': 0.0,
#  'anim': 0.5,
#  'anim feed store': 0.0,
#  'anim protect organ': 0.0,
#  'brew suppli store': 0.0,
#  'cosmet store': 0.6,
#  'counti govern offic': 0.5,
#  'sugar factori': 1.0,
#  'confectioneri wholesal': 0.222,
#  'financi institut': 0.0,
#  'candi store': 0.0,
#  'confectioneri': 0.0,
#  'chocol factori': 1.0,
#  'chocol shop': 1.0,
#  'courier servic': 1.0,
#  'cowork space': 0.0,
#  'frozen food manufactur': 0.4,
#  'beverag distributor': 0.0,
#  'agricultur organ': 0.0,
#  'dairi store': 0.222,
#  'dairi': 0.0,
#  'ice cream shop': 0.2,
#  'medic laboratori': 1.0,
#  'demolit contractor': 1.0,
#  'meat processor': 1.0,
#  'fmcg manufactur': 0.0,
#  'garbag collect servic': 0.333,
#  'wholesal bakeri': 0.0,
#  'dentist': 1.0,
#  'dessert shop': 0.167,
#  'cupcak shop': 0.0,
#  'nut store': 0.0,
#  'wholesal grocer': 0.111,
#  'design engin': 0.0,
#  'busi busi servic': 0.0,
#  'condiment supplier': 1.0,
#  'digit print servic': 0.75,
#  'culinari school': 0.25,
#  'import': 0.0,
#  'bottl water supplier': 0.5,
#  'coffe roaster': 0.625,
#  'packag suppli store': 0.333,
#  'ice supplier': 0.5,
#  'breweri': 1.0,
#  'winemak compani': 0.0,
#  'distilleri': 0.0,
#  'disabl servic support organis': 0.667,
#  'district govern offic': 0.0,
#  'air filter supplier': 0.667,
#  'tire shop': 0.5,
#  'fasten supplier': 0.545,
#  'fabric product manufactur': 0.5,
#  'textil': 1.0,
#  'textil export': 1.0,
#  'textil engin': 1.0,
#  'fabric store': 0.0,
#  'knit shop': 0.75,
#  'doctor': 1.0,
#  'lamin servic': 0.091,
#  'plastic resin manufactur': 0.333,
#  'carpet manufactur': 0.5,
#  'upholsteri shop': 0.2,
#  'busi administr servic': 0.0,
#  'furnitur store': 0.0,
#  'dri cleaner': 0.0,
#  'packag compani': 0.333,
#  'duti free store': 0.0,
#  'commerc servic': 0.0,
#  'cabl compani': 1.0,
#  'educ': 1.0,
#  'outlet store': 0.0,
#  'lingeri store': 0.167,
#  'cloth fabric manufactur': 0.0,
#  'educ center': 1.0,
#  'uniform store': 0.167,
#  'men cloth store': 0.167,
#  'cloth store': 0.333,
#  'women cloth store': 0.167,
#  'western apparel store': 0.167,
#  'costum store': 0.5,
#  'game store': 0.0,
#  'hat shop': 0.167,
#  'leather good manufactur': 0.0,
#  'educ consult': 1.0,
#  'leather export': 1.0,
#  'shoe store': 1.0,
#  'boutiqu': 0.0,
#  'leather wholesal': 0.0,
#  'handbag shop': 1.0,
#  'electron store': 0.0,
#  'luggag store': 1.0,
#  'build materi store': 0.0,
#  'saw mill': 1.0,
#  'electr engin': 0.0,
#  'deck builder': 0.167,
#  'concret product supplier': 0.6,
#  'plywood supplier': 0.8,
#  'electr instal servic': 0.333,
#  'truss manufactur': 0.4,
#  'door supplier': 0.143,
#  'wood lamin floor supplier': 0.714,
#  'aircraft suppli store': 0.0,
#  'modular home builder': 0.0,
#  'portabl build manufactur': 0.0,
#  'modular home dealer': 0.0,
#  'mulch supplier': 0.167,
#  'electrician': 0.333,
#  'paper mill': 0.75,
#  'energi supplier': 0.5,
#  'engin': 0.125,
#  'print shop': 1.0,
#  'custom label printer': 0.0,
#  'market': 0.0,
#  'market agenc': 0.0,
#  'engin consult': 0.125,
#  'entertain': 0.167,
#  'envelop supplier': 0.143,
#  'oil refineri': 0.0,
#  'record studio': 0.25,
#  'environ renew natur resourc': 0.0,
#  'finish materi supplier': 0.0,
#  'event ticket seller': 0.0,
#  'waterproof compani': 0.167,
#  'auto part store': 0.5,
#  'heat oil supplier': 0.0,
#  'famili practic physician': 0.0,
#  'machin manufactur': 0.2,
#  'industri supplier': 0.286,
#  'weld suppli store': 0.071,
#  'dri ice supplier': 0.0,
#  'privat equiti firm': 0.0,
#  'famili servic center': 0.333,
#  'feder govern offic': 0.167,
#  'vitamin supplement store': 0.2,
#  'feed manufactur': 0.5,
#  'medic equip supplier': 0.143,
#  'medic suppli store': 0.143,
#  'medic clinic': 0.5,
#  'research institut': 0.75,
#  'biochem supplier': 0.0,
#  'fiber optic product supplier': 0.0,
#  'paint manufactur': 0.5,
#  'equip supplier': 0.333,
#  'food': 0.5,
#  'pipe supplier': 0.4,
#  'oil field equip supplier': 0.0,
#  'food broker': 0.0,
#  'food manufactur': 0.5,
#  'food process compani': 0.5,
#  'fenc suppli store': 0.25,
#  'food produc': 0.5,
#  'forestri servic': 1.0,
#  'foundri': 1.0,
#  'wholesal jewel': 0.0,
#  'cooki shop': 1.0,
#  'truck rental agenc': 0.0,
#  'fruit veget process': 0.6,
#  'kitchen suppli store': 0.0,
#  'hydraul equip supplier': 0.0,
#  'irrig equip supplier': 0.333,
#  'bear supplier': 0.5,
#  'metallurgi compani': 1.0,
#  'plastic inject mold servic': 0.0,
#  'gener contractor': 0.5,
#  'gener hospit': 0.0,
#  'tool manufactur': 0.8,
#  'industri design compani': 0.0,
#  'hyundai dealer': 0.0,
#  'glass industri': 0.75,
#  'polym supplier': 0.0,
#  'print equip suppli': 0.2,
#  'toner cartridg supplier': 0.2,
#  'printer repair servic': 0.25,
#  'fuel supplier': 0.0,
#  'glass manufactur': 0.75,
#  'plastic bag supplier': 0.273,
#  'glasswar manufactur': 0.5,
#  'polythen plastic sheet supplier': 0.0,
#  'pvc industri': 0.091,
#  'countertop store': 0.25,
#  'cabinet store': 0.25,
#  'fiberglass supplier': 0.2,
#  'golf cart dealer': 0.0,
#  'auto repair shop': 0.0,
#  'hose supplier': 0.4,
#  'rubber product supplier': 0.4,
#  'automot': 0.0,
#  'commerci refriger supplier': 0.0,
#  'golf club': 0.167,
#  'golf cours': 0.167,
#  'green energi supplier': 0.0,
#  'greenhous': 0.75,
#  'auto glass shop': 0.0,
#  'light manufactur': 1.0,
#  'cement manufactur': 0.2,
#  'brick manufactur': 0.4,
#  'natur stone supplier': 0.0,
#  'gym': 0.167,
#  'marbl supplier': 0.2,
#  'corpor gift supplier': 0.0,
#  'shipbuild repair compani': 0.0,
#  'construct mainten offic': 1.0,
#  'boiler manufactur': 0.75,
#  'contain supplier': 0.25,
#  'home construct': 0.25,
#  'health': 0.5,
#  'heart hospit': 0.0,
#  'spring supplier': 1.0,
#  'electr util manufactur': 0.0,
#  'aircraft manufactur': 0.5,
#  'metal heat treat servic': 0.333,
#  'plate servic': 0.667,
#  'autom compani': 0.0,
#  'heat contractor': 0.667,
#  'plumb suppli store': 0.25,
#  'gun shop': 0.25,
#  'ammunit supplier': 0.6,
#  'pipe manufactur': 0.4,
#  'school': 1.0,
#  'fire protect equip supplier': 0.0,
#  'agricultur machineri manufactur': 0.2,
#  'lawn mower store': 0.0,
#  'lawn irrig equip supplier': 0.0,
#  'financi consult': 0.2,
#  'helicopt charter': 0.667,
#  'packag machineri': 0.0,
#  'histor landmark': 0.5,
#  'electron manufactur': 0.167,
#  'graphic design': 0.5,
#  'eye care center': 0.167,
#  'optic product manufactur': 1.0,
#  'imag consult': 0.0,
#  'clean product supplier': 0.0,
#  'fireplac store': 0.25,
#  'home builder': 0.25,
#  'tool die shop': 0.8,
#  'metal stamp servic': 0.0,
#  'environment organ': 0.333,
#  'food process equip': 0.2,
#  'loan agenc': 0.667,
#  'power plant equip supplier': 0.0,
#  'home good store': 0.333,
#  'engin rebuild servic': 0.0,
#  'air compressor supplier': 0.0,
#  'honda dealer': 0.0,
#  'elev manufactur': 0.286,
#  'crane dealer': 0.286,
#  'crane rental agenc': 0.5,
#  'compound build': 0.0,
#  'tractor dealer': 0.0,
#  'furnac part supplier': 0.0,
#  'heat equip supplier': 0.25,
#  'pneumat tool supplier': 0.0,
#  'truck stop': 0.0,
#  'comput hardwar manufactur': 0.667,
#  'satellit commun servic': 1.0,
#  'hospit': 0.0,
#  'electron compani': 0.0,
#  'electron part supplier': 1.0,
#  'hvac contractor': 0.333,
#  'industri engin': 0.0,
#  'contact lens supplier': 0.0,
#  'inform servic': 0.25,
#  'build': 1.0,
#  'water work equip supplier': 0.0,
#  'measur instrument supplier': 0.889,
#  'scientif equip supplier': 0.0,
#  'medic center': 0.0,
#  'watch manufactur': 0.4,
#  'corpor entertain servic': 0.0,
#  'insur': 0.75,
#  'record compani': 0.25,
#  'video duplic servic': 0.5,
#  'insur agenc': 0.75,
#  'light store': 1.0,
#  'light wholesal': 1.0,
#  'entertain agenc': 1.0,
#  'insur broker': 0.75,
#  'electr equip supplier': 0.333,
#  'electr motor store': 0.0,
#  'railroad compani': 1.0,
#  'electr suppli store': 0.333,
#  'insur compani': 0.75,
#  'factori equip supplier': 0.0,
#  'invest servic': 1.0,
#  'laser equip supplier': 0.222,
#  'execut suit rental agenc': 0.833,
#  'truck dealer': 0.0,
#  'motor vehicl dealer': 0.0,
#  'car dealer': 0.0,
#  'truck topper supplier': 0.167,
#  'polic suppli store': 0.2,
#  'iron steel contractor': 0.0,
#  'fire depart equip supplier': 0.0,
#  'tow equip provid': 1.0,
#  'logist servic': 0.286,
#  'trailer manufactur': 0.75,
#  'trailer dealer': 0.333,
#  'dealer': 1.0,
#  'auto spring shop': 0.0,
#  'auto upholster': 0.0,
#  'auto bodi part supplier': 0.5,
#  'car factori': 0.0,
#  'freight forward servic': 0.0,
#  'brake shop': 0.111,
#  'railroad equip supplier': 0.167,
#  'jewelri equip supplier': 0.545,
#  'boat builder': 1.0,
#  'ship build': 1.0,
#  'marin suppli store': 0.0,
#  'boat dealer': 0.667,
#  'kawasaki motorcycl dealer': 0.0,
#  'knife manufactur': 0.5,
#  'labor union': 0.8,
#  'furnitur maker': 1.0,
#  'bank financ': 0.5,
#  'furnitur manufactur': 1.0,
#  'logist': 0.286,
#  'massag suppli store': 0.167,
#  'telecommun equip supplier': 0.0,
#  'babi store': 0.0,
#  'mold supplier': 0.0,
#  'offic equip supplier': 0.0,
#  'offic furnitur store': 0.0,
#  'store equip supplier': 0.0,
#  'laboratori': 0.125,
#  'health beauti shop': 0.0,
#  'learn center': 0.667,
#  'dental laboratori': 0.6,
#  'land surveyor': 0.125,
#  'educ suppli store': 0.0,
#  'jewelri store': 0.0,
#  'playground equip supplier': 0.2,
#  'outdoor sport store': 0.25,
#  'toy store': 0.0,
#  'secur servic': 0.0,
#  'sign shop': 0.545,
#  'offic suppli store': 0.0,
#  'landscap': 1.0,
#  'gasket manufactur': 0.545,
#  'piano maker': 0.091,
#  'piano store': 0.25,
#  'funer home': 1.0,
#  'monument': 0.0,
#  'book publish': 0.5,
#  'wig shop': 0.167,
#  'laundromat': 0.25,
#  'auto wrecker': 0.0,
#  'auto part market': 0.5,
#  'jeep dealer': 0.0,
#  'restaur suppli store': 0.167,
#  'roof suppli store': 1.0,
#  'law firm': 0.25,
#  'build materi market': 0.0,
#  'camera store': 0.286,
#  'lawn care servic': 0.2,
#  'comput secur servic': 0.0,
#  'comput store': 0.0,
#  'design agenc': 0.25,
#  'diagnost center': 1.0,
#  'laboratori equip supplier': 0.556,
#  'home theater store': 0.0,
#  'metal industri supplier': 0.5,
#  'landscap suppli store': 0.0,
#  'applianc part supplier': 1.0,
#  'vacuum cleaner store': 0.5,
#  'audio visual equip supplier': 1.0,
#  'lawyer': 1.0,
#  'cell phone store': 0.0,
#  'bathroom suppli store': 0.0,
#  'leas servic': 1.0,
#  'construct machin dealer': 0.0,
#  'dairi farm equip supplier': 0.0,
#  'propan supplier': 0.0,
#  'legal servic': 0.5,
#  'janitori equip supplier': 1.0,
#  'life insur agenc': 0.0,
#  'railroad contractor': 1.0,
#  'swim pool suppli store': 0.2,
#  'light bulb supplier': 1.0,
#  'linen store': 0.75,
#  'metal construct compani': 0.5,
#  'local govern offic': 0.0,
#  'log contractor': 0.0,
#  'machin shop': 0.0,
#  'hotel suppli store': 0.5,
#  'import export compani': 0.0,
#  'sew compani': 0.0,
#  'research foundat': 0.75,
#  'machineri part manufactur': 0.6,
#  'sport accessori wholesal': 0.2,
#  'fashion design': 0.25,
#  'chees manufactur': 0.4,
#  'chees shop': 0.4,
#  'ship mail': 0.0,
#  'wholesal food store': 0.111,
#  'organ food store': 0.0,
#  'pie shop': 0.5,
#  'auction hous': 0.2,
#  'livestock auction hous': 0.333,
#  'cotton export': 0.143,
#  'plastic wholesal': 0.0,
#  'mail servic': 1.0,
#  'manufactur': 0.0,
#  'station': 0.0,
#  'beer distributor': 1.0,
#  'alcohol beverag wholesal': 0.5,
#  'religi good store': 1.0,
#  'book wholesal': 0.167,
#  'masonri suppli store': 0.0,
#  'wholesal florist': 0.167,
#  'florist': 1.0,
#  'marin engin': 0.0,
#  'paint store': 0.0,
#  'use auto part store': 0.0,
#  'masonri contractor': 0.25,
#  'use car dealer': 0.0,
#  'use truck dealer': 0.0,
#  'massag therapist': 0.167,
#  'materi handl equip supplier': 0.167,
#  'marina': 1.0,
#  'meat packer': 0.333,
#  'mattress store': 0.0,
#  'blind shop': 1.0,
#  'interior design': 0.25,
#  'window treatment store': 0.0,
#  'applianc store': 0.0,
#  'health food store': 0.0,
#  'direct mail advertis': 0.0,
#  'meat wholesal': 0.333,
#  'butcher shop deli': 0.167,
#  'italian groceri store': 0.0,
#  'food servic': 0.0,
#  'groceri deliveri servic': 0.0,
#  'wine store': 1.0,
#  'liquor store': 1.0,
#  'kiosk': 0.0,
#  'optometrist': 0.5,
#  'optician': 0.167,
#  'mechan contractor': 0.333,
#  'mechan engin': 0.0,
#  'cafe': 0.5,
#  'jewel': 0.2,
#  'leather good store': 0.0,
#  'gift shop': 1.0,
#  'craft store': 0.25,
#  'hobbi store': 0.0,
#  'fabric wholesal': 0.0,
#  'scrap metal dealer': 0.0,
#  'quilt shop': 0.0,
#  'sheet music store': 0.0,
#  'music instrument manufactur': 0.182,
#  'music store': 0.0,
#  'music instrument store': 0.0,
#  'band': 0.25,
#  'bookstor': 0.0,
#  'art museum': 0.0,
#  'newsstand': 0.5,
#  'medic equip manufactur': 0.6,
#  'fashion accessori store': 0.333,
#  'discount store': 0.0,
#  'cemeteri': 0.5,
#  'stop': 0.0,
#  'varieti store': 0.0,
#  'thrift store': 1.0,
#  'medic group': 0.5,
#  'donat center': 0.0,
#  'pet store': 0.2,
#  'art galleri': 0.0,
#  'art dealer': 0.0,
#  'hous develop': 0.0,
#  'mobil home dealer': 0.2,
#  'conveni store': 1.0,
#  'medic offic': 0.5,
#  'medic technolog manufactur': 0.6,
#  'children furnitur store': 0.0,
#  'mental health clinic': 0.5,
#  'airlin': 0.0,
#  'aviat consult': 0.333,
#  'travel agenc': 0.5,
#  'travel servic': 0.5,
#  'airport': 0.333,
#  'mental health servic': 0.5,
#  'ship compani': 0.0,
#  'metal fabric': 0.5,
#  'cruis line compani': 0.0,
#  'tow servic': 1.0,
#  'ferri termin': 0.0,
#  'ferri servic': 0.5,
#  'metal finish': 0.333,
#  'boat tour agenc': 1.0,
#  'move compani': 1.0,
#  'move storag servic': 1.0,
#  'state depart transport': 0.2,
#  'depart transport': 0.2,
#  'handicap transport servic': 1.0,
#  'railway servic': 1.0,
#  'train station': 0.0,
#  'depot': 0.0,
#  'charter': 0.0,
#  'metal process compani': 0.5,
#  'mix use': 0.0,
#  'motorcycl shop': 0.667,
#  'limousin servic': 1.0,
#  'chauffeur servic': 0.0,
#  'school servic': 0.0,
#  'airport shuttl servic': 0.0,
#  'tourist inform center': 0.25,
#  'carriag ride servic': 1.0,
#  'cruis agenc': 0.25,
#  'tourist attract': 0.25,
#  'ski resort': 0.5,
#  'ski area': 0.5,
#  'fix base oper': 0.0,
#  'aircraft mainten compani': 0.667,
#  'motorsport store': 0.0,
#  'boat rental servic': 0.0,
#  'util trailer dealer': 0.0,
#  'forklift dealer': 0.167,
#  'municip administr offic': 0.0,
#  'nephrologist': 0.5,
#  'coach compani': 0.0,
#  'ship servic': 0.0,
#  'ship mail servic': 0.0,
#  'newspap publish': 0.667,
#  'shred servic': 0.333,
#  'nuclear power compani': 0.4,
#  'nurs home': 1.0,
#  'media compani': 0.625,
#  'multimedia electron book publish': 0.25,
#  'internet market servic': 0.0,
#  'greet card shop': 0.5,
#  'theme park': 0.5,
#  'film product compani': 0.333,
#  'obstetrician gynecologist': 0.5,
#  'movi studio': 0.5,
#  'video product servic': 0.5,
#  'movi theater': 0.5,
#  'theater compani': 0.25,
#  'perform art theater': 0.0,
#  'occup safeti health': 0.0,
#  'offic space rental agenc': 0.0,
#  'commerci real estat agenc': 0.0,
#  'art school': 0.0,
#  'music publish': 0.0,
#  'print music publish': 0.0,
#  'home audio store': 0.0,
#  'musician': 0.25,
#  'music manag promot': 1.0,
#  'video edit servic': 0.5,
#  'offic suppli wholesal': 0.667,
#  'offici resid': 0.0,
#  'orthoped clinic': 0.5,
#  'painter': 0.0,
#  'paint': 0.167,
#  'telephon compani': 1.0,
#  'media hous': 0.625,
#  'paper distributor': 0.333,
#  'news servic': 0.5,
#  'public librari': 0.0,
#  'law librari': 0.25,
#  'museum': 1.0,
#  'feder reserv bank': 0.0,
#  'credit union': 0.25,
#  'atm': 0.333,
#  'pave contractor': 0.5,
#  'mortgag lender': 0.333,
#  'invest bank': 0.5,
#  'check cash servic': 1.0,
#  'stock broker': 0.0,
#  'health consult': 0.0,
#  'health insur agenc': 0.0,
#  'payrol servic': 0.5,
#  'pediatrician': 1.0,
#  'human resourc consult': 0.429,
#  'pest control servic': 1.0,
#  'pet board servic': 0.4,
#  'pet care': 0.4,
#  'loss adjust': 0.5,
#  'pharmaceut compani': 1.0,
#  'pharmaceut product wholesal': 1.0,
#  'pharmaci': 0.2,
#  'educ institut': 1.0,
#  'retir commun': 1.0,
#  'fratern organ': 1.0,
#  'photo lab': 0.0,
#  'properti invest': 0.25,
#  'photograph': 0.167,
#  'photographi school': 0.333,
#  'star hotel': 0.0,
#  'convent center': 0.25,
#  'real estat apprais': 0.75,
#  'photographi servic': 0.333,
#  'resort hotel': 0.25,
#  'real estat consult': 1.0,
#  'car rental agenc': 0.667,
#  'car leas servic': 0.667,
#  'ford dealer': 0.0,
#  'car financ loan compani': 0.0,
#  'trailer rental servic': 0.333,
#  'furnitur rental servic': 0.0,
#  'tuxedo shop': 0.167,
#  'dress tuxedo rental servic': 0.0,
#  'wed store': 0.0,
#  'video store': 0.0,
#  'movi rental': 0.5,
#  'photographi studio': 0.333,
#  'home health care servic': 0.0,
#  'skateboard shop': 0.091,
#  'event technolog servic': 0.0,
#  'parti equip rental servic': 0.333,
#  'construct machin rental servic': 0.0,
#  'audio visual equip rental servic': 1.0,
#  'ship equip industri': 0.0,
#  'physic therapi clinic': 0.167,
#  'plastic fabric compani': 0.273,
#  'plastic product supplier': 0.273,
#  'auto tag agenc': 0.0,
#  'depart motor vehicl': 0.2,
#  'notari public': 1.0,
#  'privat investig': 0.0,
#  'escrow servic': 0.4,
#  'real estat agent': 1.0,
#  'playground': 0.0,
#  'plumber': 0.333,
#  'port author': 1.0,
#  'portrait studio': 0.333,
#  'post offic': 1.0,
#  'profession servic': 0.333,
#  'univers hospit': 0.0,
#  'public relat firm': 0.0,
#  'civil engin compani': 1.0,
#  'draft servic': 0.75,
#  'pump supplier': 0.5,
#  'interior construct contractor': 0.0,
#  'carpet clean servic': 0.6,
#  'exhibit planner': 0.0,
#  'decal supplier': 0.0,
#  'stage light equip supplier': 0.0,
#  'event manag compani': 0.0,
#  'radio broadcast': 0.0,
#  'comput support servic': 0.0,
#  'ravin': 0.0,
#  'employ center': 0.5,
#  'nation health foundat': 0.0,
#  'real estat develop': 0.0,
#  'advertis agenc': 0.125,
#  'promot product supplier': 0.0,
#  'advertis servic': 0.125,
#  'record storag facil': 0.0,
#  'fund manag compani': 0.0,
#  'recreat center': 0.667,
#  'bakeri': 0.667,
#  'databas manag compani': 0.0,
#  'market research': 0.0,
#  'recycl center': 0.4,
#  'region govern offic': 0.0,
#  'rehabilit center': 0.5,
#  'religi institut': 1.0,
#  'religi organ': 1.0,
#  'repair servic': 0.2,
#  'emerg veterinarian servic': 0.0,
#  'pet sitter': 0.4,
#  'research product develop': 0.75,
#  'build societi': 1.0,
#  'valet park servic': 0.4,
#  'nurs agenc': 1.0,
#  'execut search firm': 0.5,
#  'recruit': 1.0,
#  'temp agenc': 0.0,
#  'health center': 0.0,
#  'restaur': 0.75,
#  'roof contractor': 0.25,
#  'sport nutrit store': 0.0,
#  'credit report agenc': 0.0,
#  'automobil storag facil': 0.0,
#  'debt collect agenc': 0.3,
#  'park': 0.2,
#  'court report': 0.3,
#  'tour agenc': 0.75,
#  'tour oper': 0.75,
#  'convent inform bureau': 0.25,
#  'balloon ride tour agenc': 1.0,
#  'secur guard servic': 0.0,
#  'locksmith': 0.4,
#  'commerci clean servic': 0.0,
#  'blast clean servic': 0.0,
#  'confer center': 0.333,
#  'safeti equip supplier': 0.0,
#  'garbag dump': 0.25,
#  'sanit servic': 0.2,
#  'garbag dump servic': 0.333,
#  'environment health servic': 0.286,
#  'portabl toilet supplier': 0.0,
#  'public work depart': 0.333,
#  'school district offic': 1.0,
#  'sailmak': 0.0,
#  'commun colleg': 0.0,
#  'salvag yard': 0.0,
#  'busi school': 0.0,
#  'trade school': 0.0,
#  'privat univers': 0.0,
#  'comput train school': 0.0,
#  'school suppli store': 0.0,
#  'screen printer': 0.5,
#  'media consult': 0.625,
#  'beauti school': 0.0,
#  'flight school': 1.0,
#  'seaport': 0.0,
#  'secur system supplier': 0.0,
#  'middl school': 1.0,
#  'nonprofit': 0.0,
#  'shoot rang': 0.167,
#  'soccer club': 0.333,
#  'camp': 1.0,
#  'dive contractor': 0.333,
#  'languag school': 0.833,
#  'english languag school': 0.0,
#  'preschool': 1.0,
#  'self storag facil': 1.0,
#  'semi conductor supplier': 0.0,
#  'drive school': 0.167,
#  'truck school': 0.0,
#  'senior citizen center': 0.333,
#  'servic': 0.0,
#  'children hospit': 0.0,
#  'dental suppli store': 0.6,
#  'shipyard': 1.0,
#  'orthodox synagogu': 0.0,
#  'short term apart rental agenc': 0.0,
#  'nutritionist': 0.167,
#  'ophthalmologist': 0.0,
#  'ophthalmolog clinic': 0.0,
#  'social servic organ': 1.0,
#  'social welfar center': 1.0,
#  'solar energi compani': 0.7,
#  'solar energi equip supplier': 0.7,
#  'special educ school': 0.0,
#  'podiatrist': 0.333,
#  'reproduct health clinic': 0.0,
#  'sport good store': 0.0,
#  'dialysi center': 0.667,
#  'sport complex': 0.333,
#  'well program': 0.0,
#  'sportswear store': 0.0,
#  'privat hospit': 0.0,
#  'radiologist': 0.0,
#  'medic diagnost imag center': 1.0,
#  'ray lab': 1.0,
#  'blood bank': 0.667,
#  'stainless steel plant': 1.0,
#  'state agenc': 0.167,
#  'heliport': 0.0,
#  'health care compani': 0.0,
#  'psychiatr hospit': 1.0,
#  'state govern offic': 0.167,
#  'medic institut': 0.0,
#  'steel construct compani': 0.125,
#  'clean servic': 0.6,
#  'steel drum supplier': 0.0,
#  'assist live facil': 0.5,
#  'steel erector': 0.125,
#  ...}

# %%
avg_pre, mean_avg_pre = calc_avg_pre(create_testing_dicts(normalization='stem')[0], create_testing_dicts(normalization='stem')[1])

# %%
avg_pre
# Out:
# {'home improv store': 0.0,
#  'diesel fuel supplier': 0.05,
#  'church': 0.125,
#  'farm': 0.061,
#  'seed supplier': 0.021,
#  'account': 0.0,
#  'truck compani': 0.033,
#  'export': 0.0,
#  'grain elev': 0.0,
#  'popcorn store': 0.069,
#  'agricultur servic': 0.167,
#  'warehous': 0.0,
#  'agricultur product': 0.048,
#  'ranch': 0.025,
#  'hold compani': 0.867,
#  'farm equip supplier': 0.0,
#  'store': 0.0,
#  'groceri store': 0.0,
#  'rice mill': 0.429,
#  'food product supplier': 0.0,
#  'account firm': 0.0,
#  'produc market': 0.0,
#  'pet suppli store': 0.1,
#  'wholesal': 0.0,
#  'produc wholesal': 0.0,
#  'distribut servic': 0.0,
#  'crop grower': 0.071,
#  'addict treatment center': 0.5,
#  'natur good store': 0.0,
#  'orchard': 0.037,
#  'lumber store': 0.036,
#  'mine': 0.117,
#  'transport servic': 0.0,
#  'invest compani': 0.133,
#  'fruit wholesal': 0.037,
#  'real estat agenc': 0.5,
#  'event venu': 0.0,
#  'frozen dessert supplier': 0.192,
#  'wine wholesal import': 0.367,
#  'wineri': 0.948,
#  'aerospac compani': 0.915,
#  'cold storag facil': 0.031,
#  'employ agenc': 0.306,
#  'plant nurseri': 0.0,
#  'air condit contractor': 0.167,
#  'air condit repair servic': 0.167,
#  'fruit veget wholesal': 0.0,
#  'aircraft rental servic': 0.0,
#  'monasteri': 1.0,
#  'allergist': 0.5,
#  'herb shop': 0.0,
#  'aluminum supplier': 0.565,
#  'ambul servic': 0.917,
#  'wholesal plant nurseri': 0.042,
#  'amus machin supplier': 0.125,
#  'anim hospit': 0.0,
#  'farmer market': 0.0,
#  'vapor store': 0.0,
#  'cigar shop': 0.167,
#  'tobacco shop': 0.0,
#  'well drill contractor': 0.332,
#  'librari': 0.408,
#  'apart build': 0.0,
#  'apart rental agenc': 0.0,
#  'dairi farm': 0.0,
#  'architect': 0.25,
#  'organ farm': 0.0,
#  'architectur design': 0.103,
#  'architectur firm': 0.103,
#  'livestock produc': 0.0,
#  'dairi supplier': 0.065,
#  'biotechnolog compani': 0.75,
#  'artist': 1.0,
#  'egg supplier': 0.463,
#  'poultri farm': 0.242,
#  'chicken hatcheri': 0.7,
#  'art organ': 0.196,
#  'associ organ': 0.18,
#  'food store': 0.0,
#  'deli': 0.0,
#  'bank': 0.113,
#  'fish process': 0.0,
#  'fish farm': 0.0,
#  'seafood wholesal': 0.139,
#  'tropic fish store': 0.0,
#  'non profit organ': 0.0,
#  'econom develop agenc': 0.244,
#  'seafood market': 0.019,
#  'honey farm': 0.567,
#  'hors breeder': 0.062,
#  'asphalt contractor': 0.0,
#  'livestock dealer': 0.333,
#  'depart store': 0.2,
#  'mill': 0.0,
#  'atv dealer': 0.556,
#  'audio visual consult': 0.25,
#  'pallet supplier': 0.286,
#  'wood supplier': 0.0,
#  'hardwar store': 0.0,
#  'furnitur wholesal': 0.0,
#  'auditor': 0.25,
#  'oil natur compani': 0.1,
#  'auto bodi shop': 0.0,
#  'boat repair shop': 1.0,
#  'associ': 0.18,
#  'rail contractor': 0.028,
#  'publish': 0.569,
#  'pond suppli store': 0.0,
#  'agricultur cooper': 0.0,
#  'print equip supplier': 0.025,
#  'auto insur agenc': 0.0,
#  'altern fuel station': 0.05,
#  'auto part manufactur': 0.0,
#  'foundat': 0.067,
#  'fertil supplier': 0.608,
#  'farm compani': 0.061,
#  'financ broker': 0.033,
#  'fire station': 0.0,
#  'environment consult': 0.064,
#  'civil engin': 1.0,
#  'fire protect servic': 0.0,
#  'compani': 0.0,
#  'oilfield': 0.0,
#  'banquet hall': 0.333,
#  'mine compani': 0.117,
#  'coalfield': 0.0,
#  'steel fabric': 0.019,
#  'quarri': 0.353,
#  'gold mine compani': 0.217,
#  'high rise build': 0.0,
#  'basketbal club': 0.167,
#  'gold dealer': 0.0,
#  'batteri manufactur': 0.548,
#  'electr util compani': 0.0,
#  'environment program': 0.048,
#  'offic': 0.0,
#  'stone supplier': 0.042,
#  'aggreg supplier': 0.0,
#  'sand gravel supplier': 0.2,
#  'build materi supplier': 0.0,
#  'beauti suppli store': 0.183,
#  'crush stone supplier': 0.0,
#  'rock shop': 0.0,
#  'road construct compani': 1.0,
#  'market consult': 0.0,
#  'blood test servic': 0.0,
#  'contractor': 0.417,
#  'excav contractor': 0.5,
#  'asphalt mix plant': 0.967,
#  'readi mix concret supplier': 0.0,
#  'sand plant': 0.2,
#  'bmw dealer': 0.0,
#  'bookbind': 1.0,
#  'garden center': 0.05,
#  'abras supplier': 0.5,
#  'granit supplier': 0.05,
#  'drill contractor': 0.419,
#  'bpo compani': 0.0,
#  'oil explor servic': 0.1,
#  'build complex': 0.0,
#  'construct equip supplier': 0.0,
#  'mine equip': 0.0,
#  'ticket agenc': 0.306,
#  'busi center': 0.0,
#  'skyscrap': 0.0,
#  'softwar compani': 0.2,
#  'busi develop servic': 0.0,
#  'busi manag consult': 0.0,
#  'cabinet maker': 0.702,
#  'call center': 0.2,
#  'cancer treatment center': 0.5,
#  'power plant consult': 0.333,
#  'busi park': 0.0,
#  'petroleum product compani': 0.156,
#  'park lot': 0.067,
#  'water util compani': 0.056,
#  'car repair mainten': 0.114,
#  'water treatment plant': 0.056,
#  'car servic': 0.114,
#  'cattl market': 0.056,
#  'sewag dispos servic': 0.532,
#  'certifi public account': 0.25,
#  'govern offic': 0.167,
#  'chariti': 0.333,
#  'air condit system supplier': 0.062,
#  'chemic industri': 0.067,
#  'chemic manufactur': 0.067,
#  'titl compani': 0.0,
#  'chemic plant': 0.067,
#  'properti manag compani': 0.025,
#  'custom home builder': 0.0,
#  'window instal servic': 0.0,
#  'fire damag restor servic': 0.0,
#  'equip rental agenc': 0.062,
#  'chemic wholesal': 0.083,
#  'financi planner': 0.1,
#  'telecommun servic provid': 0.833,
#  'energi equip solut': 0.0,
#  'chiropractor': 0.5,
#  'steel distributor': 0.0,
#  'citi govern offic': 0.5,
#  'crane servic': 0.11,
#  'garag door supplier': 0.083,
#  'industri door supplier': 0.0,
#  'citi town hall': 0.5,
#  'cloth wholesal': 0.306,
#  'coin oper laundri equip supplier': 0.433,
#  'metal supplier': 0.056,
#  'glass shop': 0.0,
#  'colleg': 1.0,
#  'side contractor': 0.046,
#  'commerci printer': 0.083,
#  'storag facil': 0.455,
#  'commun tower': 0.0,
#  'janitori servic': 0.786,
#  'comput consult': 0.0,
#  'fire protect system supplier': 0.0,
#  'elev servic': 0.091,
#  'industri equip supplier': 0.0,
#  'dri wall contractor': 0.0,
#  'insul contractor': 0.083,
#  'concret contractor': 0.128,
#  'scaffold rental servic': 0.062,
#  'construct compani': 0.7,
#  'floor store': 0.0,
#  'floor contractor': 0.033,
#  'tile contractor': 0.287,
#  'tile manufactur': 0.287,
#  'glass mirror shop': 0.0,
#  'construct materi wholesal': 0.0,
#  'gutter clean servic': 0.1,
#  'sheet metal contractor': 0.125,
#  'consult': 0.714,
#  'contain servic': 0.062,
#  'septic system servic': 0.442,
#  'corpor campu': 0.0,
#  'water damag restor servic': 0.0,
#  'welder': 0.0,
#  'corpor offic': 0.0,
#  'anim': 0.321,
#  'anim feed store': 0.0,
#  'anim protect organ': 0.0,
#  'brew suppli store': 0.0,
#  'cosmet store': 0.202,
#  'counti govern offic': 0.239,
#  'sugar factori': 0.731,
#  'confectioneri wholesal': 0.148,
#  'financi institut': 0.0,
#  'candi store': 0.0,
#  'confectioneri': 0.0,
#  'chocol factori': 0.877,
#  'chocol shop': 0.877,
#  'courier servic': 0.5,
#  'cowork space': 0.0,
#  'frozen food manufactur': 0.333,
#  'beverag distributor': 0.0,
#  'agricultur organ': 0.0,
#  'dairi store': 0.065,
#  'dairi': 0.0,
#  'ice cream shop': 0.067,
#  'medic laboratori': 0.417,
#  'demolit contractor': 0.833,
#  'meat processor': 0.771,
#  'fmcg manufactur': 0.0,
#  'garbag collect servic': 0.111,
#  'wholesal bakeri': 0.0,
#  'dentist': 0.143,
#  'dessert shop': 0.033,
#  'cupcak shop': 0.0,
#  'nut store': 0.0,
#  'wholesal grocer': 0.056,
#  'design engin': 0.0,
#  'busi busi servic': 0.0,
#  'condiment supplier': 1.0,
#  'digit print servic': 0.492,
#  'culinari school': 0.25,
#  'import': 0.0,
#  'bottl water supplier': 0.129,
#  'coffe roaster': 0.486,
#  'packag suppli store': 0.056,
#  'ice supplier': 0.194,
#  'breweri': 1.0,
#  'winemak compani': 0.0,
#  'distilleri': 0.0,
#  'disabl servic support organis': 0.556,
#  'district govern offic': 0.0,
#  'air filter supplier': 0.556,
#  'tire shop': 0.05,
#  'fasten supplier': 0.413,
#  'fabric product manufactur': 0.056,
#  'textil': 0.361,
#  'textil export': 0.361,
#  'textil engin': 0.361,
#  'fabric store': 0.0,
#  'knit shop': 0.172,
#  'doctor': 0.833,
#  'lamin servic': 0.045,
#  'plastic resin manufactur': 0.048,
#  'carpet manufactur': 0.1,
#  'upholsteri shop': 0.022,
#  'busi administr servic': 0.0,
#  'furnitur store': 0.0,
#  'dri cleaner': 0.0,
#  'packag compani': 0.056,
#  'duti free store': 0.0,
#  'commerc servic': 0.0,
#  'cabl compani': 0.125,
#  'educ': 0.167,
#  'outlet store': 0.0,
#  'lingeri store': 0.083,
#  'cloth fabric manufactur': 0.0,
#  'educ center': 0.167,
#  'uniform store': 0.021,
#  'men cloth store': 0.021,
#  'cloth store': 0.083,
#  'women cloth store': 0.017,
#  'western apparel store': 0.083,
#  'costum store': 0.171,
#  'game store': 0.0,
#  'hat shop': 0.042,
#  'leather good manufactur': 0.0,
#  'educ consult': 0.167,
#  'leather export': 0.667,
#  'shoe store': 0.167,
#  'boutiqu': 0.0,
#  'leather wholesal': 0.0,
#  'handbag shop': 0.833,
#  'electron store': 0.0,
#  'luggag store': 0.292,
#  'build materi store': 0.0,
#  'saw mill': 0.417,
#  'electr engin': 0.0,
#  'deck builder': 0.033,
#  'concret product supplier': 0.352,
#  'plywood supplier': 0.332,
#  'electr instal servic': 0.033,
#  'truss manufactur': 0.117,
#  'door supplier': 0.036,
#  'wood lamin floor supplier': 0.651,
#  'aircraft suppli store': 0.0,
#  'modular home builder': 0.0,
#  'portabl build manufactur': 0.0,
#  'modular home dealer': 0.0,
#  'mulch supplier': 0.083,
#  'electrician': 0.167,
#  'paper mill': 0.271,
#  'energi supplier': 0.181,
#  'engin': 0.018,
#  'print shop': 1.0,
#  'custom label printer': 0.0,
#  'market': 0.0,
#  'market agenc': 0.0,
#  'engin consult': 0.018,
#  'entertain': 0.042,
#  'envelop supplier': 0.071,
#  'oil refineri': 0.0,
#  'record studio': 0.062,
#  'environ renew natur resourc': 0.0,
#  'finish materi supplier': 0.0,
#  'event ticket seller': 0.0,
#  'waterproof compani': 0.167,
#  'auto part store': 0.05,
#  'heat oil supplier': 0.0,
#  'famili practic physician': 0.0,
#  'machin manufactur': 0.033,
#  'industri supplier': 0.167,
#  'weld suppli store': 0.036,
#  'dri ice supplier': 0.0,
#  'privat equiti firm': 0.0,
#  'famili servic center': 0.333,
#  'feder govern offic': 0.024,
#  'vitamin supplement store': 0.1,
#  'feed manufactur': 0.5,
#  'medic equip supplier': 0.024,
#  'medic suppli store': 0.024,
#  'medic clinic': 0.056,
#  'research institut': 0.75,
#  'biochem supplier': 0.0,
#  'fiber optic product supplier': 0.0,
#  'paint manufactur': 0.25,
#  'equip supplier': 0.12,
#  'food': 0.312,
#  'pipe supplier': 0.284,
#  'oil field equip supplier': 0.0,
#  'food broker': 0.0,
#  'food manufactur': 0.25,
#  'food process compani': 0.312,
#  'fenc suppli store': 0.062,
#  'food produc': 0.312,
#  'forestri servic': 0.2,
#  'foundri': 1.0,
#  'wholesal jewel': 0.0,
#  'cooki shop': 0.762,
#  'truck rental agenc': 0.0,
#  'fruit veget process': 0.174,
#  'kitchen suppli store': 0.0,
#  'hydraul equip supplier': 0.0,
#  'irrig equip supplier': 0.167,
#  'bear supplier': 0.451,
#  'metallurgi compani': 1.0,
#  'plastic inject mold servic': 0.0,
#  'gener contractor': 0.25,
#  'gener hospit': 0.0,
#  'tool manufactur': 0.683,
#  'industri design compani': 0.0,
#  'hyundai dealer': 0.0,
#  'glass industri': 0.575,
#  'polym supplier': 0.0,
#  'print equip suppli': 0.025,
#  'toner cartridg supplier': 0.1,
#  'printer repair servic': 0.042,
#  'fuel supplier': 0.0,
#  'glass manufactur': 0.575,
#  'plastic bag supplier': 0.182,
#  'glasswar manufactur': 0.375,
#  'polythen plastic sheet supplier': 0.0,
#  'pvc industri': 0.045,
#  'countertop store': 0.062,
#  'cabinet store': 0.028,
#  'fiberglass supplier': 0.05,
#  'golf cart dealer': 0.0,
#  'auto repair shop': 0.0,
#  'hose supplier': 0.4,
#  'rubber product supplier': 0.333,
#  'automot': 0.0,
#  'commerci refriger supplier': 0.0,
#  'golf club': 0.167,
#  'golf cours': 0.167,
#  'green energi supplier': 0.0,
#  'greenhous': 0.333,
#  'auto glass shop': 0.0,
#  'light manufactur': 1.0,
#  'cement manufactur': 0.067,
#  'brick manufactur': 0.124,
#  'natur stone supplier': 0.0,
#  'gym': 0.167,
#  'marbl supplier': 0.05,
#  'corpor gift supplier': 0.0,
#  'shipbuild repair compani': 0.0,
#  'construct mainten offic': 0.7,
#  'boiler manufactur': 0.302,
#  'contain supplier': 0.062,
#  'home construct': 0.028,
#  'health': 0.25,
#  'heart hospit': 0.0,
#  'spring supplier': 0.583,
#  'electr util manufactur': 0.0,
#  'aircraft manufactur': 0.458,
#  'metal heat treat servic': 0.033,
#  'plate servic': 0.15,
#  'autom compani': 0.0,
#  'heat contractor': 0.417,
#  'plumb suppli store': 0.062,
#  'gun shop': 0.125,
#  'ammunit supplier': 0.501,
#  'pipe manufactur': 0.284,
#  'school': 0.5,
#  'fire protect equip supplier': 0.0,
#  'agricultur machineri manufactur': 0.029,
#  'lawn mower store': 0.0,
#  'lawn irrig equip supplier': 0.0,
#  'financi consult': 0.1,
#  'helicopt charter': 0.122,
#  'packag machineri': 0.0,
#  'histor landmark': 0.306,
#  'electron manufactur': 0.056,
#  'graphic design': 0.146,
#  'eye care center': 0.167,
#  'optic product manufactur': 0.833,
#  'imag consult': 0.0,
#  'clean product supplier': 0.0,
#  'fireplac store': 0.042,
#  'home builder': 0.028,
#  'tool die shop': 0.683,
#  'metal stamp servic': 0.0,
#  'environment organ': 0.048,
#  'food process equip': 0.022,
#  'loan agenc': 0.178,
#  'power plant equip supplier': 0.0,
#  'home good store': 0.033,
#  'engin rebuild servic': 0.0,
#  'air compressor supplier': 0.0,
#  'honda dealer': 0.0,
#  'elev manufactur': 0.091,
#  'crane dealer': 0.11,
#  'crane rental agenc': 0.125,
#  'compound build': 0.0,
#  'tractor dealer': 0.0,
#  'furnac part supplier': 0.0,
#  'heat equip supplier': 0.036,
#  'pneumat tool supplier': 0.0,
#  'truck stop': 0.0,
#  'comput hardwar manufactur': 0.157,
#  'satellit commun servic': 0.167,
#  'hospit': 0.0,
#  'electron compani': 0.0,
#  'electron part supplier': 0.569,
#  'hvac contractor': 0.333,
#  'industri engin': 0.0,
#  'contact lens supplier': 0.0,
#  'inform servic': 0.25,
#  'build': 0.7,
#  'water work equip supplier': 0.0,
#  'measur instrument supplier': 0.889,
#  'scientif equip supplier': 0.0,
#  'medic center': 0.0,
#  'watch manufactur': 0.13,
#  'corpor entertain servic': 0.0,
#  'insur': 0.221,
#  'record compani': 0.062,
#  'video duplic servic': 0.319,
#  'insur agenc': 0.221,
#  'light store': 1.0,
#  'light wholesal': 1.0,
#  'entertain agenc': 0.167,
#  'insur broker': 0.221,
#  'electr equip supplier': 0.037,
#  'electr motor store': 0.0,
#  'railroad compani': 0.833,
#  'electr suppli store': 0.037,
#  'insur compani': 0.221,
#  'factori equip supplier': 0.0,
#  'invest servic': 0.519,
#  'laser equip supplier': 0.059,
#  'execut suit rental agenc': 0.327,
#  'truck dealer': 0.0,
#  'motor vehicl dealer': 0.0,
#  'car dealer': 0.0,
#  'truck topper supplier': 0.028,
#  'polic suppli store': 0.02,
#  'iron steel contractor': 0.0,
#  'fire depart equip supplier': 0.0,
#  'tow equip provid': 0.31,
#  'logist servic': 0.238,
#  'trailer manufactur': 0.75,
#  'trailer dealer': 0.048,
#  'dealer': 0.7,
#  'auto spring shop': 0.0,
#  'auto upholster': 0.0,
#  'auto bodi part supplier': 0.05,
#  'car factori': 0.0,
#  'freight forward servic': 0.0,
#  'brake shop': 0.019,
#  'railroad equip supplier': 0.033,
#  'jewelri equip supplier': 0.499,
#  'boat builder': 1.0,
#  'ship build': 0.833,
#  'marin suppli store': 0.0,
#  'boat dealer': 0.217,
#  'kawasaki motorcycl dealer': 0.0,
#  'knife manufactur': 0.5,
#  'labor union': 0.282,
#  'furnitur maker': 0.958,
#  'bank financ': 0.113,
#  'furnitur manufactur': 0.958,
#  'logist': 0.238,
#  'massag suppli store': 0.033,
#  'telecommun equip supplier': 0.0,
#  'babi store': 0.0,
#  'mold supplier': 0.0,
#  'offic equip supplier': 0.0,
#  'offic furnitur store': 0.0,
#  'store equip supplier': 0.0,
#  'laboratori': 0.021,
#  'health beauti shop': 0.0,
#  'learn center': 0.345,
#  'dental laboratori': 0.36,
#  'land surveyor': 0.021,
#  'educ suppli store': 0.0,
#  'jewelri store': 0.0,
#  'playground equip supplier': 0.1,
#  'outdoor sport store': 0.031,
#  'toy store': 0.0,
#  'secur servic': 0.0,
#  'sign shop': 0.545,
#  'offic suppli store': 0.0,
#  'landscap': 0.786,
#  'gasket manufactur': 0.391,
#  'piano maker': 0.03,
#  'piano store': 0.125,
#  'funer home': 1.0,
#  'monument': 0.0,
#  'book publish': 0.378,
#  'wig shop': 0.083,
#  'laundromat': 0.25,
#  'auto wrecker': 0.0,
#  'auto part market': 0.05,
#  'jeep dealer': 0.0,
#  'restaur suppli store': 0.033,
#  'roof suppli store': 0.525,
#  'law firm': 0.25,
#  'build materi market': 0.0,
#  'camera store': 0.107,
#  'lawn care servic': 0.04,
#  'comput secur servic': 0.0,
#  'comput store': 0.0,
#  'design agenc': 0.028,
#  'diagnost center': 1.0,
#  'laboratori equip supplier': 0.288,
#  'home theater store': 0.0,
#  'metal industri supplier': 0.056,
#  'landscap suppli store': 0.0,
#  'applianc part supplier': 0.294,
#  'vacuum cleaner store': 0.05,
#  'audio visual equip supplier': 0.25,
#  'lawyer': 0.887,
#  'cell phone store': 0.0,
#  'bathroom suppli store': 0.0,
#  'leas servic': 0.582,
#  'construct machin dealer': 0.0,
#  'dairi farm equip supplier': 0.0,
#  'propan supplier': 0.0,
#  'legal servic': 0.5,
#  'janitori equip supplier': 0.786,
#  'life insur agenc': 0.0,
#  'railroad contractor': 0.167,
#  'swim pool suppli store': 0.04,
#  'light bulb supplier': 1.0,
#  'linen store': 0.417,
#  'metal construct compani': 0.151,
#  'local govern offic': 0.0,
#  'log contractor': 0.0,
#  'machin shop': 0.0,
#  'hotel suppli store': 0.333,
#  'import export compani': 0.0,
#  'sew compani': 0.0,
#  'research foundat': 0.75,
#  'machineri part manufactur': 0.342,
#  'sport accessori wholesal': 0.02,
#  'fashion design': 0.028,
#  'chees manufactur': 0.333,
#  'chees shop': 0.333,
#  'ship mail': 0.0,
#  'wholesal food store': 0.056,
#  'organ food store': 0.0,
#  'pie shop': 0.317,
#  'auction hous': 0.2,
#  'livestock auction hous': 0.333,
#  'cotton export': 0.071,
#  'plastic wholesal': 0.0,
#  'mail servic': 0.1,
#  'manufactur': 0.0,
#  'station': 0.0,
#  'beer distributor': 0.5,
#  'alcohol beverag wholesal': 0.167,
#  'religi good store': 0.5,
#  'book wholesal': 0.042,
#  'masonri suppli store': 0.0,
#  'wholesal florist': 0.042,
#  'florist': 0.125,
#  'marin engin': 0.0,
#  'paint store': 0.0,
#  'use auto part store': 0.0,
#  'masonri contractor': 0.087,
#  'use car dealer': 0.0,
#  'use truck dealer': 0.0,
#  'massag therapist': 0.042,
#  'materi handl equip supplier': 0.019,
#  'marina': 1.0,
#  'meat packer': 0.114,
#  'mattress store': 0.0,
#  'blind shop': 0.6,
#  'interior design': 0.062,
#  'window treatment store': 0.0,
#  'applianc store': 0.0,
#  'health food store': 0.0,
#  'direct mail advertis': 0.0,
#  'meat wholesal': 0.114,
#  'butcher shop deli': 0.167,
#  'italian groceri store': 0.0,
#  'food servic': 0.0,
#  'groceri deliveri servic': 0.0,
#  'wine store': 0.111,
#  'liquor store': 0.25,
#  'kiosk': 0.0,
#  'optometrist': 0.35,
#  'optician': 0.028,
#  'mechan contractor': 0.111,
#  'mechan engin': 0.0,
#  'cafe': 0.113,
#  'jewel': 0.2,
#  'leather good store': 0.0,
#  'gift shop': 0.393,
#  'craft store': 0.083,
#  'hobbi store': 0.0,
#  'fabric wholesal': 0.0,
#  'scrap metal dealer': 0.0,
#  'quilt shop': 0.0,
#  'sheet music store': 0.0,
#  'music instrument manufactur': 0.031,
#  'music store': 0.0,
#  'music instrument store': 0.0,
#  'band': 0.05,
#  'bookstor': 0.0,
#  'art museum': 0.0,
#  'newsstand': 0.5,
#  'medic equip manufactur': 0.475,
#  'fashion accessori store': 0.057,
#  'discount store': 0.0,
#  'cemeteri': 0.25,
#  'stop': 0.0,
#  'varieti store': 0.0,
#  'thrift store': 1.0,
#  'medic group': 0.056,
#  'donat center': 0.0,
#  'pet store': 0.1,
#  'art galleri': 0.0,
#  'art dealer': 0.0,
#  'hous develop': 0.0,
#  'mobil home dealer': 0.04,
#  'conveni store': 0.292,
#  'medic offic': 0.056,
#  'medic technolog manufactur': 0.475,
#  'children furnitur store': 0.0,
#  'mental health clinic': 0.187,
#  'airlin': 0.0,
#  'aviat consult': 0.033,
#  'travel agenc': 0.306,
#  'travel servic': 0.306,
#  'airport': 0.333,
#  'mental health servic': 0.187,
#  'ship compani': 0.0,
#  'metal fabric': 0.151,
#  'cruis line compani': 0.0,
#  'tow servic': 0.31,
#  'ferri termin': 0.0,
#  'ferri servic': 0.1,
#  'metal finish': 0.033,
#  'boat tour agenc': 0.167,
#  'move compani': 0.556,
#  'move storag servic': 0.556,
#  'state depart transport': 0.025,
#  'depart transport': 0.02,
#  'handicap transport servic': 1.0,
#  'railway servic': 0.143,
#  'train station': 0.0,
#  'depot': 0.0,
#  'charter': 0.0,
#  'metal process compani': 0.151,
#  'mix use': 0.0,
#  'motorcycl shop': 0.444,
#  'limousin servic': 1.0,
#  'chauffeur servic': 0.0,
#  'school servic': 0.0,
#  'airport shuttl servic': 0.0,
#  'tourist inform center': 0.042,
#  'carriag ride servic': 0.25,
#  'cruis agenc': 0.125,
#  'tourist attract': 0.042,
#  'ski resort': 0.433,
#  'ski area': 0.433,
#  'fix base oper': 0.0,
#  'aircraft mainten compani': 0.15,
#  'motorsport store': 0.0,
#  'boat rental servic': 0.0,
#  'util trailer dealer': 0.0,
#  'forklift dealer': 0.042,
#  'municip administr offic': 0.0,
#  'nephrologist': 0.5,
#  'coach compani': 0.0,
#  'ship servic': 0.0,
#  'ship mail servic': 0.0,
#  'newspap publish': 0.554,
#  'shred servic': 0.083,
#  'nuclear power compani': 0.118,
#  'nurs home': 1.0,
#  'media compani': 0.362,
#  'multimedia electron book publish': 0.25,
#  'internet market servic': 0.0,
#  'greet card shop': 0.1,
#  'theme park': 0.5,
#  'film product compani': 0.122,
#  'obstetrician gynecologist': 0.5,
#  'movi studio': 0.125,
#  'video product servic': 0.319,
#  'movi theater': 0.125,
#  'theater compani': 0.25,
#  'perform art theater': 0.0,
#  'occup safeti health': 0.0,
#  'offic space rental agenc': 0.0,
#  'commerci real estat agenc': 0.0,
#  'art school': 0.0,
#  'music publish': 0.0,
#  'print music publish': 0.0,
#  'home audio store': 0.0,
#  'musician': 0.25,
#  'music manag promot': 0.125,
#  'video edit servic': 0.319,
#  'offic suppli wholesal': 0.167,
#  'offici resid': 0.0,
#  'orthoped clinic': 0.167,
#  'painter': 0.0,
#  'paint': 0.019,
#  'telephon compani': 0.225,
#  'media hous': 0.362,
#  'paper distributor': 0.056,
#  'news servic': 0.05,
#  'public librari': 0.0,
#  'law librari': 0.125,
#  'museum': 1.0,
#  'feder reserv bank': 0.0,
#  'credit union': 0.031,
#  'atm': 0.167,
#  'pave contractor': 0.5,
#  'mortgag lender': 0.037,
#  'invest bank': 0.133,
#  'check cash servic': 0.806,
#  'stock broker': 0.0,
#  'health consult': 0.0,
#  'health insur agenc': 0.0,
#  'payrol servic': 0.5,
#  'pediatrician': 1.0,
#  'human resourc consult': 0.3,
#  'pest control servic': 0.686,
#  'pet board servic': 0.167,
#  'pet care': 0.167,
#  'loss adjust': 0.091,
#  'pharmaceut compani': 0.444,
#  'pharmaceut product wholesal': 0.167,
#  'pharmaci': 0.067,
#  'educ institut': 0.25,
#  'retir commun': 0.45,
#  'fratern organ': 1.0,
#  'photo lab': 0.0,
#  'properti invest': 0.025,
#  'photograph': 0.019,
#  'photographi school': 0.333,
#  'star hotel': 0.0,
#  'convent center': 0.083,
#  'real estat apprais': 0.249,
#  'photographi servic': 0.333,
#  'resort hotel': 0.083,
#  'real estat consult': 0.5,
#  'car rental agenc': 0.122,
#  'car leas servic': 0.122,
#  'ford dealer': 0.0,
#  'car financ loan compani': 0.0,
#  'trailer rental servic': 0.048,
#  'furnitur rental servic': 0.0,
#  'tuxedo shop': 0.056,
#  'dress tuxedo rental servic': 0.0,
#  'wed store': 0.0,
#  'video store': 0.0,
#  'movi rental': 0.125,
#  'photographi studio': 0.333,
#  'home health care servic': 0.0,
#  'skateboard shop': 0.091,
#  'event technolog servic': 0.0,
#  'parti equip rental servic': 0.097,
#  'construct machin rental servic': 0.0,
#  'audio visual equip rental servic': 0.25,
#  'ship equip industri': 0.0,
#  'physic therapi clinic': 0.042,
#  'plastic fabric compani': 0.182,
#  'plastic product supplier': 0.182,
#  'auto tag agenc': 0.0,
#  'depart motor vehicl': 0.02,
#  'notari public': 1.0,
#  'privat investig': 0.0,
#  'escrow servic': 0.233,
#  'real estat agent': 0.5,
#  'playground': 0.0,
#  'plumber': 0.056,
#  'port author': 0.607,
#  'portrait studio': 0.204,
#  'post offic': 0.143,
#  'profession servic': 0.222,
#  'univers hospit': 0.0,
#  'public relat firm': 0.0,
#  'civil engin compani': 1.0,
#  'draft servic': 0.379,
#  'pump supplier': 0.369,
#  'interior construct contractor': 0.0,
#  'carpet clean servic': 0.192,
#  'exhibit planner': 0.0,
#  'decal supplier': 0.0,
#  'stage light equip supplier': 0.0,
#  'event manag compani': 0.0,
#  'radio broadcast': 0.0,
#  'comput support servic': 0.0,
#  'ravin': 0.0,
#  'employ center': 0.306,
#  'nation health foundat': 0.0,
#  'real estat develop': 0.0,
#  'advertis agenc': 0.025,
#  'promot product supplier': 0.0,
#  'advertis servic': 0.025,
#  'record storag facil': 0.0,
#  'fund manag compani': 0.0,
#  'recreat center': 0.462,
#  'bakeri': 0.444,
#  'databas manag compani': 0.0,
#  'market research': 0.0,
#  'recycl center': 0.18,
#  'region govern offic': 0.0,
#  'rehabilit center': 0.1,
#  'religi institut': 0.5,
#  'religi organ': 0.5,
#  'repair servic': 0.1,
#  'emerg veterinarian servic': 0.0,
#  'pet sitter': 0.167,
#  'research product develop': 0.75,
#  'build societi': 0.7,
#  'valet park servic': 0.4,
#  'nurs agenc': 1.0,
#  'execut search firm': 0.375,
#  'recruit': 1.0,
#  'temp agenc': 0.0,
#  'health center': 0.0,
#  'restaur': 0.396,
#  'roof contractor': 0.153,
#  'sport nutrit store': 0.0,
#  'credit report agenc': 0.0,
#  'automobil storag facil': 0.0,
#  'debt collect agenc': 0.097,
#  'park': 0.067,
#  'court report': 0.192,
#  'tour agenc': 0.271,
#  'tour oper': 0.271,
#  'convent inform bureau': 0.083,
#  'balloon ride tour agenc': 0.167,
#  'secur guard servic': 0.0,
#  'locksmith': 0.4,
#  'commerci clean servic': 0.0,
#  'blast clean servic': 0.0,
#  'confer center': 0.333,
#  'safeti equip supplier': 0.0,
#  'garbag dump': 0.031,
#  'sanit servic': 0.067,
#  'garbag dump servic': 0.111,
#  'environment health servic': 0.064,
#  'portabl toilet supplier': 0.0,
#  'public work depart': 0.061,
#  'school district offic': 0.5,
#  'sailmak': 0.0,
#  'commun colleg': 0.0,
#  'salvag yard': 0.0,
#  'busi school': 0.0,
#  'trade school': 0.0,
#  'privat univers': 0.0,
#  'comput train school': 0.0,
#  'school suppli store': 0.0,
#  'screen printer': 0.417,
#  'media consult': 0.362,
#  'beauti school': 0.0,
#  'flight school': 0.517,
#  'seaport': 0.0,
#  'secur system supplier': 0.0,
#  'middl school': 1.0,
#  'nonprofit': 0.0,
#  'shoot rang': 0.083,
#  'soccer club': 0.333,
#  'camp': 0.643,
#  'dive contractor': 0.333,
#  'languag school': 0.449,
#  'english languag school': 0.0,
#  'preschool': 1.0,
#  'self storag facil': 0.793,
#  'semi conductor supplier': 0.0,
#  'drive school': 0.033,
#  'truck school': 0.0,
#  'senior citizen center': 0.111,
#  'servic': 0.0,
#  'children hospit': 0.0,
#  'dental suppli store': 0.36,
#  'shipyard': 1.0,
#  'orthodox synagogu': 0.0,
#  'short term apart rental agenc': 0.0,
#  'nutritionist': 0.167,
#  'ophthalmologist': 0.0,
#  'ophthalmolog clinic': 0.0,
#  'social servic organ': 0.633,
#  'social welfar center': 0.633,
#  'solar energi compani': 0.371,
#  'solar energi equip supplier': 0.371,
#  'special educ school': 0.0,
#  'podiatrist': 0.333,
#  'reproduct health clinic': 0.0,
#  'sport good store': 0.0,
#  'dialysi center': 0.667,
#  'sport complex': 0.204,
#  'well program': 0.0,
#  'sportswear store': 0.0,
#  'privat hospit': 0.0,
#  'radiologist': 0.0,
#  'medic diagnost imag center': 0.417,
#  'ray lab': 0.5,
#  'blood bank': 0.3,
#  'stainless steel plant': 0.5,
#  'state agenc': 0.019,
#  'heliport': 0.0,
#  'health care compani': 0.0,
#  'psychiatr hospit': 1.0,
#  'state govern offic': 0.019,
#  'medic institut': 0.0,
#  'steel construct compani': 0.025,
#  'clean servic': 0.3,
#  'steel drum supplier': 0.0,
#  'assist live facil': 0.056,
#  'steel erector': 0.025,
#  ...}

# %%
mean_avg_pre
# Out:
# 0.186

# %%
calc_NDCG_at_n(create_testing_dicts(normalization='stem')[0], create_testing_dicts(normalization='stem')[1], n=-1, base=2)
# Out:
# {'home improv store': 0.37488311901084637,
#  'diesel fuel supplier': 0.7094988669199906,
#  'church': 0.8934099845459849,
#  'farm': 0.3359741328967002,
#  'seed supplier': 0.3370042346712697,
#  'account': 0.37488311901084637,
#  'truck compani': 0.5380180285434618,
#  'export': 0.20341748548710972,
#  'grain elev': 0.37488311901084637,
#  'popcorn store': 0.4138609632427184,
#  'agricultur servic': 0.42991332271992105,
#  'warehous': 0.37488311901084637,
#  'agricultur product': 0.37439397160220267,
#  'ranch': 0.43931428176353743,
#  'hold compani': 0.9293020998846204,
#  'farm equip supplier': 0.24409514662261833,
#  'store': 0.6365616336988094,
#  'groceri store': 0.6365616336988094,
#  'rice mill': 0.8366662357680575,
#  'food product supplier': 0.14833755686686634,
#  'account firm': 0.37488311901084637,
#  'produc market': 0.24409514662261833,
#  'pet suppli store': 0.35581457655797505,
#  'wholesal': 0.6365616336988094,
#  'produc wholesal': 0.14833755686686634,
#  'distribut servic': 0.20341748548710972,
#  'crop grower': 0.47440880448460354,
#  'addict treatment center': 0.8475982933896377,
#  'natur good store': 0.2989251547368574,
#  'orchard': 0.2017721420527986,
#  'lumber store': 0.4765378536522128,
#  'mine': 0.5368066219547875,
#  'transport servic': 0.6365616336988094,
#  'invest compani': 0.6193695950697208,
#  'fruit wholesal': 0.1661490852621771,
#  'real estat agenc': 1.0,
#  'event venu': 0.48270920670499107,
#  'frozen dessert supplier': 0.5127795298668696,
#  'wine wholesal import': 0.8416058145148295,
#  'wineri': 0.9501879401842349,
#  'aerospac compani': 0.9676985902998954,
#  'cold storag facil': 0.4700100922261463,
#  'employ agenc': 0.705277866983292,
#  'plant nurseri': 0.6365616336988094,
#  'air condit contractor': 0.7583071004454944,
#  'air condit repair servic': 0.7583071004454944,
#  'fruit veget wholesal': 0.24409514662261833,
#  'aircraft rental servic': 0.37488311901084637,
#  'monasteri': 1.0,
#  'allergist': 1.0,
#  'herb shop': 0.2989251547368574,
#  'aluminum supplier': 0.6744285184232585,
#  'ambul servic': 0.8819413462977922,
#  'wholesal plant nurseri': 0.2673224186347812,
#  'amus machin supplier': 0.7577077557992062,
#  'anim hospit': 0.24409514662261833,
#  'farmer market': 0.14285714285714285,
#  'vapor store': 0.27344333252192715,
#  'cigar shop': 0.6365220046885751,
#  'tobacco shop': 0.2989251547368574,
#  'well drill contractor': 0.6820918078258305,
#  'librari': 0.6494510429808847,
#  'apart build': 0.37488311901084637,
#  'apart rental agenc': 0.37488311901084637,
#  'dairi farm': 0.37488311901084637,
#  'architect': 0.7425684929788066,
#  'organ farm': 0.20341748548710972,
#  'architectur design': 0.33262559402287944,
#  'architectur firm': 0.33262559402287944,
#  'livestock produc': 0.37488311901084637,
#  'dairi supplier': 0.25084089902346995,
#  'biotechnolog compani': 0.9661179301650845,
#  'artist': 1.0,
#  'egg supplier': 0.680676344503465,
#  'poultri farm': 0.6806928482409674,
#  'chicken hatcheri': 0.8278600394102978,
#  'art organ': 0.5248049965468942,
#  'associ organ': 0.6489875439248499,
#  'food store': 0.6365616336988094,
#  'deli': 0.2,
#  'bank': 0.5106972125673794,
#  'fish process': 0.8401149768189771,
#  'fish farm': 0.48270920670499107,
#  'seafood wholesal': 0.26125997521525685,
#  'tropic fish store': 0.1945418823618167,
#  'non profit organ': 0.8401149768189771,
#  'econom develop agenc': 0.6013188782876562,
#  'seafood market': 0.2587499236293894,
#  'honey farm': 0.7171303014042586,
#  'hors breeder': 0.41055573396658385,
#  'asphalt contractor': 0.6365616336988094,
#  'livestock dealer': 0.5745751712851589,
#  'depart store': 0.9089737082900646,
#  'mill': 0.6365616336988094,
#  'atv dealer': 0.8437466104869134,
#  'audio visual consult': 0.9200574884094885,
#  'pallet supplier': 0.513121850055674,
#  'wood supplier': 0.37488311901084637,
#  'hardwar store': 0.37488311901084637,
#  'furnitur wholesal': 0.6365616336988094,
#  'auditor': 0.6087448857095201,
#  'oil natur compani': 0.5264828420213281,
#  'auto bodi shop': 0.14833755686686634,
#  'boat repair shop': 1.0,
#  'associ': 0.6489875439248499,
#  'rail contractor': 0.35192157121028417,
#  'publish': 0.7857810711718708,
#  'pond suppli store': 0.2857142857142857,
#  'agricultur cooper': 0.2989251547368574,
#  'print equip supplier': 0.3178882953438966,
#  'auto insur agenc': 0.37488311901084637,
#  'altern fuel station': 0.7094988669199906,
#  'auto part manufactur': 0.17245330615262136,
#  'foundat': 0.6014027589934278,
#  'fertil supplier': 0.7736640213362871,
#  'farm compani': 0.3359741328967002,
#  'financ broker': 0.5380180285434618,
#  'fire station': 0.20341748548710972,
#  'environment consult': 0.31042072637202806,
#  'civil engin': 1.0,
#  'fire protect servic': 0.20341748548710972,
#  'compani': 0.37488311901084637,
#  'oilfield': 0,
#  'banquet hall': 0.6997292924605046,
#  'mine compani': 0.5368066219547875,
#  'coalfield': 0,
#  'steel fabric': 0.2587499236293894,
#  'quarri': 0.3894675741140442,
#  'gold mine compani': 0.471865956278566,
#  'high rise build': 0.6365616336988094,
#  'basketbal club': 0.7253551569309719,
#  'gold dealer': 0.2989251547368574,
#  'batteri manufactur': 0.674840018238358,
#  'electr util compani': 0.2989251547368574,
#  'environment program': 0.5154325235390578,
#  'offic': 0.8401149768189771,
#  'stone supplier': 0.48528352890703774,
#  'aggreg supplier': 0.24152948254127113,
#  'sand gravel supplier': 0.36091118361649976,
#  'build materi supplier': 0.37488311901084637,
#  'beauti suppli store': 0.47330225720508345,
#  'crush stone supplier': 0.37488311901084637,
#  'rock shop': 0.2989251547368574,
#  'road construct compani': 1.0,
#  'market consult': 0.20341748548710972,
#  'blood test servic': 0.17245330615262136,
#  'contractor': 0.8514391906394404,
#  'excav contractor': 0.8742686287246381,
#  'asphalt mix plant': 0.9910700137756355,
#  'readi mix concret supplier': 0.2989251547368574,
#  'sand plant': 0.3628129372431496,
#  'bmw dealer': 0,
#  'bookbind': 0.9110227062871531,
#  'garden center': 0.7094988669199906,
#  'abras supplier': 0.7536930347815097,
#  'granit supplier': 0.4092261388667199,
#  'drill contractor': 0.7667422492427368,
#  'bpo compani': 0,
#  'oil explor servic': 0.5264828420213281,
#  'build complex': 0.37488311901084637,
#  'construct equip supplier': 0.24409514662261833,
#  'mine equip': 0.2989251547368574,
#  'ticket agenc': 0.7277847811465649,
#  'busi center': 0.12917591694169767,
#  'skyscrap': 0,
#  'softwar compani': 0.9089737082900646,
#  'busi develop servic': 0.20341748548710972,
#  'busi manag consult': 0.20341748548710972,
#  'cabinet maker': 0.7457465739174283,
#  'call center': 0.6372054921596307,
#  'cancer treatment center': 1.0,
#  'power plant consult': 0.7583071004454944,
#  'busi park': 0.2989251547368574,
#  'petroleum product compani': 0.749464943272341,
#  'park lot': 0.3348183836272778,
#  'water util compani': 0.5893250255664316,
#  'car repair mainten': 0.24518763024406134,
#  'water treatment plant': 0.5893250255664316,
#  'car servic': 0.384799614051925,
#  'cattl market': 0.5893250255664316,
#  'sewag dispos servic': 0.7886670625756983,
#  'certifi public account': 0.6087448857095201,
#  'govern offic': 0.592504226805061,
#  'chariti': 1.0,
#  'air condit system supplier': 0.5175735788337962,
#  'chemic industri': 0.4783912991889597,
#  'chemic manufactur': 0.4783912991889597,
#  'titl compani': 0.37488311901084637,
#  'chemic plant': 0.4783912991889597,
#  'properti manag compani': 0.43931428176353743,
#  'custom home builder': 0.37488311901084637,
#  'window instal servic': 0.17245330615262136,
#  'fire damag restor servic': 0.37488311901084637,
#  'equip rental agenc': 0.5175735788337962,
#  'chemic wholesal': 0.7302930685390434,
#  'financi planner': 0.35581457655797505,
#  'telecommun servic provid': 0.9552885708625443,
#  'energi equip solut': 0.6365616336988094,
#  'chiropractor': 0.5828977410970466,
#  'steel distributor': 0.6365616336988094,
#  'citi govern offic': 0.666267173535879,
#  'crane servic': 0.4330725642896344,
#  'garag door supplier': 0.5228224107685725,
#  'industri door supplier': 0.24409514662261833,
#  'citi town hall': 0.7963799224438143,
#  'cloth wholesal': 0.5850943213236149,
#  'coin oper laundri equip supplier': 0.7343325951214598,
#  'metal supplier': 0.7129963266617504,
#  'glass shop': 0.17245330615262136,
#  'colleg': 1.0,
#  'side contractor': 0.28390569829189805,
#  'commerci printer': 0.5549384323170297,
#  'storag facil': 0.6908373370502754,
#  'commun tower': 0.48270920670499107,
#  'janitori servic': 0.8469349217578641,
#  'comput consult': 0.37488311901084637,
#  'fire protect system supplier': 0.20341748548710972,
#  'elev servic': 0.36777288282208837,
#  'industri equip supplier': 0.24409514662261833,
#  'dri wall contractor': 0.24409514662261833,
#  'insul contractor': 0.5228224107685725,
#  'concret contractor': 0.4136180521451026,
#  'scaffold rental servic': 0.431431991359717,
#  'construct compani': 0.9310286727897411,
#  'floor store': 0.48270920670499107,
#  'floor contractor': 0.36413644538621126,
#  'tile contractor': 0.5539538490810466,
#  'tile manufactur': 0.5539538490810466,
#  'glass mirror shop': 0.17245330615262136,
#  'construct materi wholesal': 0.37488311901084637,
#  'gutter clean servic': 0.5682291817959194,
#  'sheet metal contractor': 0.5847618028010066,
#  'consult': 0.6682947603883531,
#  'contain servic': 0.5175735788337962,
#  'septic system servic': 0.8567589597428414,
#  'corpor campu': 0.48270920670499107,
#  'water damag restor servic': 0.37488311901084637,
#  'welder': 0.07429372775974477,
#  'corpor offic': 0.48270920670499107,
#  'anim': 0.736505089637771,
#  'anim feed store': 0.2989251547368574,
#  'anim protect organ': 0.48270920670499107,
#  'brew suppli store': 0.4,
#  'cosmet store': 0.4779378701608672,
#  'counti govern offic': 0.480788053530072,
#  'sugar factori': 0.9403056679283182,
#  'confectioneri wholesal': 0.27485795916398736,
#  'financi institut': 0.24409514662261833,
#  'candi store': 0.24409514662261833,
#  'confectioneri': 0.24409514662261833,
#  'chocol factori': 0.9544000403992323,
#  'chocol shop': 0.9544000403992323,
#  'courier servic': 1.0,
#  'cowork space': 0,
#  'frozen food manufactur': 0.7269451794041278,
#  'beverag distributor': 0.6365616336988094,
#  'agricultur organ': 0.2989251547368574,
#  'dairi store': 0.25084089902346995,
#  'dairi': 0.37488311901084637,
#  'ice cream shop': 0.4783912991889597,
#  'medic laboratori': 0.85000408067489,
#  'demolit contractor': 0.9344566061769004,
#  'meat processor': 0.8861783435402169,
#  'fmcg manufactur': 0,
#  'garbag collect servic': 0.6565921178874996,
#  'wholesal bakeri': 0.24409514662261833,
#  'dentist': 0.8970671711869902,
#  'dessert shop': 0.33478458957832113,
#  'cupcak shop': 0,
#  'nut store': 0.24409514662261833,
#  'wholesal grocer': 0.402412998150745,
#  'design engin': 0.17245330615262136,
#  'busi busi servic': 0.12917591694169767,
#  'condiment supplier': 0.8538081518334687,
#  'digit print servic': 0.8382596321381778,
#  'culinari school': 1.0,
#  'import': 0.20341748548710972,
#  'bottl water supplier': 0.4734463278142646,
#  'coffe roaster': 0.5793926173063703,
#  'packag suppli store': 0.5893250255664316,
#  'ice supplier': 0.5269647852802398,
#  'breweri': 0.9157289224789645,
#  'winemak compani': 0,
#  'distilleri': 0.24409514662261833,
#  'disabl servic support organis': 0.7484580824676673,
#  'district govern offic': 0.19527122273431988,
#  'air filter supplier': 0.690497112073498,
#  'tire shop': 0.7094988669199906,
#  'fasten supplier': 0.6841288292362028,
#  'fabric product manufactur': 0.7129963266617504,
#  'textil': 0.9170712243810738,
#  'textil export': 0.9170712243810738,
#  'textil engin': 0.9170712243810738,
#  'fabric store': 0.37488311901084637,
#  'knit shop': 0.5957583798986505,
#  'doctor': 0.9552885708625443,
#  'lamin servic': 0.13616993153014392,
#  'plastic resin manufactur': 0.5808791572071914,
#  'carpet manufactur': 0.7409112234790852,
#  'upholsteri shop': 0.3886582269629085,
#  'busi administr servic': 0.20341748548710972,
#  'furnitur store': 0.8401149768189771,
#  'dri cleaner': 0.37488311901084637,
#  'packag compani': 0.5893250255664316,
#  'duti free store': 0.2989251547368574,
#  'commerc servic': 0.5,
#  'cabl compani': 0.8934099845459849,
#  'educ': 0.9019669468713154,
#  'outlet store': 0.6365616336988094,
#  'lingeri store': 0.5029527076138053,
#  'cloth fabric manufactur': 0.6365616336988094,
#  'educ center': 0.9019669468713154,
#  'uniform store': 0.3370042346712697,
#  'men cloth store': 0.2595799946307269,
#  'cloth store': 0.39894362670370387,
#  'women cloth store': 0.2580793578088333,
#  'western apparel store': 0.6153846153846154,
#  'costum store': 0.46992708897445207,
#  'game store': 0.37488311901084637,
#  'hat shop': 0.3834587786955953,
#  'leather good manufactur': 0.6365616336988094,
#  'educ consult': 0.9019669468713154,
#  'leather export': 0.9257195953197203,
#  'shoe store': 0.9019669468713154,
#  'boutiqu': 0,
#  'leather wholesal': 0.6365616336988094,
#  'handbag shop': 0.9105771417250885,
#  'electron store': 0.6365616336988094,
#  'luggag store': 0.8045734732193234,
#  'build materi store': 0.37488311901084637,
#  'saw mill': 0.8341424487621473,
#  'electr engin': 0.17245330615262136,
#  'deck builder': 0.3230659936552878,
#  'concret product supplier': 0.6476523498324467,
#  'plywood supplier': 0.5854958718130581,
#  'electr instal servic': 0.5656724394626971,
#  'truss manufactur': 0.3778224090914244,
#  'door supplier': 0.3389131449858566,
#  'wood lamin floor supplier': 0.7380174502917,
#  'aircraft suppli store': 0.24409514662261833,
#  'modular home builder': 0.17300838984520514,
#  'portabl build manufactur': 0.24409514662261833,
#  'modular home dealer': 0.25887852427956426,
#  'mulch supplier': 0.5342691059148444,
#  'electrician': 0.6815571904488514,
#  'paper mill': 0.6577143803756419,
#  'energi supplier': 0.401564240872645,
#  'engin': 0.2659794970423415,
#  'print shop': 0.9906587866291917,
#  'custom label printer': 0.37488311901084637,
#  'market': 0.20341748548710972,
#  'market agenc': 0.17245330615262136,
#  'engin consult': 0.2659794970423415,
#  'entertain': 0.3834587786955953,
#  'envelop supplier': 0.461558138830586,
#  'oil refineri': 0.2989251547368574,
#  'record studio': 0.44622834892232127,
#  'environ renew natur resourc': 0.12917591694169767,
#  'finish materi supplier': 0.37488311901084637,
#  'event ticket seller': 0.37488311901084637,
#  'waterproof compani': 0.5228224107685725,
#  'auto part store': 0.7094988669199906,
#  'heat oil supplier': 0.6365616336988094,
#  'famili practic physician': 0.6365616336988094,
#  'machin manufactur': 0.40896431740410416,
#  'industri supplier': 0.382694880073548,
#  'weld suppli store': 0.3120915390090897,
#  'dri ice supplier': 0.24409514662261833,
#  'privat equiti firm': 0.2989251547368574,
#  'famili servic center': 0.7583071004454944,
#  'feder govern offic': 0.2937374739884908,
#  'vitamin supplement store': 0.5389718247009109,
#  'feed manufactur': 0.8788538778996032,
#  'medic equip supplier': 0.3082512379774813,
#  'medic suppli store': 0.3082512379774813,
#  'medic clinic': 0.7129963266617504,
#  'research institut': 0.8479683268062419,
#  'biochem supplier': 0,
#  'fiber optic product supplier': 0.17245330615262136,
#  'paint manufactur': 0.8788538778996032,
#  'equip supplier': 0.5521319647821147,
#  'food': 0.5621806695921612,
#  'pipe supplier': 0.5123353778402562,
#  'oil field equip supplier': 0.2989251547368574,
#  'food broker': 0.14833755686686634,
#  'food manufactur': 0.8788538778996032,
#  'food process compani': 0.5621806695921612,
#  'fenc suppli store': 0.5175735788337962,
#  'food produc': 0.5621806695921612,
#  'forestri servic': 0.9089737082900646,
#  'foundri': 0.8620127541951508,
#  'wholesal jewel': 0.2989251547368574,
#  'cooki shop': 0.9333224076692107,
#  'truck rental agenc': 0.48270920670499107,
#  'fruit veget process': 0.5378352009493783,
#  'kitchen suppli store': 0.20341748548710972,
#  'hydraul equip supplier': 0.24409514662261833,
#  'irrig equip supplier': 0.7352016187252012,
#  'bear supplier': 0.7428039481462458,
#  'metallurgi compani': 0.8697315677929974,
#  'plastic inject mold servic': 0.2989251547368574,
#  'gener contractor': 0.8788538778996032,
#  'gener hospit': 0.8401149768189771,
#  'tool manufactur': 0.7916193159955882,
#  'industri design compani': 0.37488311901084637,
#  'hyundai dealer': 0,
#  'glass industri': 0.8244315527305931,
#  'polym supplier': 0.3333333333333333,
#  'print equip suppli': 0.3178882953438966,
#  'toner cartridg supplier': 0.3424301960636389,
#  'printer repair servic': 0.48528352890703774,
#  'fuel supplier': 0.6365616336988094,
#  'glass manufactur': 0.8244315527305931,
#  'plastic bag supplier': 0.2254559318113939,
#  'glasswar manufactur': 0.6253548280533437,
#  'polythen plastic sheet supplier': 0,
#  'pvc industri': 0.5652173913043478,
#  'countertop store': 0.4953783145603117,
#  'cabinet store': 0.46491077566393807,
#  'fiberglass supplier': 0.43141138915474486,
#  'golf cart dealer': 0.48270920670499107,
#  'auto repair shop': 0.14833755686686634,
#  'hose supplier': 0.6402616856635636,
#  'rubber product supplier': 0.6192654927328665,
#  'automot': 0.37488311901084637,
#  'commerci refriger supplier': 0.37488311901084637,
#  'golf club': 0.29054969064694397,
#  'golf cours': 0.29054969064694397,
#  'green energi supplier': 0.10570727898967354,
#  'greenhous': 0.6088699363760065,
#  'auto glass shop': 0.14833755686686634,
#  'light manufactur': 0.8666507535478586,
#  'cement manufactur': 0.3348183836272778,
#  'brick manufactur': 0.43614048824278817,
#  'natur stone supplier': 0.37488311901084637,
#  'gym': 1.0,
#  'marbl supplier': 0.4208362571589232,
#  'corpor gift supplier': 0.6365616336988094,
#  'shipbuild repair compani': 0,
#  'construct mainten offic': 0.9310286727897411,
#  'boiler manufactur': 0.685738020488067,
#  'contain supplier': 0.5175735788337962,
#  'home construct': 0.4198969473373922,
#  'health': 0.8788538778996032,
#  'heart hospit': 0.6666666666666666,
#  'spring supplier': 0.9105771417250885,
#  'electr util manufactur': 0.2989251547368574,
#  'aircraft manufactur': 0.8480042189388519,
#  'metal heat treat servic': 0.5380180285434618,
#  'plate servic': 0.611605421752781,
#  'autom compani': 0.3106498928198043,
#  'heat contractor': 0.7889290886388838,
#  'plumb suppli store': 0.5175735788337962,
#  'gun shop': 0.6602640386567461,
#  'ammunit supplier': 0.798364177221176,
#  'pipe manufactur': 0.5123353778402562,
#  'school': 1.0,
#  'fire protect equip supplier': 0.20341748548710972,
#  'agricultur machineri manufactur': 0.40024725935236766,
#  'lawn mower store': 0.6365616336988094,
#  'lawn irrig equip supplier': 0.48270920670499107,
#  'financi consult': 0.35581457655797505,
#  'helicopt charter': 0.6350972959643788,
#  'packag machineri': 0.08516885643976688,
#  'histor landmark': 0.6339326370718169,
#  'electron manufactur': 0.41995247070387165,
#  'graphic design': 0.5787201756208546,
#  'eye care center': 0.5228224107685725,
#  'optic product manufactur': 0.9212502775999563,
#  'imag consult': 0.37488311901084637,
#  'clean product supplier': 0.24409514662261833,
#  'fireplac store': 0.48528352890703774,
#  'home builder': 0.4198969473373922,
#  'tool die shop': 0.7218561374202516,
#  'metal stamp servic': 0.2989251547368574,
#  'environment organ': 0.5154325235390578,
#  'food process equip': 0.3168717691820676,
#  'loan agenc': 0.6724799715677215,
#  'power plant equip supplier': 0.48270920670499107,
#  'home good store': 0.5656724394626971,
#  'engin rebuild servic': 0.14833755686686634,
#  'air compressor supplier': 0.08516885643976688,
#  'honda dealer': 0,
#  'elev manufactur': 0.36777288282208837,
#  'crane dealer': 0.4330725642896344,
#  'crane rental agenc': 0.588918808745271,
#  'compound build': 0.17245330615262136,
#  'tractor dealer': 0.24409514662261833,
#  'furnac part supplier': 0.37488311901084637,
#  'heat equip supplier': 0.4765378536522128,
#  'pneumat tool supplier': 0.37488311901084637,
#  'truck stop': 0.6365616336988094,
#  'comput hardwar manufactur': 0.6155836445863292,
#  'satellit commun servic': 0.9019669468713154,
#  'hospit': 0.8401149768189771,
#  'electron compani': 0.6365616336988094,
#  'electron part supplier': 0.85508968311942,
#  'hvac contractor': 0.7142857142857143,
#  'industri engin': 0.17245330615262136,
#  'contact lens supplier': 0.48270920670499107,
#  'inform servic': 0.44622834892232127,
#  'build': 0.9310286727897411,
#  'water work equip supplier': 0.37488311901084637,
#  'measur instrument supplier': 0.8223685339655229,
#  'scientif equip supplier': 0.20341748548710972,
#  'medic center': 0.8401149768189771,
#  'watch manufactur': 0.4656496496703559,
#  'corpor entertain servic': 0.8401149768189771,
#  'insur': 0.5341962857506611,
#  'record compani': 0.5175735788337962,
#  'video duplic servic': 0.7451342788741513,
#  'insur agenc': 0.5341962857506611,
#  'light store': 0.8666507535478586,
#  'light wholesal': 0.8666507535478586,
#  'entertain agenc': 0.9019669468713154,
#  'insur broker': 0.5341962857506611,
#  'electr equip supplier': 0.5696506622962453,
#  'electr motor store': 0.17245330615262136,
#  'railroad compani': 0.9105771417250885,
#  'electr suppli store': 0.5696506622962453,
#  'insur compani': 0.5341962857506611,
#  'factori equip supplier': 0.24409514662261833,
#  'invest servic': 0.79841846650365,
#  'laser equip supplier': 0.3341360887539999,
#  'execut suit rental agenc': 0.5579608333129188,
#  'truck dealer': 0.37488311901084637,
#  'motor vehicl dealer': 0.6365616336988094,
#  'car dealer': 0.6365616336988094,
#  'truck topper supplier': 0.2980083589164512,
#  'polic suppli store': 0.3845522667575446,
#  'iron steel contractor': 0.17245330615262136,
#  'fire depart equip supplier': 0.20341748548710972,
#  'tow equip provid': 0.7993025654266052,
#  'logist servic': 0.6209600782975403,
#  'trailer manufactur': 0.9643273850442625,
#  'trailer dealer': 0.5808791572071914,
#  'dealer': 0.7851346881537634,
#  'auto spring shop': 0.14833755686686634,
#  'auto upholster': 0.17245330615262136,
#  'auto bodi part supplier': 0.7094988669199906,
#  'car factori': 0.48270920670499107,
#  'freight forward servic': 0.8401149768189771,
#  'brake shop': 0.2466273545768897,
#  'railroad equip supplier': 0.36413644538621126,
#  'jewelri equip supplier': 0.6752788328410487,
#  'boat builder': 1.0,
#  'ship build': 0.9552885708625443,
#  'marin suppli store': 0.48270920670499107,
#  'boat dealer': 0.6932687235735957,
#  'kawasaki motorcycl dealer': 0,
#  'knife manufactur': 0.8368926019063473,
#  'labor union': 0.6006618462197832,
#  'furnitur maker': 0.9589015523436788,
#  'bank financ': 0.5106972125673794,
#  'furnitur manufactur': 0.879558569652498,
#  'logist': 0.6209600782975403,
#  'massag suppli store': 0.3230659936552878,
#  'telecommun equip supplier': 0.48270920670499107,
#  'babi store': 0.24409514662261833,
#  'mold supplier': 0.2989251547368574,
#  'offic equip supplier': 0.20341748548710972,
#  'offic furnitur store': 0.37488311901084637,
#  'store equip supplier': 0.24409514662261833,
#  'laboratori': 0.27402584821553533,
#  'health beauti shop': 0.2989251547368574,
#  'learn center': 0.5778549884979471,
#  'dental laboratori': 0.5665398207273191,
#  'land surveyor': 0.2486327126998068,
#  'educ suppli store': 0.6365616336988094,
#  'jewelri store': 0.6365616336988094,
#  'playground equip supplier': 0.5389718247009109,
#  'outdoor sport store': 0.4700100922261463,
#  'toy store': 0.37488311901084637,
#  'secur servic': 0.2989251547368574,
#  'sign shop': 0.6059986444669639,
#  'offic suppli store': 0.6365616336988094,
#  'landscap': 0.828649581734812,
#  'gasket manufactur': 0.7121499322161745,
#  'piano maker': 0.281892775459689,
#  'piano store': 0.6135941319459651,
#  'funer home': 1.0,
#  'monument': 0.2632628633144879,
#  'book publish': 0.6600675099500067,
#  'wig shop': 0.5029527076138053,
#  'laundromat': 1.0,
#  'auto wrecker': 0.6365616336988094,
#  'auto part market': 0.7094988669199906,
#  'jeep dealer': 0,
#  'restaur suppli store': 0.36413644538621126,
#  'roof suppli store': 0.7385419868147584,
#  'law firm': 0.6602640386567461,
#  'build materi market': 0.37488311901084637,
#  'camera store': 0.5002175015319839,
#  'lawn care servic': 0.4214298566403791,
#  'comput secur servic': 0.2989251547368574,
#  'comput store': 0.20341748548710972,
#  'design agenc': 0.3973900331741193,
#  'diagnost center': 1.0,
#  'laboratori equip supplier': 0.47357856884302907,
#  'home theater store': 0.8401149768189771,
#  'metal industri supplier': 0.7129963266617504,
#  'landscap suppli store': 0.6072270042334288,
#  'applianc part supplier': 0.7113555817008604,
#  'vacuum cleaner store': 0.7094988669199906,
#  'audio visual equip supplier': 0.9200574884094885,
#  'lawyer': 0.8807291832885272,
#  'cell phone store': 0.5893036212289409,
#  'bathroom suppli store': 0.3611627773218964,
#  'leas servic': 0.829327373800143,
#  'construct machin dealer': 0.24409514662261833,
#  'dairi farm equip supplier': 0.24409514662261833,
#  'propan supplier': 0.5427948801689131,
#  'legal servic': 0.802954498479696,
#  'janitori equip supplier': 0.8469349217578641,
#  'life insur agenc': 0.37488311901084637,
#  'railroad contractor': 0.9019669468713154,
#  'swim pool suppli store': 0.4214298566403791,
#  'light bulb supplier': 0.9379959834593335,
#  'linen store': 0.8229056261104315,
#  'metal construct compani': 0.3640193756741945,
#  'local govern offic': 0.24409514662261833,
#  'log contractor': 0.8401149768189771,
#  'machin shop': 0.48270920670499107,
#  'hotel suppli store': 0.6878641411307941,
#  'import export compani': 0.20341748548710972,
#  'sew compani': 0.37488311901084637,
#  'research foundat': 0.8479683268062419,
#  'machineri part manufactur': 0.7093298751903218,
#  'sport accessori wholesal': 0.3845522667575446,
#  'fashion design': 0.46491077566393807,
#  'chees manufactur': 0.7113478069283244,
#  'chees shop': 0.7113478069283244,
#  'ship mail': 0.8401149768189771,
#  'wholesal food store': 0.402412998150745,
#  'organ food store': 0.2989251547368574,
#  'pie shop': 0.6387920848068563,
#  'auction hous': 0.5833722638424459,
#  'livestock auction hous': 0.5745751712851589,
#  'cotton export': 0.24213053105818025,
#  'plastic wholesal': 0.6365616336988094,
#  'mail servic': 0.888245164653896,
#  'manufactur': 0.11439839887088857,
#  'station': 0.6365616336988094,
#  'beer distributor': 0.9394269389498017,
#  'alcohol beverag wholesal': 0.7894310196246915,
#  'religi good store': 1.0,
#  'book wholesal': 0.2673224186347812,
#  'masonri suppli store': 0.37488311901084637,
#  'wholesal florist': 0.2673224186347812,
#  'florist': 0.8934099845459849,
#  'marin engin': 0.17245330615262136,
#  'paint store': 0.37488311901084637,
#  'use auto part store': 0.6365616336988094,
#  'masonri contractor': 0.44489436856453907,
#  'use car dealer': 0.6365616336988094,
#  'use truck dealer': 0.6365616336988094,
#  'massag therapist': 0.34363635722486485,
#  'materi handl equip supplier': 0.332023808663245,
#  'marina': 0.8106180309403008,
#  'meat packer': 0.31620785066798135,
#  'mattress store': 0.8401149768189771,
#  'blind shop': 0.9153224945101938,
#  'interior design': 0.5175735788337962,
#  'window treatment store': 0.48270920670499107,
#  'applianc store': 0.6365616336988094,
#  'health food store': 0.2989251547368574,
#  'direct mail advertis': 0.17245330615262136,
#  'meat wholesal': 0.31620785066798135,
#  'butcher shop deli': 0.5342691059148444,
#  'italian groceri store': 0.14285714285714285,
#  'food servic': 0.48270920670499107,
#  'groceri deliveri servic': 0.8401149768189771,
#  'wine store': 0.8905530859566619,
#  'liquor store': 0.9113160638548322,
#  'kiosk': 0,
#  'optometrist': 0.44545859484674494,
#  'optician': 0.33281404039050166,
#  'mechan contractor': 0.6565921178874996,
#  'mechan engin': 0.17245330615262136,
#  'cafe': 0.4881855834352799,
#  'jewel': 0.5389718247009109,
#  'leather good store': 0.6365616336988094,
#  'gift shop': 0.9220069972820306,
#  'craft store': 0.45316640078743653,
#  'hobbi store': 0.37488311901084637,
#  'fabric wholesal': 0.37488311901084637,
#  'scrap metal dealer': 0.2989251547368574,
#  'quilt shop': 0.2222222222222222,
#  'sheet music store': 0.37488311901084637,
#  'music instrument manufactur': 0.23902864564639348,
#  'music store': 0.37488311901084637,
#  'music instrument store': 0.37488311901084637,
#  'band': 0.497789991223762,
#  'bookstor': 0,
#  'art museum': 0.37488311901084637,
#  'newsstand': 1.0,
#  'medic equip manufactur': 0.8678193729480344,
#  'fashion accessori store': 0.344547856195199,
#  'discount store': 0.5427948801689131,
#  'cemeteri': 0.8475982933896377,
#  'stop': 0.2632628633144879,
#  'varieti store': 0.6365616336988094,
#  'thrift store': 1.0,
#  'medic group': 0.7129963266617504,
#  'donat center': 0.7807789774739647,
#  'pet store': 0.35581457655797505,
#  'art galleri': 0.2989251547368574,
#  'art dealer': 0.2989251547368574,
#  'hous develop': 0.6365616336988094,
#  'mobil home dealer': 0.3234260951175617,
#  'conveni store': 0.7636723823898807,
#  'medic offic': 0.7129963266617504,
#  'medic technolog manufactur': 0.8678193729480344,
#  'children furnitur store': 0.8401149768189771,
#  'mental health clinic': 0.43379867639900227,
#  'airlin': 0.5106778057190418,
#  'aviat consult': 0.5103636176242264,
#  'travel agenc': 0.4912421772488671,
#  'travel servic': 0.4912421772488671,
#  'airport': 0.7583071004454944,
#  'mental health servic': 0.43379867639900227,
#  'ship compani': 0.8401149768189771,
#  'metal fabric': 0.3640193756741945,
#  'cruis line compani': 0.37488311901084637,
#  'tow servic': 0.7993025654266052,
#  'ferri termin': 0.3106498928198043,
#  'ferri servic': 0.692212784552135,
#  'metal finish': 0.5103636176242264,
#  'boat tour agenc': 0.9019669468713154,
#  'move compani': 0.7971129309349386,
#  'move storag servic': 0.7971129309349386,
#  'state depart transport': 0.3178882953438966,
#  'depart transport': 0.3845522667575446,
#  'handicap transport servic': 1.0,
#  'railway servic': 0.8970671711869902,
#  'train station': 0.37488311901084637,
#  'depot': 0.5,
#  'charter': 0.8401149768189771,
#  'metal process compani': 0.3640193756741945,
#  'mix use': 0.37488311901084637,
#  'motorcycl shop': 0.8293843130197884,
#  'limousin servic': 1.0,
#  'chauffeur servic': 0.5427948801689131,
#  'school servic': 0.8401149768189771,
#  'airport shuttl servic': 0.6365616336988094,
#  'tourist inform center': 0.4323943804654636,
#  'carriag ride servic': 0.8789618730340989,
#  'cruis agenc': 0.44622834892232127,
#  'tourist attract': 0.4323943804654636,
#  'ski resort': 0.6292976041746945,
#  'ski area': 0.6292976041746945,
#  'fix base oper': 0.48270920670499107,
#  'aircraft mainten compani': 0.6320247471868171,
#  'motorsport store': 0,
#  'boat rental servic': 0.24409514662261833,
#  'util trailer dealer': 0.48270920670499107,
#  'forklift dealer': 0.33770577618809333,
#  'municip administr offic': 0.16285898823168393,
#  'nephrologist': 1.0,
#  'coach compani': 0.7245884476238134,
#  'ship servic': 0.8401149768189771,
#  'ship mail servic': 0.8401149768189771,
#  'newspap publish': 0.7350556422195847,
#  'shred servic': 0.5285327560657864,
#  'nuclear power compani': 0.3812384644298092,
#  'nurs home': 1.0,
#  'media compani': 0.5810948609073042,
#  'multimedia electron book publish': 0.6602640386567461,
#  'internet market servic': 0.17245330615262136,
#  'greet card shop': 0.7409112234790852,
#  'theme park': 1.0,
#  'film product compani': 0.3134184668906915,
#  'obstetrician gynecologist': 1.0,
#  'movi studio': 0.3990006673070808,
#  'video product servic': 0.4885324307470056,
#  'movi theater': 0.36305852577785885,
#  'theater compani': 0.6602640386567461,
#  'perform art theater': 0.37488311901084637,
#  'occup safeti health': 0.8401149768189771,
#  'offic space rental agenc': 0.37488311901084637,
#  'commerci real estat agenc': 0.8401149768189771,
#  'art school': 0.24409514662261833,
#  'music publish': 0.37488311901084637,
#  'print music publish': 0.37488311901084637,
#  'home audio store': 0.8401149768189771,
#  'musician': 1.0,
#  'music manag promot': 0.8934099845459849,
#  'video edit servic': 0.7451342788741513,
#  'offic suppli wholesal': 0.6511301417686322,
#  'offici resid': 0.2222222222222222,
#  'orthoped clinic': 0.7724351171857794,
#  'painter': 0.16285898823168393,
#  'paint': 0.332023808663245,
#  'telephon compani': 0.7695005099892119,
#  'media hous': 0.5810948609073042,
#  'paper distributor': 0.5893250255664316,
#  'news servic': 0.7094988669199906,
#  'public librari': 0.37488311901084637,
#  'law librari': 0.5175735788337962,
#  'museum': 0.9517140391719545,
#  'feder reserv bank': 0.8401149768189771,
#  'credit union': 0.42244660561849634,
#  'atm': 0.6997292924605046,
#  'pave contractor': 0.8788538778996032,
#  'mortgag lender': 0.5696506622962453,
#  'invest bank': 0.6193695950697208,
#  'check cash servic': 0.8403240470478353,
#  'stock broker': 0.37488311901084637,
#  'health consult': 0.20341748548710972,
#  'health insur agenc': 0.24409514662261833,
#  'payrol servic': 0.6602640386567461,
#  'pediatrician': 1.0,
#  'human resourc consult': 0.651871702941267,
#  'pest control servic': 0.7862428070124468,
#  'pet board servic': 0.477041938180072,
#  'pet care': 0.477041938180072,
#  'loss adjust': 0.5110504867568866,
#  'pharmaceut compani': 0.8340177353295776,
#  'pharmaceut product wholesal': 0.9019669468713154,
#  'pharmaci': 0.43652535971905876,
#  'educ institut': 0.9200574884094885,
#  'retir commun': 0.8620573455794822,
#  'fratern organ': 1.0,
#  'photo lab': 0.17245884476238132,
#  'properti invest': 0.41783722751264046,
#  'photograph': 0.2587499236293894,
#  'photographi school': 0.7550951308902007,
#  'star hotel': 0,
#  'convent center': 0.5099246039904839,
#  'real estat apprais': 0.5420695445695504,
#  'photographi servic': 0.7550951308902007,
#  'resort hotel': 0.5549384323170297,
#  'real estat consult': 1.0,
#  'car rental agenc': 0.6446338474049024,
#  'car leas servic': 0.6367496520369909,
#  'ford dealer': 0,
#  'car financ loan compani': 0.20341748548710972,
#  'trailer rental servic': 0.5808791572071914,
#  'furnitur rental servic': 0.24409514662261833,
#  'tuxedo shop': 0.3971926822554664,
#  'dress tuxedo rental servic': 0.24409514662261833,
#  'wed store': 0.19527122273431988,
#  'video store': 0.6365616336988094,
#  'movi rental': 0.48262190907480623,
#  'photographi studio': 0.7550951308902007,
#  'home health care servic': 0.8401149768189771,
#  'skateboard shop': 1.0,
#  'event technolog servic': 0.48270920670499107,
#  'parti equip rental servic': 0.41940092022481734,
#  'construct machin rental servic': 0.37488311901084637,
#  'audio visual equip rental servic': 0.9200574884094885,
#  'ship equip industri': 0.24409514662261833,
#  'physic therapi clinic': 0.3834587786955953,
#  'plastic fabric compani': 0.539325412552986,
#  'plastic product supplier': 0.539325412552986,
#  'auto tag agenc': 0.2989251547368574,
#  'depart motor vehicl': 0.3845522667575446,
#  'notari public': 0.8782809948064147,
#  'privat investig': 0.2989251547368574,
#  'escrow servic': 0.7508769412563502,
#  'real estat agent': 1.0,
#  'playground': 0.18314728256823934,
#  'plumber': 0.5333343920587591,
#  'port author': 0.8181092508446417,
#  'portrait studio': 0.596096295802428,
#  'post offic': 0.8970671711869902,
#  'profession servic': 0.5407934815331834,
#  'univers hospit': 0.8401149768189771,
#  'public relat firm': 0.17245330615262136,
#  'civil engin compani': 1.0,
#  'draft servic': 0.4752547722072787,
#  'pump supplier': 0.5701719690557259,
#  'interior construct contractor': 0.6365616336988094,
#  'carpet clean servic': 0.5041275149635895,
#  'exhibit planner': 0.48270920670499107,
#  'decal supplier': 0,
#  'stage light equip supplier': 0.37488311901084637,
#  'event manag compani': 0.48270920670499107,
#  'radio broadcast': 0.08516885643976688,
#  'comput support servic': 0.37488311901084637,
#  'ravin': 0,
#  'employ center': 0.705277866983292,
#  'nation health foundat': 0.48270920670499107,
#  'real estat develop': 0.37488311901084637,
#  'advertis agenc': 0.22899278575874843,
#  'promot product supplier': 0.17245330615262136,
#  'advertis servic': 0.22899278575874843,
#  'record storag facil': 0.37488311901084637,
#  'fund manag compani': 0.2989251547368574,
#  'recreat center': 0.6561834955539751,
#  'bakeri': 0.6569671408390381,
#  'databas manag compani': 0.757923746068198,
#  'market research': 0.24409514662261833,
#  'recycl center': 0.4783192784614968,
#  'region govern offic': 0.18314728256823934,
#  'rehabilit center': 0.7409112234790852,
#  'religi institut': 1.0,
#  'religi organ': 1.0,
#  'repair servic': 0.5833722638424459,
#  'emerg veterinarian servic': 0.24409514662261833,
#  'pet sitter': 0.477041938180072,
#  'research product develop': 0.8479683268062419,
#  'build societi': 0.9310286727897411,
#  'valet park servic': 0.6382068234672832,
#  'nurs agenc': 1.0,
#  'execut search firm': 0.7316092685682212,
#  'recruit': 1.0,
#  'temp agenc': 0,
#  'health center': 0.8401149768189771,
#  'restaur': 0.7065526961238439,
#  'roof contractor': 0.44536812355044475,
#  'sport nutrit store': 0.2989251547368574,
#  'credit report agenc': 0.12917591694169767,
#  'automobil storag facil': 0.37488311901084637,
#  'debt collect agenc': 0.2545910715984998,
#  'park': 0.3348183836272778,
#  'court report': 0.5819253370730626,
#  'tour agenc': 0.586369150464167,
#  'tour oper': 0.586369150464167,
#  'convent inform bureau': 0.5099246039904839,
#  'balloon ride tour agenc': 0.9019669468713154,
#  'secur guard servic': 0.2989251547368574,
#  'locksmith': 0.8600392940200164,
#  'commerci clean servic': 0.2989251547368574,
#  'blast clean servic': 0.2989251547368574,
#  'confer center': 0.7514331300839273,
#  'safeti equip supplier': 0.20341748548710972,
#  'garbag dump': 0.4700100922261463,
#  'sanit servic': 0.45943249576071976,
#  'garbag dump servic': 0.6565921178874996,
#  'environment health servic': 0.31042072637202806,
#  'portabl toilet supplier': 0.37488311901084637,
#  'public work depart': 0.3819136260337411,
#  'school district offic': 1.0,
#  'sailmak': 0,
#  'commun colleg': 0.8401149768189771,
#  'salvag yard': 0.2632628633144879,
#  'busi school': 0.48270920670499107,
#  'trade school': 0.37488311901084637,
#  'privat univers': 0.8401149768189771,
#  'comput train school': 0.48270920670499107,
#  'school suppli store': 0.48270920670499107,
#  'screen printer': 0.7689741220514547,
#  'media consult': 0.5810948609073042,
#  'beauti school': 0.37488311901084637,
#  'flight school': 0.6660737498977496,
#  'seaport': 0.37488311901084637,
#  'secur system supplier': 0.2989251547368574,
#  'middl school': 1.0,
#  'nonprofit': 0,
#  'shoot rang': 0.5087536112410581,
#  'soccer club': 0.6815571904488514,
#  'camp': 0.9220069972820306,
#  'dive contractor': 0.6997292924605046,
#  'languag school': 0.6887351473112096,
#  'english languag school': 0.15384615384615385,
#  'preschool': 1.0,
#  'self storag facil': 0.9099222675139497,
#  'semi conductor supplier': 0.2218085303102923,
#  'drive school': 0.3241226791316803,
#  'truck school': 0.24409514662261833,
#  'senior citizen center': 0.6097725499371341,
#  'servic': 0.37488311901084637,
#  'children hospit': 0.8401149768189771,
#  'dental suppli store': 0.7372080861906722,
#  'shipyard': 1.0,
#  'orthodox synagogu': 0,
#  'short term apart rental agenc': 0.37488311901084637,
#  'nutritionist': 1.0,
#  'ophthalmologist': 0.16285898823168393,
#  'ophthalmolog clinic': 0.15384615384615385,
#  'social servic organ': 0.8729747415915995,
#  'social welfar center': 0.8729747415915995,
#  'solar energi compani': 0.5598611705240579,
#  'solar energi equip supplier': 0.5598611705240579,
#  'special educ school': 0.8401149768189771,
#  'podiatrist': 1.0,
#  'reproduct health clinic': 0.24409514662261833,
#  'sport good store': 0.37488311901084637,
#  'dialysi center': 0.9042842652183054,
#  'sport complex': 0.37847835268757063,
#  'well program': 0.48270920670499107,
#  'sportswear store': 0.2,
#  'privat hospit': 0.8401149768189771,
#  'radiologist': 0.3333333333333333,
#  'medic diagnost imag center': 0.8341424487621473,
#  'ray lab': 0.9394269389498017,
#  'blood bank': 0.8374361353044526,
#  'stainless steel plant': 1.0,
#  'state agenc': 0.30271425464970275,
#  'heliport': 0,
#  'health care compani': 0.8401149768189771,
#  'psychiatr hospit': 1.0,
#  'state govern offic': 0.30271425464970275,
#  'medic institut': 0.8401149768189771,
#  'steel construct compani': 0.2855322653648754,
#  'clean servic': 0.5640616287111175,
#  'steel drum supplier': 0.37488311901084637,
#  'assist live facil': 0.7129963266617504,
#  'steel erector': 0.2855322653648754,
#  ...}

# %% [markdown]
# ## Lemmatize

# %%
# IMPORT INVERTED_INDEX
with open(r'assets/inverted_index_lem.json') as f:
    inverted_index_lem = json.load(f)

# %%
pre_at_n, rec_at_n = calc_pre_rec_at_n(create_testing_dicts(normalization='lemmatize')[0], create_testing_dicts(normalization='lemmatize')[1])

# %%
pre_at_n
# Out:
# {'home improvement store': 0.0,
#  'diesel fuel supplier': 0.1,
#  'church': 0.1,
#  'farm': 0.2,
#  'seed supplier': 0.1,
#  'accountant': 0.8,
#  'trucking company': 0.375,
#  'exporter': 1.0,
#  'grain elevator': 0.0,
#  'popcorn store': 0.2,
#  'agricultural service': 0.1,
#  'warehouse': 0.0,
#  'agricultural production': 0.1,
#  'ranch': 0.0,
#  'holding company': 0.3,
#  'farm equipment supplier': 0.1,
#  'store': 0.0,
#  'grocery store': 0.0,
#  'rice mill': 0.4,
#  'food product supplier': 0.0,
#  'accounting firm': 0.2,
#  'produce market': 0.0,
#  'pet supply store': 0.1,
#  'wholesaler': 0.0,
#  'produce wholesaler': 0.0,
#  'distribution service': 0.0,
#  'crop grower': 0.1,
#  'addiction treatment center': 0.2,
#  'natural good store': 0.0,
#  'orchard': 0.1,
#  'lumber store': 0.1,
#  'mine': 0.2,
#  'transportation service': 0.1,
#  'investment company': 0.1,
#  'fruit wholesaler': 0.1,
#  'real estate agency': 0.1,
#  'event venue': 0.0,
#  'frozen dessert supplier': 0.3,
#  'wine wholesaler importer': 0.2,
#  'winery': 0.857,
#  'aerospace company': 0.6,
#  'cold storage facility': 0.1,
#  'employment agency': 0.4,
#  'plant nursery': 0.0,
#  'air conditioning contractor': 0.1,
#  'air conditioning repair service': 0.1,
#  'fruit vegetable wholesaler': 0.0,
#  'aircraft rental service': 0.0,
#  'monastery': 1.0,
#  'allergist': 1.0,
#  'herb shop': 0.0,
#  'aluminum supplier': 0.4,
#  'ambulance service': 0.5,
#  'wholesale plant nursery': 0.1,
#  'amusement machine supplier': 0.1,
#  'animal hospital': 0.0,
#  'farmer market': 0.0,
#  'vaporizer store': 0.0,
#  'cigar shop': 0.2,
#  'tobacco shop': 0.0,
#  'well drilling contractor': 0.3,
#  'library': 0.3,
#  'apartment building': 0.1,
#  'apartment rental agency': 0.1,
#  'dairy farm': 0.0,
#  'architect': 0.5,
#  'organic farm': 0.0,
#  'architectural designer': 0.3,
#  'architecture firm': 0.0,
#  'livestock producer': 0.0,
#  'dairy supplier': 0.2,
#  'biotechnology company': 1.0,
#  'artist': 0.1,
#  'egg supplier': 0.5,
#  'poultry farm': 0.3,
#  'chicken hatchery': 0.4,
#  'art organization': 0.3,
#  'association organization': 0.3,
#  'food store': 0.0,
#  'deli': 0.0,
#  'bank': 0.3,
#  'fish processing': 0.1,
#  'fish farm': 0.1,
#  'seafood wholesaler': 0.2,
#  'tropical fish store': 0.0,
#  'non profit organization': 0.0,
#  'economic development agency': 0.1,
#  'seafood market': 0.1,
#  'honey farm': 0.571,
#  'horse breeder': 0.1,
#  'asphalt contractor': 0.0,
#  'livestock dealer': 0.1,
#  'department store': 0.1,
#  'mill': 0.0,
#  'atv dealer': 1.0,
#  'audio visual consultant': 0.1,
#  'pallet supplier': 0.4,
#  'wood supplier': 0.0,
#  'hardware store': 0.0,
#  'furniture wholesaler': 0.0,
#  'auditor': 0.333,
#  'oil natural gas company': 0.1,
#  'auto body shop': 0.0,
#  'boat repair shop': 0.2,
#  'association': 0.3,
#  'railing contractor': 0.333,
#  'publisher': 0.6,
#  'pond supply store': 0.0,
#  'agriculture cooperative': 0.0,
#  'printing equipment supplier': 0.1,
#  'auto insurance agency': 0.0,
#  'alternative fuel station': 0.2,
#  'auto part manufacturer': 0.0,
#  'foundation': 0.1,
#  'fertilizer supplier': 0.4,
#  'farming company': 0.0,
#  'finance broker': 0.1,
#  'agricultural cooperative': 0.0,
#  'fire station': 0.0,
#  'environmental consultant': 0.2,
#  'civil engineer': 0.1,
#  'fire protection service': 0.0,
#  'gas company': 0.0,
#  'oilfield': 0.0,
#  'banquet hall': 0.25,
#  'mining company': 0.2,
#  'coalfield': 0.2,
#  'steel fabricator': 0.1,
#  'quarry': 0.6,
#  'gold mining company': 0.3,
#  'high rise building': 0.0,
#  'basketball club': 0.167,
#  'gold dealer': 0.0,
#  'battery manufacturer': 0.5,
#  'electric utility company': 0.0,
#  'environmental program': 0.1,
#  'office': 0.0,
#  'stone supplier': 0.1,
#  'aggregate supplier': 0.0,
#  'sand gravel supplier': 0.4,
#  'building material supplier': 0.0,
#  'beauty supply store': 0.3,
#  'crushed stone supplier': 0.167,
#  'rock shop': 0.0,
#  'road construction company': 0.1,
#  'marketing consultant': 0.0,
#  'blood testing service': 0.0,
#  'contractor': 0.2,
#  'excavating contractor': 0.125,
#  'asphalt mixing plant': 0.5,
#  'ready mix concrete supplier': 0.0,
#  'sand plant': 0.4,
#  'bmw dealer': 0.4,
#  'bookbinder': 0.0,
#  'garden center': 0.1,
#  'abrasive supplier': 0.4,
#  'granite supplier': 0.143,
#  'drilling contractor': 0.4,
#  'bpo company': 0.4,
#  'oil gas exploration service': 0.1,
#  'building complex': 0.0,
#  'construction equipment supplier': 0.0,
#  'mining equipment': 0.0,
#  'bus ticket agency': 0.1,
#  'business center': 0.0,
#  'skyscraper': 0.0,
#  'software company': 0.1,
#  'business development service': 0.0,
#  'business management consultant': 0.0,
#  'cabinet maker': 0.6,
#  'call center': 0.5,
#  'cancer treatment center': 0.333,
#  'power plant consultant': 0.1,
#  'business park': 0.0,
#  'petroleum product company': 0.2,
#  'parking lot': 0.2,
#  'water utility company': 0.2,
#  'car repair maintenance': 0.3,
#  'water treatment plant': 0.2,
#  'car service': 0.3,
#  'cattle market': 0.1,
#  'sewage disposal service': 0.3,
#  'certified public accountant': 0.333,
#  'government office': 0.2,
#  'charity': 1.0,
#  'air conditioning system supplier': 0.1,
#  'chemical industry': 0.1,
#  'chemical manufacturer': 0.1,
#  'title company': 0.0,
#  'chemical plant': 0.1,
#  'property management company': 0.1,
#  'custom home builder': 0.0,
#  'window installation service': 0.0,
#  'fire damage restoration service': 0.0,
#  'equipment rental agency': 0.1,
#  'chemical wholesaler': 0.1,
#  'financial planner': 0.1,
#  'telecommunication service provider': 0.2,
#  'energy equipment solution': 0.0,
#  'chiropractor': 1.0,
#  'steel distributor': 0.0,
#  'city government office': 0.5,
#  'crane service': 0.4,
#  'garage door supplier': 0.1,
#  'industrial door supplier': 0.0,
#  'city town hall': 0.5,
#  'clothing wholesaler': 0.2,
#  'coin operated laundry equipment supplier': 0.3,
#  'metal supplier': 0.1,
#  'glass shop': 0.0,
#  'college': 0.1,
#  'siding contractor': 0.2,
#  'commercial printer': 0.1,
#  'storage facility': 0.4,
#  'communication tower': 0.0,
#  'janitorial service': 0.556,
#  'computer consultant': 0.0,
#  'fire protection system supplier': 0.0,
#  'elevator service': 0.4,
#  'industrial equipment supplier': 0.2,
#  'dry wall contractor': 0.0,
#  'insulation contractor': 0.2,
#  'concrete contractor': 0.3,
#  'scaffolding rental service': 0.333,
#  'construction company': 0.2,
#  'flooring store': 0.0,
#  'flooring contractor': 0.2,
#  'tile contractor': 0.4,
#  'tile manufacturer': 0.4,
#  'glass mirror shop': 0.0,
#  'construction material wholesaler': 0.0,
#  'gutter cleaning service': 0.125,
#  'sheet metal contractor': 0.2,
#  'consultant': 0.125,
#  'container service': 0.2,
#  'septic system service': 0.3,
#  'corporate campus': 0.143,
#  'water damage restoration service': 0.0,
#  'welder': 0.0,
#  'corporate office': 0.143,
#  'animal': 0.2,
#  'animal feed store': 0.0,
#  'animal protection organization': 0.0,
#  'brewing supply store': 0.0,
#  'cosmetic store': 0.3,
#  'county government office': 0.375,
#  'sugar factory': 0.5,
#  'confectionery wholesaler': 0.2,
#  'financial institution': 0.0,
#  'candy store': 0.0,
#  'confectionery': 0.0,
#  'chocolate factory': 0.5,
#  'chocolate shop': 0.5,
#  'courier service': 0.125,
#  'coworking space': 0.125,
#  'frozen food manufacturer': 0.2,
#  'beverage distributor': 0.0,
#  'agricultural organization': 0.0,
#  'dairy store': 0.2,
#  'dairy': 0.0,
#  'ice cream shop': 0.1,
#  'medical laboratory': 0.2,
#  'demolition contractor': 0.667,
#  'meat processor': 0.4,
#  'fmcg manufacturer': 0.4,
#  'garbage collection service': 0.1,
#  'wholesale bakery': 0.0,
#  'dentist': 0.1,
#  'dessert shop': 0.143,
#  'cupcake shop': 0.143,
#  'nut store': 0.0,
#  'wholesale grocer': 0.1,
#  'design engineer': 0.0,
#  'business business service': 0.0,
#  'condiment supplier': 1.0,
#  'digital printing service': 0.4,
#  'culinary school': 1.0,
#  'importer': 1.0,
#  'bottled water supplier': 0.143,
#  'coffee roaster': 0.5,
#  'packaging supply store': 0.1,
#  'ice supplier': 0.3,
#  'brewery': 0.857,
#  'winemaking company': 0.857,
#  'distillery': 0.0,
#  'disability service support organisation': 0.2,
#  'district government office': 0.0,
#  'air filter supplier': 0.2,
#  'tire shop': 0.1,
#  'fastener supplier': 0.6,
#  'fabric product manufacturer': 0.1,
#  'textile': 0.2,
#  'textile exporter': 0.2,
#  'textile engineer': 0.2,
#  'fabric store': 0.0,
#  'knit shop': 0.111,
#  'doctor': 0.2,
#  'lamination service': 0.1,
#  'plastic resin manufacturer': 0.1,
#  'carpet manufacturer': 0.1,
#  'upholstery shop': 0.1,
#  'business administration service': 0.0,
#  'furniture store': 0.0,
#  'dry cleaner': 0.0,
#  'packaging company': 0.1,
#  'duty free store': 0.0,
#  'commerce service': 0.0,
#  'cable company': 0.1,
#  'education': 0.1,
#  'outlet store': 0.0,
#  'lingerie store': 0.25,
#  'clothes fabric manufacturer': 0.0,
#  'education center': 0.1,
#  'uniform store': 0.1,
#  'men clothing store': 0.1,
#  'clothing store': 0.2,
#  'woman clothing store': 0.1,
#  'western apparel store': 0.5,
#  'costume store': 0.3,
#  'game store': 0.0,
#  'hat shop': 0.1,
#  'leather good manufacturer': 0.0,
#  'educational consultant': 0.1,
#  'leather exporter': 0.2,
#  'shoe store': 0.1,
#  'boutique': 0.1,
#  'leather wholesaler': 0.0,
#  'handbag shop': 0.2,
#  'electronics store': 0.1,
#  'luggage store': 0.2,
#  'building material store': 0.0,
#  'saw mill': 0.0,
#  'electrical engineer': 0.0,
#  'deck builder': 0.2,
#  'concrete product supplier': 0.3,
#  'plywood supplier': 0.4,
#  'electrical installation service': 0.1,
#  'truss manufacturer': 0.2,
#  'door supplier': 0.1,
#  'wood laminate flooring supplier': 0.5,
#  'aircraft supply store': 0.0,
#  'modular home builder': 0.0,
#  'portable building manufacturer': 0.0,
#  'modular home dealer': 0.0,
#  'mulch supplier': 1.0,
#  'electrician': 0.333,
#  'paper mill': 0.3,
#  'energy supplier': 0.5,
#  'engineer': 0.25,
#  'print shop': 0.4,
#  'custom label printer': 0.0,
#  'marketing': 0.0,
#  'marketing agency': 0.0,
#  'engineering consultant': 0.1,
#  'entertainer': 0.0,
#  'envelope supplier': 0.125,
#  'oil refinery': 0.0,
#  'recording studio': 0.2,
#  'environment renewable natural resource': 0.0,
#  'finishing material supplier': 0.0,
#  'event ticket seller': 0.0,
#  'waterproofing company': 0.5,
#  'auto part store': 0.1,
#  'heating oil supplier': 0.0,
#  'family practice physician': 0.0,
#  'machining manufacturer': 0.1,
#  'industrial gas supplier': 0.1,
#  'welding supply store': 0.2,
#  'dry ice supplier': 0.0,
#  'private equity firm': 0.0,
#  'family service center': 0.1,
#  'federal government office': 0.1,
#  'vitamin supplement store': 0.25,
#  'feed manufacturer': 0.2,
#  'medical equipment supplier': 0.1,
#  'medical supply store': 0.1,
#  'medical clinic': 0.1,
#  'research institute': 0.3,
#  'biochemical supplier': 0.3,
#  'fiber optic product supplier': 0.0,
#  'paint manufacturer': 0.2,
#  'equipment supplier': 0.2,
#  'food': 0.4,
#  'pipe supplier': 0.4,
#  'oil field equipment supplier': 0.0,
#  'food broker': 0.0,
#  'food manufacturer': 0.1,
#  'food processing company': 0.4,
#  'fence supply store': 0.0,
#  'food producer': 0.4,
#  'forestry service': 0.1,
#  'foundry': 0.6,
#  'wholesale jeweler': 0.0,
#  'cookie shop': 0.667,
#  'truck rental agency': 0.0,
#  'fruit vegetable processing': 0.3,
#  'kitchen supply store': 0.0,
#  'hydraulic equipment supplier': 0.0,
#  'irrigation equipment supplier': 0.143,
#  'bearing supplier': 0.5,
#  'metallurgy company': 1.0,
#  'plastic injection molding service': 0.0,
#  'general contractor': 0.2,
#  'general hospital': 0.0,
#  'tool manufacturer': 0.4,
#  'industrial design company': 0.0,
#  'hyundai dealer': 0.0,
#  'glass industry': 0.3,
#  'polymer supplier': 0.0,
#  'printing equipment supply': 0.1,
#  'toner cartridge supplier': 0.333,
#  'printer repair service': 0.1,
#  'fuel supplier': 0.0,
#  'glass manufacturer': 0.3,
#  'plastic bag supplier': 0.4,
#  'glassware manufacturer': 0.333,
#  'polythene plastic sheeting supplier': 0.333,
#  'pvc industry': 0.5,
#  'countertop store': 0.125,
#  'cabinet store': 0.1,
#  'fiberglass supplier': 0.111,
#  'golf cart dealer': 0.0,
#  'auto repair shop': 0.0,
#  'hose supplier': 0.2,
#  'rubber product supplier': 0.2,
#  'automotive': 0.0,
#  'commercial refrigerator supplier': 0.0,
#  'golf club': 0.1,
#  'golf course': 0.1,
#  'green energy supplier': 0.0,
#  'greenhouse': 0.3,
#  'auto glass shop': 0.0,
#  'lighting manufacturer': 0.4,
#  'cement manufacturer': 0.1,
#  'brick manufacturer': 0.2,
#  'natural stone supplier': 0.0,
#  'gym': 1.0,
#  'marble supplier': 0.125,
#  'corporate gift supplier': 0.0,
#  'shipbuilding repair company': 0.0,
#  'construction maintenance office': 0.2,
#  'boiler manufacturer': 0.3,
#  'container supplier': 0.2,
#  'home construction': 0.1,
#  'health': 0.1,
#  'heart hospital': 0.0,
#  'spring supplier': 0.2,
#  'electric utility manufacturer': 0.0,
#  'aircraft manufacturer': 0.3,
#  'metal heat treating service': 0.1,
#  'plating service': 1.0,
#  'automation company': 0.0,
#  'heating contractor': 0.3,
#  'plumbing supply store': 0.1,
#  'gun shop': 0.1,
#  'ammunition supplier': 0.6,
#  'pipe manufacturer': 0.4,
#  'school': 0.1,
#  'fire protection equipment supplier': 0.0,
#  'agricultural machinery manufacturer': 0.1,
#  'lawn mower store': 0.0,
#  'lawn irrigation equipment supplier': 0.0,
#  'financial consultant': 0.1,
#  'helicopter charter': 0.2,
#  'packaging machinery': 0.0,
#  'historical landmark': 0.2,
#  'electronics manufacturer': 0.0,
#  'graphic designer': 0.2,
#  'eye care center': 0.1,
#  'optical product manufacturer': 0.3,
#  'image consultant': 0.0,
#  'cleaning product supplier': 0.0,
#  'fireplace store': 0.1,
#  'home builder': 0.1,
#  'tool die shop': 0.4,
#  'metal stamping service': 0.0,
#  'environmental organization': 0.1,
#  'food processing equipment': 0.1,
#  'loan agency': 0.2,
#  'power plant equipment supplier': 0.0,
#  'home good store': 0.1,
#  'engine rebuilding service': 0.0,
#  'air compressor supplier': 0.0,
#  'honda dealer': 0.0,
#  'elevator manufacturer': 0.4,
#  'crane dealer': 0.4,
#  'crane rental agency': 0.2,
#  'compound building': 0.0,
#  'tractor dealer': 0.0,
#  'furnace part supplier': 0.0,
#  'heating equipment supplier': 0.2,
#  'pneumatic tool supplier': 0.0,
#  'truck stop': 0.0,
#  'computer hardware manufacturer': 0.2,
#  'satellite communication service': 0.1,
#  'hospital': 0.0,
#  'electronics company': 0.1,
#  'electronic part supplier': 0.3,
#  'hvac contractor': 0.5,
#  'industrial engineer': 0.0,
#  'contact lens supplier': 0.0,
#  'information service': 0.1,
#  'building': 0.2,
#  'water work equipment supplier': 0.0,
#  'measuring instrument supplier': 0.8,
#  'scientific equipment supplier': 0.0,
#  'medical center': 0.0,
#  'watch manufacturer': 0.2,
#  'corporate entertainment service': 0.0,
#  'insurance': 0.3,
#  'record company': 0.1,
#  'video duplication service': 0.3,
#  'insurance agency': 0.3,
#  'lighting store': 0.4,
#  'lighting wholesaler': 0.4,
#  'entertainment agency': 0.1,
#  'insurance broker': 0.3,
#  'electrical equipment supplier': 0.2,
#  'electric motor store': 0.0,
#  'railroad company': 0.2,
#  'electrical supply store': 0.2,
#  'insurance company': 0.3,
#  'factory equipment supplier': 0.0,
#  'investment service': 0.5,
#  'laser equipment supplier': 0.2,
#  'executive suite rental agency': 0.6,
#  'truck dealer': 0.0,
#  'motor vehicle dealer': 0.0,
#  'car dealer': 0.0,
#  'truck topper supplier': 0.1,
#  'police supply store': 0.1,
#  'iron steel contractor': 0.0,
#  'fire department equipment supplier': 0.0,
#  'towing equipment provider': 0.2,
#  'logistics service': 0.4,
#  'trailer manufacturer': 0.3,
#  'trailer dealer': 0.1,
#  'dealer': 0.3,
#  'auto spring shop': 0.0,
#  'auto upholsterer': 0.0,
#  'auto body part supplier': 0.1,
#  'car factory': 0.0,
#  'freight forwarding service': 0.0,
#  'brake shop': 0.1,
#  'railroad equipment supplier': 0.1,
#  'jewelry equipment supplier': 0.6,
#  'boat builder': 0.2,
#  'ship building': 0.2,
#  'marine supply store': 0.0,
#  'boat dealer': 0.2,
#  'kawasaki motorcycle dealer': 0.2,
#  'knife manufacturing': 0.222,
#  'labor union': 0.4,
#  'furniture maker': 0.6,
#  'banking finance': 0.25,
#  'furniture manufacturer': 0.6,
#  'logistics': 0.4,
#  'massage supply store': 0.167,
#  'telecommunication equipment supplier': 0.0,
#  'baby store': 0.0,
#  'molding supplier': 0.0,
#  'office equipment supplier': 0.0,
#  'office furniture store': 0.0,
#  'store equipment supplier': 0.0,
#  'laboratory': 0.1,
#  'health beauty shop': 0.0,
#  'learning center': 0.4,
#  'dental laboratory': 0.3,
#  'land surveyor': 0.1,
#  'educational supply store': 0.0,
#  'jewelry store': 0.0,
#  'playground equipment supplier': 0.2,
#  'outdoor sport store': 0.1,
#  'toy store': 0.0,
#  'security service': 0.0,
#  'sign shop': 0.6,
#  'office supply store': 0.0,
#  'landscaper': 0.0,
#  'gasket manufacturer': 0.667,
#  'piano maker': 0.2,
#  'piano store': 0.2,
#  'funeral home': 0.5,
#  'monument': 0.0,
#  'book publisher': 0.3,
#  'wig shop': 0.25,
#  'laundromat': 1.0,
#  'auto wrecker': 0.0,
#  'auto part market': 0.1,
#  'jeep dealer': 0.1,
#  'restaurant supply store': 0.1,
#  'roofing supply store': 0.4,
#  'law firm': 0.1,
#  'building material market': 0.0,
#  'camera store': 0.2,
#  'lawn care service': 0.1,
#  'computer security service': 0.0,
#  'computer store': 0.0,
#  'design agency': 0.2,
#  'diagnostic center': 0.2,
#  'laboratory equipment supplier': 0.5,
#  'home theater store': 0.0,
#  'metal industry supplier': 0.1,
#  'landscaping supply store': 0.0,
#  'appliance part supplier': 0.3,
#  'vacuum cleaner store': 0.1,
#  'audio visual equipment supplier': 0.1,
#  'lawyer': 0.8,
#  'cell phone store': 0.0,
#  'bathroom supply store': 0.0,
#  'leasing service': 0.4,
#  'construction machine dealer': 0.0,
#  'dairy farm equipment supplier': 0.0,
#  'propane supplier': 0.0,
#  'legal service': 0.2,
#  'janitorial equipment supplier': 0.556,
#  'life insurance agency': 0.0,
#  'railroad contractor': 0.1,
#  'swimming pool supply store': 0.1,
#  'light bulb supplier': 0.4,
#  'linen store': 0.3,
#  'metal construction company': 0.3,
#  'local government office': 0.0,
#  'logging contractor': 0.1,
#  'machine shop': 0.0,
#  'hotel supply store': 0.2,
#  'import export company': 0.0,
#  'sewing company': 0.0,
#  'research foundation': 0.3,
#  'machinery part manufacturer': 0.3,
#  'sport accessory wholesaler': 0.0,
#  'fashion designer': 0.1,
#  'cheese manufacturer': 0.286,
#  'cheese shop': 0.286,
#  'shipping mailing': 0.0,
#  'wholesale food store': 0.1,
#  'organic food store': 0.0,
#  'pie shop': 0.3,
#  'auction house': 0.1,
#  'livestock auction house': 0.1,
#  'cotton exporter': 0.1,
#  'plastic wholesaler': 0.0,
#  'mailing service': 0.0,
#  'manufacturer': 0.0,
#  'gas station': 0.0,
#  'beer distributor': 0.2,
#  'alcoholic beverage wholesaler': 0.1,
#  'religious good store': 0.1,
#  'book wholesaler': 0.1,
#  'masonry supply store': 0.0,
#  'wholesale florist': 0.1,
#  'florist': 0.1,
#  'marine engineer': 0.0,
#  'paint store': 0.0,
#  'used auto part store': 0.0,
#  'masonry contractor': 0.2,
#  'used car dealer': 0.0,
#  'used truck dealer': 0.0,
#  'massage therapist': 0.167,
#  'material handling equipment supplier': 0.1,
#  'marina': 1.0,
#  'meat packer': 0.3,
#  'mattress store': 0.0,
#  'blind shop': 0.2,
#  'interior designer': 0.1,
#  'window treatment store': 0.0,
#  'appliance store': 0.0,
#  'health food store': 0.0,
#  'direct mail advertising': 0.0,
#  'meat wholesaler': 0.3,
#  'butcher shop deli': 0.333,
#  'italian grocery store': 0.0,
#  'market': 0.0,
#  'food service': 0.0,
#  'grocery delivery service': 0.0,
#  'wine store': 0.1,
#  'liquor store': 0.125,
#  'kiosk': 0.125,
#  'optometrist': 0.429,
#  'optician': 0.125,
#  'mechanical contractor': 0.1,
#  'mechanical engineer': 0.0,
#  'cafe': 0.25,
#  'jeweler': 0.25,
#  'leather good store': 0.0,
#  'gift shop': 0.2,
#  'craft store': 0.111,
#  'hobby store': 0.0,
#  'fabric wholesaler': 0.0,
#  'scrap metal dealer': 0.0,
#  'quilt shop': 0.0,
#  'sheet music store': 0.0,
#  'musical instrument manufacturer': 0.2,
#  'music store': 0.0,
#  'musical instrument store': 0.0,
#  'band': 0.1,
#  'bookstore': 0.1,
#  'art museum': 0.0,
#  'newsstand': 1.0,
#  'medical equipment manufacturer': 0.3,
#  'fashion accessory store': 0.2,
#  'discount store': 0.0,
#  'cemetery': 0.2,
#  'bus stop': 0.2,
#  'variety store': 0.0,
#  'thrift store': 0.5,
#  'medical group': 0.1,
#  'donation center': 0.0,
#  'pet store': 0.1,
#  'art gallery': 0.0,
#  'art dealer': 0.0,
#  'housing development': 0.1,
#  'mobile home dealer': 0.1,
#  'convenience store': 0.333,
#  'medical office': 0.1,
#  'medical technology manufacturer': 0.3,
#  'childrens furniture store': 0.3,
#  'mental health clinic': 0.3,
#  'airline': 0.0,
#  'aviation consultant': 0.1,
#  'travel agency': 0.2,
#  'travel service': 0.2,
#  'airport': 0.1,
#  'mental health service': 0.3,
#  'shipping company': 0.0,
#  'metal fabricator': 0.3,
#  'cruise line company': 0.0,
#  'towing service': 0.2,
#  'ferry terminal': 0.0,
#  'ferry service': 0.5,
#  'metal finisher': 0.1,
#  'boat tour agency': 0.1,
#  'bus company': 0.2,
#  'moving company': 0.3,
#  'moving storage service': 0.3,
#  'state department transportation': 0.1,
#  'department transportation': 0.1,
#  'handicapped transportation service': 0.667,
#  'railway service': 0.1,
#  'train station': 0.0,
#  'bus depot': 0.1,
#  'bus charter': 0.0,
#  'metal processing company': 0.3,
#  'mixed use': 0.0,
#  'motorcycle shop': 0.2,
#  'limousine service': 0.2,
#  'chauffeur service': 0.0,
#  'school bus service': 0.0,
#  'airport shuttle service': 0.0,
#  'tourist information center': 0.167,
#  'carriage ride service': 0.25,
#  'cruise agency': 0.1,
#  'tourist attraction': 0.167,
#  'ski resort': 0.1,
#  'ski area': 0.1,
#  'fixed base operator': 0.0,
#  'aircraft maintenance company': 0.2,
#  'motorsports store': 0.2,
#  'boat rental service': 0.0,
#  'utility trailer dealer': 0.0,
#  'forklift dealer': 0.25,
#  'municipal administration office': 0.0,
#  'nephrologist': 0.0,
#  'bus coach company': 0.0,
#  'shipping service': 0.0,
#  'shipping mailing service': 0.0,
#  'newspaper publisher': 0.4,
#  'shredding service': 0.333,
#  'nuclear power company': 0.4,
#  'nursing home': 0.1,
#  'medium company': 0.1,
#  'multimedia electronic book publisher': 0.1,
#  'internet marketing service': 0.0,
#  'greeting card shop': 0.1,
#  'theme park': 1.0,
#  'film production company': 0.2,
#  'obstetrician gynecologist': 1.0,
#  'movie studio': 0.3,
#  'video production service': 0.3,
#  'movie theater': 0.3,
#  'theater company': 0.1,
#  'performing art theater': 0.1,
#  'occupational safety health': 0.0,
#  'office space rental agency': 0.0,
#  'commercial real estate agency': 0.0,
#  'art school': 0.0,
#  'music publisher': 0.2,
#  'printed music publisher': 0.0,
#  'home audio store': 0.0,
#  'musician': 1.0,
#  'music management promotion': 0.0,
#  'video editing service': 0.3,
#  'office supply wholesaler': 0.2,
#  'official residence': 0.0,
#  'orthopedic clinic': 0.125,
#  'painter': 0.0,
#  'painting': 0.3,
#  'telephone company': 0.2,
#  'medium house': 0.1,
#  'paper distributor': 0.1,
#  'news service': 0.1,
#  'public library': 0.0,
#  'law library': 0.1,
#  'museum': 0.571,
#  'federal reserve bank': 0.0,
#  'credit union': 0.1,
#  'atm': 0.25,
#  'paving contractor': 0.1,
#  'mortgage lender': 0.1,
#  'investment bank': 0.1,
#  'check cashing service': 0.3,
#  'stock broker': 0.0,
#  'health consultant': 0.0,
#  'health insurance agency': 0.0,
#  'payroll service': 0.2,
#  'pediatrician': 1.0,
#  'human resource consulting': 0.3,
#  'pest control service': 0.5,
#  'pet boarding service': 0.2,
#  'pet care': 0.2,
#  'loss adjuster': 0.222,
#  'pharmaceutical company': 0.4,
#  'pharmaceutical product wholesaler': 0.1,
#  'pharmacy': 0.167,
#  'educational institution': 0.1,
#  'retirement community': 0.2,
#  'fraternal organization': 0.5,
#  'photo lab': 0.0,
#  'property investment': 0.1,
#  'photographer': 0.5,
#  'photography school': 0.2,
#  'star hotel': 0.2,
#  'convention center': 0.25,
#  'real estate appraiser': 0.3,
#  'photography service': 0.2,
#  'resort hotel': 0.1,
#  'real estate consultant': 0.1,
#  'car rental agency': 0.2,
#  'car leasing service': 0.2,
#  'ford dealer': 0.2,
#  'car finance loan company': 0.0,
#  'trailer rental service': 0.1,
#  'furniture rental service': 0.0,
#  'tuxedo shop': 0.333,
#  'dress tuxedo rental service': 0.111,
#  'wedding store': 0.0,
#  'video store': 0.0,
#  'movie rental': 0.3,
#  'photography studio': 0.2,
#  'home health care service': 0.0,
#  'skateboard shop': 1.0,
#  'event technology service': 0.0,
#  'party equipment rental service': 0.2,
#  'construction machine rental service': 0.0,
#  'audio visual equipment rental service': 0.1,
#  'shipping equipment industry': 0.0,
#  'physical therapy clinic': 0.2,
#  'plastic fabrication company': 0.4,
#  'plastic product supplier': 0.4,
#  'auto tag agency': 0.0,
#  'department motor vehicle': 0.1,
#  'notary public': 0.8,
#  'private investigator': 0.0,
#  'escrow service': 0.667,
#  'real estate agent': 0.1,
#  'playground': 0.0,
#  'plumber': 0.167,
#  'port authority': 0.4,
#  'portrait studio': 0.2,
#  'post office': 0.1,
#  'professional service': 0.2,
#  'university hospital': 0.0,
#  'public relation firm': 0.0,
#  'civil engineering company': 0.1,
#  'drafting service': 0.7,
#  'pump supplier': 0.9,
#  'interior construction contractor': 0.0,
#  'carpet cleaning service': 0.3,
#  'exhibition planner': 0.0,
#  'decal supplier': 0.0,
#  'stage lighting equipment supplier': 0.0,
#  'event management company': 0.0,
#  'radio broadcaster': 0.0,
#  'computer support service': 0.0,
#  'ravine': 0.0,
#  'employment center': 0.4,
#  'national health foundation': 0.0,
#  'real estate developer': 0.0,
#  'advertising agency': 0.1,
#  'promotional product supplier': 0.0,
#  'advertising service': 0.1,
#  'record storage facility': 0.0,
#  'fund management company': 0.0,
#  'recreation center': 0.4,
#  'bakery': 0.4,
#  'database management company': 0.0,
#  'market researcher': 0.0,
#  'recycling center': 0.0,
#  'regional government office': 0.0,
#  'rehabilitation center': 0.1,
#  'religious institution': 0.1,
#  'religious organization': 0.1,
#  'repair service': 0.1,
#  'emergency veterinarian service': 0.0,
#  'pet sitter': 0.2,
#  'research product development': 0.3,
#  'building society': 0.2,
#  'valet parking service': 0.667,
#  'nursing agency': 0.1,
#  'executive search firm': 0.2,
#  'recruiter': 0.2,
#  'temp agency': 0.2,
#  'health center': 0.0,
#  'restaurant': 0.3,
#  'roofing contractor': 0.2,
#  'sport nutrition store': 0.0,
#  'credit reporting agency': 0.0,
#  'automobile storage facility': 0.0,
#  'debt collection agency': 0.3,
#  'park': 0.0,
#  'court reporter': 0.3,
#  'bus tour agency': 0.1,
#  'tour operator': 0.3,
#  'convention information bureau': 0.25,
#  'balloon ride tour agency': 0.1,
#  'security guard service': 0.0,
#  'locksmith': 0.667,
#  'commercial cleaning service': 0.0,
#  'blast cleaning service': 0.0,
#  'conference center': 0.111,
#  'safety equipment supplier': 0.0,
#  'garbage dump': 0.1,
#  'sanitation service': 0.125,
#  'garbage dump service': 0.1,
#  'environmental health service': 0.2,
#  'portable toilet supplier': 0.0,
#  'public work department': 0.2,
#  'school district office': 0.1,
#  'sailmaker': 0.1,
#  'community college': 0.0,
#  'salvage yard': 0.0,
#  'business school': 0.0,
#  'trade school': 0.0,
#  'private university': 0.0,
#  'computer training school': 0.0,
#  'school supply store': 0.0,
#  'screen printer': 0.4,
#  'medium consultant': 0.1,
#  'beauty school': 0.0,
#  'flight school': 0.4,
#  'seaport': 0.0,
#  'security system supplier': 0.0,
#  'middle school': 1.0,
#  'nonprofit': 1.0,
#  'shooting range': 0.125,
#  'soccer club': 0.333,
#  'camp': 0.2,
#  'diving contractor': 0.25,
#  'language school': 0.5,
#  'english language school': 0.0,
#  'preschool': 0.5,
#  'self storage facility': 0.4,
#  'semi conductor supplier': 0.0,
#  'driving school': 0.3,
#  'trucking school': 0.0,
#  'senior citizen center': 0.167,
#  'service': 0.0,
#  'childrens hospital': 0.0,
#  'dental supply store': 0.3,
#  'shipyard': 0.2,
#  'orthodox synagogue': 0.2,
#  'short term apartment rental agency': 0.0,
#  'nutritionist': 1.0,
#  'ophthalmologist': 0.0,
#  'ophthalmology clinic': 0.0,
#  'social service organization': 0.3,
#  'social welfare center': 0.3,
#  'solar energy company': 0.7,
#  'solar energy equipment supplier': 0.7,
#  'special education school': 0.0,
#  'podiatrist': 1.0,
#  'reproductive health clinic': 0.5,
#  'sporting good store': 0.1,
#  'dialysis center': 0.8,
#  'sport complex': 0.2,
#  'wellness program': 0.0,
#  'sportswear store': 0.0,
#  'private hospital': 0.0,
#  'radiologist': 0.0,
#  'medical diagnostic imaging center': 0.2,
#  'ray lab': 0.2,
#  'blood bank': 0.2,
#  'stainless steel plant': 0.25,
#  'state agency': 0.1,
#  'heliport': 0.1,
#  'health care company': 0.0,
#  'psychiatric hospital': 0.2,
#  'state government office': 0.1,
#  'medical institution': 0.0,
#  'steel construction company': 0.1,
#  'cleaning service': 0.3,
#  ...}

# %%
rec_at_n
# Out:
# {'home improvement store': 0.0,
#  'diesel fuel supplier': 0.5,
#  'church': 1.0,
#  'farm': 0.333,
#  'seed supplier': 0.167,
#  'accountant': 1.0,
#  'trucking company': 1.0,
#  'exporter': 0.143,
#  'grain elevator': 0.0,
#  'popcorn store': 0.333,
#  'agricultural service': 0.167,
#  'warehouse': 0.0,
#  'agricultural production': 0.143,
#  'ranch': 0.0,
#  'holding company': 1.0,
#  'farm equipment supplier': 0.167,
#  'store': 0.0,
#  'grocery store': 0.0,
#  'rice mill': 0.571,
#  'food product supplier': 0.0,
#  'accounting firm': 0.5,
#  'produce market': 0.0,
#  'pet supply store': 0.2,
#  'wholesaler': 0.0,
#  'produce wholesaler': 0.0,
#  'distribution service': 0.0,
#  'crop grower': 0.143,
#  'addiction treatment center': 0.5,
#  'natural good store': 0.0,
#  'orchard': 0.111,
#  'lumber store': 0.25,
#  'mine': 0.333,
#  'transportation service': 0.5,
#  'investment company': 0.25,
#  'fruit wholesaler': 0.111,
#  'real estate agency': 1.0,
#  'event venue': 0.0,
#  'frozen dessert supplier': 0.6,
#  'wine wholesaler importer': 1.0,
#  'winery': 1.0,
#  'aerospace company': 1.0,
#  'cold storage facility': 0.25,
#  'employment agency': 1.0,
#  'plant nursery': 0.0,
#  'air conditioning contractor': 0.333,
#  'air conditioning repair service': 0.333,
#  'fruit vegetable wholesaler': 0.0,
#  'aircraft rental service': 0.0,
#  'monastery': 1.0,
#  'allergist': 0.5,
#  'herb shop': 0.0,
#  'aluminum supplier': 1.0,
#  'ambulance service': 1.0,
#  'wholesale plant nursery': 0.167,
#  'amusement machine supplier': 0.5,
#  'animal hospital': 0.0,
#  'farmer market': 0.0,
#  'vaporizer store': 0.0,
#  'cigar shop': 0.4,
#  'tobacco shop': 0.0,
#  'well drilling contractor': 0.6,
#  'library': 0.75,
#  'apartment building': 0.25,
#  'apartment rental agency': 0.25,
#  'dairy farm': 0.0,
#  'architect': 0.25,
#  'organic farm': 0.0,
#  'architectural designer': 0.375,
#  'architecture firm': 0.0,
#  'livestock producer': 0.0,
#  'dairy supplier': 0.222,
#  'biotechnology company': 0.75,
#  'artist': 1.0,
#  'egg supplier': 1.0,
#  'poultry farm': 0.75,
#  'chicken hatchery': 0.8,
#  'art organization': 0.75,
#  'association organization': 0.6,
#  'food store': 0.0,
#  'deli': 0.0,
#  'bank': 0.75,
#  'fish processing': 1.0,
#  'fish farm': 0.333,
#  'seafood wholesaler': 0.222,
#  'tropical fish store': 0.0,
#  'non profit organization': 0.0,
#  'economic development agency': 0.2,
#  'seafood market': 0.167,
#  'honey farm': 1.0,
#  'horse breeder': 0.25,
#  'asphalt contractor': 0.0,
#  'livestock dealer': 0.333,
#  'department store': 1.0,
#  'mill': 0.0,
#  'atv dealer': 0.667,
#  'audio visual consultant': 1.0,
#  'pallet supplier': 0.571,
#  'wood supplier': 0.0,
#  'hardware store': 0.0,
#  'furniture wholesaler': 0.0,
#  'auditor': 0.25,
#  'oil natural gas company': 0.2,
#  'auto body shop': 0.0,
#  'boat repair shop': 1.0,
#  'association': 0.6,
#  'railing contractor': 0.167,
#  'publisher': 1.0,
#  'pond supply store': 0.0,
#  'agriculture cooperative': 0.0,
#  'printing equipment supplier': 0.2,
#  'auto insurance agency': 0.0,
#  'alternative fuel station': 1.0,
#  'auto part manufacturer': 0.0,
#  'foundation': 0.333,
#  'fertilizer supplier': 1.0,
#  'farming company': 0.0,
#  'finance broker': 0.333,
#  'agricultural cooperative': 0.0,
#  'fire station': 0.0,
#  'environmental consultant': 0.286,
#  'civil engineer': 1.0,
#  'fire protection service': 0.0,
#  'gas company': 0.0,
#  'oilfield': 0.0,
#  'banquet hall': 0.333,
#  'mining company': 0.333,
#  'coalfield': 0.0,
#  'steel fabricator': 0.167,
#  'quarry': 0.5,
#  'gold mining company': 0.5,
#  'high rise building': 0.0,
#  'basketball club': 0.333,
#  'gold dealer': 0.0,
#  'battery manufacturer': 0.625,
#  'electric utility company': 0.0,
#  'environmental program': 0.333,
#  'office': 0.0,
#  'stone supplier': 0.25,
#  'aggregate supplier': 0.0,
#  'sand gravel supplier': 0.333,
#  'building material supplier': 0.0,
#  'beauty supply store': 0.6,
#  'crushed stone supplier': 0.25,
#  'rock shop': 0.0,
#  'road construction company': 1.0,
#  'marketing consultant': 0.0,
#  'blood testing service': 0.0,
#  'contractor': 1.0,
#  'excavating contractor': 0.5,
#  'asphalt mixing plant': 1.0,
#  'ready mix concrete supplier': 0.0,
#  'sand plant': 0.333,
#  'bmw dealer': 0.0,
#  'bookbinder': 0.0,
#  'garden center': 0.5,
#  'abrasive supplier': 0.8,
#  'granite supplier': 0.2,
#  'drilling contractor': 0.8,
#  'bpo company': 0.0,
#  'oil gas exploration service': 0.2,
#  'building complex': 0.0,
#  'construction equipment supplier': 0.0,
#  'mining equipment': 0.0,
#  'bus ticket agency': 0.25,
#  'business center': 0.0,
#  'skyscraper': 0.0,
#  'software company': 1.0,
#  'business development service': 0.0,
#  'business management consultant': 0.0,
#  'cabinet maker': 1.0,
#  'call center': 0.2,
#  'cancer treatment center': 1.0,
#  'power plant consultant': 0.333,
#  'business park': 0.0,
#  'petroleum product company': 1.0,
#  'parking lot': 0.4,
#  'water utility company': 0.667,
#  'car repair maintenance': 0.333,
#  'water treatment plant': 0.667,
#  'car service': 0.333,
#  'cattle market': 0.333,
#  'sewage disposal service': 1.0,
#  'certified public accountant': 0.25,
#  'government office': 0.333,
#  'charity': 0.333,
#  'air conditioning system supplier': 0.25,
#  'chemical industry': 0.2,
#  'chemical manufacturer': 0.2,
#  'title company': 0.0,
#  'chemical plant': 0.2,
#  'property management company': 0.25,
#  'custom home builder': 0.0,
#  'window installation service': 0.0,
#  'fire damage restoration service': 0.0,
#  'equipment rental agency': 0.25,
#  'chemical wholesaler': 0.5,
#  'financial planner': 0.2,
#  'telecommunication service provider': 1.0,
#  'energy equipment solution': 0.0,
#  'chiropractor': 0.5,
#  'steel distributor': 0.0,
#  'city government office': 0.5,
#  'crane service': 0.286,
#  'garage door supplier': 0.167,
#  'industrial door supplier': 0.0,
#  'city town hall': 0.5,
#  'clothing wholesaler': 0.5,
#  'coin operated laundry equipment supplier': 0.75,
#  'metal supplier': 0.5,
#  'glass shop': 0.0,
#  'college': 1.0,
#  'siding contractor': 0.25,
#  'commercial printer': 0.25,
#  'storage facility': 1.0,
#  'communication tower': 0.0,
#  'janitorial service': 1.0,
#  'computer consultant': 0.0,
#  'fire protection system supplier': 0.0,
#  'elevator service': 0.286,
#  'industrial equipment supplier': 0.333,
#  'dry wall contractor': 0.0,
#  'insulation contractor': 0.333,
#  'concrete contractor': 0.375,
#  'scaffolding rental service': 0.25,
#  'construction company': 1.0,
#  'flooring store': 0.0,
#  'flooring contractor': 0.333,
#  'tile contractor': 0.667,
#  'tile manufacturer': 0.667,
#  'glass mirror shop': 0.0,
#  'construction material wholesaler': 0.0,
#  'gutter cleaning service': 0.2,
#  'sheet metal contractor': 0.333,
#  'consultant': 0.143,
#  'container service': 0.5,
#  'septic system service': 0.75,
#  'corporate campus': 0.333,
#  'water damage restoration service': 0.0,
#  'welder': 0.0,
#  'corporate office': 0.333,
#  'animal': 0.5,
#  'animal feed store': 0.0,
#  'animal protection organization': 0.0,
#  'brewing supply store': 0.0,
#  'cosmetic store': 0.6,
#  'county government office': 0.5,
#  'sugar factory': 1.0,
#  'confectionery wholesaler': 0.222,
#  'financial institution': 0.0,
#  'candy store': 0.0,
#  'confectionery': 0.0,
#  'chocolate factory': 1.0,
#  'chocolate shop': 1.0,
#  'courier service': 1.0,
#  'coworking space': 0.0,
#  'frozen food manufacturer': 0.4,
#  'beverage distributor': 0.0,
#  'agricultural organization': 0.0,
#  'dairy store': 0.222,
#  'dairy': 0.0,
#  'ice cream shop': 0.2,
#  'medical laboratory': 1.0,
#  'demolition contractor': 1.0,
#  'meat processor': 1.0,
#  'fmcg manufacturer': 0.0,
#  'garbage collection service': 0.333,
#  'wholesale bakery': 0.0,
#  'dentist': 1.0,
#  'dessert shop': 0.167,
#  'cupcake shop': 0.0,
#  'nut store': 0.0,
#  'wholesale grocer': 0.111,
#  'design engineer': 0.0,
#  'business business service': 0.0,
#  'condiment supplier': 1.0,
#  'digital printing service': 1.0,
#  'culinary school': 0.25,
#  'importer': 0.0,
#  'bottled water supplier': 0.167,
#  'coffee roaster': 0.625,
#  'packaging supply store': 0.333,
#  'ice supplier': 0.5,
#  'brewery': 1.0,
#  'winemaking company': 0.0,
#  'distillery': 0.0,
#  'disability service support organisation': 0.667,
#  'district government office': 0.0,
#  'air filter supplier': 0.667,
#  'tire shop': 0.5,
#  'fastener supplier': 0.545,
#  'fabric product manufacturer': 0.5,
#  'textile': 1.0,
#  'textile exporter': 1.0,
#  'textile engineer': 1.0,
#  'fabric store': 0.0,
#  'knit shop': 0.25,
#  'doctor': 1.0,
#  'lamination service': 0.091,
#  'plastic resin manufacturer': 0.333,
#  'carpet manufacturer': 0.5,
#  'upholstery shop': 0.2,
#  'business administration service': 0.0,
#  'furniture store': 0.0,
#  'dry cleaner': 0.0,
#  'packaging company': 0.333,
#  'duty free store': 0.0,
#  'commerce service': 0.0,
#  'cable company': 1.0,
#  'education': 1.0,
#  'outlet store': 0.0,
#  'lingerie store': 0.167,
#  'clothes fabric manufacturer': 0.0,
#  'education center': 1.0,
#  'uniform store': 0.167,
#  'men clothing store': 0.167,
#  'clothing store': 0.333,
#  'woman clothing store': 0.167,
#  'western apparel store': 0.167,
#  'costume store': 0.5,
#  'game store': 0.0,
#  'hat shop': 0.167,
#  'leather good manufacturer': 0.0,
#  'educational consultant': 1.0,
#  'leather exporter': 1.0,
#  'shoe store': 1.0,
#  'boutique': 0.0,
#  'leather wholesaler': 0.0,
#  'handbag shop': 1.0,
#  'electronics store': 0.5,
#  'luggage store': 1.0,
#  'building material store': 0.0,
#  'saw mill': 0.0,
#  'electrical engineer': 0.0,
#  'deck builder': 0.167,
#  'concrete product supplier': 0.6,
#  'plywood supplier': 0.8,
#  'electrical installation service': 0.333,
#  'truss manufacturer': 0.4,
#  'door supplier': 0.143,
#  'wood laminate flooring supplier': 0.714,
#  'aircraft supply store': 0.0,
#  'modular home builder': 0.0,
#  'portable building manufacturer': 0.0,
#  'modular home dealer': 0.0,
#  'mulch supplier': 0.167,
#  'electrician': 0.333,
#  'paper mill': 0.75,
#  'energy supplier': 0.5,
#  'engineer': 0.125,
#  'print shop': 1.0,
#  'custom label printer': 0.0,
#  'marketing': 0.0,
#  'marketing agency': 0.0,
#  'engineering consultant': 0.125,
#  'entertainer': 0.0,
#  'envelope supplier': 0.143,
#  'oil refinery': 0.0,
#  'recording studio': 0.5,
#  'environment renewable natural resource': 0.0,
#  'finishing material supplier': 0.0,
#  'event ticket seller': 0.0,
#  'waterproofing company': 0.167,
#  'auto part store': 0.5,
#  'heating oil supplier': 0.0,
#  'family practice physician': 0.0,
#  'machining manufacturer': 0.2,
#  'industrial gas supplier': 0.143,
#  'welding supply store': 0.143,
#  'dry ice supplier': 0.0,
#  'private equity firm': 0.0,
#  'family service center': 0.333,
#  'federal government office': 0.167,
#  'vitamin supplement store': 0.2,
#  'feed manufacturer': 1.0,
#  'medical equipment supplier': 0.143,
#  'medical supply store': 0.143,
#  'medical clinic': 0.5,
#  'research institute': 0.75,
#  'biochemical supplier': 0.0,
#  'fiber optic product supplier': 0.0,
#  'paint manufacturer': 1.0,
#  'equipment supplier': 0.333,
#  'food': 0.5,
#  'pipe supplier': 0.4,
#  'oil field equipment supplier': 0.0,
#  'food broker': 0.0,
#  'food manufacturer': 0.5,
#  'food processing company': 0.5,
#  'fence supply store': 0.0,
#  'food producer': 0.5,
#  'forestry service': 1.0,
#  'foundry': 1.0,
#  'wholesale jeweler': 0.0,
#  'cookie shop': 0.333,
#  'truck rental agency': 0.0,
#  'fruit vegetable processing': 0.6,
#  'kitchen supply store': 0.0,
#  'hydraulic equipment supplier': 0.0,
#  'irrigation equipment supplier': 0.333,
#  'bearing supplier': 0.5,
#  'metallurgy company': 1.0,
#  'plastic injection molding service': 0.0,
#  'general contractor': 1.0,
#  'general hospital': 0.0,
#  'tool manufacturer': 0.8,
#  'industrial design company': 0.0,
#  'hyundai dealer': 0.0,
#  'glass industry': 0.75,
#  'polymer supplier': 0.0,
#  'printing equipment supply': 0.2,
#  'toner cartridge supplier': 0.2,
#  'printer repair service': 0.25,
#  'fuel supplier': 0.0,
#  'glass manufacturer': 0.75,
#  'plastic bag supplier': 0.364,
#  'glassware manufacturer': 0.5,
#  'polythene plastic sheeting supplier': 0.0,
#  'pvc industry': 0.091,
#  'countertop store': 0.25,
#  'cabinet store': 0.25,
#  'fiberglass supplier': 0.2,
#  'golf cart dealer': 0.0,
#  'auto repair shop': 0.0,
#  'hose supplier': 0.4,
#  'rubber product supplier': 0.4,
#  'automotive': 0.0,
#  'commercial refrigerator supplier': 0.0,
#  'golf club': 0.167,
#  'golf course': 0.167,
#  'green energy supplier': 0.0,
#  'greenhouse': 0.75,
#  'auto glass shop': 0.0,
#  'lighting manufacturer': 1.0,
#  'cement manufacturer': 0.2,
#  'brick manufacturer': 0.4,
#  'natural stone supplier': 0.0,
#  'gym': 0.167,
#  'marble supplier': 0.2,
#  'corporate gift supplier': 0.0,
#  'shipbuilding repair company': 0.0,
#  'construction maintenance office': 1.0,
#  'boiler manufacturer': 0.75,
#  'container supplier': 0.5,
#  'home construction': 0.25,
#  'health': 0.5,
#  'heart hospital': 0.0,
#  'spring supplier': 1.0,
#  'electric utility manufacturer': 0.0,
#  'aircraft manufacturer': 0.5,
#  'metal heat treating service': 0.333,
#  'plating service': 1.0,
#  'automation company': 0.0,
#  'heating contractor': 1.0,
#  'plumbing supply store': 0.25,
#  'gun shop': 0.25,
#  'ammunition supplier': 0.6,
#  'pipe manufacturer': 0.4,
#  'school': 1.0,
#  'fire protection equipment supplier': 0.0,
#  'agricultural machinery manufacturer': 0.2,
#  'lawn mower store': 0.0,
#  'lawn irrigation equipment supplier': 0.0,
#  'financial consultant': 0.2,
#  'helicopter charter': 0.667,
#  'packaging machinery': 0.0,
#  'historical landmark': 0.5,
#  'electronics manufacturer': 0.0,
#  'graphic designer': 0.5,
#  'eye care center': 0.167,
#  'optical product manufacturer': 1.0,
#  'image consultant': 0.0,
#  'cleaning product supplier': 0.0,
#  'fireplace store': 0.25,
#  'home builder': 0.25,
#  'tool die shop': 0.8,
#  'metal stamping service': 0.0,
#  'environmental organization': 0.333,
#  'food processing equipment': 0.2,
#  'loan agency': 0.667,
#  'power plant equipment supplier': 0.0,
#  'home good store': 0.333,
#  'engine rebuilding service': 0.0,
#  'air compressor supplier': 0.0,
#  'honda dealer': 0.0,
#  'elevator manufacturer': 0.286,
#  'crane dealer': 0.286,
#  'crane rental agency': 0.5,
#  'compound building': 0.0,
#  'tractor dealer': 0.0,
#  'furnace part supplier': 0.0,
#  'heating equipment supplier': 0.5,
#  'pneumatic tool supplier': 0.0,
#  'truck stop': 0.0,
#  'computer hardware manufacturer': 0.667,
#  'satellite communication service': 1.0,
#  'hospital': 0.0,
#  'electronics company': 0.5,
#  'electronic part supplier': 1.0,
#  'hvac contractor': 0.333,
#  'industrial engineer': 0.0,
#  'contact lens supplier': 0.0,
#  'information service': 0.25,
#  'building': 1.0,
#  'water work equipment supplier': 0.0,
#  'measuring instrument supplier': 0.889,
#  'scientific equipment supplier': 0.0,
#  'medical center': 0.0,
#  'watch manufacturer': 0.4,
#  'corporate entertainment service': 0.0,
#  'insurance': 0.75,
#  'record company': 0.25,
#  'video duplication service': 0.5,
#  'insurance agency': 0.75,
#  'lighting store': 1.0,
#  'lighting wholesaler': 1.0,
#  'entertainment agency': 1.0,
#  'insurance broker': 0.75,
#  'electrical equipment supplier': 0.667,
#  'electric motor store': 0.0,
#  'railroad company': 1.0,
#  'electrical supply store': 0.667,
#  'insurance company': 0.75,
#  'factory equipment supplier': 0.0,
#  'investment service': 1.0,
#  'laser equipment supplier': 0.222,
#  'executive suite rental agency': 1.0,
#  'truck dealer': 0.0,
#  'motor vehicle dealer': 0.0,
#  'car dealer': 0.0,
#  'truck topper supplier': 0.167,
#  'police supply store': 0.2,
#  'iron steel contractor': 0.0,
#  'fire department equipment supplier': 0.0,
#  'towing equipment provider': 1.0,
#  'logistics service': 0.571,
#  'trailer manufacturer': 0.75,
#  'trailer dealer': 0.333,
#  'dealer': 1.0,
#  'auto spring shop': 0.0,
#  'auto upholsterer': 0.0,
#  'auto body part supplier': 0.5,
#  'car factory': 0.0,
#  'freight forwarding service': 0.0,
#  'brake shop': 0.111,
#  'railroad equipment supplier': 0.167,
#  'jewelry equipment supplier': 0.545,
#  'boat builder': 1.0,
#  'ship building': 1.0,
#  'marine supply store': 0.0,
#  'boat dealer': 0.667,
#  'kawasaki motorcycle dealer': 0.0,
#  'knife manufacturing': 1.0,
#  'labor union': 0.8,
#  'furniture maker': 1.0,
#  'banking finance': 0.5,
#  'furniture manufacturer': 1.0,
#  'logistics': 0.571,
#  'massage supply store': 0.167,
#  'telecommunication equipment supplier': 0.0,
#  'baby store': 0.0,
#  'molding supplier': 0.0,
#  'office equipment supplier': 0.0,
#  'office furniture store': 0.0,
#  'store equipment supplier': 0.0,
#  'laboratory': 0.125,
#  'health beauty shop': 0.0,
#  'learning center': 0.667,
#  'dental laboratory': 0.6,
#  'land surveyor': 0.125,
#  'educational supply store': 0.0,
#  'jewelry store': 0.0,
#  'playground equipment supplier': 0.2,
#  'outdoor sport store': 0.25,
#  'toy store': 0.0,
#  'security service': 0.0,
#  'sign shop': 0.545,
#  'office supply store': 0.0,
#  'landscaper': 0.0,
#  'gasket manufacturer': 0.545,
#  'piano maker': 0.091,
#  'piano store': 0.25,
#  'funeral home': 1.0,
#  'monument': 0.0,
#  'book publisher': 0.5,
#  'wig shop': 0.167,
#  'laundromat': 0.25,
#  'auto wrecker': 0.0,
#  'auto part market': 0.5,
#  'jeep dealer': 0.0,
#  'restaurant supply store': 0.167,
#  'roofing supply store': 1.0,
#  'law firm': 0.25,
#  'building material market': 0.0,
#  'camera store': 0.286,
#  'lawn care service': 0.2,
#  'computer security service': 0.0,
#  'computer store': 0.0,
#  'design agency': 0.5,
#  'diagnostic center': 1.0,
#  'laboratory equipment supplier': 0.556,
#  'home theater store': 0.0,
#  'metal industry supplier': 0.5,
#  'landscaping supply store': 0.0,
#  'appliance part supplier': 1.0,
#  'vacuum cleaner store': 0.5,
#  'audio visual equipment supplier': 1.0,
#  'lawyer': 1.0,
#  'cell phone store': 0.0,
#  'bathroom supply store': 0.0,
#  'leasing service': 1.0,
#  'construction machine dealer': 0.0,
#  'dairy farm equipment supplier': 0.0,
#  'propane supplier': 0.0,
#  'legal service': 0.5,
#  'janitorial equipment supplier': 1.0,
#  'life insurance agency': 0.0,
#  'railroad contractor': 1.0,
#  'swimming pool supply store': 0.2,
#  'light bulb supplier': 1.0,
#  'linen store': 0.75,
#  'metal construction company': 0.5,
#  'local government office': 0.0,
#  'logging contractor': 1.0,
#  'machine shop': 0.0,
#  'hotel supply store': 0.5,
#  'import export company': 0.0,
#  'sewing company': 0.0,
#  'research foundation': 0.75,
#  'machinery part manufacturer': 0.6,
#  'sport accessory wholesaler': 0.0,
#  'fashion designer': 0.25,
#  'cheese manufacturer': 0.4,
#  'cheese shop': 0.4,
#  'shipping mailing': 0.0,
#  'wholesale food store': 0.111,
#  'organic food store': 0.0,
#  'pie shop': 0.5,
#  'auction house': 0.2,
#  'livestock auction house': 0.333,
#  'cotton exporter': 0.143,
#  'plastic wholesaler': 0.0,
#  'mailing service': 0.0,
#  'manufacturer': 0.0,
#  'gas station': 0.0,
#  'beer distributor': 1.0,
#  'alcoholic beverage wholesaler': 0.5,
#  'religious good store': 1.0,
#  'book wholesaler': 0.167,
#  'masonry supply store': 0.0,
#  'wholesale florist': 0.167,
#  'florist': 1.0,
#  'marine engineer': 0.0,
#  'paint store': 0.0,
#  'used auto part store': 0.0,
#  'masonry contractor': 0.25,
#  'used car dealer': 0.0,
#  'used truck dealer': 0.0,
#  'massage therapist': 0.167,
#  'material handling equipment supplier': 0.167,
#  'marina': 1.0,
#  'meat packer': 0.333,
#  'mattress store': 0.0,
#  'blind shop': 1.0,
#  'interior designer': 0.25,
#  'window treatment store': 0.0,
#  'appliance store': 0.0,
#  'health food store': 0.0,
#  'direct mail advertising': 0.0,
#  'meat wholesaler': 0.333,
#  'butcher shop deli': 0.167,
#  'italian grocery store': 0.0,
#  'market': 0.0,
#  'food service': 0.0,
#  'grocery delivery service': 0.0,
#  'wine store': 1.0,
#  'liquor store': 1.0,
#  'kiosk': 0.0,
#  'optometrist': 0.5,
#  'optician': 0.167,
#  'mechanical contractor': 0.333,
#  'mechanical engineer': 0.0,
#  'cafe': 0.5,
#  'jeweler': 0.2,
#  'leather good store': 0.0,
#  'gift shop': 1.0,
#  'craft store': 0.25,
#  'hobby store': 0.0,
#  'fabric wholesaler': 0.0,
#  'scrap metal dealer': 0.0,
#  'quilt shop': 0.0,
#  'sheet music store': 0.0,
#  'musical instrument manufacturer': 0.182,
#  'music store': 0.0,
#  'musical instrument store': 0.0,
#  'band': 0.25,
#  'bookstore': 0.0,
#  'art museum': 0.0,
#  'newsstand': 0.5,
#  'medical equipment manufacturer': 0.6,
#  'fashion accessory store': 0.333,
#  'discount store': 0.0,
#  'cemetery': 0.5,
#  'bus stop': 0.5,
#  'variety store': 0.0,
#  'thrift store': 1.0,
#  'medical group': 0.5,
#  'donation center': 0.0,
#  'pet store': 0.2,
#  'art gallery': 0.0,
#  'art dealer': 0.0,
#  'housing development': 0.5,
#  'mobile home dealer': 0.2,
#  'convenience store': 1.0,
#  'medical office': 0.5,
#  'medical technology manufacturer': 0.6,
#  'childrens furniture store': 0.0,
#  'mental health clinic': 0.5,
#  'airline': 0.0,
#  'aviation consultant': 0.333,
#  'travel agency': 0.5,
#  'travel service': 0.5,
#  'airport': 0.333,
#  'mental health service': 0.5,
#  'shipping company': 0.0,
#  'metal fabricator': 0.5,
#  'cruise line company': 0.0,
#  'towing service': 1.0,
#  'ferry terminal': 0.0,
#  'ferry service': 0.5,
#  'metal finisher': 0.333,
#  'boat tour agency': 1.0,
#  'bus company': 0.5,
#  'moving company': 1.0,
#  'moving storage service': 1.0,
#  'state department transportation': 0.2,
#  'department transportation': 0.2,
#  'handicapped transportation service': 1.0,
#  'railway service': 1.0,
#  'train station': 0.0,
#  'bus depot': 1.0,
#  'bus charter': 0.0,
#  'metal processing company': 0.5,
#  'mixed use': 0.0,
#  'motorcycle shop': 0.667,
#  'limousine service': 1.0,
#  'chauffeur service': 0.0,
#  'school bus service': 0.0,
#  'airport shuttle service': 0.0,
#  'tourist information center': 0.25,
#  'carriage ride service': 1.0,
#  'cruise agency': 0.25,
#  'tourist attraction': 0.25,
#  'ski resort': 0.167,
#  'ski area': 0.167,
#  'fixed base operator': 0.0,
#  'aircraft maintenance company': 0.667,
#  'motorsports store': 0.0,
#  'boat rental service': 0.0,
#  'utility trailer dealer': 0.0,
#  'forklift dealer': 0.167,
#  'municipal administration office': 0.0,
#  'nephrologist': 0.0,
#  'bus coach company': 0.0,
#  'shipping service': 0.0,
#  'shipping mailing service': 0.0,
#  'newspaper publisher': 0.667,
#  'shredding service': 0.333,
#  'nuclear power company': 0.4,
#  'nursing home': 1.0,
#  'medium company': 0.125,
#  'multimedia electronic book publisher': 0.25,
#  'internet marketing service': 0.0,
#  'greeting card shop': 0.5,
#  'theme park': 0.5,
#  'film production company': 0.333,
#  'obstetrician gynecologist': 0.5,
#  'movie studio': 0.5,
#  'video production service': 0.5,
#  'movie theater': 0.5,
#  'theater company': 0.25,
#  'performing art theater': 0.25,
#  'occupational safety health': 0.0,
#  'office space rental agency': 0.0,
#  'commercial real estate agency': 0.0,
#  'art school': 0.0,
#  'music publisher': 0.5,
#  'printed music publisher': 0.0,
#  'home audio store': 0.0,
#  'musician': 0.25,
#  'music management promotion': 0.0,
#  'video editing service': 0.5,
#  'office supply wholesaler': 0.667,
#  'official residence': 0.0,
#  'orthopedic clinic': 0.5,
#  'painter': 0.0,
#  'painting': 0.5,
#  'telephone company': 1.0,
#  'medium house': 0.125,
#  'paper distributor': 0.333,
#  'news service': 0.5,
#  'public library': 0.0,
#  'law library': 0.25,
#  'museum': 1.0,
#  'federal reserve bank': 0.0,
#  'credit union': 0.25,
#  'atm': 0.333,
#  'paving contractor': 0.5,
#  'mortgage lender': 0.333,
#  'investment bank': 0.25,
#  'check cashing service': 1.0,
#  'stock broker': 0.0,
#  'health consultant': 0.0,
#  'health insurance agency': 0.0,
#  'payroll service': 0.5,
#  'pediatrician': 1.0,
#  'human resource consulting': 0.429,
#  'pest control service': 1.0,
#  'pet boarding service': 0.4,
#  'pet care': 0.4,
#  'loss adjuster': 0.5,
#  'pharmaceutical company': 1.0,
#  'pharmaceutical product wholesaler': 1.0,
#  'pharmacy': 0.2,
#  'educational institution': 1.0,
#  'retirement community': 1.0,
#  'fraternal organization': 1.0,
#  'photo lab': 0.0,
#  'property investment': 0.25,
#  'photographer': 0.167,
#  'photography school': 0.333,
#  'star hotel': 0.0,
#  'convention center': 0.5,
#  'real estate appraiser': 0.75,
#  'photography service': 0.333,
#  'resort hotel': 0.25,
#  'real estate consultant': 1.0,
#  'car rental agency': 0.667,
#  'car leasing service': 0.667,
#  'ford dealer': 0.0,
#  'car finance loan company': 0.0,
#  'trailer rental service': 0.333,
#  'furniture rental service': 0.0,
#  'tuxedo shop': 0.167,
#  'dress tuxedo rental service': 0.167,
#  'wedding store': 0.0,
#  'video store': 0.0,
#  'movie rental': 0.5,
#  'photography studio': 0.333,
#  'home health care service': 0.0,
#  'skateboard shop': 0.091,
#  'event technology service': 0.0,
#  'party equipment rental service': 0.333,
#  'construction machine rental service': 0.0,
#  'audio visual equipment rental service': 1.0,
#  'shipping equipment industry': 0.0,
#  'physical therapy clinic': 0.333,
#  'plastic fabrication company': 0.364,
#  'plastic product supplier': 0.364,
#  'auto tag agency': 0.0,
#  'department motor vehicle': 0.2,
#  'notary public': 1.0,
#  'private investigator': 0.0,
#  'escrow service': 0.4,
#  'real estate agent': 1.0,
#  'playground': 0.0,
#  'plumber': 0.333,
#  'port authority': 1.0,
#  'portrait studio': 0.333,
#  'post office': 1.0,
#  'professional service': 0.333,
#  'university hospital': 0.0,
#  'public relation firm': 0.0,
#  'civil engineering company': 1.0,
#  'drafting service': 0.875,
#  'pump supplier': 0.643,
#  'interior construction contractor': 0.0,
#  'carpet cleaning service': 0.6,
#  'exhibition planner': 0.0,
#  'decal supplier': 0.0,
#  'stage lighting equipment supplier': 0.0,
#  'event management company': 0.0,
#  'radio broadcaster': 0.0,
#  'computer support service': 0.0,
#  'ravine': 0.0,
#  'employment center': 1.0,
#  'national health foundation': 0.0,
#  'real estate developer': 0.0,
#  'advertising agency': 0.125,
#  'promotional product supplier': 0.0,
#  'advertising service': 0.125,
#  'record storage facility': 0.0,
#  'fund management company': 0.0,
#  'recreation center': 0.667,
#  'bakery': 0.667,
#  'database management company': 0.0,
#  'market researcher': 0.0,
#  'recycling center': 0.0,
#  'regional government office': 0.0,
#  'rehabilitation center': 0.5,
#  'religious institution': 1.0,
#  'religious organization': 1.0,
#  'repair service': 0.2,
#  'emergency veterinarian service': 0.0,
#  'pet sitter': 0.4,
#  'research product development': 0.75,
#  'building society': 1.0,
#  'valet parking service': 0.4,
#  'nursing agency': 1.0,
#  'executive search firm': 0.5,
#  'recruiter': 0.0,
#  'temp agency': 0.0,
#  'health center': 0.0,
#  'restaurant': 0.75,
#  'roofing contractor': 0.25,
#  'sport nutrition store': 0.0,
#  'credit reporting agency': 0.0,
#  'automobile storage facility': 0.0,
#  'debt collection agency': 0.3,
#  'park': 0.0,
#  'court reporter': 0.3,
#  'bus tour agency': 0.25,
#  'tour operator': 0.75,
#  'convention information bureau': 0.5,
#  'balloon ride tour agency': 1.0,
#  'security guard service': 0.0,
#  'locksmith': 0.4,
#  'commercial cleaning service': 0.0,
#  'blast cleaning service': 0.0,
#  'conference center': 0.333,
#  'safety equipment supplier': 0.0,
#  'garbage dump': 0.25,
#  'sanitation service': 0.2,
#  'garbage dump service': 0.333,
#  'environmental health service': 0.286,
#  'portable toilet supplier': 0.0,
#  'public work department': 0.333,
#  'school district office': 1.0,
#  'sailmaker': 0.0,
#  'community college': 0.0,
#  'salvage yard': 0.0,
#  'business school': 0.0,
#  'trade school': 0.0,
#  'private university': 0.0,
#  'computer training school': 0.0,
#  'school supply store': 0.0,
#  'screen printer': 1.0,
#  'medium consultant': 0.125,
#  'beauty school': 0.0,
#  'flight school': 1.0,
#  'seaport': 0.0,
#  'security system supplier': 0.0,
#  'middle school': 1.0,
#  'nonprofit': 0.0,
#  'shooting range': 0.167,
#  'soccer club': 0.333,
#  'camp': 1.0,
#  'diving contractor': 0.333,
#  'language school': 0.833,
#  'english language school': 0.0,
#  'preschool': 1.0,
#  'self storage facility': 1.0,
#  'semi conductor supplier': 0.0,
#  'driving school': 0.5,
#  'trucking school': 0.0,
#  'senior citizen center': 0.333,
#  'service': 0.0,
#  'childrens hospital': 0.0,
#  'dental supply store': 0.6,
#  'shipyard': 1.0,
#  'orthodox synagogue': 0.0,
#  'short term apartment rental agency': 0.0,
#  'nutritionist': 0.167,
#  'ophthalmologist': 0.0,
#  'ophthalmology clinic': 0.0,
#  'social service organization': 1.0,
#  'social welfare center': 1.0,
#  'solar energy company': 0.7,
#  'solar energy equipment supplier': 0.7,
#  'special education school': 0.0,
#  'podiatrist': 0.333,
#  'reproductive health clinic': 0.167,
#  'sporting good store': 0.25,
#  'dialysis center': 0.667,
#  'sport complex': 0.333,
#  'wellness program': 0.0,
#  'sportswear store': 0.0,
#  'private hospital': 0.0,
#  'radiologist': 0.0,
#  'medical diagnostic imaging center': 1.0,
#  'ray lab': 1.0,
#  'blood bank': 0.667,
#  'stainless steel plant': 1.0,
#  'state agency': 0.167,
#  'heliport': 0.0,
#  'health care company': 0.0,
#  'psychiatric hospital': 1.0,
#  'state government office': 0.167,
#  'medical institution': 0.0,
#  'steel construction company': 0.125,
#  'cleaning service': 0.6,
#  ...}

# %%
avg_pre, mean_avg_pre = calc_avg_pre(create_testing_dicts(normalization='lemmatize')[0], create_testing_dicts(normalization='lemmatize')[1])

# %%
avg_pre
# Out:
# {'home improvement store': 0.0,
#  'diesel fuel supplier': 0.05,
#  'church': 0.125,
#  'farm': 0.097,
#  'seed supplier': 0.021,
#  'accountant': 1.0,
#  'trucking company': 0.478,
#  'exporter': 0.143,
#  'grain elevator': 0.0,
#  'popcorn store': 0.069,
#  'agricultural service': 0.028,
#  'warehouse': 0.0,
#  'agricultural production': 0.048,
#  'ranch': 0.0,
#  'holding company': 0.867,
#  'farm equipment supplier': 0.017,
#  'store': 0.0,
#  'grocery store': 0.0,
#  'rice mill': 0.429,
#  'food product supplier': 0.0,
#  'accounting firm': 0.333,
#  'produce market': 0.0,
#  'pet supply store': 0.1,
#  'wholesaler': 0.0,
#  'produce wholesaler': 0.0,
#  'distribution service': 0.0,
#  'crop grower': 0.071,
#  'addiction treatment center': 0.5,
#  'natural good store': 0.0,
#  'orchard': 0.037,
#  'lumber store': 0.036,
#  'mine': 0.12,
#  'transportation service': 0.056,
#  'investment company': 0.083,
#  'fruit wholesaler': 0.037,
#  'real estate agency': 0.5,
#  'event venue': 0.0,
#  'frozen dessert supplier': 0.192,
#  'wine wholesaler importer': 0.367,
#  'winery': 0.948,
#  'aerospace company': 0.915,
#  'cold storage facility': 0.031,
#  'employment agency': 0.733,
#  'plant nursery': 0.0,
#  'air conditioning contractor': 0.167,
#  'air conditioning repair service': 0.167,
#  'fruit vegetable wholesaler': 0.0,
#  'aircraft rental service': 0.0,
#  'monastery': 1.0,
#  'allergist': 0.5,
#  'herb shop': 0.0,
#  'aluminum supplier': 0.565,
#  'ambulance service': 0.917,
#  'wholesale plant nursery': 0.042,
#  'amusement machine supplier': 0.125,
#  'animal hospital': 0.0,
#  'farmer market': 0.0,
#  'vaporizer store': 0.0,
#  'cigar shop': 0.167,
#  'tobacco shop': 0.0,
#  'well drilling contractor': 0.332,
#  'library': 0.408,
#  'apartment building': 0.083,
#  'apartment rental agency': 0.083,
#  'dairy farm': 0.0,
#  'architect': 0.25,
#  'organic farm': 0.0,
#  'architectural designer': 0.103,
#  'architecture firm': 0.0,
#  'livestock producer': 0.0,
#  'dairy supplier': 0.065,
#  'biotechnology company': 0.75,
#  'artist': 1.0,
#  'egg supplier': 0.463,
#  'poultry farm': 0.242,
#  'chicken hatchery': 0.7,
#  'art organization': 0.196,
#  'association organization': 0.255,
#  'food store': 0.0,
#  'deli': 0.0,
#  'bank': 0.166,
#  'fish processing': 0.143,
#  'fish farm': 0.083,
#  'seafood wholesaler': 0.139,
#  'tropical fish store': 0.0,
#  'non profit organization': 0.0,
#  'economic development agency': 0.1,
#  'seafood market': 0.019,
#  'honey farm': 0.567,
#  'horse breeder': 0.062,
#  'asphalt contractor': 0.0,
#  'livestock dealer': 0.333,
#  'department store': 0.2,
#  'mill': 0.0,
#  'atv dealer': 0.667,
#  'audio visual consultant': 0.25,
#  'pallet supplier': 0.41,
#  'wood supplier': 0.0,
#  'hardware store': 0.0,
#  'furniture wholesaler': 0.0,
#  'auditor': 0.25,
#  'oil natural gas company': 0.1,
#  'auto body shop': 0.0,
#  'boat repair shop': 1.0,
#  'association': 0.255,
#  'railing contractor': 0.167,
#  'publisher': 0.837,
#  'pond supply store': 0.0,
#  'agriculture cooperative': 0.0,
#  'printing equipment supplier': 0.029,
#  'auto insurance agency': 0.0,
#  'alternative fuel station': 0.183,
#  'auto part manufacturer': 0.0,
#  'foundation': 0.067,
#  'fertilizer supplier': 0.679,
#  'farming company': 0.0,
#  'finance broker': 0.056,
#  'agricultural cooperative': 0.0,
#  'fire station': 0.0,
#  'environmental consultant': 0.064,
#  'civil engineer': 1.0,
#  'fire protection service': 0.0,
#  'gas company': 0.0,
#  'oilfield': 0.0,
#  'banquet hall': 0.333,
#  'mining company': 0.117,
#  'coalfield': 0.0,
#  'steel fabricator': 0.019,
#  'quarry': 0.36,
#  'gold mining company': 0.217,
#  'high rise building': 0.0,
#  'basketball club': 0.167,
#  'gold dealer': 0.0,
#  'battery manufacturer': 0.548,
#  'electric utility company': 0.0,
#  'environmental program': 0.048,
#  'office': 0.0,
#  'stone supplier': 0.042,
#  'aggregate supplier': 0.0,
#  'sand gravel supplier': 0.2,
#  'building material supplier': 0.0,
#  'beauty supply store': 0.183,
#  'crushed stone supplier': 0.05,
#  'rock shop': 0.0,
#  'road construction company': 1.0,
#  'marketing consultant': 0.0,
#  'blood testing service': 0.0,
#  'contractor': 0.417,
#  'excavating contractor': 0.25,
#  'asphalt mixing plant': 0.967,
#  'ready mix concrete supplier': 0.0,
#  'sand plant': 0.2,
#  'bmw dealer': 0.0,
#  'bookbinder': 0.0,
#  'garden center': 0.05,
#  'abrasive supplier': 0.5,
#  'granite supplier': 0.05,
#  'drilling contractor': 0.6,
#  'bpo company': 0.0,
#  'oil gas exploration service': 0.1,
#  'building complex': 0.0,
#  'construction equipment supplier': 0.0,
#  'mining equipment': 0.0,
#  'bus ticket agency': 0.028,
#  'business center': 0.0,
#  'skyscraper': 0.0,
#  'software company': 0.2,
#  'business development service': 0.0,
#  'business management consultant': 0.0,
#  'cabinet maker': 0.702,
#  'call center': 0.2,
#  'cancer treatment center': 0.5,
#  'power plant consultant': 0.333,
#  'business park': 0.0,
#  'petroleum product company': 0.156,
#  'parking lot': 0.24,
#  'water utility company': 0.133,
#  'car repair maintenance': 0.114,
#  'water treatment plant': 0.133,
#  'car service': 0.114,
#  'cattle market': 0.056,
#  'sewage disposal service': 0.532,
#  'certified public accountant': 0.25,
#  'government office': 0.167,
#  'charity': 0.333,
#  'air conditioning system supplier': 0.062,
#  'chemical industry': 0.067,
#  'chemical manufacturer': 0.067,
#  'title company': 0.0,
#  'chemical plant': 0.067,
#  'property management company': 0.025,
#  'custom home builder': 0.0,
#  'window installation service': 0.0,
#  'fire damage restoration service': 0.0,
#  'equipment rental agency': 0.062,
#  'chemical wholesaler': 0.1,
#  'financial planner': 0.1,
#  'telecommunication service provider': 0.833,
#  'energy equipment solution': 0.0,
#  'chiropractor': 0.5,
#  'steel distributor': 0.0,
#  'city government office': 0.5,
#  'crane service': 0.11,
#  'garage door supplier': 0.083,
#  'industrial door supplier': 0.0,
#  'city town hall': 0.5,
#  'clothing wholesaler': 0.312,
#  'coin operated laundry equipment supplier': 0.433,
#  'metal supplier': 0.056,
#  'glass shop': 0.0,
#  'college': 1.0,
#  'siding contractor': 0.049,
#  'commercial printer': 0.083,
#  'storage facility': 0.455,
#  'communication tower': 0.0,
#  'janitorial service': 0.786,
#  'computer consultant': 0.0,
#  'fire protection system supplier': 0.0,
#  'elevator service': 0.104,
#  'industrial equipment supplier': 0.122,
#  'dry wall contractor': 0.0,
#  'insulation contractor': 0.222,
#  'concrete contractor': 0.128,
#  'scaffolding rental service': 0.083,
#  'construction company': 0.7,
#  'flooring store': 0.0,
#  'flooring contractor': 0.097,
#  'tile contractor': 0.287,
#  'tile manufacturer': 0.287,
#  'glass mirror shop': 0.0,
#  'construction material wholesaler': 0.0,
#  'gutter cleaning service': 0.1,
#  'sheet metal contractor': 0.125,
#  'consultant': 0.048,
#  'container service': 0.118,
#  'septic system service': 0.442,
#  'corporate campus': 0.111,
#  'water damage restoration service': 0.0,
#  'welder': 0.0,
#  'corporate office': 0.111,
#  'animal': 0.321,
#  'animal feed store': 0.0,
#  'animal protection organization': 0.0,
#  'brewing supply store': 0.0,
#  'cosmetic store': 0.202,
#  'county government office': 0.239,
#  'sugar factory': 0.731,
#  'confectionery wholesaler': 0.148,
#  'financial institution': 0.0,
#  'candy store': 0.0,
#  'confectionery': 0.0,
#  'chocolate factory': 0.877,
#  'chocolate shop': 0.877,
#  'courier service': 0.5,
#  'coworking space': 0.0,
#  'frozen food manufacturer': 0.333,
#  'beverage distributor': 0.0,
#  'agricultural organization': 0.0,
#  'dairy store': 0.065,
#  'dairy': 0.0,
#  'ice cream shop': 0.067,
#  'medical laboratory': 0.417,
#  'demolition contractor': 0.833,
#  'meat processor': 0.771,
#  'fmcg manufacturer': 0.0,
#  'garbage collection service': 0.111,
#  'wholesale bakery': 0.0,
#  'dentist': 0.143,
#  'dessert shop': 0.033,
#  'cupcake shop': 0.0,
#  'nut store': 0.0,
#  'wholesale grocer': 0.056,
#  'design engineer': 0.0,
#  'business business service': 0.0,
#  'condiment supplier': 1.0,
#  'digital printing service': 0.812,
#  'culinary school': 0.25,
#  'importer': 0.0,
#  'bottled water supplier': 0.033,
#  'coffee roaster': 0.486,
#  'packaging supply store': 0.083,
#  'ice supplier': 0.194,
#  'brewery': 1.0,
#  'winemaking company': 0.0,
#  'distillery': 0.0,
#  'disability service support organisation': 0.556,
#  'district government office': 0.0,
#  'air filter supplier': 0.556,
#  'tire shop': 0.05,
#  'fastener supplier': 0.413,
#  'fabric product manufacturer': 0.083,
#  'textile': 0.361,
#  'textile exporter': 0.361,
#  'textile engineer': 0.361,
#  'fabric store': 0.0,
#  'knit shop': 0.042,
#  'doctor': 0.833,
#  'lamination service': 0.091,
#  'plastic resin manufacturer': 0.048,
#  'carpet manufacturer': 0.062,
#  'upholstery shop': 0.022,
#  'business administration service': 0.0,
#  'furniture store': 0.0,
#  'dry cleaner': 0.0,
#  'packaging company': 0.083,
#  'duty free store': 0.0,
#  'commerce service': 0.0,
#  'cable company': 0.125,
#  'education': 0.1,
#  'outlet store': 0.0,
#  'lingerie store': 0.083,
#  'clothes fabric manufacturer': 0.0,
#  'education center': 0.1,
#  'uniform store': 0.028,
#  'men clothing store': 0.021,
#  'clothing store': 0.089,
#  'woman clothing store': 0.017,
#  'western apparel store': 0.083,
#  'costume store': 0.171,
#  'game store': 0.0,
#  'hat shop': 0.042,
#  'leather good manufacturer': 0.0,
#  'educational consultant': 0.167,
#  'leather exporter': 0.667,
#  'shoe store': 0.167,
#  'boutique': 0.0,
#  'leather wholesaler': 0.0,
#  'handbag shop': 0.833,
#  'electronics store': 0.125,
#  'luggage store': 0.292,
#  'building material store': 0.0,
#  'saw mill': 0.0,
#  'electrical engineer': 0.0,
#  'deck builder': 0.042,
#  'concrete product supplier': 0.352,
#  'plywood supplier': 0.332,
#  'electrical installation service': 0.067,
#  'truss manufacturer': 0.117,
#  'door supplier': 0.036,
#  'wood laminate flooring supplier': 0.651,
#  'aircraft supply store': 0.0,
#  'modular home builder': 0.0,
#  'portable building manufacturer': 0.0,
#  'modular home dealer': 0.0,
#  'mulch supplier': 0.167,
#  'electrician': 0.167,
#  'paper mill': 0.271,
#  'energy supplier': 0.181,
#  'engineer': 0.125,
#  'print shop': 0.6,
#  'custom label printer': 0.0,
#  'marketing': 0.0,
#  'marketing agency': 0.0,
#  'engineering consultant': 0.031,
#  'entertainer': 0.0,
#  'envelope supplier': 0.071,
#  'oil refinery': 0.0,
#  'recording studio': 0.118,
#  'environment renewable natural resource': 0.0,
#  'finishing material supplier': 0.0,
#  'event ticket seller': 0.0,
#  'waterproofing company': 0.167,
#  'auto part store': 0.05,
#  'heating oil supplier': 0.0,
#  'family practice physician': 0.0,
#  'machining manufacturer': 0.067,
#  'industrial gas supplier': 0.024,
#  'welding supply store': 0.05,
#  'dry ice supplier': 0.0,
#  'private equity firm': 0.0,
#  'family service center': 0.333,
#  'federal government office': 0.024,
#  'vitamin supplement store': 0.1,
#  'feed manufacturer': 0.75,
#  'medical equipment supplier': 0.024,
#  'medical supply store': 0.024,
#  'medical clinic': 0.056,
#  'research institute': 0.75,
#  'biochemical supplier': 0.0,
#  'fiber optic product supplier': 0.0,
#  'paint manufacturer': 0.375,
#  'equipment supplier': 0.12,
#  'food': 0.312,
#  'pipe supplier': 0.284,
#  'oil field equipment supplier': 0.0,
#  'food broker': 0.0,
#  'food manufacturer': 0.25,
#  'food processing company': 0.312,
#  'fence supply store': 0.0,
#  'food producer': 0.312,
#  'forestry service': 0.2,
#  'foundry': 1.0,
#  'wholesale jeweler': 0.0,
#  'cookie shop': 0.333,
#  'truck rental agency': 0.0,
#  'fruit vegetable processing': 0.174,
#  'kitchen supply store': 0.0,
#  'hydraulic equipment supplier': 0.0,
#  'irrigation equipment supplier': 0.167,
#  'bearing supplier': 0.451,
#  'metallurgy company': 1.0,
#  'plastic injection molding service': 0.0,
#  'general contractor': 0.667,
#  'general hospital': 0.0,
#  'tool manufacturer': 0.683,
#  'industrial design company': 0.0,
#  'hyundai dealer': 0.0,
#  'glass industry': 0.575,
#  'polymer supplier': 0.0,
#  'printing equipment supply': 0.029,
#  'toner cartridge supplier': 0.1,
#  'printer repair service': 0.042,
#  'fuel supplier': 0.0,
#  'glass manufacturer': 0.575,
#  'plastic bag supplier': 0.218,
#  'glassware manufacturer': 0.375,
#  'polythene plastic sheeting supplier': 0.0,
#  'pvc industry': 0.045,
#  'countertop store': 0.062,
#  'cabinet store': 0.028,
#  'fiberglass supplier': 0.05,
#  'golf cart dealer': 0.0,
#  'auto repair shop': 0.0,
#  'hose supplier': 0.4,
#  'rubber product supplier': 0.333,
#  'automotive': 0.0,
#  'commercial refrigerator supplier': 0.0,
#  'golf club': 0.167,
#  'golf course': 0.167,
#  'green energy supplier': 0.0,
#  'greenhouse': 0.333,
#  'auto glass shop': 0.0,
#  'lighting manufacturer': 1.0,
#  'cement manufacturer': 0.1,
#  'brick manufacturer': 0.124,
#  'natural stone supplier': 0.0,
#  'gym': 0.167,
#  'marble supplier': 0.05,
#  'corporate gift supplier': 0.0,
#  'shipbuilding repair company': 0.0,
#  'construction maintenance office': 0.7,
#  'boiler manufacturer': 0.302,
#  'container supplier': 0.118,
#  'home construction': 0.028,
#  'health': 0.25,
#  'heart hospital': 0.0,
#  'spring supplier': 0.583,
#  'electric utility manufacturer': 0.0,
#  'aircraft manufacturer': 0.458,
#  'metal heat treating service': 0.033,
#  'plating service': 1.0,
#  'automation company': 0.0,
#  'heating contractor': 0.592,
#  'plumbing supply store': 0.062,
#  'gun shop': 0.125,
#  'ammunition supplier': 0.501,
#  'pipe manufacturer': 0.284,
#  'school': 0.5,
#  'fire protection equipment supplier': 0.0,
#  'agricultural machinery manufacturer': 0.029,
#  'lawn mower store': 0.0,
#  'lawn irrigation equipment supplier': 0.0,
#  'financial consultant': 0.1,
#  'helicopter charter': 0.122,
#  'packaging machinery': 0.0,
#  'historical landmark': 0.306,
#  'electronics manufacturer': 0.0,
#  'graphic designer': 0.196,
#  'eye care center': 0.167,
#  'optical product manufacturer': 0.867,
#  'image consultant': 0.0,
#  'cleaning product supplier': 0.0,
#  'fireplace store': 0.042,
#  'home builder': 0.028,
#  'tool die shop': 0.683,
#  'metal stamping service': 0.0,
#  'environmental organization': 0.048,
#  'food processing equipment': 0.022,
#  'loan agency': 0.178,
#  'power plant equipment supplier': 0.0,
#  'home good store': 0.033,
#  'engine rebuilding service': 0.0,
#  'air compressor supplier': 0.0,
#  'honda dealer': 0.0,
#  'elevator manufacturer': 0.104,
#  'crane dealer': 0.11,
#  'crane rental agency': 0.125,
#  'compound building': 0.0,
#  'tractor dealer': 0.0,
#  'furnace part supplier': 0.0,
#  'heating equipment supplier': 0.146,
#  'pneumatic tool supplier': 0.0,
#  'truck stop': 0.0,
#  'computer hardware manufacturer': 0.15,
#  'satellite communication service': 0.167,
#  'hospital': 0.0,
#  'electronics company': 0.125,
#  'electronic part supplier': 0.362,
#  'hvac contractor': 0.333,
#  'industrial engineer': 0.0,
#  'contact lens supplier': 0.0,
#  'information service': 0.25,
#  'building': 0.7,
#  'water work equipment supplier': 0.0,
#  'measuring instrument supplier': 0.889,
#  'scientific equipment supplier': 0.0,
#  'medical center': 0.0,
#  'watch manufacturer': 0.13,
#  'corporate entertainment service': 0.0,
#  'insurance': 0.25,
#  'record company': 0.05,
#  'video duplication service': 0.319,
#  'insurance agency': 0.25,
#  'lighting store': 1.0,
#  'lighting wholesaler': 1.0,
#  'entertainment agency': 0.111,
#  'insurance broker': 0.25,
#  'electrical equipment supplier': 0.104,
#  'electric motor store': 0.0,
#  'railroad company': 0.833,
#  'electrical supply store': 0.104,
#  'insurance company': 0.25,
#  'factory equipment supplier': 0.0,
#  'investment service': 0.596,
#  'laser equipment supplier': 0.059,
#  'executive suite rental agency': 0.58,
#  'truck dealer': 0.0,
#  'motor vehicle dealer': 0.0,
#  'car dealer': 0.0,
#  'truck topper supplier': 0.042,
#  'police supply store': 0.02,
#  'iron steel contractor': 0.0,
#  'fire department equipment supplier': 0.0,
#  'towing equipment provider': 1.0,
#  'logistics service': 0.343,
#  'trailer manufacturer': 0.75,
#  'trailer dealer': 0.048,
#  'dealer': 0.7,
#  'auto spring shop': 0.0,
#  'auto upholsterer': 0.0,
#  'auto body part supplier': 0.05,
#  'car factory': 0.0,
#  'freight forwarding service': 0.0,
#  'brake shop': 0.019,
#  'railroad equipment supplier': 0.033,
#  'jewelry equipment supplier': 0.499,
#  'boat builder': 1.0,
#  'ship building': 1.0,
#  'marine supply store': 0.0,
#  'boat dealer': 0.278,
#  'kawasaki motorcycle dealer': 0.0,
#  'knife manufacturing': 0.417,
#  'labor union': 0.282,
#  'furniture maker': 0.958,
#  'banking finance': 0.133,
#  'furniture manufacturer': 0.958,
#  'logistics': 0.343,
#  'massage supply store': 0.033,
#  'telecommunication equipment supplier': 0.0,
#  'baby store': 0.0,
#  'molding supplier': 0.0,
#  'office equipment supplier': 0.0,
#  'office furniture store': 0.0,
#  'store equipment supplier': 0.0,
#  'laboratory': 0.021,
#  'health beauty shop': 0.0,
#  'learning center': 0.345,
#  'dental laboratory': 0.36,
#  'land surveyor': 0.021,
#  'educational supply store': 0.0,
#  'jewelry store': 0.0,
#  'playground equipment supplier': 0.1,
#  'outdoor sport store': 0.031,
#  'toy store': 0.0,
#  'security service': 0.0,
#  'sign shop': 0.545,
#  'office supply store': 0.0,
#  'landscaper': 0.0,
#  'gasket manufacturer': 0.391,
#  'piano maker': 0.03,
#  'piano store': 0.125,
#  'funeral home': 1.0,
#  'monument': 0.0,
#  'book publisher': 0.378,
#  'wig shop': 0.083,
#  'laundromat': 0.25,
#  'auto wrecker': 0.0,
#  'auto part market': 0.05,
#  'jeep dealer': 0.0,
#  'restaurant supply store': 0.033,
#  'roofing supply store': 0.646,
#  'law firm': 0.25,
#  'building material market': 0.0,
#  'camera store': 0.107,
#  'lawn care service': 0.04,
#  'computer security service': 0.0,
#  'computer store': 0.0,
#  'design agency': 0.118,
#  'diagnostic center': 1.0,
#  'laboratory equipment supplier': 0.288,
#  'home theater store': 0.0,
#  'metal industry supplier': 0.056,
#  'landscaping supply store': 0.0,
#  'appliance part supplier': 0.294,
#  'vacuum cleaner store': 0.05,
#  'audio visual equipment supplier': 0.25,
#  'lawyer': 0.887,
#  'cell phone store': 0.0,
#  'bathroom supply store': 0.0,
#  'leasing service': 0.643,
#  'construction machine dealer': 0.0,
#  'dairy farm equipment supplier': 0.0,
#  'propane supplier': 0.0,
#  'legal service': 0.5,
#  'janitorial equipment supplier': 0.786,
#  'life insurance agency': 0.0,
#  'railroad contractor': 0.167,
#  'swimming pool supply store': 0.04,
#  'light bulb supplier': 0.413,
#  'linen store': 0.417,
#  'metal construction company': 0.151,
#  'local government office': 0.0,
#  'logging contractor': 0.25,
#  'machine shop': 0.0,
#  'hotel supply store': 0.333,
#  'import export company': 0.0,
#  'sewing company': 0.0,
#  'research foundation': 0.75,
#  'machinery part manufacturer': 0.342,
#  'sport accessory wholesaler': 0.0,
#  'fashion designer': 0.028,
#  'cheese manufacturer': 0.333,
#  'cheese shop': 0.333,
#  'shipping mailing': 0.0,
#  'wholesale food store': 0.056,
#  'organic food store': 0.0,
#  'pie shop': 0.317,
#  'auction house': 0.2,
#  'livestock auction house': 0.333,
#  'cotton exporter': 0.071,
#  'plastic wholesaler': 0.0,
#  'mailing service': 0.0,
#  'manufacturer': 0.0,
#  'gas station': 0.0,
#  'beer distributor': 0.5,
#  'alcoholic beverage wholesaler': 0.125,
#  'religious good store': 0.5,
#  'book wholesaler': 0.042,
#  'masonry supply store': 0.0,
#  'wholesale florist': 0.042,
#  'florist': 0.125,
#  'marine engineer': 0.0,
#  'paint store': 0.0,
#  'used auto part store': 0.0,
#  'masonry contractor': 0.087,
#  'used car dealer': 0.0,
#  'used truck dealer': 0.0,
#  'massage therapist': 0.042,
#  'material handling equipment supplier': 0.019,
#  'marina': 1.0,
#  'meat packer': 0.114,
#  'mattress store': 0.0,
#  'blind shop': 0.6,
#  'interior designer': 0.062,
#  'window treatment store': 0.0,
#  'appliance store': 0.0,
#  'health food store': 0.0,
#  'direct mail advertising': 0.0,
#  'meat wholesaler': 0.114,
#  'butcher shop deli': 0.167,
#  'italian grocery store': 0.0,
#  'market': 0.0,
#  'food service': 0.0,
#  'grocery delivery service': 0.0,
#  'wine store': 0.111,
#  'liquor store': 0.25,
#  'kiosk': 0.0,
#  'optometrist': 0.35,
#  'optician': 0.028,
#  'mechanical contractor': 0.111,
#  'mechanical engineer': 0.0,
#  'cafe': 0.113,
#  'jeweler': 0.2,
#  'leather good store': 0.0,
#  'gift shop': 0.393,
#  'craft store': 0.083,
#  'hobby store': 0.0,
#  'fabric wholesaler': 0.0,
#  'scrap metal dealer': 0.0,
#  'quilt shop': 0.0,
#  'sheet music store': 0.0,
#  'musical instrument manufacturer': 0.031,
#  'music store': 0.0,
#  'musical instrument store': 0.0,
#  'band': 0.05,
#  'bookstore': 0.0,
#  'art museum': 0.0,
#  'newsstand': 0.5,
#  'medical equipment manufacturer': 0.475,
#  'fashion accessory store': 0.057,
#  'discount store': 0.0,
#  'cemetery': 0.25,
#  'bus stop': 0.125,
#  'variety store': 0.0,
#  'thrift store': 1.0,
#  'medical group': 0.056,
#  'donation center': 0.0,
#  'pet store': 0.1,
#  'art gallery': 0.0,
#  'art dealer': 0.0,
#  'housing development': 0.056,
#  'mobile home dealer': 0.04,
#  'convenience store': 0.325,
#  'medical office': 0.056,
#  'medical technology manufacturer': 0.475,
#  'childrens furniture store': 0.0,
#  'mental health clinic': 0.187,
#  'airline': 0.0,
#  'aviation consultant': 0.033,
#  'travel agency': 0.306,
#  'travel service': 0.306,
#  'airport': 0.333,
#  'mental health service': 0.187,
#  'shipping company': 0.0,
#  'metal fabricator': 0.151,
#  'cruise line company': 0.0,
#  'towing service': 1.0,
#  'ferry terminal': 0.0,
#  'ferry service': 0.25,
#  'metal finisher': 0.033,
#  'boat tour agency': 0.2,
#  'bus company': 0.125,
#  'moving company': 0.556,
#  'moving storage service': 0.556,
#  'state department transportation': 0.025,
#  'department transportation': 0.02,
#  'handicapped transportation service': 1.0,
#  'railway service': 0.143,
#  'train station': 0.0,
#  'bus depot': 0.1,
#  'bus charter': 0.0,
#  'metal processing company': 0.151,
#  'mixed use': 0.0,
#  'motorcycle shop': 0.444,
#  'limousine service': 1.0,
#  'chauffeur service': 0.0,
#  'school bus service': 0.0,
#  'airport shuttle service': 0.0,
#  'tourist information center': 0.042,
#  'carriage ride service': 0.25,
#  'cruise agency': 0.125,
#  'tourist attraction': 0.042,
#  'ski resort': 0.021,
#  'ski area': 0.021,
#  'fixed base operator': 0.0,
#  'aircraft maintenance company': 0.15,
#  'motorsports store': 0.0,
#  'boat rental service': 0.0,
#  'utility trailer dealer': 0.0,
#  'forklift dealer': 0.042,
#  'municipal administration office': 0.0,
#  'nephrologist': 0.0,
#  'bus coach company': 0.0,
#  'shipping service': 0.0,
#  'shipping mailing service': 0.0,
#  'newspaper publisher': 0.554,
#  'shredding service': 0.111,
#  'nuclear power company': 0.118,
#  'nursing home': 1.0,
#  'medium company': 0.025,
#  'multimedia electronic book publisher': 0.25,
#  'internet marketing service': 0.0,
#  'greeting card shop': 0.1,
#  'theme park': 0.5,
#  'film production company': 0.122,
#  'obstetrician gynecologist': 0.5,
#  'movie studio': 0.125,
#  'video production service': 0.319,
#  'movie theater': 0.125,
#  'theater company': 0.25,
#  'performing art theater': 0.031,
#  'occupational safety health': 0.0,
#  'office space rental agency': 0.0,
#  'commercial real estate agency': 0.0,
#  'art school': 0.0,
#  'music publisher': 0.118,
#  'printed music publisher': 0.0,
#  'home audio store': 0.0,
#  'musician': 0.25,
#  'music management promotion': 0.0,
#  'video editing service': 0.319,
#  'office supply wholesaler': 0.167,
#  'official residence': 0.0,
#  'orthopedic clinic': 0.167,
#  'painter': 0.0,
#  'painting': 0.125,
#  'telephone company': 0.225,
#  'medium house': 0.025,
#  'paper distributor': 0.056,
#  'news service': 0.05,
#  'public library': 0.0,
#  'law library': 0.125,
#  'museum': 1.0,
#  'federal reserve bank': 0.0,
#  'credit union': 0.031,
#  'atm': 0.167,
#  'paving contractor': 0.5,
#  'mortgage lender': 0.037,
#  'investment bank': 0.083,
#  'check cashing service': 0.806,
#  'stock broker': 0.0,
#  'health consultant': 0.0,
#  'health insurance agency': 0.0,
#  'payroll service': 0.5,
#  'pediatrician': 1.0,
#  'human resource consulting': 0.3,
#  'pest control service': 0.686,
#  'pet boarding service': 0.167,
#  'pet care': 0.167,
#  'loss adjuster': 0.091,
#  'pharmaceutical company': 0.444,
#  'pharmaceutical product wholesaler': 0.167,
#  'pharmacy': 0.067,
#  'educational institution': 0.25,
#  'retirement community': 0.45,
#  'fraternal organization': 1.0,
#  'photo lab': 0.0,
#  'property investment': 0.025,
#  'photographer': 0.083,
#  'photography school': 0.333,
#  'star hotel': 0.0,
#  'convention center': 0.225,
#  'real estate appraiser': 0.249,
#  'photography service': 0.333,
#  'resort hotel': 0.083,
#  'real estate consultant': 0.5,
#  'car rental agency': 0.122,
#  'car leasing service': 0.122,
#  'ford dealer': 0.0,
#  'car finance loan company': 0.0,
#  'trailer rental service': 0.048,
#  'furniture rental service': 0.0,
#  'tuxedo shop': 0.056,
#  'dress tuxedo rental service': 0.021,
#  'wedding store': 0.0,
#  'video store': 0.0,
#  'movie rental': 0.125,
#  'photography studio': 0.333,
#  'home health care service': 0.0,
#  'skateboard shop': 0.091,
#  'event technology service': 0.0,
#  'party equipment rental service': 0.097,
#  'construction machine rental service': 0.0,
#  'audio visual equipment rental service': 0.25,
#  'shipping equipment industry': 0.0,
#  'physical therapy clinic': 0.079,
#  'plastic fabrication company': 0.218,
#  'plastic product supplier': 0.218,
#  'auto tag agency': 0.0,
#  'department motor vehicle': 0.02,
#  'notary public': 1.0,
#  'private investigator': 0.0,
#  'escrow service': 0.233,
#  'real estate agent': 0.5,
#  'playground': 0.0,
#  'plumber': 0.056,
#  'port authority': 0.607,
#  'portrait studio': 0.204,
#  'post office': 0.143,
#  'professional service': 0.222,
#  'university hospital': 0.0,
#  'public relation firm': 0.0,
#  'civil engineering company': 1.0,
#  'drafting service': 0.475,
#  'pump supplier': 0.609,
#  'interior construction contractor': 0.0,
#  'carpet cleaning service': 0.216,
#  'exhibition planner': 0.0,
#  'decal supplier': 0.0,
#  'stage lighting equipment supplier': 0.0,
#  'event management company': 0.0,
#  'radio broadcaster': 0.0,
#  'computer support service': 0.0,
#  'ravine': 0.0,
#  'employment center': 0.733,
#  'national health foundation': 0.0,
#  'real estate developer': 0.0,
#  'advertising agency': 0.025,
#  'promotional product supplier': 0.0,
#  'advertising service': 0.025,
#  'record storage facility': 0.0,
#  'fund management company': 0.0,
#  'recreation center': 0.47,
#  'bakery': 0.444,
#  'database management company': 0.0,
#  'market researcher': 0.0,
#  'recycling center': 0.0,
#  'regional government office': 0.0,
#  'rehabilitation center': 0.1,
#  'religious institution': 0.5,
#  'religious organization': 0.5,
#  'repair service': 0.067,
#  'emergency veterinarian service': 0.0,
#  'pet sitter': 0.167,
#  'research product development': 0.75,
#  'building society': 0.7,
#  'valet parking service': 0.4,
#  'nursing agency': 1.0,
#  'executive search firm': 0.5,
#  'recruiter': 0.0,
#  'temp agency': 0.0,
#  'health center': 0.0,
#  'restaurant': 0.396,
#  'roofing contractor': 0.056,
#  'sport nutrition store': 0.0,
#  'credit reporting agency': 0.0,
#  'automobile storage facility': 0.0,
#  'debt collection agency': 0.097,
#  'park': 0.0,
#  'court reporter': 0.192,
#  'bus tour agency': 0.028,
#  'tour operator': 0.271,
#  'convention information bureau': 0.225,
#  'balloon ride tour agency': 0.167,
#  'security guard service': 0.0,
#  'locksmith': 0.4,
#  'commercial cleaning service': 0.0,
#  'blast cleaning service': 0.0,
#  'conference center': 0.333,
#  'safety equipment supplier': 0.0,
#  'garbage dump': 0.031,
#  'sanitation service': 0.067,
#  'garbage dump service': 0.111,
#  'environmental health service': 0.064,
#  'portable toilet supplier': 0.0,
#  'public work department': 0.061,
#  'school district office': 0.5,
#  'sailmaker': 0.0,
#  'community college': 0.0,
#  'salvage yard': 0.0,
#  'business school': 0.0,
#  'trade school': 0.0,
#  'private university': 0.0,
#  'computer training school': 0.0,
#  'school supply store': 0.0,
#  'screen printer': 1.0,
#  'medium consultant': 0.025,
#  'beauty school': 0.0,
#  'flight school': 0.517,
#  'seaport': 0.0,
#  'security system supplier': 0.0,
#  'middle school': 1.0,
#  'nonprofit': 0.0,
#  'shooting range': 0.083,
#  'soccer club': 0.333,
#  'camp': 0.643,
#  'diving contractor': 0.333,
#  'language school': 0.449,
#  'english language school': 0.0,
#  'preschool': 1.0,
#  'self storage facility': 0.793,
#  'semi conductor supplier': 0.0,
#  'driving school': 0.167,
#  'trucking school': 0.0,
#  'senior citizen center': 0.111,
#  'service': 0.0,
#  'childrens hospital': 0.0,
#  'dental supply store': 0.36,
#  'shipyard': 1.0,
#  'orthodox synagogue': 0.0,
#  'short term apartment rental agency': 0.0,
#  'nutritionist': 0.167,
#  'ophthalmologist': 0.0,
#  'ophthalmology clinic': 0.0,
#  'social service organization': 0.633,
#  'social welfare center': 0.633,
#  'solar energy company': 0.371,
#  'solar energy equipment supplier': 0.371,
#  'special education school': 0.0,
#  'podiatrist': 0.333,
#  'reproductive health clinic': 0.083,
#  'sporting good store': 0.05,
#  'dialysis center': 0.667,
#  'sport complex': 0.214,
#  'wellness program': 0.0,
#  'sportswear store': 0.0,
#  'private hospital': 0.0,
#  'radiologist': 0.0,
#  'medical diagnostic imaging center': 0.417,
#  'ray lab': 0.5,
#  'blood bank': 0.3,
#  'stainless steel plant': 0.5,
#  'state agency': 0.019,
#  'heliport': 0.0,
#  'health care company': 0.0,
#  'psychiatric hospital': 1.0,
#  'state government office': 0.019,
#  'medical institution': 0.0,
#  'steel construction company': 0.025,
#  'cleaning service': 0.3,
#  ...}

# %%
mean_avg_pre
# Out:
# 0.19

# %%
## BoW mAP results are going to be used later on the Charts.ipynb file
word_count_maps = []
for i in range(1, 11):
    word_count_maps.append(calc_avg_pre(create_testing_dicts(normalization='lemmatize')[0], create_testing_dicts(normalization='lemmatize')[1], cutoff=i)[1])

# %%
word_count_maps
# Out:
# [0.069, 0.109, 0.128, 0.145, 0.157, 0.168, 0.175, 0.182, 0.187, 0.19]

# %% [markdown]
# #### NDCG
# NDCG is a good way of measuring the order of results returned from the Recommender system. While I did say that order doesn't entirely matter in this project, it's still good to see how close results are to the top. Since users are more likely to only read the first few, it's probably good if we have a decent NDCG score.

# %%
calc_NDCG_at_n(create_testing_dicts(normalization='lemmatize')[0], create_testing_dicts(normalization='lemmatize')[1], n=-1, base=2)
# Out:
# {'home improvement store': 0.37488311901084637,
#  'diesel fuel supplier': 0.7094988669199906,
#  'church': 0.8934099845459849,
#  'farm': 0.364653646682137,
#  'seed supplier': 0.3370042346712697,
#  'accountant': 1.0,
#  'trucking company': 0.77529654295015,
#  'exporter': 1.0,
#  'grain elevator': 0.37488311901084637,
#  'popcorn store': 0.4138609632427184,
#  'agricultural service': 0.28003728815184026,
#  'warehouse': 0.37488311901084637,
#  'agricultural production': 0.37439397160220267,
#  'ranch': 0.37488311901084637,
#  'holding company': 0.9816035470353093,
#  'farm equipment supplier': 0.3000319913674782,
#  'store': 0.6365616336988094,
#  'grocery store': 0.6365616336988094,
#  'rice mill': 0.8366662357680575,
#  'food product supplier': 0.14833755686686634,
#  'accounting firm': 0.6993192186414626,
#  'produce market': 0.24409514662261833,
#  'pet supply store': 0.35581457655797505,
#  'wholesaler': 0.6365616336988094,
#  'produce wholesaler': 0.14833755686686634,
#  'distribution service': 0.20341748548710972,
#  'crop grower': 0.47440880448460354,
#  'addiction treatment center': 0.8475982933896377,
#  'natural good store': 0.2989251547368574,
#  'orchard': 0.2017721420527986,
#  'lumber store': 0.4765378536522128,
#  'mine': 0.5374771877753436,
#  'transportation service': 0.7129963266617504,
#  'investment company': 0.5549384323170297,
#  'fruit wholesaler': 0.1661490852621771,
#  'real estate agency': 1.0,
#  'event venue': 0.48270920670499107,
#  'frozen dessert supplier': 0.5127795298668696,
#  'wine wholesaler importer': 0.8416058145148295,
#  'winery': 0.9501879401842349,
#  'aerospace company': 0.9676985902998954,
#  'cold storage facility': 0.4700100922261463,
#  'employment agency': 0.8700719519435725,
#  'plant nursery': 0.6365616336988094,
#  'air conditioning contractor': 0.7583071004454944,
#  'air conditioning repair service': 0.7583071004454944,
#  'fruit vegetable wholesaler': 0.24409514662261833,
#  'aircraft rental service': 0.37488311901084637,
#  'monastery': 1.0,
#  'allergist': 1.0,
#  'herb shop': 0.2989251547368574,
#  'aluminum supplier': 0.6744285184232585,
#  'ambulance service': 0.8819413462977922,
#  'wholesale plant nursery': 0.2673224186347812,
#  'amusement machine supplier': 0.7577077557992062,
#  'animal hospital': 0.24409514662261833,
#  'farmer market': 0.14285714285714285,
#  'vaporizer store': 0.16666666666666666,
#  'cigar shop': 0.6365220046885751,
#  'tobacco shop': 0.2989251547368574,
#  'well drilling contractor': 0.6820918078258305,
#  'library': 0.6494510429808847,
#  'apartment building': 0.5549384323170297,
#  'apartment rental agency': 0.5549384323170297,
#  'dairy farm': 0.37488311901084637,
#  'architect': 0.7425684929788066,
#  'organic farm': 0.20341748548710972,
#  'architectural designer': 0.33262559402287944,
#  'architecture firm': 0.1111111111111111,
#  'livestock producer': 0.37488311901084637,
#  'dairy supplier': 0.25084089902346995,
#  'biotechnology company': 0.9661179301650845,
#  'artist': 1.0,
#  'egg supplier': 0.680676344503465,
#  'poultry farm': 0.6806928482409674,
#  'chicken hatchery': 0.8278600394102978,
#  'art organization': 0.5248049965468942,
#  'association organization': 0.6679506845318891,
#  'food store': 0.6365616336988094,
#  'deli': 0.2,
#  'bank': 0.5537257621645948,
#  'fish processing': 0.8970671711869902,
#  'fish farm': 0.6205081535752428,
#  'seafood wholesaler': 0.26125997521525685,
#  'tropical fish store': 0.1945418823618167,
#  'non profit organization': 0.8401149768189771,
#  'economic development agency': 0.5833722638424459,
#  'seafood market': 0.2587499236293894,
#  'honey farm': 0.7171303014042586,
#  'horse breeder': 0.41055573396658385,
#  'asphalt contractor': 0.6365616336988094,
#  'livestock dealer': 0.5745751712851589,
#  'department store': 0.9089737082900646,
#  'mill': 0.6365616336988094,
#  'atv dealer': 1.0,
#  'audio visual consultant': 0.9200574884094885,
#  'pallet supplier': 0.5773393986434197,
#  'wood supplier': 0.37488311901084637,
#  'hardware store': 0.37488311901084637,
#  'furniture wholesaler': 0.6365616336988094,
#  'auditor': 0.6087448857095201,
#  'oil natural gas company': 0.5264828420213281,
#  'auto body shop': 0.14833755686686634,
#  'boat repair shop': 1.0,
#  'association': 0.6679506845318891,
#  'railing contractor': 0.5342691059148444,
#  'publisher': 0.8988615422085057,
#  'pond supply store': 0.2857142857142857,
#  'agriculture cooperative': 0.2989251547368574,
#  'printing equipment supplier': 0.3191895756599594,
#  'auto insurance agency': 0.37488311901084637,
#  'alternative fuel station': 0.7610852189451346,
#  'auto part manufacturer': 0.17245330615262136,
#  'foundation': 0.6014027589934278,
#  'fertilizer supplier': 0.794754943202175,
#  'farming company': 0.24409514662261833,
#  'finance broker': 0.5537864192792847,
#  'agricultural cooperative': 0.2989251547368574,
#  'fire station': 0.20341748548710972,
#  'environmental consultant': 0.31042072637202806,
#  'civil engineer': 1.0,
#  'fire protection service': 0.20341748548710972,
#  'gas company': 0.8401149768189771,
#  'oilfield': 0,
#  'banquet hall': 0.6997292924605046,
#  'mining company': 0.5368066219547875,
#  'coalfield': 0,
#  'steel fabricator': 0.2587499236293894,
#  'quarry': 0.3746479543538447,
#  'gold mining company': 0.471865956278566,
#  'high rise building': 0.6365616336988094,
#  'basketball club': 0.7253551569309719,
#  'gold dealer': 0.2989251547368574,
#  'battery manufacturer': 0.674840018238358,
#  'electric utility company': 0.2989251547368574,
#  'environmental program': 0.5154325235390578,
#  'office': 0.8401149768189771,
#  'stone supplier': 0.48528352890703774,
#  'aggregate supplier': 0.24152948254127113,
#  'sand gravel supplier': 0.36091118361649976,
#  'building material supplier': 0.37488311901084637,
#  'beauty supply store': 0.47330225720508345,
#  'crushed stone supplier': 0.4461859311348952,
#  'rock shop': 0.2989251547368574,
#  'road construction company': 1.0,
#  'marketing consultant': 0.20341748548710972,
#  'blood testing service': 0.17245330615262136,
#  'contractor': 0.8514391906394404,
#  'excavating contractor': 0.8690756680778096,
#  'asphalt mixing plant': 0.9490776279142411,
#  'ready mix concrete supplier': 0.2989251547368574,
#  'sand plant': 0.3628129372431496,
#  'bmw dealer': 0,
#  'bookbinder': 0.2,
#  'garden center': 0.7094988669199906,
#  'abrasive supplier': 0.7536930347815097,
#  'granite supplier': 0.4092261388667199,
#  'drilling contractor': 0.9186836170773045,
#  'bpo company': 0,
#  'oil gas exploration service': 0.5264828420213281,
#  'building complex': 0.37488311901084637,
#  'construction equipment supplier': 0.24409514662261833,
#  'mining equipment': 0.2989251547368574,
#  'bus ticket agency': 0.46491077566393807,
#  'business center': 0.12917591694169767,
#  'skyscraper': 0,
#  'software company': 0.9089737082900646,
#  'business development service': 0.20341748548710972,
#  'business management consultant': 0.20341748548710972,
#  'cabinet maker': 0.7457465739174283,
#  'call center': 0.721385502342571,
#  'cancer treatment center': 1.0,
#  'power plant consultant': 0.7583071004454944,
#  'business park': 0.2989251547368574,
#  'petroleum product company': 0.749464943272341,
#  'parking lot': 0.4414416885786623,
#  'water utility company': 0.6290571699126631,
#  'car repair maintenance': 0.24518763024406134,
#  'water treatment plant': 0.6290571699126631,
#  'car service': 0.384799614051925,
#  'cattle market': 0.5893250255664316,
#  'sewage disposal service': 0.7886670625756983,
#  'certified public accountant': 0.6087448857095201,
#  'government office': 0.592504226805061,
#  'charity': 1.0,
#  'air conditioning system supplier': 0.5175735788337962,
#  'chemical industry': 0.4783912991889597,
#  'chemical manufacturer': 0.4783912991889597,
#  'title company': 0.37488311901084637,
#  'chemical plant': 0.4783912991889597,
#  'property management company': 0.43931428176353743,
#  'custom home builder': 0.37488311901084637,
#  'window installation service': 0.17245330615262136,
#  'fire damage restoration service': 0.37488311901084637,
#  'equipment rental agency': 0.5175735788337962,
#  'chemical wholesaler': 0.7409112234790852,
#  'financial planner': 0.35581457655797505,
#  'telecommunication service provider': 0.9552885708625443,
#  'energy equipment solution': 0.6365616336988094,
#  'chiropractor': 0.5828977410970466,
#  'steel distributor': 0.6365616336988094,
#  'city government office': 0.666267173535879,
#  'crane service': 0.4330725642896344,
#  'garage door supplier': 0.5228224107685725,
#  'industrial door supplier': 0.24409514662261833,
#  'city town hall': 0.7963799224438143,
#  'clothing wholesaler': 0.588918808745271,
#  'coin operated laundry equipment supplier': 0.7343325951214598,
#  'metal supplier': 0.7129963266617504,
#  'glass shop': 0.17245330615262136,
#  'college': 1.0,
#  'siding contractor': 0.28437945327780373,
#  'commercial printer': 0.5549384323170297,
#  'storage facility': 0.6908373370502754,
#  'communication tower': 0.48270920670499107,
#  'janitorial service': 0.8469349217578641,
#  'computer consultant': 0.37488311901084637,
#  'fire protection system supplier': 0.20341748548710972,
#  'elevator service': 0.39139570448920796,
#  'industrial equipment supplier': 0.4799731200856681,
#  'dry wall contractor': 0.24409514662261833,
#  'insulation contractor': 0.5407934815331834,
#  'concrete contractor': 0.4136180521451026,
#  'scaffolding rental service': 0.4732166063698578,
#  'construction company': 0.9310286727897411,
#  'flooring store': 0.48270920670499107,
#  'flooring contractor': 0.43543731871198016,
#  'tile contractor': 0.5539538490810466,
#  'tile manufacturer': 0.5539538490810466,
#  'glass mirror shop': 0.17245330615262136,
#  'construction material wholesaler': 0.37488311901084637,
#  'gutter cleaning service': 0.5682291817959194,
#  'sheet metal contractor': 0.5847618028010066,
#  'consultant': 0.3340755437930592,
#  'container service': 0.5400804929970692,
#  'septic system service': 0.8567589597428414,
#  'corporate campus': 0.623762835118414,
#  'water damage restoration service': 0.37488311901084637,
#  'welder': 0.07429372775974477,
#  'corporate office': 0.623762835118414,
#  'animal': 0.736505089637771,
#  'animal feed store': 0.2989251547368574,
#  'animal protection organization': 0.48270920670499107,
#  'brewing supply store': 0.4,
#  'cosmetic store': 0.4779378701608672,
#  'county government office': 0.480788053530072,
#  'sugar factory': 0.9403056679283182,
#  'confectionery wholesaler': 0.27485795916398736,
#  'financial institution': 0.24409514662261833,
#  'candy store': 0.24409514662261833,
#  'confectionery': 0.24409514662261833,
#  'chocolate factory': 0.9544000403992323,
#  'chocolate shop': 0.9544000403992323,
#  'courier service': 1.0,
#  'coworking space': 0,
#  'frozen food manufacturer': 0.7269451794041278,
#  'beverage distributor': 0.6365616336988094,
#  'agricultural organization': 0.2989251547368574,
#  'dairy store': 0.25084089902346995,
#  'dairy': 0.37488311901084637,
#  'ice cream shop': 0.4783912991889597,
#  'medical laboratory': 0.85000408067489,
#  'demolition contractor': 0.9344566061769004,
#  'meat processor': 0.8861783435402169,
#  'fmcg manufacturer': 0,
#  'garbage collection service': 0.6565921178874996,
#  'wholesale bakery': 0.24409514662261833,
#  'dentist': 0.8970671711869902,
#  'dessert shop': 0.33478458957832113,
#  'cupcake shop': 0,
#  'nut store': 0.24409514662261833,
#  'wholesale grocer': 0.402412998150745,
#  'design engineer': 0.17245330615262136,
#  'business business service': 0.12917591694169767,
#  'condiment supplier': 0.8538081518334687,
#  'digital printing service': 0.9694267016064707,
#  'culinary school': 1.0,
#  'importer': 0,
#  'bottled water supplier': 0.33478458957832113,
#  'coffee roaster': 0.5793926173063703,
#  'packaging supply store': 0.6205081535752428,
#  'ice supplier': 0.5269647852802398,
#  'brewery': 0.9157289224789645,
#  'winemaking company': 0,
#  'distillery': 0.24409514662261833,
#  'disability service support organisation': 0.7484580824676673,
#  'district government office': 0.19527122273431988,
#  'air filter supplier': 0.690497112073498,
#  'tire shop': 0.7094988669199906,
#  'fastener supplier': 0.6841288292362028,
#  'fabric product manufacturer': 0.7302930685390434,
#  'textile': 0.9170712243810738,
#  'textile exporter': 0.9170712243810738,
#  'textile engineer': 0.9170712243810738,
#  'fabric store': 0.37488311901084637,
#  'knit shop': 0.47398630422618876,
#  'doctor': 0.9552885708625443,
#  'lamination service': 0.13616993153014392,
#  'plastic resin manufacturer': 0.5808791572071914,
#  'carpet manufacturer': 0.717325715099074,
#  'upholstery shop': 0.3886582269629085,
#  'business administration service': 0.20341748548710972,
#  'furniture store': 0.8401149768189771,
#  'dry cleaner': 0.37488311901084637,
#  'packaging company': 0.6205081535752428,
#  'duty free store': 0.2989251547368574,
#  'commerce service': 0.5,
#  'cable company': 0.8934099845459849,
#  'education': 0.888245164653896,
#  'outlet store': 0.6365616336988094,
#  'lingerie store': 0.5029527076138053,
#  'clothes fabric manufacturer': 0.6365616336988094,
#  'education center': 0.888245164653896,
#  'uniform store': 0.35192157121028417,
#  'men clothing store': 0.2595799946307269,
#  'clothing store': 0.40000622115088613,
#  'woman clothing store': 0.2580793578088333,
#  'western apparel store': 0.6153846153846154,
#  'costume store': 0.46992708897445207,
#  'game store': 0.37488311901084637,
#  'hat shop': 0.3834587786955953,
#  'leather good manufacturer': 0.6365616336988094,
#  'educational consultant': 0.9019669468713154,
#  'leather exporter': 0.9257195953197203,
#  'shoe store': 0.9019669468713154,
#  'boutique': 0,
#  'leather wholesaler': 0.6365616336988094,
#  'handbag shop': 0.9105771417250885,
#  'electronics store': 0.7577077557992062,
#  'luggage store': 0.8045734732193234,
#  'building material store': 0.37488311901084637,
#  'saw mill': 0.6228058861739143,
#  'electrical engineer': 0.17245330615262136,
#  'deck builder': 0.3374152728029518,
#  'concrete product supplier': 0.6476523498324467,
#  'plywood supplier': 0.5854958718130581,
#  'electrical installation service': 0.6014027589934278,
#  'truss manufacturer': 0.3778224090914244,
#  'door supplier': 0.3389131449858566,
#  'wood laminate flooring supplier': 0.7380174502917,
#  'aircraft supply store': 0.24409514662261833,
#  'modular home builder': 0.17300838984520514,
#  'portable building manufacturer': 0.24409514662261833,
#  'modular home dealer': 0.25887852427956426,
#  'mulch supplier': 1.0,
#  'electrician': 0.6815571904488514,
#  'paper mill': 0.6577143803756419,
#  'energy supplier': 0.401564240872645,
#  'engineer': 0.4558772134084502,
#  'print shop': 0.8314261410683534,
#  'custom label printer': 0.37488311901084637,
#  'marketing': 0.20341748548710972,
#  'marketing agency': 0.17245330615262136,
#  'engineering consultant': 0.3037339123203988,
#  'entertainer': 0.24409514662261833,
#  'envelope supplier': 0.461558138830586,
#  'oil refinery': 0.2989251547368574,
#  'recording studio': 0.51374909141214,
#  'environment renewable natural resource': 0.12917591694169767,
#  'finishing material supplier': 0.37488311901084637,
#  'event ticket seller': 0.37488311901084637,
#  'waterproofing company': 0.6153846153846154,
#  'auto part store': 0.7094988669199906,
#  'heating oil supplier': 0.6365616336988094,
#  'family practice physician': 0.6365616336988094,
#  'machining manufacturer': 0.4783912991889597,
#  'industrial gas supplier': 0.21839373584287705,
#  'welding supply store': 0.3462468060840408,
#  'dry ice supplier': 0.24409514662261833,
#  'private equity firm': 0.2989251547368574,
#  'family service center': 0.7583071004454944,
#  'federal government office': 0.2937374739884908,
#  'vitamin supplement store': 0.5412061917451916,
#  'feed manufacturer': 0.9394269389498017,
#  'medical equipment supplier': 0.3082512379774813,
#  'medical supply store': 0.3082512379774813,
#  'medical clinic': 0.7129963266617504,
#  'research institute': 0.8479683268062419,
#  'biochemical supplier': 0,
#  'fiber optic product supplier': 0.17245330615262136,
#  'paint manufacturer': 0.9192359185997355,
#  'equipment supplier': 0.5521319647821147,
#  'food': 0.5621806695921612,
#  'pipe supplier': 0.5123353778402562,
#  'oil field equipment supplier': 0.2989251547368574,
#  'food broker': 0.14833755686686634,
#  'food manufacturer': 0.8788538778996032,
#  'food processing company': 0.5621806695921612,
#  'fence supply store': 0.37488311901084637,
#  'food producer': 0.5621806695921612,
#  'forestry service': 0.9089737082900646,
#  'foundry': 0.8620127541951508,
#  'wholesale jeweler': 0.2989251547368574,
#  'cookie shop': 0.8437775373174783,
#  'truck rental agency': 0.48270920670499107,
#  'fruit vegetable processing': 0.5378352009493783,
#  'kitchen supply store': 0.20341748548710972,
#  'hydraulic equipment supplier': 0.24409514662261833,
#  'irrigation equipment supplier': 0.7352016187252012,
#  'bearing supplier': 0.7428039481462458,
#  'metallurgy company': 0.8697315677929974,
#  'plastic injection molding service': 0.2989251547368574,
#  'general contractor': 0.9257195953197203,
#  'general hospital': 0.8401149768189771,
#  'tool manufacturer': 0.7916193159955882,
#  'industrial design company': 0.37488311901084637,
#  'hyundai dealer': 0,
#  'glass industry': 0.8244315527305931,
#  'polymer supplier': 0.3333333333333333,
#  'printing equipment supply': 0.3191895756599594,
#  'toner cartridge supplier': 0.3424301960636389,
#  'printer repair service': 0.48528352890703774,
#  'fuel supplier': 0.6365616336988094,
#  'glass manufacturer': 0.8244315527305931,
#  'plastic bag supplier': 0.2582253537214632,
#  'glassware manufacturer': 0.6253548280533437,
#  'polythene plastic sheeting supplier': 0,
#  'pvc industry': 0.5652173913043478,
#  'countertop store': 0.4953783145603117,
#  'cabinet store': 0.46491077566393807,
#  'fiberglass supplier': 0.43141138915474486,
#  'golf cart dealer': 0.48270920670499107,
#  'auto repair shop': 0.14833755686686634,
#  'hose supplier': 0.6402616856635636,
#  'rubber product supplier': 0.6192654927328665,
#  'automotive': 0.37488311901084637,
#  'commercial refrigerator supplier': 0.37488311901084637,
#  'golf club': 0.29054969064694397,
#  'golf course': 0.29054969064694397,
#  'green energy supplier': 0.10570727898967354,
#  'greenhouse': 0.6088699363760065,
#  'auto glass shop': 0.14833755686686634,
#  'lighting manufacturer': 0.947337196830142,
#  'cement manufacturer': 0.35581457655797505,
#  'brick manufacturer': 0.43614048824278817,
#  'natural stone supplier': 0.37488311901084637,
#  'gym': 1.0,
#  'marble supplier': 0.4208362571589232,
#  'corporate gift supplier': 0.5893036212289409,
#  'shipbuilding repair company': 0,
#  'construction maintenance office': 0.9310286727897411,
#  'boiler manufacturer': 0.685738020488067,
#  'container supplier': 0.5400804929970692,
#  'home construction': 0.4198969473373922,
#  'health': 0.8788538778996032,
#  'heart hospital': 0.6666666666666666,
#  'spring supplier': 0.9105771417250885,
#  'electric utility manufacturer': 0.2989251547368574,
#  'aircraft manufacturer': 0.8480042189388519,
#  'metal heat treating service': 0.5380180285434618,
#  'plating service': 0.9553284286534457,
#  'automation company': 0.2222222222222222,
#  'heating contractor': 0.8591155942617521,
#  'plumbing supply store': 0.5175735788337962,
#  'gun shop': 0.6602640386567461,
#  'ammunition supplier': 0.798364177221176,
#  'pipe manufacturer': 0.5123353778402562,
#  'school': 1.0,
#  'fire protection equipment supplier': 0.20341748548710972,
#  'agricultural machinery manufacturer': 0.40024725935236766,
#  'lawn mower store': 0.6365616336988094,
#  'lawn irrigation equipment supplier': 0.48270920670499107,
#  'financial consultant': 0.35581457655797505,
#  'helicopter charter': 0.6350972959643788,
#  'packaging machinery': 0.08516885643976688,
#  'historical landmark': 0.6339326370718169,
#  'electronics manufacturer': 0.24409514662261833,
#  'graphic designer': 0.6856777223170878,
#  'eye care center': 0.5228224107685725,
#  'optical product manufacturer': 0.9293020998846204,
#  'image consultant': 0.3611627773218964,
#  'cleaning product supplier': 0.24409514662261833,
#  'fireplace store': 0.48528352890703774,
#  'home builder': 0.4198969473373922,
#  'tool die shop': 0.7218561374202516,
#  'metal stamping service': 0.2989251547368574,
#  'environmental organization': 0.5154325235390578,
#  'food processing equipment': 0.3168717691820676,
#  'loan agency': 0.6724799715677215,
#  'power plant equipment supplier': 0.48270920670499107,
#  'home good store': 0.5656724394626971,
#  'engine rebuilding service': 0.14833755686686634,
#  'air compressor supplier': 0.08516885643976688,
#  'honda dealer': 0,
#  'elevator manufacturer': 0.39139570448920796,
#  'crane dealer': 0.4330725642896344,
#  'crane rental agency': 0.588918808745271,
#  'compound building': 0.17245330615262136,
#  'tractor dealer': 0.24409514662261833,
#  'furnace part supplier': 0.37488311901084637,
#  'heating equipment supplier': 0.5727737837818918,
#  'pneumatic tool supplier': 0.37488311901084637,
#  'truck stop': 0.6365616336988094,
#  'computer hardware manufacturer': 0.611605421752781,
#  'satellite communication service': 0.9019669468713154,
#  'hospital': 0.8401149768189771,
#  'electronics company': 0.7577077557992062,
#  'electronic part supplier': 0.8463392391180321,
#  'hvac contractor': 0.7142857142857143,
#  'industrial engineer': 0.17245330615262136,
#  'contact lens supplier': 0.48270920670499107,
#  'information service': 0.44622834892232127,
#  'building': 0.9310286727897411,
#  'water work equipment supplier': 0.37488311901084637,
#  'measuring instrument supplier': 0.7702731530065885,
#  'scientific equipment supplier': 0.20341748548710972,
#  'medical center': 0.8401149768189771,
#  'watch manufacturer': 0.4656496496703559,
#  'corporate entertainment service': 0.8114867284165843,
#  'insurance': 0.5477110830860815,
#  'record company': 0.497789991223762,
#  'video duplication service': 0.7451342788741513,
#  'insurance agency': 0.5477110830860815,
#  'lighting store': 0.947337196830142,
#  'lighting wholesaler': 0.947337196830142,
#  'entertainment agency': 0.8905530859566619,
#  'insurance broker': 0.5477110830860815,
#  'electrical equipment supplier': 0.5973050732154807,
#  'electric motor store': 0.17245330615262136,
#  'railroad company': 0.9105771417250885,
#  'electrical supply store': 0.5973050732154807,
#  'insurance company': 0.5477110830860815,
#  'factory equipment supplier': 0.24409514662261833,
#  'investment service': 0.822060257862576,
#  'laser equipment supplier': 0.3341360887539999,
#  'executive suite rental agency': 0.6997830116337383,
#  'truck dealer': 0.37488311901084637,
#  'motor vehicle dealer': 0.6365616336988094,
#  'car dealer': 0.6365616336988094,
#  'truck topper supplier': 0.3137769626591068,
#  'police supply store': 0.3845522667575446,
#  'iron steel contractor': 0.17245330615262136,
#  'fire department equipment supplier': 0.20341748548710972,
#  'towing equipment provider': 1.0,
#  'logistics service': 0.6936768969933295,
#  'trailer manufacturer': 0.9643273850442625,
#  'trailer dealer': 0.5808791572071914,
#  'dealer': 0.7851346881537634,
#  'auto spring shop': 0.14833755686686634,
#  'auto upholsterer': 0.17245330615262136,
#  'auto body part supplier': 0.7094988669199906,
#  'car factory': 0.48270920670499107,
#  'freight forwarding service': 0.8401149768189771,
#  'brake shop': 0.2466273545768897,
#  'railroad equipment supplier': 0.36413644538621126,
#  'jewelry equipment supplier': 0.6752788328410487,
#  'boat builder': 1.0,
#  'ship building': 1.0,
#  'marine supply store': 0.48270920670499107,
#  'boat dealer': 0.7364300943635819,
#  'kawasaki motorcycle dealer': 0,
#  'knife manufacturing': 0.8443268980015263,
#  'labor union': 0.6006618462197832,
#  'furniture maker': 0.9589015523436788,
#  'banking finance': 0.5035544482293756,
#  'furniture manufacturer': 0.879558569652498,
#  'logistics': 0.6936768969933295,
#  'massage supply store': 0.3230659936552878,
#  'telecommunication equipment supplier': 0.48270920670499107,
#  'baby store': 0.24409514662261833,
#  'molding supplier': 0.2989251547368574,
#  'office equipment supplier': 0.20341748548710972,
#  'office furniture store': 0.37488311901084637,
#  'store equipment supplier': 0.24409514662261833,
#  'laboratory': 0.27402584821553533,
#  'health beauty shop': 0.2989251547368574,
#  'learning center': 0.5778549884979471,
#  'dental laboratory': 0.5665398207273191,
#  'land surveyor': 0.2486327126998068,
#  'educational supply store': 0.6365616336988094,
#  'jewelry store': 0.6365616336988094,
#  'playground equipment supplier': 0.5389718247009109,
#  'outdoor sport store': 0.4700100922261463,
#  'toy store': 0.37488311901084637,
#  'security service': 0.2989251547368574,
#  'sign shop': 0.6059986444669639,
#  'office supply store': 0.6365616336988094,
#  'landscaper': 0,
#  'gasket manufacturer': 0.7121499322161745,
#  'piano maker': 0.281892775459689,
#  'piano store': 0.6135941319459651,
#  'funeral home': 1.0,
#  'monument': 0.2632628633144879,
#  'book publisher': 0.6600675099500067,
#  'wig shop': 0.5029527076138053,
#  'laundromat': 1.0,
#  'auto wrecker': 0.6365616336988094,
#  'auto part market': 0.7094988669199906,
#  'jeep dealer': 0,
#  'restaurant supply store': 0.36413644538621126,
#  'roofing supply store': 0.8598469419552878,
#  'law firm': 0.6602640386567461,
#  'building material market': 0.37488311901084637,
#  'camera store': 0.5002175015319839,
#  'lawn care service': 0.4214298566403791,
#  'computer security service': 0.2989251547368574,
#  'computer store': 0.20341748548710972,
#  'design agency': 0.5005833906196755,
#  'diagnostic center': 1.0,
#  'laboratory equipment supplier': 0.47357856884302907,
#  'home theater store': 0.8401149768189771,
#  'metal industry supplier': 0.7129963266617504,
#  'landscaping supply store': 0.5427948801689131,
#  'appliance part supplier': 0.7113555817008604,
#  'vacuum cleaner store': 0.7094988669199906,
#  'audio visual equipment supplier': 0.9200574884094885,
#  'lawyer': 0.8807291832885272,
#  'cell phone store': 0.5893036212289409,
#  'bathroom supply store': 0.3611627773218964,
#  'leasing service': 0.8398232596507063,
#  'construction machine dealer': 0.24409514662261833,
#  'dairy farm equipment supplier': 0.24409514662261833,
#  'propane supplier': 0.5427948801689131,
#  'legal service': 0.802954498479696,
#  'janitorial equipment supplier': 0.8469349217578641,
#  'life insurance agency': 0.37488311901084637,
#  'railroad contractor': 0.9019669468713154,
#  'swimming pool supply store': 0.4214298566403791,
#  'light bulb supplier': 0.8042231993688148,
#  'linen store': 0.8229056261104315,
#  'metal construction company': 0.3640193756741945,
#  'local government office': 0.24409514662261833,
#  'logging contractor': 0.9200574884094885,
#  'machine shop': 0.48270920670499107,
#  'hotel supply store': 0.6878641411307941,
#  'import export company': 0.20341748548710972,
#  'sewing company': 0.37488311901084637,
#  'research foundation': 0.8479683268062419,
#  'machinery part manufacturer': 0.7093298751903218,
#  'sport accessory wholesaler': 0.2989251547368574,
#  'fashion designer': 0.46491077566393807,
#  'cheese manufacturer': 0.7113478069283244,
#  'cheese shop': 0.7113478069283244,
#  'shipping mailing': 0.8401149768189771,
#  'wholesale food store': 0.402412998150745,
#  'organic food store': 0.2989251547368574,
#  'pie shop': 0.6387920848068563,
#  'auction house': 0.5833722638424459,
#  'livestock auction house': 0.5745751712851589,
#  'cotton exporter': 0.24213053105818025,
#  'plastic wholesaler': 0.6365616336988094,
#  'mailing service': 0.8401149768189771,
#  'manufacturer': 0.11439839887088857,
#  'gas station': 0.6365616336988094,
#  'beer distributor': 0.9394269389498017,
#  'alcoholic beverage wholesaler': 0.7577077557992062,
#  'religious good store': 1.0,
#  'book wholesaler': 0.2673224186347812,
#  'masonry supply store': 0.37488311901084637,
#  'wholesale florist': 0.2673224186347812,
#  'florist': 0.8934099845459849,
#  'marine engineer': 0.17245330615262136,
#  'paint store': 0.37488311901084637,
#  'used auto part store': 0.6365616336988094,
#  'masonry contractor': 0.44489436856453907,
#  'used car dealer': 0.6365616336988094,
#  'used truck dealer': 0.6365616336988094,
#  'massage therapist': 0.34363635722486485,
#  'material handling equipment supplier': 0.332023808663245,
#  'marina': 0.8106180309403008,
#  'meat packer': 0.31620785066798135,
#  'mattress store': 0.8401149768189771,
#  'blind shop': 0.9153224945101938,
#  'interior designer': 0.5175735788337962,
#  'window treatment store': 0.48270920670499107,
#  'appliance store': 0.6365616336988094,
#  'health food store': 0.2989251547368574,
#  'direct mail advertising': 0.17245330615262136,
#  'meat wholesaler': 0.31620785066798135,
#  'butcher shop deli': 0.5342691059148444,
#  'italian grocery store': 0.14285714285714285,
#  'market': 0.20341748548710972,
#  'food service': 0.48270920670499107,
#  'grocery delivery service': 0.8401149768189771,
#  'wine store': 0.8905530859566619,
#  'liquor store': 0.9113160638548322,
#  'kiosk': 0,
#  'optometrist': 0.44545859484674494,
#  'optician': 0.33281404039050166,
#  'mechanical contractor': 0.6565921178874996,
#  'mechanical engineer': 0.17245330615262136,
#  'cafe': 0.4881855834352799,
#  'jeweler': 0.5412061917451916,
#  'leather good store': 0.6365616336988094,
#  'gift shop': 0.9220069972820306,
#  'craft store': 0.45316640078743653,
#  'hobby store': 0.37488311901084637,
#  'fabric wholesaler': 0.37488311901084637,
#  'scrap metal dealer': 0.2989251547368574,
#  'quilt shop': 0.2,
#  'sheet music store': 0.37488311901084637,
#  'musical instrument manufacturer': 0.23902864564639348,
#  'music store': 0.37488311901084637,
#  'musical instrument store': 0.37488311901084637,
#  'band': 0.497789991223762,
#  'bookstore': 0,
#  'art museum': 0.37488311901084637,
#  'newsstand': 1.0,
#  'medical equipment manufacturer': 0.8678193729480344,
#  'fashion accessory store': 0.344547856195199,
#  'discount store': 0.5427948801689131,
#  'cemetery': 0.8475982933896377,
#  'bus stop': 0.5413553221376213,
#  'variety store': 0.6365616336988094,
#  'thrift store': 1.0,
#  'medical group': 0.7129963266617504,
#  'donation center': 0.757923746068198,
#  'pet store': 0.35581457655797505,
#  'art gallery': 0.2989251547368574,
#  'art dealer': 0.2989251547368574,
#  'housing development': 0.6747789801802799,
#  'mobile home dealer': 0.3234260951175617,
#  'convenience store': 0.764171184457154,
#  'medical office': 0.7129963266617504,
#  'medical technology manufacturer': 0.8678193729480344,
#  'childrens furniture store': 0,
#  'mental health clinic': 0.43379867639900227,
#  'airline': 0.5106778057190418,
#  'aviation consultant': 0.5103636176242264,
#  'travel agency': 0.4912421772488671,
#  'travel service': 0.4912421772488671,
#  'airport': 0.7583071004454944,
#  'mental health service': 0.43379867639900227,
#  'shipping company': 0.8401149768189771,
#  'metal fabricator': 0.3640193756741945,
#  'cruise line company': 0.37488311901084637,
#  'towing service': 1.0,
#  'ferry terminal': 0.2222222222222222,
#  'ferry service': 0.8,
#  'metal finisher': 0.5103636176242264,
#  'boat tour agency': 0.9089737082900646,
#  'bus company': 0.5413553221376213,
#  'moving company': 0.7971129309349386,
#  'moving storage service': 0.7971129309349386,
#  'state department transportation': 0.3178882953438966,
#  'department transportation': 0.3845522667575446,
#  'handicapped transportation service': 1.0,
#  'railway service': 0.8970671711869902,
#  'train station': 0.37488311901084637,
#  'bus depot': 0.888245164653896,
#  'bus charter': 0.8401149768189771,
#  'metal processing company': 0.3640193756741945,
#  'mixed use': 0.37488311901084637,
#  'motorcycle shop': 0.8293843130197884,
#  'limousine service': 1.0,
#  'chauffeur service': 0.5427948801689131,
#  'school bus service': 0.8401149768189771,
#  'airport shuttle service': 0.6365616336988094,
#  'tourist information center': 0.4323943804654636,
#  'carriage ride service': 0.8789618730340989,
#  'cruise agency': 0.44622834892232127,
#  'tourist attraction': 0.4323943804654636,
#  'ski resort': 0.3370042346712697,
#  'ski area': 0.3370042346712697,
#  'fixed base operator': 0.48270920670499107,
#  'aircraft maintenance company': 0.6320247471868171,
#  'motorsports store': 0,
#  'boat rental service': 0.24409514662261833,
#  'utility trailer dealer': 0.48270920670499107,
#  'forklift dealer': 0.33770577618809333,
#  'municipal administration office': 0.16285898823168393,
#  'nephrologist': 0,
#  'bus coach company': 0.8401149768189771,
#  'shipping service': 0.8401149768189771,
#  'shipping mailing service': 0.8401149768189771,
#  'newspaper publisher': 0.7350556422195847,
#  'shredding service': 0.5475424764091885,
#  'nuclear power company': 0.3812384644298092,
#  'nursing home': 1.0,
#  'medium company': 0.2855322653648754,
#  'multimedia electronic book publisher': 0.6602640386567461,
#  'internet marketing service': 0.17245330615262136,
#  'greeting card shop': 0.7409112234790852,
#  'theme park': 1.0,
#  'film production company': 0.3134184668906915,
#  'obstetrician gynecologist': 1.0,
#  'movie studio': 0.3990006673070808,
#  'video production service': 0.4885324307470056,
#  'movie theater': 0.36305852577785885,
#  'theater company': 0.6602640386567461,
#  'performing art theater': 0.3986648623146714,
#  'occupational safety health': 0.7807789774739647,
#  'office space rental agency': 0.37488311901084637,
#  'commercial real estate agency': 0.8401149768189771,
#  'art school': 0.24409514662261833,
#  'music publisher': 0.5400804929970692,
#  'printed music publisher': 0.37488311901084637,
#  'home audio store': 0.8401149768189771,
#  'musician': 1.0,
#  'music management promotion': 0.8401149768189771,
#  'video editing service': 0.7451342788741513,
#  'office supply wholesaler': 0.6511301417686322,
#  'official residence': 0.2222222222222222,
#  'orthopedic clinic': 0.7724351171857794,
#  'painter': 0.16285898823168393,
#  'painting': 0.44068030425224824,
#  'telephone company': 0.7695005099892119,
#  'medium house': 0.2855322653648754,
#  'paper distributor': 0.5893250255664316,
#  'news service': 0.7094988669199906,
#  'public library': 0.37488311901084637,
#  'law library': 0.5175735788337962,
#  'museum': 0.9517140391719545,
#  'federal reserve bank': 0.8401149768189771,
#  'credit union': 0.42244660561849634,
#  'atm': 0.6997292924605046,
#  'paving contractor': 0.8788538778996032,
#  'mortgage lender': 0.5696506622962453,
#  'investment bank': 0.5549384323170297,
#  'check cashing service': 0.8403240470478353,
#  'stock broker': 0.37488311901084637,
#  'health consultant': 0.20341748548710972,
#  'health insurance agency': 0.24409514662261833,
#  'payroll service': 0.6602640386567461,
#  'pediatrician': 1.0,
#  'human resource consulting': 0.651871702941267,
#  'pest control service': 0.7862428070124468,
#  'pet boarding service': 0.477041938180072,
#  'pet care': 0.477041938180072,
#  'loss adjuster': 0.5110504867568866,
#  'pharmaceutical company': 0.8340177353295776,
#  'pharmaceutical product wholesaler': 0.9019669468713154,
#  'pharmacy': 0.43652535971905876,
#  'educational institution': 0.9200574884094885,
#  'retirement community': 0.8620573455794822,
#  'fraternal organization': 1.0,
#  'photo lab': 0.17245884476238132,
#  'property investment': 0.41783722751264046,
#  'photographer': 0.5384615384615384,
#  'photography school': 0.7550951308902007,
#  'star hotel': 0,
#  'convention center': 0.6985674826354195,
#  'real estate appraiser': 0.5420695445695504,
#  'photography service': 0.7550951308902007,
#  'resort hotel': 0.5549384323170297,
#  'real estate consultant': 1.0,
#  'car rental agency': 0.6446338474049024,
#  'car leasing service': 0.6367496520369909,
#  'ford dealer': 0,
#  'car finance loan company': 0.20341748548710972,
#  'trailer rental service': 0.5808791572071914,
#  'furniture rental service': 0.24409514662261833,
#  'tuxedo shop': 0.3971926822554664,
#  'dress tuxedo rental service': 0.32760126881300783,
#  'wedding store': 0.19527122273431988,
#  'video store': 0.6365616336988094,
#  'movie rental': 0.48262190907480623,
#  'photography studio': 0.7550951308902007,
#  'home health care service': 0.8401149768189771,
#  'skateboard shop': 1.0,
#  'event technology service': 0.48270920670499107,
#  'party equipment rental service': 0.41940092022481734,
#  'construction machine rental service': 0.37488311901084637,
#  'audio visual equipment rental service': 0.9200574884094885,
#  'shipping equipment industry': 0.24409514662261833,
#  'physical therapy clinic': 0.3981135557023664,
#  'plastic fabrication company': 0.5589870656990277,
#  'plastic product supplier': 0.5589870656990277,
#  'auto tag agency': 0.2989251547368574,
#  'department motor vehicle': 0.3845522667575446,
#  'notary public': 0.8782809948064147,
#  'private investigator': 0.2989251547368574,
#  'escrow service': 0.7508769412563502,
#  'real estate agent': 1.0,
#  'playground': 0.18314728256823934,
#  'plumber': 0.5333343920587591,
#  'port authority': 0.8181092508446417,
#  'portrait studio': 0.596096295802428,
#  'post office': 0.8970671711869902,
#  'professional service': 0.5407934815331834,
#  'university hospital': 0.8401149768189771,
#  'public relation firm': 0.17245330615262136,
#  'civil engineering company': 1.0,
#  'drafting service': 0.5185642123999752,
#  'pump supplier': 0.7757537847086349,
#  'interior construction contractor': 0.6365616336988094,
#  'carpet cleaning service': 0.5104150109741624,
#  'exhibition planner': 0.48270920670499107,
#  'decal supplier': 0,
#  'stage lighting equipment supplier': 0.37488311901084637,
#  'event management company': 0.48270920670499107,
#  'radio broadcaster': 0.08516885643976688,
#  'computer support service': 0.37488311901084637,
#  'ravine': 0,
#  'employment center': 0.8700719519435725,
#  'national health foundation': 0.48270920670499107,
#  'real estate developer': 0.37488311901084637,
#  'advertising agency': 0.22899278575874843,
#  'promotional product supplier': 0.1111111111111111,
#  'advertising service': 0.22899278575874843,
#  'record storage facility': 0.37488311901084637,
#  'fund management company': 0.2989251547368574,
#  'recreation center': 0.6588657588361996,
#  'bakery': 0.6569671408390381,
#  'database management company': 0.757923746068198,
#  'market researcher': 0.24409514662261833,
#  'recycling center': 0.20839911546497264,
#  'regional government office': 0.15384615384615385,
#  'rehabilitation center': 0.7409112234790852,
#  'religious institution': 1.0,
#  'religious organization': 1.0,
#  'repair service': 0.4783912991889597,
#  'emergency veterinarian service': 0.24409514662261833,
#  'pet sitter': 0.477041938180072,
#  'research product development': 0.8479683268062419,
#  'building society': 0.9310286727897411,
#  'valet parking service': 0.6382068234672832,
#  'nursing agency': 1.0,
#  'executive search firm': 0.874299728391171,
#  'recruiter': 0,
#  'temp agency': 0,
#  'health center': 0.8401149768189771,
#  'restaurant': 0.7065526961238439,
#  'roofing contractor': 0.2964723158788569,
#  'sport nutrition store': 0.2989251547368574,
#  'credit reporting agency': 0.12917591694169767,
#  'automobile storage facility': 0.37488311901084637,
#  'debt collection agency': 0.2545910715984998,
#  'park': 0.2989251547368574,
#  'court reporter': 0.5819253370730626,
#  'bus tour agency': 0.3973900331741193,
#  'tour operator': 0.586369150464167,
#  'convention information bureau': 0.6985674826354195,
#  'balloon ride tour agency': 0.9019669468713154,
#  'security guard service': 0.2989251547368574,
#  'locksmith': 0.8600392940200164,
#  'commercial cleaning service': 0.2989251547368574,
#  'blast cleaning service': 0.25887852427956426,
#  'conference center': 0.7514331300839273,
#  'safety equipment supplier': 0.20341748548710972,
#  'garbage dump': 0.4700100922261463,
#  'sanitation service': 0.45943249576071976,
#  'garbage dump service': 0.6565921178874996,
#  'environmental health service': 0.31042072637202806,
#  'portable toilet supplier': 0.37488311901084637,
#  'public work department': 0.3819136260337411,
#  'school district office': 1.0,
#  'sailmaker': 0,
#  'community college': 0.8401149768189771,
#  'salvage yard': 0.24152948254127113,
#  'business school': 0.48270920670499107,
#  'trade school': 0.37488311901084637,
#  'private university': 0.8401149768189771,
#  'computer training school': 0.48270920670499107,
#  'school supply store': 0.48270920670499107,
#  'screen printer': 1.0,
#  'medium consultant': 0.2855322653648754,
#  'beauty school': 0.37488311901084637,
#  'flight school': 0.6660737498977496,
#  'seaport': 0.37488311901084637,
#  'security system supplier': 0.2989251547368574,
#  'middle school': 1.0,
#  'nonprofit': 0,
#  'shooting range': 0.5087536112410581,
#  'soccer club': 0.6815571904488514,
#  'camp': 0.9220069972820306,
#  'diving contractor': 0.6997292924605046,
#  'language school': 0.6887351473112096,
#  'english language school': 0.15384615384615385,
#  'preschool': 1.0,
#  'self storage facility': 0.9099222675139497,
#  'semi conductor supplier': 0.2218085303102923,
#  'driving school': 0.5424336722983086,
#  'trucking school': 0.2218085303102923,
#  'senior citizen center': 0.6097725499371341,
#  'service': 0.37488311901084637,
#  'childrens hospital': 0,
#  'dental supply store': 0.7372080861906722,
#  'shipyard': 1.0,
#  'orthodox synagogue': 0,
#  'short term apartment rental agency': 0.37488311901084637,
#  'nutritionist': 1.0,
#  'ophthalmologist': 0.16285898823168393,
#  'ophthalmology clinic': 0.15384615384615385,
#  'social service organization': 0.8729747415915995,
#  'social welfare center': 0.8729747415915995,
#  'solar energy company': 0.5598611705240579,
#  'solar energy equipment supplier': 0.5598611705240579,
#  'special education school': 0.8401149768189771,
#  'podiatrist': 1.0,
#  'reproductive health clinic': 0.6153846153846154,
#  'sporting good store': 0.497789991223762,
#  'dialysis center': 0.9042842652183054,
#  'sport complex': 0.38983434537868894,
#  'wellness program': 0.25,
#  'sportswear store': 0.2,
#  'private hospital': 0.8401149768189771,
#  'radiologist': 0.3333333333333333,
#  'medical diagnostic imaging center': 0.8341424487621473,
#  'ray lab': 0.9394269389498017,
#  'blood bank': 0.8374361353044526,
#  'stainless steel plant': 1.0,
#  'state agency': 0.30271425464970275,
#  'heliport': 0,
#  'health care company': 0.8401149768189771,
#  'psychiatric hospital': 1.0,
#  'state government office': 0.30271425464970275,
#  'medical institution': 0.8401149768189771,
#  'steel construction company': 0.2855322653648754,
#  'cleaning service': 0.5640616287111175,
#  ...}
